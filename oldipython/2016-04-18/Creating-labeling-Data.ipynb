# %%
def add_label(data,label):
    start = time.time()
    data[u'label']=0
    label_num=1
    for i in range(0,len(data)):
        
        if label_num!=len(label):
            if data[u'Time'][i] > label[u'#Time'][label_num]:
                label_num +=1
            
        data[u'label'][i]=label[u'Info1'][label_num-1]
        
        #debug
        #print 'mm[label][%d]=%s' %(i,mm[u'label'][i])
    elapsed_time = time.time() - start
    print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack
from scipy import signal
import pandas as pd
import time
# %matplotlib inline

# %%
cd ~/Documents/01_SensorData/2016_04_12/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/01_SensorData/2016_04_12/cleaning-addingLABEL

# %%
ls
# Out:
# 20160331_180615.srt               exercises-1/
# Cleaning-Conv-left-hand-ags.csv   exercises-2/
# Cleaning-Conv-left-leg-ags.csv    exercises-3/
# Cleaning-Conv-right-hand-ags.csv  exercises-4/
# Cleaning-Conv-right-leg-ags.csv   exercises-5/
# Cleaning-Conv-west-ags.csv        exercises-6/
# CleaningConv-left-hand-ags.csv    exercises-finish/
# CleaningConv-left-leg-ags.csv     exercises-start/
# CleaningConv-right-hand-ags.csv   free/
# CleaningConv-right-leg-ags.csv    get-away-things/
# CleaningConv-west-ags.csv         grap-big-box/
# Cleaning_left_hand_ags.csv        grap-bloom/
# Conv-left-hand-ags.csv            grap-cleaner/
# Conv-left-hand-batt.csv           grap-small-box/
# Conv-left-leg-ags.csv             grap-small-box-one-hand/
# Conv-left-leg-batt.csv            label-data.csv
# Conv-right-hand-ags.csv           left-hand.csv
# Conv-right-hand-batt.csv          left-leg.csv
# Conv-right-leg-ags.csv            missing/
# Conv-right-leg-batt.csv           put-away-bloom/
# Conv-west-ags.csv                 put-big-box/
# Conv-west-batt.csv                put-on-bloom/
# DeviceSet1.avi                    put-on-cleaner/
# SP-left-hand-acc.dat              put-small-box/
# SP-left-hand-acc.dat.cache        put-small-box-one-hand/
# SP-left-hand-batt.dat             rift-big-box/
# SP-left-hand-gyr.dat              rift-cleaner/
# SP-left-hand-gyr.dat.cache        rift-small-box/
# SP-left-leg-acc.dat               right-hand.csv
# SP-left-leg-acc.dat.cache         right-leg.csv
# SP-left-leg-batt.dat              scale-miss/
# SP-left-leg-gyr.dat               shaking-arm/
# SP-left-leg-gyr.dat.cache         stop/
# SP-right-hand-acc.dat             stop-with-one-hand-cleaner/
# SP-right-hand-acc.dat.cache       take-big-box/
# SP-right-hand-batt.dat            use-bloom/
# SP-right-hand-gyr.dat             use-cleaner/
# SP-right-hand-gyr.dat.cache       walking/
# SP-right-leg-acc.dat              walking-back-arm/
# SP-right-leg-acc.dat.cache        walking-back-arm-turn/
# SP-right-leg-batt.dat             walking-change-hand/
# SP-right-leg-gyr.dat              walking-changed-with-small-box/
# SP-right-leg-gyr.dat.cache        walking-changed-with-small-box-turn/
# SP-west-acc.dat                   walking-cross-arm/
# SP-west-acc.dat.cache             walking-cross-arm-turn/
# SP-west-batt.dat                  walking-turn/
# SP-west-gyr.dat                   walking-with-arm-on-west/
# SP-west-gyr.dat.cache             walking-with-bloom/
# Spectrol-Data-Lefthand-walking    walking-with-bloom-one-hand/
# UNKNOWN/                          walking-with-one-hand-cleaner/
# back-up.zip                       walking-with-shaking-hand/
# cleaning.spe                      walking-with-shaking-hand-turn/
# cleaning_20160331.csv             walking-with-small-box/
# cleaning_20160331.spa             walking-with-small-box-turn/
# cleaning_20160331.spa.old         west.csv

# %%
data = pd.read_csv('Conv-left-hand-ags.csv',encoding="SHIFT-JIS")

# %%
data.columns=[u'Type',u'Time',u'AccX',u'AccY',u'AccZ',u'GyrX',u'GyrY',u'GyrZ']

# %%
label=pd.read_csv("cleaning_20160331.csv",encoding="SHIFT-JIS")
label[u'#Time']=pd.to_datetime(label[u'#Time'])
label
# Out:
#                       #Time                           Info1  Info2  Info3
# 0   2016-04-22 18:06:15.696                         walking    NaN    NaN
# 1   2016-04-22 18:06:18.745                    walking-turn    NaN    NaN
# 2   2016-04-22 18:06:19.570                         walking    NaN    NaN
# 3   2016-04-22 18:06:23.588                    walking-turn    NaN    NaN
# 4   2016-04-22 18:06:24.492                         walking    NaN    NaN
# 5   2016-04-22 18:06:28.200                    walking-turn    NaN    NaN
# 6   2016-04-22 18:06:29.954                         walking    NaN    NaN
# 7   2016-04-22 18:06:33.333                    walking-turn    NaN    NaN
# 8   2016-04-22 18:06:34.999                         walking    NaN    NaN
# 9   2016-04-22 18:06:39.181                    walking-turn    NaN    NaN
# 10  2016-04-22 18:06:44.914                    walking-turn    NaN    NaN
# 11  2016-04-22 18:06:45.904                walking-back-arm    NaN    NaN
# 12  2016-04-22 18:06:50.468           walking-back-arm-turn    NaN    NaN
# 13  2016-04-22 18:06:51.878                walking-back-arm    NaN    NaN
# 14  2016-04-22 18:06:55.595           walking-back-arm-turn    NaN    NaN
# 15  2016-04-22 18:06:57.390                walking-back-arm    NaN    NaN
# 16  2016-04-22 18:07:00.560               walking-cross-arm    NaN    NaN
# 17  2016-04-22 18:07:01.884          walking-cross-arm-turn    NaN    NaN
# 18  2016-04-22 18:07:03.487               walking-cross-arm    NaN    NaN
# 19  2016-04-22 18:07:07.542          walking-cross-arm-turn    NaN    NaN
# 20  2016-04-22 18:07:09.139               walking-cross-arm    NaN    NaN
# 21  2016-04-22 18:07:13.208          walking-cross-arm-turn    NaN    NaN
# 22  2016-04-22 18:07:15.430               walking-cross-arm    NaN    NaN
# 23  2016-04-22 18:07:19.466          walking-cross-arm-turn    NaN    NaN
# 24  2016-04-22 18:07:21.022               walking-cross-arm    NaN    NaN
# 25  2016-04-22 18:07:23.462                         walking    NaN    NaN
# 26  2016-04-22 18:07:24.360                  grap-small-box    NaN    NaN
# 27  2016-04-22 18:07:25.316                  rift-small-box    NaN    NaN
# 28  2016-04-22 18:07:27.035          walking-with-small-box    NaN    NaN
# 29  2016-04-22 18:07:30.612     walking-with-small-box-turn    NaN    NaN
# ..                      ...                             ...    ...    ...
# 147 2016-04-22 18:13:57.386                    walking-turn    NaN    NaN
# 148 2016-04-22 18:14:00.854                         walking    NaN    NaN
# 149 2016-04-22 18:14:04.031                    walking-turn    NaN    NaN
# 150 2016-04-22 18:14:05.844                         walking    NaN    NaN
# 151 2016-04-22 18:14:09.631                    walking-turn    NaN    NaN
# 152 2016-04-22 18:14:11.867                         walking    NaN    NaN
# 153 2016-04-22 18:14:14.867                            stop    NaN    NaN
# 154 2016-04-22 18:14:15.871                     shaking-arm    NaN    NaN
# 155 2016-04-22 18:14:25.706                         walking    NaN    NaN
# 156 2016-04-22 18:14:28.013                            stop    NaN    NaN
# 157 2016-04-22 18:14:29.862                         walking    NaN    NaN
# 158 2016-04-22 18:14:32.954                    walking-turn    NaN    NaN
# 159 2016-04-22 18:14:34.098                         walking    NaN    NaN
# 160 2016-04-22 18:14:38.841                    walking-turn    NaN    NaN
# 161 2016-04-22 18:14:41.028       walking-with-shaking-hand    NaN    NaN
# 162 2016-04-22 18:14:45.999  walking-with-shaking-hand-turn    NaN    NaN
# 163 2016-04-22 18:14:48.520                         walking    NaN    NaN
# 164 2016-04-22 18:14:49.315                    walking-turn    NaN    NaN
# 165 2016-04-22 18:14:51.306                         walking    NaN    NaN
# 166 2016-04-22 18:14:52.283                    walking-turn    NaN    NaN
# 167 2016-04-22 18:14:54.227                         walking    NaN    NaN
# 168 2016-04-22 18:14:57.640                    walking-turn    NaN    NaN
# 169 2016-04-22 18:14:59.673                         walking    NaN    NaN
# 170 2016-04-22 18:15:02.634                    walking-turn    NaN    NaN
# 171 2016-04-22 18:15:08.019                         walking    NaN    NaN
# 172 2016-04-22 18:15:12.407                    walking-turn    NaN    NaN
# 173 2016-04-22 18:15:16.504                         walking    NaN    NaN
# 174 2016-04-22 18:15:20.073                            stop    NaN    NaN
# 175 2016-04-22 18:15:21.180                         walking    NaN    NaN
# 176 2016-04-22 18:15:22.789                         UNKNOWN    NaN    NaN
#
# [177 rows x 4 columns]

# %%
'Cleaning'+'aaa'
# Out:
# 'Cleaningaaa'

# %%
data=[u'Conv-left-hand-ags.csv',u'Conv-left-leg-ags.csv',u'Conv-right-hand-ags.csv',
        u'Conv-right-leg-ags.csv',u'Conv-west-ags.csv']

label=pd.read_csv("label-data.csv",encoding="SHIFT-JIS")
label[u'#Time']=pd.to_datetime(label[u'#Time'])

for i in range(5):
    df = pd.read_csv(data[i],encoding="SHIFT-JIS")
    df.columns=[u'Type',u'Time',u'AccX',u'AccY',u'AccZ',u'GyrX',u'GyrY',u'GyrZ']
    df[u'Time']=pd.to_datetime(df[u'Time'])
    add_label(df,label)
    
    df.to_csv('Cleaning-'+data[i],encoding='SHIFT-JIS')
# Out:
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# elapsed_time:1883.73794818[sec]
# elapsed_time:1881.03272605[sec]
# elapsed_time:1880.34928298[sec]
# elapsed_time:1881.4829402[sec]
# elapsed_time:1862.777987[sec]

# %%
# 165 minitues

# %%
label=pd.read_csv("label-data.csv",encoding="SHIFT-JIS")
label[u'#Time']=pd.to_datetime(label[u'#Time'])

# %%
label
# Out:
#                       #Time                           Info1  Info2  Info3
# 0   2016-04-15 18:06:15.696                         walking    NaN    NaN
# 1   2016-04-15 18:06:18.745                    walking-turn    NaN    NaN
# 2   2016-04-15 18:06:19.570                         walking    NaN    NaN
# 3   2016-04-15 18:06:23.588                    walking-turn    NaN    NaN
# 4   2016-04-15 18:06:24.492                         walking    NaN    NaN
# 5   2016-04-15 18:06:28.200                    walking-turn    NaN    NaN
# 6   2016-04-15 18:06:29.954                         walking    NaN    NaN
# 7   2016-04-15 18:06:33.333                    walking-turn    NaN    NaN
# 8   2016-04-15 18:06:34.999                         walking    NaN    NaN
# 9   2016-04-15 18:06:39.181                    walking-turn    NaN    NaN
# 10  2016-04-15 18:06:44.914                    walking-turn    NaN    NaN
# 11  2016-04-15 18:06:45.904                walking-back-arm    NaN    NaN
# 12  2016-04-15 18:06:50.468           walking-back-arm-turn    NaN    NaN
# 13  2016-04-15 18:06:51.878                walking-back-arm    NaN    NaN
# 14  2016-04-15 18:06:55.595           walking-back-arm-turn    NaN    NaN
# 15  2016-04-15 18:06:57.390                walking-back-arm    NaN    NaN
# 16  2016-04-15 18:07:00.560               walking-cross-arm    NaN    NaN
# 17  2016-04-15 18:07:01.884          walking-cross-arm-turn    NaN    NaN
# 18  2016-04-15 18:07:03.487               walking-cross-arm    NaN    NaN
# 19  2016-04-15 18:07:07.542          walking-cross-arm-turn    NaN    NaN
# 20  2016-04-15 18:07:09.139               walking-cross-arm    NaN    NaN
# 21  2016-04-15 18:07:13.208          walking-cross-arm-turn    NaN    NaN
# 22  2016-04-15 18:07:15.430               walking-cross-arm    NaN    NaN
# 23  2016-04-15 18:07:19.466          walking-cross-arm-turn    NaN    NaN
# 24  2016-04-15 18:07:21.022               walking-cross-arm    NaN    NaN
# 25  2016-04-15 18:07:23.462                         walking    NaN    NaN
# 26  2016-04-15 18:07:24.360                  grap-small-box    NaN    NaN
# 27  2016-04-15 18:07:25.316                  rift-small-box    NaN    NaN
# 28  2016-04-15 18:07:27.035          walking-with-small-box    NaN    NaN
# 29  2016-04-15 18:07:30.612     walking-with-small-box-turn    NaN    NaN
# ..                      ...                             ...    ...    ...
# 147 2016-04-15 18:13:57.386                    walking-turn    NaN    NaN
# 148 2016-04-15 18:14:00.854                         walking    NaN    NaN
# 149 2016-04-15 18:14:04.031                    walking-turn    NaN    NaN
# 150 2016-04-15 18:14:05.844                         walking    NaN    NaN
# 151 2016-04-15 18:14:09.631                    walking-turn    NaN    NaN
# 152 2016-04-15 18:14:11.867                         walking    NaN    NaN
# 153 2016-04-15 18:14:14.867                            stop    NaN    NaN
# 154 2016-04-15 18:14:15.871                     shaking-arm    NaN    NaN
# 155 2016-04-15 18:14:25.706                         walking    NaN    NaN
# 156 2016-04-15 18:14:28.013                            stop    NaN    NaN
# 157 2016-04-15 18:14:29.862                         walking    NaN    NaN
# 158 2016-04-15 18:14:32.954                    walking-turn    NaN    NaN
# 159 2016-04-15 18:14:34.098                         walking    NaN    NaN
# 160 2016-04-15 18:14:38.841                    walking-turn    NaN    NaN
# 161 2016-04-15 18:14:41.028       walking-with-shaking-hand    NaN    NaN
# 162 2016-04-15 18:14:45.999  walking-with-shaking-hand-turn    NaN    NaN
# 163 2016-04-15 18:14:48.520                         walking    NaN    NaN
# 164 2016-04-15 18:14:49.315                    walking-turn    NaN    NaN
# 165 2016-04-15 18:14:51.306                         walking    NaN    NaN
# 166 2016-04-15 18:14:52.283                    walking-turn    NaN    NaN
# 167 2016-04-15 18:14:54.227                         walking    NaN    NaN
# 168 2016-04-15 18:14:57.640                    walking-turn    NaN    NaN
# 169 2016-04-15 18:14:59.673                         walking    NaN    NaN
# 170 2016-04-15 18:15:02.634                    walking-turn    NaN    NaN
# 171 2016-04-15 18:15:08.019                         walking    NaN    NaN
# 172 2016-04-15 18:15:12.407                    walking-turn    NaN    NaN
# 173 2016-04-15 18:15:16.504                         walking    NaN    NaN
# 174 2016-04-15 18:15:20.073                            stop    NaN    NaN
# 175 2016-04-15 18:15:21.180                         walking    NaN    NaN
# 176 2016-04-15 18:15:22.789                         UNKNOWN    NaN    NaN
#
# [177 rows x 4 columns]

# %%
a=label['Info1'].drop_duplicates()

# %%
a
# Out:
# 0                                  walking
# 1                             walking-turn
# 11                        walking-back-arm
# 12                   walking-back-arm-turn
# 16                       walking-cross-arm
# 17                  walking-cross-arm-turn
# 26                          grap-small-box
# 27                          rift-small-box
# 28                  walking-with-small-box
# 29             walking-with-small-box-turn
# 34                     walking-change-hand
# 35          walking-changed-with-small-box
# 36     walking-changed-with-small-box-turn
# 40                           put-small-box
# 41                            grap-big-box
# 42                            rift-big-box
# 52                             put-big-box
# 62                            take-big-box
# 63                 grap-small-box-one-hand
# 64                  put-small-box-one-hand
# 81                                    free
# 82                            grap-cleaner
# 83                            rift-cleaner
# 84                             use-cleaner
# 85                         get-away-things
# 87           walking-with-one-hand-cleaner
# 91              stop-with-one-hand-cleaner
# 92                          put-on-cleaner
# 93                              grap-bloom
# 94                      walking-with-bloom
# 95                               use-bloom
# 99                          put-away-bloom
# 100            walking-with-bloom-one-hand
# 101                           put-on-bloom
# 106              walking-with-shaking-hand
# 113               walking-with-arm-on-west
# 114                        exercises-start
# 115                            exercises-1
# 116                            exercises-2
# 117                            exercises-3
# 118                            exercises-4
# 119                            exercises-5
# 120                            exercises-6
# 121                       exercises-finish
# 153                                   stop
# 154                            shaking-arm
# 162         walking-with-shaking-hand-turn
# 176                                UNKNOWN
# Name: Info1, dtype: object
