# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import fftpack
from scipy import signal
import numpy as np
import pandas as pd
import datetime
import time as T

# %%
sample_bit=16

# %%
#my workstation

# %%
#cd /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data/

# %%
#mozart

# %%
cd ~/Documents/SyncRecord/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/SyncRecord/cleaning-addingLABEL

# %%
fft_left_hand = pd.read_csv('FFT-Cleaning-Conv-left-hand-ags.csv-'+str(sample_bit)+'bit.csv')
#left_hand.Time=pd.to_timedelta(left_hand.Time)
fft_left_leg = pd.read_csv('FFT-'+'Cleaning-Conv-left-leg-ags.csv-'+str(sample_bit)+'bit.csv')
#left_leg.Time=pd.to_timedelta(left_leg.Time)
fft_right_hand = pd.read_csv('FFT-'+'Cleaning-Conv-right-hand-ags.csv-'+str(sample_bit)+'bit.csv')
#right_hand.Time=pd.to_timedelta(right_hand.Time)
fft_right_leg = pd.read_csv('FFT-'+'Cleaning-Conv-right-leg-ags.csv-'+str(sample_bit)+'bit.csv')
#right_leg.Time=pd.to_timedelta(right_leg.Time)
fft_west = pd.read_csv('FFT-'+'Cleaning-Conv-west-ags.csv-'+str(sample_bit)+'bit.csv')
#west.Time=pd.to_timedelta(west.Time)

fft_name=['FFT-Cleaning-Conv-left-hand-ags.csv-'+str(sample_bit)+'bit.csv','FFT-'+'Cleaning-Conv-left-leg-ags.csv-'+str(sample_bit)+'bit.csv',
          'FFT-'+'Cleaning-Conv-right-hand-ags.csv-'+str(sample_bit)+'bit.csv','FFT-'+'Cleaning-Conv-right-leg-ags.csv-'+str(sample_bit)+'bit.csv',
          'FFT-'+'Cleaning-Conv-west-ags.csv-'+str(sample_bit)+'bit.csv']

# %%
# left_hand
start_time = T.clock()
Amp_left_handAX=np.array([])
Amp_left_handAY=np.array([])
Amp_left_handAZ=np.array([])

Amp_left_handGX=np.array([])
Amp_left_handGY=np.array([])
Amp_left_handGZ=np.array([])

Amp_left_hand_label=np.array([])

x = fft_right_leg.where(fft_left_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAX = np.append(Amp_left_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAY = np.append(Amp_left_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAZ = np.append(Amp_left_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGX = np.append(Amp_left_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGY = np.append(Amp_left_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGZ = np.append(Amp_left_handGZ, tmp)

tmp =np.array( x.Label )
Amp_left_hand_label = np.append(Amp_left_hand_label, tmp)

for t in range(1,fft_left_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_left_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAX = np.vstack((Amp_left_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAY = np.vstack((Amp_left_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAZ = np.vstack((Amp_left_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGX = np.vstack((Amp_left_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGY = np.vstack((Amp_left_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGZ = np.vstack((Amp_left_handGZ, tmp))
        
        tmp =np.array( x.Label )
        Amp_left_hand_label = np.vstack((Amp_left_hand_label, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:524.358541[sec]

# %%
# right_leg
start_time = T.clock()
Amp_right_legAX=np.array([])
Amp_right_legAY=np.array([])
Amp_right_legAZ=np.array([])

Amp_right_legGX=np.array([])
Amp_right_legGY=np.array([])
Amp_right_legGZ=np.array([])

Amp_right_leg_label=np.array([])

x = fft_right_leg.where(fft_right_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAX = np.append(Amp_right_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAY = np.append(Amp_right_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAZ = np.append(Amp_right_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGX = np.append(Amp_right_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGY = np.append(Amp_right_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGZ = np.append(Amp_right_legGZ, tmp)

tmp =np.array( x.Label )
Amp_right_leg_label = np.append(Amp_right_leg_label, tmp)

for t in range(1,fft_right_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_right_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAX = np.vstack((Amp_right_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAY = np.vstack((Amp_right_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAZ = np.vstack((Amp_right_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGX = np.vstack((Amp_right_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGY = np.vstack((Amp_right_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGZ = np.vstack((Amp_right_legGZ, tmp))
        
        tmp =np.array( x.Label )
        Amp_right_leg_label = np.vstack((Amp_right_leg_label, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:173.86008[sec]

# %%
# Left_leg
start_time = T.clock()
Amp_left_legAX=np.array([])
Amp_left_legAY=np.array([])
Amp_left_legAZ=np.array([])

Amp_left_legGX=np.array([])
Amp_left_legGY=np.array([])
Amp_left_legGZ=np.array([])

Amp_left_leg_label =np.array([])

x = fft_left_leg.where(fft_left_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAX = np.append(Amp_left_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAY = np.append(Amp_left_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAZ = np.append(Amp_left_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGX = np.append(Amp_left_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGY = np.append(Amp_left_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGZ = np.append(Amp_left_legGZ, tmp)

tmp =np.array( x.Label )
Amp_left_leg_label = np.append(Amp_left_leg_label, tmp)

for t in range(1,fft_left_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_left_leg.where(fft_left_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAX = np.vstack((Amp_left_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAY = np.vstack((Amp_left_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAZ = np.vstack((Amp_left_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGX = np.vstack((Amp_left_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGY = np.vstack((Amp_left_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGZ = np.vstack((Amp_left_legGZ, tmp))
        
        tmp =np.array( x.Label )
        Amp_left_leg_label = np.vstack((Amp_left_leg_label, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:155.815399[sec]

# %%
# right_hand
start_time = T.clock()
Amp_right_handAX=np.array([])
Amp_right_handAY=np.array([])
Amp_right_handAZ=np.array([])

Amp_right_handGX=np.array([])
Amp_right_handGY=np.array([])
Amp_right_handGZ=np.array([])

Amp_right_hand_label=np.array([])

x = fft_right_hand.where(fft_right_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAX = np.append(Amp_right_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAY = np.append(Amp_right_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAZ = np.append(Amp_right_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGX = np.append(Amp_right_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGY = np.append(Amp_right_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGZ = np.append(Amp_right_handGZ, tmp)

tmp =np.array( x.Label )
Amp_right_hand_label = np.append(Amp_right_hand_label, tmp)

for t in range(1,fft_right_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_hand.where(fft_right_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAX = np.vstack((Amp_right_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAY = np.vstack((Amp_right_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAZ = np.vstack((Amp_right_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGX = np.vstack((Amp_right_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGY = np.vstack((Amp_right_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGZ = np.vstack((Amp_right_handGZ, tmp))
        
        tmp =np.array( x.Label )
        Amp_right_hand_label = np.vstack((Amp_right_hand_label, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:162.879341[sec]

# %%
# west
start_time = T.clock()
Amp_westAX=np.array([])
Amp_westAY=np.array([])
Amp_westAZ=np.array([])

Amp_westGX=np.array([])
Amp_westGY=np.array([])
Amp_westGZ=np.array([])

Amp_west_label=np.array([])

x = fft_west.where(fft_west.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_westAX = np.append(Amp_westAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_westAY = np.append(Amp_westAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westAZ = np.append(Amp_westAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_westGX = np.append(Amp_westGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_westGY = np.append(Amp_westGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westGZ = np.append(Amp_westGZ, tmp)

tmp =np.array( x.Label )
Amp_west_label = np.append(Amp_west_label, tmp)

for t in range(1,fft_west.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_west.where(fft_west.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAX = np.vstack((Amp_westAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAY = np.vstack((Amp_westAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAZ = np.vstack((Amp_westAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGX = np.vstack((Amp_westGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGY = np.vstack((Amp_westGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGZ = np.vstack((Amp_westGZ, tmp))
        
        tmp =np.array( x.Label )
        Amp_west_label = np.vstack((Amp_west_label, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:3.855366[sec]

# %%
Amp_westAX.shape
# Out:
# (698, 8)

# %%
def GetLabelNam(samp):
    l=['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th', '11th',
    '12th', '13th', '14th', '15th', '16th', '17th', '18th', '19th', '20th', '21st',
    '22nd', '23rd', '24th', '25th', '26th', '27th', '28th', '29th', '30th', '31st']
    
    return l[0:(samp/2)]

# %%
df_fft_name=['fft_left_hand','fft_left_leg','fft_right_hand','fft_right_leg','west']

# %%
sample_bit
# Out:
# 16

# %%
start_time = T.clock()
df_fft =[fft_left_hand,fft_left_leg,fft_right_hand,fft_right_leg,fft_west]
for n,name in zip(df_fft,df_fft_name):
    array =  GetLabelNam(sample_bit)
    TimeArray=[]
    NumArray=[]
    LabelArray=[]

    for t in range(0,Amp_left_handAX.size/(sample_bit/2)):
        for i in range(len(array)):
            TimeArray.append(str(t))

    for i in range(0,Amp_left_handAX.size/(sample_bit/2)):
        for a in array:
            NumArray.append(a)

    TimeArray=np.array(TimeArray)
    NumArray=np.array(NumArray)

    fftdf=pd.DataFrame({
            'AccX_real':Amp_left_handAX,
            'AccY_real':Amp_left_handAY,
            'AccZ_real':Amp_left_handAZ,
            'GyrX_real':Amp_left_handGX,
            'GyrY_real':Amp_left_handGY,
            'GyrZ_real':Amp_left_handGZ,
            'Time':TimeArray,
            'Number':NumArray,
            'Label':Amp_left_hand_label
            }
          )

    #fftdf = fftdf.astype(np.float64)

    fftdf.to_csv('Amp-'+name+'-'+str(sample_bit)+'.csv')

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:2.136071[sec]

# %%
fftdf
# Out:
#        AccX_real  AccY_real  AccZ_real  GyrX_real  GyrY_real  GyrZ_real  \
# 0       0.353547   0.410197   0.416707   0.412972   0.348395   0.348101
# 1       0.155018   0.050424   0.121563   0.170728   0.168100   0.172912
# 2       0.133266   0.104927   0.074273   0.118723   0.118385   0.119944
# 3       0.118755   0.113035   0.087808   0.079542   0.091843   0.091588
# 4       0.082743   0.099714   0.084844   0.062505   0.076033   0.076411
# 5       0.068322   0.088034   0.079520   0.055400   0.070027   0.067982
# 6       0.042172   0.080889   0.073979   0.050571   0.064363   0.062267
# 7       0.046177   0.052781   0.061307   0.049560   0.062854   0.060795
# 8       0.402269   0.260825   0.282950   0.542486   0.347407   0.400069
# 9       0.187008   0.179823   0.182927   0.146876   0.173675   0.168584
# 10      0.097619   0.124595   0.134738   0.089318   0.119088   0.109020
# 11      0.076607   0.108115   0.109508   0.056584   0.093008   0.080536
# 12      0.063838   0.087070   0.078316   0.048035   0.077522   0.071057
# 13      0.065013   0.082750   0.085263   0.041225   0.066795   0.059351
# 14      0.054764   0.082753   0.060540   0.038490   0.061019   0.054782
# 15      0.052883   0.074071   0.065758   0.036986   0.061488   0.056600
# 16      0.414246   0.432806   0.375407   0.376991   0.411782   0.388858
# 17      0.137472   0.096097   0.154051   0.161654   0.159814   0.158164
# 18      0.092177   0.095201   0.103092   0.115849   0.108944   0.112507
# 19      0.085573   0.086113   0.090598   0.087274   0.080100   0.085824
# 20      0.061954   0.068376   0.091295   0.073466   0.066623   0.072450
# 21      0.074599   0.071481   0.064332   0.064903   0.060858   0.064696
# 22      0.064201   0.079468   0.056484   0.060985   0.056234   0.057958
# 23      0.069777   0.070457   0.064742   0.058878   0.055645   0.059545
# 24      0.344149   0.307887   0.293091   0.699276   0.336523   0.339521
# 25      0.120763   0.135708   0.159745   0.122793   0.174955   0.168431
# 26      0.131989   0.191419   0.144966   0.066848   0.118039   0.122297
# 27      0.111704   0.111639   0.115276   0.020644   0.092447   0.094030
# 28      0.118959   0.097941   0.096591   0.014193   0.079046   0.080652
# 29      0.089569   0.073801   0.093174   0.017829   0.070961   0.069340
# ...          ...        ...        ...        ...        ...        ...
# 55434   0.215007   0.241403   0.192087   0.105288   0.146078   0.073837
# 55435   0.101831   0.065023   0.128967   0.040499   0.036347   0.094736
# 55436   0.084365   0.088728   0.051210   0.060677   0.039934   0.085965
# 55437   0.084530   0.087056   0.078519   0.039800   0.028712   0.074655
# 55438   0.026383   0.036636   0.072858   0.039691   0.031220   0.069697
# 55439   0.054185   0.044990   0.055008   0.045215   0.025505   0.069917
# 55440   0.019625   0.404370   0.308690   0.438849   0.616248   0.327511
# 55441   0.332154   0.199385   0.100145   0.291252   0.221427   0.188264
# 55442   0.217618   0.212876   0.204674   0.051089   0.055347   0.134016
# 55443   0.088163   0.051147   0.127053   0.061491   0.015531   0.085427
# 55444   0.142869   0.017647   0.080645   0.069638   0.021005   0.076551
# 55445   0.088805   0.060548   0.066147   0.035719   0.022474   0.065278
# 55446   0.049159   0.017181   0.055633   0.023472   0.028496   0.062874
# 55447   0.061608   0.036846   0.057012   0.028489   0.019472   0.060079
# 55448   0.367453   0.289419   0.482980   0.492180   0.525872   0.364648
# 55449   0.218128   0.283140   0.164948   0.122303   0.120434   0.171438
# 55450   0.042354   0.227059   0.104899   0.209576   0.096380   0.106679
# 55451   0.109056   0.053249   0.083624   0.045329   0.067683   0.089471
# 55452   0.117129   0.079051   0.046145   0.039029   0.055495   0.073566
# 55453   0.024575   0.027164   0.053155   0.039309   0.044317   0.069672
# 55454   0.063930   0.022040   0.022175   0.022169   0.044856   0.063439
# 55455   0.057375   0.018876   0.042073   0.030106   0.044964   0.061089
# 55456   0.360560   0.329140   0.336092   0.471771   0.279168   0.347234
# 55457   0.160163   0.154999   0.242669   0.055999   0.211132   0.180739
# 55458   0.097118   0.158000   0.168037   0.234006   0.121989   0.114649
# 55459   0.091824   0.090965   0.094121   0.117795   0.092923   0.091122
# 55460   0.096615   0.084609   0.054193   0.035418   0.081908   0.076308
# 55461   0.055859   0.072210   0.011484   0.038697   0.078066   0.065828
# 55462   0.084513   0.041320   0.038245   0.022751   0.071562   0.063815
# 55463   0.053348   0.068756   0.055158   0.023563   0.063252   0.060305
#
#          Label Number  Time
# 0      walking    1st     0
# 1      walking    2nd     0
# 2      walking    3rd     0
# 3      walking    4th     0
# 4      walking    5th     0
# 5      walking    6th     0
# 6      walking    7th     0
# 7      walking    8th     0
# 8      walking    1st     1
# 9      walking    2nd     1
# 10     walking    3rd     1
# 11     walking    4th     1
# 12     walking    5th     1
# 13     walking    6th     1
# 14     walking    7th     1
# 15     walking    8th     1
# 16     walking    1st     2
# 17     walking    2nd     2
# 18     walking    3rd     2
# 19     walking    4th     2
# 20     walking    5th     2
# 21     walking    6th     2
# 22     walking    7th     2
# 23     walking    8th     2
# 24     walking    1st     3
# 25     walking    2nd     3
# 26     walking    3rd     3
# 27     walking    4th     3
# 28     walking    5th     3
# 29     walking    6th     3
# ...        ...    ...   ...
# 55434  UNKNOWN    3rd  6929
# 55435  UNKNOWN    4th  6929
# 55436  UNKNOWN    5th  6929
# 55437  UNKNOWN    6th  6929
# 55438  UNKNOWN    7th  6929
# 55439  UNKNOWN    8th  6929
# 55440  UNKNOWN    1st  6930
# 55441  UNKNOWN    2nd  6930
# 55442  UNKNOWN    3rd  6930
# 55443  UNKNOWN    4th  6930
# 55444  UNKNOWN    5th  6930
# 55445  UNKNOWN    6th  6930
# 55446  UNKNOWN    7th  6930
# 55447  UNKNOWN    8th  6930
# 55448  UNKNOWN    1st  6931
# 55449  UNKNOWN    2nd  6931
# 55450  UNKNOWN    3rd  6931
# 55451  UNKNOWN    4th  6931
# 55452  UNKNOWN    5th  6931
# 55453  UNKNOWN    6th  6931
# 55454  UNKNOWN    7th  6931
# 55455  UNKNOWN    8th  6931
# 55456  UNKNOWN    1st  6932
# 55457  UNKNOWN    2nd  6932
# 55458  UNKNOWN    3rd  6932
# 55459  UNKNOWN    4th  6932
# 55460  UNKNOWN    5th  6932
# 55461  UNKNOWN    6th  6932
# 55462  UNKNOWN    7th  6932
# 55463  UNKNOWN    8th  6932
#
# [55464 rows x 9 columns]

# %%
Amp_left_handAX.size
# Out:
# 55464

# %%
Amp_left_handAX.shape
# Out:
# (55464,)

# %%
Amp_left_handAY.shape
# Out:
# (55464,)

# %%
Amp_left_handAZ.shape
# Out:
# (55464,)

# %%
Amp_left_handGX.shape
# Out:
# (55464,)

# %%
Amp_left_handGY.shape
# Out:
# (55464,)

# %%
Amp_left_handGZ.shape
# Out:
# (55464,)

# %%
Amp_left_hand_label.shape
# Out:
# (55464,)

# %%
TimeArray.shape
# Out:
# (55504,)

# %%
NumArray.shape
# Out:
# (55504,)

# %%
len(range(0,n.Time.max()))
# Out:
# 6938

# %%
len(array)
# Out:
# 8

# %%
a=np.array([[3,3],[2,2],[2,2]])

# %%
b,c=a.shape

# %%
b

# %%
c
