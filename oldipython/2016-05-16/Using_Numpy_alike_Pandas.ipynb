# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import fftpack
from scipy import signal
import numpy as np
import pandas as pd
import datetime
import time as T

# %%
cd ~/Documents/SyncRecord/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/SyncRecord/cleaning-addingLABEL

# %%
ls
# Out:
# 20160331_180615.srt
# Amp-FFT-Cleaning-Conv-left-hand-ags.csv-16bit.csv
# Amp-fft_left_hand-16.csv
# Amp-fft_left_hand-32.csv
# Amp-fft_left_hand.csv
# Amp-fft_left_leg-16.csv
# Amp-fft_left_leg.csv
# Amp-fft_right_hand-16.csv
# Amp-fft_right_hand.csv
# Amp-fft_right_leg-16.csv
# Amp-fft_right_leg.csv
# Amp-west-16.csv
# Amp-west.csv
# Cleaning-Conv-left-hand-ags.csv
# Cleaning-Conv-left-leg-ags.csv
# Cleaning-Conv-right-hand-ags.csv
# Cleaning-Conv-right-leg-ags.csv
# Cleaning-Conv-west-ags.csv
# CleaningConv-left-hand-ags.csv
# CleaningConv-left-leg-ags.csv
# CleaningConv-right-hand-ags.csv
# CleaningConv-right-leg-ags.csv
# CleaningConv-west-ags.csv
# Cleaning_left_hand_ags.csv
# Conv-left-hand-ags.csv
# Conv-left-hand-batt.csv
# Conv-left-leg-ags.csv
# Conv-left-leg-batt.csv
# Conv-right-hand-ags.csv
# Conv-right-hand-batt.csv
# Conv-right-leg-ags.csv
# Conv-right-leg-batt.csv
# Conv-west-ags.csv
# Conv-west-batt.csv
# DeviceSet1.avi
# FFT-Cleaning-Conv-left-hand-ags.csv-128bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-16bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-256bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-32bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-512bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-64bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-128bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-16bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-256bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-32bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-512bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-64bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-128bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-16bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-256bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-32bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-512bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-64bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-128bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-16bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-256bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-32bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-512bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-64bit.csv
# FFT-Cleaning-Conv-west-ags.csv-128bit.csv
# FFT-Cleaning-Conv-west-ags.csv-16bit.csv
# FFT-Cleaning-Conv-west-ags.csv-256bit.csv
# FFT-Cleaning-Conv-west-ags.csv-32bit.csv
# FFT-Cleaning-Conv-west-ags.csv-512bit.csv
# FFT-Cleaning-Conv-west-ags.csv-64bit.csv
# SP-left-hand-acc.dat
# SP-left-hand-acc.dat.cache
# SP-left-hand-batt.dat
# SP-left-hand-gyr.dat
# SP-left-hand-gyr.dat.cache
# SP-left-leg-acc.dat
# SP-left-leg-acc.dat.cache
# SP-left-leg-batt.dat
# SP-left-leg-gyr.dat
# SP-left-leg-gyr.dat.cache
# SP-right-hand-acc.dat
# SP-right-hand-acc.dat.cache
# SP-right-hand-batt.dat
# SP-right-hand-gyr.dat
# SP-right-hand-gyr.dat.cache
# SP-right-leg-acc.dat
# SP-right-leg-acc.dat.cache
# SP-right-leg-batt.dat
# SP-right-leg-gyr.dat
# SP-right-leg-gyr.dat.cache
# SP-west-acc.dat
# SP-west-acc.dat.cache
# SP-west-batt.dat
# SP-west-gyr.dat
# SP-west-gyr.dat.cache
# back-up.zip
# cleaning.spe
# cleaning_20160331.csv
# cleaning_20160331.spa
# cleaning_20160331.spa.old
# label-data.csv
# left-hand.csv
# left-leg.csv
# missing/
# right-hand.csv
# right-leg.csv
# scale-miss/
# stop/
# walking/
# walking-back-arm/
# walking-back-arm-turn/
# walking-cross-arm/
# walking-cross-arm-turn/
# walking-turn/
# west.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e24ee6f8a94e> in <module>()
# ----> 1 f=np.genfromtxt('west.csv',delimiter=',')
#
# /home/takeyama/.pyenv/versions/2.7.10/envs/my_workspace/lib/python2.7/site-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows)
#    1767             # Raise an exception ?
#    1768             if invalid_raise:
# -> 1769                 raise ValueError(errmsg)
#    1770             # Issue a warning ?
#    1771             else:
#
# ValueError: Some errors were detected !
#     Line #75 (got 4 columns instead of 8)
#     Line #176 (got 4 columns instead of 8)
#     Line #277 (got 4 columns instead of 8)
#     Line #378 (got 4 columns instead of 8)
#     Line #479 (got 4 columns instead of 8)
#     Line #580 (got 4 columns instead of 8)
#     Line #681 (got 4 columns instead of 8)
#     Line #782 (got 4 columns instead of 8)
#     Line #883 (got 4 columns instead of 8)
#     Line #984 (got 4 columns instead of 8)
#     Line #1085 (got 4 columns instead of 8)
#     Line #1186 (got 4 columns instead of 8)
#     Line #1287 (got 4 columns instead of 8)
#     Line #1388 (got 4 columns instead of 8)
#     Line #1489 (got 4 columns instead of 8)
#     Line #1590 (got 4 columns instead of 8)
#     Line #1691 (got 4 columns instead of 8)
#     Line #1792 (got 4 columns instead of 8)
#     Line #1893 (got 4 columns instead of 8)
#     Line #1994 (got 4 columns instead of 8)
#     Line #2095 (got 4 columns instead of 8)
#     Line #2196 (got 4 columns instead of 8)
#     Line #2297 (got 4 columns instead of 8)
#     Line #2398 (got 4 columns instead of 8)
#     Line #2499 (got 4 columns instead of 8)
#     Line #2600 (got 4 columns instead of 8)
#     Line #2701 (got 4 columns instead of 8)
#     Line #2802 (got 4 columns instead of 8)
#     Line #2903 (got 4 columns instead of 8)
#     Line #3004 (got 4 columns instead of 8)
#     Line #3105 (got 4 columns instead of 8)
#     Line #3206 (got 4 columns instead of 8)
#     Line #3307 (got 4 columns instead of 8)
#     Line #3408 (got 4 columns instead of 8)
#     Line #3509 (got 4 columns instead of 8)
#     Line #3610 (got 4 columns instead of 8)
#     Line #3711 (got 4 columns instead of 8)
#     Line #3812 (got 4 columns instead of 8)
#     Line #3913 (got 4 columns instead of 8)
#     Line #4014 (got 4 columns instead of 8)
#     Line #4115 (got 4 columns instead of 8)
#     Line #4216 (got 4 columns instead of 8)
#     Line #4317 (got 4 columns instead of 8)
#     Line #4418 (got 4 columns instead of 8)
#     Line #4519 (got 4 columns instead of 8)
#     Line #4620 (got 4 columns instead of 8)
#     Line #4721 (got 4 columns instead of 8)
#     Line #4822 (got 4 columns instead of 8)
#     Line #4923 (got 4 columns instead of 8)
#     Line #5024 (got 4 columns instead of 8)
#     Line #5125 (got 4 columns instead of 8)
#     Line #5226 (got 4 columns instead of 8)
#     Line #5327 (got 4 columns instead of 8)
#     Line #5428 (got 4 columns instead of 8)
#     Line #5529 (got 4 columns instead of 8)
#     Line #5630 (got 4 columns instead of 8)
#     Line #5699 (got 4 columns instead of 8)
#     Line #5801 (got 4 columns instead of 8)
#     Line #5894 (got 4 columns instead of 8)
#     Line #5953 (got 4 columns instead of 8)
#     Line #6054 (got 4 columns instead of 8)
#     Line #6155 (got 4 columns instead of 8)
#     Line #6256 (got 4 columns instead of 8)
#     Line #6344 (got 4 columns instead of 8)
#     Line #6444 (got 4 columns instead of 8)
#     Line #6545 (got 4 columns instead of 8)
#     Line #6646 (got 4 columns instead of 8)
#     Line #6747 (got 4 columns instead of 8)
#     Line #6848 (got 4 columns instead of 8)
#     Line #6949 (got 4 columns instead of 8)
#     Line #7050 (got 4 columns instead of 8)
#     Line #7151 (got 4 columns instead of 8)
#     Line #7252 (got 4 columns instead of 8)
#     Line #7353 (got 4 columns instead of 8)
#     Line #7454 (got 4 columns instead of 8)
#     Line #7555 (got 4 columns instead of 8)
#     Line #7656 (got 4 columns instead of 8)
#     Line #7757 (got 4 columns instead of 8)
#     Line #7858 (got 4 columns instead of 8)
#     Line #7959 (got 4 columns instead of 8)
#     Line #8060 (got 4 columns instead of 8)
#     Line #8161 (got 4 columns instead of 8)
#     Line #8262 (got 4 columns instead of 8)
#     Line #8363 (got 4 columns instead of 8)
#     Line #8464 (got 4 columns instead of 8)
#     Line #8565 (got 4 columns instead of 8)
#     Line #8666 (got 4 columns instead of 8)
#     Line #8767 (got 4 columns instead of 8)
#     Line #8868 (got 4 columns instead of 8)
#     Line #8969 (got 4 columns instead of 8)
#     Line #9070 (got 4 columns instead of 8)
#     Line #9171 (got 4 columns instead of 8)
#     Line #9272 (got 4 columns instead of 8)
#     Line #9373 (got 4 columns instead of 8)
#     Line #9474 (got 4 columns instead of 8)
#     Line #9575 (got 4 columns instead of 8)
#     Line #9676 (got 4 columns instead of 8)
#     Line #9777 (got 4 columns instead of 8)
#     Line #9878 (got 4 columns instead of 8)
#     Line #9979 (got 4 columns instead of 8)
#     Line #10080 (got 4 columns instead of 8)
#     Line #10181 (got 4 columns instead of 8)
#     Line #10282 (got 4 columns instead of 8)
#     Line #10383 (got 4 columns instead of 8)
#     Line #10484 (got 4 columns instead of 8)
#     Line #10585 (got 4 columns instead of 8)
#     Line #10686 (got 4 columns instead of 8)
#     Line #10787 (got 4 columns instead of 8)
#     Line #10888 (got 4 columns instead of 8)
#     Line #10989 (got 4 columns instead of 8)
#     Line #11090 (got 4 columns instead of 8)
#     Line #11191 (got 4 columns instead of 8)
#     Line #11292 (got 4 columns instead of 8)
#     Line #11393 (got 4 columns instead of 8)
#     Line #11494 (got 4 columns instead of 8)
#     Line #11595 (got 4 columns instead of 8)
#     Line #11696 (got 4 columns instead of 8)
#     Line #11797 (got 4 columns instead of 8)
#     Line #11898 (got 4 columns instead of 8)
#     Line #11999 (got 4 columns instead of 8)
#     Line #12100 (got 4 columns instead of 8)
#     Line #12201 (got 4 columns instead of 8)
#     Line #12302 (got 4 columns instead of 8)
#     Line #12403 (got 4 columns instead of 8)
#     Line #12504 (got 4 columns instead of 8)
#     Line #12605 (got 4 columns instead of 8)
#     Line #12706 (got 4 columns instead of 8)
#     Line #12807 (got 4 columns instead of 8)
#     Line #12908 (got 4 columns instead of 8)
#     Line #13009 (got 4 columns instead of 8)
#     Line #13110 (got 4 columns instead of 8)
#     Line #13211 (got 4 columns instead of 8)
#     Line #13312 (got 4 columns instead of 8)
#     Line #13413 (got 4 columns instead of 8)
#     Line #13514 (got 4 columns instead of 8)
#     Line #13615 (got 4 columns instead of 8)
#     Line #13716 (got 4 columns instead of 8)
#     Line #13817 (got 4 columns instead of 8)
#     Line #13918 (got 4 columns instead of 8)
#     Line #14019 (got 4 columns instead of 8)
#     Line #14120 (got 4 columns instead of 8)
#     Line #14221 (got 4 columns instead of 8)
#     Line #14322 (got 4 columns instead of 8)
#     Line #14423 (got 4 columns instead of 8)
#     Line #14524 (got 4 columns instead of 8)
#     Line #14625 (got 4 columns instead of 8)
#     Line #14726 (got 4 columns instead of 8)
#     Line #14827 (got 4 columns instead of 8)
#     Line #14928 (got 4 columns instead of 8)
#     Line #15029 (got 4 columns instead of 8)
#     Line #15130 (got 4 columns instead of 8)
#     Line #15231 (got 4 columns instead of 8)
#     Line #15332 (got 4 columns instead of 8)
#     Line #15433 (got 4 columns instead of 8)
#     Line #15534 (got 4 columns instead of 8)
#     Line #15635 (got 4 columns instead of 8)
#     Line #15736 (got 4 columns instead of 8)
#     Line #15837 (got 4 columns instead of 8)
#     Line #15938 (got 4 columns instead of 8)
#     Line #16039 (got 4 columns instead of 8)
#     Line #16140 (got 4 columns instead of 8)
#     Line #16241 (got 4 columns instead of 8)
#     Line #16342 (got 4 columns instead of 8)
#     Line #16443 (got 4 columns instead of 8)
#     Line #16544 (got 4 columns instead of 8)
#     Line #16645 (got 4 columns instead of 8)
#     Line #16746 (got 4 columns instead of 8)
#     Line #16847 (got 4 columns instead of 8)
#     Line #16948 (got 4 columns instead of 8)
#     Line #17049 (got 4 columns instead of 8)
#     Line #17150 (got 4 columns instead of 8)
#     Line #17251 (got 4 columns instead of 8)
#     Line #17352 (got 4 columns instead of 8)
#     Line #17453 (got 4 columns instead of 8)
#     Line #17554 (got 4 columns instead of 8)
#     Line #17655 (got 4 columns instead of 8)
#     Line #17756 (got 4 columns instead of 8)
#     Line #17857 (got 4 columns instead of 8)
#     Line #17958 (got 4 columns instead of 8)
#     Line #18059 (got 4 columns instead of 8)
#     Line #18160 (got 4 columns instead of 8)
#     Line #18261 (got 4 columns instead of 8)
#     Line #18362 (got 4 columns instead of 8)
#     Line #18463 (got 4 columns instead of 8)
#     Line #18564 (got 4 columns instead of 8)
#     Line #18665 (got 4 columns instead of 8)
#     Line #18766 (got 4 columns instead of 8)
#     Line #18867 (got 4 columns instead of 8)
#     Line #18968 (got 4 columns instead of 8)
#     Line #19069 (got 4 columns instead of 8)
#     Line #19170 (got 4 columns instead of 8)
#     Line #19271 (got 4 columns instead of 8)
#     Line #19372 (got 4 columns instead of 8)
#     Line #19473 (got 4 columns instead of 8)
#     Line #19574 (got 4 columns instead of 8)
#     Line #19675 (got 4 columns instead of 8)
#     Line #19776 (got 4 columns instead of 8)
#     Line #19877 (got 4 columns instead of 8)
#     Line #19978 (got 4 columns instead of 8)
#     Line #20079 (got 4 columns instead of 8)
#     Line #20180 (got 4 columns instead of 8)
#     Line #20281 (got 4 columns instead of 8)
#     Line #20382 (got 4 columns instead of 8)
#     Line #20483 (got 4 columns instead of 8)
#     Line #20584 (got 4 columns instead of 8)
#     Line #20685 (got 4 columns instead of 8)
#     Line #20786 (got 4 columns instead of 8)
#     Line #20887 (got 4 columns instead of 8)
#     Line #20988 (got 4 columns instead of 8)
#     Line #21089 (got 4 columns instead of 8)
#     Line #21190 (got 4 columns instead of 8)
#     Line #21291 (got 4 columns instead of 8)
#     Line #21392 (got 4 columns instead of 8)
#     Line #21493 (got 4 columns instead of 8)
#     Line #21594 (got 4 columns instead of 8)
#     Line #21695 (got 4 columns instead of 8)
#     Line #21796 (got 4 columns instead of 8)
#     Line #21897 (got 4 columns instead of 8)
#     Line #21998 (got 4 columns instead of 8)
#     Line #22099 (got 4 columns instead of 8)
#     Line #22200 (got 4 columns instead of 8)
#     Line #22301 (got 4 columns instead of 8)
#     Line #22402 (got 4 columns instead of 8)
#     Line #22503 (got 4 columns instead of 8)
#     Line #22604 (got 4 columns instead of 8)
#     Line #22705 (got 4 columns instead of 8)
#     Line #22806 (got 4 columns instead of 8)
#     Line #22907 (got 4 columns instead of 8)
#     Line #23008 (got 4 columns instead of 8)
#     Line #23109 (got 4 columns instead of 8)
#     Line #23210 (got 4 columns instead of 8)
#     Line #23311 (got 4 columns instead of 8)
#     Line #23412 (got 4 columns instead of 8)
#     Line #23513 (got 4 columns instead of 8)
#     Line #23614 (got 4 columns instead of 8)
#     Line #23715 (got 4 columns instead of 8)
#     Line #23816 (got 4 columns instead of 8)
#     Line #23917 (got 4 columns instead of 8)
#     Line #24018 (got 4 columns instead of 8)
#     Line #24119 (got 4 columns instead of 8)
#     Line #24220 (got 4 columns instead of 8)
#     Line #24321 (got 4 columns instead of 8)
#     Line #24422 (got 4 columns instead of 8)
#     Line #24523 (got 4 columns instead of 8)
#     Line #24624 (got 4 columns instead of 8)
#     Line #24725 (got 4 columns instead of 8)
#     Line #24826 (got 4 columns instead of 8)
#     Line #24927 (got 4 columns instead of 8)
#     Line #25028 (got 4 columns instead of 8)
#     Line #25129 (got 4 columns instead of 8)
#     Line #25230 (got 4 columns instead of 8)
#     Line #25331 (got 4 columns instead of 8)
#     Line #25432 (got 4 columns instead of 8)
#     Line #25533 (got 4 columns instead of 8)
#     Line #25634 (got 4 columns instead of 8)
#     Line #25735 (got 4 columns instead of 8)
#     Line #25836 (got 4 columns instead of 8)
#     Line #25937 (got 4 columns instead of 8)
#     Line #26038 (got 4 columns instead of 8)
#     Line #26139 (got 4 columns instead of 8)
#     Line #26240 (got 4 columns instead of 8)
#     Line #26341 (got 4 columns instead of 8)
#     Line #26442 (got 4 columns instead of 8)
#     Line #26543 (got 4 columns instead of 8)
#     Line #26644 (got 4 columns instead of 8)
#     Line #26745 (got 4 columns instead of 8)
#     Line #26846 (got 4 columns instead of 8)
#     Line #26947 (got 4 columns instead of 8)
#     Line #27048 (got 4 columns instead of 8)
#     Line #27149 (got 4 columns instead of 8)
#     Line #27250 (got 4 columns instead of 8)
#     Line #27351 (got 4 columns instead of 8)
#     Line #27452 (got 4 columns instead of 8)
#     Line #27553 (got 4 columns instead of 8)
#     Line #27654 (got 4 columns instead of 8)
#     Line #27755 (got 4 columns instead of 8)
#     Line #27856 (got 4 columns instead of 8)
#     Line #27957 (got 4 columns instead of 8)
#     Line #28058 (got 4 columns instead of 8)
#     Line #28159 (got 4 columns instead of 8)
#     Line #28260 (got 4 columns instead of 8)
#     Line #28361 (got 4 columns instead of 8)
#     Line #28462 (got 4 columns instead of 8)
#     Line #28563 (got 4 columns instead of 8)
#     Line #28664 (got 4 columns instead of 8)
#     Line #28765 (got 4 columns instead of 8)
#     Line #28866 (got 4 columns instead of 8)
#     Line #28967 (got 4 columns instead of 8)
#     Line #29068 (got 4 columns instead of 8)
#     Line #29169 (got 4 columns instead of 8)
#     Line #29270 (got 4 columns instead of 8)
#     Line #29371 (got 4 columns instead of 8)
#     Line #29472 (got 4 columns instead of 8)
#     Line #29573 (got 4 columns instead of 8)
#     Line #29674 (got 4 columns instead of 8)
#     Line #29775 (got 4 columns instead of 8)
#     Line #29876 (got 4 columns instead of 8)
#     Line #29977 (got 4 columns instead of 8)
#     Line #30078 (got 4 columns instead of 8)
#     Line #30179 (got 4 columns instead of 8)
#     Line #30280 (got 4 columns instead of 8)
#     Line #30381 (got 4 columns instead of 8)
#     Line #30482 (got 4 columns instead of 8)
#     Line #30583 (got 4 columns instead of 8)
#     Line #30684 (got 4 columns instead of 8)
#     Line #30785 (got 4 columns instead of 8)
#     Line #30886 (got 4 columns instead of 8)
#     Line #30987 (got 4 columns instead of 8)
#     Line #31088 (got 4 columns instead of 8)
#     Line #31189 (got 4 columns instead of 8)
#     Line #31290 (got 4 columns instead of 8)
#     Line #31391 (got 4 columns instead of 8)
#     Line #31492 (got 4 columns instead of 8)
#     Line #31593 (got 4 columns instead of 8)
#     Line #31694 (got 4 columns instead of 8)
#     Line #31795 (got 4 columns instead of 8)
#     Line #31896 (got 4 columns instead of 8)
#     Line #31997 (got 4 columns instead of 8)
#     Line #32098 (got 4 columns instead of 8)
#     Line #32199 (got 4 columns instead of 8)
#     Line #32300 (got 4 columns instead of 8)
#     Line #32401 (got 4 columns instead of 8)
#     Line #32502 (got 4 columns instead of 8)
#     Line #32603 (got 4 columns instead of 8)
#     Line #32704 (got 4 columns instead of 8)
#     Line #32805 (got 4 columns instead of 8)
#     Line #32906 (got 4 columns instead of 8)
#     Line #33007 (got 4 columns instead of 8)
#     Line #33108 (got 4 columns instead of 8)
#     Line #33209 (got 4 columns instead of 8)
#     Line #33310 (got 4 columns instead of 8)
#     Line #33411 (got 4 columns instead of 8)
#     Line #33512 (got 4 columns instead of 8)
#     Line #33613 (got 4 columns instead of 8)
#     Line #33714 (got 4 columns instead of 8)
#     Line #33815 (got 4 columns instead of 8)
#     Line #33916 (got 4 columns instead of 8)
#     Line #34017 (got 4 columns instead of 8)
#     Line #34118 (got 4 columns instead of 8)
#     Line #34219 (got 4 columns instead of 8)
#     Line #34320 (got 4 columns instead of 8)
#     Line #34421 (got 4 columns instead of 8)
#     Line #34522 (got 4 columns instead of 8)
#     Line #34623 (got 4 columns instead of 8)
#     Line #34724 (got 4 columns instead of 8)
#     Line #34825 (got 4 columns instead of 8)
#     Line #34926 (got 4 columns instead of 8)
#     Line #35027 (got 4 columns instead of 8)
#     Line #35128 (got 4 columns instead of 8)
#     Line #35229 (got 4 columns instead of 8)
#     Line #35330 (got 4 columns instead of 8)
#     Line #35431 (got 4 columns instead of 8)
#     Line #35532 (got 4 columns instead of 8)
#     Line #35633 (got 4 columns instead of 8)
#     Line #35734 (got 4 columns instead of 8)
#     Line #35835 (got 4 columns instead of 8)
#     Line #35936 (got 4 columns instead of 8)
#     Line #36037 (got 4 columns instead of 8)
#     Line #36138 (got 4 columns instead of 8)
#     Line #36239 (got 4 columns instead of 8)
#     Line #36340 (got 4 columns instead of 8)
#     Line #36441 (got 4 columns instead of 8)
#     Line #36542 (got 4 columns instead of 8)
#     Line #36643 (got 4 columns instead of 8)
#     Line #36744 (got 4 columns instead of 8)
#     Line #36845 (got 4 columns instead of 8)
#     Line #36946 (got 4 columns instead of 8)
#     Line #37047 (got 4 columns instead of 8)
#     Line #37148 (got 4 columns instead of 8)
#     Line #37249 (got 4 columns instead of 8)
#     Line #37350 (got 4 columns instead of 8)
#     Line #37451 (got 4 columns instead of 8)
#     Line #37552 (got 4 columns instead of 8)
#     Line #37653 (got 4 columns instead of 8)
#     Line #37754 (got 4 columns instead of 8)
#     Line #37855 (got 4 columns instead of 8)
#     Line #37956 (got 4 columns instead of 8)
#     Line #38057 (got 4 columns instead of 8)
#     Line #38158 (got 4 columns instead of 8)
#     Line #38259 (got 4 columns instead of 8)
#     Line #38360 (got 4 columns instead of 8)
#     Line #38461 (got 4 columns instead of 8)
#     Line #38562 (got 4 columns instead of 8)
#     Line #38663 (got 4 columns instead of 8)
#     Line #38764 (got 4 columns instead of 8)
#     Line #38865 (got 4 columns instead of 8)
#     Line #38966 (got 4 columns instead of 8)
#     Line #39067 (got 4 columns instead of 8)
#     Line #39168 (got 4 columns instead of 8)
#     Line #39269 (got 4 columns instead of 8)
#     Line #39370 (got 4 columns instead of 8)
#     Line #39471 (got 4 columns instead of 8)
#     Line #39572 (got 4 columns instead of 8)
#     Line #39673 (got 4 columns instead of 8)
#     Line #39774 (got 4 columns instead of 8)
#     Line #39875 (got 4 columns instead of 8)
#     Line #39976 (got 4 columns instead of 8)
#     Line #40077 (got 4 columns instead of 8)
#     Line #40178 (got 4 columns instead of 8)
#     Line #40279 (got 4 columns instead of 8)
#     Line #40380 (got 4 columns instead of 8)
#     Line #40481 (got 4 columns instead of 8)
#     Line #40582 (got 4 columns instead of 8)
#     Line #40683 (got 4 columns instead of 8)
#     Line #40784 (got 4 columns instead of 8)
#     Line #40885 (got 4 columns instead of 8)
#     Line #40986 (got 4 columns instead of 8)
#     Line #41087 (got 4 columns instead of 8)
#     Line #41188 (got 4 columns instead of 8)
#     Line #41289 (got 4 columns instead of 8)
#     Line #41390 (got 4 columns instead of 8)
#     Line #41491 (got 4 columns instead of 8)
#     Line #41592 (got 4 columns instead of 8)
#     Line #41693 (got 4 columns instead of 8)
#     Line #41794 (got 4 columns instead of 8)
#     Line #41895 (got 4 columns instead of 8)
#     Line #41996 (got 4 columns instead of 8)
#     Line #42097 (got 4 columns instead of 8)
#     Line #42198 (got 4 columns instead of 8)
#     Line #42299 (got 4 columns instead of 8)
#     Line #42400 (got 4 columns instead of 8)
#     Line #42501 (got 4 columns instead of 8)
#     Line #42602 (got 4 columns instead of 8)
#     Line #42703 (got 4 columns instead of 8)
#     Line #42804 (got 4 columns instead of 8)
#     Line #42905 (got 4 columns instead of 8)
#     Line #43006 (got 4 columns instead of 8)
#     Line #43107 (got 4 columns instead of 8)
#     Line #43208 (got 4 columns instead of 8)
#     Line #43309 (got 4 columns instead of 8)
#     Line #43410 (got 4 columns instead of 8)
#     Line #43511 (got 4 columns instead of 8)
#     Line #43612 (got 4 columns instead of 8)
#     Line #43713 (got 4 columns instead of 8)
#     Line #43814 (got 4 columns instead of 8)
#     Line #43915 (got 4 columns instead of 8)
#     Line #44016 (got 4 columns instead of 8)
#     Line #44117 (got 4 columns instead of 8)
#     Line #44218 (got 4 columns instead of 8)
#     Line #44319 (got 4 columns instead of 8)
#     Line #44420 (got 4 columns instead of 8)
#     Line #44521 (got 4 columns instead of 8)
#     Line #44622 (got 4 columns instead of 8)
#     Line #44723 (got 4 columns instead of 8)
#     Line #44824 (got 4 columns instead of 8)
#     Line #44925 (got 4 columns instead of 8)
#     Line #45026 (got 4 columns instead of 8)
#     Line #45127 (got 4 columns instead of 8)
#     Line #45228 (got 4 columns instead of 8)
#     Line #45329 (got 4 columns instead of 8)
#     Line #45430 (got 4 columns instead of 8)
#     Line #45531 (got 4 columns instead of 8)
#     Line #45632 (got 4 columns instead of 8)
#     Line #45733 (got 4 columns instead of 8)
#     Line #45834 (got 4 columns instead of 8)
#     Line #45935 (got 4 columns instead of 8)
#     Line #46036 (got 4 columns instead of 8)
#     Line #46137 (got 4 columns instead of 8)
#     Line #46238 (got 4 columns instead of 8)
#     Line #46339 (got 4 columns instead of 8)
#     Line #46440 (got 4 columns instead of 8)
#     Line #46541 (got 4 columns instead of 8)
#     Line #46642 (got 4 columns instead of 8)
#     Line #46743 (got 4 columns instead of 8)
#     Line #46844 (got 4 columns instead of 8)
#     Line #46945 (got 4 columns instead of 8)
#     Line #47046 (got 4 columns instead of 8)
#     Line #47147 (got 4 columns instead of 8)
#     Line #47248 (got 4 columns instead of 8)
#     Line #47349 (got 4 columns instead of 8)
#     Line #47450 (got 4 columns instead of 8)
#     Line #47551 (got 4 columns instead of 8)
#     Line #47652 (got 4 columns instead of 8)
#     Line #47753 (got 4 columns instead of 8)
#     Line #47854 (got 4 columns instead of 8)
#     Line #47955 (got 4 columns instead of 8)
#     Line #48056 (got 4 columns instead of 8)
#     Line #48157 (got 4 columns instead of 8)
#     Line #48258 (got 4 columns instead of 8)
#     Line #48359 (got 4 columns instead of 8)
#     Line #48460 (got 4 columns instead of 8)
#     Line #48561 (got 4 columns instead of 8)
#     Line #48662 (got 4 columns instead of 8)
#     Line #48763 (got 4 columns instead of 8)
#     Line #48864 (got 4 columns instead of 8)
#     Line #48965 (got 4 columns instead of 8)
#     Line #49066 (got 4 columns instead of 8)
#     Line #49167 (got 4 columns instead of 8)
#     Line #49268 (got 4 columns instead of 8)
#     Line #49369 (got 4 columns instead of 8)
#     Line #49470 (got 4 columns instead of 8)
#     Line #49571 (got 4 columns instead of 8)
#     Line #49672 (got 4 columns instead of 8)
#     Line #49773 (got 4 columns instead of 8)
#     Line #49874 (got 4 columns instead of 8)
#     Line #49975 (got 4 columns instead of 8)
#     Line #50076 (got 4 columns instead of 8)
#     Line #50177 (got 4 columns instead of 8)
#     Line #50278 (got 4 columns instead of 8)
#     Line #50379 (got 4 columns instead of 8)
#     Line #50480 (got 4 columns instead of 8)
#     Line #50581 (got 4 columns instead of 8)
#     Line #50682 (got 4 columns instead of 8)
#     Line #50783 (got 4 columns instead of 8)
#     Line #50884 (got 4 columns instead of 8)
#     Line #50985 (got 4 columns instead of 8)
#     Line #51086 (got 4 columns instead of 8)
#     Line #51187 (got 4 columns instead of 8)
#     Line #51288 (got 4 columns instead of 8)
#     Line #51389 (got 4 columns instead of 8)
#     Line #51490 (got 4 columns instead of 8)
#     Line #51591 (got 4 columns instead of 8)
#     Line #51692 (got 4 columns instead of 8)
#     Line #51793 (got 4 columns instead of 8)
#     Line #51894 (got 4 columns instead of 8)
#     Line #51995 (got 4 columns instead of 8)
#     Line #52096 (got 4 columns instead of 8)
#     Line #52197 (got 4 columns instead of 8)
#     Line #52298 (got 4 columns instead of 8)
#     Line #52399 (got 4 columns instead of 8)
#     Line #52500 (got 4 columns instead of 8)
#     Line #52601 (got 4 columns instead of 8)
#     Line #52702 (got 4 columns instead of 8)
#     Line #52803 (got 4 columns instead of 8)
#     Line #52904 (got 4 columns instead of 8)
#     Line #53005 (got 4 columns instead of 8)
#     Line #53106 (got 4 columns instead of 8)
#     Line #53207 (got 4 columns instead of 8)
#     Line #53308 (got 4 columns instead of 8)
#     Line #53409 (got 4 columns instead of 8)
#     Line #53510 (got 4 columns instead of 8)
#     Line #53611 (got 4 columns instead of 8)
#     Line #53712 (got 4 columns instead of 8)
#     Line #53813 (got 4 columns instead of 8)
#     Line #53914 (got 4 columns instead of 8)
#     Line #54015 (got 4 columns instead of 8)
#     Line #54116 (got 4 columns instead of 8)
#     Line #54217 (got 4 columns instead of 8)
#     Line #54318 (got 4 columns instead of 8)
#     Line #54419 (got 4 columns instead of 8)
#     Line #54520 (got 4 columns instead of 8)
#     Line #54621 (got 4 columns instead of 8)
#     Line #54722 (got 4 columns instead of 8)
#     Line #54823 (got 4 columns instead of 8)
#     Line #54924 (got 4 columns instead of 8)
#     Line #55025 (got 4 columns instead of 8)
#     Line #55126 (got 4 columns instead of 8)
#     Line #55227 (got 4 columns instead of 8)
#     Line #55328 (got 4 columns instead of 8)
#     Line #55429 (got 4 columns instead of 8)
#     Line #55530 (got 4 columns instead of 8)

# %%
f
# Out:
# <open file 'west.csv', mode 'r' at 0x7fe74df095d0>
