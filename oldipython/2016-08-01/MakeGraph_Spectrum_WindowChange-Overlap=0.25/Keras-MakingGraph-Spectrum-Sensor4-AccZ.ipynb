# %%
SensorNum=4 # Sensor number
WindowWidth=[16,32,64,128,256,512,1024] # Window Width
OverlapArray=[4,8,16,32,64,128,256] # sliding window
width=3000 # graph width 
EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
Axis='AccZ' # Axis

# chopin
#WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData/2016-07-25"

# mozart
WORKSPACE_PATH = "/home/takeyama/Documents/01_SyncChopin/2016-07-25"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib
import matplotlib.pyplot as plt
import pylab
import pickle
import copy
import processing
import datetime
import multiprocessing as mp
import processing

# %matplotlib inline

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
if not os.path.exists(WORKSPACE_PATH+'/study/'+DataName+'/'): os.makedirs(WORKSPACE_PATH+'/study/'+DataName+'/')
StudyDataPath=WORKSPACE_PATH+'/study/'+DataName+'/'

if not os.path.exists(WORKSPACE_PATH+'/graph/'+DataName+'/loss/'): os.makedirs(WORKSPACE_PATH+'/graph/'+DataName+'/loss/')
GraphDataPath=WORKSPACE_PATH+'/graph/'+DataName+'/loss/'

if not os.path.exists(WORKSPACE_PATH+'/graph/'+DataName+'/Time/'): os.makedirs(WORKSPACE_PATH+'/graph/'+DataName+'/Time/')
GraphDataTimePath=WORKSPACE_PATH+'/graph/'+DataName+'/Time/'

if not os.path.exists(WORKSPACE_PATH+'/graph/'+DataName+'/Spectrum/'): os.makedirs(WORKSPACE_PATH+'/graph/'+DataName+'/Spectrum/')
GraphDataSpectrumPath=WORKSPACE_PATH+'/graph/'+DataName+'/Spectrum/'

if not os.path.exists(WORKSPACE_PATH+'/modelPic/'+DataName+'/'): os.makedirs(WORKSPACE_PATH+'/modelPic/'+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+'/modelPic/'+DataName+'/'

if not os.path.exists(WORKSPACE_PATH+'/window/'+DataName+'/'): os.makedirs(WORKSPACE_PATH+'/window/'+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+DataName+'/'

RawDataPath=WORKSPACE_PATH+"raw/"

# %%
def kld(p, q):
    """Calculates Kullback–Leibler divergence"""
    p = np.array(p)
    q = np.array(q)
    return np.sum(p * np.log(p / q), axis=(p.ndim - 1))
 
def jsd(p, q):
    """Calculates Jensen-Shannon Divergence"""
    p = np.array(p)
    q = np.array(q)
    m = 0.5 * (p + q)
    return 0.5 * kld(p, m) + 0.5 * kld(q, m)

# %%
fig = plt.figure(figsize=(30,15))
ax = fig.add_subplot(311)
bx = fig.add_subplot(312)
cx = fig.add_subplot(313)

# loop windowWidth
for SampleNum,Overlap in zip(WindowWidth,OverlapArray):
    # define SaveFileName
    for encoding_dim in EncodingDim:
        print "hiden node = "+str(encoding_dim)
        CommonName = '_edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap*100)
        SaveFileNameEncord=DataName+'_encoded'+ CommonName
        SaveFileNameDecord=DataName+'_decoded'+ CommonName
        SaveFileNameNet=DataName+'_net'+ CommonName
        SaveFileNameTrain=DataName+'_train'+ CommonName
        SaveFileNameTest=DataName+'_test'+ CommonName
        SaveFileNameGraph= GraphDataSpectrumPath+DataName+CommonName

        #window = processing.LoadDicDataFromFileNPZ(StudyDataPath+SaveFileNameTrain)
        window = processing.LoadDicDataFromFileNPZ(WindowDataPath+SaveFileNameTrain)
        reconstructData = processing.LoadDicDataFromFileNPZ(StudyDataPath+SaveFileNameDecord)
        
        # FFT 
        fftDataE = np.array([])
        fftDataD = np.array([])
        for i in range(len(window)):
                fftDataE=np.append(fftDataE, fftpack.fft( window[i])[1:(SampleNum/2)+1])
                fftDataD=np.append(fftDataD, fftpack.fft( reconstructData[i])[1:(SampleNum/2)+1])
        fftDataE = fftDataE.reshape(len(fftDataE)/(SampleNum/2),(SampleNum/2))
        fftDataD = fftDataD.reshape(len(fftDataD)/(SampleNum/2),(SampleNum/2))
        processing.SaveDicDataFromFileNPZ(StudyDataPath, DataName+CommonName+'-fft-raw',fftDataE)
        processing.SaveDicDataFromFileNPZ(StudyDataPath, DataName+CommonName+'-fft-restruct',fftDataD)
        
        # Power
        PowerDataE = np.imag(fftDataE)**2+np.real(fftDataE)**2
        PowerDataD = np.imag(fftDataD)**2+np.real(fftDataD)**2
        processing.SaveDicDataFromFileNPZ(StudyDataPath, DataName+CommonName+'-power-raw',PowerDataE)
        processing.SaveDicDataFromFileNPZ(StudyDataPath, DataName+CommonName+'-power-restruct',PowerDataD)
        
        # to distribution
        DistributePowerDataE = np.array([])
        DistributePowerDataD = np.array([])

        for i in range( PowerDataE.shape[0] ):
            DistributePowerDataE = np.append(DistributePowerDataE,PowerDataE[i]/( np.sum(PowerDataE[i]) ))
        DistributePowerDataE = DistributePowerDataE.reshape(PowerDataE.shape)

        for i in range( PowerDataD.shape[0] ):
            DistributePowerDataD = np.append(DistributePowerDataD,PowerDataD[i]/( np.sum(PowerDataD[i]) ))
        DistributePowerDataD = DistributePowerDataD.reshape(PowerDataD.shape)

        processing.SaveDicDataFromFileNPZ(StudyDataPath, DataName+CommonName+'-power-distribution-raw',DistributePowerDataE)
        processing.SaveDicDataFromFileNPZ(StudyDataPath, DataName+CommonName+'-power-distribution-reconst',DistributePowerDataD)

        # Kullback-leibler-divergence plot
        ArrayKLD = np.array([])
        for i in range(DistributePowerDataE.shape[0]):
            ArrayKLD = np.append(ArrayKLD, kld(DistributePowerDataE[i],DistributePowerDataD[i]))
        
        width = DistributePowerDataE.shape[0]/20
        for i in range(width,DistributePowerDataE.shape[0],width):
            start =i-width
            goal=i

            data = ArrayKLD[start:goal]
            dataE = DistributePowerDataE[start:goal]
            dataD = DistributePowerDataD[start:goal]

            #dataE,dataDをPower
            ax.pcolormesh(range(start,goal),range(dataE.shape[1]),dataE.T ,label='rawData')
            ax.legend(loc='best')
            ax.set_title(str(start)+"-"+str(goal))

            bx.pcolormesh(range(start,goal),range(dataD.shape[1]),dataD.T ,label='reconst' )
            bx.legend(loc='best')
            bx.set_title(str(start)+"-"+str(goal))

            cx.plot(range(start,goal),data,'g',label="kld data")
            cx.legend(loc='best')
            cx.set_title(str(start)+"-"+str(goal))
            ax.figure.savefig(SaveFileNameGraph+'-'+str(start)+"-"+str(goal)+'-'+'-glaph')
            ax.clear()
            bx.clear()
            cx.clear()
            print 'Graph range='+str(start)+' : '+str(goal)
            time.sleep(3)
# Out:
# hiden node = 4
# /home/takeyama/.pyenv/versions/takeyama/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# Graph range=0 : 3184
# Graph range=3184 : 6368
# Graph range=6368 : 9552
# Graph range=9552 : 12736
# Graph range=12736 : 15920
# Graph range=15920 : 19104
# Graph range=19104 : 22288
# Graph range=22288 : 25472
# Graph range=25472 : 28656
# Graph range=28656 : 31840
# Graph range=31840 : 35024
# Graph range=35024 : 38208
# Graph range=38208 : 41392
# Graph range=41392 : 44576
# Graph range=44576 : 47760
# Graph range=47760 : 50944
# Graph range=50944 : 54128
# Graph range=54128 : 57312
# Graph range=57312 : 60496
# Graph range=60496 : 63680
# hiden node = 8
# Graph range=0 : 3184
# Graph range=3184 : 6368
# Graph range=6368 : 9552
# Graph range=9552 : 12736
# Graph range=12736 : 15920
# Graph range=15920 : 19104
# Graph range=19104 : 22288
# Graph range=22288 : 25472
# Graph range=25472 : 28656
# Graph range=28656 : 31840
# Graph range=31840 : 35024
# Graph range=35024 : 38208
# Graph range=38208 : 41392
# Graph range=41392 : 44576
# Graph range=44576 : 47760
# Graph range=47760 : 50944
# Graph range=50944 : 54128
# Graph range=54128 : 57312
# Graph range=57312 : 60496
# Graph range=60496 : 63680
# hiden node = 12
# Graph range=0 : 3184
# Graph range=3184 : 6368
# Graph range=6368 : 9552
# Graph range=9552 : 12736
# Graph range=12736 : 15920
# Graph range=15920 : 19104
# Graph range=19104 : 22288
# Graph range=22288 : 25472
# Graph range=25472 : 28656
# Graph range=28656 : 31840
# Graph range=31840 : 35024
# Graph range=35024 : 38208
# Graph range=38208 : 41392
# Graph range=41392 : 44576
# Graph range=44576 : 47760
# Graph range=47760 : 50944
# Graph range=50944 : 54128
# Graph range=54128 : 57312
# Graph range=57312 : 60496
# Graph range=60496 : 63680
# hiden node = 16
# Graph range=0 : 3184
# Graph range=3184 : 6368
# Graph range=6368 : 9552
# Graph range=9552 : 12736
# Graph range=12736 : 15920
# Graph range=15920 : 19104
# Graph range=19104 : 22288
# Graph range=22288 : 25472
# Graph range=25472 : 28656
# Graph range=28656 : 31840
# Graph range=31840 : 35024
# Graph range=35024 : 38208
# Graph range=38208 : 41392
# Graph range=41392 : 44576
# Graph range=44576 : 47760
# Graph range=47760 : 50944
# Graph range=50944 : 54128
# Graph range=54128 : 57312
# Graph range=57312 : 60496
# Graph range=60496 : 63680
# hiden node = 32
# Graph range=0 : 3184
# Graph range=3184 : 6368
# Graph range=6368 : 9552
# Graph range=9552 : 12736
# Graph range=12736 : 15920
# Graph range=15920 : 19104
# Graph range=19104 : 22288
# Graph range=22288 : 25472
# Graph range=25472 : 28656
# Graph range=28656 : 31840
# Graph range=31840 : 35024
# Graph range=35024 : 38208
# Graph range=38208 : 41392
# Graph range=41392 : 44576
# Graph range=44576 : 47760
# Graph range=47760 : 50944
# Graph range=50944 : 54128
# Graph range=54128 : 57312
# Graph range=57312 : 60496
# Graph range=60496 : 63680
# hiden node = 64
# Graph range=0 : 3184
# Graph range=3184 : 6368
# Graph range=6368 : 9552
# Graph range=9552 : 12736
# Graph range=12736 : 15920
# Graph range=15920 : 19104
# Graph range=19104 : 22288
# Graph range=22288 : 25472
# Graph range=25472 : 28656
# Graph range=28656 : 31840
# Graph range=31840 : 35024
# Graph range=35024 : 38208
# Graph range=38208 : 41392
# Graph range=41392 : 44576
# Graph range=44576 : 47760
# Graph range=47760 : 50944
# Graph range=50944 : 54128
# Graph range=54128 : 57312
# Graph range=57312 : 60496
# Graph range=60496 : 63680
# hiden node = 4
# Graph range=0 : 1591
# Graph range=1591 : 3182
# Graph range=3182 : 4773
# Graph range=4773 : 6364
# Graph range=6364 : 7955
# Graph range=7955 : 9546
# Graph range=9546 : 11137
# Graph range=11137 : 12728
# Graph range=12728 : 14319
# Graph range=14319 : 15910
# Graph range=15910 : 17501
# Graph range=17501 : 19092
# Graph range=19092 : 20683
# Graph range=20683 : 22274
# Graph range=22274 : 23865
# Graph range=23865 : 25456
# Graph range=25456 : 27047
# Graph range=27047 : 28638
# Graph range=28638 : 30229
# Graph range=30229 : 31820
# hiden node = 8
# Graph range=0 : 1591
# Graph range=1591 : 3182
# Graph range=3182 : 4773
# Graph range=4773 : 6364
# Graph range=6364 : 7955
# Graph range=7955 : 9546
# Graph range=9546 : 11137
# Graph range=11137 : 12728
# Graph range=12728 : 14319
# Graph range=14319 : 15910
# Graph range=15910 : 17501
# Graph range=17501 : 19092
# Graph range=19092 : 20683
# Graph range=20683 : 22274
# Graph range=22274 : 23865
# Graph range=23865 : 25456
# Graph range=25456 : 27047
# Graph range=27047 : 28638
# Graph range=28638 : 30229
# Graph range=30229 : 31820
# hiden node = 12
# Graph range=0 : 1591
# Graph range=1591 : 3182
# Graph range=3182 : 4773
# Graph range=4773 : 6364
# Graph range=6364 : 7955
# Graph range=7955 : 9546
# Graph range=9546 : 11137
# Graph range=11137 : 12728
# Graph range=12728 : 14319
# Graph range=14319 : 15910
# Graph range=15910 : 17501
# Graph range=17501 : 19092
# Graph range=19092 : 20683
# Graph range=20683 : 22274
# Graph range=22274 : 23865
# Graph range=23865 : 25456
# Graph range=25456 : 27047
# Graph range=27047 : 28638
# Graph range=28638 : 30229
# Graph range=30229 : 31820
# hiden node = 16
# Graph range=0 : 1591
# Graph range=1591 : 3182
# Graph range=3182 : 4773
# Graph range=4773 : 6364
# Graph range=6364 : 7955
# Graph range=7955 : 9546
# Graph range=9546 : 11137
# Graph range=11137 : 12728
# Graph range=12728 : 14319
# Graph range=14319 : 15910
# Graph range=15910 : 17501
# Graph range=17501 : 19092
# Graph range=19092 : 20683
# Graph range=20683 : 22274
# Graph range=22274 : 23865
# Graph range=23865 : 25456
# Graph range=25456 : 27047
# Graph range=27047 : 28638
# Graph range=28638 : 30229
# Graph range=30229 : 31820
# hiden node = 32
# Graph range=0 : 1591
# Graph range=1591 : 3182
# Graph range=3182 : 4773
# Graph range=4773 : 6364
# Graph range=6364 : 7955
# Graph range=7955 : 9546
# Graph range=9546 : 11137
# Graph range=11137 : 12728
# Graph range=12728 : 14319
# Graph range=14319 : 15910
# Graph range=15910 : 17501
# Graph range=17501 : 19092
# Graph range=19092 : 20683
# Graph range=20683 : 22274
# Graph range=22274 : 23865
# Graph range=23865 : 25456
# Graph range=25456 : 27047
# Graph range=27047 : 28638
# Graph range=28638 : 30229
# Graph range=30229 : 31820
# hiden node = 64
# Graph range=0 : 1591
# Graph range=1591 : 3182
# Graph range=3182 : 4773
# Graph range=4773 : 6364
# Graph range=6364 : 7955
# Graph range=7955 : 9546
# Graph range=9546 : 11137
# Graph range=11137 : 12728
# Graph range=12728 : 14319
# Graph range=14319 : 15910
# Graph range=15910 : 17501
# Graph range=17501 : 19092
# Graph range=19092 : 20683
# Graph range=20683 : 22274
# Graph range=22274 : 23865
# Graph range=23865 : 25456
# Graph range=25456 : 27047
# Graph range=27047 : 28638
# Graph range=28638 : 30229
# Graph range=30229 : 31820
# hiden node = 4
# Graph range=0 : 795
# Graph range=795 : 1590
# Graph range=1590 : 2385
# Graph range=2385 : 3180
# Graph range=3180 : 3975
# Graph range=3975 : 4770
# Graph range=4770 : 5565
# Graph range=5565 : 6360
# Graph range=6360 : 7155
# Graph range=7155 : 7950
# Graph range=7950 : 8745
# Graph range=8745 : 9540
# Graph range=9540 : 10335
# Graph range=10335 : 11130
# Graph range=11130 : 11925
# Graph range=11925 : 12720
# Graph range=12720 : 13515
# Graph range=13515 : 14310
# Graph range=14310 : 15105
# Graph range=15105 : 15900
# hiden node = 8
# Graph range=0 : 795
# Graph range=795 : 1590
# Graph range=1590 : 2385
# Graph range=2385 : 3180
# Graph range=3180 : 3975
# Graph range=3975 : 4770
# Graph range=4770 : 5565
# Graph range=5565 : 6360
# Graph range=6360 : 7155
# Graph range=7155 : 7950
# Graph range=7950 : 8745
# Graph range=8745 : 9540
# Graph range=9540 : 10335
# Graph range=10335 : 11130
# Graph range=11130 : 11925
# Graph range=11925 : 12720
# Graph range=12720 : 13515
# Graph range=13515 : 14310
# Graph range=14310 : 15105
# Graph range=15105 : 15900
# hiden node = 12
# Graph range=0 : 795
# Graph range=795 : 1590
# Graph range=1590 : 2385
# Graph range=2385 : 3180
# Graph range=3180 : 3975
# Graph range=3975 : 4770
# Graph range=4770 : 5565
# Graph range=5565 : 6360
# Graph range=6360 : 7155
# Graph range=7155 : 7950
# Graph range=7950 : 8745
# Graph range=8745 : 9540
# Graph range=9540 : 10335
# Graph range=10335 : 11130
# Graph range=11130 : 11925
# Graph range=11925 : 12720
# Graph range=12720 : 13515
# Graph range=13515 : 14310
# Graph range=14310 : 15105
# Graph range=15105 : 15900
# hiden node = 16
# Graph range=0 : 795
# Graph range=795 : 1590
# Graph range=1590 : 2385
# Graph range=2385 : 3180
# Graph range=3180 : 3975
# Graph range=3975 : 4770
# Graph range=4770 : 5565
# Graph range=5565 : 6360
# Graph range=6360 : 7155
# Graph range=7155 : 7950
# Graph range=7950 : 8745
# Graph range=8745 : 9540
# Graph range=9540 : 10335
# Graph range=10335 : 11130
# Graph range=11130 : 11925
# Graph range=11925 : 12720
# Graph range=12720 : 13515
# Graph range=13515 : 14310
# Graph range=14310 : 15105
# Graph range=15105 : 15900
# hiden node = 32
# Graph range=0 : 795
# Graph range=795 : 1590
# Graph range=1590 : 2385
# Graph range=2385 : 3180
# Graph range=3180 : 3975
# Graph range=3975 : 4770
# Graph range=4770 : 5565
# Graph range=5565 : 6360
# Graph range=6360 : 7155
# Graph range=7155 : 7950
# Graph range=7950 : 8745
# Graph range=8745 : 9540
# Graph range=9540 : 10335
# Graph range=10335 : 11130
# Graph range=11130 : 11925
# Graph range=11925 : 12720
# Graph range=12720 : 13515
# Graph range=13515 : 14310
# Graph range=14310 : 15105
# Graph range=15105 : 15900
# hiden node = 64
# Graph range=0 : 795
# Graph range=795 : 1590
# Graph range=1590 : 2385
# Graph range=2385 : 3180
# Graph range=3180 : 3975
# Graph range=3975 : 4770
# Graph range=4770 : 5565
# Graph range=5565 : 6360
# Graph range=6360 : 7155
# Graph range=7155 : 7950
# Graph range=7950 : 8745
# Graph range=8745 : 9540
# Graph range=9540 : 10335
# Graph range=10335 : 11130
# Graph range=11130 : 11925
# Graph range=11925 : 12720
# Graph range=12720 : 13515
# Graph range=13515 : 14310
# Graph range=14310 : 15105
# Graph range=15105 : 15900
# hiden node = 4
# Graph range=0 : 397
# Graph range=397 : 794
# Graph range=794 : 1191
# Graph range=1191 : 1588
# Graph range=1588 : 1985
# Graph range=1985 : 2382
# Graph range=2382 : 2779
# Graph range=2779 : 3176
# Graph range=3176 : 3573
# Graph range=3573 : 3970
# Graph range=3970 : 4367
# Graph range=4367 : 4764
# Graph range=4764 : 5161
# Graph range=5161 : 5558
# Graph range=5558 : 5955
# Graph range=5955 : 6352
# Graph range=6352 : 6749
# Graph range=6749 : 7146
# Graph range=7146 : 7543
# Graph range=7543 : 7940
# hiden node = 8
# Graph range=0 : 397
# Graph range=397 : 794
# Graph range=794 : 1191
# Graph range=1191 : 1588
# Graph range=1588 : 1985
# Graph range=1985 : 2382
# Graph range=2382 : 2779
# Graph range=2779 : 3176
# Graph range=3176 : 3573
# Graph range=3573 : 3970
# Graph range=3970 : 4367
# Graph range=4367 : 4764
# Graph range=4764 : 5161
# Graph range=5161 : 5558
# Graph range=5558 : 5955
# Graph range=5955 : 6352
# Graph range=6352 : 6749
# Graph range=6749 : 7146
# Graph range=7146 : 7543
# Graph range=7543 : 7940
# hiden node = 12
# Graph range=0 : 397
# Graph range=397 : 794
# Graph range=794 : 1191
# Graph range=1191 : 1588
# Graph range=1588 : 1985
# Graph range=1985 : 2382
# Graph range=2382 : 2779
# Graph range=2779 : 3176
# Graph range=3176 : 3573
# Graph range=3573 : 3970
# Graph range=3970 : 4367
# Graph range=4367 : 4764
# Graph range=4764 : 5161
# Graph range=5161 : 5558
# Graph range=5558 : 5955
# Graph range=5955 : 6352
# Graph range=6352 : 6749
# Graph range=6749 : 7146
# Graph range=7146 : 7543
# Graph range=7543 : 7940
# hiden node = 16
# Graph range=0 : 397
# Graph range=397 : 794
# Graph range=794 : 1191
# Graph range=1191 : 1588
# Graph range=1588 : 1985
# Graph range=1985 : 2382
# Graph range=2382 : 2779
# Graph range=2779 : 3176
# Graph range=3176 : 3573
# Graph range=3573 : 3970
# Graph range=3970 : 4367
# Graph range=4367 : 4764
# Graph range=4764 : 5161
# Graph range=5161 : 5558
# Graph range=5558 : 5955
# Graph range=5955 : 6352
# Graph range=6352 : 6749
# Graph range=6749 : 7146
# Graph range=7146 : 7543
# Graph range=7543 : 7940
# hiden node = 32
# Graph range=0 : 397
# Graph range=397 : 794
# Graph range=794 : 1191
# Graph range=1191 : 1588
# Graph range=1588 : 1985
# Graph range=1985 : 2382
# Graph range=2382 : 2779
# Graph range=2779 : 3176
# Graph range=3176 : 3573
# Graph range=3573 : 3970
# Graph range=3970 : 4367
# Graph range=4367 : 4764
# Graph range=4764 : 5161
# Graph range=5161 : 5558
# Graph range=5558 : 5955
# Graph range=5955 : 6352
# Graph range=6352 : 6749
# Graph range=6749 : 7146
# Graph range=7146 : 7543
# Graph range=7543 : 7940
# hiden node = 64
# Graph range=0 : 397
# Graph range=397 : 794
# Graph range=794 : 1191
# Graph range=1191 : 1588
# Graph range=1588 : 1985
# Graph range=1985 : 2382
# Graph range=2382 : 2779
# Graph range=2779 : 3176
# Graph range=3176 : 3573
# Graph range=3573 : 3970
# Graph range=3970 : 4367
# Graph range=4367 : 4764
# Graph range=4764 : 5161
# Graph range=5161 : 5558
# Graph range=5558 : 5955
# Graph range=5955 : 6352
# Graph range=6352 : 6749
# Graph range=6749 : 7146
# Graph range=7146 : 7543
# Graph range=7543 : 7940
# hiden node = 4
# Graph range=0 : 198
# Graph range=198 : 396
# Graph range=396 : 594
# Graph range=594 : 792
# Graph range=792 : 990
# Graph range=990 : 1188
# Graph range=1188 : 1386
# Graph range=1386 : 1584
# Graph range=1584 : 1782
# Graph range=1782 : 1980
# Graph range=1980 : 2178
# Graph range=2178 : 2376
# Graph range=2376 : 2574
# Graph range=2574 : 2772
# Graph range=2772 : 2970
# Graph range=2970 : 3168
# Graph range=3168 : 3366
# Graph range=3366 : 3564
# Graph range=3564 : 3762
# Graph range=3762 : 3960
# hiden node = 8
# Graph range=0 : 198
# Graph range=198 : 396
# Graph range=396 : 594
# Graph range=594 : 792
# Graph range=792 : 990
# Graph range=990 : 1188
# Graph range=1188 : 1386
# Graph range=1386 : 1584
# Graph range=1584 : 1782
# Graph range=1782 : 1980
# Graph range=1980 : 2178
# Graph range=2178 : 2376
# Graph range=2376 : 2574
# Graph range=2574 : 2772
# Graph range=2772 : 2970
# Graph range=2970 : 3168
# Graph range=3168 : 3366
# Graph range=3366 : 3564
# Graph range=3564 : 3762
# Graph range=3762 : 3960
# hiden node = 12
# Graph range=0 : 198
# Graph range=198 : 396
# Graph range=396 : 594
# Graph range=594 : 792
# Graph range=792 : 990
# Graph range=990 : 1188
# Graph range=1188 : 1386
# Graph range=1386 : 1584
# Graph range=1584 : 1782
# Graph range=1782 : 1980
# Graph range=1980 : 2178
# Graph range=2178 : 2376
# Graph range=2376 : 2574
# Graph range=2574 : 2772
# Graph range=2772 : 2970
# Graph range=2970 : 3168
# Graph range=3168 : 3366
# Graph range=3366 : 3564
# Graph range=3564 : 3762
# Graph range=3762 : 3960
# hiden node = 16
# Graph range=0 : 198
# Graph range=198 : 396
# Graph range=396 : 594
# Graph range=594 : 792
# Graph range=792 : 990
# Graph range=990 : 1188
# Graph range=1188 : 1386
# Graph range=1386 : 1584
# Graph range=1584 : 1782
# Graph range=1782 : 1980
# Graph range=1980 : 2178
# Graph range=2178 : 2376
# Graph range=2376 : 2574
# Graph range=2574 : 2772
# Graph range=2772 : 2970
# Graph range=2970 : 3168
# Graph range=3168 : 3366
# Graph range=3366 : 3564
# Graph range=3564 : 3762
# Graph range=3762 : 3960
# hiden node = 32
# Graph range=0 : 198
# Graph range=198 : 396
# Graph range=396 : 594
# Graph range=594 : 792
# Graph range=792 : 990
# Graph range=990 : 1188
# Graph range=1188 : 1386
# Graph range=1386 : 1584
# Graph range=1584 : 1782
# Graph range=1782 : 1980
# Graph range=1980 : 2178
# Graph range=2178 : 2376
# Graph range=2376 : 2574
# Graph range=2574 : 2772
# Graph range=2772 : 2970
# Graph range=2970 : 3168
# Graph range=3168 : 3366
# Graph range=3366 : 3564
# Graph range=3564 : 3762
# Graph range=3762 : 3960
# hiden node = 64
# Graph range=0 : 198
# Graph range=198 : 396
# Graph range=396 : 594
# Graph range=594 : 792
# Graph range=792 : 990
# Graph range=990 : 1188
# Graph range=1188 : 1386
# Graph range=1386 : 1584
# Graph range=1584 : 1782
# Graph range=1782 : 1980
# Graph range=1980 : 2178
# Graph range=2178 : 2376
# Graph range=2376 : 2574
# Graph range=2574 : 2772
# Graph range=2772 : 2970
# Graph range=2970 : 3168
# Graph range=3168 : 3366
# Graph range=3366 : 3564
# Graph range=3564 : 3762
# Graph range=3762 : 3960
# hiden node = 4
# Graph range=0 : 99
# Graph range=99 : 198
# Graph range=198 : 297
# Graph range=297 : 396
# Graph range=396 : 495
# Graph range=495 : 594
# Graph range=594 : 693
# Graph range=693 : 792
# Graph range=792 : 891
# Graph range=891 : 990
# Graph range=990 : 1089
# Graph range=1089 : 1188
# Graph range=1188 : 1287
# Graph range=1287 : 1386
# Graph range=1386 : 1485
# Graph range=1485 : 1584
# Graph range=1584 : 1683
# Graph range=1683 : 1782
# Graph range=1782 : 1881
# Graph range=1881 : 1980
# hiden node = 8
# Graph range=0 : 99
# Graph range=99 : 198
# Graph range=198 : 297
# Graph range=297 : 396
# Graph range=396 : 495
# Graph range=495 : 594
# Graph range=594 : 693
# Graph range=693 : 792
# Graph range=792 : 891
# Graph range=891 : 990
# Graph range=990 : 1089
# Graph range=1089 : 1188
# Graph range=1188 : 1287
# Graph range=1287 : 1386
# Graph range=1386 : 1485
# Graph range=1485 : 1584
# Graph range=1584 : 1683
# Graph range=1683 : 1782
# Graph range=1782 : 1881
# Graph range=1881 : 1980
# hiden node = 12
# Graph range=0 : 99
# Graph range=99 : 198
# Graph range=198 : 297
# Graph range=297 : 396
# Graph range=396 : 495
# Graph range=495 : 594
# Graph range=594 : 693
# Graph range=693 : 792
# Graph range=792 : 891
# Graph range=891 : 990
# Graph range=990 : 1089
# Graph range=1089 : 1188
# Graph range=1188 : 1287
# Graph range=1287 : 1386
# Graph range=1386 : 1485
# Graph range=1485 : 1584
# Graph range=1584 : 1683
# Graph range=1683 : 1782
# Graph range=1782 : 1881
# Graph range=1881 : 1980
# hiden node = 16
# Graph range=0 : 99
# Graph range=99 : 198
# Graph range=198 : 297
# Graph range=297 : 396
# Graph range=396 : 495
# Graph range=495 : 594
# Graph range=594 : 693
# Graph range=693 : 792
# Graph range=792 : 891
# Graph range=891 : 990
# Graph range=990 : 1089
# Graph range=1089 : 1188
# Graph range=1188 : 1287
# Graph range=1287 : 1386
# Graph range=1386 : 1485
# Graph range=1485 : 1584
# Graph range=1584 : 1683
# Graph range=1683 : 1782
# Graph range=1782 : 1881
# Graph range=1881 : 1980
# hiden node = 32
# Graph range=0 : 99
# Graph range=99 : 198
# Graph range=198 : 297
# Graph range=297 : 396
# Graph range=396 : 495
# Graph range=495 : 594
# Graph range=594 : 693
# Graph range=693 : 792
# Graph range=792 : 891
# Graph range=891 : 990
# Graph range=990 : 1089
# Graph range=1089 : 1188
# Graph range=1188 : 1287
# Graph range=1287 : 1386
# Graph range=1386 : 1485
# Graph range=1485 : 1584
# Graph range=1584 : 1683
# Graph range=1683 : 1782
# Graph range=1782 : 1881
# Graph range=1881 : 1980
# hiden node = 64
# Graph range=0 : 99
# Graph range=99 : 198
# Graph range=198 : 297
# Graph range=297 : 396
# Graph range=396 : 495
# Graph range=495 : 594
# Graph range=594 : 693
# Graph range=693 : 792
# Graph range=792 : 891
# Graph range=891 : 990
# Graph range=990 : 1089
# Graph range=1089 : 1188
# Graph range=1188 : 1287
# Graph range=1287 : 1386
# Graph range=1386 : 1485
# Graph range=1485 : 1584
# Graph range=1584 : 1683
# Graph range=1683 : 1782
# Graph range=1782 : 1881
# Graph range=1881 : 1980
# hiden node = 4
# Graph range=0 : 49
# Graph range=49 : 98
# Graph range=98 : 147
# Graph range=147 : 196
# Graph range=196 : 245
# Graph range=245 : 294
# Graph range=294 : 343
# Graph range=343 : 392
# Graph range=392 : 441
# Graph range=441 : 490
# Graph range=490 : 539
# Graph range=539 : 588
# Graph range=588 : 637
# Graph range=637 : 686
# Graph range=686 : 735
# Graph range=735 : 784
# Graph range=784 : 833
# Graph range=833 : 882
# Graph range=882 : 931
# Graph range=931 : 980
# hiden node = 8
# Graph range=0 : 49
# Graph range=49 : 98
# Graph range=98 : 147
# Graph range=147 : 196
# Graph range=196 : 245
# Graph range=245 : 294
# Graph range=294 : 343
# Graph range=343 : 392
# Graph range=392 : 441
# Graph range=441 : 490
# Graph range=490 : 539
# Graph range=539 : 588
# Graph range=588 : 637
# Graph range=637 : 686
# Graph range=686 : 735
# Graph range=735 : 784
# Graph range=784 : 833
# Graph range=833 : 882
# Graph range=882 : 931
# Graph range=931 : 980
# hiden node = 12
# Graph range=0 : 49
# Graph range=49 : 98
# Graph range=98 : 147
# Graph range=147 : 196
# Graph range=196 : 245
# Graph range=245 : 294
# Graph range=294 : 343
# Graph range=343 : 392
# Graph range=392 : 441
# Graph range=441 : 490
# Graph range=490 : 539
# Graph range=539 : 588
# Graph range=588 : 637
# Graph range=637 : 686
# Graph range=686 : 735
# Graph range=735 : 784
# Graph range=784 : 833
# Graph range=833 : 882
# Graph range=882 : 931
# Graph range=931 : 980
# hiden node = 16
# Graph range=0 : 49
# Graph range=49 : 98
# Graph range=98 : 147
# Graph range=147 : 196
# Graph range=196 : 245
# Graph range=245 : 294
# Graph range=294 : 343
# Graph range=343 : 392
# Graph range=392 : 441
# Graph range=441 : 490
# Graph range=490 : 539
# Graph range=539 : 588
# Graph range=588 : 637
# Graph range=637 : 686
# Graph range=686 : 735
# Graph range=735 : 784
# Graph range=784 : 833
# Graph range=833 : 882
# Graph range=882 : 931
# Graph range=931 : 980
# hiden node = 32
# Graph range=0 : 49
# Graph range=49 : 98
# Graph range=98 : 147
# Graph range=147 : 196
# Graph range=196 : 245
# Graph range=245 : 294
# Graph range=294 : 343
# Graph range=343 : 392
# Graph range=392 : 441
# Graph range=441 : 490
# Graph range=490 : 539
# Graph range=539 : 588
# Graph range=588 : 637
# Graph range=637 : 686
# Graph range=686 : 735
# Graph range=735 : 784
# Graph range=784 : 833
# Graph range=833 : 882
# Graph range=882 : 931
# Graph range=931 : 980
# hiden node = 64
# Graph range=0 : 49
# Graph range=49 : 98
# Graph range=98 : 147
# Graph range=147 : 196
# Graph range=196 : 245
# Graph range=245 : 294
# Graph range=294 : 343
# Graph range=343 : 392
# Graph range=392 : 441
# Graph range=441 : 490
# Graph range=490 : 539
# Graph range=539 : 588
# Graph range=588 : 637
# Graph range=637 : 686
# Graph range=686 : 735
# Graph range=735 : 784
# Graph range=784 : 833
# Graph range=833 : 882
# Graph range=882 : 931
# Graph range=931 : 980

# %%
print "finish"
# Out:
# finish
