# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
fig=plt.figure()

# %%
cd ~/Documents/01_SensorData/2016_04_12/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/01_SensorData/2016_04_12/cleaning-addingLABEL

# %%
ls
# Out:
# 20160331_180615.srt               exercises-1/
# Cleaning-Conv-left-hand-ags.csv   exercises-2/
# Cleaning-Conv-left-leg-ags.csv    exercises-3/
# Cleaning-Conv-right-hand-ags.csv  exercises-4/
# Cleaning-Conv-right-leg-ags.csv   exercises-5/
# Cleaning-Conv-west-ags.csv        exercises-6/
# CleaningConv-left-hand-ags.csv    exercises-finish/
# CleaningConv-left-leg-ags.csv     exercises-start/
# CleaningConv-right-hand-ags.csv   free/
# CleaningConv-right-leg-ags.csv    get-away-things/
# CleaningConv-west-ags.csv         grap-big-box/
# Cleaning_left_hand_ags.csv        grap-bloom/
# Conv-left-hand-ags.csv            grap-cleaner/
# Conv-left-hand-batt.csv           grap-small-box/
# Conv-left-leg-ags.csv             grap-small-box-one-hand/
# Conv-left-leg-batt.csv            label-data.csv
# Conv-right-hand-ags.csv           left-hand.csv
# Conv-right-hand-batt.csv          left-leg.csv
# Conv-right-leg-ags.csv            missing/
# ...

# %%
Rdata=pd.read_csv("Cleaning-Conv-right-hand-ags.csv")
Ldata=pd.read_csv("Cleaning-Conv-left-hand-ags.csv")

# %%
WRdata=Rdata[Rdata.label=='walking']

# %%
TRdata=Rdata[Rdata.label=='walking-turn']

# %%
TRdata
# Out:
#        Unnamed: 0  Unnamed: 0.1 Type                     Time    AccX    AccY  \
# 309           309           309  ags  2016-04-14 18:06:18.746  1.2023 -0.3056
# 310           310           310  ags  2016-04-14 18:06:18.756  1.1346 -0.2919
# 311           311           311  ags  2016-04-14 18:06:18.766  1.0826 -0.2582
# 312           312           312  ags  2016-04-14 18:06:18.776  1.0404 -0.1984
# 313           313           313  ags  2016-04-14 18:06:18.786  1.0316 -0.1847
# 314           314           314  ags  2016-04-14 18:06:18.796  1.0272 -0.1794
# 315           315           315  ags  2016-04-14 18:06:18.806  1.0482 -0.1669
# 316           316           316  ags  2016-04-14 18:06:18.816  1.0721 -0.1496
# 317           317           317  ags  2016-04-14 18:06:18.826  1.0866 -0.1178
# 318           318           318  ags  2016-04-14 18:06:18.836  1.0968 -0.1100
# 319           319           319  ags  2016-04-14 18:06:18.846  1.0883 -0.1007
# ...

# %%
plt.scatter(WRdata.AccX, WRdata.AccY,color='red')
plt.scatter(TRdata.AccX, TRdata.AccY,color='blue',alpha=0.3)

# %%
data.AccX.mean()
# Out:
# 0.70937705500450854

# %%
data.AccX.var()
# Out:
# 0.33603481053936202

# %%
data.AccX.var(ddof=False)
# Out:
# 0.33602875039850466

# %%
data.AccX.describe()
# Out:
# count    55450.000000
# mean         0.709377
# std          0.579685
# min         -2.747100
# 25%          0.338500
# 50%          0.849200
# 75%          1.005000
# max          7.953000
# Name: AccX, dtype: float64

# %%
data.AccY.describe()
# Out:
# count    55450.000000
# mean        -0.440691
# std          0.379654
# min         -4.129800
# 25%         -0.723800
# 50%         -0.337800
# 75%         -0.189400
# max          7.982400
# Name: AccY, dtype: float64

# %%
data.AccZ.describe()
# Out:
# count    55450.000000
# mean         0.102556
# std          0.332528
# min         -5.352800
# 25%         -0.096700
# 50%          0.077800
# 75%          0.236300
# max          8.017500
# Name: AccZ, dtype: float64
