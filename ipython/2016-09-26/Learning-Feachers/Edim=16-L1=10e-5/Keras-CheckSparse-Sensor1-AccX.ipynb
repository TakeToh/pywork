# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,32,64,128,256] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccX' # Axis

WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData"
DATE_PATH="/2016-08-15/"
TITLE_PATH="Sparse/"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras import regularizers

import matplotlib.image as mpimg
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5005)

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
# define rawdata directory
if not os.path.exists(WORKSPACE_PATH+"/raw/"):
    os.makedirs(WORKSPACE_PATH+"/raw/")
RawDataPath=WORKSPACE_PATH+"/raw/"

# define restoring windowdata directory
if not os.path.exists(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'

# define restoring netowrk model picture's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'

# define restoring graph data's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/')
GlaphDataPath=WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'

# define restoring model paarmeter directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/')
StudyDataPath=WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成 & Learning**

# %%
encoding_dim
# Out:
# 16

# %%
# loop windowWidth
for SampleNum in WindowWidth:
    for Overlap in OverlapArray:

        w=window.Window()
        w.SetData(Axis,dic[Axis])
        wind=w.Compile(windowWidth=SampleNum,overlapNum=Overlap)
        windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
        print "hiden node = "+str(encoding_dim)
        CommonName='-edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+"l1_reg=10e-5"
        print CommonName
        SaveFileNameEncord=DataName+'_encoded'+CommonName
        SaveFileNameDecord=DataName+'_decoded'+CommonName
        SaveFileNameNet=DataName+'_net'+CommonName
        SaveFileNameTrain=DataName+'_train'+CommonName
        SaveFileNameTest=DataName+'_test'+CommonName
        SaveFileNameGlaph=GlaphDataPath+DataName+CommonName+'_loss_val_loss.png'

        window_test=windoW
        window_train=windoW
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTrain,window_test)
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTest,window_test)
        shapeNum=windoW.shape[1]

        # this is our input placeholder
        input_img = Input(shape=(shapeNum,))
        # "encoded" is the encoded representation of the input
        encoded = Dense(encoding_dim, activation='tanh',
                    W_regularizer=regularizers.WeightRegularizer(l1=10e-5,l2=0.0))(input_img)
        # "decoded" is the lossy reconstruction of the input
        decoded = Dense(shapeNum, activation='linear')(encoded)

        # this model maps an input to its reconstruction
        autoencoder = Model(input=input_img, output=decoded)

        # this model maps an input to its encoded representation
        encoder = Model(input=input_img, output=encoded)

        # create a placeholder for an encoded (32-dimensional) input
        encoded_input = Input(shape=(encoding_dim,))
        # retrieve the last layer of the autoencoder model
        decoder_layer = autoencoder.layers[-1]
        # create the decoder model
        decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))
        
        #autoencoder.compile(optimizer='adam', loss='mse')
        autoencoder.compile(optimizer='adam', loss='categorical_crossentropy')
        
        plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')

        early_stopping = EarlyStopping(monitor='val_loss', patience=5)
        
        hist = autoencoder.fit(window_train, window_train,
                        nb_epoch=100,
                        verbose=2,
                        batch_size=shapeNum/8,
                        shuffle=True,
                        validation_data=(window_test, window_test)
                        ,callbacks=[early_stopping]
                              )
        time.sleep(0.1)
        encoded_imgs = encoder.predict(window_test)
        decoded_imgs = decoder.predict(encoded_imgs)

        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameEncord,encoded_imgs)
        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameDecord,decoded_imgs)

        # save model and wights
        json_string = encoder.to_json()
        open(StudyDataPath+SaveFileNameEncord+'.json', 'w').write(json_string)
        encoder.save_weights(StudyDataPath+SaveFileNameEncord+'_weights.h5',overwrite=True)

        json_string = decoder.to_json()
        open(StudyDataPath+SaveFileNameDecord+'.json', 'w').write(json_string)
        decoder.save_weights(StudyDataPath+SaveFileNameDecord+'_weights.h5',overwrite=True)

        json_string = autoencoder.to_json()
        open(StudyDataPath+SaveFileNameNet+'.json', 'w').write(json_string)
        autoencoder.save_weights(StudyDataPath+SaveFileNameNet+'_weights.h5',overwrite=True)

        # plot loss
        loss = hist.history['loss']
        val_loss = hist.history['val_loss']

        nb_epoch = len(loss)
        plt.plot(range(nb_epoch), loss, marker='.', label='loss')
        plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
        plt.legend(loc='best', fontsize=10)
        plt.grid()
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.savefig(SaveFileNameGlaph)
        plt.show()
# Out:
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15914
# SourceData's aborting data = 6
# window shape is (15914, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=16-l1_reg=10e-5
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 2s - loss: -1.2989e+03 - val_loss: -1.3708e+03
# Epoch 2/100
# 1s - loss: -1.3890e+03 - val_loss: -1.4305e+03
# Epoch 3/100
# 2s - loss: -1.4355e+03 - val_loss: -1.4425e+03
# Epoch 4/100
# 3s - loss: -1.4652e+03 - val_loss: -1.4901e+03
# Epoch 5/100
# 3s - loss: -1.4940e+03 - val_loss: -1.4943e+03
# Epoch 6/100
# 3s - loss: -1.5056e+03 - val_loss: -1.5128e+03
# Epoch 7/100
# 3s - loss: -1.5202e+03 - val_loss: -1.5341e+03
# Epoch 8/100
# 3s - loss: -1.5292e+03 - val_loss: -1.5261e+03
# Epoch 9/100
# 3s - loss: -1.5301e+03 - val_loss: -1.5309e+03
# Epoch 10/100
# 3s - loss: -1.5359e+03 - val_loss: -1.5403e+03
# Epoch 11/100
# 3s - loss: -1.5408e+03 - val_loss: -1.5410e+03
# Epoch 12/100
# 3s - loss: -1.5410e+03 - val_loss: -1.5408e+03
# Epoch 13/100
# 4s - loss: -1.5414e+03 - val_loss: -1.5420e+03
# Epoch 14/100
# 4s - loss: -1.5420e+03 - val_loss: -1.5414e+03
# Epoch 15/100
# 4s - loss: -1.5422e+03 - val_loss: -1.5432e+03
# Epoch 16/100
# 4s - loss: -1.5423e+03 - val_loss: -1.5426e+03
# Epoch 17/100
# 3s - loss: -1.5422e+03 - val_loss: -1.5425e+03
# Epoch 18/100
# 3s - loss: -1.5426e+03 - val_loss: -1.5432e+03
# Epoch 19/100
# 3s - loss: -1.5432e+03 - val_loss: -1.5444e+03
# Epoch 20/100
# 3s - loss: -1.5433e+03 - val_loss: -1.5435e+03
# Epoch 21/100
# 3s - loss: -1.5434e+03 - val_loss: -1.5409e+03
# Epoch 22/100
# 4s - loss: -1.5428e+03 - val_loss: -1.5418e+03
# Epoch 23/100
# 4s - loss: -1.5427e+03 - val_loss: -1.5435e+03
# Epoch 24/100
# 4s - loss: -1.5430e+03 - val_loss: -1.5447e+03
# Epoch 25/100
# 3s - loss: -1.5438e+03 - val_loss: -1.5437e+03
# Epoch 26/100
# 4s - loss: -1.5442e+03 - val_loss: -1.5451e+03
# Epoch 27/100
# 4s - loss: -1.5442e+03 - val_loss: -1.5450e+03
# Epoch 28/100
# 4s - loss: -1.5442e+03 - val_loss: -1.5451e+03
# Epoch 29/100
# 4s - loss: -1.5444e+03 - val_loss: -1.5437e+03
# Epoch 30/100
# 4s - loss: -1.5439e+03 - val_loss: -1.5446e+03
# Epoch 31/100
# 2s - loss: -1.5445e+03 - val_loss: -1.5447e+03
# Epoch 32/100
# 2s - loss: -1.5442e+03 - val_loss: -1.5443e+03
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/backend/theano_backend.py:558: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 1 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7957
# SourceData's aborting data = 22
# window shape is (7957, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=32-l1_reg=10e-5
# Train on 7957 samples, validate on 7957 samples
# Epoch 1/100
# 2s - loss: -1.2430e+03 - val_loss: -1.2947e+03
# Epoch 2/100
# 2s - loss: -1.3403e+03 - val_loss: -1.3794e+03
# Epoch 3/100
# 1s - loss: -1.4040e+03 - val_loss: -1.4203e+03
# Epoch 4/100
# 1s - loss: -1.4379e+03 - val_loss: -1.4599e+03
# Epoch 5/100
# 2s - loss: -1.4636e+03 - val_loss: -1.4714e+03
# Epoch 6/100
# 1s - loss: -1.4834e+03 - val_loss: -1.5001e+03
# Epoch 7/100
# 1s - loss: -1.5007e+03 - val_loss: -1.5019e+03
# Epoch 8/100
# 2s - loss: -1.5108e+03 - val_loss: -1.5119e+03
# Epoch 9/100
# 2s - loss: -1.5183e+03 - val_loss: -1.5246e+03
# Epoch 10/100
# 2s - loss: -1.5413e+03 - val_loss: -1.5547e+03
# Epoch 11/100
# 1s - loss: -1.5554e+03 - val_loss: -1.5560e+03
# Epoch 12/100
# 1s - loss: -1.5559e+03 - val_loss: -1.5562e+03
# Epoch 13/100
# 1s - loss: -1.5560e+03 - val_loss: -1.5559e+03
# Epoch 14/100
# 1s - loss: -1.5521e+03 - val_loss: -1.5515e+03
# Epoch 15/100
# 1s - loss: -1.5508e+03 - val_loss: -1.5520e+03
# Epoch 16/100
# 1s - loss: -1.5619e+03 - val_loss: -1.5632e+03
# Epoch 17/100
# 0s - loss: -1.5635e+03 - val_loss: -1.5642e+03
# Epoch 18/100
# 0s - loss: -1.2822e+03 - val_loss: -7.9938e+02
# Epoch 19/100
# 0s - loss: -9.7213e+02 - val_loss: -1.1082e+03
# Epoch 20/100
# 1s - loss: -1.1857e+03 - val_loss: -1.2572e+03
# Epoch 21/100
# 1s - loss: -1.2796e+03 - val_loss: -1.3130e+03
# Epoch 22/100
# 1s - loss: -1.3293e+03 - val_loss: -1.3416e+03
# Epoch 23/100
# 1s - loss: -1.3694e+03 - val_loss: -1.3864e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =3979
# SourceData's aborting data = 22
# window shape is (3979, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=64-l1_reg=10e-5
# Train on 3979 samples, validate on 3979 samples
# Epoch 1/100
# 0s - loss: -1.1546e+03 - val_loss: -1.2545e+03
# Epoch 2/100
# 0s - loss: -1.2939e+03 - val_loss: -1.3548e+03
# Epoch 3/100
# 0s - loss: -1.3621e+03 - val_loss: -1.3676e+03
# Epoch 4/100
# 0s - loss: -1.3765e+03 - val_loss: -1.3801e+03
# Epoch 5/100
# 0s - loss: -1.3875e+03 - val_loss: -1.3896e+03
# Epoch 6/100
# 0s - loss: -1.3924e+03 - val_loss: -1.3921e+03
# Epoch 7/100
# 0s - loss: -1.3972e+03 - val_loss: -1.4011e+03
# Epoch 8/100
# 0s - loss: -1.4113e+03 - val_loss: -1.4205e+03
# Epoch 9/100
# 0s - loss: -1.4311e+03 - val_loss: -1.4388e+03
# Epoch 10/100
# 0s - loss: -1.4399e+03 - val_loss: -1.4411e+03
# Epoch 11/100
# 0s - loss: -1.4483e+03 - val_loss: -1.4509e+03
# Epoch 12/100
# 0s - loss: -1.4515e+03 - val_loss: -1.4547e+03
# Epoch 13/100
# 0s - loss: -1.4625e+03 - val_loss: -1.4704e+03
# Epoch 14/100
# 0s - loss: -1.4724e+03 - val_loss: -1.4811e+03
# Epoch 15/100
# 0s - loss: -1.4816e+03 - val_loss: -1.4819e+03
# Epoch 16/100
# 0s - loss: -1.4857e+03 - val_loss: -1.4927e+03
# Epoch 17/100
# 0s - loss: -1.4980e+03 - val_loss: -1.5029e+03
# Epoch 18/100
# 0s - loss: -1.5032e+03 - val_loss: -1.5035e+03
# Epoch 19/100
# 0s - loss: -1.5087e+03 - val_loss: -1.5129e+03
# Epoch 20/100
# 0s - loss: -1.5132e+03 - val_loss: -1.5130e+03
# Epoch 21/100
# 0s - loss: -1.5113e+03 - val_loss: -1.5125e+03
# Epoch 22/100
# 0s - loss: -1.5203e+03 - val_loss: -1.5232e+03
# Epoch 23/100
# 0s - loss: -1.5234e+03 - val_loss: -1.5233e+03
# Epoch 24/100
# 0s - loss: -1.5263e+03 - val_loss: -1.5349e+03
# Epoch 25/100
# 0s - loss: -1.5347e+03 - val_loss: -1.5347e+03
# Epoch 26/100
# 0s - loss: -1.5365e+03 - val_loss: -1.5450e+03
# Epoch 27/100
# 0s - loss: -1.5453e+03 - val_loss: -1.5457e+03
# Epoch 28/100
# 0s - loss: -1.5456e+03 - val_loss: -1.5457e+03
# Epoch 29/100
# 0s - loss: -1.5469e+03 - val_loss: -1.5559e+03
# Epoch 30/100
# 0s - loss: -1.5564e+03 - val_loss: -1.5567e+03
# Epoch 31/100
# 0s - loss: -1.5563e+03 - val_loss: -1.5562e+03
# Epoch 32/100
# 0s - loss: -1.5567e+03 - val_loss: -1.5572e+03
# Epoch 33/100
# 0s - loss: -1.5604e+03 - val_loss: -1.5683e+03
# Epoch 34/100
# 0s - loss: -1.5686e+03 - val_loss: -1.5685e+03
# Epoch 35/100
# 0s - loss: -1.5643e+03 - val_loss: -1.5620e+03
# Epoch 36/100
# 0s - loss: -1.5633e+03 - val_loss: -1.5632e+03
# Epoch 37/100
# 0s - loss: -1.5644e+03 - val_loss: -1.5652e+03
# Epoch 38/100
# 0s - loss: -1.5750e+03 - val_loss: -1.5763e+03
# Epoch 39/100
# 0s - loss: -1.3807e+03 - val_loss: -7.3469e+02
# Epoch 40/100
# 0s - loss: -8.4636e+02 - val_loss: -9.1047e+02
# Epoch 41/100
# 0s - loss: -9.3220e+02 - val_loss: -9.6131e+02
# Epoch 42/100
# 0s - loss: -1.0145e+03 - val_loss: -1.0628e+03
# Epoch 43/100
# 0s - loss: -1.0886e+03 - val_loss: -1.1177e+03
# Epoch 44/100
# 1s - loss: -1.1593e+03 - val_loss: -1.1857e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =1990
# SourceData's aborting data = 22
# window shape is (1990, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=128-l1_reg=10e-5
# Train on 1990 samples, validate on 1990 samples
# Epoch 1/100
# 0s - loss: -1.0719e+03 - val_loss: -1.1450e+03
# Epoch 2/100
# 0s - loss: -1.1956e+03 - val_loss: -1.2299e+03
# Epoch 3/100
# 0s - loss: -1.2782e+03 - val_loss: -1.3269e+03
# Epoch 4/100
# 0s - loss: -1.3338e+03 - val_loss: -1.3378e+03
# Epoch 5/100
# 0s - loss: -1.3414e+03 - val_loss: -1.3468e+03
# Epoch 6/100
# 0s - loss: -1.3467e+03 - val_loss: -1.3428e+03
# Epoch 7/100
# 0s - loss: -1.3478e+03 - val_loss: -1.3499e+03
# Epoch 8/100
# 0s - loss: -1.3564e+03 - val_loss: -1.3687e+03
# Epoch 9/100
# 0s - loss: -1.3735e+03 - val_loss: -1.3802e+03
# Epoch 10/100
# 0s - loss: -1.3885e+03 - val_loss: -1.3981e+03
# Epoch 11/100
# 0s - loss: -1.4005e+03 - val_loss: -1.4076e+03
# Epoch 12/100
# 0s - loss: -1.4088e+03 - val_loss: -1.4097e+03
# Epoch 13/100
# 0s - loss: -1.4172e+03 - val_loss: -1.4194e+03
# Epoch 14/100
# 0s - loss: -1.4239e+03 - val_loss: -1.4377e+03
# Epoch 15/100
# 0s - loss: -1.4378e+03 - val_loss: -1.4382e+03
# Epoch 16/100
# 0s - loss: -1.4414e+03 - val_loss: -1.4478e+03
# Epoch 17/100
# 0s - loss: -1.4472e+03 - val_loss: -1.4406e+03
# Epoch 18/100
# 0s - loss: -1.4469e+03 - val_loss: -1.4485e+03
# Epoch 19/100
# 0s - loss: -1.4488e+03 - val_loss: -1.4492e+03
# Epoch 20/100
# 0s - loss: -1.4494e+03 - val_loss: -1.4498e+03
# Epoch 21/100
# 0s - loss: -1.4500e+03 - val_loss: -1.4504e+03
# Epoch 22/100
# 0s - loss: -1.4533e+03 - val_loss: -1.4599e+03
# Epoch 23/100
# 0s - loss: -1.4584e+03 - val_loss: -1.4592e+03
# Epoch 24/100
# 0s - loss: -1.4593e+03 - val_loss: -1.4596e+03
# Epoch 25/100
# 0s - loss: -1.4599e+03 - val_loss: -1.4600e+03
# Epoch 26/100
# 0s - loss: -1.4606e+03 - val_loss: -1.4610e+03
# Epoch 27/100
# 0s - loss: -1.4633e+03 - val_loss: -1.4705e+03
# Epoch 28/100
# 0s - loss: -1.4708e+03 - val_loss: -1.4709e+03
# Epoch 29/100
# 0s - loss: -1.4710e+03 - val_loss: -1.4708e+03
# Epoch 30/100
# 0s - loss: -1.4765e+03 - val_loss: -1.4804e+03
# Epoch 31/100
# 0s - loss: -1.4807e+03 - val_loss: -1.4811e+03
# Epoch 32/100
# 0s - loss: -1.4813e+03 - val_loss: -1.4815e+03
# Epoch 33/100
# 0s - loss: -1.4772e+03 - val_loss: -1.4832e+03
# Epoch 34/100
# 0s - loss: -1.4908e+03 - val_loss: -1.4911e+03
# Epoch 35/100
# 0s - loss: -1.4907e+03 - val_loss: -1.4858e+03
# Epoch 36/100
# 0s - loss: -1.4916e+03 - val_loss: -1.4920e+03
# Epoch 37/100
# 0s - loss: -1.4917e+03 - val_loss: -1.4915e+03
# Epoch 38/100
# 0s - loss: -1.4915e+03 - val_loss: -1.4915e+03
# Epoch 39/100
# 0s - loss: -1.4919e+03 - val_loss: -1.4922e+03
# Epoch 40/100
# 0s - loss: -1.4913e+03 - val_loss: -1.4917e+03
# Epoch 41/100
# 0s - loss: -1.4920e+03 - val_loss: -1.4919e+03
# Epoch 42/100
# 0s - loss: -1.4919e+03 - val_loss: -1.4921e+03
# Epoch 43/100
# 0s - loss: -1.4922e+03 - val_loss: -1.4927e+03
# Epoch 44/100
# 0s - loss: -1.4932e+03 - val_loss: -1.4939e+03
# Epoch 45/100
# 0s - loss: -1.5005e+03 - val_loss: -1.5029e+03
# Epoch 46/100
# 0s - loss: -1.5027e+03 - val_loss: -1.5032e+03
# Epoch 47/100
# 0s - loss: -1.5040e+03 - val_loss: -1.5128e+03
# Epoch 48/100
# 0s - loss: -1.5137e+03 - val_loss: -1.5140e+03
# Epoch 49/100
# 0s - loss: -1.5141e+03 - val_loss: -1.5145e+03
# Epoch 50/100
# 0s - loss: -1.5175e+03 - val_loss: -1.5244e+03
# Epoch 51/100
# 0s - loss: -1.5205e+03 - val_loss: -1.5219e+03
# Epoch 52/100
# 0s - loss: -1.5217e+03 - val_loss: -1.5219e+03
# Epoch 53/100
# 0s - loss: -1.5224e+03 - val_loss: -1.5228e+03
# Epoch 54/100
# 0s - loss: -1.5232e+03 - val_loss: -1.5234e+03
# Epoch 55/100
# 0s - loss: -1.5238e+03 - val_loss: -1.5240e+03
# Epoch 56/100
# 0s - loss: -1.5243e+03 - val_loss: -1.5245e+03
# Epoch 57/100
# 0s - loss: -1.5234e+03 - val_loss: -1.5244e+03
# Epoch 58/100
# 0s - loss: -1.5246e+03 - val_loss: -1.5246e+03
# Epoch 59/100
# 0s - loss: -1.5245e+03 - val_loss: -1.5245e+03
# Epoch 60/100
# 0s - loss: -1.5232e+03 - val_loss: -1.5232e+03
# Epoch 61/100
# 0s - loss: -1.5233e+03 - val_loss: -1.5235e+03
# Epoch 62/100
# 0s - loss: -1.5239e+03 - val_loss: -1.5240e+03
# Epoch 63/100
# 0s - loss: -1.5242e+03 - val_loss: -1.5241e+03
# Epoch 64/100
# 0s - loss: -1.5238e+03 - val_loss: -1.5237e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =995
# SourceData's aborting data = 150
# window shape is (995, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=256-l1_reg=10e-5
# Train on 995 samples, validate on 995 samples
# Epoch 1/100
# 0s - loss: -1.0654e+03 - val_loss: -1.1152e+03
# Epoch 2/100
# 0s - loss: -1.1557e+03 - val_loss: -1.1783e+03
# Epoch 3/100
# 0s - loss: -1.2011e+03 - val_loss: -1.2261e+03
# Epoch 4/100
# 0s - loss: -1.2461e+03 - val_loss: -1.2620e+03
# Epoch 5/100
# 0s - loss: -1.2881e+03 - val_loss: -1.3130e+03
# Epoch 6/100
# 0s - loss: -1.3248e+03 - val_loss: -1.3278e+03
# Epoch 7/100
# 0s - loss: -1.3329e+03 - val_loss: -1.3398e+03
# Epoch 8/100
# 0s - loss: -1.3475e+03 - val_loss: -1.3484e+03
# Epoch 9/100
# 0s - loss: -1.3490e+03 - val_loss: -1.3493e+03
# Epoch 10/100
# 0s - loss: -1.3495e+03 - val_loss: -1.3496e+03
# Epoch 11/100
# 0s - loss: -1.3501e+03 - val_loss: -1.3507e+03
# Epoch 12/100
# 0s - loss: -1.3577e+03 - val_loss: -1.3596e+03
# Epoch 13/100
# 0s - loss: -1.3602e+03 - val_loss: -1.3594e+03
# Epoch 14/100
# 0s - loss: -1.3691e+03 - val_loss: -1.3794e+03
# Epoch 15/100
# 0s - loss: -1.3856e+03 - val_loss: -1.3888e+03
# Epoch 16/100
# 0s - loss: -1.3893e+03 - val_loss: -1.3895e+03
# Epoch 17/100
# 0s - loss: -1.3898e+03 - val_loss: -1.3902e+03
# Epoch 18/100
# 0s - loss: -1.3944e+03 - val_loss: -1.3993e+03
# Epoch 19/100
# 0s - loss: -1.3995e+03 - val_loss: -1.3998e+03
# Epoch 20/100
# 0s - loss: -1.3999e+03 - val_loss: -1.4003e+03
# Epoch 21/100
# 0s - loss: -1.4012e+03 - val_loss: -1.4101e+03
# Epoch 22/100
# 0s - loss: -1.4124e+03 - val_loss: -1.4195e+03
# Epoch 23/100
# 0s - loss: -1.4195e+03 - val_loss: -1.4195e+03
# Epoch 24/100
# 0s - loss: -1.4195e+03 - val_loss: -1.4201e+03
# Epoch 25/100
# 0s - loss: -1.4271e+03 - val_loss: -1.4295e+03
# Epoch 26/100
# 0s - loss: -1.4294e+03 - val_loss: -1.4299e+03
# Epoch 27/100
# 0s - loss: -1.4300e+03 - val_loss: -1.4304e+03
# Epoch 28/100
# 0s - loss: -1.4310e+03 - val_loss: -1.4398e+03
# Epoch 29/100
# 0s - loss: -1.4401e+03 - val_loss: -1.4403e+03
# Epoch 30/100
# 0s - loss: -1.4401e+03 - val_loss: -1.4401e+03
# Epoch 31/100
# 0s - loss: -1.4406e+03 - val_loss: -1.4412e+03
# Epoch 32/100
# 0s - loss: -1.4435e+03 - val_loss: -1.4446e+03
# Epoch 33/100
# 0s - loss: -1.4506e+03 - val_loss: -1.4586e+03
# Epoch 34/100
# 0s - loss: -1.4590e+03 - val_loss: -1.4594e+03
# Epoch 35/100
# 0s - loss: -1.4597e+03 - val_loss: -1.4604e+03
# Epoch 36/100
# 0s - loss: -1.4649e+03 - val_loss: -1.4691e+03
# Epoch 37/100
# 0s - loss: -1.4777e+03 - val_loss: -1.4805e+03
# Epoch 38/100
# 0s - loss: -1.4810e+03 - val_loss: -1.4872e+03
# Epoch 39/100
# 0s - loss: -1.4905e+03 - val_loss: -1.4908e+03
# Epoch 40/100
# 0s - loss: -1.4912e+03 - val_loss: -1.4915e+03
# Epoch 41/100
# 0s - loss: -1.4994e+03 - val_loss: -1.5007e+03
# Epoch 42/100
# 0s - loss: -1.5009e+03 - val_loss: -1.5011e+03
# Epoch 43/100
# 0s - loss: -1.5011e+03 - val_loss: -1.5012e+03
# Epoch 44/100
# 0s - loss: -1.5012e+03 - val_loss: -1.5016e+03
# Epoch 45/100
# 0s - loss: -1.5019e+03 - val_loss: -1.5023e+03
# Epoch 46/100
# 0s - loss: -1.5076e+03 - val_loss: -1.5118e+03
# Epoch 47/100
# 0s - loss: -1.5116e+03 - val_loss: -1.5116e+03
# Epoch 48/100
# 0s - loss: -1.5118e+03 - val_loss: -1.5119e+03
# Epoch 49/100
# 0s - loss: -1.5121e+03 - val_loss: -1.5121e+03
# Epoch 50/100
# 0s - loss: -1.5121e+03 - val_loss: -1.5122e+03
# Epoch 51/100
# 0s - loss: -1.5124e+03 - val_loss: -1.5125e+03
# Epoch 52/100
# 0s - loss: -1.5127e+03 - val_loss: -1.5128e+03
# Epoch 53/100
# 0s - loss: -1.5099e+03 - val_loss: -1.5107e+03
# Epoch 54/100
# 0s - loss: -1.5113e+03 - val_loss: -1.5081e+03
# Epoch 55/100
# 0s - loss: -1.5163e+03 - val_loss: -1.5206e+03
# Epoch 56/100
# 0s - loss: -1.5209e+03 - val_loss: -1.5211e+03
# Epoch 57/100
# 0s - loss: -1.5213e+03 - val_loss: -1.5217e+03
# Epoch 58/100
# 0s - loss: -1.5219e+03 - val_loss: -1.5223e+03
# Epoch 59/100
# 0s - loss: -1.5226e+03 - val_loss: -1.5225e+03
# Epoch 60/100
# 0s - loss: -1.5299e+03 - val_loss: -1.5317e+03
# Epoch 61/100
# 0s - loss: -1.5320e+03 - val_loss: -1.5321e+03
# Epoch 62/100
# 0s - loss: -1.5322e+03 - val_loss: -1.5323e+03
# Epoch 63/100
# 0s - loss: -1.5290e+03 - val_loss: -1.5244e+03
# Epoch 64/100
# 0s - loss: -1.5269e+03 - val_loss: -1.5326e+03
# Epoch 65/100
# 0s - loss: -1.5330e+03 - val_loss: -1.5337e+03
# Epoch 66/100
# 0s - loss: -1.5418e+03 - val_loss: -1.5430e+03
# Epoch 67/100
# 0s - loss: -1.5428e+03 - val_loss: -1.5431e+03
# Epoch 68/100
# 0s - loss: -1.5432e+03 - val_loss: -1.5434e+03
# Epoch 69/100
# 0s - loss: -1.5435e+03 - val_loss: -1.5438e+03
# Epoch 70/100
# 0s - loss: -1.5510e+03 - val_loss: -1.5641e+03
# Epoch 71/100
# 0s - loss: -1.5643e+03 - val_loss: -1.5644e+03
# Epoch 72/100
# 0s - loss: -1.5637e+03 - val_loss: -1.5646e+03
# Epoch 73/100
# 0s - loss: -1.5646e+03 - val_loss: -1.5649e+03
# Epoch 74/100
# 0s - loss: -1.5650e+03 - val_loss: -1.5650e+03
# Epoch 75/100
# 0s - loss: -1.5651e+03 - val_loss: -1.5653e+03
# Epoch 76/100
# 0s - loss: -1.5652e+03 - val_loss: -1.5655e+03
# Epoch 77/100
# 0s - loss: -1.5655e+03 - val_loss: -1.5658e+03
# Epoch 78/100
# 0s - loss: -1.5646e+03 - val_loss: -1.5646e+03
# Epoch 79/100
# 0s - loss: -1.5648e+03 - val_loss: -1.5651e+03
# Epoch 80/100
# 0s - loss: -1.5652e+03 - val_loss: -1.5653e+03
# Epoch 81/100
# 0s - loss: -1.5653e+03 - val_loss: -1.5655e+03
# Epoch 82/100
# 0s - loss: -1.5656e+03 - val_loss: -1.5657e+03
# Epoch 83/100
# 0s - loss: -1.5655e+03 - val_loss: -1.5646e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15906
# SourceData's aborting data = 6
# window shape is (15906, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=16-l1_reg=10e-5
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/100
# 1s - loss: -2.5055e+03 - val_loss: -2.7228e+03
# Epoch 2/100
# 1s - loss: -2.7762e+03 - val_loss: -2.8179e+03
# Epoch 3/100
# 1s - loss: -2.8412e+03 - val_loss: -2.8518e+03
# Epoch 4/100
# 1s - loss: -2.8862e+03 - val_loss: -2.9071e+03
# Epoch 5/100
# 1s - loss: -2.9088e+03 - val_loss: -2.9193e+03
# Epoch 6/100
# 1s - loss: -2.9380e+03 - val_loss: -2.9675e+03
# Epoch 7/100
# 1s - loss: -2.9713e+03 - val_loss: -2.9776e+03
# Epoch 8/100
# 1s - loss: -3.0079e+03 - val_loss: -3.0187e+03
# Epoch 9/100
# 1s - loss: -3.0191e+03 - val_loss: -3.0203e+03
# Epoch 10/100
# 1s - loss: -3.0295e+03 - val_loss: -3.0389e+03
# Epoch 11/100
# 1s - loss: -3.0433e+03 - val_loss: -3.0496e+03
# Epoch 12/100
# 1s - loss: -3.0551e+03 - val_loss: -3.0581e+03
# Epoch 13/100
# 1s - loss: -3.0710e+03 - val_loss: -3.0729e+03
# Epoch 14/100
# 1s - loss: -3.0727e+03 - val_loss: -3.0792e+03
# Epoch 15/100
# 1s - loss: -3.0793e+03 - val_loss: -3.0801e+03
# Epoch 16/100
# 1s - loss: -3.0780e+03 - val_loss: -3.0729e+03
# Epoch 17/100
# 1s - loss: -3.0787e+03 - val_loss: -3.0868e+03
# Epoch 18/100
# 1s - loss: -3.0927e+03 - val_loss: -3.0970e+03
# Epoch 19/100
# 1s - loss: -3.0972e+03 - val_loss: -3.0978e+03
# Epoch 20/100
# 1s - loss: -3.0974e+03 - val_loss: -3.0976e+03
# Epoch 21/100
# 1s - loss: -3.0977e+03 - val_loss: -3.0982e+03
# Epoch 22/100
# 1s - loss: -3.0982e+03 - val_loss: -3.0988e+03
# Epoch 23/100
# 1s - loss: -3.0993e+03 - val_loss: -3.0994e+03
# Epoch 24/100
# 1s - loss: -3.0980e+03 - val_loss: -3.0988e+03
# Epoch 25/100
# 1s - loss: -3.0999e+03 - val_loss: -3.1001e+03
# Epoch 26/100
# 1s - loss: -3.1005e+03 - val_loss: -3.1018e+03
# Epoch 27/100
# 1s - loss: -3.1083e+03 - val_loss: -3.1084e+03
# Epoch 28/100
# 1s - loss: -3.1084e+03 - val_loss: -3.1095e+03
# Epoch 29/100
# 1s - loss: -3.1095e+03 - val_loss: -3.1096e+03
# Epoch 30/100
# 1s - loss: -3.1092e+03 - val_loss: -3.1101e+03
# Epoch 31/100
# 1s - loss: -3.1110e+03 - val_loss: -3.1129e+03
# Epoch 32/100
# 1s - loss: -3.1109e+03 - val_loss: -3.1102e+03
# Epoch 33/100
# 1s - loss: -3.1109e+03 - val_loss: -3.1126e+03
# Epoch 34/100
# 1s - loss: -3.1116e+03 - val_loss: -3.1119e+03
# Epoch 35/100
# 0s - loss: -3.1123e+03 - val_loss: -3.1113e+03
# Epoch 36/100
# 0s - loss: -3.1120e+03 - val_loss: -3.1101e+03
# Epoch 37/100
# 0s - loss: -3.1104e+03 - val_loss: -3.1108e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7953
# SourceData's aborting data = 22
# window shape is (7953, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=32-l1_reg=10e-5
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -2.4340e+03 - val_loss: -2.6164e+03
# Epoch 2/100
# 0s - loss: -2.6645e+03 - val_loss: -2.7188e+03
# Epoch 3/100
# 0s - loss: -2.7719e+03 - val_loss: -2.8074e+03
# Epoch 4/100
# 0s - loss: -2.8456e+03 - val_loss: -2.8683e+03
# Epoch 5/100
# 0s - loss: -2.8704e+03 - val_loss: -2.8730e+03
# Epoch 6/100
# 0s - loss: -2.8785e+03 - val_loss: -2.9028e+03
# Epoch 7/100
# 0s - loss: -2.9326e+03 - val_loss: -2.9569e+03
# Epoch 8/100
# 0s - loss: -2.9571e+03 - val_loss: -2.9594e+03
# Epoch 9/100
# 0s - loss: -2.9750e+03 - val_loss: -2.9817e+03
# Epoch 10/100
# 0s - loss: -2.9959e+03 - val_loss: -3.0103e+03
# Epoch 11/100
# 0s - loss: -3.0164e+03 - val_loss: -3.0362e+03
# Epoch 12/100
# 0s - loss: -3.0386e+03 - val_loss: -3.0403e+03
# Epoch 13/100
# 0s - loss: -3.0400e+03 - val_loss: -3.0497e+03
# Epoch 14/100
# 0s - loss: -3.0508e+03 - val_loss: -3.0518e+03
# Epoch 15/100
# 0s - loss: -3.0516e+03 - val_loss: -3.0528e+03
# Epoch 16/100
# 0s - loss: -3.0596e+03 - val_loss: -3.0724e+03
# Epoch 17/100
# 0s - loss: -3.0798e+03 - val_loss: -3.0797e+03
# Epoch 18/100
# 0s - loss: -3.0792e+03 - val_loss: -3.0808e+03
# Epoch 19/100
# 0s - loss: -3.0804e+03 - val_loss: -3.0766e+03
# Epoch 20/100
# 0s - loss: -3.0790e+03 - val_loss: -3.0800e+03
# Epoch 21/100
# 0s - loss: -3.0795e+03 - val_loss: -3.0725e+03
# Epoch 22/100
# 0s - loss: -3.0778e+03 - val_loss: -3.0872e+03
# Epoch 23/100
# 0s - loss: -3.0817e+03 - val_loss: -3.0825e+03
# Epoch 24/100
# 0s - loss: -3.0828e+03 - val_loss: -3.0836e+03
# Epoch 25/100
# 0s - loss: -3.0830e+03 - val_loss: -3.0844e+03
# Epoch 26/100
# 0s - loss: -3.0856e+03 - val_loss: -3.0847e+03
# Epoch 27/100
# 0s - loss: -3.0832e+03 - val_loss: -3.0831e+03
# Epoch 28/100
# 0s - loss: -3.0821e+03 - val_loss: -3.0818e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =3977
# SourceData's aborting data = 22
# window shape is (3977, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=64-l1_reg=10e-5
# Train on 3977 samples, validate on 3977 samples
# Epoch 1/100
# 0s - loss: -2.2282e+03 - val_loss: -2.4071e+03
# Epoch 2/100
# 0s - loss: -2.4962e+03 - val_loss: -2.5895e+03
# Epoch 3/100
# 0s - loss: -2.6130e+03 - val_loss: -2.6227e+03
# Epoch 4/100
# 0s - loss: -2.6574e+03 - val_loss: -2.6971e+03
# Epoch 5/100
# 0s - loss: -2.7086e+03 - val_loss: -2.7253e+03
# Epoch 6/100
# 0s - loss: -2.7448e+03 - val_loss: -2.7613e+03
# Epoch 7/100
# 0s - loss: -2.7686e+03 - val_loss: -2.7796e+03
# Epoch 8/100
# 0s - loss: -2.7974e+03 - val_loss: -2.8148e+03
# Epoch 9/100
# 0s - loss: -2.8112e+03 - val_loss: -2.8114e+03
# Epoch 10/100
# 0s - loss: -2.8253e+03 - val_loss: -2.8307e+03
# Epoch 11/100
# 0s - loss: -2.8687e+03 - val_loss: -2.8818e+03
# Epoch 12/100
# 0s - loss: -2.8916e+03 - val_loss: -2.9096e+03
# Epoch 13/100
# 0s - loss: -2.9172e+03 - val_loss: -2.9282e+03
# Epoch 14/100
# 0s - loss: -2.9290e+03 - val_loss: -2.9299e+03
# Epoch 15/100
# 0s - loss: -2.9362e+03 - val_loss: -2.9314e+03
# Epoch 16/100
# 0s - loss: -2.9450e+03 - val_loss: -2.9422e+03
# Epoch 17/100
# 0s - loss: -2.9557e+03 - val_loss: -2.9579e+03
# Epoch 18/100
# 0s - loss: -2.9589e+03 - val_loss: -2.9600e+03
# Epoch 19/100
# 0s - loss: -2.9656e+03 - val_loss: -2.9614e+03
# Epoch 20/100
# 0s - loss: -2.9676e+03 - val_loss: -2.9714e+03
# Epoch 21/100
# 0s - loss: -2.9687e+03 - val_loss: -2.9714e+03
# Epoch 22/100
# 0s - loss: -2.9773e+03 - val_loss: -2.9850e+03
# Epoch 23/100
# 0s - loss: -2.9963e+03 - val_loss: -3.0000e+03
# Epoch 24/100
# 0s - loss: -3.0069e+03 - val_loss: -3.0097e+03
# Epoch 25/100
# 0s - loss: -3.0127e+03 - val_loss: -3.0185e+03
# Epoch 26/100
# 0s - loss: -3.0230e+03 - val_loss: -3.0308e+03
# Epoch 27/100
# 0s - loss: -3.0459e+03 - val_loss: -3.0480e+03
# Epoch 28/100
# 0s - loss: -3.0475e+03 - val_loss: -3.0483e+03
# Epoch 29/100
# 0s - loss: -3.0488e+03 - val_loss: -3.0496e+03
# Epoch 30/100
# 0s - loss: -3.0512e+03 - val_loss: -3.0592e+03
# Epoch 31/100
# 0s - loss: -3.0588e+03 - val_loss: -3.0588e+03
# Epoch 32/100
# 0s - loss: -3.0592e+03 - val_loss: -3.0597e+03
# Epoch 33/100
# 0s - loss: -3.0599e+03 - val_loss: -3.0601e+03
# Epoch 34/100
# 0s - loss: -3.0605e+03 - val_loss: -3.0613e+03
# Epoch 35/100
# 0s - loss: -3.0614e+03 - val_loss: -3.0711e+03
# Epoch 36/100
# 0s - loss: -3.0782e+03 - val_loss: -3.0814e+03
# Epoch 37/100
# 0s - loss: -3.0840e+03 - val_loss: -3.0917e+03
# Epoch 38/100
# 0s - loss: -3.0926e+03 - val_loss: -3.0935e+03
# Epoch 39/100
# 0s - loss: -3.1007e+03 - val_loss: -3.1127e+03
# Epoch 40/100
# 0s - loss: -3.1114e+03 - val_loss: -3.1055e+03
# Epoch 41/100
# 0s - loss: -3.1116e+03 - val_loss: -3.1124e+03
# Epoch 42/100
# 0s - loss: -3.1138e+03 - val_loss: -3.1225e+03
# Epoch 43/100
# 0s - loss: -3.1231e+03 - val_loss: -3.1233e+03
# Epoch 44/100
# 0s - loss: -3.1234e+03 - val_loss: -3.1241e+03
# Epoch 45/100
# 0s - loss: -3.1211e+03 - val_loss: -3.1202e+03
# Epoch 46/100
# 0s - loss: -3.1206e+03 - val_loss: -3.1218e+03
# Epoch 47/100
# 0s - loss: -3.1222e+03 - val_loss: -3.1224e+03
# Epoch 48/100
# 0s - loss: -3.1231e+03 - val_loss: -3.1229e+03
# Epoch 49/100
# 0s - loss: -3.1243e+03 - val_loss: -3.1249e+03
# Epoch 50/100
# 0s - loss: -3.1250e+03 - val_loss: -3.1249e+03
# Epoch 51/100
# 0s - loss: -3.1235e+03 - val_loss: -3.1225e+03
# Epoch 52/100
# 0s - loss: -3.1232e+03 - val_loss: -3.1240e+03
# Epoch 53/100
# 0s - loss: -3.1240e+03 - val_loss: -3.1237e+03
# Epoch 54/100
# 0s - loss: -3.1236e+03 - val_loss: -3.1235e+03
# Epoch 55/100
# 0s - loss: -3.1218e+03 - val_loss: -3.1220e+03
# Epoch 56/100
# 0s - loss: -3.1217e+03 - val_loss: -3.1224e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =1989
# SourceData's aborting data = 22
# window shape is (1989, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=128-l1_reg=10e-5
# Train on 1989 samples, validate on 1989 samples
# Epoch 1/100
# 0s - loss: -2.0569e+03 - val_loss: -2.2324e+03
# Epoch 2/100
# 0s - loss: -2.2846e+03 - val_loss: -2.3207e+03
# Epoch 3/100
# 0s - loss: -2.3577e+03 - val_loss: -2.3873e+03
# Epoch 4/100
# 0s - loss: -2.4111e+03 - val_loss: -2.4181e+03
# Epoch 5/100
# 0s - loss: -2.4443e+03 - val_loss: -2.4753e+03
# Epoch 6/100
# 0s - loss: -2.4845e+03 - val_loss: -2.5051e+03
# Epoch 7/100
# 0s - loss: -2.5268e+03 - val_loss: -2.5556e+03
# Epoch 8/100
# 0s - loss: -2.5751e+03 - val_loss: -2.5916e+03
# Epoch 9/100
# 0s - loss: -2.6116e+03 - val_loss: -2.6241e+03
# Epoch 10/100
# 0s - loss: -2.6298e+03 - val_loss: -2.6348e+03
# Epoch 11/100
# 0s - loss: -2.6422e+03 - val_loss: -2.6524e+03
# Epoch 12/100
# 0s - loss: -2.6577e+03 - val_loss: -2.6711e+03
# Epoch 13/100
# 0s - loss: -2.6842e+03 - val_loss: -2.6979e+03
# Epoch 14/100
# 0s - loss: -2.7141e+03 - val_loss: -2.7226e+03
# Epoch 15/100
# 0s - loss: -2.7313e+03 - val_loss: -2.7393e+03
# Epoch 16/100
# 0s - loss: -2.7457e+03 - val_loss: -2.7482e+03
# Epoch 17/100
# 0s - loss: -2.7393e+03 - val_loss: -2.7416e+03
# Epoch 18/100
# 0s - loss: -2.7424e+03 - val_loss: -2.7455e+03
# Epoch 19/100
# 0s - loss: -2.7466e+03 - val_loss: -2.7513e+03
# Epoch 20/100
# 0s - loss: -2.7583e+03 - val_loss: -2.7604e+03
# Epoch 21/100
# 0s - loss: -2.7609e+03 - val_loss: -2.7628e+03
# Epoch 22/100
# 0s - loss: -2.7789e+03 - val_loss: -2.8038e+03
# Epoch 23/100
# 0s - loss: -2.8042e+03 - val_loss: -2.8034e+03
# Epoch 24/100
# 0s - loss: -2.8042e+03 - val_loss: -2.8057e+03
# Epoch 25/100
# 0s - loss: -2.8055e+03 - val_loss: -2.8061e+03
# Epoch 26/100
# 0s - loss: -2.8104e+03 - val_loss: -2.8138e+03
# Epoch 27/100
# 0s - loss: -2.8135e+03 - val_loss: -2.8138e+03
# Epoch 28/100
# 0s - loss: -2.8139e+03 - val_loss: -2.8093e+03
# Epoch 29/100
# 0s - loss: -2.8133e+03 - val_loss: -2.8133e+03
# Epoch 30/100
# 0s - loss: -2.8130e+03 - val_loss: -2.8130e+03
# Epoch 31/100
# 0s - loss: -2.8142e+03 - val_loss: -2.8202e+03
# Epoch 32/100
# 0s - loss: -2.8213e+03 - val_loss: -2.8216e+03
# Epoch 33/100
# 0s - loss: -2.8221e+03 - val_loss: -2.8309e+03
# Epoch 34/100
# 0s - loss: -2.8308e+03 - val_loss: -2.8315e+03
# Epoch 35/100
# 0s - loss: -2.8321e+03 - val_loss: -2.8327e+03
# Epoch 36/100
# 0s - loss: -2.8328e+03 - val_loss: -2.8327e+03
# Epoch 37/100
# 0s - loss: -2.8329e+03 - val_loss: -2.8336e+03
# Epoch 38/100
# 0s - loss: -2.8341e+03 - val_loss: -2.8346e+03
# Epoch 39/100
# 0s - loss: -2.8354e+03 - val_loss: -2.8364e+03
# Epoch 40/100
# 0s - loss: -2.8471e+03 - val_loss: -2.8522e+03
# Epoch 41/100
# 0s - loss: -2.8529e+03 - val_loss: -2.8537e+03
# Epoch 42/100
# 0s - loss: -2.8542e+03 - val_loss: -2.8485e+03
# Epoch 43/100
# 0s - loss: -2.8588e+03 - val_loss: -2.8631e+03
# Epoch 44/100
# 0s - loss: -2.8635e+03 - val_loss: -2.8638e+03
# Epoch 45/100
# 0s - loss: -2.8647e+03 - val_loss: -2.8657e+03
# Epoch 46/100
# 0s - loss: -2.8699e+03 - val_loss: -2.8755e+03
# Epoch 47/100
# 0s - loss: -2.8877e+03 - val_loss: -2.9017e+03
# Epoch 48/100
# 0s - loss: -2.9078e+03 - val_loss: -2.9103e+03
# Epoch 49/100
# 0s - loss: -2.9103e+03 - val_loss: -2.9104e+03
# Epoch 50/100
# 0s - loss: -2.9103e+03 - val_loss: -2.9107e+03
# Epoch 51/100
# 0s - loss: -2.9111e+03 - val_loss: -2.9117e+03
# Epoch 52/100
# 0s - loss: -2.9164e+03 - val_loss: -2.9202e+03
# Epoch 53/100
# 0s - loss: -2.9204e+03 - val_loss: -2.9210e+03
# Epoch 54/100
# 0s - loss: -2.9210e+03 - val_loss: -2.9214e+03
# Epoch 55/100
# 0s - loss: -2.9217e+03 - val_loss: -2.9217e+03
# Epoch 56/100
# 0s - loss: -2.9223e+03 - val_loss: -2.9222e+03
# Epoch 57/100
# 0s - loss: -2.9226e+03 - val_loss: -2.9234e+03
# Epoch 58/100
# 0s - loss: -2.9239e+03 - val_loss: -2.9240e+03
# Epoch 59/100
# 0s - loss: -2.9249e+03 - val_loss: -2.9259e+03
# Epoch 60/100
# 0s - loss: -2.9332e+03 - val_loss: -2.9350e+03
# Epoch 61/100
# 0s - loss: -2.9317e+03 - val_loss: -2.9297e+03
# Epoch 62/100
# 0s - loss: -2.9312e+03 - val_loss: -2.9324e+03
# Epoch 63/100
# 0s - loss: -2.9325e+03 - val_loss: -2.9331e+03
# Epoch 64/100
# 0s - loss: -2.9323e+03 - val_loss: -2.9329e+03
# Epoch 65/100
# 0s - loss: -2.9324e+03 - val_loss: -2.9334e+03
# Epoch 66/100
# 0s - loss: -2.9363e+03 - val_loss: -2.9421e+03
# Epoch 67/100
# 0s - loss: -2.9426e+03 - val_loss: -2.9430e+03
# Epoch 68/100
# 0s - loss: -2.9475e+03 - val_loss: -2.9520e+03
# Epoch 69/100
# 0s - loss: -2.9523e+03 - val_loss: -2.9526e+03
# Epoch 70/100
# 0s - loss: -2.9529e+03 - val_loss: -2.9533e+03
# Epoch 71/100
# 0s - loss: -2.9537e+03 - val_loss: -2.9539e+03
# Epoch 72/100
# 0s - loss: -2.9540e+03 - val_loss: -2.9547e+03
# Epoch 73/100
# 0s - loss: -2.9616e+03 - val_loss: -2.9717e+03
# Epoch 74/100
# 0s - loss: -2.9715e+03 - val_loss: -2.9714e+03
# Epoch 75/100
# 0s - loss: -2.9715e+03 - val_loss: -2.9715e+03
# Epoch 76/100
# 0s - loss: -2.9716e+03 - val_loss: -2.9717e+03
# Epoch 77/100
# 0s - loss: -2.9714e+03 - val_loss: -2.9710e+03
# Epoch 78/100
# 0s - loss: -2.9704e+03 - val_loss: -2.9706e+03
# Epoch 79/100
# 0s - loss: -2.9707e+03 - val_loss: -2.9707e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =995
# SourceData's aborting data = 22
# window shape is (995, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=256-l1_reg=10e-5
# Train on 995 samples, validate on 995 samples
# Epoch 1/100
# 0s - loss: -2.0235e+03 - val_loss: -2.2113e+03
# Epoch 2/100
# 0s - loss: -2.2749e+03 - val_loss: -2.3451e+03
# Epoch 3/100
# 0s - loss: -2.3992e+03 - val_loss: -2.4423e+03
# Epoch 4/100
# 0s - loss: -2.4664e+03 - val_loss: -2.4911e+03
# Epoch 5/100
# 0s - loss: -2.5086e+03 - val_loss: -2.5252e+03
# Epoch 6/100
# 0s - loss: -2.5278e+03 - val_loss: -2.5310e+03
# Epoch 7/100
# 0s - loss: -2.5433e+03 - val_loss: -2.5647e+03
# Epoch 8/100
# 0s - loss: -2.5722e+03 - val_loss: -2.5742e+03
# Epoch 9/100
# 0s - loss: -2.5930e+03 - val_loss: -2.6104e+03
# Epoch 10/100
# 0s - loss: -2.6315e+03 - val_loss: -2.6428e+03
# Epoch 11/100
# 0s - loss: -2.6440e+03 - val_loss: -2.6461e+03
# Epoch 12/100
# 0s - loss: -2.6737e+03 - val_loss: -2.6946e+03
# Epoch 13/100
# 0s - loss: -2.6964e+03 - val_loss: -2.7049e+03
# Epoch 14/100
# 0s - loss: -2.7054e+03 - val_loss: -2.7026e+03
# Epoch 15/100
# 0s - loss: -2.7057e+03 - val_loss: -2.7079e+03
# Epoch 16/100
# 0s - loss: -2.7099e+03 - val_loss: -2.7164e+03
# Epoch 17/100
# 0s - loss: -2.7172e+03 - val_loss: -2.7175e+03
# Epoch 18/100
# 0s - loss: -2.7181e+03 - val_loss: -2.7259e+03
# Epoch 19/100
# 0s - loss: -2.7275e+03 - val_loss: -2.7348e+03
# Epoch 20/100
# 0s - loss: -2.7484e+03 - val_loss: -2.7539e+03
# Epoch 21/100
# 0s - loss: -2.7667e+03 - val_loss: -2.7779e+03
# Epoch 22/100
# 0s - loss: -2.7784e+03 - val_loss: -2.7798e+03
# Epoch 23/100
# 0s - loss: -2.7818e+03 - val_loss: -2.7802e+03
# Epoch 24/100
# 0s - loss: -2.7828e+03 - val_loss: -2.7815e+03
# Epoch 25/100
# 0s - loss: -2.7817e+03 - val_loss: -2.7834e+03
# Epoch 26/100
# 0s - loss: -2.7905e+03 - val_loss: -2.7971e+03
# Epoch 27/100
# 0s - loss: -2.7976e+03 - val_loss: -2.7981e+03
# Epoch 28/100
# 0s - loss: -2.7986e+03 - val_loss: -2.7991e+03
# Epoch 29/100
# 0s - loss: -2.8011e+03 - val_loss: -2.8033e+03
# Epoch 30/100
# 0s - loss: -2.8043e+03 - val_loss: -2.8055e+03
# Epoch 31/100
# 0s - loss: -2.8114e+03 - val_loss: -2.8090e+03
# Epoch 32/100
# 0s - loss: -2.8148e+03 - val_loss: -2.8240e+03
# Epoch 33/100
# 0s - loss: -2.8308e+03 - val_loss: -2.8336e+03
# Epoch 34/100
# 0s - loss: -2.8374e+03 - val_loss: -2.8421e+03
# Epoch 35/100
# 0s - loss: -2.8421e+03 - val_loss: -2.8425e+03
# Epoch 36/100
# 0s - loss: -2.8430e+03 - val_loss: -2.8436e+03
# Epoch 37/100
# 0s - loss: -2.8436e+03 - val_loss: -2.8439e+03
# Epoch 38/100
# 0s - loss: -2.8440e+03 - val_loss: -2.8439e+03
# Epoch 39/100
# 0s - loss: -2.8442e+03 - val_loss: -2.8447e+03
# Epoch 40/100
# 0s - loss: -2.8450e+03 - val_loss: -2.8459e+03
# Epoch 41/100
# 0s - loss: -2.8521e+03 - val_loss: -2.8540e+03
# Epoch 42/100
# 0s - loss: -2.8544e+03 - val_loss: -2.8554e+03
# Epoch 43/100
# 0s - loss: -2.8594e+03 - val_loss: -2.8735e+03
# Epoch 44/100
# 0s - loss: -2.8790e+03 - val_loss: -2.8823e+03
# Epoch 45/100
# 0s - loss: -2.8836e+03 - val_loss: -2.8920e+03
# Epoch 46/100
# 0s - loss: -2.8989e+03 - val_loss: -2.8997e+03
# Epoch 47/100
# 0s - loss: -2.8997e+03 - val_loss: -2.8999e+03
# Epoch 48/100
# 0s - loss: -2.9000e+03 - val_loss: -2.9004e+03
# Epoch 49/100
# 0s - loss: -2.9007e+03 - val_loss: -2.9011e+03
# Epoch 50/100
# 0s - loss: -2.8997e+03 - val_loss: -2.8974e+03
# Epoch 51/100
# 0s - loss: -2.8997e+03 - val_loss: -2.9080e+03
# Epoch 52/100
# 0s - loss: -2.9103e+03 - val_loss: -2.9169e+03
# Epoch 53/100
# 0s - loss: -2.9168e+03 - val_loss: -2.9171e+03
# Epoch 54/100
# 0s - loss: -2.9175e+03 - val_loss: -2.9177e+03
# Epoch 55/100
# 0s - loss: -2.9177e+03 - val_loss: -2.9181e+03
# Epoch 56/100
# 0s - loss: -2.9180e+03 - val_loss: -2.9179e+03
# Epoch 57/100
# 0s - loss: -2.9178e+03 - val_loss: -2.9182e+03
# Epoch 58/100
# 0s - loss: -2.9182e+03 - val_loss: -2.9182e+03
# Epoch 59/100
# 0s - loss: -2.9185e+03 - val_loss: -2.9188e+03
# Epoch 60/100
# 0s - loss: -2.9189e+03 - val_loss: -2.9193e+03
# Epoch 61/100
# 0s - loss: -2.9194e+03 - val_loss: -2.9145e+03
# Epoch 62/100
# 0s - loss: -2.9261e+03 - val_loss: -2.9287e+03
# Epoch 63/100
# 0s - loss: -2.9285e+03 - val_loss: -2.9287e+03
# Epoch 64/100
# 0s - loss: -2.9287e+03 - val_loss: -2.9289e+03
# Epoch 65/100
# 0s - loss: -2.9287e+03 - val_loss: -2.9289e+03
# Epoch 66/100
# 0s - loss: -2.9289e+03 - val_loss: -2.9289e+03
# Epoch 67/100
# 0s - loss: -2.9289e+03 - val_loss: -2.9294e+03
# Epoch 68/100
# 0s - loss: -2.9295e+03 - val_loss: -2.9295e+03
# Epoch 69/100
# 0s - loss: -2.9295e+03 - val_loss: -2.9296e+03
# Epoch 70/100
# 0s - loss: -2.9297e+03 - val_loss: -2.9299e+03
# Epoch 71/100
# 0s - loss: -2.9285e+03 - val_loss: -2.9241e+03
# Epoch 72/100
# 0s - loss: -2.9293e+03 - val_loss: -2.9302e+03
# Epoch 73/100
# 0s - loss: -2.9303e+03 - val_loss: -2.9305e+03
# Epoch 74/100
# 0s - loss: -2.9310e+03 - val_loss: -2.9392e+03
# Epoch 75/100
# 0s - loss: -2.9392e+03 - val_loss: -2.9397e+03
# Epoch 76/100
# 0s - loss: -2.9398e+03 - val_loss: -2.9402e+03
# Epoch 77/100
# 0s - loss: -2.9397e+03 - val_loss: -2.9401e+03
# Epoch 78/100
# 0s - loss: -2.9399e+03 - val_loss: -2.9396e+03
# Epoch 79/100
# 0s - loss: -2.9394e+03 - val_loss: -2.9389e+03
# Epoch 80/100
# 0s - loss: -2.9397e+03 - val_loss: -2.9398e+03
# Epoch 81/100
# 0s - loss: -2.9397e+03 - val_loss: -2.9398e+03
# Epoch 82/100
# 0s - loss: -2.9398e+03 - val_loss: -2.9399e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15890
# SourceData's aborting data = 6
# window shape is (15890, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=16-l1_reg=10e-5
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/100
# 1s - loss: -4.8799e+03 - val_loss: -5.2553e+03
# Epoch 2/100
# 1s - loss: -5.3738e+03 - val_loss: -5.4811e+03
# Epoch 3/100
# 1s - loss: -5.5235e+03 - val_loss: -5.5877e+03
# Epoch 4/100
# 1s - loss: -5.6266e+03 - val_loss: -5.6539e+03
# Epoch 5/100
# 0s - loss: -5.6964e+03 - val_loss: -5.7100e+03
# Epoch 6/100
# 1s - loss: -5.7475e+03 - val_loss: -5.7861e+03
# Epoch 7/100
# 1s - loss: -5.7906e+03 - val_loss: -5.7993e+03
# Epoch 8/100
# 1s - loss: -5.8177e+03 - val_loss: -5.8352e+03
# Epoch 9/100
# 1s - loss: -5.8479e+03 - val_loss: -5.8563e+03
# Epoch 10/100
# 1s - loss: -5.8642e+03 - val_loss: -5.8698e+03
# Epoch 11/100
# 1s - loss: -5.8758e+03 - val_loss: -5.8811e+03
# Epoch 12/100
# 1s - loss: -5.8847e+03 - val_loss: -5.8920e+03
# Epoch 13/100
# 1s - loss: -5.9075e+03 - val_loss: -5.9258e+03
# Epoch 14/100
# 1s - loss: -5.9364e+03 - val_loss: -5.9470e+03
# Epoch 15/100
# 0s - loss: -5.9610e+03 - val_loss: -5.9635e+03
# Epoch 16/100
# 0s - loss: -5.9644e+03 - val_loss: -5.9662e+03
# Epoch 17/100
# 1s - loss: -5.9791e+03 - val_loss: -6.0031e+03
# Epoch 18/100
# 0s - loss: -6.0129e+03 - val_loss: -6.0310e+03
# Epoch 19/100
# 1s - loss: -6.0346e+03 - val_loss: -6.0402e+03
# Epoch 20/100
# 1s - loss: -6.0421e+03 - val_loss: -6.0453e+03
# Epoch 21/100
# 0s - loss: -6.0562e+03 - val_loss: -6.0664e+03
# Epoch 22/100
# 0s - loss: -6.0748e+03 - val_loss: -6.0809e+03
# Epoch 23/100
# 0s - loss: -6.0816e+03 - val_loss: -6.0828e+03
# Epoch 24/100
# 0s - loss: -6.0832e+03 - val_loss: -6.0920e+03
# Epoch 25/100
# 0s - loss: -5.6665e+03 - val_loss: -5.9566e+03
# Epoch 26/100
# 0s - loss: -6.0531e+03 - val_loss: -6.0799e+03
# Epoch 27/100
# 0s - loss: -6.0864e+03 - val_loss: -6.0877e+03
# Epoch 28/100
# 1s - loss: -6.0873e+03 - val_loss: -6.0971e+03
# Epoch 29/100
# 0s - loss: -6.1039e+03 - val_loss: -6.1060e+03
# Epoch 30/100
# 0s - loss: -6.1056e+03 - val_loss: -6.1059e+03
# Epoch 31/100
# 0s - loss: -6.1059e+03 - val_loss: -6.1146e+03
# Epoch 32/100
# 0s - loss: -6.1142e+03 - val_loss: -6.1145e+03
# Epoch 33/100
# 0s - loss: -6.1148e+03 - val_loss: -6.1155e+03
# Epoch 34/100
# 0s - loss: -6.1153e+03 - val_loss: -6.1159e+03
# Epoch 35/100
# 1s - loss: -6.1158e+03 - val_loss: -6.1164e+03
# Epoch 36/100
# 0s - loss: -6.1166e+03 - val_loss: -6.1170e+03
# Epoch 37/100
# 1s - loss: -6.1169e+03 - val_loss: -6.1174e+03
# Epoch 38/100
# 1s - loss: -6.1177e+03 - val_loss: -6.1184e+03
# Epoch 39/100
# 1s - loss: -6.1266e+03 - val_loss: -6.1372e+03
# Epoch 40/100
# 0s - loss: -6.1375e+03 - val_loss: -6.1384e+03
# Epoch 41/100
# 0s - loss: -6.1457e+03 - val_loss: -6.1478e+03
# Epoch 42/100
# 0s - loss: -6.1522e+03 - val_loss: -6.1586e+03
# Epoch 43/100
# 0s - loss: -6.1703e+03 - val_loss: -6.1765e+03
# Epoch 44/100
# 1s - loss: -6.1765e+03 - val_loss: -6.1768e+03
# Epoch 45/100
# 0s - loss: -6.1769e+03 - val_loss: -6.1772e+03
# Epoch 46/100
# 0s - loss: -6.1774e+03 - val_loss: -6.1777e+03
# Epoch 47/100
# 0s - loss: -6.1792e+03 - val_loss: -6.1873e+03
# Epoch 48/100
# 0s - loss: -6.1873e+03 - val_loss: -6.1875e+03
# Epoch 49/100
# 0s - loss: -6.1875e+03 - val_loss: -6.1878e+03
# Epoch 50/100
# 0s - loss: -6.1878e+03 - val_loss: -6.1880e+03
# Epoch 51/100
# 0s - loss: -6.1880e+03 - val_loss: -6.1882e+03
# Epoch 52/100
# 0s - loss: -6.1883e+03 - val_loss: -6.1885e+03
# Epoch 53/100
# 0s - loss: -6.1884e+03 - val_loss: -6.1886e+03
# Epoch 54/100
# 0s - loss: -6.1882e+03 - val_loss: -6.1884e+03
# Epoch 55/100
# 0s - loss: -6.1885e+03 - val_loss: -6.1887e+03
# Epoch 56/100
# 0s - loss: -6.1888e+03 - val_loss: -6.1890e+03
# Epoch 57/100
# 0s - loss: -6.1890e+03 - val_loss: -6.1892e+03
# Epoch 58/100
# 0s - loss: -6.1894e+03 - val_loss: -6.1896e+03
# Epoch 59/100
# 0s - loss: -6.1896e+03 - val_loss: -6.1899e+03
# Epoch 60/100
# 1s - loss: -6.1898e+03 - val_loss: -6.1900e+03
# Epoch 61/100
# 0s - loss: -6.1893e+03 - val_loss: -6.1902e+03
# Epoch 62/100
# 0s - loss: -6.1885e+03 - val_loss: -6.1888e+03
# Epoch 63/100
# 1s - loss: -6.1896e+03 - val_loss: -6.1806e+03
# Epoch 64/100
# 1s - loss: -6.1907e+03 - val_loss: -6.1925e+03
# Epoch 65/100
# 1s - loss: -6.1985e+03 - val_loss: -6.1995e+03
# Epoch 66/100
# 1s - loss: -6.1996e+03 - val_loss: -6.1998e+03
# Epoch 67/100
# 1s - loss: -6.2004e+03 - val_loss: -6.2008e+03
# Epoch 68/100
# 1s - loss: -6.2010e+03 - val_loss: -6.2013e+03
# Epoch 69/100
# 1s - loss: -6.2012e+03 - val_loss: -6.2014e+03
# Epoch 70/100
# 1s - loss: -6.2013e+03 - val_loss: -6.1979e+03
# Epoch 71/100
# 1s - loss: -6.2009e+03 - val_loss: -6.2015e+03
# Epoch 72/100
# 1s - loss: -6.2015e+03 - val_loss: -6.2019e+03
# Epoch 73/100
# 1s - loss: -6.2018e+03 - val_loss: -6.2019e+03
# Epoch 74/100
# 1s - loss: -6.2008e+03 - val_loss: -6.2016e+03
# Epoch 75/100
# 1s - loss: -6.2017e+03 - val_loss: -6.2023e+03
# Epoch 76/100
# 1s - loss: -6.2037e+03 - val_loss: -6.2102e+03
# Epoch 77/100
# 1s - loss: -6.2109e+03 - val_loss: -6.2114e+03
# Epoch 78/100
# 1s - loss: -6.2113e+03 - val_loss: -6.2116e+03
# Epoch 79/100
# 1s - loss: -6.2116e+03 - val_loss: -6.2121e+03
# Epoch 80/100
# 1s - loss: -6.2121e+03 - val_loss: -6.2128e+03
# Epoch 81/100
# 1s - loss: -6.2125e+03 - val_loss: -6.2128e+03
# Epoch 82/100
# 1s - loss: -6.2126e+03 - val_loss: -6.2132e+03
# Epoch 83/100
# 1s - loss: -6.2132e+03 - val_loss: -6.2136e+03
# Epoch 84/100
# 1s - loss: -6.2134e+03 - val_loss: -6.2137e+03
# Epoch 85/100
# 1s - loss: -6.2137e+03 - val_loss: -6.2142e+03
# Epoch 86/100
# 1s - loss: -6.2143e+03 - val_loss: -6.2147e+03
# Epoch 87/100
# 1s - loss: -6.2162e+03 - val_loss: -6.2188e+03
# Epoch 88/100
# 1s - loss: -6.2232e+03 - val_loss: -6.2240e+03
# Epoch 89/100
# 0s - loss: -6.2288e+03 - val_loss: -6.2361e+03
# Epoch 90/100
# 1s - loss: -6.2430e+03 - val_loss: -6.2435e+03
# Epoch 91/100
# 1s - loss: -6.2438e+03 - val_loss: -6.2439e+03
# Epoch 92/100
# 1s - loss: -6.2437e+03 - val_loss: -6.2439e+03
# Epoch 93/100
# 1s - loss: -6.2432e+03 - val_loss: -6.2436e+03
# Epoch 94/100
# 1s - loss: -6.2434e+03 - val_loss: -6.2440e+03
# Epoch 95/100
# 1s - loss: -6.2442e+03 - val_loss: -6.2444e+03
# Epoch 96/100
# 1s - loss: -6.2446e+03 - val_loss: -6.2446e+03
# Epoch 97/100
# 1s - loss: -6.2449e+03 - val_loss: -6.2453e+03
# Epoch 98/100
# 1s - loss: -6.2453e+03 - val_loss: -6.2458e+03
# Epoch 99/100
# 1s - loss: -6.2455e+03 - val_loss: -6.2458e+03
# Epoch 100/100
# 1s - loss: -6.2459e+03 - val_loss: -6.2460e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7945
# SourceData's aborting data = 22
# window shape is (7945, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=32-l1_reg=10e-5
# Train on 7945 samples, validate on 7945 samples
# Epoch 1/100
# 0s - loss: -4.6083e+03 - val_loss: -4.9604e+03
# Epoch 2/100
# 0s - loss: -5.0672e+03 - val_loss: -5.1687e+03
# Epoch 3/100
# 0s - loss: -5.2517e+03 - val_loss: -5.3364e+03
# Epoch 4/100
# 0s - loss: -5.3746e+03 - val_loss: -5.3965e+03
# Epoch 5/100
# 0s - loss: -5.4202e+03 - val_loss: -5.4332e+03
# Epoch 6/100
# 0s - loss: -5.4437e+03 - val_loss: -5.4707e+03
# Epoch 7/100
# 0s - loss: -5.4969e+03 - val_loss: -5.5225e+03
# Epoch 8/100
# 0s - loss: -5.5425e+03 - val_loss: -5.5557e+03
# Epoch 9/100
# 0s - loss: -5.5576e+03 - val_loss: -5.5732e+03
# Epoch 10/100
# 0s - loss: -5.5729e+03 - val_loss: -5.5685e+03
# Epoch 11/100
# 0s - loss: -5.5727e+03 - val_loss: -5.5789e+03
# Epoch 12/100
# 0s - loss: -5.5794e+03 - val_loss: -5.5812e+03
# Epoch 13/100
# 0s - loss: -5.5900e+03 - val_loss: -5.6090e+03
# Epoch 14/100
# 0s - loss: -5.6107e+03 - val_loss: -5.6126e+03
# Epoch 15/100
# 0s - loss: -5.6232e+03 - val_loss: -5.6318e+03
# Epoch 16/100
# 0s - loss: -5.6395e+03 - val_loss: -5.6519e+03
# Epoch 17/100
# 0s - loss: -5.6658e+03 - val_loss: -5.6780e+03
# Epoch 18/100
# 0s - loss: -5.6861e+03 - val_loss: -5.6846e+03
# Epoch 19/100
# 0s - loss: -5.7002e+03 - val_loss: -5.7062e+03
# Epoch 20/100
# 0s - loss: -5.7069e+03 - val_loss: -5.7148e+03
# Epoch 21/100
# 0s - loss: -5.7207e+03 - val_loss: -5.7243e+03
# Epoch 22/100
# 0s - loss: -5.7299e+03 - val_loss: -5.7334e+03
# Epoch 23/100
# 0s - loss: -5.7345e+03 - val_loss: -5.7356e+03
# Epoch 24/100
# 0s - loss: -5.7363e+03 - val_loss: -5.7443e+03
# Epoch 25/100
# 0s - loss: -5.7451e+03 - val_loss: -5.7469e+03
# Epoch 26/100
# 0s - loss: -5.7552e+03 - val_loss: -5.7661e+03
# Epoch 27/100
# 0s - loss: -5.7772e+03 - val_loss: -5.7838e+03
# Epoch 28/100
# 0s - loss: -5.7976e+03 - val_loss: -5.8012e+03
# Epoch 29/100
# 0s - loss: -5.8001e+03 - val_loss: -5.7995e+03
# Epoch 30/100
# 0s - loss: -5.8002e+03 - val_loss: -5.8017e+03
# Epoch 31/100
# 0s - loss: -5.8039e+03 - val_loss: -5.8059e+03
# Epoch 32/100
# 0s - loss: -5.8167e+03 - val_loss: -5.8230e+03
# Epoch 33/100
# 0s - loss: -5.8257e+03 - val_loss: -5.8300e+03
# Epoch 34/100
# 0s - loss: -5.8322e+03 - val_loss: -5.8330e+03
# Epoch 35/100
# 0s - loss: -5.8333e+03 - val_loss: -5.8346e+03
# Epoch 36/100
# 0s - loss: -5.8417e+03 - val_loss: -5.8495e+03
# Epoch 37/100
# 0s - loss: -5.8585e+03 - val_loss: -5.8683e+03
# Epoch 38/100
# 0s - loss: -5.8811e+03 - val_loss: -5.9029e+03
# Epoch 39/100
# 0s - loss: -5.9140e+03 - val_loss: -5.9259e+03
# Epoch 40/100
# 0s - loss: -5.9290e+03 - val_loss: -5.9418e+03
# Epoch 41/100
# 0s - loss: -5.9472e+03 - val_loss: -5.9503e+03
# Epoch 42/100
# 0s - loss: -5.9531e+03 - val_loss: -5.9592e+03
# Epoch 43/100
# 0s - loss: -4.5569e+03 - val_loss: -4.8715e+03
# Epoch 44/100
# 0s - loss: -5.3748e+03 - val_loss: -5.6416e+03
# Epoch 45/100
# 0s - loss: -5.7654e+03 - val_loss: -5.8286e+03
# Epoch 46/100
# 0s - loss: -5.8794e+03 - val_loss: -5.9141e+03
# Epoch 47/100
# 0s - loss: -5.9251e+03 - val_loss: -5.9345e+03
# Epoch 48/100
# 0s - loss: -5.9364e+03 - val_loss: -5.9429e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =3973
# SourceData's aborting data = 22
# window shape is (3973, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=64-l1_reg=10e-5
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: -4.5194e+03 - val_loss: -4.7860e+03
# Epoch 2/100
# 0s - loss: -4.9014e+03 - val_loss: -5.0179e+03
# Epoch 3/100
# 0s - loss: -5.1285e+03 - val_loss: -5.2128e+03
# Epoch 4/100
# 0s - loss: -5.2681e+03 - val_loss: -5.3198e+03
# Epoch 5/100
# 0s - loss: -5.3710e+03 - val_loss: -5.4094e+03
# Epoch 6/100
# 0s - loss: -5.4345e+03 - val_loss: -5.4510e+03
# Epoch 7/100
# 0s - loss: -5.4812e+03 - val_loss: -5.5029e+03
# Epoch 8/100
# 0s - loss: -5.5125e+03 - val_loss: -5.5293e+03
# Epoch 9/100
# 0s - loss: -5.5540e+03 - val_loss: -5.5713e+03
# Epoch 10/100
# 0s - loss: -5.5975e+03 - val_loss: -5.6255e+03
# Epoch 11/100
# 0s - loss: -5.6267e+03 - val_loss: -5.6315e+03
# Epoch 12/100
# 0s - loss: -5.6580e+03 - val_loss: -5.6745e+03
# Epoch 13/100
# 0s - loss: -5.6862e+03 - val_loss: -5.6961e+03
# Epoch 14/100
# 0s - loss: -5.6991e+03 - val_loss: -5.7062e+03
# Epoch 15/100
# 0s - loss: -5.7193e+03 - val_loss: -5.7240e+03
# Epoch 16/100
# 0s - loss: -5.7291e+03 - val_loss: -5.7352e+03
# Epoch 17/100
# 0s - loss: -5.7422e+03 - val_loss: -5.7436e+03
# Epoch 18/100
# 0s - loss: -5.7483e+03 - val_loss: -5.7488e+03
# Epoch 19/100
# 0s - loss: -5.7513e+03 - val_loss: -5.7514e+03
# Epoch 20/100
# 0s - loss: -5.7540e+03 - val_loss: -5.7612e+03
# Epoch 21/100
# 0s - loss: -5.7702e+03 - val_loss: -5.7774e+03
# Epoch 22/100
# 0s - loss: -5.7841e+03 - val_loss: -5.7865e+03
# Epoch 23/100
# 0s - loss: -5.7907e+03 - val_loss: -5.7962e+03
# Epoch 24/100
# 0s - loss: -5.8010e+03 - val_loss: -5.8056e+03
# Epoch 25/100
# 0s - loss: -5.8061e+03 - val_loss: -5.8066e+03
# Epoch 26/100
# 0s - loss: -5.8115e+03 - val_loss: -5.8124e+03
# Epoch 27/100
# 0s - loss: -5.8170e+03 - val_loss: -5.8279e+03
# Epoch 28/100
# 0s - loss: -5.8299e+03 - val_loss: -5.8330e+03
# Epoch 29/100
# 0s - loss: -5.8491e+03 - val_loss: -5.8688e+03
# Epoch 30/100
# 0s - loss: -5.8746e+03 - val_loss: -5.8808e+03
# Epoch 31/100
# 0s - loss: -5.8882e+03 - val_loss: -5.8957e+03
# Epoch 32/100
# 0s - loss: -5.8985e+03 - val_loss: -5.9006e+03
# Epoch 33/100
# 0s - loss: -5.8998e+03 - val_loss: -5.9003e+03
# Epoch 34/100
# 0s - loss: -5.9036e+03 - val_loss: -5.9194e+03
# Epoch 35/100
# 0s - loss: -5.9214e+03 - val_loss: -5.9284e+03
# Epoch 36/100
# 0s - loss: -5.9310e+03 - val_loss: -5.9383e+03
# Epoch 37/100
# 0s - loss: -5.9381e+03 - val_loss: -5.9400e+03
# Epoch 38/100
# 0s - loss: -5.9474e+03 - val_loss: -5.9492e+03
# Epoch 39/100
# 0s - loss: -5.9512e+03 - val_loss: -5.9501e+03
# Epoch 40/100
# 0s - loss: -5.9521e+03 - val_loss: -5.9536e+03
# Epoch 41/100
# 0s - loss: -5.9561e+03 - val_loss: -5.9653e+03
# Epoch 42/100
# 0s - loss: -5.9773e+03 - val_loss: -5.9904e+03
# Epoch 43/100
# 0s - loss: -5.9909e+03 - val_loss: -5.9921e+03
# Epoch 44/100
# 0s - loss: -5.9938e+03 - val_loss: -5.9970e+03
# Epoch 45/100
# 0s - loss: -5.9995e+03 - val_loss: -6.0069e+03
# Epoch 46/100
# 0s - loss: -6.0092e+03 - val_loss: -6.0159e+03
# Epoch 47/100
# 0s - loss: -6.0162e+03 - val_loss: -6.0172e+03
# Epoch 48/100
# 0s - loss: -6.0242e+03 - val_loss: -6.0277e+03
# Epoch 49/100
# 0s - loss: -6.0414e+03 - val_loss: -6.0530e+03
# Epoch 50/100
# 0s - loss: -6.0540e+03 - val_loss: -6.0544e+03
# Epoch 51/100
# 0s - loss: -6.0578e+03 - val_loss: -6.0632e+03
# Epoch 52/100
# 0s - loss: -6.0639e+03 - val_loss: -6.0649e+03
# Epoch 53/100
# 0s - loss: -6.0679e+03 - val_loss: -6.0757e+03
# Epoch 54/100
# 0s - loss: -6.0828e+03 - val_loss: -6.0857e+03
# Epoch 55/100
# 0s - loss: -6.0876e+03 - val_loss: -6.0940e+03
# Epoch 56/100
# 0s - loss: -6.0931e+03 - val_loss: -6.0887e+03
# Epoch 57/100
# 0s - loss: -6.0941e+03 - val_loss: -6.0964e+03
# Epoch 58/100
# 0s - loss: -6.0964e+03 - val_loss: -6.0974e+03
# Epoch 59/100
# 0s - loss: -6.0979e+03 - val_loss: -6.0981e+03
# Epoch 60/100
# 0s - loss: -6.1016e+03 - val_loss: -6.1084e+03
# Epoch 61/100
# 0s - loss: -6.1110e+03 - val_loss: -6.1181e+03
# Epoch 62/100
# 0s - loss: -6.1225e+03 - val_loss: -6.1273e+03
# Epoch 63/100
# 0s - loss: -6.1357e+03 - val_loss: -6.1453e+03
# Epoch 64/100
# 0s - loss: -6.1457e+03 - val_loss: -6.1464e+03
# Epoch 65/100
# 0s - loss: -6.1525e+03 - val_loss: -6.1535e+03
# ...
# 0s - loss: -4.1539e+04 - val_loss: -4.1546e+04
# Epoch 43/100
# 0s - loss: -4.1544e+04 - val_loss: -4.1554e+04
# Epoch 44/100
# 0s - loss: -4.1563e+04 - val_loss: -4.1562e+04
# Epoch 45/100
# 0s - loss: -4.1579e+04 - val_loss: -4.1594e+04
# Epoch 46/100
# 0s - loss: -4.1600e+04 - val_loss: -4.1612e+04
# Epoch 47/100
# 0s - loss: -4.1622e+04 - val_loss: -4.1643e+04
# Epoch 48/100
# 0s - loss: -4.1645e+04 - val_loss: -4.1649e+04
# Epoch 49/100
# 0s - loss: -4.1661e+04 - val_loss: -4.1679e+04
# Epoch 50/100
# 0s - loss: -4.1684e+04 - val_loss: -4.1693e+04
# Epoch 51/100
# 1s - loss: -4.1696e+04 - val_loss: -4.1702e+04
# Epoch 52/100
# 1s - loss: -4.1709e+04 - val_loss: -4.1718e+04
# Epoch 53/100
# 0s - loss: -4.1724e+04 - val_loss: -4.1728e+04
# Epoch 54/100
# 0s - loss: -4.1730e+04 - val_loss: -4.1742e+04
# Epoch 55/100
# 0s - loss: -4.1746e+04 - val_loss: -4.1750e+04
# Epoch 56/100
# 0s - loss: -4.1754e+04 - val_loss: -4.1762e+04
# Epoch 57/100
# 0s - loss: -4.1763e+04 - val_loss: -4.1769e+04
# Epoch 58/100
# 0s - loss: -4.1770e+04 - val_loss: -4.1774e+04
# Epoch 59/100
# 0s - loss: -4.1779e+04 - val_loss: -4.1791e+04
# Epoch 60/100
# 0s - loss: -4.1799e+04 - val_loss: -4.1806e+04
# Epoch 61/100
# 0s - loss: -4.1814e+04 - val_loss: -4.1819e+04
# Epoch 62/100
# 0s - loss: -4.1824e+04 - val_loss: -4.1830e+04
# Epoch 63/100
# 0s - loss: -4.1839e+04 - val_loss: -4.1848e+04
# Epoch 64/100
# 0s - loss: -4.1854e+04 - val_loss: -4.1861e+04
# Epoch 65/100
# 0s - loss: -4.1873e+04 - val_loss: -4.1875e+04
# Epoch 66/100
# 0s - loss: -4.1889e+04 - val_loss: -4.1896e+04
# Epoch 67/100
# 0s - loss: -4.1904e+04 - val_loss: -4.1913e+04
# Epoch 68/100
# 0s - loss: -4.1916e+04 - val_loss: -4.1926e+04
# Epoch 69/100
# 0s - loss: -4.1928e+04 - val_loss: -4.1934e+04
# Epoch 70/100
# 0s - loss: -4.1941e+04 - val_loss: -4.1951e+04
# Epoch 71/100
# 0s - loss: -4.1961e+04 - val_loss: -4.1976e+04
# Epoch 72/100
# 0s - loss: -4.1988e+04 - val_loss: -4.2001e+04
# Epoch 73/100
# 0s - loss: -4.2006e+04 - val_loss: -4.2012e+04
# Epoch 74/100
# 0s - loss: -4.2019e+04 - val_loss: -4.2026e+04
# Epoch 75/100
# 0s - loss: -4.2031e+04 - val_loss: -4.2051e+04
# Epoch 76/100
# 0s - loss: -4.2049e+04 - val_loss: -4.2052e+04
# Epoch 77/100
# 0s - loss: -4.2052e+04 - val_loss: -4.2052e+04
# Epoch 78/100
# 0s - loss: -4.2056e+04 - val_loss: -4.2064e+04
# Epoch 79/100
# 0s - loss: -4.2066e+04 - val_loss: -4.2073e+04
# Epoch 80/100
# 0s - loss: -4.2079e+04 - val_loss: -4.2086e+04
# Epoch 81/100
# 0s - loss: -4.2091e+04 - val_loss: -4.2098e+04
# Epoch 82/100
# 0s - loss: -4.2101e+04 - val_loss: -4.2107e+04
# Epoch 83/100
# 0s - loss: -4.2110e+04 - val_loss: -4.2117e+04
# Epoch 84/100
# 0s - loss: -4.2119e+04 - val_loss: -4.2124e+04
# Epoch 85/100
# 0s - loss: -4.2130e+04 - val_loss: -4.2137e+04
# Epoch 86/100
# 0s - loss: -4.2148e+04 - val_loss: -4.2156e+04
# Epoch 87/100
# 0s - loss: -4.2165e+04 - val_loss: -4.2167e+04
# Epoch 88/100
# 0s - loss: -4.2171e+04 - val_loss: -4.2179e+04
# Epoch 89/100
# 0s - loss: -4.2183e+04 - val_loss: -4.2189e+04
# Epoch 90/100
# 0s - loss: -4.2197e+04 - val_loss: -4.2202e+04
# Epoch 91/100
# 0s - loss: -4.2205e+04 - val_loss: -4.2211e+04
# Epoch 92/100
# 0s - loss: -4.2220e+04 - val_loss: -4.2228e+04
# Epoch 93/100
# 0s - loss: -4.2237e+04 - val_loss: -4.2253e+04
# Epoch 94/100
# 0s - loss: -4.2263e+04 - val_loss: -4.2278e+04
# Epoch 95/100
# 0s - loss: -4.2278e+04 - val_loss: -4.2282e+04
# Epoch 96/100
# 0s - loss: -4.2284e+04 - val_loss: -4.2287e+04
# Epoch 97/100
# 0s - loss: -4.2294e+04 - val_loss: -4.2307e+04
# Epoch 98/100
# 0s - loss: -4.2310e+04 - val_loss: -4.2315e+04
# Epoch 99/100
# 0s - loss: -4.2316e+04 - val_loss: -4.2323e+04
# Epoch 100/100
# 0s - loss: -4.2326e+04 - val_loss: -4.2326e+04
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =1959
# SourceData's aborting data = 22
# window shape is (1959, 4096, 1)
# hiden node = 16
# -edim=16-Window=4096-Overlap=128-l1_reg=10e-5
# Train on 1959 samples, validate on 1959 samples
# Epoch 1/100
# 0s - loss: -3.4122e+04 - val_loss: -3.5375e+04
# Epoch 2/100
# 0s - loss: -3.6192e+04 - val_loss: -3.7281e+04
# Epoch 3/100
# 0s - loss: -3.7640e+04 - val_loss: -3.8167e+04
# Epoch 4/100
# 0s - loss: -3.8374e+04 - val_loss: -3.8678e+04
# Epoch 5/100
# 0s - loss: -3.8816e+04 - val_loss: -3.9006e+04
# Epoch 6/100
# 0s - loss: -3.9108e+04 - val_loss: -3.9270e+04
# Epoch 7/100
# 0s - loss: -3.9338e+04 - val_loss: -3.9494e+04
# Epoch 8/100
# 0s - loss: -3.9570e+04 - val_loss: -3.9714e+04
# Epoch 9/100
# 0s - loss: -3.9810e+04 - val_loss: -3.9953e+04
# Epoch 10/100
# 0s - loss: -3.9990e+04 - val_loss: -4.0072e+04
# Epoch 11/100
# 0s - loss: -4.0152e+04 - val_loss: -4.0267e+04
# Epoch 12/100
# 0s - loss: -4.0309e+04 - val_loss: -4.0389e+04
# Epoch 13/100
# 0s - loss: -4.0447e+04 - val_loss: -4.0545e+04
# Epoch 14/100
# 0s - loss: -4.0591e+04 - val_loss: -4.0657e+04
# Epoch 15/100
# 0s - loss: -4.0693e+04 - val_loss: -4.0751e+04
# Epoch 16/100
# 0s - loss: -4.0790e+04 - val_loss: -4.0815e+04
# Epoch 17/100
# 0s - loss: -4.0855e+04 - val_loss: -4.0907e+04
# Epoch 18/100
# 0s - loss: -4.0936e+04 - val_loss: -4.0970e+04
# Epoch 19/100
# 0s - loss: -4.1009e+04 - val_loss: -4.1056e+04
# Epoch 20/100
# 0s - loss: -4.1100e+04 - val_loss: -4.1147e+04
# Epoch 21/100
# 0s - loss: -4.1197e+04 - val_loss: -4.1205e+04
# Epoch 22/100
# 0s - loss: -4.1241e+04 - val_loss: -4.1296e+04
# Epoch 23/100
# 0s - loss: -4.1319e+04 - val_loss: -4.1371e+04
# Epoch 24/100
# 0s - loss: -4.1402e+04 - val_loss: -4.1464e+04
# Epoch 25/100
# 0s - loss: -4.1469e+04 - val_loss: -4.1509e+04
# Epoch 26/100
# 0s - loss: -4.1539e+04 - val_loss: -4.1581e+04
# Epoch 27/100
# 0s - loss: -4.1616e+04 - val_loss: -4.1668e+04
# Epoch 28/100
# 0s - loss: -4.1675e+04 - val_loss: -4.1703e+04
# Epoch 29/100
# 0s - loss: -4.1742e+04 - val_loss: -4.1759e+04
# Epoch 30/100
# 0s - loss: -4.1786e+04 - val_loss: -4.1810e+04
# Epoch 31/100
# 0s - loss: -4.1828e+04 - val_loss: -4.1874e+04
# Epoch 32/100
# 0s - loss: -4.1887e+04 - val_loss: -4.1904e+04
# Epoch 33/100
# 0s - loss: -4.1929e+04 - val_loss: -4.1961e+04
# Epoch 34/100
# 0s - loss: -4.1983e+04 - val_loss: -4.2007e+04
# Epoch 35/100
# 0s - loss: -4.2045e+04 - val_loss: -4.2080e+04
# Epoch 36/100
# 0s - loss: -4.2097e+04 - val_loss: -4.2126e+04
# Epoch 37/100
# 0s - loss: -4.2133e+04 - val_loss: -4.2160e+04
# Epoch 38/100
# 0s - loss: -4.2175e+04 - val_loss: -4.2198e+04
# Epoch 39/100
# 0s - loss: -4.2231e+04 - val_loss: -4.2266e+04
# Epoch 40/100
# 0s - loss: -4.2276e+04 - val_loss: -4.2288e+04
# Epoch 41/100
# 0s - loss: -4.2298e+04 - val_loss: -4.2313e+04
# Epoch 42/100
# 0s - loss: -4.2318e+04 - val_loss: -4.2344e+04
# Epoch 43/100
# 0s - loss: -4.2354e+04 - val_loss: -4.2374e+04
# Epoch 44/100
# 0s - loss: -4.2381e+04 - val_loss: -4.2387e+04
# Epoch 45/100
# 0s - loss: -4.2392e+04 - val_loss: -4.2410e+04
# Epoch 46/100
# 0s - loss: -4.2416e+04 - val_loss: -4.2430e+04
# Epoch 47/100
# 0s - loss: -4.2445e+04 - val_loss: -4.2462e+04
# Epoch 48/100
# 0s - loss: -4.2477e+04 - val_loss: -4.2502e+04
# Epoch 49/100
# 0s - loss: -4.2522e+04 - val_loss: -4.2536e+04
# Epoch 50/100
# 0s - loss: -4.2549e+04 - val_loss: -4.2582e+04
# Epoch 51/100
# 0s - loss: -4.2593e+04 - val_loss: -4.2614e+04
# Epoch 52/100
# 0s - loss: -4.2621e+04 - val_loss: -4.2642e+04
# Epoch 53/100
# 0s - loss: -4.2658e+04 - val_loss: -4.2692e+04
# Epoch 54/100
# 0s - loss: -4.2702e+04 - val_loss: -4.2709e+04
# Epoch 55/100
# 0s - loss: -4.2715e+04 - val_loss: -4.2723e+04
# Epoch 56/100
# 0s - loss: -4.2730e+04 - val_loss: -4.2741e+04
# Epoch 57/100
# 0s - loss: -4.2752e+04 - val_loss: -4.2763e+04
# Epoch 58/100
# 0s - loss: -4.2772e+04 - val_loss: -4.2780e+04
# Epoch 59/100
# 0s - loss: -4.2793e+04 - val_loss: -4.2808e+04
# Epoch 60/100
# 0s - loss: -4.2819e+04 - val_loss: -4.2839e+04
# Epoch 61/100
# 0s - loss: -4.2842e+04 - val_loss: -4.2859e+04
# Epoch 62/100
# 0s - loss: -4.2865e+04 - val_loss: -4.2886e+04
# Epoch 63/100
# 0s - loss: -4.2906e+04 - val_loss: -4.2927e+04
# Epoch 64/100
# 0s - loss: -4.2929e+04 - val_loss: -4.2954e+04
# Epoch 65/100
# 0s - loss: -4.2964e+04 - val_loss: -4.2987e+04
# Epoch 66/100
# 0s - loss: -4.2988e+04 - val_loss: -4.2999e+04
# Epoch 67/100
# 0s - loss: -4.3013e+04 - val_loss: -4.3039e+04
# Epoch 68/100
# 0s - loss: -4.3052e+04 - val_loss: -4.3078e+04
# Epoch 69/100
# 0s - loss: -4.3078e+04 - val_loss: -4.3092e+04
# Epoch 70/100
# 0s - loss: -4.3095e+04 - val_loss: -4.3112e+04
# Epoch 71/100
# 0s - loss: -4.3123e+04 - val_loss: -4.3141e+04
# Epoch 72/100
# 0s - loss: -4.3146e+04 - val_loss: -4.3157e+04
# Epoch 73/100
# 0s - loss: -4.3158e+04 - val_loss: -4.3168e+04
# Epoch 74/100
# 0s - loss: -4.3174e+04 - val_loss: -4.3174e+04
# Epoch 75/100
# 0s - loss: -4.3181e+04 - val_loss: -4.3193e+04
# Epoch 76/100
# 0s - loss: -4.3207e+04 - val_loss: -4.3219e+04
# Epoch 77/100
# 0s - loss: -4.3220e+04 - val_loss: -4.3239e+04
# Epoch 78/100
# 0s - loss: -4.3244e+04 - val_loss: -4.3263e+04
# Epoch 79/100
# 0s - loss: -4.3264e+04 - val_loss: -4.3266e+04
# Epoch 80/100
# 0s - loss: -4.3275e+04 - val_loss: -4.3282e+04
# Epoch 81/100
# 0s - loss: -4.3289e+04 - val_loss: -4.3294e+04
# Epoch 82/100
# 0s - loss: -4.3295e+04 - val_loss: -4.3295e+04
# Epoch 83/100
# 0s - loss: -4.3298e+04 - val_loss: -4.3303e+04
# Epoch 84/100
# 0s - loss: -4.3308e+04 - val_loss: -4.3314e+04
# Epoch 85/100
# 0s - loss: -4.3324e+04 - val_loss: -4.3338e+04
# Epoch 86/100
# 0s - loss: -4.3349e+04 - val_loss: -4.3375e+04
# Epoch 87/100
# 0s - loss: -4.3377e+04 - val_loss: -4.3393e+04
# Epoch 88/100
# 0s - loss: -4.3398e+04 - val_loss: -4.3415e+04
# Epoch 89/100
# 0s - loss: -4.3425e+04 - val_loss: -4.3424e+04
# Epoch 90/100
# 0s - loss: -4.3437e+04 - val_loss: -4.3455e+04
# Epoch 91/100
# 0s - loss: -4.3458e+04 - val_loss: -4.3468e+04
# Epoch 92/100
# 0s - loss: -4.3478e+04 - val_loss: -4.3492e+04
# Epoch 93/100
# 0s - loss: -4.3503e+04 - val_loss: -4.3511e+04
# Epoch 94/100
# 0s - loss: -4.3519e+04 - val_loss: -4.3526e+04
# Epoch 95/100
# 0s - loss: -4.3528e+04 - val_loss: -4.3538e+04
# Epoch 96/100
# 0s - loss: -4.3542e+04 - val_loss: -4.3547e+04
# Epoch 97/100
# 0s - loss: -4.3552e+04 - val_loss: -4.3557e+04
# Epoch 98/100
# 0s - loss: -4.3569e+04 - val_loss: -4.3581e+04
# Epoch 99/100
# 0s - loss: -4.3588e+04 - val_loss: -4.3598e+04
# Epoch 100/100
# 0s - loss: -4.3606e+04 - val_loss: -4.3627e+04
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =980
# SourceData's aborting data = 22
# window shape is (980, 4096, 1)
# hiden node = 16
# -edim=16-Window=4096-Overlap=256-l1_reg=10e-5
# Train on 980 samples, validate on 980 samples
# Epoch 1/100
# 0s - loss: -3.2538e+04 - val_loss: -3.4345e+04
# Epoch 2/100
# 0s - loss: -3.4654e+04 - val_loss: -3.5469e+04
# Epoch 3/100
# 0s - loss: -3.5679e+04 - val_loss: -3.6187e+04
# Epoch 4/100
# 0s - loss: -3.6284e+04 - val_loss: -3.6596e+04
# Epoch 5/100
# 0s - loss: -3.6706e+04 - val_loss: -3.6929e+04
# Epoch 6/100
# 0s - loss: -3.7011e+04 - val_loss: -3.7196e+04
# Epoch 7/100
# 0s - loss: -3.7284e+04 - val_loss: -3.7482e+04
# Epoch 8/100
# 0s - loss: -3.7555e+04 - val_loss: -3.7700e+04
# Epoch 9/100
# 0s - loss: -3.7769e+04 - val_loss: -3.7938e+04
# Epoch 10/100
# 0s - loss: -3.7993e+04 - val_loss: -3.8096e+04
# Epoch 11/100
# 0s - loss: -3.8114e+04 - val_loss: -3.8230e+04
# Epoch 12/100
# 0s - loss: -3.8253e+04 - val_loss: -3.8341e+04
# Epoch 13/100
# 0s - loss: -3.8378e+04 - val_loss: -3.8474e+04
# Epoch 14/100
# 0s - loss: -3.8518e+04 - val_loss: -3.8615e+04
# Epoch 15/100
# 0s - loss: -3.8635e+04 - val_loss: -3.8753e+04
# Epoch 16/100
# 0s - loss: -3.8771e+04 - val_loss: -3.8871e+04
# Epoch 17/100
# 0s - loss: -3.8884e+04 - val_loss: -3.8987e+04
# Epoch 18/100
# 0s - loss: -3.9005e+04 - val_loss: -3.9058e+04
# Epoch 19/100
# 0s - loss: -3.9086e+04 - val_loss: -3.9157e+04
# Epoch 20/100
# 0s - loss: -3.9173e+04 - val_loss: -3.9244e+04
# Epoch 21/100
# 0s - loss: -3.9256e+04 - val_loss: -3.9308e+04
# Epoch 22/100
# 0s - loss: -3.9316e+04 - val_loss: -3.9374e+04
# Epoch 23/100
# 0s - loss: -3.9386e+04 - val_loss: -3.9392e+04
# Epoch 24/100
# 0s - loss: -3.9422e+04 - val_loss: -3.9529e+04
# Epoch 25/100
# 0s - loss: -3.9542e+04 - val_loss: -3.9608e+04
# Epoch 26/100
# 0s - loss: -3.9639e+04 - val_loss: -3.9672e+04
# Epoch 27/100
# 0s - loss: -3.9694e+04 - val_loss: -3.9734e+04
# Epoch 28/100
# 0s - loss: -3.9763e+04 - val_loss: -3.9812e+04
# Epoch 29/100
# 0s - loss: -3.9821e+04 - val_loss: -3.9816e+04
# Epoch 30/100
# 0s - loss: -3.9845e+04 - val_loss: -3.9893e+04
# Epoch 31/100
# 0s - loss: -3.9927e+04 - val_loss: -3.9935e+04
# Epoch 32/100
# 0s - loss: -3.9956e+04 - val_loss: -3.9965e+04
# Epoch 33/100
# 0s - loss: -3.9986e+04 - val_loss: -4.0027e+04
# Epoch 34/100
# 0s - loss: -4.0058e+04 - val_loss: -4.0064e+04
# Epoch 35/100
# 0s - loss: -4.0071e+04 - val_loss: -4.0103e+04
# Epoch 36/100
# 0s - loss: -4.0118e+04 - val_loss: -4.0136e+04
# Epoch 37/100
# 0s - loss: -4.0136e+04 - val_loss: -4.0155e+04
# Epoch 38/100
# 0s - loss: -4.0175e+04 - val_loss: -4.0204e+04
# Epoch 39/100
# 0s - loss: -4.0216e+04 - val_loss: -4.0275e+04
# Epoch 40/100
# 0s - loss: -4.0288e+04 - val_loss: -4.0311e+04
# Epoch 41/100
# 0s - loss: -4.0316e+04 - val_loss: -4.0333e+04
# Epoch 42/100
# 0s - loss: -4.0327e+04 - val_loss: -4.0358e+04
# Epoch 43/100
# 0s - loss: -4.0363e+04 - val_loss: -4.0375e+04
# Epoch 44/100
# 0s - loss: -4.0377e+04 - val_loss: -4.0414e+04
# Epoch 45/100
# 0s - loss: -4.0405e+04 - val_loss: -4.0405e+04
# Epoch 46/100
# 0s - loss: -4.0408e+04 - val_loss: -4.0434e+04
# Epoch 47/100
# 0s - loss: -4.0439e+04 - val_loss: -4.0431e+04
# Epoch 48/100
# 0s - loss: -4.0452e+04 - val_loss: -4.0489e+04
# Epoch 49/100
# 0s - loss: -4.0482e+04 - val_loss: -4.0508e+04
# Epoch 50/100
# 0s - loss: -4.0511e+04 - val_loss: -4.0515e+04
# Epoch 51/100
# 0s - loss: -4.0535e+04 - val_loss: -4.0558e+04
# Epoch 52/100
# 0s - loss: -4.0559e+04 - val_loss: -4.0560e+04
# Epoch 53/100
# 0s - loss: -4.0583e+04 - val_loss: -4.0605e+04
# Epoch 54/100
# 0s - loss: -4.0614e+04 - val_loss: -4.0652e+04
# Epoch 55/100
# 0s - loss: -4.0647e+04 - val_loss: -4.0674e+04
# Epoch 56/100
# 0s - loss: -4.0675e+04 - val_loss: -4.0710e+04
# Epoch 57/100
# 0s - loss: -4.0708e+04 - val_loss: -4.0712e+04
# Epoch 58/100
# 0s - loss: -4.0718e+04 - val_loss: -4.0731e+04
# Epoch 59/100
# 0s - loss: -4.0739e+04 - val_loss: -4.0778e+04
# Epoch 60/100
# 0s - loss: -4.0783e+04 - val_loss: -4.0804e+04
# Epoch 61/100
# 0s - loss: -4.0806e+04 - val_loss: -4.0793e+04
# Epoch 62/100
# 0s - loss: -4.0818e+04 - val_loss: -4.0814e+04
# Epoch 63/100
# 0s - loss: -4.0826e+04 - val_loss: -4.0883e+04
# Epoch 64/100
# 0s - loss: -4.0887e+04 - val_loss: -4.0890e+04
# Epoch 65/100
# 0s - loss: -4.0901e+04 - val_loss: -4.0906e+04
# Epoch 66/100
# 0s - loss: -4.0911e+04 - val_loss: -4.0922e+04
# Epoch 67/100
# 0s - loss: -4.0921e+04 - val_loss: -4.0951e+04
# Epoch 68/100
# 0s - loss: -4.0945e+04 - val_loss: -4.0975e+04
# Epoch 69/100
# 0s - loss: -4.0979e+04 - val_loss: -4.1006e+04
# Epoch 70/100
# 0s - loss: -4.1010e+04 - val_loss: -4.1019e+04
# Epoch 71/100
# 0s - loss: -4.1030e+04 - val_loss: -4.1035e+04
# Epoch 72/100
# 0s - loss: -4.1039e+04 - val_loss: -4.1058e+04
# Epoch 73/100
# 0s - loss: -4.1061e+04 - val_loss: -4.1083e+04
# Epoch 74/100
# 0s - loss: -4.1082e+04 - val_loss: -4.1090e+04
# Epoch 75/100
# 0s - loss: -4.1095e+04 - val_loss: -4.1115e+04
# Epoch 76/100
# 0s - loss: -4.1116e+04 - val_loss: -4.1145e+04
# Epoch 77/100
# 0s - loss: -4.1146e+04 - val_loss: -4.1147e+04
# Epoch 78/100
# 0s - loss: -4.1142e+04 - val_loss: -4.1176e+04
# Epoch 79/100
# 0s - loss: -4.1171e+04 - val_loss: -4.1176e+04
# Epoch 80/100
# 0s - loss: -4.1184e+04 - val_loss: -4.1195e+04
# Epoch 81/100
# 0s - loss: -4.1188e+04 - val_loss: -4.1204e+04
# Epoch 82/100
# 0s - loss: -4.1209e+04 - val_loss: -4.1214e+04
# Epoch 83/100
# 0s - loss: -4.1210e+04 - val_loss: -4.1208e+04
# Epoch 84/100
# 0s - loss: -4.1211e+04 - val_loss: -4.1224e+04
# Epoch 85/100
# 0s - loss: -4.1231e+04 - val_loss: -4.1219e+04
# Epoch 86/100
# 0s - loss: -4.1232e+04 - val_loss: -4.1248e+04
# Epoch 87/100
# 0s - loss: -4.1253e+04 - val_loss: -4.1259e+04
# Epoch 88/100
# 0s - loss: -4.1259e+04 - val_loss: -4.1261e+04
# Epoch 89/100
# 0s - loss: -4.1264e+04 - val_loss: -4.1264e+04
# Epoch 90/100
# 0s - loss: -4.1269e+04 - val_loss: -4.1289e+04
# Epoch 91/100
# 0s - loss: -4.1292e+04 - val_loss: -4.1287e+04
# Epoch 92/100
# 0s - loss: -4.1289e+04 - val_loss: -4.1310e+04
# Epoch 93/100
# 0s - loss: -4.1297e+04 - val_loss: -4.1293e+04
# Epoch 94/100
# 0s - loss: -4.1291e+04 - val_loss: -4.1297e+04
# Epoch 95/100
# 0s - loss: -4.1299e+04 - val_loss: -4.1299e+04
# Epoch 96/100
# 0s - loss: -4.1308e+04 - val_loss: -4.1324e+04
# Epoch 97/100
# 0s - loss: -4.1325e+04 - val_loss: -4.1332e+04
# Epoch 98/100
# 0s - loss: -4.1331e+04 - val_loss: -4.1345e+04
# Epoch 99/100
# 0s - loss: -4.1345e+04 - val_loss: -4.1353e+04
# Epoch 100/100
# 0s - loss: -4.1352e+04 - val_loss: -4.1343e+04

# %%
print "finish"
# Out:
# finish
