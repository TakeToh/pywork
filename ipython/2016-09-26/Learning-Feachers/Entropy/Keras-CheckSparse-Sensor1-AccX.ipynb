# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,32,64,128,256] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccX' # Axis

#WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData"
WORKSPACE_PATH = "/media/takeyama/01_TAKEYAMA_WORKSPACE/02_CommonData"

DATE_PATH="/2016-09-26/"
TITLE_PATH="Sparse/"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras import regularizers

import matplotlib.image as mpimg
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5005)

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
# define rawdata directory
if not os.path.exists(WORKSPACE_PATH+"/raw/"):
    os.makedirs(WORKSPACE_PATH+"/raw/")
RawDataPath=WORKSPACE_PATH+"/raw/"

# define restoring windowdata directory
if not os.path.exists(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'

# define restoring netowrk model picture's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'

# define restoring graph data's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/')
GlaphDataPath=WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'

# define restoring model paarmeter directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/')
StudyDataPath=WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成 & Learning**

# %%
encoding_dim
# Out:
# 16

# %%
# loop windowWidth
for SampleNum in WindowWidth:
    for Overlap in OverlapArray:

        w=window.Window()
        w.SetData(Axis,dic[Axis])
        wind=w.Compile(windowWidth=SampleNum,overlapNum=Overlap)
        windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
        print "hiden node = "+str(encoding_dim)
        CommonName='-edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+"l1_reg=1"
        print CommonName
        SaveFileNameEncord=DataName+'_encoded'+CommonName
        SaveFileNameDecord=DataName+'_decoded'+CommonName
        SaveFileNameNet=DataName+'_net'+CommonName
        SaveFileNameTrain=DataName+'_train'+CommonName
        SaveFileNameTest=DataName+'_test'+CommonName
        SaveFileNameGlaph=GlaphDataPath+DataName+CommonName+'_loss_val_loss.png'

        window_test=windoW
        window_train=windoW
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTrain,window_test)
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTest,window_test)
        shapeNum=windoW.shape[1]

        # this is our input placeholder
        input_img = Input(shape=(shapeNum,))
        # "encoded" is the encoded representation of the input
        encoded = Dense(encoding_dim, activation='tanh',
                    W_regularizer=regularizers.WeightRegularizer(l1=10e-5,l2=0.0))(input_img)
        # "decoded" is the lossy reconstruction of the input
        decoded = Dense(shapeNum, activation='linear')(encoded)

        # this model maps an input to its reconstruction
        autoencoder = Model(input=input_img, output=decoded)

        # this model maps an input to its encoded representation
        encoder = Model(input=input_img, output=encoded)

        # create a placeholder for an encoded (32-dimensional) input
        encoded_input = Input(shape=(encoding_dim,))
        # retrieve the last layer of the autoencoder model
        decoder_layer = autoencoder.layers[-1]
        # create the decoder model
        decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))
        
        #autoencoder.compile(optimizer='adam', loss='mse')
        autoencoder.compile(optimizer='adam', loss='categorical_crossentropy')
        
        plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')

        early_stopping = EarlyStopping(monitor='val_loss', patience=5)
        
        hist = autoencoder.fit(window_train, window_train,
                        nb_epoch=100,
                        verbose=2,
                        batch_size=shapeNum/8,
                        shuffle=True,
                        validation_data=(window_test, window_test)
                        ,callbacks=[early_stopping]
                              )
        time.sleep(0.1)
        encoded_imgs = encoder.predict(window_test)
        decoded_imgs = decoder.predict(encoded_imgs)

        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameEncord,encoded_imgs)
        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameDecord,decoded_imgs)

        # save model and wights
        json_string = encoder.to_json()
        open(StudyDataPath+SaveFileNameEncord+'.json', 'w').write(json_string)
        encoder.save_weights(StudyDataPath+SaveFileNameEncord+'_weights.h5',overwrite=True)

        json_string = decoder.to_json()
        open(StudyDataPath+SaveFileNameDecord+'.json', 'w').write(json_string)
        decoder.save_weights(StudyDataPath+SaveFileNameDecord+'_weights.h5',overwrite=True)

        json_string = autoencoder.to_json()
        open(StudyDataPath+SaveFileNameNet+'.json', 'w').write(json_string)
        autoencoder.save_weights(StudyDataPath+SaveFileNameNet+'_weights.h5',overwrite=True)

        # plot loss
        loss = hist.history['loss']
        val_loss = hist.history['val_loss']

        nb_epoch = len(loss)
        plt.plot(range(nb_epoch), loss, marker='.', label='loss')
        plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
        plt.legend(loc='best', fontsize=10)
        plt.grid()
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.savefig(SaveFileNameGlaph)
        plt.show()
# Out:
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15914
# SourceData's aborting data = 6
# window shape is (15914, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=16-l1_reg=1
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 12s - loss: -1.2715e+03 - val_loss: -1.3678e+03
# Epoch 2/100
# 12s - loss: -1.3899e+03 - val_loss: -1.4097e+03
# Epoch 3/100
# 12s - loss: -1.4210e+03 - val_loss: -1.4314e+03
# Epoch 4/100
# 12s - loss: -1.4393e+03 - val_loss: -1.4618e+03
# Epoch 5/100
# 12s - loss: -1.4797e+03 - val_loss: -1.4838e+03
# Epoch 6/100
# 12s - loss: -1.4907e+03 - val_loss: -1.5082e+03
# Epoch 7/100
# 12s - loss: -1.5113e+03 - val_loss: -1.5086e+03
# Epoch 8/100
# 12s - loss: -1.5110e+03 - val_loss: -1.5094e+03
# Epoch 9/100
# 12s - loss: -1.5086e+03 - val_loss: -1.5088e+03
# Epoch 10/100
# 12s - loss: -1.5185e+03 - val_loss: -1.5187e+03
# Epoch 11/100
# 12s - loss: -1.5199e+03 - val_loss: -1.5200e+03
# Epoch 12/100
# 13s - loss: -1.5208e+03 - val_loss: -1.5219e+03
# Epoch 13/100
# 12s - loss: -1.5305e+03 - val_loss: -1.5313e+03
# Epoch 14/100
# 12s - loss: -1.5316e+03 - val_loss: -1.5319e+03
# Epoch 15/100
# 12s - loss: -1.5318e+03 - val_loss: -1.5319e+03
# Epoch 16/100
# 12s - loss: -1.5320e+03 - val_loss: -1.5325e+03
# Epoch 17/100
# 12s - loss: -1.5385e+03 - val_loss: -1.5432e+03
# Epoch 18/100
# 12s - loss: -1.5433e+03 - val_loss: -1.5438e+03
# Epoch 19/100
# 12s - loss: -1.5437e+03 - val_loss: -1.5437e+03
# Epoch 20/100
# 12s - loss: -1.5437e+03 - val_loss: -1.5441e+03
# Epoch 21/100
# 12s - loss: -1.5491e+03 - val_loss: -1.5545e+03
# Epoch 22/100
# 12s - loss: -1.5545e+03 - val_loss: -1.5548e+03
# Epoch 23/100
# 13s - loss: -1.5545e+03 - val_loss: -1.5551e+03
# Epoch 24/100
# 12s - loss: -1.5549e+03 - val_loss: -1.5552e+03
# Epoch 25/100
# 12s - loss: -1.5551e+03 - val_loss: -1.5554e+03
# Epoch 26/100
# 12s - loss: -1.5553e+03 - val_loss: -1.5557e+03
# Epoch 27/100
# 12s - loss: -1.5548e+03 - val_loss: -1.5548e+03
# Epoch 28/100
# 12s - loss: -1.5552e+03 - val_loss: -1.5556e+03
# Epoch 29/100
# 12s - loss: -1.5554e+03 - val_loss: -1.5558e+03
# Epoch 30/100
# 12s - loss: -1.5556e+03 - val_loss: -1.5558e+03
# Epoch 31/100
# 12s - loss: -1.5558e+03 - val_loss: -1.5553e+03
# Epoch 32/100
# 11s - loss: -1.5651e+03 - val_loss: -1.5661e+03
# Epoch 33/100
# 11s - loss: -1.5660e+03 - val_loss: -1.5660e+03
# Epoch 34/100
# 12s - loss: -1.5657e+03 - val_loss: -1.5658e+03
# Epoch 35/100
# 12s - loss: -1.2936e+03 - val_loss: -8.8922e+02
# Epoch 36/100
# 12s - loss: -1.0682e+03 - val_loss: -1.1819e+03
# Epoch 37/100
# 12s - loss: -1.2277e+03 - val_loss: -1.2716e+03
# Epoch 38/100
# 12s - loss: -1.3202e+03 - val_loss: -1.3453e+03
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/backend/theano_backend.py:558: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 1 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7957
# SourceData's aborting data = 22
# window shape is (7957, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=32-l1_reg=1
# Train on 7957 samples, validate on 7957 samples
# Epoch 1/100
# 6s - loss: -1.2355e+03 - val_loss: -1.3589e+03
# Epoch 2/100
# 6s - loss: -1.3829e+03 - val_loss: -1.3984e+03
# Epoch 3/100
# 6s - loss: -1.4123e+03 - val_loss: -1.4485e+03
# Epoch 4/100
# 22s - loss: -1.4626e+03 - val_loss: -1.4701e+03
# Epoch 5/100
# 35s - loss: -1.4896e+03 - val_loss: -1.5097e+03
# Epoch 6/100
# 11s - loss: -1.5131e+03 - val_loss: -1.5325e+03
# Epoch 7/100
# 5s - loss: -1.5421e+03 - val_loss: -1.5432e+03
# Epoch 8/100
# 6s - loss: -1.5437e+03 - val_loss: -1.5443e+03
# Epoch 9/100
# 6s - loss: -1.5527e+03 - val_loss: -1.5646e+03
# Epoch 10/100
# 6s - loss: -1.5296e+03 - val_loss: -7.4924e+02
# Epoch 11/100
# 6s - loss: -1.1324e+03 - val_loss: -1.2295e+03
# Epoch 12/100
# 6s - loss: -1.2962e+03 - val_loss: -1.3410e+03
# Epoch 13/100
# 6s - loss: -1.3637e+03 - val_loss: -1.3954e+03
# Epoch 14/100
# 6s - loss: -1.4031e+03 - val_loss: -1.4154e+03
# Epoch 15/100
# 6s - loss: -1.4295e+03 - val_loss: -1.4345e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =3979
# SourceData's aborting data = 22
# window shape is (3979, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=64-l1_reg=1
# Train on 3979 samples, validate on 3979 samples
# Epoch 1/100
# 3s - loss: -1.1560e+03 - val_loss: -1.2513e+03
# Epoch 2/100
# 3s - loss: -1.2973e+03 - val_loss: -1.3217e+03
# Epoch 3/100
# 3s - loss: -1.3408e+03 - val_loss: -1.3596e+03
# Epoch 4/100
# 3s - loss: -1.3665e+03 - val_loss: -1.3799e+03
# Epoch 5/100
# 3s - loss: -1.3992e+03 - val_loss: -1.4178e+03
# Epoch 6/100
# 3s - loss: -1.4235e+03 - val_loss: -1.4278e+03
# Epoch 7/100
# 2s - loss: -1.4345e+03 - val_loss: -1.4385e+03
# Epoch 8/100
# 3s - loss: -1.4529e+03 - val_loss: -1.4595e+03
# Epoch 9/100
# 3s - loss: -1.4680e+03 - val_loss: -1.4776e+03
# Epoch 10/100
# 3s - loss: -1.4777e+03 - val_loss: -1.4779e+03
# Epoch 11/100
# 3s - loss: -1.4784e+03 - val_loss: -1.4789e+03
# Epoch 12/100
# 3s - loss: -1.4844e+03 - val_loss: -1.4985e+03
# Epoch 13/100
# 3s - loss: -1.4989e+03 - val_loss: -1.4987e+03
# Epoch 14/100
# 3s - loss: -1.4990e+03 - val_loss: -1.4992e+03
# Epoch 15/100
# 3s - loss: -1.4994e+03 - val_loss: -1.5001e+03
# Epoch 16/100
# 3s - loss: -1.5003e+03 - val_loss: -1.5008e+03
# Epoch 17/100
# 3s - loss: -1.4993e+03 - val_loss: -1.5001e+03
# Epoch 18/100
# 3s - loss: -1.5077e+03 - val_loss: -1.5101e+03
# Epoch 19/100
# 3s - loss: -1.5103e+03 - val_loss: -1.5106e+03
# Epoch 20/100
# 3s - loss: -1.5110e+03 - val_loss: -1.5116e+03
# Epoch 21/100
# 3s - loss: -1.5119e+03 - val_loss: -1.5124e+03
# Epoch 22/100
# 3s - loss: -1.5119e+03 - val_loss: -1.5109e+03
# Epoch 23/100
# 3s - loss: -1.5112e+03 - val_loss: -1.5128e+03
# Epoch 24/100
# 2s - loss: -1.5130e+03 - val_loss: -1.5128e+03
# Epoch 25/100
# 3s - loss: -1.5125e+03 - val_loss: -1.5117e+03
# Epoch 26/100
# 2s - loss: -1.5122e+03 - val_loss: -1.5130e+03
# Epoch 27/100
# 3s - loss: -1.5132e+03 - val_loss: -1.5136e+03
# Epoch 28/100
# 3s - loss: -1.5172e+03 - val_loss: -1.5240e+03
# Epoch 29/100
# 3s - loss: -1.5243e+03 - val_loss: -1.5245e+03
# Epoch 30/100
# 3s - loss: -1.5212e+03 - val_loss: -1.5219e+03
# Epoch 31/100
# 3s - loss: -1.5224e+03 - val_loss: -1.5233e+03
# Epoch 32/100
# 3s - loss: -1.5234e+03 - val_loss: -1.5236e+03
# Epoch 33/100
# 3s - loss: -1.5212e+03 - val_loss: -1.5186e+03
# Epoch 34/100
# 3s - loss: -1.5170e+03 - val_loss: -1.5201e+03
# Epoch 35/100
# 3s - loss: -1.5200e+03 - val_loss: -1.5192e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =1990
# SourceData's aborting data = 22
# window shape is (1990, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=128-l1_reg=1
# Train on 1990 samples, validate on 1990 samples
# Epoch 1/100
# 1s - loss: -1.0902e+03 - val_loss: -1.1639e+03
# Epoch 2/100
# 1s - loss: -1.2205e+03 - val_loss: -1.2722e+03
# Epoch 3/100
# 1s - loss: -1.2867e+03 - val_loss: -1.3014e+03
# Epoch 4/100
# 1s - loss: -1.3167e+03 - val_loss: -1.3237e+03
# Epoch 5/100
# 1s - loss: -1.3421e+03 - val_loss: -1.3497e+03
# Epoch 6/100
# 1s - loss: -1.3534e+03 - val_loss: -1.3607e+03
# Epoch 7/100
# 1s - loss: -1.3718e+03 - val_loss: -1.3884e+03
# Epoch 8/100
# 1s - loss: -1.3889e+03 - val_loss: -1.3897e+03
# Epoch 9/100
# 1s - loss: -1.3900e+03 - val_loss: -1.3908e+03
# Epoch 10/100
# 1s - loss: -1.3985e+03 - val_loss: -1.4009e+03
# Epoch 11/100
# 1s - loss: -1.4059e+03 - val_loss: -1.4099e+03
# Epoch 12/100
# 1s - loss: -1.4162e+03 - val_loss: -1.4275e+03
# Epoch 13/100
# 1s - loss: -1.4381e+03 - val_loss: -1.4389e+03
# Epoch 14/100
# 1s - loss: -1.4370e+03 - val_loss: -1.4398e+03
# Epoch 15/100
# 1s - loss: -1.4361e+03 - val_loss: -1.4318e+03
# Epoch 16/100
# 1s - loss: -1.4337e+03 - val_loss: -1.4407e+03
# Epoch 17/100
# 1s - loss: -1.4413e+03 - val_loss: -1.4424e+03
# Epoch 18/100
# 1s - loss: -1.4502e+03 - val_loss: -1.4516e+03
# Epoch 19/100
# 1s - loss: -1.4520e+03 - val_loss: -1.4526e+03
# Epoch 20/100
# 1s - loss: -1.4596e+03 - val_loss: -1.4607e+03
# Epoch 21/100
# 1s - loss: -1.4611e+03 - val_loss: -1.4611e+03
# Epoch 22/100
# 1s - loss: -1.4604e+03 - val_loss: -1.4603e+03
# Epoch 23/100
# 1s - loss: -1.4610e+03 - val_loss: -1.4618e+03
# Epoch 24/100
# 1s - loss: -1.4699e+03 - val_loss: -1.4711e+03
# Epoch 25/100
# 1s - loss: -1.4710e+03 - val_loss: -1.4710e+03
# Epoch 26/100
# 1s - loss: -1.4713e+03 - val_loss: -1.4717e+03
# Epoch 27/100
# 1s - loss: -1.4714e+03 - val_loss: -1.4709e+03
# Epoch 28/100
# 1s - loss: -1.4714e+03 - val_loss: -1.4716e+03
# Epoch 29/100
# 1s - loss: -1.4718e+03 - val_loss: -1.4719e+03
# Epoch 30/100
# 1s - loss: -1.4719e+03 - val_loss: -1.4721e+03
# Epoch 31/100
# 1s - loss: -1.4720e+03 - val_loss: -1.4714e+03
# Epoch 32/100
# 1s - loss: -1.4724e+03 - val_loss: -1.4722e+03
# Epoch 33/100
# 1s - loss: -1.4736e+03 - val_loss: -1.4834e+03
# Epoch 34/100
# 1s - loss: -1.4882e+03 - val_loss: -1.4924e+03
# Epoch 35/100
# 1s - loss: -1.4919e+03 - val_loss: -1.4915e+03
# Epoch 36/100
# 1s - loss: -1.4923e+03 - val_loss: -1.4929e+03
# Epoch 37/100
# 1s - loss: -1.4934e+03 - val_loss: -1.4938e+03
# Epoch 38/100
# 1s - loss: -1.4996e+03 - val_loss: -1.5041e+03
# Epoch 39/100
# 1s - loss: -1.5084e+03 - val_loss: -1.5141e+03
# Epoch 40/100
# 1s - loss: -1.5140e+03 - val_loss: -1.5137e+03
# Epoch 41/100
# 1s - loss: -1.5141e+03 - val_loss: -1.5145e+03
# Epoch 42/100
# 1s - loss: -1.5147e+03 - val_loss: -1.5151e+03
# Epoch 43/100
# 1s - loss: -1.5212e+03 - val_loss: -1.5249e+03
# Epoch 44/100
# 1s - loss: -1.5244e+03 - val_loss: -1.5246e+03
# Epoch 45/100
# 1s - loss: -1.5239e+03 - val_loss: -1.5236e+03
# Epoch 46/100
# 1s - loss: -1.5184e+03 - val_loss: -1.5152e+03
# Epoch 47/100
# 1s - loss: -1.5103e+03 - val_loss: -1.5237e+03
# Epoch 48/100
# 1s - loss: -1.5242e+03 - val_loss: -1.5246e+03
# Epoch 49/100
# 1s - loss: -1.5298e+03 - val_loss: -1.5346e+03
# Epoch 50/100
# 1s - loss: -1.5348e+03 - val_loss: -1.5351e+03
# Epoch 51/100
# 1s - loss: -1.5330e+03 - val_loss: -1.5334e+03
# Epoch 52/100
# 1s - loss: -1.5338e+03 - val_loss: -1.5340e+03
# Epoch 53/100
# 1s - loss: -1.5341e+03 - val_loss: -1.5344e+03
# Epoch 54/100
# 1s - loss: -1.5347e+03 - val_loss: -1.5350e+03
# Epoch 55/100
# 1s - loss: -1.5349e+03 - val_loss: -1.5352e+03
# Epoch 56/100
# 1s - loss: -1.5355e+03 - val_loss: -1.5358e+03
# Epoch 57/100
# 1s - loss: -1.5359e+03 - val_loss: -1.5361e+03
# Epoch 58/100
# 1s - loss: -1.5380e+03 - val_loss: -1.5461e+03
# Epoch 59/100
# 1s - loss: -1.5463e+03 - val_loss: -1.5460e+03
# Epoch 60/100
# 1s - loss: -1.5462e+03 - val_loss: -1.5461e+03
# Epoch 61/100
# 1s - loss: -1.5463e+03 - val_loss: -1.5462e+03
# Epoch 62/100
# 1s - loss: -1.5457e+03 - val_loss: -1.5458e+03
# Epoch 63/100
# 1s - loss: -1.5459e+03 - val_loss: -1.5459e+03
# Epoch 64/100
# 1s - loss: -1.5454e+03 - val_loss: -1.5458e+03
# Epoch 65/100
# 1s - loss: -1.5447e+03 - val_loss: -1.5432e+03
# Epoch 66/100
# 1s - loss: -1.5429e+03 - val_loss: -1.5431e+03
# Epoch 67/100
# 1s - loss: -1.5470e+03 - val_loss: -1.5518e+03
# Epoch 68/100
# 1s - loss: -1.5499e+03 - val_loss: -1.5509e+03
# Epoch 69/100
# 1s - loss: -1.5511e+03 - val_loss: -1.5519e+03
# Epoch 70/100
# 1s - loss: -1.5508e+03 - val_loss: -1.5490e+03
# Epoch 71/100
# 1s - loss: -1.5497e+03 - val_loss: -1.5491e+03
# Epoch 72/100
# 1s - loss: -1.5509e+03 - val_loss: -1.5495e+03
# Epoch 73/100
# 1s - loss: -1.5500e+03 - val_loss: -1.5513e+03
# Epoch 74/100
# 1s - loss: -1.5513e+03 - val_loss: -1.5521e+03
# Epoch 75/100
# 1s - loss: -1.5519e+03 - val_loss: -1.5519e+03
# Epoch 76/100
# 1s - loss: -1.5517e+03 - val_loss: -1.5513e+03
# Epoch 77/100
# 1s - loss: -1.5518e+03 - val_loss: -1.5516e+03
# Epoch 78/100
# 1s - loss: -1.5517e+03 - val_loss: -1.5513e+03
# Epoch 79/100
# 1s - loss: -1.5521e+03 - val_loss: -1.5527e+03
# Epoch 80/100
# 1s - loss: -1.5520e+03 - val_loss: -1.5526e+03
# Epoch 81/100
# 1s - loss: -1.5521e+03 - val_loss: -1.5516e+03
# Epoch 82/100
# 1s - loss: -1.5523e+03 - val_loss: -1.5527e+03
# Epoch 83/100
# 1s - loss: -1.5529e+03 - val_loss: -1.5533e+03
# Epoch 84/100
# 1s - loss: -1.5534e+03 - val_loss: -1.5534e+03
# Epoch 85/100
# 1s - loss: -1.5532e+03 - val_loss: -1.5529e+03
# Epoch 86/100
# 1s - loss: -1.5523e+03 - val_loss: -1.5522e+03
# Epoch 87/100
# 1s - loss: -1.5528e+03 - val_loss: -1.5528e+03
# Epoch 88/100
# 1s - loss: -1.5528e+03 - val_loss: -1.5520e+03
# Epoch 89/100
# 1s - loss: -1.5526e+03 - val_loss: -1.5531e+03
# Epoch 90/100
# 1s - loss: -1.5532e+03 - val_loss: -1.5531e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =995
# SourceData's aborting data = 150
# window shape is (995, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=256-l1_reg=1
# Train on 995 samples, validate on 995 samples
# Epoch 1/100
# 0s - loss: -1.0812e+03 - val_loss: -1.1638e+03
# Epoch 2/100
# 0s - loss: -1.2005e+03 - val_loss: -1.2367e+03
# Epoch 3/100
# 0s - loss: -1.2608e+03 - val_loss: -1.2969e+03
# Epoch 4/100
# 0s - loss: -1.3065e+03 - val_loss: -1.3098e+03
# Epoch 5/100
# 0s - loss: -1.3177e+03 - val_loss: -1.3284e+03
# Epoch 6/100
# 0s - loss: -1.3296e+03 - val_loss: -1.3305e+03
# Epoch 7/100
# 0s - loss: -1.3377e+03 - val_loss: -1.3328e+03
# Epoch 8/100
# 0s - loss: -1.3450e+03 - val_loss: -1.3514e+03
# Epoch 9/100
# 0s - loss: -1.3541e+03 - val_loss: -1.3599e+03
# Epoch 10/100
# 0s - loss: -1.3676e+03 - val_loss: -1.3693e+03
# Epoch 11/100
# 0s - loss: -1.3861e+03 - val_loss: -1.3970e+03
# Epoch 12/100
# 0s - loss: -1.4018e+03 - val_loss: -1.4074e+03
# Epoch 13/100
# 0s - loss: -1.4151e+03 - val_loss: -1.4167e+03
# Epoch 14/100
# 0s - loss: -1.4168e+03 - val_loss: -1.4171e+03
# Epoch 15/100
# 0s - loss: -1.4167e+03 - val_loss: -1.4168e+03
# Epoch 16/100
# 0s - loss: -1.4172e+03 - val_loss: -1.4177e+03
# Epoch 17/100
# 0s - loss: -1.4180e+03 - val_loss: -1.4183e+03
# Epoch 18/100
# 0s - loss: -1.4184e+03 - val_loss: -1.4188e+03
# Epoch 19/100
# 0s - loss: -1.4189e+03 - val_loss: -1.4185e+03
# Epoch 20/100
# 0s - loss: -1.4225e+03 - val_loss: -1.4284e+03
# Epoch 21/100
# 0s - loss: -1.4285e+03 - val_loss: -1.4288e+03
# Epoch 22/100
# 0s - loss: -1.4285e+03 - val_loss: -1.4283e+03
# Epoch 23/100
# 0s - loss: -1.4286e+03 - val_loss: -1.4285e+03
# Epoch 24/100
# 0s - loss: -1.4294e+03 - val_loss: -1.4292e+03
# Epoch 25/100
# 0s - loss: -1.4362e+03 - val_loss: -1.4384e+03
# Epoch 26/100
# 0s - loss: -1.4319e+03 - val_loss: -1.4306e+03
# Epoch 27/100
# 0s - loss: -1.4317e+03 - val_loss: -1.4381e+03
# Epoch 28/100
# 0s - loss: -1.4386e+03 - val_loss: -1.4393e+03
# Epoch 29/100
# 0s - loss: -1.4400e+03 - val_loss: -1.4489e+03
# Epoch 30/100
# 0s - loss: -1.4488e+03 - val_loss: -1.4490e+03
# Epoch 31/100
# 0s - loss: -1.4492e+03 - val_loss: -1.4495e+03
# Epoch 32/100
# 0s - loss: -1.4494e+03 - val_loss: -1.4492e+03
# Epoch 33/100
# 0s - loss: -1.4493e+03 - val_loss: -1.4497e+03
# Epoch 34/100
# 0s - loss: -1.4512e+03 - val_loss: -1.4593e+03
# Epoch 35/100
# 0s - loss: -1.4595e+03 - val_loss: -1.4595e+03
# Epoch 36/100
# 0s - loss: -1.4596e+03 - val_loss: -1.4597e+03
# Epoch 37/100
# 0s - loss: -1.4599e+03 - val_loss: -1.4601e+03
# Epoch 38/100
# 0s - loss: -1.4602e+03 - val_loss: -1.4603e+03
# Epoch 39/100
# 0s - loss: -1.4605e+03 - val_loss: -1.4607e+03
# Epoch 40/100
# 0s - loss: -1.4614e+03 - val_loss: -1.4698e+03
# Epoch 41/100
# 0s - loss: -1.4700e+03 - val_loss: -1.4701e+03
# Epoch 42/100
# 0s - loss: -1.4702e+03 - val_loss: -1.4702e+03
# Epoch 43/100
# 0s - loss: -1.4701e+03 - val_loss: -1.4698e+03
# Epoch 44/100
# 0s - loss: -1.4698e+03 - val_loss: -1.4699e+03
# Epoch 45/100
# 0s - loss: -1.4698e+03 - val_loss: -1.4701e+03
# Epoch 46/100
# 0s - loss: -1.4702e+03 - val_loss: -1.4703e+03
# Epoch 47/100
# 0s - loss: -1.4705e+03 - val_loss: -1.4707e+03
# Epoch 48/100
# 0s - loss: -1.4707e+03 - val_loss: -1.4709e+03
# Epoch 49/100
# 0s - loss: -1.4741e+03 - val_loss: -1.4802e+03
# Epoch 50/100
# 0s - loss: -1.4803e+03 - val_loss: -1.4804e+03
# Epoch 51/100
# 0s - loss: -1.4805e+03 - val_loss: -1.4806e+03
# Epoch 52/100
# 0s - loss: -1.4805e+03 - val_loss: -1.4805e+03
# Epoch 53/100
# 0s - loss: -1.4806e+03 - val_loss: -1.4807e+03
# Epoch 54/100
# 0s - loss: -1.4807e+03 - val_loss: -1.4807e+03
# Epoch 55/100
# 0s - loss: -1.4807e+03 - val_loss: -1.4808e+03
# Epoch 56/100
# 0s - loss: -1.4809e+03 - val_loss: -1.4808e+03
# Epoch 57/100
# 0s - loss: -1.4808e+03 - val_loss: -1.4814e+03
# Epoch 58/100
# 0s - loss: -1.4811e+03 - val_loss: -1.4813e+03
# Epoch 59/100
# 0s - loss: -1.4817e+03 - val_loss: -1.4820e+03
# Epoch 60/100
# 0s - loss: -1.4908e+03 - val_loss: -1.5006e+03
# Epoch 61/100
# 0s - loss: -1.5005e+03 - val_loss: -1.5007e+03
# Epoch 62/100
# 0s - loss: -1.5009e+03 - val_loss: -1.5010e+03
# Epoch 63/100
# 0s - loss: -1.5011e+03 - val_loss: -1.5012e+03
# Epoch 64/100
# 0s - loss: -1.5016e+03 - val_loss: -1.5025e+03
# Epoch 65/100
# 0s - loss: -1.5101e+03 - val_loss: -1.5110e+03
# Epoch 66/100
# 0s - loss: -1.5110e+03 - val_loss: -1.5111e+03
# Epoch 67/100
# 0s - loss: -1.5112e+03 - val_loss: -1.5113e+03
# Epoch 68/100
# 0s - loss: -1.5115e+03 - val_loss: -1.5113e+03
# Epoch 69/100
# 0s - loss: -1.5076e+03 - val_loss: -1.5023e+03
# Epoch 70/100
# 0s - loss: -1.5063e+03 - val_loss: -1.5106e+03
# Epoch 71/100
# 0s - loss: -1.5106e+03 - val_loss: -1.5107e+03
# Epoch 72/100
# 0s - loss: -1.5109e+03 - val_loss: -1.5111e+03
# Epoch 73/100
# 0s - loss: -1.5112e+03 - val_loss: -1.5111e+03
# Epoch 74/100
# 0s - loss: -1.5116e+03 - val_loss: -1.5116e+03
# Epoch 75/100
# 0s - loss: -1.5117e+03 - val_loss: -1.5116e+03
# Epoch 76/100
# 0s - loss: -1.5118e+03 - val_loss: -1.5120e+03
# Epoch 77/100
# 0s - loss: -1.5121e+03 - val_loss: -1.5124e+03
# Epoch 78/100
# 0s - loss: -1.5125e+03 - val_loss: -1.5129e+03
# Epoch 79/100
# 0s - loss: -1.5162e+03 - val_loss: -1.5222e+03
# Epoch 80/100
# 0s - loss: -1.5221e+03 - val_loss: -1.5221e+03
# Epoch 81/100
# 0s - loss: -1.5221e+03 - val_loss: -1.5221e+03
# Epoch 82/100
# 0s - loss: -1.5220e+03 - val_loss: -1.5221e+03
# Epoch 83/100
# 0s - loss: -1.5222e+03 - val_loss: -1.5222e+03
# Epoch 84/100
# 0s - loss: -1.5221e+03 - val_loss: -1.5221e+03
# Epoch 85/100
# 0s - loss: -1.5221e+03 - val_loss: -1.5222e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15906
# SourceData's aborting data = 6
# window shape is (15906, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=16-l1_reg=1
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/100
# 6s - loss: -2.5009e+03 - val_loss: -2.6738e+03
# Epoch 2/100
# 6s - loss: -2.7527e+03 - val_loss: -2.7914e+03
# Epoch 3/100
# 6s - loss: -2.8358e+03 - val_loss: -2.8734e+03
# Epoch 4/100
# 6s - loss: -2.9009e+03 - val_loss: -2.9323e+03
# Epoch 5/100
# 6s - loss: -2.9693e+03 - val_loss: -3.0075e+03
# Epoch 6/100
# 6s - loss: -3.0195e+03 - val_loss: -3.0305e+03
# Epoch 7/100
# 6s - loss: -3.0609e+03 - val_loss: -3.0773e+03
# Epoch 8/100
# 6s - loss: -3.0785e+03 - val_loss: -3.0797e+03
# Epoch 9/100
# 6s - loss: -3.0807e+03 - val_loss: -3.0896e+03
# Epoch 10/100
# 6s - loss: -3.0904e+03 - val_loss: -3.0918e+03
# Epoch 11/100
# 6s - loss: -3.0979e+03 - val_loss: -3.1029e+03
# Epoch 12/100
# 6s - loss: -3.1150e+03 - val_loss: -3.1236e+03
# Epoch 13/100
# 6s - loss: -3.1201e+03 - val_loss: -3.1158e+03
# Epoch 14/100
# 6s - loss: -3.1130e+03 - val_loss: -3.1172e+03
# Epoch 15/100
# 6s - loss: -3.1169e+03 - val_loss: -3.1172e+03
# Epoch 16/100
# 6s - loss: -3.1179e+03 - val_loss: -3.1180e+03
# Epoch 17/100
# 6s - loss: -3.1173e+03 - val_loss: -3.1155e+03
# Epoch 18/100
# 6s - loss: -3.1167e+03 - val_loss: -3.1168e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7953
# SourceData's aborting data = 22
# window shape is (7953, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=32-l1_reg=1
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 3s - loss: -2.4633e+03 - val_loss: -2.6105e+03
# Epoch 2/100
# 3s - loss: -2.6859e+03 - val_loss: -2.7330e+03
# Epoch 3/100
# 3s - loss: -2.7630e+03 - val_loss: -2.7804e+03
# Epoch 4/100
# 3s - loss: -2.7939e+03 - val_loss: -2.8183e+03
# Epoch 5/100
# 3s - loss: -2.8455e+03 - val_loss: -2.8650e+03
# Epoch 6/100
# 3s - loss: -2.8778e+03 - val_loss: -2.9001e+03
# Epoch 7/100
# 3s - loss: -2.9294e+03 - val_loss: -2.9387e+03
# Epoch 8/100
# 3s - loss: -2.9534e+03 - val_loss: -2.9665e+03
# Epoch 9/100
# 3s - loss: -2.9676e+03 - val_loss: -2.9791e+03
# Epoch 10/100
# 3s - loss: -2.9995e+03 - val_loss: -3.0173e+03
# Epoch 11/100
# 3s - loss: -3.0266e+03 - val_loss: -3.0374e+03
# Epoch 12/100
# 3s - loss: -3.0418e+03 - val_loss: -3.0451e+03
# Epoch 13/100
# 3s - loss: -3.0570e+03 - val_loss: -3.0589e+03
# Epoch 14/100
# 3s - loss: -3.0645e+03 - val_loss: -3.0695e+03
# Epoch 15/100
# 3s - loss: -3.0708e+03 - val_loss: -3.0718e+03
# Epoch 16/100
# 3s - loss: -3.0799e+03 - val_loss: -3.0809e+03
# Epoch 17/100
# 3s - loss: -3.0804e+03 - val_loss: -3.0822e+03
# Epoch 18/100
# 3s - loss: -3.0877e+03 - val_loss: -3.0907e+03
# Epoch 19/100
# 3s - loss: -3.0913e+03 - val_loss: -3.0920e+03
# Epoch 20/100
# 3s - loss: -3.0924e+03 - val_loss: -3.0926e+03
# Epoch 21/100
# 3s - loss: -3.0922e+03 - val_loss: -3.0901e+03
# Epoch 22/100
# 3s - loss: -3.0924e+03 - val_loss: -3.0934e+03
# Epoch 23/100
# 3s - loss: -3.0923e+03 - val_loss: -3.0922e+03
# Epoch 24/100
# 3s - loss: -3.0898e+03 - val_loss: -3.0861e+03
# Epoch 25/100
# 3s - loss: -3.0839e+03 - val_loss: -3.0893e+03
# Epoch 26/100
# 3s - loss: -3.0851e+03 - val_loss: -3.0883e+03
# Epoch 27/100
# 3s - loss: -3.0886e+03 - val_loss: -3.0827e+03
# Epoch 28/100
# 3s - loss: -3.0841e+03 - val_loss: -3.0875e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =3977
# SourceData's aborting data = 22
# window shape is (3977, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=64-l1_reg=1
# Train on 3977 samples, validate on 3977 samples
# Epoch 1/100
# 1s - loss: -2.2114e+03 - val_loss: -2.3887e+03
# Epoch 2/100
# 1s - loss: -2.4714e+03 - val_loss: -2.5213e+03
# Epoch 3/100
# 1s - loss: -2.5653e+03 - val_loss: -2.6085e+03
# Epoch 4/100
# 1s - loss: -2.6501e+03 - val_loss: -2.6853e+03
# Epoch 5/100
# 1s - loss: -2.7030e+03 - val_loss: -2.7221e+03
# Epoch 6/100
# 1s - loss: -2.7339e+03 - val_loss: -2.7505e+03
# Epoch 7/100
# 1s - loss: -2.7708e+03 - val_loss: -2.7860e+03
# Epoch 8/100
# 1s - loss: -2.7948e+03 - val_loss: -2.8019e+03
# Epoch 9/100
# 1s - loss: -2.8141e+03 - val_loss: -2.8231e+03
# Epoch 10/100
# 1s - loss: -2.8246e+03 - val_loss: -2.8256e+03
# Epoch 11/100
# 1s - loss: -2.8271e+03 - val_loss: -2.8282e+03
# Epoch 12/100
# 1s - loss: -2.8374e+03 - val_loss: -2.8365e+03
# Epoch 13/100
# 1s - loss: -2.8458e+03 - val_loss: -2.8801e+03
# Epoch 14/100
# 1s - loss: -2.8821e+03 - val_loss: -2.8881e+03
# Epoch 15/100
# 1s - loss: -2.8894e+03 - val_loss: -2.8989e+03
# Epoch 16/100
# 1s - loss: -2.8965e+03 - val_loss: -2.8914e+03
# Epoch 17/100
# 1s - loss: -2.8962e+03 - val_loss: -2.8993e+03
# Epoch 18/100
# 1s - loss: -2.8984e+03 - val_loss: -2.9099e+03
# Epoch 19/100
# 1s - loss: -2.9097e+03 - val_loss: -2.9103e+03
# Epoch 20/100
# 1s - loss: -2.9120e+03 - val_loss: -2.9212e+03
# Epoch 21/100
# 1s - loss: -2.9254e+03 - val_loss: -2.9305e+03
# Epoch 22/100
# 1s - loss: -2.9342e+03 - val_loss: -2.9405e+03
# Epoch 23/100
# 1s - loss: -2.9403e+03 - val_loss: -2.9415e+03
# Epoch 24/100
# 1s - loss: -2.9410e+03 - val_loss: -2.9410e+03
# Epoch 25/100
# 1s - loss: -2.9437e+03 - val_loss: -2.9518e+03
# Epoch 26/100
# 1s - loss: -2.9551e+03 - val_loss: -2.9634e+03
# Epoch 27/100
# 1s - loss: -2.9625e+03 - val_loss: -2.9619e+03
# Epoch 28/100
# 1s - loss: -2.9697e+03 - val_loss: -2.9724e+03
# Epoch 29/100
# 1s - loss: -2.9749e+03 - val_loss: -2.9833e+03
# Epoch 30/100
# 1s - loss: -2.9948e+03 - val_loss: -3.0100e+03
# Epoch 31/100
# 1s - loss: -3.0098e+03 - val_loss: -3.0093e+03
# Epoch 32/100
# 6s - loss: -3.0110e+03 - val_loss: -3.0201e+03
# Epoch 33/100
# 7s - loss: -3.0204e+03 - val_loss: -3.0213e+03
# Epoch 34/100
# 7s - loss: -3.0245e+03 - val_loss: -3.0282e+03
# Epoch 35/100
# 7s - loss: -3.0293e+03 - val_loss: -3.0304e+03
# Epoch 36/100
# 7s - loss: -3.0271e+03 - val_loss: -3.0307e+03
# Epoch 37/100
# 7s - loss: -3.0314e+03 - val_loss: -3.0321e+03
# Epoch 38/100
# 7s - loss: -3.0327e+03 - val_loss: -3.0338e+03
# Epoch 39/100
# 7s - loss: -3.0330e+03 - val_loss: -3.0315e+03
# Epoch 40/100
# 7s - loss: -3.0313e+03 - val_loss: -3.0329e+03
# Epoch 41/100
# 7s - loss: -3.0326e+03 - val_loss: -3.0325e+03
# Epoch 42/100
# 7s - loss: -3.0333e+03 - val_loss: -3.0338e+03
# Epoch 43/100
# 7s - loss: -3.0238e+03 - val_loss: -3.0277e+03
# Epoch 44/100
# 7s - loss: -3.0287e+03 - val_loss: -3.0293e+03
# Epoch 45/100
# 7s - loss: -3.0328e+03 - val_loss: -3.0406e+03
# Epoch 46/100
# 7s - loss: -3.0413e+03 - val_loss: -3.0425e+03
# Epoch 47/100
# 7s - loss: -3.0501e+03 - val_loss: -3.0528e+03
# Epoch 48/100
# 7s - loss: -3.0526e+03 - val_loss: -3.0526e+03
# Epoch 49/100
# 6s - loss: -3.0519e+03 - val_loss: -3.0533e+03
# Epoch 50/100
# 3s - loss: -3.0538e+03 - val_loss: -3.0616e+03
# Epoch 51/100
# 7s - loss: -3.0615e+03 - val_loss: -3.0620e+03
# Epoch 52/100
# 7s - loss: -3.0619e+03 - val_loss: -3.0585e+03
# Epoch 53/100
# 7s - loss: -3.0610e+03 - val_loss: -3.0624e+03
# Epoch 54/100
# 7s - loss: -3.0614e+03 - val_loss: -3.0607e+03
# Epoch 55/100
# 7s - loss: -3.0648e+03 - val_loss: -3.0622e+03
# Epoch 56/100
# 7s - loss: -3.0644e+03 - val_loss: -3.0632e+03
# Epoch 57/100
# 6s - loss: -3.0634e+03 - val_loss: -3.0666e+03
# Epoch 58/100
# 7s - loss: -3.0647e+03 - val_loss: -3.0670e+03
# Epoch 59/100
# 7s - loss: -3.0742e+03 - val_loss: -3.0734e+03
# Epoch 60/100
# 7s - loss: -3.0725e+03 - val_loss: -3.0748e+03
# Epoch 61/100
# 7s - loss: -3.0797e+03 - val_loss: -3.0815e+03
# Epoch 62/100
# 7s - loss: -3.0821e+03 - val_loss: -3.0844e+03
# Epoch 63/100
# 7s - loss: -3.0828e+03 - val_loss: -3.0856e+03
# Epoch 64/100
# 7s - loss: -3.0854e+03 - val_loss: -3.0850e+03
# Epoch 65/100
# 7s - loss: -3.0847e+03 - val_loss: -3.0844e+03
# Epoch 66/100
# 7s - loss: -3.0855e+03 - val_loss: -3.0837e+03
# Epoch 67/100
# 7s - loss: -3.0845e+03 - val_loss: -3.0862e+03
# Epoch 68/100
# 6s - loss: -3.0864e+03 - val_loss: -3.0867e+03
# Epoch 69/100
# 5s - loss: -3.0863e+03 - val_loss: -3.0860e+03
# Epoch 70/100
# 7s - loss: -3.0869e+03 - val_loss: -3.0878e+03
# Epoch 71/100
# 7s - loss: -3.0881e+03 - val_loss: -3.0772e+03
# Epoch 72/100
# 7s - loss: -3.0949e+03 - val_loss: -3.0971e+03
# Epoch 73/100
# 7s - loss: -3.0977e+03 - val_loss: -3.0981e+03
# Epoch 74/100
# 7s - loss: -3.0981e+03 - val_loss: -3.0984e+03
# Epoch 75/100
# 7s - loss: -3.0951e+03 - val_loss: -3.0979e+03
# Epoch 76/100
# 7s - loss: -3.0979e+03 - val_loss: -3.0982e+03
# Epoch 77/100
# 7s - loss: -3.0990e+03 - val_loss: -3.0994e+03
# Epoch 78/100
# 7s - loss: -3.1005e+03 - val_loss: -3.1076e+03
# Epoch 79/100
# 7s - loss: -3.1076e+03 - val_loss: -3.1073e+03
# Epoch 80/100
# 7s - loss: -3.1076e+03 - val_loss: -3.1080e+03
# Epoch 81/100
# 7s - loss: -3.1081e+03 - val_loss: -3.1085e+03
# Epoch 82/100
# 7s - loss: -3.1084e+03 - val_loss: -3.1086e+03
# Epoch 83/100
# 7s - loss: -3.1088e+03 - val_loss: -3.1092e+03
# Epoch 84/100
# 7s - loss: -3.1088e+03 - val_loss: -3.1092e+03
# Epoch 85/100
# 7s - loss: -3.1091e+03 - val_loss: -3.1087e+03
# Epoch 86/100
# 7s - loss: -3.1093e+03 - val_loss: -3.1095e+03
# Epoch 87/100
# 4s - loss: -3.1094e+03 - val_loss: -3.1096e+03
# Epoch 88/100
# 7s - loss: -3.1088e+03 - val_loss: -3.1079e+03
# Epoch 89/100
# 7s - loss: -3.1084e+03 - val_loss: -3.1089e+03
# Epoch 90/100
# 7s - loss: -3.1084e+03 - val_loss: -3.1087e+03
# Epoch 91/100
# 7s - loss: -3.1088e+03 - val_loss: -3.1093e+03
# Epoch 92/100
# 7s - loss: -3.1092e+03 - val_loss: -3.1095e+03
# Epoch 93/100
# 7s - loss: -3.1095e+03 - val_loss: -3.1094e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =1989
# SourceData's aborting data = 22
# window shape is (1989, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=128-l1_reg=1
# Train on 1989 samples, validate on 1989 samples
# Epoch 1/100
# 3s - loss: -2.3028e+03 - val_loss: -2.4376e+03
# Epoch 2/100
# 3s - loss: -2.4934e+03 - val_loss: -2.5433e+03
# Epoch 3/100
# 3s - loss: -2.5495e+03 - val_loss: -2.5690e+03
# Epoch 4/100
# 3s - loss: -2.5956e+03 - val_loss: -2.6124e+03
# Epoch 5/100
# 3s - loss: -2.6381e+03 - val_loss: -2.6550e+03
# Epoch 6/100
# 3s - loss: -2.6814e+03 - val_loss: -2.7079e+03
# Epoch 7/100
# 3s - loss: -2.7157e+03 - val_loss: -2.7175e+03
# Epoch 8/100
# 3s - loss: -2.7208e+03 - val_loss: -2.7312e+03
# Epoch 9/100
# 4s - loss: -2.7627e+03 - val_loss: -2.7766e+03
# Epoch 10/100
# 3s - loss: -2.7830e+03 - val_loss: -2.7896e+03
# Epoch 11/100
# 3s - loss: -2.7975e+03 - val_loss: -2.7982e+03
# Epoch 12/100
# 3s - loss: -2.8038e+03 - val_loss: -2.8177e+03
# Epoch 13/100
# 3s - loss: -2.8267e+03 - val_loss: -2.8335e+03
# Epoch 14/100
# 3s - loss: -2.8475e+03 - val_loss: -2.8608e+03
# Epoch 15/100
# 3s - loss: -2.8779e+03 - val_loss: -2.8835e+03
# Epoch 16/100
# 3s - loss: -2.8898e+03 - val_loss: -2.8926e+03
# Epoch 17/100
# 3s - loss: -2.8997e+03 - val_loss: -2.9011e+03
# Epoch 18/100
# 3s - loss: -2.9058e+03 - val_loss: -2.9111e+03
# Epoch 19/100
# 3s - loss: -2.9204e+03 - val_loss: -2.9286e+03
# Epoch 20/100
# 3s - loss: -2.9289e+03 - val_loss: -2.9294e+03
# Epoch 21/100
# 3s - loss: -2.9297e+03 - val_loss: -2.9308e+03
# Epoch 22/100
# 1s - loss: -2.9417e+03 - val_loss: -2.9482e+03
# Epoch 23/100
# 2s - loss: -2.9536e+03 - val_loss: -2.9567e+03
# Epoch 24/100
# 3s - loss: -2.9570e+03 - val_loss: -2.9571e+03
# Epoch 25/100
# 3s - loss: -2.9576e+03 - val_loss: -2.9582e+03
# Epoch 26/100
# 3s - loss: -2.9578e+03 - val_loss: -2.9574e+03
# Epoch 27/100
# 3s - loss: -2.9578e+03 - val_loss: -2.9583e+03
# Epoch 28/100
# 3s - loss: -2.9576e+03 - val_loss: -2.9594e+03
# Epoch 29/100
# 3s - loss: -2.9661e+03 - val_loss: -2.9673e+03
# Epoch 30/100
# 4s - loss: -2.9673e+03 - val_loss: -2.9672e+03
# Epoch 31/100
# 3s - loss: -2.9683e+03 - val_loss: -2.9690e+03
# Epoch 32/100
# 3s - loss: -2.9689e+03 - val_loss: -2.9690e+03
# Epoch 33/100
# 3s - loss: -2.9683e+03 - val_loss: -2.9697e+03
# Epoch 34/100
# 3s - loss: -2.9709e+03 - val_loss: -2.9801e+03
# Epoch 35/100
# 3s - loss: -2.9872e+03 - val_loss: -2.9989e+03
# Epoch 36/100
# 3s - loss: -2.9991e+03 - val_loss: -2.9992e+03
# Epoch 37/100
# 3s - loss: -2.9994e+03 - val_loss: -2.9997e+03
# Epoch 38/100
# 3s - loss: -3.0000e+03 - val_loss: -3.0002e+03
# Epoch 39/100
# 3s - loss: -2.9978e+03 - val_loss: -3.0014e+03
# Epoch 40/100
# 3s - loss: -3.0089e+03 - val_loss: -3.0099e+03
# Epoch 41/100
# 3s - loss: -3.0099e+03 - val_loss: -3.0102e+03
# Epoch 42/100
# 3s - loss: -3.0106e+03 - val_loss: -3.0108e+03
# Epoch 43/100
# 3s - loss: -3.0088e+03 - val_loss: -3.0093e+03
# Epoch 44/100
# 3s - loss: -3.0097e+03 - val_loss: -3.0105e+03
# Epoch 45/100
# 3s - loss: -3.0108e+03 - val_loss: -3.0111e+03
# Epoch 46/100
# 3s - loss: -3.0102e+03 - val_loss: -3.0106e+03
# Epoch 47/100
# 3s - loss: -3.0093e+03 - val_loss: -3.0093e+03
# Epoch 48/100
# 3s - loss: -3.0153e+03 - val_loss: -3.0193e+03
# Epoch 49/100
# 3s - loss: -3.0199e+03 - val_loss: -3.0289e+03
# Epoch 50/100
# 4s - loss: -3.0290e+03 - val_loss: -3.0290e+03
# Epoch 51/100
# 3s - loss: -3.0287e+03 - val_loss: -3.0256e+03
# Epoch 52/100
# 3s - loss: -3.0294e+03 - val_loss: -3.0298e+03
# Epoch 53/100
# 3s - loss: -3.0297e+03 - val_loss: -3.0297e+03
# Epoch 54/100
# 3s - loss: -3.0303e+03 - val_loss: -3.0312e+03
# Epoch 55/100
# 3s - loss: -3.0363e+03 - val_loss: -3.0403e+03
# Epoch 56/100
# 3s - loss: -3.0407e+03 - val_loss: -3.0411e+03
# Epoch 57/100
# 3s - loss: -3.0399e+03 - val_loss: -3.0407e+03
# Epoch 58/100
# 1s - loss: -3.0412e+03 - val_loss: -3.0419e+03
# Epoch 59/100
# 2s - loss: -3.0421e+03 - val_loss: -3.0413e+03
# Epoch 60/100
# 3s - loss: -3.0425e+03 - val_loss: -3.0509e+03
# Epoch 61/100
# 3s - loss: -3.0516e+03 - val_loss: -3.0524e+03
# Epoch 62/100
# 3s - loss: -3.0532e+03 - val_loss: -3.0547e+03
# Epoch 63/100
# 4s - loss: -3.0626e+03 - val_loss: -3.0614e+03
# Epoch 64/100
# 3s - loss: -3.0718e+03 - val_loss: -3.0725e+03
# Epoch 65/100
# 3s - loss: -3.0738e+03 - val_loss: -3.0798e+03
# Epoch 66/100
# 3s - loss: -3.0821e+03 - val_loss: -3.0826e+03
# Epoch 67/100
# 3s - loss: -3.0828e+03 - val_loss: -3.0830e+03
# Epoch 68/100
# 3s - loss: -3.0822e+03 - val_loss: -3.0836e+03
# Epoch 69/100
# 3s - loss: -3.0891e+03 - val_loss: -3.0921e+03
# Epoch 70/100
# 3s - loss: -3.0926e+03 - val_loss: -3.0931e+03
# Epoch 71/100
# 3s - loss: -3.0928e+03 - val_loss: -3.0929e+03
# Epoch 72/100
# 3s - loss: -3.0930e+03 - val_loss: -3.0931e+03
# Epoch 73/100
# 3s - loss: -3.0928e+03 - val_loss: -3.0936e+03
# Epoch 74/100
# 3s - loss: -3.0927e+03 - val_loss: -3.0930e+03
# Epoch 75/100
# 3s - loss: -3.0924e+03 - val_loss: -3.0913e+03
# Epoch 76/100
# 3s - loss: -3.0921e+03 - val_loss: -3.0931e+03
# Epoch 77/100
# 3s - loss: -3.0934e+03 - val_loss: -3.0937e+03
# Epoch 78/100
# 3s - loss: -3.0940e+03 - val_loss: -3.0943e+03
# Epoch 79/100
# 3s - loss: -3.0948e+03 - val_loss: -3.1028e+03
# Epoch 80/100
# 3s - loss: -3.1005e+03 - val_loss: -3.1015e+03
# Epoch 81/100
# 3s - loss: -3.1021e+03 - val_loss: -3.1027e+03
# Epoch 82/100
# 3s - loss: -3.1030e+03 - val_loss: -3.1027e+03
# Epoch 83/100
# 3s - loss: -3.1024e+03 - val_loss: -3.1027e+03
# Epoch 84/100
# 3s - loss: -3.1032e+03 - val_loss: -3.1034e+03
# Epoch 85/100
# 3s - loss: -3.1032e+03 - val_loss: -3.1030e+03
# Epoch 86/100
# 3s - loss: -3.1035e+03 - val_loss: -3.1036e+03
# Epoch 87/100
# 3s - loss: -3.1032e+03 - val_loss: -3.1032e+03
# Epoch 88/100
# 3s - loss: -3.1035e+03 - val_loss: -3.1042e+03
# Epoch 89/100
# 3s - loss: -3.1038e+03 - val_loss: -3.1036e+03
# Epoch 90/100
# 3s - loss: -3.1040e+03 - val_loss: -3.1039e+03
# Epoch 91/100
# 3s - loss: -3.1035e+03 - val_loss: -3.1034e+03
# Epoch 92/100
# 3s - loss: -3.1030e+03 - val_loss: -3.1036e+03
# Epoch 93/100
# 3s - loss: -3.1039e+03 - val_loss: -3.1043e+03
# Epoch 94/100
# 1s - loss: -3.1040e+03 - val_loss: -3.1037e+03
# Epoch 95/100
# 2s - loss: -3.1040e+03 - val_loss: -3.1049e+03
# Epoch 96/100
# 3s - loss: -3.1083e+03 - val_loss: -3.1143e+03
# Epoch 97/100
# 3s - loss: -3.1139e+03 - val_loss: -3.1136e+03
# Epoch 98/100
# 3s - loss: -3.1128e+03 - val_loss: -3.1125e+03
# Epoch 99/100
# 3s - loss: -3.1128e+03 - val_loss: -3.1112e+03
# Epoch 100/100
# 3s - loss: -3.1060e+03 - val_loss: -3.1097e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =995
# SourceData's aborting data = 22
# window shape is (995, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=256-l1_reg=1
# Train on 995 samples, validate on 995 samples
# Epoch 1/100
# 1s - loss: -2.0587e+03 - val_loss: -2.2647e+03
# Epoch 2/100
# 2s - loss: -2.3250e+03 - val_loss: -2.4091e+03
# Epoch 3/100
# 2s - loss: -2.4432e+03 - val_loss: -2.4741e+03
# Epoch 4/100
# 2s - loss: -2.4844e+03 - val_loss: -2.5172e+03
# Epoch 5/100
# 2s - loss: -2.5344e+03 - val_loss: -2.5510e+03
# Epoch 6/100
# 2s - loss: -2.5651e+03 - val_loss: -2.5925e+03
# Epoch 7/100
# 2s - loss: -2.6018e+03 - val_loss: -2.6041e+03
# Epoch 8/100
# 2s - loss: -2.6003e+03 - val_loss: -2.6123e+03
# Epoch 9/100
# 2s - loss: -2.6236e+03 - val_loss: -2.6384e+03
# Epoch 10/100
# 2s - loss: -2.6431e+03 - val_loss: -2.6479e+03
# Epoch 11/100
# 2s - loss: -2.6532e+03 - val_loss: -2.6576e+03
# Epoch 12/100
# 2s - loss: -2.6617e+03 - val_loss: -2.6655e+03
# Epoch 13/100
# 2s - loss: -2.6673e+03 - val_loss: -2.6743e+03
# Epoch 14/100
# 2s - loss: -2.6768e+03 - val_loss: -2.6785e+03
# Epoch 15/100
# 3s - loss: -2.6805e+03 - val_loss: -2.6890e+03
# Epoch 16/100
# 3s - loss: -2.6971e+03 - val_loss: -2.6999e+03
# Epoch 17/100
# 3s - loss: -2.7066e+03 - val_loss: -2.7083e+03
# Epoch 18/100
# 3s - loss: -2.7146e+03 - val_loss: -2.7168e+03
# Epoch 19/100
# 3s - loss: -2.7203e+03 - val_loss: -2.7251e+03
# Epoch 20/100
# 3s - loss: -2.7285e+03 - val_loss: -2.7433e+03
# Epoch 21/100
# 3s - loss: -2.7466e+03 - val_loss: -2.7607e+03
# Epoch 22/100
# 3s - loss: -2.7595e+03 - val_loss: -2.7609e+03
# Epoch 23/100
# 3s - loss: -2.7721e+03 - val_loss: -2.7777e+03
# Epoch 24/100
# 3s - loss: -2.7785e+03 - val_loss: -2.7790e+03
# Epoch 25/100
# 3s - loss: -2.7793e+03 - val_loss: -2.7757e+03
# Epoch 26/100
# 3s - loss: -2.7860e+03 - val_loss: -2.7882e+03
# Epoch 27/100
# 3s - loss: -2.7882e+03 - val_loss: -2.7952e+03
# Epoch 28/100
# 3s - loss: -2.7942e+03 - val_loss: -2.7990e+03
# Epoch 29/100
# 3s - loss: -2.8042e+03 - val_loss: -2.8052e+03
# Epoch 30/100
# 3s - loss: -2.8056e+03 - val_loss: -2.8061e+03
# Epoch 31/100
# 3s - loss: -2.8043e+03 - val_loss: -2.8055e+03
# Epoch 32/100
# 3s - loss: -2.8073e+03 - val_loss: -2.8083e+03
# Epoch 33/100
# 3s - loss: -2.8088e+03 - val_loss: -2.8096e+03
# Epoch 34/100
# 3s - loss: -2.8154e+03 - val_loss: -2.8178e+03
# Epoch 35/100
# 3s - loss: -2.8184e+03 - val_loss: -2.8192e+03
# Epoch 36/100
# 3s - loss: -2.8182e+03 - val_loss: -2.8350e+03
# Epoch 37/100
# 3s - loss: -2.8432e+03 - val_loss: -2.8525e+03
# Epoch 38/100
# 3s - loss: -2.8662e+03 - val_loss: -2.8691e+03
# Epoch 39/100
# 3s - loss: -2.8697e+03 - val_loss: -2.8706e+03
# Epoch 40/100
# 3s - loss: -2.8757e+03 - val_loss: -2.8792e+03
# Epoch 41/100
# 2s - loss: -2.8792e+03 - val_loss: -2.8790e+03
# Epoch 42/100
# 2s - loss: -2.8732e+03 - val_loss: -2.8708e+03
# Epoch 43/100
# 2s - loss: -2.8714e+03 - val_loss: -2.8722e+03
# Epoch 44/100
# 2s - loss: -2.8726e+03 - val_loss: -2.8730e+03
# Epoch 45/100
# 2s - loss: -2.8738e+03 - val_loss: -2.8749e+03
# Epoch 46/100
# 2s - loss: -2.8856e+03 - val_loss: -2.8894e+03
# Epoch 47/100
# 2s - loss: -2.8892e+03 - val_loss: -2.8894e+03
# Epoch 48/100
# 2s - loss: -2.8897e+03 - val_loss: -2.8902e+03
# Epoch 49/100
# 2s - loss: -2.8902e+03 - val_loss: -2.8906e+03
# Epoch 50/100
# 2s - loss: -2.8907e+03 - val_loss: -2.8918e+03
# Epoch 51/100
# 2s - loss: -2.8986e+03 - val_loss: -2.8988e+03
# Epoch 52/100
# 2s - loss: -2.9037e+03 - val_loss: -2.9085e+03
# Epoch 53/100
# 2s - loss: -2.9089e+03 - val_loss: -2.9095e+03
# Epoch 54/100
# 2s - loss: -2.9106e+03 - val_loss: -2.9196e+03
# Epoch 55/100
# 1s - loss: -2.9264e+03 - val_loss: -2.9273e+03
# Epoch 56/100
# 1s - loss: -2.9273e+03 - val_loss: -2.9270e+03
# Epoch 57/100
# 0s - loss: -2.9273e+03 - val_loss: -2.9274e+03
# Epoch 58/100
# 0s - loss: -2.9279e+03 - val_loss: -2.9281e+03
# Epoch 59/100
# 1s - loss: -2.9281e+03 - val_loss: -2.9280e+03
# Epoch 60/100
# 2s - loss: -2.9281e+03 - val_loss: -2.9284e+03
# Epoch 61/100
# 2s - loss: -2.9284e+03 - val_loss: -2.9286e+03
# Epoch 62/100
# 2s - loss: -2.9286e+03 - val_loss: -2.9288e+03
# Epoch 63/100
# 2s - loss: -2.9289e+03 - val_loss: -2.9292e+03
# Epoch 64/100
# 2s - loss: -2.9312e+03 - val_loss: -2.9377e+03
# Epoch 65/100
# 1s - loss: -2.9368e+03 - val_loss: -2.9375e+03
# Epoch 66/100
# 1s - loss: -2.9374e+03 - val_loss: -2.9375e+03
# Epoch 67/100
# 2s - loss: -2.9377e+03 - val_loss: -2.9378e+03
# Epoch 68/100
# 2s - loss: -2.9383e+03 - val_loss: -2.9387e+03
# Epoch 69/100
# 2s - loss: -2.9383e+03 - val_loss: -2.9385e+03
# Epoch 70/100
# 2s - loss: -2.9387e+03 - val_loss: -2.9361e+03
# Epoch 71/100
# 1s - loss: -2.9396e+03 - val_loss: -2.9400e+03
# Epoch 72/100
# 1s - loss: -2.9402e+03 - val_loss: -2.9403e+03
# Epoch 73/100
# 1s - loss: -2.9402e+03 - val_loss: -2.9400e+03
# Epoch 74/100
# 1s - loss: -2.9402e+03 - val_loss: -2.9405e+03
# Epoch 75/100
# 1s - loss: -2.9408e+03 - val_loss: -2.9411e+03
# Epoch 76/100
# 1s - loss: -2.9416e+03 - val_loss: -2.9429e+03
# Epoch 77/100
# 1s - loss: -2.9501e+03 - val_loss: -2.9509e+03
# Epoch 78/100
# 1s - loss: -2.9505e+03 - val_loss: -2.9509e+03
# Epoch 79/100
# 2s - loss: -2.9508e+03 - val_loss: -2.9517e+03
# Epoch 80/100
# 2s - loss: -2.9610e+03 - val_loss: -2.9684e+03
# Epoch 81/100
# 2s - loss: -2.9687e+03 - val_loss: -2.9692e+03
# Epoch 82/100
# 2s - loss: -2.9696e+03 - val_loss: -2.9697e+03
# Epoch 83/100
# 2s - loss: -2.9702e+03 - val_loss: -2.9705e+03
# Epoch 84/100
# 2s - loss: -2.9774e+03 - val_loss: -2.9750e+03
# Epoch 85/100
# 2s - loss: -2.9786e+03 - val_loss: -2.9789e+03
# Epoch 86/100
# 2s - loss: -2.9790e+03 - val_loss: -2.9795e+03
# Epoch 87/100
# 2s - loss: -2.9798e+03 - val_loss: -2.9805e+03
# Epoch 88/100
# 2s - loss: -2.9810e+03 - val_loss: -2.9840e+03
# Epoch 89/100
# 2s - loss: -2.9893e+03 - val_loss: -2.9896e+03
# Epoch 90/100
# 2s - loss: -2.9899e+03 - val_loss: -2.9827e+03
# Epoch 91/100
# 2s - loss: -2.9880e+03 - val_loss: -2.9894e+03
# Epoch 92/100
# 2s - loss: -2.9915e+03 - val_loss: -2.9977e+03
# Epoch 93/100
# 2s - loss: -2.9976e+03 - val_loss: -2.9982e+03
# Epoch 94/100
# 2s - loss: -2.9952e+03 - val_loss: -2.9918e+03
# Epoch 95/100
# 2s - loss: -2.9967e+03 - val_loss: -2.9995e+03
# Epoch 96/100
# 2s - loss: -3.0043e+03 - val_loss: -3.0090e+03
# Epoch 97/100
# 2s - loss: -3.0090e+03 - val_loss: -3.0093e+03
# Epoch 98/100
# 2s - loss: -3.0095e+03 - val_loss: -3.0099e+03
# Epoch 99/100
# 2s - loss: -3.0102e+03 - val_loss: -3.0107e+03
# Epoch 100/100
# 2s - loss: -3.0110e+03 - val_loss: -3.0113e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15890
# SourceData's aborting data = 6
# window shape is (15890, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=16-l1_reg=1
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/100
# 15s - loss: -4.9687e+03 - val_loss: -5.3044e+03
# Epoch 2/100
# 15s - loss: -5.4447e+03 - val_loss: -5.5413e+03
# Epoch 3/100
# 15s - loss: -5.5647e+03 - val_loss: -5.6072e+03
# Epoch 4/100
# 15s - loss: -5.6506e+03 - val_loss: -5.7092e+03
# Epoch 5/100
# 15s - loss: -5.7321e+03 - val_loss: -5.7656e+03
# Epoch 6/100
# 12s - loss: -5.7886e+03 - val_loss: -5.8033e+03
# Epoch 7/100
# 15s - loss: -5.8217e+03 - val_loss: -5.8350e+03
# Epoch 8/100
# 15s - loss: -5.8520e+03 - val_loss: -5.8806e+03
# Epoch 9/100
# 15s - loss: -5.8958e+03 - val_loss: -5.9123e+03
# Epoch 10/100
# 15s - loss: -5.9182e+03 - val_loss: -5.9353e+03
# Epoch 11/100
# 15s - loss: -5.9612e+03 - val_loss: -5.9898e+03
# Epoch 12/100
# 15s - loss: -6.0048e+03 - val_loss: -6.0061e+03
# Epoch 13/100
# 15s - loss: -6.0282e+03 - val_loss: -6.0356e+03
# Epoch 14/100
# 15s - loss: -6.0371e+03 - val_loss: -6.0449e+03
# Epoch 15/100
# 12s - loss: -6.0510e+03 - val_loss: -6.0659e+03
# Epoch 16/100
# 22s - loss: -6.0678e+03 - val_loss: -6.0778e+03
# Epoch 17/100
# 28s - loss: -6.0904e+03 - val_loss: -6.0968e+03
# Epoch 18/100
# 29s - loss: -6.1070e+03 - val_loss: -6.1239e+03
# Epoch 19/100
# 26s - loss: -6.1266e+03 - val_loss: -6.1361e+03
# Epoch 20/100
# 15s - loss: -6.1349e+03 - val_loss: -6.1337e+03
# Epoch 21/100
# 15s - loss: -6.1336e+03 - val_loss: -6.1343e+03
# Epoch 22/100
# 15s - loss: -6.1434e+03 - val_loss: -6.1494e+03
# Epoch 23/100
# 15s - loss: -6.1491e+03 - val_loss: -6.1504e+03
# Epoch 24/100
# 12s - loss: -6.1544e+03 - val_loss: -6.1549e+03
# Epoch 25/100
# 15s - loss: -6.1546e+03 - val_loss: -6.1561e+03
# Epoch 26/100
# 15s - loss: -6.1558e+03 - val_loss: -6.1592e+03
# Epoch 27/100
# 15s - loss: -6.1567e+03 - val_loss: -6.1541e+03
# Epoch 28/100
# 15s - loss: -6.1577e+03 - val_loss: -6.1585e+03
# Epoch 29/100
# 15s - loss: -6.1592e+03 - val_loss: -6.1688e+03
# Epoch 30/100
# 15s - loss: -6.1680e+03 - val_loss: -6.1702e+03
# Epoch 31/100
# 15s - loss: -6.1683e+03 - val_loss: -6.1682e+03
# Epoch 32/100
# 15s - loss: -6.1686e+03 - val_loss: -6.1702e+03
# Epoch 33/100
# 11s - loss: -6.1698e+03 - val_loss: -6.1698e+03
# Epoch 34/100
# 15s - loss: -6.1682e+03 - val_loss: -6.1673e+03
# Epoch 35/100
# 15s - loss: -6.1659e+03 - val_loss: -6.1673e+03
# Epoch 36/100
# 15s - loss: -6.1650e+03 - val_loss: -6.1664e+03
# Epoch 37/100
# 15s - loss: -6.1724e+03 - val_loss: -6.1757e+03
# Epoch 38/100
# 15s - loss: -6.1787e+03 - val_loss: -6.1815e+03
# Epoch 39/100
# 15s - loss: -6.1817e+03 - val_loss: -6.1830e+03
# Epoch 40/100
# 15s - loss: -6.1819e+03 - val_loss: -6.1800e+03
# Epoch 41/100
# 15s - loss: -6.1820e+03 - val_loss: -6.1824e+03
# Epoch 42/100
# 13s - loss: -6.1826e+03 - val_loss: -6.1838e+03
# Epoch 43/100
# 14s - loss: -6.1835e+03 - val_loss: -6.1823e+03
# Epoch 44/100
# 14s - loss: -6.1838e+03 - val_loss: -6.1845e+03
# Epoch 45/100
# 15s - loss: -6.1836e+03 - val_loss: -6.1851e+03
# Epoch 46/100
# 15s - loss: -6.1835e+03 - val_loss: -6.1830e+03
# Epoch 47/100
# 15s - loss: -6.1829e+03 - val_loss: -6.1800e+03
# Epoch 48/100
# 15s - loss: -6.1837e+03 - val_loss: -6.1852e+03
# Epoch 49/100
# 15s - loss: -6.1828e+03 - val_loss: -6.1815e+03
# Epoch 50/100
# 15s - loss: -6.1830e+03 - val_loss: -6.1845e+03
# Epoch 51/100
# 14s - loss: -6.1842e+03 - val_loss: -6.1837e+03
# Epoch 52/100
# 12s - loss: -6.1841e+03 - val_loss: -6.1812e+03
# Epoch 53/100
# 15s - loss: -6.1833e+03 - val_loss: -6.1821e+03
# Epoch 54/100
# 15s - loss: -6.1840e+03 - val_loss: -6.1834e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7945
# SourceData's aborting data = 22
# window shape is (7945, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=32-l1_reg=1
# Train on 7945 samples, validate on 7945 samples
# Epoch 1/100
# 7s - loss: -4.7949e+03 - val_loss: -5.0758e+03
# Epoch 2/100
# 7s - loss: -5.1964e+03 - val_loss: -5.3024e+03
# Epoch 3/100
# 7s - loss: -5.3699e+03 - val_loss: -5.4325e+03
# Epoch 4/100
# 7s - loss: -5.4776e+03 - val_loss: -5.5233e+03
# Epoch 5/100
# 7s - loss: -5.5761e+03 - val_loss: -5.6079e+03
# Epoch 6/100
# 7s - loss: -5.6322e+03 - val_loss: -5.6533e+03
# Epoch 7/100
# 7s - loss: -5.6836e+03 - val_loss: -5.6925e+03
# Epoch 8/100
# 7s - loss: -5.7021e+03 - val_loss: -5.7123e+03
# Epoch 9/100
# 5s - loss: -5.7270e+03 - val_loss: -5.7462e+03
# Epoch 10/100
# 6s - loss: -5.7463e+03 - val_loss: -5.7446e+03
# Epoch 11/100
# 7s - loss: -5.7480e+03 - val_loss: -5.7577e+03
# Epoch 12/100
# 7s - loss: -5.7684e+03 - val_loss: -5.7750e+03
# Epoch 13/100
# 7s - loss: -5.7802e+03 - val_loss: -5.7951e+03
# Epoch 14/100
# 7s - loss: -5.8078e+03 - val_loss: -5.8200e+03
# Epoch 15/100
# 7s - loss: -5.8235e+03 - val_loss: -5.8288e+03
# Epoch 16/100
# 7s - loss: -5.8363e+03 - val_loss: -5.8432e+03
# Epoch 17/100
# 7s - loss: -5.8490e+03 - val_loss: -5.8545e+03
# Epoch 18/100
# 7s - loss: -5.8548e+03 - val_loss: -5.8554e+03
# Epoch 19/100
# 7s - loss: -5.8597e+03 - val_loss: -5.8638e+03
# Epoch 20/100
# 7s - loss: -5.8640e+03 - val_loss: -5.8643e+03
# Epoch 21/100
# 7s - loss: -5.8738e+03 - val_loss: -5.8827e+03
# Epoch 22/100
# 7s - loss: -5.8972e+03 - val_loss: -5.9083e+03
# Epoch 23/100
# 7s - loss: -5.9144e+03 - val_loss: -5.9172e+03
# Epoch 24/100
# 7s - loss: -5.9212e+03 - val_loss: -5.9255e+03
# Epoch 25/100
# 7s - loss: -5.9259e+03 - val_loss: -5.9266e+03
# Epoch 26/100
# 7s - loss: -5.9268e+03 - val_loss: -5.9270e+03
# Epoch 27/100
# 6s - loss: -5.9315e+03 - val_loss: -5.9317e+03
# Epoch 28/100
# 6s - loss: -5.9365e+03 - val_loss: -5.9370e+03
# Epoch 29/100
# 7s - loss: -5.9370e+03 - val_loss: -5.9375e+03
# Epoch 30/100
# 7s - loss: -5.9463e+03 - val_loss: -5.9551e+03
# Epoch 31/100
# 7s - loss: -5.9556e+03 - val_loss: -5.9575e+03
# Epoch 32/100
# 7s - loss: -5.9705e+03 - val_loss: -5.9751e+03
# Epoch 33/100
# 7s - loss: -5.9751e+03 - val_loss: -5.9762e+03
# Epoch 34/100
# 7s - loss: -5.9770e+03 - val_loss: -5.9869e+03
# Epoch 35/100
# 7s - loss: -5.9913e+03 - val_loss: -6.0041e+03
# Epoch 36/100
# 7s - loss: -6.0074e+03 - val_loss: -6.0125e+03
# Epoch 37/100
# 7s - loss: -6.0152e+03 - val_loss: -6.0254e+03
# Epoch 38/100
# 7s - loss: -6.0401e+03 - val_loss: -6.0434e+03
# Epoch 39/100
# 7s - loss: -6.0491e+03 - val_loss: -6.0526e+03
# Epoch 40/100
# 7s - loss: -6.0544e+03 - val_loss: -6.0561e+03
# Epoch 41/100
# 7s - loss: -6.0555e+03 - val_loss: -6.0592e+03
# Epoch 42/100
# 7s - loss: -4.9152e+03 - val_loss: -5.1083e+03
# Epoch 43/100
# 7s - loss: -5.4323e+03 - val_loss: -5.6678e+03
# Epoch 44/100
# 7s - loss: -5.7894e+03 - val_loss: -5.8639e+03
# Epoch 45/100
# 6s - loss: -5.8964e+03 - val_loss: -5.9199e+03
# Epoch 46/100
# 5s - loss: -5.9468e+03 - val_loss: -5.9652e+03
# Epoch 47/100
# 7s - loss: -5.9736e+03 - val_loss: -5.9893e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =3973
# SourceData's aborting data = 22
# window shape is (3973, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=64-l1_reg=1
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 3s - loss: -4.5920e+03 - val_loss: -4.8811e+03
# Epoch 2/100
# 3s - loss: -4.9850e+03 - val_loss: -5.0875e+03
# Epoch 3/100
# 4s - loss: -5.1693e+03 - val_loss: -5.2330e+03
# Epoch 4/100
# 3s - loss: -5.2711e+03 - val_loss: -5.2915e+03
# Epoch 5/100
# 3s - loss: -5.3622e+03 - val_loss: -5.3947e+03
# Epoch 6/100
# 3s - loss: -5.4301e+03 - val_loss: -5.4730e+03
# Epoch 7/100
# 3s - loss: -5.4879e+03 - val_loss: -5.5089e+03
# Epoch 8/100
# 3s - loss: -5.5238e+03 - val_loss: -5.5354e+03
# Epoch 9/100
# 3s - loss: -5.5481e+03 - val_loss: -5.5678e+03
# Epoch 10/100
# 4s - loss: -5.5920e+03 - val_loss: -5.6031e+03
# Epoch 11/100
# 3s - loss: -5.6161e+03 - val_loss: -5.6374e+03
# Epoch 12/100
# 3s - loss: -5.6494e+03 - val_loss: -5.5672e+03
# Epoch 13/100
# 3s - loss: -5.6495e+03 - val_loss: -5.6509e+03
# Epoch 14/100
# 3s - loss: -5.6739e+03 - val_loss: -5.6775e+03
# Epoch 15/100
# 3s - loss: -5.6826e+03 - val_loss: -5.6908e+03
# Epoch 16/100
# 4s - loss: -5.7043e+03 - val_loss: -5.7075e+03
# Epoch 17/100
# 3s - loss: -5.7069e+03 - val_loss: -5.7061e+03
# Epoch 18/100
# 4s - loss: -5.7209e+03 - val_loss: -5.7306e+03
# Epoch 19/100
# 3s - loss: -5.7304e+03 - val_loss: -5.7312e+03
# Epoch 20/100
# 3s - loss: -5.7318e+03 - val_loss: -5.7329e+03
# Epoch 21/100
# 3s - loss: -5.7329e+03 - val_loss: -5.7348e+03
# Epoch 22/100
# 3s - loss: -5.7430e+03 - val_loss: -5.7473e+03
# Epoch 23/100
# 3s - loss: -5.7504e+03 - val_loss: -5.7501e+03
# Epoch 24/100
# 3s - loss: -5.7569e+03 - val_loss: -5.7595e+03
# Epoch 25/100
# 3s - loss: -5.7635e+03 - val_loss: -5.7698e+03
# Epoch 26/100
# 3s - loss: -5.7781e+03 - val_loss: -5.7875e+03
# Epoch 27/100
# 3s - loss: -5.7936e+03 - val_loss: -5.8043e+03
# Epoch 28/100
# 3s - loss: -5.8043e+03 - val_loss: -5.8014e+03
# Epoch 29/100
# 3s - loss: -5.8123e+03 - val_loss: -5.8132e+03
# Epoch 30/100
# 2s - loss: -5.8132e+03 - val_loss: -5.8141e+03
# Epoch 31/100
# 3s - loss: -5.8144e+03 - val_loss: -5.8147e+03
# Epoch 32/100
# 3s - loss: -5.8148e+03 - val_loss: -5.8147e+03
# Epoch 33/100
# 4s - loss: -5.8149e+03 - val_loss: -5.8161e+03
# Epoch 34/100
# 3s - loss: -5.8159e+03 - val_loss: -5.8164e+03
# Epoch 35/100
# 4s - loss: -5.8181e+03 - val_loss: -5.8204e+03
# Epoch 36/100
# 3s - loss: -5.8233e+03 - val_loss: -5.8263e+03
# Epoch 37/100
# 3s - loss: -5.8275e+03 - val_loss: -5.8289e+03
# Epoch 38/100
# ...
# Epoch 71/100
# 1s - loss: -5.7187e+03 - val_loss: -5.7158e+03
# Epoch 72/100
# 1s - loss: -5.7163e+03 - val_loss: -5.7205e+03
# Epoch 73/100
# 1s - loss: -5.7203e+03 - val_loss: -5.7206e+03
# Epoch 74/100
# 1s - loss: -5.7202e+03 - val_loss: -5.7207e+03
# Epoch 75/100
# 1s - loss: -5.7203e+03 - val_loss: -5.7185e+03
# Epoch 76/100
# 1s - loss: -5.7202e+03 - val_loss: -5.7209e+03
# Epoch 77/100
# 1s - loss: -5.7208e+03 - val_loss: -5.7210e+03
# Epoch 78/100
# 1s - loss: -5.7206e+03 - val_loss: -5.7215e+03
# Epoch 79/100
# 1s - loss: -5.7217e+03 - val_loss: -5.7220e+03
# Epoch 80/100
# 1s - loss: -5.7221e+03 - val_loss: -5.7226e+03
# Epoch 81/100
# 1s - loss: -5.7223e+03 - val_loss: -5.7199e+03
# Epoch 82/100
# 1s - loss: -5.7220e+03 - val_loss: -5.7230e+03
# Epoch 83/100
# 1s - loss: -5.7222e+03 - val_loss: -5.7238e+03
# Epoch 84/100
# 1s - loss: -5.7285e+03 - val_loss: -5.7313e+03
# Epoch 85/100
# 1s - loss: -5.7364e+03 - val_loss: -5.7383e+03
# Epoch 86/100
# 1s - loss: -5.7379e+03 - val_loss: -5.7367e+03
# Epoch 87/100
# 1s - loss: -5.7377e+03 - val_loss: -5.7383e+03
# Epoch 88/100
# 1s - loss: -5.7379e+03 - val_loss: -5.7384e+03
# Epoch 89/100
# 1s - loss: -5.7381e+03 - val_loss: -5.7385e+03
# Epoch 90/100
# 1s - loss: -5.7385e+03 - val_loss: -5.7391e+03
# Epoch 91/100
# 1s - loss: -5.7421e+03 - val_loss: -5.7470e+03
# Epoch 92/100
# 1s - loss: -5.7470e+03 - val_loss: -5.7438e+03
# Epoch 93/100
# 1s - loss: -5.7472e+03 - val_loss: -5.7481e+03
# Epoch 94/100
# 1s - loss: -5.7472e+03 - val_loss: -5.7486e+03
# Epoch 95/100
# 1s - loss: -5.7537e+03 - val_loss: -5.7565e+03
# Epoch 96/100
# 1s - loss: -5.7610e+03 - val_loss: -5.7642e+03
# Epoch 97/100
# 0s - loss: -5.7636e+03 - val_loss: -5.7643e+03
# Epoch 98/100
# 0s - loss: -5.7645e+03 - val_loss: -5.7660e+03
# Epoch 99/100
# 0s - loss: -5.7702e+03 - val_loss: -5.7719e+03
# Epoch 100/100
# 0s - loss: -5.7714e+03 - val_loss: -5.7719e+03
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15858
# SourceData's aborting data = 6
# window shape is (15858, 1024, 1)
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-l1_reg=1
# Train on 15858 samples, validate on 15858 samples
# Epoch 1/100
# 8s - loss: -9.3269e+03 - val_loss: -9.9342e+03
# Epoch 2/100
# 8s - loss: -1.0186e+04 - val_loss: -1.0402e+04
# Epoch 3/100
# 8s - loss: -1.0527e+04 - val_loss: -1.0602e+04
# Epoch 4/100
# 8s - loss: -1.0666e+04 - val_loss: -1.0727e+04
# Epoch 5/100
# 8s - loss: -1.0785e+04 - val_loss: -1.0833e+04
# Epoch 6/100
# 8s - loss: -1.0856e+04 - val_loss: -1.0882e+04
# Epoch 7/100
# 8s - loss: -1.0900e+04 - val_loss: -1.0908e+04
# Epoch 8/100
# 8s - loss: -1.0908e+04 - val_loss: -1.0910e+04
# Epoch 9/100
# 8s - loss: -1.0925e+04 - val_loss: -1.0951e+04
# Epoch 10/100
# 8s - loss: -1.0954e+04 - val_loss: -1.0962e+04
# Epoch 11/100
# 8s - loss: -1.0971e+04 - val_loss: -1.0984e+04
# Epoch 12/100
# 8s - loss: -1.0987e+04 - val_loss: -1.0990e+04
# Epoch 13/100
# 8s - loss: -1.0994e+04 - val_loss: -1.1002e+04
# Epoch 14/100
# 8s - loss: -1.1018e+04 - val_loss: -1.1042e+04
# Epoch 15/100
# 8s - loss: -1.1049e+04 - val_loss: -1.1055e+04
# Epoch 16/100
# 7s - loss: -1.1066e+04 - val_loss: -1.1073e+04
# Epoch 17/100
# 6s - loss: -1.1077e+04 - val_loss: -1.1084e+04
# Epoch 18/100
# 8s - loss: -1.1100e+04 - val_loss: -1.1108e+04
# Epoch 19/100
# 8s - loss: -1.1112e+04 - val_loss: -1.1125e+04
# Epoch 20/100
# 8s - loss: -1.1134e+04 - val_loss: -1.1138e+04
# Epoch 21/100
# 8s - loss: -1.1144e+04 - val_loss: -1.1153e+04
# Epoch 22/100
# 8s - loss: -1.1153e+04 - val_loss: -1.1152e+04
# Epoch 23/100
# 8s - loss: -1.1157e+04 - val_loss: -1.1171e+04
# Epoch 24/100
# 8s - loss: -1.1174e+04 - val_loss: -1.1187e+04
# Epoch 25/100
# 8s - loss: -1.1195e+04 - val_loss: -1.1203e+04
# Epoch 26/100
# 8s - loss: -1.1211e+04 - val_loss: -1.1223e+04
# Epoch 27/100
# 8s - loss: -1.1227e+04 - val_loss: -1.1235e+04
# Epoch 28/100
# 8s - loss: -1.1236e+04 - val_loss: -1.1238e+04
# Epoch 29/100
# 8s - loss: -1.1248e+04 - val_loss: -1.1255e+04
# Epoch 30/100
# 8s - loss: -1.1268e+04 - val_loss: -1.1277e+04
# Epoch 31/100
# 8s - loss: -1.1279e+04 - val_loss: -1.1288e+04
# Epoch 32/100
# 8s - loss: -1.1294e+04 - val_loss: -1.1297e+04
# Epoch 33/100
# 8s - loss: -1.1308e+04 - val_loss: -1.1321e+04
# Epoch 34/100
# 4s - loss: -1.1324e+04 - val_loss: -1.1331e+04
# Epoch 35/100
# 8s - loss: -1.1345e+04 - val_loss: -1.1354e+04
# Epoch 36/100
# 8s - loss: -1.1359e+04 - val_loss: -1.1365e+04
# Epoch 37/100
# 8s - loss: -1.1372e+04 - val_loss: -1.1378e+04
# Epoch 38/100
# 8s - loss: -1.1392e+04 - val_loss: -1.1395e+04
# Epoch 39/100
# 8s - loss: -1.1403e+04 - val_loss: -1.1420e+04
# Epoch 40/100
# 8s - loss: -1.1428e+04 - val_loss: -1.1437e+04
# Epoch 41/100
# 8s - loss: -1.1444e+04 - val_loss: -1.1453e+04
# Epoch 42/100
# 8s - loss: -1.1459e+04 - val_loss: -1.1464e+04
# Epoch 43/100
# 8s - loss: -1.1473e+04 - val_loss: -1.1488e+04
# Epoch 44/100
# 8s - loss: -1.1500e+04 - val_loss: -1.1513e+04
# Epoch 45/100
# 8s - loss: -1.1520e+04 - val_loss: -1.1521e+04
# Epoch 46/100
# 8s - loss: -1.1522e+04 - val_loss: -1.1523e+04
# Epoch 47/100
# 8s - loss: -1.1523e+04 - val_loss: -1.1525e+04
# Epoch 48/100
# 8s - loss: -1.1537e+04 - val_loss: -1.1543e+04
# Epoch 49/100
# 8s - loss: -1.1551e+04 - val_loss: -1.1565e+04
# Epoch 50/100
# 7s - loss: -1.1565e+04 - val_loss: -1.1567e+04
# Epoch 51/100
# 6s - loss: -1.1573e+04 - val_loss: -1.1575e+04
# Epoch 52/100
# 6s - loss: -1.1580e+04 - val_loss: -1.1591e+04
# Epoch 53/100
# 8s - loss: -1.1595e+04 - val_loss: -1.1601e+04
# Epoch 54/100
# 8s - loss: -1.1614e+04 - val_loss: -1.1632e+04
# Epoch 55/100
# 8s - loss: -1.1638e+04 - val_loss: -1.1641e+04
# Epoch 56/100
# 8s - loss: -1.1646e+04 - val_loss: -1.1658e+04
# Epoch 57/100
# 8s - loss: -1.1667e+04 - val_loss: -1.1674e+04
# Epoch 58/100
# 8s - loss: -1.1674e+04 - val_loss: -1.1674e+04
# Epoch 59/100
# 8s - loss: -1.1689e+04 - val_loss: -1.1690e+04
# Epoch 60/100
# 8s - loss: -1.1698e+04 - val_loss: -1.1699e+04
# Epoch 61/100
# 8s - loss: -1.1699e+04 - val_loss: -1.1702e+04
# Epoch 62/100
# 8s - loss: -1.1708e+04 - val_loss: -1.1707e+04
# Epoch 63/100
# 8s - loss: -1.1720e+04 - val_loss: -1.1729e+04
# Epoch 64/100
# 8s - loss: -1.1742e+04 - val_loss: -1.1748e+04
# Epoch 65/100
# 8s - loss: -1.1757e+04 - val_loss: -1.1766e+04
# Epoch 66/100
# 8s - loss: -1.1768e+04 - val_loss: -1.1773e+04
# Epoch 67/100
# 8s - loss: -1.1777e+04 - val_loss: -1.1779e+04
# Epoch 68/100
# 8s - loss: -1.1781e+04 - val_loss: -1.1783e+04
# Epoch 69/100
# 4s - loss: -1.1779e+04 - val_loss: -1.1767e+04
# Epoch 70/100
# 8s - loss: -1.1768e+04 - val_loss: -1.1780e+04
# Epoch 71/100
# 8s - loss: -9.7008e+03 - val_loss: -1.0518e+04
# Epoch 72/100
# 8s - loss: -1.0933e+04 - val_loss: -1.1344e+04
# Epoch 73/100
# 8s - loss: -1.1509e+04 - val_loss: -1.1610e+04
# Epoch 74/100
# 8s - loss: -1.1642e+04 - val_loss: -1.1664e+04
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =7929
# SourceData's aborting data = 22
# window shape is (7929, 1024, 1)
# hiden node = 16
# -edim=16-Window=1024-Overlap=32-l1_reg=1
# Train on 7929 samples, validate on 7929 samples
# Epoch 1/100
# 4s - loss: -8.9069e+03 - val_loss: -9.4417e+03
# Epoch 2/100
# 4s - loss: -9.7177e+03 - val_loss: -9.9527e+03
# Epoch 3/100
# 4s - loss: -1.0085e+04 - val_loss: -1.0204e+04
# Epoch 4/100
# 4s - loss: -1.0306e+04 - val_loss: -1.0377e+04
# Epoch 5/100
# 4s - loss: -1.0442e+04 - val_loss: -1.0496e+04
# Epoch 6/100
# 4s - loss: -1.0531e+04 - val_loss: -1.0559e+04
# Epoch 7/100
# 4s - loss: -1.0592e+04 - val_loss: -1.0618e+04
# Epoch 8/100
# 3s - loss: -1.0637e+04 - val_loss: -1.0654e+04
# Epoch 9/100
# 4s - loss: -1.0674e+04 - val_loss: -1.0684e+04
# Epoch 10/100
# 4s - loss: -1.0690e+04 - val_loss: -1.0705e+04
# Epoch 11/100
# 4s - loss: -1.0714e+04 - val_loss: -1.0731e+04
# Epoch 12/100
# 3s - loss: -1.0748e+04 - val_loss: -1.0762e+04
# Epoch 13/100
# 3s - loss: -1.0779e+04 - val_loss: -1.0791e+04
# Epoch 14/100
# 3s - loss: -1.0805e+04 - val_loss: -1.0821e+04
# Epoch 15/100
# 2s - loss: -1.0830e+04 - val_loss: -1.0839e+04
# Epoch 16/100
# 1s - loss: -1.0852e+04 - val_loss: -1.0863e+04
# Epoch 17/100
# 0s - loss: -1.0876e+04 - val_loss: -1.0882e+04
# Epoch 18/100
# 2s - loss: -1.0883e+04 - val_loss: -1.0885e+04
# Epoch 19/100
# 3s - loss: -1.0897e+04 - val_loss: -1.0909e+04
# Epoch 20/100
# 5s - loss: -1.0912e+04 - val_loss: -1.0919e+04
# Epoch 21/100
# 2s - loss: -1.0925e+04 - val_loss: -1.0930e+04
# Epoch 22/100
# 2s - loss: -1.0938e+04 - val_loss: -1.0947e+04
# Epoch 23/100
# 2s - loss: -1.0947e+04 - val_loss: -1.0948e+04
# Epoch 24/100
# 2s - loss: -1.0947e+04 - val_loss: -1.0945e+04
# Epoch 25/100
# 2s - loss: -1.0962e+04 - val_loss: -1.0965e+04
# Epoch 26/100
# 2s - loss: -1.0965e+04 - val_loss: -1.0965e+04
# Epoch 27/100
# 2s - loss: -1.0969e+04 - val_loss: -1.0974e+04
# Epoch 28/100
# 2s - loss: -1.0975e+04 - val_loss: -1.0977e+04
# Epoch 29/100
# 2s - loss: -1.0977e+04 - val_loss: -1.0979e+04
# Epoch 30/100
# 2s - loss: -1.0986e+04 - val_loss: -1.0989e+04
# Epoch 31/100
# 2s - loss: -1.0998e+04 - val_loss: -1.1004e+04
# Epoch 32/100
# 2s - loss: -1.1008e+04 - val_loss: -1.1013e+04
# Epoch 33/100
# 2s - loss: -1.1021e+04 - val_loss: -1.1037e+04
# Epoch 34/100
# 2s - loss: -1.1045e+04 - val_loss: -1.1060e+04
# Epoch 35/100
# 2s - loss: -1.1063e+04 - val_loss: -1.1066e+04
# Epoch 36/100
# 2s - loss: -1.1076e+04 - val_loss: -1.1081e+04
# Epoch 37/100
# 3s - loss: -1.1087e+04 - val_loss: -1.1088e+04
# Epoch 38/100
# 4s - loss: -1.1093e+04 - val_loss: -1.1099e+04
# Epoch 39/100
# 4s - loss: -1.1106e+04 - val_loss: -1.1106e+04
# Epoch 40/100
# 4s - loss: -1.1116e+04 - val_loss: -1.1123e+04
# Epoch 41/100
# 4s - loss: -1.1128e+04 - val_loss: -1.1132e+04
# Epoch 42/100
# 4s - loss: -1.1137e+04 - val_loss: -1.1141e+04
# Epoch 43/100
# 4s - loss: -1.1149e+04 - val_loss: -1.1157e+04
# Epoch 44/100
# 4s - loss: -1.1163e+04 - val_loss: -1.1171e+04
# Epoch 45/100
# 4s - loss: -1.1174e+04 - val_loss: -1.1180e+04
# Epoch 46/100
# 4s - loss: -1.1180e+04 - val_loss: -1.1181e+04
# Epoch 47/100
# 4s - loss: -1.1181e+04 - val_loss: -1.1182e+04
# Epoch 48/100
# 4s - loss: -1.1183e+04 - val_loss: -1.1182e+04
# Epoch 49/100
# 4s - loss: -1.1185e+04 - val_loss: -1.1191e+04
# Epoch 50/100
# 4s - loss: -1.1217e+04 - val_loss: -1.1223e+04
# Epoch 51/100
# 4s - loss: -1.1235e+04 - val_loss: -1.1244e+04
# Epoch 52/100
# 4s - loss: -1.1245e+04 - val_loss: -1.1244e+04
# Epoch 53/100
# 3s - loss: -1.1251e+04 - val_loss: -1.1259e+04
# Epoch 54/100
# 2s - loss: -1.1260e+04 - val_loss: -1.1261e+04
# Epoch 55/100
# 2s - loss: -1.1266e+04 - val_loss: -1.1270e+04
# Epoch 56/100
# 2s - loss: -1.1271e+04 - val_loss: -1.1272e+04
# Epoch 57/100
# 2s - loss: -1.1278e+04 - val_loss: -1.1280e+04
# Epoch 58/100
# 2s - loss: -1.1282e+04 - val_loss: -1.1289e+04
# Epoch 59/100
# 2s - loss: -1.1291e+04 - val_loss: -1.1297e+04
# Epoch 60/100
# 2s - loss: -1.1303e+04 - val_loss: -1.1306e+04
# Epoch 61/100
# 2s - loss: -1.1313e+04 - val_loss: -1.1323e+04
# Epoch 62/100
# 2s - loss: -1.1330e+04 - val_loss: -1.1338e+04
# Epoch 63/100
# 2s - loss: -1.1352e+04 - val_loss: -1.1356e+04
# Epoch 64/100
# 2s - loss: -1.1362e+04 - val_loss: -1.1368e+04
# Epoch 65/100
# 2s - loss: -1.1368e+04 - val_loss: -1.1369e+04
# Epoch 66/100
# 2s - loss: -1.1374e+04 - val_loss: -1.1376e+04
# Epoch 67/100
# 2s - loss: -1.1381e+04 - val_loss: -1.1385e+04
# Epoch 68/100
# 2s - loss: -1.1384e+04 - val_loss: -1.1384e+04
# Epoch 69/100
# 2s - loss: -1.1384e+04 - val_loss: -1.1386e+04
# Epoch 70/100
# 2s - loss: -1.1386e+04 - val_loss: -1.1394e+04
# Epoch 71/100
# 2s - loss: -1.1394e+04 - val_loss: -1.1395e+04
# Epoch 72/100
# 2s - loss: -1.1395e+04 - val_loss: -1.1395e+04
# Epoch 73/100
# 2s - loss: -1.1396e+04 - val_loss: -1.1397e+04
# Epoch 74/100
# 2s - loss: -1.1403e+04 - val_loss: -1.1405e+04
# Epoch 75/100
# 2s - loss: -1.1409e+04 - val_loss: -1.1411e+04
# Epoch 76/100
# 2s - loss: -1.1410e+04 - val_loss: -1.1411e+04
# Epoch 77/100
# 2s - loss: -1.1417e+04 - val_loss: -1.1420e+04
# Epoch 78/100
# 3s - loss: -1.1425e+04 - val_loss: -1.1429e+04
# Epoch 79/100
# 4s - loss: -1.1427e+04 - val_loss: -1.1424e+04
# Epoch 80/100
# 4s - loss: -1.1431e+04 - val_loss: -1.1436e+04
# Epoch 81/100
# 4s - loss: -1.1436e+04 - val_loss: -1.1437e+04
# Epoch 82/100
# 4s - loss: -1.1437e+04 - val_loss: -1.1439e+04
# Epoch 83/100
# 4s - loss: -1.1446e+04 - val_loss: -1.1453e+04
# Epoch 84/100
# 4s - loss: -1.1452e+04 - val_loss: -1.1452e+04
# Epoch 85/100
# 4s - loss: -1.1460e+04 - val_loss: -1.1462e+04
# Epoch 86/100
# 4s - loss: -1.1463e+04 - val_loss: -1.1464e+04
# Epoch 87/100
# 4s - loss: -1.1469e+04 - val_loss: -1.1471e+04
# Epoch 88/100
# 4s - loss: -1.1472e+04 - val_loss: -1.1473e+04
# Epoch 89/100
# 4s - loss: -1.1473e+04 - val_loss: -1.1474e+04
# Epoch 90/100
# 4s - loss: -1.1481e+04 - val_loss: -1.1482e+04
# Epoch 91/100
# 4s - loss: -1.1489e+04 - val_loss: -1.1490e+04
# Epoch 92/100
# 4s - loss: -1.1491e+04 - val_loss: -1.1492e+04
# Epoch 93/100
# 4s - loss: -1.1496e+04 - val_loss: -1.1499e+04
# Epoch 94/100
# 4s - loss: -1.1500e+04 - val_loss: -1.1501e+04
# Epoch 95/100
# 4s - loss: -1.1506e+04 - val_loss: -1.1507e+04
# Epoch 96/100
# 4s - loss: -1.1508e+04 - val_loss: -1.1516e+04
# Epoch 97/100
# 4s - loss: -1.1518e+04 - val_loss: -1.1524e+04
# Epoch 98/100
# 4s - loss: -1.1524e+04 - val_loss: -1.1531e+04
# Epoch 99/100
# 4s - loss: -1.1532e+04 - val_loss: -1.1533e+04
# Epoch 100/100
# 3s - loss: -1.1534e+04 - val_loss: -1.1535e+04
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-ab097881d91a> in <module>()
#      61                               )
#      62         time.sleep(0.1)
# ---> 63         encoded_imgs = encoder.predict(window_test)
#      64         decoded_imgs = decoder.predict(encoded_imgs)
#      65
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1179         f = self.predict_function
#    1180         return self._predict_loop(f, ins,
# -> 1181                                   batch_size=batch_size, verbose=verbose)
#    1182
#    1183     def train_on_batch(self, x, y,
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#     878                 ins_batch = slice_X(ins, batch_ids)
#     879
# --> 880             batch_outs = f(ins_batch)
#     881             if type(batch_outs) != list:
#     882                 batch_outs = [batch_outs]
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     560     def __call__(self, inputs):
#     561         assert type(inputs) in {list, tuple}
# --> 562         return self.function(*inputs)
#     563
#     564
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     869                     node=self.fn.nodes[self.fn.position_of_error],
#     870                     thunk=thunk,
# --> 871                     storage_map=getattr(self.fn, 'storage_map', None))
#     872             else:
#     873                 # old-style linkers raise their own exceptions
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     312         # extra long error message in that case.
#     313         pass
# --> 314     reraise(exc_type, exc_value, exc_trace)
#     315
#     316
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# MemoryError: Error allocating 131072 bytes of device memory (out of memory).
# Apply node that caused the error: GpuFromHost(input_33)
# Toposort index: 1
# Inputs types: [TensorType(float32, matrix)]
# Inputs shapes: [(32, 1024)]
# Inputs strides: [(4096, 4)]
# Inputs values: ['not shown']
# Outputs clients: [[GpuDot22(GpuFromHost.0, dense_33_W)]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %%
print "finish"
