# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,32,64,128,256] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccX,AccY,AccZ' # Axis
PathAxis='AccXYZ'

WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData"
DATE_PATH="/2016-08-15/"
TITLE_PATH="Sparse/"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras import regularizers

import matplotlib.image as mpimg
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5005)

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
# define rawdata directory
if not os.path.exists(WORKSPACE_PATH+"/raw/"):
    os.makedirs(WORKSPACE_PATH+"/raw/")
RawDataPath=WORKSPACE_PATH+"/raw/"

# define restoring windowdata directory
if not os.path.exists(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'

# define restoring netowrk model picture's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'

# define restoring graph data's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/')
GlaphDataPath=WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'

# define restoring model paarmeter directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/')
StudyDataPath=WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成**

# %%
# loop windowWidth
for SampleNum,Overlap in zip(WindowWidth,OverlapArray):
    ArrayAxis = Axis.split(",")
    w=window.Window()
    for a in ArrayAxis:
        w.SetData(a,dic[a])
    wind=w.Compile(windowWidth=SampleNum,overlapNum=Overlap)
    print wind.shape
    windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))

    # define SaveFileName
    for AxisName,WindowNum in zip(ArrayAxis,range(3)):
            print "hiden node = "+str(encoding_dim)
            CommonName='_edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+"l1_reg=1"+'-'+AxisName
            SaveFileNameEncord=DataName+'_encoded'+CommonName
            SaveFileNameDecord=DataName+'_decoded'+CommonName
            SaveFileNameNet=DataName+'_net'+CommonName
            SaveFileNameTrain=DataName+'_train'+CommonName
            SaveFileNameTest=DataName+'_test'+CommonName
            SaveFileNameGlaph=GlaphDataPath+DataName+CommonName+'_loss_val_loss.png'

            window_test=wind[:,:,WindowNum]
            window_train=wind[:,:,WindowNum]
            processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTrain,window_test)
            processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTest,window_test)
            shapeNum=wind.shape[1]


            # this is our input placeholder
            input_img = Input(shape=(shapeNum,))
            # "encoded" is the encoded representation of the input
            encoded = Dense(encoding_dim, activation='tanh',
                        W_regularizer=regularizers.WeightRegularizer(l1=10e-5,l2=0.0))(input_img)
            # "decoded" is the lossy reconstruction of the input
            decoded = Dense(shapeNum, activation='linear')(encoded)

            # this model maps an input to its reconstruction
            autoencoder = Model(input=input_img, output=decoded)

            # this model maps an input to its encoded representation
            encoder = Model(input=input_img, output=encoded)

            # create a placeholder for an encoded (32-dimensional) input
            encoded_input = Input(shape=(encoding_dim,))
            # retrieve the last layer of the autoencoder model
            decoder_layer = autoencoder.layers[-1]
            # create the decoder model
            decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))

            #autoencoder.compile(optimizer='adam', loss='mse')
            autoencoder.compile(optimizer='adam', loss='categorical_crossentropy')

            plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')

            early_stopping = EarlyStopping(monitor='val_loss', patience=5)

            hist = autoencoder.fit(window_train, window_train,
                            nb_epoch=100,
                            verbose=2,
                            batch_size=shapeNum/8,
                            shuffle=True,
                            validation_data=(window_test, window_test)
                            ,callbacks=[early_stopping]
                                  )
            time.sleep(0.1)
            encoded_imgs = encoder.predict(window_test)
            decoded_imgs = decoder.predict(encoded_imgs)

            processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameEncord,encoded_imgs)
            processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameDecord,decoded_imgs)

            # save model and wights
            json_string = encoder.to_json()
            open(StudyDataPath+SaveFileNameEncord+'.json', 'w').write(json_string)
            encoder.save_weights(StudyDataPath+SaveFileNameEncord+'_weights.h5',overwrite=True)

            json_string = decoder.to_json()
            open(StudyDataPath+SaveFileNameDecord+'.json', 'w').write(json_string)
            decoder.save_weights(StudyDataPath+SaveFileNameDecord+'_weights.h5',overwrite=True)

            json_string = autoencoder.to_json()
            open(StudyDataPath+SaveFileNameNet+'.json', 'w').write(json_string)
            autoencoder.save_weights(StudyDataPath+SaveFileNameNet+'_weights.h5',overwrite=True)

            # plot loss
            loss = hist.history['loss']
            val_loss = hist.history['val_loss']

            nb_epoch = len(loss)
            plt.plot(range(nb_epoch), loss, marker='.', label='loss')
            plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
            plt.legend(loc='best', fontsize=10)
            plt.grid()
            plt.xlabel('epoch')
            plt.ylabel('loss')
            plt.savefig(SaveFileNameGlaph)
            plt.show()
# Out:
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =15914
# SourceData's aborting data = 6
# window shape is (15914, 128, 3)
# (15914, 128, 3)
# hiden node = 16
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 2s - loss: -5.6917e+02 - val_loss: -6.0980e+02
# Epoch 2/100
# 2s - loss: -6.2553e+02 - val_loss: -6.4727e+02
# Epoch 3/100
# 2s - loss: -6.5752e+02 - val_loss: -6.6764e+02
# Epoch 4/100
# 1s - loss: -6.7291e+02 - val_loss: -6.6736e+02
# Epoch 5/100
# 2s - loss: -5.9285e+02 - val_loss: -6.3985e+02
# Epoch 6/100
# 3s - loss: -6.5270e+02 - val_loss: -6.6079e+02
# Epoch 7/100
# 3s - loss: -6.6388e+02 - val_loss: -6.6544e+02
# Epoch 8/100
# 3s - loss: -6.7149e+02 - val_loss: -6.7545e+02
# Epoch 9/100
# 3s - loss: -6.7606e+02 - val_loss: -6.7783e+02
# Epoch 10/100
# 3s - loss: -6.4577e+02 - val_loss: -5.2998e+02
# Epoch 11/100
# 3s - loss: -6.2323e+02 - val_loss: -6.5479e+02
# Epoch 12/100
# 3s - loss: -6.7135e+02 - val_loss: -6.7585e+02
# Epoch 13/100
# 3s - loss: -6.7982e+02 - val_loss: -6.8276e+02
# Epoch 14/100
# 3s - loss: -6.8006e+02 - val_loss: -6.8572e+02
# Epoch 15/100
# 3s - loss: -6.8402e+02 - val_loss: -6.8701e+02
# Epoch 16/100
# 3s - loss: -6.8870e+02 - val_loss: -6.9038e+02
# Epoch 17/100
# 3s - loss: -6.9264e+02 - val_loss: -6.8699e+02
# Epoch 18/100
# 3s - loss: -6.9659e+02 - val_loss: -6.8743e+02
# Epoch 19/100
# 3s - loss: -6.9911e+02 - val_loss: -6.9189e+02
# Epoch 20/100
# 3s - loss: -6.9997e+02 - val_loss: -7.1080e+02
# Epoch 21/100
# 2s - loss: -6.9630e+02 - val_loss: -6.9335e+02
# Epoch 22/100
# 2s - loss: -5.4247e+02 - val_loss: -5.4406e+02
# Epoch 23/100
# 3s - loss: -5.6629e+02 - val_loss: -5.9242e+02
# Epoch 24/100
# 3s - loss: -6.3808e+02 - val_loss: -6.7263e+02
# Epoch 25/100
# 3s - loss: -6.7945e+02 - val_loss: -6.8575e+02
# Epoch 26/100
# 3s - loss: -6.8746e+02 - val_loss: -6.8558e+02
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/backend/theano_backend.py:558: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 1 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# hiden node = 16
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 3s - loss: -1.2657e+03 - val_loss: -1.3620e+03
# Epoch 2/100
# 3s - loss: -1.4171e+03 - val_loss: -1.4489e+03
# Epoch 3/100
# 2s - loss: -1.4616e+03 - val_loss: -1.4803e+03
# Epoch 4/100
# 2s - loss: -1.4879e+03 - val_loss: -1.5019e+03
# Epoch 5/100
# 3s - loss: -1.5020e+03 - val_loss: -1.5028e+03
# Epoch 6/100
# 3s - loss: -1.5101e+03 - val_loss: -1.5240e+03
# Epoch 7/100
# 3s - loss: -1.5280e+03 - val_loss: -1.5466e+03
# Epoch 8/100
# 3s - loss: -1.5543e+03 - val_loss: -1.5559e+03
# Epoch 9/100
# 3s - loss: -1.5616e+03 - val_loss: -1.5621e+03
# Epoch 10/100
# 3s - loss: -1.5629e+03 - val_loss: -1.5645e+03
# Epoch 11/100
# 3s - loss: -1.3408e+03 - val_loss: -1.4458e+03
# Epoch 12/100
# 3s - loss: -1.4851e+03 - val_loss: -1.5031e+03
# Epoch 13/100
# 3s - loss: -1.5036e+03 - val_loss: -1.5042e+03
# Epoch 14/100
# 3s - loss: -1.5042e+03 - val_loss: -1.5016e+03
# Epoch 15/100
# 3s - loss: -1.5045e+03 - val_loss: -1.5047e+03
# Epoch 16/100
# 4s - loss: -1.5022e+03 - val_loss: -1.5050e+03
# hiden node = 16
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 3s - loss: -2.1099e+01 - val_loss: -1.7095e+01
# Epoch 2/100
# 3s - loss: -3.1052e+01 - val_loss: -2.7480e+01
# Epoch 3/100
# 3s - loss: -3.9598e+01 - val_loss: -2.5466e+01
# Epoch 4/100
# 3s - loss: -4.5498e+01 - val_loss: -2.4115e+01
# Epoch 5/100
# 3s - loss: -4.6129e+01 - val_loss: -2.4821e+01
# Epoch 6/100
# 3s - loss: -4.7067e+01 - val_loss: -2.5769e+01
# Epoch 7/100
# 3s - loss: -4.8954e+01 - val_loss: -2.6344e+01
# Epoch 8/100
# 3s - loss: -5.3175e+01 - val_loss: -2.3949e+01
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =7953
# SourceData's aborting data = 22
# window shape is (7953, 256, 3)
# (7953, 256, 3)
# hiden node = 16
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -1.0428e+03 - val_loss: -1.1258e+03
# Epoch 2/100
# 1s - loss: -1.1720e+03 - val_loss: -1.1938e+03
# Epoch 3/100
# 1s - loss: -1.2330e+03 - val_loss: -1.2582e+03
# Epoch 4/100
# 0s - loss: -1.2739e+03 - val_loss: -1.2852e+03
# Epoch 5/100
# 0s - loss: -1.2889e+03 - val_loss: -1.2971e+03
# Epoch 6/100
# 0s - loss: -1.2947e+03 - val_loss: -1.3007e+03
# Epoch 7/100
# 0s - loss: -1.2045e+03 - val_loss: -7.8626e+02
# Epoch 8/100
# 0s - loss: -8.9412e+02 - val_loss: -9.5168e+02
# Epoch 9/100
# 0s - loss: -9.7175e+02 - val_loss: -1.0064e+03
# Epoch 10/100
# 0s - loss: -1.0551e+03 - val_loss: -1.0829e+03
# Epoch 11/100
# 0s - loss: -1.1143e+03 - val_loss: -1.1449e+03
# Epoch 12/100
# 0s - loss: -1.1648e+03 - val_loss: -1.1889e+03
# hiden node = 16
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -2.4033e+03 - val_loss: -2.5662e+03
# Epoch 2/100
# 0s - loss: -2.6443e+03 - val_loss: -2.7173e+03
# Epoch 3/100
# 1s - loss: -2.7689e+03 - val_loss: -2.8242e+03
# Epoch 4/100
# 1s - loss: -2.8463e+03 - val_loss: -2.8531e+03
# Epoch 5/100
# 1s - loss: -2.8630e+03 - val_loss: -2.8820e+03
# Epoch 6/100
# 1s - loss: -2.8978e+03 - val_loss: -2.9176e+03
# Epoch 7/100
# 1s - loss: -2.9292e+03 - val_loss: -2.9389e+03
# Epoch 8/100
# 0s - loss: -2.9522e+03 - val_loss: -2.9578e+03
# Epoch 9/100
# 1s - loss: -2.9622e+03 - val_loss: -2.9718e+03
# Epoch 10/100
# 0s - loss: -2.9913e+03 - val_loss: -2.9988e+03
# Epoch 11/100
# 1s - loss: -3.0001e+03 - val_loss: -3.0081e+03
# Epoch 12/100
# 0s - loss: -3.0167e+03 - val_loss: -3.0197e+03
# Epoch 13/100
# 0s - loss: -3.0238e+03 - val_loss: -3.0269e+03
# Epoch 14/100
# 0s - loss: -3.0272e+03 - val_loss: -3.0292e+03
# Epoch 15/100
# 0s - loss: -3.0416e+03 - val_loss: -3.0485e+03
# Epoch 16/100
# 0s - loss: -3.0551e+03 - val_loss: -3.0659e+03
# Epoch 17/100
# 0s - loss: -3.0713e+03 - val_loss: -3.0792e+03
# Epoch 18/100
# 0s - loss: -3.0870e+03 - val_loss: -3.0871e+03
# Epoch 19/100
# 0s - loss: -3.0863e+03 - val_loss: -3.0772e+03
# Epoch 20/100
# 0s - loss: -3.0848e+03 - val_loss: -3.0876e+03
# Epoch 21/100
# 0s - loss: -3.0886e+03 - val_loss: -3.0898e+03
# Epoch 22/100
# 0s - loss: -3.0895e+03 - val_loss: -3.0888e+03
# Epoch 23/100
# 1s - loss: -3.0893e+03 - val_loss: -3.0994e+03
# Epoch 24/100
# 0s - loss: -2.6232e+03 - val_loss: -1.9706e+03
# Epoch 25/100
# 0s - loss: -2.2061e+03 - val_loss: -2.4020e+03
# Epoch 26/100
# 0s - loss: -2.4876e+03 - val_loss: -2.5844e+03
# Epoch 27/100
# 0s - loss: -2.6586e+03 - val_loss: -2.7184e+03
# Epoch 28/100
# 0s - loss: -2.7605e+03 - val_loss: -2.8024e+03
# Epoch 29/100
# 0s - loss: -2.8277e+03 - val_loss: -2.8420e+03
# hiden node = 16
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -1.8069e+01 - val_loss: -8.1221e+01
# Epoch 2/100
# 0s - loss: -3.7106e+01 - val_loss: -3.4894e+01
# Epoch 3/100
# 0s - loss: -4.6628e+01 - val_loss: -3.0961e+01
# Epoch 4/100
# 0s - loss: -5.8170e+01 - val_loss: -1.2552e+02
# Epoch 5/100
# 0s - loss: -5.9969e+01 - val_loss: -4.5012e+01
# Epoch 6/100
# 1s - loss: -6.2403e+01 - val_loss: -2.2073e+01
# Epoch 7/100
# 0s - loss: -6.4405e+01 - val_loss: -1.2085e+02
# Epoch 8/100
# 0s - loss: -7.1853e+01 - val_loss: -1.4419e+02
# Epoch 9/100
# 0s - loss: -6.2809e+01 - val_loss: -1.4097e+02
# Epoch 10/100
# 0s - loss: -7.6507e+01 - val_loss: -4.7902e+01
# Epoch 11/100
# 0s - loss: -8.7977e+01 - val_loss: -5.5290e+01
# Epoch 12/100
# 0s - loss: -8.2650e+01 - val_loss: -1.4103e+02
# Epoch 13/100
# 0s - loss: -8.3847e+01 - val_loss: -1.0393e+02
# Epoch 14/100
# 0s - loss: -9.0652e+01 - val_loss: -5.8663e+01
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =3973
# SourceData's aborting data = 22
# window shape is (3973, 512, 3)
# (3973, 512, 3)
# hiden node = 16
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: -1.9519e+03 - val_loss: -2.0954e+03
# Epoch 2/100
# 0s - loss: -2.1503e+03 - val_loss: -2.1816e+03
# Epoch 3/100
# 0s - loss: -2.2115e+03 - val_loss: -2.2385e+03
# Epoch 4/100
# 0s - loss: -2.2642e+03 - val_loss: -2.2810e+03
# Epoch 5/100
# 0s - loss: -2.3034e+03 - val_loss: -2.3242e+03
# Epoch 6/100
# 0s - loss: -2.3418e+03 - val_loss: -2.3520e+03
# Epoch 7/100
# 0s - loss: -2.3629e+03 - val_loss: -2.3691e+03
# Epoch 8/100
# 0s - loss: -2.3751e+03 - val_loss: -2.3883e+03
# Epoch 9/100
# 0s - loss: -2.4013e+03 - val_loss: -2.4089e+03
# Epoch 10/100
# 0s - loss: -2.4172e+03 - val_loss: -2.4210e+03
# Epoch 11/100
# 0s - loss: -2.4249e+03 - val_loss: -2.4324e+03
# Epoch 12/100
# 0s - loss: -2.4395e+03 - val_loss: -2.4476e+03
# Epoch 13/100
# 0s - loss: -2.4568e+03 - val_loss: -2.4633e+03
# Epoch 14/100
# 0s - loss: -2.4643e+03 - val_loss: -2.4687e+03
# Epoch 15/100
# 0s - loss: -2.4726e+03 - val_loss: -2.4777e+03
# Epoch 16/100
# 0s - loss: -2.4872e+03 - val_loss: -2.4938e+03
# Epoch 17/100
# 0s - loss: -2.4973e+03 - val_loss: -2.5042e+03
# Epoch 18/100
# 0s - loss: -2.5104e+03 - val_loss: -2.5139e+03
# Epoch 19/100
# 0s - loss: -2.5180e+03 - val_loss: -2.5233e+03
# Epoch 20/100
# 0s - loss: -2.5265e+03 - val_loss: -2.5285e+03
# Epoch 21/100
# 0s - loss: -2.5279e+03 - val_loss: -2.5306e+03
# Epoch 22/100
# 0s - loss: -2.5292e+03 - val_loss: -2.5285e+03
# Epoch 23/100
# 0s - loss: -2.5305e+03 - val_loss: -2.5292e+03
# Epoch 24/100
# 0s - loss: -2.5223e+03 - val_loss: -2.5246e+03
# Epoch 25/100
# 0s - loss: -2.5213e+03 - val_loss: -2.5267e+03
# Epoch 26/100
# 0s - loss: -2.5336e+03 - val_loss: -2.5428e+03
# Epoch 27/100
# 0s - loss: -2.5466e+03 - val_loss: -2.5460e+03
# Epoch 28/100
# 0s - loss: -2.5462e+03 - val_loss: -2.5508e+03
# Epoch 29/100
# 0s - loss: -2.5536e+03 - val_loss: -2.5566e+03
# Epoch 30/100
# 0s - loss: -2.5604e+03 - val_loss: -2.5555e+03
# Epoch 31/100
# 0s - loss: -2.3457e+03 - val_loss: -1.7668e+03
# Epoch 32/100
# 0s - loss: -1.9733e+03 - val_loss: -2.1837e+03
# Epoch 33/100
# 0s - loss: -2.3506e+03 - val_loss: -2.4412e+03
# Epoch 34/100
# 0s - loss: -2.5045e+03 - val_loss: -2.5304e+03
# Epoch 35/100
# 0s - loss: -2.5447e+03 - val_loss: -2.5555e+03
# hiden node = 16
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: -4.3287e+03 - val_loss: -4.5878e+03
# Epoch 2/100
# 0s - loss: -4.7696e+03 - val_loss: -4.8974e+03
# Epoch 3/100
# 0s - loss: -4.9804e+03 - val_loss: -5.0594e+03
# Epoch 4/100
# 0s - loss: -5.1328e+03 - val_loss: -5.1866e+03
# Epoch 5/100
# 0s - loss: -5.2225e+03 - val_loss: -5.2654e+03
# Epoch 6/100
# 0s - loss: -5.3002e+03 - val_loss: -5.3438e+03
# Epoch 7/100
# 0s - loss: -5.3662e+03 - val_loss: -5.3765e+03
# Epoch 8/100
# 0s - loss: -5.3965e+03 - val_loss: -5.4143e+03
# Epoch 9/100
# 0s - loss: -5.4283e+03 - val_loss: -5.4363e+03
# Epoch 10/100
# 0s - loss: -5.4659e+03 - val_loss: -5.4755e+03
# Epoch 11/100
# 0s - loss: -5.4861e+03 - val_loss: -5.4953e+03
# Epoch 12/100
# 0s - loss: -5.5042e+03 - val_loss: -5.5083e+03
# Epoch 13/100
# 0s - loss: -5.5141e+03 - val_loss: -5.5327e+03
# Epoch 14/100
# 0s - loss: -5.5450e+03 - val_loss: -5.5590e+03
# Epoch 15/100
# 0s - loss: -5.5643e+03 - val_loss: -5.5710e+03
# Epoch 16/100
# 0s - loss: -5.5750e+03 - val_loss: -5.5753e+03
# Epoch 17/100
# 0s - loss: -5.5937e+03 - val_loss: -5.6066e+03
# Epoch 18/100
# 0s - loss: -5.6195e+03 - val_loss: -5.6238e+03
# Epoch 19/100
# 0s - loss: -5.6353e+03 - val_loss: -5.6290e+03
# Epoch 20/100
# 0s - loss: -5.6307e+03 - val_loss: -5.6329e+03
# Epoch 21/100
# 0s - loss: -5.6342e+03 - val_loss: -5.6354e+03
# Epoch 22/100
# 0s - loss: -5.6361e+03 - val_loss: -5.6378e+03
# Epoch 23/100
# 0s - loss: -5.6439e+03 - val_loss: -5.6421e+03
# Epoch 24/100
# 0s - loss: -5.6492e+03 - val_loss: -5.6479e+03
# Epoch 25/100
# 0s - loss: -5.6542e+03 - val_loss: -5.6574e+03
# Epoch 26/100
# 0s - loss: -5.6587e+03 - val_loss: -5.6602e+03
# Epoch 27/100
# 0s - loss: -5.6604e+03 - val_loss: -5.6620e+03
# Epoch 28/100
# 0s - loss: -5.6682e+03 - val_loss: -5.6692e+03
# Epoch 29/100
# 0s - loss: -5.6715e+03 - val_loss: -5.6726e+03
# Epoch 30/100
# 0s - loss: -5.6770e+03 - val_loss: -5.6791e+03
# Epoch 31/100
# 0s - loss: -5.6811e+03 - val_loss: -5.6886e+03
# Epoch 32/100
# 0s - loss: -5.6922e+03 - val_loss: -5.6982e+03
# Epoch 33/100
# 0s - loss: -5.7136e+03 - val_loss: -5.7213e+03
# Epoch 34/100
# 0s - loss: -5.7209e+03 - val_loss: -5.7214e+03
# Epoch 35/100
# 0s - loss: -5.7251e+03 - val_loss: -5.7379e+03
# Epoch 36/100
# 0s - loss: -5.7412e+03 - val_loss: -5.7465e+03
# Epoch 37/100
# 0s - loss: -5.7470e+03 - val_loss: -5.7482e+03
# Epoch 38/100
# 0s - loss: -5.7542e+03 - val_loss: -5.7561e+03
# Epoch 39/100
# 0s - loss: -5.7568e+03 - val_loss: -5.7562e+03
# Epoch 40/100
# 0s - loss: -5.7561e+03 - val_loss: -5.7554e+03
# Epoch 41/100
# 0s - loss: -5.7549e+03 - val_loss: -5.7551e+03
# Epoch 42/100
# 0s - loss: -5.7553e+03 - val_loss: -5.7497e+03
# Epoch 43/100
# 0s - loss: -5.7579e+03 - val_loss: -5.7650e+03
# Epoch 44/100
# 0s - loss: -5.7695e+03 - val_loss: -5.7823e+03
# Epoch 45/100
# 0s - loss: -5.7818e+03 - val_loss: -5.7889e+03
# Epoch 46/100
# 0s - loss: -5.7980e+03 - val_loss: -5.8085e+03
# Epoch 47/100
# 0s - loss: -5.8086e+03 - val_loss: -5.8097e+03
# Epoch 48/100
# 0s - loss: -5.8102e+03 - val_loss: -5.8105e+03
# Epoch 49/100
# 0s - loss: -5.8160e+03 - val_loss: -5.8186e+03
# Epoch 50/100
# 0s - loss: -5.8230e+03 - val_loss: -5.8271e+03
# Epoch 51/100
# 0s - loss: -5.8277e+03 - val_loss: -5.8279e+03
# Epoch 52/100
# 0s - loss: -5.8273e+03 - val_loss: -5.8280e+03
# Epoch 53/100
# 0s - loss: -5.8314e+03 - val_loss: -5.8371e+03
# Epoch 54/100
# 0s - loss: -5.8376e+03 - val_loss: -5.8386e+03
# Epoch 55/100
# 0s - loss: -5.8391e+03 - val_loss: -5.8396e+03
# Epoch 56/100
# 0s - loss: -5.8403e+03 - val_loss: -5.8408e+03
# Epoch 57/100
# 0s - loss: -5.8410e+03 - val_loss: -5.8417e+03
# Epoch 58/100
# 0s - loss: -5.8422e+03 - val_loss: -5.8428e+03
# Epoch 59/100
# 0s - loss: -5.8493e+03 - val_loss: -5.8519e+03
# Epoch 60/100
# 0s - loss: -5.8517e+03 - val_loss: -5.8532e+03
# Epoch 61/100
# 0s - loss: -5.8539e+03 - val_loss: -5.8549e+03
# Epoch 62/100
# 0s - loss: -5.8550e+03 - val_loss: -5.8531e+03
# Epoch 63/100
# 0s - loss: -5.8562e+03 - val_loss: -5.8574e+03
# Epoch 64/100
# 0s - loss: -5.8559e+03 - val_loss: -5.8564e+03
# Epoch 65/100
# 0s - loss: -5.8586e+03 - val_loss: -5.8653e+03
# Epoch 66/100
# 0s - loss: -5.8660e+03 - val_loss: -5.8657e+03
# Epoch 67/100
# 0s - loss: -5.8667e+03 - val_loss: -5.8686e+03
# Epoch 68/100
# 0s - loss: -5.8755e+03 - val_loss: -5.8840e+03
# Epoch 69/100
# 0s - loss: -5.8902e+03 - val_loss: -5.8928e+03
# Epoch 70/100
# 0s - loss: -5.8926e+03 - val_loss: -5.8936e+03
# Epoch 71/100
# 0s - loss: -5.8880e+03 - val_loss: -5.8908e+03
# Epoch 72/100
# 0s - loss: -5.8924e+03 - val_loss: -5.8929e+03
# Epoch 73/100
# 0s - loss: -5.9003e+03 - val_loss: -5.9012e+03
# Epoch 74/100
# 0s - loss: -5.9031e+03 - val_loss: -5.9049e+03
# Epoch 75/100
# 0s - loss: -5.9120e+03 - val_loss: -5.9222e+03
# Epoch 76/100
# 0s - loss: -5.9227e+03 - val_loss: -5.9238e+03
# Epoch 77/100
# 0s - loss: -5.9231e+03 - val_loss: -5.9247e+03
# Epoch 78/100
# 0s - loss: -5.9251e+03 - val_loss: -5.9330e+03
# Epoch 79/100
# 0s - loss: -5.9337e+03 - val_loss: -5.9341e+03
# Epoch 80/100
# 0s - loss: -5.9371e+03 - val_loss: -5.9419e+03
# Epoch 81/100
# 0s - loss: -5.9428e+03 - val_loss: -5.9436e+03
# Epoch 82/100
# 0s - loss: -5.9438e+03 - val_loss: -5.9442e+03
# Epoch 83/100
# 0s - loss: -5.9471e+03 - val_loss: -5.9522e+03
# Epoch 84/100
# 0s - loss: -5.9525e+03 - val_loss: -5.9525e+03
# Epoch 85/100
# 0s - loss: -5.9529e+03 - val_loss: -5.9535e+03
# Epoch 86/100
# 0s - loss: -5.9540e+03 - val_loss: -5.9501e+03
# Epoch 87/100
# 0s - loss: -5.9604e+03 - val_loss: -5.9640e+03
# Epoch 88/100
# 0s - loss: -5.9642e+03 - val_loss: -5.9643e+03
# Epoch 89/100
# 0s - loss: -5.9713e+03 - val_loss: -5.9810e+03
# Epoch 90/100
# 0s - loss: -5.9877e+03 - val_loss: -5.9893e+03
# Epoch 91/100
# 0s - loss: -5.9930e+03 - val_loss: -5.9978e+03
# Epoch 92/100
# 0s - loss: -5.9978e+03 - val_loss: -5.9982e+03
# Epoch 93/100
# 0s - loss: -5.9961e+03 - val_loss: -5.9970e+03
# Epoch 94/100
# 0s - loss: -6.0042e+03 - val_loss: -6.0054e+03
# Epoch 95/100
# 0s - loss: -6.0036e+03 - val_loss: -6.0027e+03
# Epoch 96/100
# 0s - loss: -6.0025e+03 - val_loss: -6.0120e+03
# Epoch 97/100
# 0s - loss: -6.0117e+03 - val_loss: -6.0145e+03
# Epoch 98/100
# 0s - loss: -6.0216e+03 - val_loss: -6.0226e+03
# Epoch 99/100
# 0s - loss: -6.0223e+03 - val_loss: -6.0229e+03
# Epoch 100/100
# 0s - loss: -6.0213e+03 - val_loss: -6.0210e+03
# hiden node = 16
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: 8.8486 - val_loss: -1.1577e+01
# Epoch 2/100
# 0s - loss: -1.2819e+01 - val_loss: 7.3232
# Epoch 3/100
# 0s - loss: -3.0702e+01 - val_loss: 0.7296
# Epoch 4/100
# 0s - loss: -2.5720e+01 - val_loss: -1.0720e+01
# Epoch 5/100
# 0s - loss: -3.0365e+01 - val_loss: -1.4480e+01
# Epoch 6/100
# 0s - loss: -4.8590e+01 - val_loss: -2.5227e+01
# Epoch 7/100
# 0s - loss: -3.4292e+01 - val_loss: -5.6601e+01
# Epoch 8/100
# 0s - loss: -3.1747e+01 - val_loss: -2.7286e+01
# Epoch 9/100
# 0s - loss: -5.2525e+01 - val_loss: -3.0981e+01
# Epoch 10/100
# 0s - loss: -7.7074e+01 - val_loss: -6.6530e+01
# Epoch 11/100
# 0s - loss: -9.0291e+01 - val_loss: -6.0364e+01
# Epoch 12/100
# 0s - loss: -8.6054e+01 - val_loss: -1.0001e+02
# Epoch 13/100
# 0s - loss: -6.3083e+01 - val_loss: -1.3388e+02
# Epoch 14/100
# 0s - loss: -8.8760e+01 - val_loss: -5.8564e+01
# Epoch 15/100
# 0s - loss: -9.0215e+01 - val_loss: -6.6214e+01
# Epoch 16/100
# 0s - loss: -9.5084e+01 - val_loss: -9.3846e+01
# Epoch 17/100
# 0s - loss: -8.7145e+01 - val_loss: -1.6316e+02
# Epoch 18/100
# 0s - loss: -7.3559e+01 - val_loss: -6.3641e+01
# Epoch 19/100
# 0s - loss: -9.4825e+01 - val_loss: -7.6427e+01
# Epoch 20/100
# 0s - loss: -1.0411e+02 - val_loss: -1.6354e+02
# Epoch 21/100
# 0s - loss: -1.1113e+02 - val_loss: -1.6158e+02
# Epoch 22/100
# 0s - loss: -1.1856e+02 - val_loss: -1.7739e+02
# Epoch 23/100
# 0s - loss: -6.1968e+01 - val_loss: -5.5980e+01
# Epoch 24/100
# 0s - loss: -1.0024e+02 - val_loss: -9.1726e+01
# Epoch 25/100
# 0s - loss: -8.4825e+01 - val_loss: -1.2288e+02
# Epoch 26/100
# 0s - loss: -9.4274e+01 - val_loss: -6.3356e+01
# Epoch 27/100
# 0s - loss: -9.7287e+01 - val_loss: -7.8165e+01
# Epoch 28/100
# 0s - loss: -9.6602e+01 - val_loss: -6.5858e+01
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =1983
# SourceData's aborting data = 22
# window shape is (1983, 1024, 3)
# (1983, 1024, 3)
# hiden node = 16
# Train on 1983 samples, validate on 1983 samples
# Epoch 1/100
# 0s - loss: -3.6969e+03 - val_loss: -3.9404e+03
# Epoch 2/100
# 0s - loss: -4.0142e+03 - val_loss: -4.0789e+03
# Epoch 3/100
# 0s - loss: -4.1205e+03 - val_loss: -4.1711e+03
# Epoch 4/100
# 0s - loss: -4.1989e+03 - val_loss: -4.2359e+03
# Epoch 5/100
# 0s - loss: -4.2537e+03 - val_loss: -4.2986e+03
# Epoch 6/100
# 0s - loss: -4.3233e+03 - val_loss: -4.3576e+03
# Epoch 7/100
# 0s - loss: -4.3860e+03 - val_loss: -4.4203e+03
# Epoch 8/100
# 0s - loss: -4.4355e+03 - val_loss: -4.4576e+03
# Epoch 9/100
# 0s - loss: -4.4812e+03 - val_loss: -4.5057e+03
# Epoch 10/100
# 0s - loss: -4.5178e+03 - val_loss: -4.5355e+03
# Epoch 11/100
# 0s - loss: -4.5525e+03 - val_loss: -4.5748e+03
# Epoch 12/100
# 0s - loss: -4.5823e+03 - val_loss: -4.6033e+03
# Epoch 13/100
# 0s - loss: -4.6158e+03 - val_loss: -4.6309e+03
# Epoch 14/100
# 0s - loss: -4.6406e+03 - val_loss: -4.6581e+03
# Epoch 15/100
# 0s - loss: -4.6685e+03 - val_loss: -4.6740e+03
# Epoch 16/100
# 0s - loss: -4.6830e+03 - val_loss: -4.6997e+03
# Epoch 17/100
# 0s - loss: -4.7052e+03 - val_loss: -4.7109e+03
# Epoch 18/100
# 0s - loss: -4.7178e+03 - val_loss: -4.7234e+03
# Epoch 19/100
# 0s - loss: -4.7274e+03 - val_loss: -4.7254e+03
# Epoch 20/100
# 0s - loss: -4.7386e+03 - val_loss: -4.7485e+03
# Epoch 21/100
# 0s - loss: -4.7531e+03 - val_loss: -4.7522e+03
# Epoch 22/100
# 0s - loss: -4.7612e+03 - val_loss: -4.7719e+03
# Epoch 23/100
# 0s - loss: -4.7766e+03 - val_loss: -4.7888e+03
# Epoch 24/100
# 0s - loss: -4.7899e+03 - val_loss: -4.7944e+03
# Epoch 25/100
# 0s - loss: -4.8009e+03 - val_loss: -4.8086e+03
# Epoch 26/100
# 0s - loss: -4.8113e+03 - val_loss: -4.8134e+03
# Epoch 27/100
# 0s - loss: -4.8171e+03 - val_loss: -4.8379e+03
# Epoch 28/100
# 0s - loss: -4.8427e+03 - val_loss: -4.8456e+03
# Epoch 29/100
# 0s - loss: -4.8481e+03 - val_loss: -4.8487e+03
# Epoch 30/100
# 0s - loss: -4.8583e+03 - val_loss: -4.8652e+03
# Epoch 31/100
# 0s - loss: -4.8665e+03 - val_loss: -4.8704e+03
# Epoch 32/100
# 0s - loss: -4.8755e+03 - val_loss: -4.8823e+03
# Epoch 33/100
# 0s - loss: -4.8823e+03 - val_loss: -4.8830e+03
# Epoch 34/100
# 0s - loss: -4.8857e+03 - val_loss: -4.8877e+03
# Epoch 35/100
# 0s - loss: -4.8886e+03 - val_loss: -4.8885e+03
# Epoch 36/100
# 0s - loss: -4.8917e+03 - val_loss: -4.8947e+03
# Epoch 37/100
# 0s - loss: -4.8962e+03 - val_loss: -4.8953e+03
# Epoch 38/100
# 0s - loss: -4.9030e+03 - val_loss: -4.9115e+03
# Epoch 39/100
# 0s - loss: -4.9152e+03 - val_loss: -4.9218e+03
# Epoch 40/100
# 0s - loss: -4.9227e+03 - val_loss: -4.9300e+03
# Epoch 41/100
# 0s - loss: -4.9314e+03 - val_loss: -4.9337e+03
# Epoch 42/100
# 0s - loss: -4.9469e+03 - val_loss: -4.9565e+03
# Epoch 43/100
# 0s - loss: -4.9600e+03 - val_loss: -4.9645e+03
# Epoch 44/100
# 0s - loss: -4.9639e+03 - val_loss: -4.9655e+03
# Epoch 45/100
# 0s - loss: -4.9620e+03 - val_loss: -4.9648e+03
# Epoch 46/100
# 0s - loss: -4.9631e+03 - val_loss: -4.9642e+03
# Epoch 47/100
# 0s - loss: -4.9649e+03 - val_loss: -4.9697e+03
# Epoch 48/100
# 0s - loss: -4.9709e+03 - val_loss: -4.9701e+03
# Epoch 49/100
# 0s - loss: -4.9774e+03 - val_loss: -4.9827e+03
# Epoch 50/100
# 0s - loss: -4.9829e+03 - val_loss: -4.9876e+03
# Epoch 51/100
# 0s - loss: -4.9871e+03 - val_loss: -4.9878e+03
# Epoch 52/100
# 0s - loss: -4.9907e+03 - val_loss: -4.9927e+03
# Epoch 53/100
# 0s - loss: -4.9952e+03 - val_loss: -5.0019e+03
# Epoch 54/100
# 0s - loss: -5.0015e+03 - val_loss: -5.0049e+03
# Epoch 55/100
# 0s - loss: -5.0039e+03 - val_loss: -5.0041e+03
# Epoch 56/100
# 0s - loss: -5.0065e+03 - val_loss: -5.0070e+03
# Epoch 57/100
# 0s - loss: -5.0087e+03 - val_loss: -5.0102e+03
# Epoch 58/100
# 0s - loss: -5.0094e+03 - val_loss: -5.0076e+03
# Epoch 59/100
# 0s - loss: -5.0079e+03 - val_loss: -5.0065e+03
# Epoch 60/100
# 0s - loss: -5.0093e+03 - val_loss: -5.0139e+03
# Epoch 61/100
# 0s - loss: -5.0148e+03 - val_loss: -5.0145e+03
# Epoch 62/100
# 0s - loss: -5.0196e+03 - val_loss: -5.0199e+03
# Epoch 63/100
# 0s - loss: -5.0190e+03 - val_loss: -5.0170e+03
# Epoch 64/100
# 0s - loss: -5.0201e+03 - val_loss: -5.0215e+03
# Epoch 65/100
# 0s - loss: -5.0239e+03 - val_loss: -5.0261e+03
# Epoch 66/100
# 0s - loss: -5.0290e+03 - val_loss: -5.0356e+03
# Epoch 67/100
# 0s - loss: -5.0358e+03 - val_loss: -5.0372e+03
# Epoch 68/100
# 0s - loss: -5.0378e+03 - val_loss: -5.0424e+03
# Epoch 69/100
# 0s - loss: -5.0417e+03 - val_loss: -5.0391e+03
# Epoch 70/100
# 0s - loss: -5.0386e+03 - val_loss: -5.0305e+03
# Epoch 71/100
# 0s - loss: -5.0229e+03 - val_loss: -5.0208e+03
# Epoch 72/100
# 0s - loss: -5.0248e+03 - val_loss: -5.0275e+03
# Epoch 73/100
# 0s - loss: -5.0317e+03 - val_loss: -5.0352e+03
# Epoch 74/100
# 0s - loss: -5.0349e+03 - val_loss: -5.0366e+03
# hiden node = 16
# Train on 1983 samples, validate on 1983 samples
# Epoch 1/100
# 0s - loss: -8.4566e+03 - val_loss: -9.1058e+03
# Epoch 2/100
# 0s - loss: -9.2592e+03 - val_loss: -9.4133e+03
# Epoch 3/100
# 0s - loss: -9.5419e+03 - val_loss: -9.6474e+03
# Epoch 4/100
# 0s - loss: -9.7156e+03 - val_loss: -9.7941e+03
# Epoch 5/100
# 0s - loss: -9.8487e+03 - val_loss: -9.8993e+03
# Epoch 6/100
# 0s - loss: -9.9478e+03 - val_loss: -1.0002e+04
# Epoch 7/100
# 0s - loss: -1.0054e+04 - val_loss: -1.0109e+04
# Epoch 8/100
# 0s - loss: -1.0143e+04 - val_loss: -1.0190e+04
# Epoch 9/100
# 0s - loss: -1.0248e+04 - val_loss: -1.0264e+04
# Epoch 10/100
# 0s - loss: -1.0352e+04 - val_loss: -1.0385e+04
# Epoch 11/100
# 0s - loss: -1.0411e+04 - val_loss: -1.0433e+04
# Epoch 12/100
# 0s - loss: -1.0455e+04 - val_loss: -1.0472e+04
# Epoch 13/100
# 0s - loss: -1.0497e+04 - val_loss: -1.0523e+04
# Epoch 14/100
# 0s - loss: -1.0563e+04 - val_loss: -1.0601e+04
# Epoch 15/100
# 0s - loss: -1.0638e+04 - val_loss: -1.0671e+04
# Epoch 16/100
# 0s - loss: -1.0687e+04 - val_loss: -1.0697e+04
# Epoch 17/100
# 0s - loss: -1.0707e+04 - val_loss: -1.0717e+04
# Epoch 18/100
# 0s - loss: -1.0742e+04 - val_loss: -1.0760e+04
# Epoch 19/100
# 0s - loss: -1.0785e+04 - val_loss: -1.0810e+04
# Epoch 20/100
# 0s - loss: -1.0840e+04 - val_loss: -1.0856e+04
# Epoch 21/100
# 0s - loss: -1.0868e+04 - val_loss: -1.0884e+04
# Epoch 22/100
# 0s - loss: -1.0896e+04 - val_loss: -1.0909e+04
# Epoch 23/100
# 0s - loss: -1.0923e+04 - val_loss: -1.0944e+04
# Epoch 24/100
# 0s - loss: -1.0950e+04 - val_loss: -1.0970e+04
# Epoch 25/100
# 0s - loss: -1.0977e+04 - val_loss: -1.0983e+04
# Epoch 26/100
# 0s - loss: -1.0994e+04 - val_loss: -1.1002e+04
# Epoch 27/100
# 0s - loss: -1.1013e+04 - val_loss: -1.1034e+04
# Epoch 28/100
# 0s - loss: -1.1048e+04 - val_loss: -1.1054e+04
# Epoch 29/100
# 0s - loss: -1.1025e+04 - val_loss: -1.1043e+04
# Epoch 30/100
# 0s - loss: -1.1045e+04 - val_loss: -1.1060e+04
# Epoch 31/100
# 0s - loss: -1.1064e+04 - val_loss: -1.1067e+04
# Epoch 32/100
# 0s - loss: -1.1077e+04 - val_loss: -1.1085e+04
# Epoch 33/100
# 0s - loss: -1.1092e+04 - val_loss: -1.1100e+04
# Epoch 34/100
# 0s - loss: -1.1104e+04 - val_loss: -1.1106e+04
# Epoch 35/100
# 0s - loss: -1.1109e+04 - val_loss: -1.1111e+04
# Epoch 36/100
# 0s - loss: -1.1124e+04 - val_loss: -1.1139e+04
# Epoch 37/100
# 0s - loss: -1.1155e+04 - val_loss: -1.1170e+04
# Epoch 38/100
# 0s - loss: -1.1174e+04 - val_loss: -1.1171e+04
# Epoch 39/100
# 0s - loss: -1.1193e+04 - val_loss: -1.1210e+04
# Epoch 40/100
# 0s - loss: -1.1211e+04 - val_loss: -1.1214e+04
# Epoch 41/100
# 0s - loss: -1.1225e+04 - val_loss: -1.1240e+04
# Epoch 42/100
# 0s - loss: -1.1248e+04 - val_loss: -1.1256e+04
# Epoch 43/100
# 0s - loss: -1.1261e+04 - val_loss: -1.1265e+04
# Epoch 44/100
# 0s - loss: -1.1271e+04 - val_loss: -1.1280e+04
# Epoch 45/100
# 0s - loss: -1.1281e+04 - val_loss: -1.1290e+04
# Epoch 46/100
# 0s - loss: -1.1296e+04 - val_loss: -1.1305e+04
# Epoch 47/100
# 0s - loss: -1.1305e+04 - val_loss: -1.1314e+04
# Epoch 48/100
# 0s - loss: -1.1314e+04 - val_loss: -1.1315e+04
# Epoch 49/100
# 0s - loss: -1.1320e+04 - val_loss: -1.1326e+04
# Epoch 50/100
# 0s - loss: -1.1332e+04 - val_loss: -1.1339e+04
# Epoch 51/100
# 0s - loss: -1.1346e+04 - val_loss: -1.1346e+04
# Epoch 52/100
# 0s - loss: -1.1351e+04 - val_loss: -1.1358e+04
# Epoch 53/100
# 0s - loss: -1.1358e+04 - val_loss: -1.1360e+04
# Epoch 54/100
# 0s - loss: -1.1365e+04 - val_loss: -1.1371e+04
# Epoch 55/100
# 0s - loss: -1.1381e+04 - val_loss: -1.1392e+04
# Epoch 56/100
# 0s - loss: -1.1393e+04 - val_loss: -1.1402e+04
# Epoch 57/100
# 0s - loss: -1.1404e+04 - val_loss: -1.1412e+04
# Epoch 58/100
# 0s - loss: -1.1422e+04 - val_loss: -1.1426e+04
# Epoch 59/100
# 0s - loss: -1.1437e+04 - val_loss: -1.1449e+04
# Epoch 60/100
# 0s - loss: -1.1449e+04 - val_loss: -1.1452e+04
# Epoch 61/100
# 0s - loss: -1.1458e+04 - val_loss: -1.1459e+04
# Epoch 62/100
# 0s - loss: -1.1467e+04 - val_loss: -1.1474e+04
# Epoch 63/100
# 0s - loss: -1.1474e+04 - val_loss: -1.1476e+04
# Epoch 64/100
# 0s - loss: -1.1477e+04 - val_loss: -1.1484e+04
# Epoch 65/100
# 0s - loss: -1.1485e+04 - val_loss: -1.1487e+04
# Epoch 66/100
# 0s - loss: -1.1493e+04 - val_loss: -1.1497e+04
# Epoch 67/100
# 0s - loss: -1.1486e+04 - val_loss: -1.1488e+04
# Epoch 68/100
# 0s - loss: -1.1491e+04 - val_loss: -1.1491e+04
# Epoch 69/100
# 0s - loss: -1.1494e+04 - val_loss: -1.1496e+04
# Epoch 70/100
# 0s - loss: -1.1500e+04 - val_loss: -1.1511e+04
# Epoch 71/100
# 0s - loss: -1.1512e+04 - val_loss: -1.1513e+04
# Epoch 72/100
# 0s - loss: -1.1513e+04 - val_loss: -1.1515e+04
# Epoch 73/100
# 0s - loss: -1.1515e+04 - val_loss: -1.1523e+04
# Epoch 74/100
# 0s - loss: -1.1526e+04 - val_loss: -1.1532e+04
# Epoch 75/100
# 0s - loss: -1.1532e+04 - val_loss: -1.1534e+04
# Epoch 76/100
# 0s - loss: -1.1534e+04 - val_loss: -1.1536e+04
# Epoch 77/100
# 0s - loss: -1.1542e+04 - val_loss: -1.1544e+04
# Epoch 78/100
# 0s - loss: -1.1543e+04 - val_loss: -1.1545e+04
# Epoch 79/100
# 0s - loss: -1.1548e+04 - val_loss: -1.1553e+04
# Epoch 80/100
# 0s - loss: -1.1554e+04 - val_loss: -1.1555e+04
# Epoch 81/100
# 0s - loss: -1.1555e+04 - val_loss: -1.1556e+04
# Epoch 82/100
# 0s - loss: -1.1557e+04 - val_loss: -1.1565e+04
# Epoch 83/100
# 0s - loss: -1.1573e+04 - val_loss: -1.1580e+04
# Epoch 84/100
# 0s - loss: -1.1581e+04 - val_loss: -1.1580e+04
# Epoch 85/100
# 0s - loss: -1.1592e+04 - val_loss: -1.1596e+04
# Epoch 86/100
# 0s - loss: -1.1596e+04 - val_loss: -1.1597e+04
# Epoch 87/100
# 0s - loss: -1.1601e+04 - val_loss: -1.1612e+04
# Epoch 88/100
# 0s - loss: -1.1611e+04 - val_loss: -1.1611e+04
# Epoch 89/100
# 0s - loss: -1.1613e+04 - val_loss: -1.1618e+04
# Epoch 90/100
# 0s - loss: -1.1617e+04 - val_loss: -1.1614e+04
# Epoch 91/100
# 0s - loss: -1.1617e+04 - val_loss: -1.1618e+04
# Epoch 92/100
# 0s - loss: -1.1619e+04 - val_loss: -1.1620e+04
# Epoch 93/100
# 0s - loss: -1.1620e+04 - val_loss: -1.1621e+04
# Epoch 94/100
# 0s - loss: -1.1623e+04 - val_loss: -1.1628e+04
# Epoch 95/100
# 0s - loss: -1.1628e+04 - val_loss: -1.1628e+04
# Epoch 96/100
# 0s - loss: -1.1628e+04 - val_loss: -1.1629e+04
# Epoch 97/100
# 0s - loss: -1.1629e+04 - val_loss: -1.1631e+04
# Epoch 98/100
# 0s - loss: -1.1637e+04 - val_loss: -1.1641e+04
# Epoch 99/100
# 0s - loss: -1.1649e+04 - val_loss: -1.1653e+04
# Epoch 100/100
# 0s - loss: -1.1652e+04 - val_loss: -1.1653e+04
# hiden node = 16
# Train on 1983 samples, validate on 1983 samples
# Epoch 1/100
# 0s - loss: 55.0804 - val_loss: 45.8572
# Epoch 2/100
# 0s - loss: 34.2546 - val_loss: 6.9515
# Epoch 3/100
# 0s - loss: 44.5969 - val_loss: 14.0525
# Epoch 4/100
# 0s - loss: -2.0546e+01 - val_loss: -1.8708e+01
# Epoch 5/100
# 0s - loss: 49.6640 - val_loss: 28.4148
# Epoch 6/100
# 0s - loss: 10.7708 - val_loss: -5.0584e+00
# Epoch 7/100
# 0s - loss: -2.0604e+01 - val_loss: -3.7425e+01
# Epoch 8/100
# 0s - loss: -4.8865e+01 - val_loss: -6.1878e+01
# Epoch 9/100
# 0s - loss: -6.8204e+01 - val_loss: -7.9989e+01
# Epoch 10/100
# 0s - loss: -8.8570e+01 - val_loss: -9.9964e+01
# Epoch 11/100
# 0s - loss: -1.0619e+02 - val_loss: -1.1399e+02
# Epoch 12/100
# 0s - loss: -1.2099e+02 - val_loss: -1.2694e+02
# Epoch 13/100
# 0s - loss: -1.3166e+02 - val_loss: -1.3876e+02
# Epoch 14/100
# 0s - loss: -1.4027e+02 - val_loss: -1.4390e+02
# Epoch 15/100
# 0s - loss: -1.4887e+02 - val_loss: -1.5382e+02
# Epoch 16/100
# 0s - loss: -1.5578e+02 - val_loss: -1.5773e+02
# Epoch 17/100
# 0s - loss: -1.6043e+02 - val_loss: -1.6574e+02
# Epoch 18/100
# 0s - loss: -1.6697e+02 - val_loss: -1.6801e+02
# Epoch 19/100
# 0s - loss: -1.7300e+02 - val_loss: -1.7573e+02
# Epoch 20/100
# 0s - loss: -1.7682e+02 - val_loss: -1.8121e+02
# Epoch 21/100
# 0s - loss: -1.8426e+02 - val_loss: -1.8713e+02
# Epoch 22/100
# 0s - loss: -1.8967e+02 - val_loss: -1.9139e+02
# Epoch 23/100
# 0s - loss: -1.9114e+02 - val_loss: -1.9051e+02
# Epoch 24/100
# 0s - loss: -1.9089e+02 - val_loss: -1.9329e+02
# Epoch 25/100
# 0s - loss: -1.9311e+02 - val_loss: -1.9345e+02
# Epoch 26/100
# 0s - loss: -1.9368e+02 - val_loss: -1.9662e+02
# Epoch 27/100
# 0s - loss: -1.9860e+02 - val_loss: -2.0135e+02
# Epoch 28/100
# 0s - loss: -2.0347e+02 - val_loss: -2.0692e+02
# Epoch 29/100
# 0s - loss: -2.0760e+02 - val_loss: -2.0887e+02
# Epoch 30/100
# 0s - loss: -2.0798e+02 - val_loss: -2.0688e+02
# Epoch 31/100
# 0s - loss: -2.0902e+02 - val_loss: -2.1202e+02
# Epoch 32/100
# 0s - loss: -2.1311e+02 - val_loss: -2.1289e+02
# Epoch 33/100
# 0s - loss: -2.1508e+02 - val_loss: -2.1676e+02
# Epoch 34/100
# 0s - loss: -2.1741e+02 - val_loss: -2.1535e+02
# Epoch 35/100
# 0s - loss: -2.1317e+02 - val_loss: -2.1473e+02
# Epoch 36/100
# 0s - loss: -2.1339e+02 - val_loss: -2.1287e+02
# Epoch 37/100
# 0s - loss: -2.1448e+02 - val_loss: -2.1453e+02
# Epoch 38/100
# 0s - loss: -2.1670e+02 - val_loss: -2.2091e+02
# Epoch 39/100
# 0s - loss: -2.2285e+02 - val_loss: -2.2446e+02
# Epoch 40/100
# 0s - loss: -2.2421e+02 - val_loss: -2.2385e+02
# Epoch 41/100
# 0s - loss: -2.2134e+02 - val_loss: -2.2206e+02
# Epoch 42/100
# 0s - loss: -2.2434e+02 - val_loss: -2.2505e+02
# Epoch 43/100
# 0s - loss: -2.2602e+02 - val_loss: -2.2828e+02
# Epoch 44/100
# 0s - loss: -2.2990e+02 - val_loss: -2.3209e+02
# Epoch 45/100
# 0s - loss: -2.3386e+02 - val_loss: -2.3641e+02
# Epoch 46/100
# 0s - loss: -2.3772e+02 - val_loss: -2.3623e+02
# Epoch 47/100
# 0s - loss: -2.3600e+02 - val_loss: -2.3845e+02
# Epoch 48/100
# 0s - loss: -2.3956e+02 - val_loss: -2.4085e+02
# Epoch 49/100
# 0s - loss: -2.4267e+02 - val_loss: -2.4135e+02
# Epoch 50/100
# 0s - loss: -2.3967e+02 - val_loss: -2.3797e+02
# Epoch 51/100
# 0s - loss: -2.3916e+02 - val_loss: -2.3676e+02
# Epoch 52/100
# 0s - loss: -2.3915e+02 - val_loss: -2.4226e+02
# Epoch 53/100
# 0s - loss: -2.3503e+02 - val_loss: -2.3152e+02
# Epoch 54/100
# 0s - loss: -2.2879e+02 - val_loss: -2.2082e+02
# Epoch 55/100
# 0s - loss: 7.2703 - val_loss: 73.0194
# Epoch 56/100
# 0s - loss: 22.7365 - val_loss: -3.3026e+01
# Epoch 57/100
# 0s - loss: -6.0609e+01 - val_loss: -8.9237e+01
# Epoch 58/100
# 0s - loss: -1.0629e+02 - val_loss: -1.2329e+02
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =988
# SourceData's aborting data = 22
# window shape is (988, 2048, 3)
# (988, 2048, 3)
# hiden node = 16
# Train on 988 samples, validate on 988 samples
# Epoch 1/100
# 0s - loss: -7.2340e+03 - val_loss: -7.5836e+03
# Epoch 2/100
# 0s - loss: -7.7103e+03 - val_loss: -7.9606e+03
# Epoch 3/100
# 0s - loss: -8.0660e+03 - val_loss: -8.2202e+03
# Epoch 4/100
# 0s - loss: -8.2780e+03 - val_loss: -8.3479e+03
# Epoch 5/100
# 0s - loss: -8.3802e+03 - val_loss: -8.4343e+03
# Epoch 6/100
# 0s - loss: -8.4591e+03 - val_loss: -8.5013e+03
# Epoch 7/100
# 0s - loss: -8.5221e+03 - val_loss: -8.5543e+03
# Epoch 8/100
# 0s - loss: -8.5769e+03 - val_loss: -8.6043e+03
# Epoch 9/100
# 0s - loss: -8.6238e+03 - val_loss: -8.6563e+03
# Epoch 10/100
# 0s - loss: -8.6711e+03 - val_loss: -8.7000e+03
# Epoch 11/100
# 0s - loss: -8.7173e+03 - val_loss: -8.7466e+03
# Epoch 12/100
# 0s - loss: -8.7594e+03 - val_loss: -8.7863e+03
# Epoch 13/100
# 0s - loss: -8.7949e+03 - val_loss: -8.8085e+03
# Epoch 14/100
# 0s - loss: -8.8193e+03 - val_loss: -8.8422e+03
# Epoch 15/100
# 0s - loss: -8.8529e+03 - val_loss: -8.8780e+03
# Epoch 16/100
# 0s - loss: -8.8879e+03 - val_loss: -8.9062e+03
# Epoch 17/100
# 0s - loss: -8.9189e+03 - val_loss: -8.9335e+03
# Epoch 18/100
# 0s - loss: -8.9430e+03 - val_loss: -8.9628e+03
# Epoch 19/100
# 0s - loss: -8.9719e+03 - val_loss: -8.9923e+03
# Epoch 20/100
# 0s - loss: -9.0028e+03 - val_loss: -9.0201e+03
# Epoch 21/100
# 0s - loss: -9.0270e+03 - val_loss: -9.0384e+03
# Epoch 22/100
# 0s - loss: -9.0408e+03 - val_loss: -9.0492e+03
# Epoch 23/100
# 0s - loss: -9.0578e+03 - val_loss: -9.0719e+03
# Epoch 24/100
# 0s - loss: -9.0783e+03 - val_loss: -9.0972e+03
# Epoch 25/100
# 0s - loss: -9.1053e+03 - val_loss: -9.1199e+03
# Epoch 26/100
# 0s - loss: -9.1341e+03 - val_loss: -9.1532e+03
# Epoch 27/100
# 0s - loss: -9.1599e+03 - val_loss: -9.1686e+03
# Epoch 28/100
# 0s - loss: -9.1748e+03 - val_loss: -9.1887e+03
# Epoch 29/100
# 0s - loss: -9.1933e+03 - val_loss: -9.2075e+03
# Epoch 30/100
# 0s - loss: -9.2116e+03 - val_loss: -9.2147e+03
# Epoch 31/100
# 0s - loss: -9.2242e+03 - val_loss: -9.2309e+03
# Epoch 32/100
# 0s - loss: -9.2357e+03 - val_loss: -9.2395e+03
# Epoch 33/100
# 0s - loss: -9.2492e+03 - val_loss: -9.2640e+03
# Epoch 34/100
# 0s - loss: -9.2686e+03 - val_loss: -9.2768e+03
# Epoch 35/100
# 0s - loss: -9.2836e+03 - val_loss: -9.2923e+03
# Epoch 36/100
# 0s - loss: -9.2970e+03 - val_loss: -9.3027e+03
# Epoch 37/100
# 0s - loss: -9.3074e+03 - val_loss: -9.3128e+03
# Epoch 38/100
# 0s - loss: -9.3162e+03 - val_loss: -9.3236e+03
# Epoch 39/100
# 0s - loss: -9.3276e+03 - val_loss: -9.3393e+03
# Epoch 40/100
# 0s - loss: -9.3430e+03 - val_loss: -9.3518e+03
# Epoch 41/100
# 0s - loss: -9.3578e+03 - val_loss: -9.3687e+03
# Epoch 42/100
# 0s - loss: -9.3696e+03 - val_loss: -9.3829e+03
# Epoch 43/100
# 0s - loss: -9.3885e+03 - val_loss: -9.3974e+03
# Epoch 44/100
# 0s - loss: -9.3986e+03 - val_loss: -9.4029e+03
# Epoch 45/100
# 0s - loss: -9.4073e+03 - val_loss: -9.4145e+03
# Epoch 46/100
# 0s - loss: -9.4152e+03 - val_loss: -9.4203e+03
# Epoch 47/100
# 0s - loss: -9.4206e+03 - val_loss: -9.4266e+03
# Epoch 48/100
# 0s - loss: -9.4281e+03 - val_loss: -9.4335e+03
# Epoch 49/100
# 0s - loss: -9.4371e+03 - val_loss: -9.4440e+03
# Epoch 50/100
# 0s - loss: -9.4462e+03 - val_loss: -9.4509e+03
# Epoch 51/100
# 0s - loss: -9.4510e+03 - val_loss: -9.4511e+03
# Epoch 52/100
# 0s - loss: -9.4589e+03 - val_loss: -9.4628e+03
# Epoch 53/100
# 0s - loss: -9.4643e+03 - val_loss: -9.4696e+03
# Epoch 54/100
# 0s - loss: -9.4714e+03 - val_loss: -9.4809e+03
# Epoch 55/100
# 0s - loss: -9.4823e+03 - val_loss: -9.4856e+03
# Epoch 56/100
# 0s - loss: -9.4854e+03 - val_loss: -9.4892e+03
# Epoch 57/100
# 0s - loss: -9.4939e+03 - val_loss: -9.5068e+03
# Epoch 58/100
# 0s - loss: -9.5071e+03 - val_loss: -9.5102e+03
# Epoch 59/100
# 0s - loss: -9.5116e+03 - val_loss: -9.5150e+03
# Epoch 60/100
# 0s - loss: -9.5158e+03 - val_loss: -9.5167e+03
# Epoch 61/100
# 0s - loss: -9.5198e+03 - val_loss: -9.5235e+03
# Epoch 62/100
# 0s - loss: -9.5257e+03 - val_loss: -9.5289e+03
# Epoch 63/100
# 0s - loss: -9.5302e+03 - val_loss: -9.5333e+03
# Epoch 64/100
# 0s - loss: -9.5351e+03 - val_loss: -9.5417e+03
# Epoch 65/100
# 0s - loss: -9.5426e+03 - val_loss: -9.5464e+03
# Epoch 66/100
# 0s - loss: -9.5453e+03 - val_loss: -9.5461e+03
# Epoch 67/100
# 0s - loss: -9.5497e+03 - val_loss: -9.5510e+03
# Epoch 68/100
# 0s - loss: -9.5532e+03 - val_loss: -9.5581e+03
# Epoch 69/100
# 0s - loss: -9.5594e+03 - val_loss: -9.5661e+03
# Epoch 70/100
# 0s - loss: -9.5697e+03 - val_loss: -9.5768e+03
# Epoch 71/100
# 0s - loss: -9.5772e+03 - val_loss: -9.5808e+03
# Epoch 72/100
# 0s - loss: -9.5828e+03 - val_loss: -9.5900e+03
# Epoch 73/100
# 0s - loss: -9.5894e+03 - val_loss: -9.5896e+03
# Epoch 74/100
# 0s - loss: -9.5930e+03 - val_loss: -9.5977e+03
# Epoch 75/100
# 0s - loss: -9.6028e+03 - val_loss: -9.6097e+03
# Epoch 76/100
# 0s - loss: -9.6134e+03 - val_loss: -9.6163e+03
# Epoch 77/100
# 0s - loss: -9.6190e+03 - val_loss: -9.6255e+03
# Epoch 78/100
# 0s - loss: -9.6233e+03 - val_loss: -9.6288e+03
# Epoch 79/100
# 0s - loss: -9.6292e+03 - val_loss: -9.6340e+03
# Epoch 80/100
# 0s - loss: -9.6321e+03 - val_loss: -9.6362e+03
# Epoch 81/100
# 0s - loss: -9.6372e+03 - val_loss: -9.6354e+03
# Epoch 82/100
# 0s - loss: -9.6385e+03 - val_loss: -9.6412e+03
# Epoch 83/100
# 0s - loss: -9.6449e+03 - val_loss: -9.6470e+03
# Epoch 84/100
# 0s - loss: -9.6485e+03 - val_loss: -9.6513e+03
# Epoch 85/100
# 0s - loss: -9.6519e+03 - val_loss: -9.6560e+03
# Epoch 86/100
# 0s - loss: -9.6567e+03 - val_loss: -9.6596e+03
# Epoch 87/100
# 0s - loss: -9.6622e+03 - val_loss: -9.6597e+03
# Epoch 88/100
# 0s - loss: -9.6621e+03 - val_loss: -9.6661e+03
# Epoch 89/100
# 0s - loss: -9.6675e+03 - val_loss: -9.6738e+03
# Epoch 90/100
# 0s - loss: -9.6716e+03 - val_loss: -9.6717e+03
# Epoch 91/100
# 0s - loss: -9.6767e+03 - val_loss: -9.6788e+03
# Epoch 92/100
# 0s - loss: -9.6813e+03 - val_loss: -9.6826e+03
# Epoch 93/100
# 0s - loss: -9.6835e+03 - val_loss: -9.6874e+03
# Epoch 94/100
# 0s - loss: -9.6863e+03 - val_loss: -9.6873e+03
# Epoch 95/100
# 0s - loss: -9.6864e+03 - val_loss: -9.6878e+03
# Epoch 96/100
# 0s - loss: -9.6880e+03 - val_loss: -9.6848e+03
# Epoch 97/100
# 0s - loss: -9.6871e+03 - val_loss: -9.6877e+03
# Epoch 98/100
# 0s - loss: -9.6923e+03 - val_loss: -9.6942e+03
# Epoch 99/100
# 0s - loss: -9.6938e+03 - val_loss: -9.6916e+03
# Epoch 100/100
# 0s - loss: -9.6976e+03 - val_loss: -9.7016e+03
# hiden node = 16
# Train on 988 samples, validate on 988 samples
# Epoch 1/100
# 0s - loss: -1.6548e+04 - val_loss: -1.7265e+04
# Epoch 2/100
# 0s - loss: -1.7583e+04 - val_loss: -1.7996e+04
# Epoch 3/100
# 0s - loss: -1.8170e+04 - val_loss: -1.8423e+04
# Epoch 4/100
# 0s - loss: -1.8509e+04 - val_loss: -1.8673e+04
# Epoch 5/100
# 0s - loss: -1.8762e+04 - val_loss: -1.8938e+04
# Epoch 6/100
# 0s - loss: -1.9015e+04 - val_loss: -1.9161e+04
# Epoch 7/100
# 0s - loss: -1.9225e+04 - val_loss: -1.9322e+04
# Epoch 8/100
# 0s - loss: -1.9384e+04 - val_loss: -1.9485e+04
# Epoch 9/100
# 0s - loss: -1.9527e+04 - val_loss: -1.9583e+04
# Epoch 10/100
# 0s - loss: -1.9628e+04 - val_loss: -1.9703e+04
# Epoch 11/100
# 0s - loss: -1.9735e+04 - val_loss: -1.9787e+04
# Epoch 12/100
# 0s - loss: -1.9811e+04 - val_loss: -1.9862e+04
# Epoch 13/100
# 0s - loss: -1.9900e+04 - val_loss: -1.9958e+04
# Epoch 14/100
# 0s - loss: -1.9988e+04 - val_loss: -2.0049e+04
# Epoch 15/100
# 0s - loss: -2.0101e+04 - val_loss: -2.0187e+04
# Epoch 16/100
# 0s - loss: -2.0209e+04 - val_loss: -2.0254e+04
# Epoch 17/100
# 0s - loss: -2.0280e+04 - val_loss: -2.0325e+04
# Epoch 18/100
# 0s - loss: -2.0344e+04 - val_loss: -2.0391e+04
# Epoch 19/100
# 0s - loss: -2.0419e+04 - val_loss: -2.0449e+04
# Epoch 20/100
# 0s - loss: -2.0476e+04 - val_loss: -2.0514e+04
# Epoch 21/100
# 0s - loss: -2.0530e+04 - val_loss: -2.0575e+04
# Epoch 22/100
# 0s - loss: -2.0589e+04 - val_loss: -2.0612e+04
# Epoch 23/100
# 0s - loss: -2.0617e+04 - val_loss: -2.0640e+04
# Epoch 24/100
# 0s - loss: -2.0647e+04 - val_loss: -2.0666e+04
# Epoch 25/100
# 0s - loss: -2.0682e+04 - val_loss: -2.0717e+04
# Epoch 26/100
# 0s - loss: -2.0744e+04 - val_loss: -2.0780e+04
# Epoch 27/100
# 0s - loss: -2.0790e+04 - val_loss: -2.0823e+04
# Epoch 28/100
# 0s - loss: -2.0839e+04 - val_loss: -2.0863e+04
# Epoch 29/100
# 0s - loss: -2.0878e+04 - val_loss: -2.0888e+04
# Epoch 30/100
# 0s - loss: -2.0902e+04 - val_loss: -2.0936e+04
# Epoch 31/100
# 0s - loss: -2.0944e+04 - val_loss: -2.0900e+04
# Epoch 32/100
# 0s - loss: -2.0979e+04 - val_loss: -2.1017e+04
# Epoch 33/100
# 0s - loss: -2.1046e+04 - val_loss: -2.1079e+04
# Epoch 34/100
# 0s - loss: -2.1089e+04 - val_loss: -2.1101e+04
# Epoch 35/100
# 0s - loss: -2.1120e+04 - val_loss: -2.1155e+04
# Epoch 36/100
# 0s - loss: -2.1169e+04 - val_loss: -2.1197e+04
# Epoch 37/100
# 0s - loss: -2.1213e+04 - val_loss: -2.1237e+04
# Epoch 38/100
# 0s - loss: -2.1249e+04 - val_loss: -2.1282e+04
# Epoch 39/100
# 0s - loss: -2.1302e+04 - val_loss: -2.1326e+04
# Epoch 40/100
# 0s - loss: -2.1336e+04 - val_loss: -2.1341e+04
# Epoch 41/100
# 0s - loss: -2.1363e+04 - val_loss: -2.1382e+04
# Epoch 42/100
# 0s - loss: -2.1388e+04 - val_loss: -2.1398e+04
# Epoch 43/100
# 0s - loss: -2.1405e+04 - val_loss: -2.1415e+04
# Epoch 44/100
# 0s - loss: -2.1424e+04 - val_loss: -2.1445e+04
# Epoch 45/100
# 0s - loss: -2.1458e+04 - val_loss: -2.1474e+04
# Epoch 46/100
# 0s - loss: -2.1482e+04 - val_loss: -2.1496e+04
# Epoch 47/100
# 0s - loss: -2.1499e+04 - val_loss: -2.1508e+04
# Epoch 48/100
# 0s - loss: -2.1528e+04 - val_loss: -2.1564e+04
# Epoch 49/100
# 0s - loss: -2.1573e+04 - val_loss: -2.1582e+04
# Epoch 50/100
# 0s - loss: -2.1555e+04 - val_loss: -2.1397e+04
# Epoch 51/100
# 0s - loss: -2.1528e+04 - val_loss: -2.1612e+04
# Epoch 52/100
# 0s - loss: -2.1614e+04 - val_loss: -2.1623e+04
# Epoch 53/100
# 0s - loss: -2.1627e+04 - val_loss: -2.1633e+04
# Epoch 54/100
# 0s - loss: -2.1646e+04 - val_loss: -2.1668e+04
# Epoch 55/100
# 0s - loss: -2.1652e+04 - val_loss: -2.1653e+04
# Epoch 56/100
# 0s - loss: -2.1678e+04 - val_loss: -2.1700e+04
# Epoch 57/100
# 0s - loss: -2.1696e+04 - val_loss: -2.1697e+04
# Epoch 58/100
# 0s - loss: -2.1698e+04 - val_loss: -2.1702e+04
# Epoch 59/100
# 0s - loss: -2.1713e+04 - val_loss: -2.1726e+04
# Epoch 60/100
# 0s - loss: -2.1720e+04 - val_loss: -2.1720e+04
# Epoch 61/100
# 0s - loss: -2.1719e+04 - val_loss: -2.1700e+04
# Epoch 62/100
# 0s - loss: -2.1723e+04 - val_loss: -2.1719e+04
# Epoch 63/100
# 0s - loss: -2.1729e+04 - val_loss: -2.1746e+04
# Epoch 64/100
# 0s - loss: -2.1747e+04 - val_loss: -2.1759e+04
# Epoch 65/100
# 0s - loss: -2.1750e+04 - val_loss: -2.1754e+04
# Epoch 66/100
# 0s - loss: -2.1758e+04 - val_loss: -2.1774e+04
# Epoch 67/100
# 0s - loss: -2.1780e+04 - val_loss: -2.1771e+04
# Epoch 68/100
# 0s - loss: -2.1789e+04 - val_loss: -2.1785e+04
# Epoch 69/100
# 0s - loss: -2.1794e+04 - val_loss: -2.1819e+04
# Epoch 70/100
# 0s - loss: -2.1818e+04 - val_loss: -2.1811e+04
# Epoch 71/100
# 0s - loss: -2.1813e+04 - val_loss: -2.1818e+04
# Epoch 72/100
# 0s - loss: -2.1817e+04 - val_loss: -2.1822e+04
# Epoch 73/100
# 0s - loss: -2.1830e+04 - val_loss: -2.1844e+04
# Epoch 74/100
# 0s - loss: -2.1844e+04 - val_loss: -2.1845e+04
# Epoch 75/100
# 0s - loss: -2.1850e+04 - val_loss: -2.1862e+04
# Epoch 76/100
# 0s - loss: -2.1863e+04 - val_loss: -2.1874e+04
# Epoch 77/100
# 0s - loss: -2.1881e+04 - val_loss: -2.1895e+04
# Epoch 78/100
# 0s - loss: -2.1897e+04 - val_loss: -2.1909e+04
# Epoch 79/100
# 0s - loss: -2.1914e+04 - val_loss: -2.1910e+04
# Epoch 80/100
# 0s - loss: -2.1921e+04 - val_loss: -2.1927e+04
# Epoch 81/100
# 0s - loss: -2.1928e+04 - val_loss: -2.1928e+04
# Epoch 82/100
# 0s - loss: -2.1937e+04 - val_loss: -2.1945e+04
# Epoch 83/100
# 0s - loss: -2.1943e+04 - val_loss: -2.1952e+04
# Epoch 84/100
# 0s - loss: -2.1954e+04 - val_loss: -2.1966e+04
# Epoch 85/100
# 0s - loss: -2.1964e+04 - val_loss: -2.1966e+04
# Epoch 86/100
# 0s - loss: -2.1972e+04 - val_loss: -2.1980e+04
# Epoch 87/100
# 0s - loss: -2.1986e+04 - val_loss: -2.1994e+04
# Epoch 88/100
# 0s - loss: -2.1995e+04 - val_loss: -2.2006e+04
# Epoch 89/100
# 0s - loss: -2.2008e+04 - val_loss: -2.2021e+04
# Epoch 90/100
# 0s - loss: -2.2026e+04 - val_loss: -2.2037e+04
# Epoch 91/100
# 0s - loss: -2.2035e+04 - val_loss: -2.2031e+04
# Epoch 92/100
# 0s - loss: -2.2033e+04 - val_loss: -2.2033e+04
# Epoch 93/100
# 0s - loss: -2.2037e+04 - val_loss: -2.2043e+04
# Epoch 94/100
# 0s - loss: -2.2039e+04 - val_loss: -2.2045e+04
# Epoch 95/100
# 0s - loss: -2.2046e+04 - val_loss: -2.2051e+04
# Epoch 96/100
# 0s - loss: -2.2051e+04 - val_loss: -2.2048e+04
# Epoch 97/100
# 0s - loss: -2.2050e+04 - val_loss: -2.2061e+04
# Epoch 98/100
# 0s - loss: -2.2060e+04 - val_loss: -2.2053e+04
# Epoch 99/100
# 0s - loss: -2.2059e+04 - val_loss: -2.2065e+04
# Epoch 100/100
# 0s - loss: -2.2066e+04 - val_loss: -2.2074e+04
# hiden node = 16
# Train on 988 samples, validate on 988 samples
# Epoch 1/100
# 0s - loss: 82.4563 - val_loss: 84.9972
# Epoch 2/100
# 0s - loss: 72.8605 - val_loss: 110.6680
# Epoch 3/100
# 0s - loss: 118.8569 - val_loss: 125.5333
# Epoch 4/100
# 0s - loss: 125.6036 - val_loss: 122.2666
# Epoch 5/100
# 0s - loss: 121.0902 - val_loss: 116.3111
# Epoch 6/100
# 0s - loss: 113.8640 - val_loss: 109.9126
# Epoch 7/100
# 0s - loss: 107.4632 - val_loss: 101.6999

# %%
print "finish
# Out:
#   File "<ipython-input-8-ff76b7c1dbed>", line 1
#     print "finish
#                 ^
# SyntaxError: EOL while scanning string literal
