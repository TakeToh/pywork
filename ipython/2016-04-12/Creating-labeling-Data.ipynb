# %%
def add_label(data,label):
    start = time.time()
    data[u'label']=0
    label_num=1
    for i in range(0,len(data)):
        
        if label_num!=len(label):
            if data[u'時刻'][i] > label[u'#Time'][label_num]:
                label_num +=1
            
        data[u'label'][i]=label[u'Info1'][label_num-1]
        
        #debug
        #print 'mm[label][%d]=%s' %(i,mm[u'label'][i])
    elapsed_time = time.time() - start
    print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack
from scipy import signal
import pandas as pd
import time
# %matplotlib inline

# %%
cd ~/Documents/01_SensorData/2016_04_04/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/01_SensorData/2016_04_04/cleaning-addingLABEL

# %%
ls
# Out:
# 20160331_180615.srt         SP-right-hand-acc.dat.cache
# Cleaning_left_hand_ags.csv  SP-right-hand-batt.dat
# Conv-left-hand-ags.csv      SP-right-hand-gyr.dat
# Conv-left-hand-batt.csv     SP-right-hand-gyr.dat.cache
# Conv-left-leg-ags.csv       SP-right-leg-acc.dat
# Conv-left-leg-batt.csv      SP-right-leg-acc.dat.cache
# Conv-right-hand-ags.csv     SP-right-leg-batt.dat
# Conv-right-hand-batt.csv    SP-right-leg-gyr.dat
# Conv-right-leg-ags.csv      SP-right-leg-gyr.dat.cache
# Conv-right-leg-batt.csv     SP-west-acc.dat
# Conv-west-ags.csv           SP-west-acc.dat.cache
# Conv-west-batt.csv          SP-west-batt.dat
# DeviceSet1.avi              SP-west-gyr.dat
# SP-left-hand-acc.dat        SP-west-gyr.dat.cache
# SP-left-hand-acc.dat.cache  cleaning.spe
# SP-left-hand-batt.dat       cleaning_20160331.csv
# SP-left-hand-gyr.dat        cleaning_20160331.spa
# SP-left-hand-gyr.dat.cache  cleaning_20160331.spa.old
# SP-left-leg-acc.dat         left-hand.csv
# SP-left-leg-acc.dat.cache   left-leg.csv
# SP-left-leg-batt.dat        right-hand.csv
# SP-left-leg-gyr.dat         right-leg.csv
# SP-left-leg-gyr.dat.cache   west.csv
# SP-right-hand-acc.dat

# %%
data = pd.read_csv('Conv-left-hand-ags.csv',encoding="SHIFT-JIS")

# %%
data
# Out:
#         種別            時刻  加速度X   加速度Y  加速度Z   角速度X   角速度Y   角速度Z
# 0      ags  18:06:15.696  8226   7922  -543  35311   7196   -953
# 1      ags  18:06:15.706  8058   8437  -582  36141   5974  -2270
# 2      ags  18:06:15.716  8292   9091  -231  35395   4803  -3402
# 3      ags  18:06:15.726  7628  11183  -436  32518   3560  -4706
# 4      ags  18:06:15.736  7811  13112  -370  27451   1863  -5504
# 5      ags  18:06:15.746  7496  13971  -375  20880    -85  -6060
# 6      ags  18:06:15.756  7459  13967  -302  14215  -2121  -6425
# 7      ags  18:06:15.766  7171  13822  -204   7738  -3918  -6913
# 8      ags  18:06:15.776  7054  13510  -226   1725  -5776  -7469
# 9      ags  18:06:15.786  7008  13061  -141  -3581  -7509  -8049
# 55460  ags  18:15:30.296 -1031   7680 -5683  -1194   5892  -3965
# 55461  ags  18:15:30.306 -1080   8547 -6229   -952   5988  -4035
# 55462  ags  18:15:30.316 -1094   9242 -6620   -532   6023  -4296
# 55463  ags  18:15:30.326 -1316   9467 -6803   -158   5909  -4455
# 55464  ags  18:15:30.336 -1597   9423 -6911    -70   5710  -4718
# 55465  ags  18:15:30.346 -1832   8884 -6539   -403   5568  -4680
# 55466  ags  18:15:30.356 -1585   7836 -5997   -939   5506  -4449
# 55467  ags  18:15:30.366 -1705   7001 -5275   -858   5547  -3951
# 55468  ags  18:15:30.376 -1397   7067 -5123   -459   5600  -3690
# 55469  ags  18:15:30.386 -1346   7526 -4901   -253   5786  -3273
# 55470  ags  18:15:30.396 -1292   8188 -5248   -267   6015  -2973
#
# [55471 rows x 8 columns]

# %%
label=pd.read_csv("cleaning_20160331.csv",encoding="SHIFT-JIS")
label[u'#Time']=pd.to_datetime(label[u'#Time'])
label
# Out:
#                       #Time                        Info1  Info2  Info3
# 0   2016-04-13 18:06:15.696                      walking    NaN    NaN
# 1   2016-04-13 18:06:18.745                 walking-turn    NaN    NaN
# 2   2016-04-13 18:06:19.570                      walking    NaN    NaN
# 3   2016-04-13 18:06:23.588                 walking-turn    NaN    NaN
# 4   2016-04-13 18:06:24.492                      walking    NaN    NaN
# 5   2016-04-13 18:06:28.200                 walking-turn    NaN    NaN
# 6   2016-04-13 18:06:29.954                      walking    NaN    NaN
# 7   2016-04-13 18:06:33.333                 walking-turn    NaN    NaN
# 8   2016-04-13 18:06:34.999                      walking    NaN    NaN
# 9   2016-04-13 18:06:39.181                 walking-turn    NaN    NaN
# 10  2016-04-13 18:06:44.914                 walking-turn    NaN    NaN
# 11  2016-04-13 18:06:45.904             walking-back-arm    NaN    NaN
# 12  2016-04-13 18:06:50.468        walking-back-arm-turn    NaN    NaN
# 13  2016-04-13 18:06:51.878             walking-back-arm    NaN    NaN
# 14  2016-04-13 18:06:55.595        walking-back-arm-turn    NaN    NaN
# 15  2016-04-13 18:06:57.390             walking-back-arm    NaN    NaN
# 16  2016-04-13 18:07:00.560            walking-cross-arm    NaN    NaN
# 17  2016-04-13 18:07:01.884       walking-cross-arm-turn    NaN    NaN
# 18  2016-04-13 18:07:03.487            walking-cross-arm    NaN    NaN
# 19  2016-04-13 18:07:07.542       walking-cross-arm-turn    NaN    NaN
# 20  2016-04-13 18:07:09.139            walking-cross-arm    NaN    NaN
# 21  2016-04-13 18:07:13.208       walking-cross-arm-turn    NaN    NaN
# 22  2016-04-13 18:07:15.430            walking-cross-arm    NaN    NaN
# 23  2016-04-13 18:07:19.466       walking-cross-arm-turn    NaN    NaN
# 24  2016-04-13 18:07:21.022            walking-cross-arm    NaN    NaN
# 25  2016-04-13 18:07:23.462                      walking    NaN    NaN
# 26  2016-04-13 18:07:24.360               grap-small-box    NaN    NaN
# 27  2016-04-13 18:07:25.316               rift-small-box    NaN    NaN
# 28  2016-04-13 18:07:27.035       walking-with-small-box    NaN    NaN
# 29  2016-04-13 18:07:30.612  walking-with-small-box-turn    NaN    NaN
# ..                      ...                          ...    ...    ...
# 147 2016-04-13 18:13:57.386                 walking-turn    NaN    NaN
# 148 2016-04-13 18:14:00.854                      walking    NaN    NaN
# 149 2016-04-13 18:14:04.031                 walking-turn    NaN    NaN
# 150 2016-04-13 18:14:05.844                      walking    NaN    NaN
# 151 2016-04-13 18:14:09.631                 walking-turn    NaN    NaN
# 152 2016-04-13 18:14:11.867                      walking    NaN    NaN
# 153 2016-04-13 18:14:14.867                          止まる    NaN    NaN
# 154 2016-04-13 18:14:15.871                       腕のみ動かす    NaN    NaN
# 155 2016-04-13 18:14:25.706                      walking    NaN    NaN
# 156 2016-04-13 18:14:28.013                          止まる    NaN    NaN
# 157 2016-04-13 18:14:29.862                      walking    NaN    NaN
# 158 2016-04-13 18:14:32.954                 walking-turn    NaN    NaN
# 159 2016-04-13 18:14:34.098                      walking    NaN    NaN
# 160 2016-04-13 18:14:38.841                 walking-turn    NaN    NaN
# 161 2016-04-13 18:14:41.028              walking-腕を振りながら    NaN    NaN
# 162 2016-04-13 18:14:45.999         walking-腕を振りながら-turn    NaN    NaN
# 163 2016-04-13 18:14:48.520                      walking    NaN    NaN
# 164 2016-04-13 18:14:49.315                 walking-turn    NaN    NaN
# 165 2016-04-13 18:14:51.306                      walking    NaN    NaN
# 166 2016-04-13 18:14:52.283                 walking-turn    NaN    NaN
# 167 2016-04-13 18:14:54.227                      walking    NaN    NaN
# 168 2016-04-13 18:14:57.640                 walking-turn    NaN    NaN
# 169 2016-04-13 18:14:59.673                      walking    NaN    NaN
# 170 2016-04-13 18:15:02.634                 walking-turn    NaN    NaN
# 171 2016-04-13 18:15:08.019                      walking    NaN    NaN
# 172 2016-04-13 18:15:12.407                 walking-turn    NaN    NaN
# 173 2016-04-13 18:15:16.504                      walking    NaN    NaN
# 174 2016-04-13 18:15:20.073                          止まる    NaN    NaN
# 175 2016-04-13 18:15:21.180                      walking    NaN    NaN
# 176 2016-04-13 18:15:22.789                           不明    NaN    NaN
#
# [177 rows x 4 columns]

# %%
'Cleaning'+'aaa'
# Out:
# 'Cleaningaaa'

# %%
data=[u'Conv-left-hand-ags.csv',u'Conv-left-leg-ags.csv',u'Conv-right-hand-ags.csv',
        u'Conv-right-leg-ags.csv',u'Conv-west-ags.csv']

label=pd.read_csv("cleaning_20160331.csv",encoding="SHIFT-JIS")
label[u'#Time']=pd.to_datetime(label[u'#Time'])

for i in range(5):
    df = pd.read_csv(data[i],encoding="SHIFT-JIS")
    df[u'時刻']=pd.to_datetime(df[u'時刻'])
    add_label(df,label)
    
    df.to_csv('Cleaning'+data[i],encoding='SHIFT-JIS')
# Out:
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
