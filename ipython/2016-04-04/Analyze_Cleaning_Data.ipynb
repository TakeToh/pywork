# %%
import pandas as pd

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import time

# %%
ls
# Out:
# 20160331_180615.srt         SP-right-hand-acc.dat.cache
# Conv-left-hand-ags.csv      SP-right-hand-batt.dat
# Conv-left-hand-batt.csv     SP-right-hand-gyr.dat
# Conv-left-leg-ags.csv       SP-right-hand-gyr.dat.cache
# Conv-left-leg-batt.csv      SP-right-leg-acc.dat
# Conv-right-hand-ags.csv     SP-right-leg-acc.dat.cache
# Conv-right-hand-batt.csv    SP-right-leg-batt.dat
# Conv-right-leg-ags.csv      SP-right-leg-gyr.dat
# Conv-right-leg-batt.csv     SP-right-leg-gyr.dat.cache
# Conv-west-ags.csv           SP-west-acc.dat
# Conv-west-batt.csv          SP-west-acc.dat.cache
# DeviceSet1.avi              SP-west-batt.dat
# SP-left-hand-acc.dat        SP-west-gyr.dat
# SP-left-hand-acc.dat.cache  SP-west-gyr.dat.cache
# SP-left-hand-batt.dat       cleaning.spe
# SP-left-hand-gyr.dat        cleaning_20160331.csv
# SP-left-hand-gyr.dat.cache  cleaning_20160331.spa
# SP-left-leg-acc.dat         cleaning_20160331.spa.old
# SP-left-leg-acc.dat.cache   left-hand.csv
# SP-left-leg-batt.dat        left-leg.csv
# SP-left-leg-gyr.dat         right-hand.csv
# SP-left-leg-gyr.dat.cache   right-leg.csv
# SP-right-hand-acc.dat       west.csv

# %%
cd ~/Documents/01_SensorData/2016_04_04/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/01_SensorData/2016_04_04/cleaning-addingLABEL

# %%
ls
# Out:
# 20160331_180615.srt         SP-right-hand-acc.dat.cache
# Conv-left-hand-ags.csv      SP-right-hand-batt.dat
# Conv-left-hand-batt.csv     SP-right-hand-gyr.dat
# Conv-left-leg-ags.csv       SP-right-hand-gyr.dat.cache
# Conv-left-leg-batt.csv      SP-right-leg-acc.dat
# Conv-right-hand-ags.csv     SP-right-leg-acc.dat.cache
# Conv-right-hand-batt.csv    SP-right-leg-batt.dat
# Conv-right-leg-ags.csv      SP-right-leg-gyr.dat
# Conv-right-leg-batt.csv     SP-right-leg-gyr.dat.cache
# Conv-west-ags.csv           SP-west-acc.dat
# Conv-west-batt.csv          SP-west-acc.dat.cache
# DeviceSet1.avi              SP-west-batt.dat
# SP-left-hand-acc.dat        SP-west-gyr.dat
# SP-left-hand-acc.dat.cache  SP-west-gyr.dat.cache
# SP-left-hand-batt.dat       cleaning.spe
# SP-left-hand-gyr.dat        cleaning_20160331.csv
# SP-left-hand-gyr.dat.cache  cleaning_20160331.spa
# SP-left-leg-acc.dat         cleaning_20160331.spa.old
# SP-left-leg-acc.dat.cache   left-hand.csv
# SP-left-leg-batt.dat        left-leg.csv
# SP-left-leg-gyr.dat         right-hand.csv
# SP-left-leg-gyr.dat.cache   right-leg.csv
# SP-right-hand-acc.dat       west.csv

# %%
raw_left_hand_ags=pd.read_csv("Conv-left-hand-ags.csv",encoding="SHIFT-JIS")
raw_left_hand_ags[u'時刻']=pd.to_datetime(raw_left_hand_ags[u'時刻'])
raw_right_hand_ags=pd.read_csv("Conv-right-hand-ags.csv",encoding="SHIFT-JIS")
raw_right_hand_ags[u'時刻']=pd.to_datetime(raw_right_hand_ags[u'時刻'])

# %%
raw_label=pd.read_csv("cleaning_20160331.csv",encoding="SHIFT-JIS")
raw_label[u'#Time']=pd.to_datetime(raw_label[u'#Time'])

# %%
test_label=raw_label
test_left_ags=raw_left_hand_ags

# %%
test.dtypes
test_left_ags.dtypes
# Out:
# 種別              object
# 時刻      datetime64[ns]
# 加速度X             int64
# 加速度Y             int64
# 加速度Z             int64
# 角速度X             int64
# 角速度Y             int64
# 角速度Z             int64
# dtype: object

# %%
def add_label(data,label):
    start = time.time()
    data[u'label']=0
    label_num=1
    for i in range(0,len(data)):
        
        if label_num!=len(label):
            if data[u'時刻'][i] > label[u'#Time'][label_num]:
                label_num +=1
            
        data[u'label'][i]=label[u'Info1'][label_num-1]
        
        #debug
        #print 'mm[label][%d]=%s' %(i,mm[u'label'][i])
    elapsed_time = time.time() - start
    print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"

# %%
add_label(test_left_ags,test_label)
# Out:
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/indexing.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# elapsed_time:1534.91133595[sec]

# %%
test_left_ags
# Out:
#         種別                      時刻  加速度X   加速度Y  加速度Z   角速度X   角速度Y   角速度Z  \
# 0      ags 2016-04-06 18:06:15.696  8226   7922  -543  35311   7196   -953
# 1      ags 2016-04-06 18:06:15.706  8058   8437  -582  36141   5974  -2270
# 2      ags 2016-04-06 18:06:15.716  8292   9091  -231  35395   4803  -3402
# 3      ags 2016-04-06 18:06:15.726  7628  11183  -436  32518   3560  -4706
# 4      ags 2016-04-06 18:06:15.736  7811  13112  -370  27451   1863  -5504
# 5      ags 2016-04-06 18:06:15.746  7496  13971  -375  20880    -85  -6060
# 6      ags 2016-04-06 18:06:15.756  7459  13967  -302  14215  -2121  -6425
# 7      ags 2016-04-06 18:06:15.766  7171  13822  -204   7738  -3918  -6913
# 8      ags 2016-04-06 18:06:15.776  7054  13510  -226   1725  -5776  -7469
# 9      ags 2016-04-06 18:06:15.786  7008  13061  -141  -3581  -7509  -8049
# 10     ags 2016-04-06 18:06:15.796  7271  12133   262  -8082  -8945  -8673
# 11     ags 2016-04-06 18:06:15.806  7528  11445   707 -10702  -9774  -9415
# 12     ags 2016-04-06 18:06:15.816  7669  10885  1514 -12039 -10237 -10185
# 55456  ags 2016-04-06 18:15:30.256 -1541   7531 -4811    393   4881  -4304
# 55457  ags 2016-04-06 18:15:30.266 -1204   7255 -4682   -319   5014  -4350
# 55458  ags 2016-04-06 18:15:30.276  -994   7314 -4540   -905   5322  -4164
# 55459  ags 2016-04-06 18:15:30.286 -1045   7350 -5099  -1169   5638  -4066
# 55460  ags 2016-04-06 18:15:30.296 -1031   7680 -5683  -1194   5892  -3965
# 55461  ags 2016-04-06 18:15:30.306 -1080   8547 -6229   -952   5988  -4035
# 55462  ags 2016-04-06 18:15:30.316 -1094   9242 -6620   -532   6023  -4296
# 55463  ags 2016-04-06 18:15:30.326 -1316   9467 -6803   -158   5909  -4455
# 55464  ags 2016-04-06 18:15:30.336 -1597   9423 -6911    -70   5710  -4718
# 55465  ags 2016-04-06 18:15:30.346 -1832   8884 -6539   -403   5568  -4680
# 55466  ags 2016-04-06 18:15:30.356 -1585   7836 -5997   -939   5506  -4449
# 55467  ags 2016-04-06 18:15:30.366 -1705   7001 -5275   -858   5547  -3951
# 55468  ags 2016-04-06 18:15:30.376 -1397   7067 -5123   -459   5600  -3690
# 55469  ags 2016-04-06 18:15:30.386 -1346   7526 -4901   -253   5786  -3273
# 55470  ags 2016-04-06 18:15:30.396 -1292   8188 -5248   -267   6015  -2973
#
#       label
# 0        歩く
# 1        歩く
# 2        歩く
# 3        歩く
# 4        歩く
# 5        歩く
# 6        歩く
# 7        歩く
# 8        歩く
# 9        歩く
# 10       歩く
# 11       歩く
# 12       歩く
# 13       歩く
# 14       歩く
# 15       歩く
# 16       歩く
# 17       歩く
# 18       歩く
# 19       歩く
# 20       歩く
# 21       歩く
# 22       歩く
# 23       歩く
# 24       歩く
# 25       歩く
# 26       歩く
# 27       歩く
# 28       歩く
# 29       歩く
# ...     ...
# 55441    不明
# 55442    不明
# 55443    不明
# 55444    不明
# 55445    不明
# 55446    不明
# 55447    不明
# 55448    不明
# 55449    不明
# 55450    不明
# 55451    不明
# 55452    不明
# 55453    不明
# 55454    不明
# 55455    不明
# 55456    不明
# 55457    不明
# 55458    不明
# 55459    不明
# 55460    不明
# 55461    不明
# 55462    不明
# 55463    不明
# 55464    不明
# 55465    不明
# 55466    不明
# 55467    不明
# 55468    不明
# 55469    不明
# 55470    不明
#
# [55471 rows x 9 columns]

# %%
temp_left_hand_ags=pd.DataFrame({
    'Time':raw_left_hand_ags[u'時刻'],
    'AccX':raw_left_hand_ags[u'加速度X'],
    'AccY':raw_left_hand_ags[u'加速度Y'],
    'AccZ':raw_left_hand_ags[u'加速度Z'],
    'GyrX':raw_left_hand_ags[u'角速度X'],
    'GyrY':raw_left_hand_ags[u'角速度Y'],
    'GyrZ':raw_left_hand_ags[u'角速度Z'],
    })
