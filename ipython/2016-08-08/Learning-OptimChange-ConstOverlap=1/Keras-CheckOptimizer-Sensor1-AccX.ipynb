# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,16,16,16,16,16] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccX' # Axis

WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData/2016-07-25"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping

import matplotlib.image as mpimg

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
if not os.path.exists(WORKSPACE_PATH+'/study/'+DataName+'/OptimChange/'): os.makedirs(WORKSPACE_PATH+'/study/'+DataName+'/OptimChange/')
StudyDataPath=WORKSPACE_PATH+'/study/'+DataName+'/OptimChange/'

if not os.path.exists(WORKSPACE_PATH+'/graph/'+DataName+'/OptimChange_loss/'): os.makedirs(WORKSPACE_PATH+'/graph/'+DataName+'/OptimChange_loss/')
GlaphDataPath=WORKSPACE_PATH+'/graph/'+DataName+'/OptimChange_loss/'

#if not os.path.exists(WORKSPACE_PATH+'/graph/'+DataName+'/Time'): os.makedirs(WORKSPACE_PATH+'/graph/'+DataName+'/Time')
#GlaphDataTimePath=WORKSPACE_PATH+'/graph/'+DataName+'/Time'

if not os.path.exists(WORKSPACE_PATH+'/OptimChange_modelPic/'+DataName+'/'): os.makedirs(WORKSPACE_PATH+'/OptimChange_modelPic/'+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+'/OptimChange_modelPic/'+DataName+'/'

if not os.path.exists(WORKSPACE_PATH+'/OptimChange_window/'+DataName+'/'): os.makedirs(WORKSPACE_PATH+'/OptimChange_window/'+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/OptimChange_window/'+DataName+'/'

RawDataPath="/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData/raw/"

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成 & Learning**

# %%
optimizers = [SGD, Adadelta, Adamax, Adam, Adagrad,  RMSprop, Nadam]
optimArray = ["SGD", "Adadelta","Adamax", "Adam", "Adagrad",  "RMSprop", "Nadam"]

# %%
# loop windowWidth
for SampleNum,Overlap in zip(WindowWidth,OverlapArray):
    w=window.Window()
    w.SetData(Axis,dic[Axis])
    wind=w.Compile(windowWidth=SampleNum,overlapNum=Overlap)
    windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
    for opt,optName in zip(optimizers,optimArray):
        print "hiden node = "+str(encoding_dim)
        CommonName='_encoded'+'_edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+optName
        print CommonName
        SaveFileNameEncord=DataName+'_encoded'+CommonName
        SaveFileNameDecord=DataName+'_decoded'+CommonName
        SaveFileNameNet=DataName+'_net'+CommonName
        SaveFileNameTrain=DataName+'_train'+CommonName
        SaveFileNameTest=DataName+'_test'+CommonName
        SaveFileNameGlaph=GlaphDataPath+DataName+CommonName+'_loss_val_loss.png'

        window_test=windoW
        window_train=windoW
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTrain,window_test)
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTest,window_test)
        shapeNum=windoW.shape[1]

        # this is our input placeholder
        input_img = Input(shape=(shapeNum,))
        # "encoded" is the encoded representation of the input
        encoded = Dense(encoding_dim, activation='tanh')(input_img)
        # "decoded" is the lossy reconstruction of the input
        decoded = Dense(shapeNum, activation='linear')(encoded)

        # this model maps an input to its reconstruction
        autoencoder = Model(input=input_img, output=decoded)

        # this model maps an input to its encoded representation
        encoder = Model(input=input_img, output=encoded)

        # create a placeholder for an encoded (32-dimensional) input
        encoded_input = Input(shape=(encoding_dim,))
        # retrieve the last layer of the autoencoder model
        decoder_layer = autoencoder.layers[-1]
        # create the decoder model
        decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))

        autoencoder.compile(optimizer=opt(), loss='mse')
        plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')

        early_stopping = EarlyStopping(monitor='val_loss', patience=5)
        hist = autoencoder.fit(window_train, window_train,
                        nb_epoch=50,
                        verbose=2,
                        batch_size=32,
                        shuffle=True,
                        validation_data=(window_test, window_test),
                        callbacks=[early_stopping])
        time.sleep(0.1)
        encoded_imgs = encoder.predict(window_test)
        decoded_imgs = decoder.predict(encoded_imgs)

        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameEncord,encoded_imgs)
        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameDecord,decoded_imgs)

        # save model and wights
        json_string = encoder.to_json()
        open(StudyDataPath+SaveFileNameEncord+'.json', 'w').write(json_string)
        encoder.save_weights(StudyDataPath+SaveFileNameEncord+'_weights.h5',overwrite=True)

        json_string = decoder.to_json()
        open(StudyDataPath+SaveFileNameDecord+'.json', 'w').write(json_string)
        decoder.save_weights(StudyDataPath+SaveFileNameDecord+'_weights.h5',overwrite=True)

        json_string = autoencoder.to_json()
        open(StudyDataPath+SaveFileNameNet+'.json', 'w').write(json_string)
        autoencoder.save_weights(StudyDataPath+SaveFileNameNet+'_weights.h5',overwrite=True)

        # plot loss
        loss = hist.history['loss']
        val_loss = hist.history['val_loss']

        nb_epoch = len(loss)
        plt.plot(range(nb_epoch), loss, marker='.', label='loss')
        plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
        plt.legend(loc='best', fontsize=10)
        plt.grid()
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.savefig(SaveFileNameGlaph)
        plt.show()
# Out:
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15914
# SourceData's aborting data = 6
# window shape is (15914, 128, 1)
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-SGD
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.4329 - val_loss: 0.1982
# Epoch 2/50
# 0s - loss: 0.1145 - val_loss: 0.0687
# Epoch 3/50
# 0s - loss: 0.0544 - val_loss: 0.0450
# Epoch 4/50
# 0s - loss: 0.0399 - val_loss: 0.0358
# Epoch 5/50
# 0s - loss: 0.0331 - val_loss: 0.0308
# Epoch 6/50
# 0s - loss: 0.0291 - val_loss: 0.0275
# Epoch 7/50
# 0s - loss: 0.0263 - val_loss: 0.0252
# Epoch 8/50
# 0s - loss: 0.0243 - val_loss: 0.0235
# Epoch 9/50
# 0s - loss: 0.0227 - val_loss: 0.0221
# Epoch 10/50
# 0s - loss: 0.0215 - val_loss: 0.0210
# Epoch 11/50
# 0s - loss: 0.0205 - val_loss: 0.0201
# Epoch 12/50
# 0s - loss: 0.0197 - val_loss: 0.0193
# Epoch 13/50
# 0s - loss: 0.0190 - val_loss: 0.0187
# Epoch 14/50
# 0s - loss: 0.0184 - val_loss: 0.0181
# Epoch 15/50
# 0s - loss: 0.0179 - val_loss: 0.0176
# Epoch 16/50
# 0s - loss: 0.0174 - val_loss: 0.0172
# Epoch 17/50
# 0s - loss: 0.0170 - val_loss: 0.0168
# Epoch 18/50
# 0s - loss: 0.0167 - val_loss: 0.0165
# Epoch 19/50
# 0s - loss: 0.0164 - val_loss: 0.0162
# Epoch 20/50
# 0s - loss: 0.0161 - val_loss: 0.0159
# Epoch 21/50
# 0s - loss: 0.0158 - val_loss: 0.0157
# Epoch 22/50
# 0s - loss: 0.0156 - val_loss: 0.0155
# Epoch 23/50
# 0s - loss: 0.0154 - val_loss: 0.0152
# Epoch 24/50
# 0s - loss: 0.0151 - val_loss: 0.0150
# Epoch 25/50
# 0s - loss: 0.0149 - val_loss: 0.0149
# Epoch 26/50
# 0s - loss: 0.0148 - val_loss: 0.0147
# Epoch 27/50
# 0s - loss: 0.0146 - val_loss: 0.0145
# Epoch 28/50
# 0s - loss: 0.0144 - val_loss: 0.0143
# Epoch 29/50
# 0s - loss: 0.0143 - val_loss: 0.0142
# Epoch 30/50
# 0s - loss: 0.0141 - val_loss: 0.0140
# Epoch 31/50
# 0s - loss: 0.0140 - val_loss: 0.0139
# Epoch 32/50
# 0s - loss: 0.0138 - val_loss: 0.0138
# Epoch 33/50
# 0s - loss: 0.0137 - val_loss: 0.0136
# Epoch 34/50
# 0s - loss: 0.0136 - val_loss: 0.0135
# Epoch 35/50
# 0s - loss: 0.0135 - val_loss: 0.0134
# Epoch 36/50
# 0s - loss: 0.0133 - val_loss: 0.0133
# Epoch 37/50
# 0s - loss: 0.0132 - val_loss: 0.0132
# Epoch 38/50
# 0s - loss: 0.0131 - val_loss: 0.0131
# Epoch 39/50
# 0s - loss: 0.0130 - val_loss: 0.0129
# Epoch 40/50
# 0s - loss: 0.0129 - val_loss: 0.0128
# Epoch 41/50
# 0s - loss: 0.0128 - val_loss: 0.0127
# Epoch 42/50
# 0s - loss: 0.0127 - val_loss: 0.0126
# Epoch 43/50
# 0s - loss: 0.0126 - val_loss: 0.0125
# Epoch 44/50
# 0s - loss: 0.0125 - val_loss: 0.0124
# Epoch 45/50
# 0s - loss: 0.0124 - val_loss: 0.0123
# Epoch 46/50
# 0s - loss: 0.0123 - val_loss: 0.0122
# Epoch 47/50
# 0s - loss: 0.0122 - val_loss: 0.0122
# Epoch 48/50
# 0s - loss: 0.0121 - val_loss: 0.0121
# Epoch 49/50
# 0s - loss: 0.0120 - val_loss: 0.0120
# Epoch 50/50
# 0s - loss: 0.0119 - val_loss: 0.0119
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-Adadelta
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.0863 - val_loss: 0.0153
# Epoch 2/50
# 0s - loss: 0.0141 - val_loss: 0.0124
# Epoch 3/50
# 0s - loss: 0.0101 - val_loss: 0.0070
# Epoch 4/50
# 0s - loss: 0.0069 - val_loss: 0.0052
# Epoch 5/50
# 0s - loss: 0.0061 - val_loss: 0.0053
# Epoch 6/50
# 0s - loss: 0.0056 - val_loss: 0.0045
# Epoch 7/50
# 0s - loss: 0.0054 - val_loss: 0.0039
# Epoch 8/50
# 0s - loss: 0.0053 - val_loss: 0.0041
# Epoch 9/50
# 0s - loss: 0.0048 - val_loss: 0.0069
# Epoch 10/50
# 0s - loss: 0.0044 - val_loss: 0.0030
# Epoch 11/50
# 0s - loss: 0.0044 - val_loss: 0.0028
# Epoch 12/50
# 0s - loss: 0.0044 - val_loss: 0.0036
# Epoch 13/50
# 0s - loss: 0.0042 - val_loss: 0.0032
# Epoch 14/50
# 0s - loss: 0.0043 - val_loss: 0.0045
# Epoch 15/50
# 0s - loss: 0.0039 - val_loss: 0.0028
# Epoch 16/50
# 0s - loss: 0.0036 - val_loss: 0.0029
# Epoch 17/50
# 0s - loss: 0.0037 - val_loss: 0.0022
# Epoch 18/50
# 0s - loss: 0.0039 - val_loss: 0.0024
# Epoch 19/50
# 0s - loss: 0.0039 - val_loss: 0.0029
# Epoch 20/50
# 0s - loss: 0.0037 - val_loss: 0.0046
# Epoch 21/50
# 0s - loss: 0.0037 - val_loss: 0.0022
# Epoch 22/50
# 0s - loss: 0.0037 - val_loss: 0.0099
# Epoch 23/50
# 0s - loss: 0.0032 - val_loss: 0.0022
# Epoch 24/50
# 0s - loss: 0.0036 - val_loss: 0.0061
# Epoch 25/50
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 26/50
# 0s - loss: 0.0034 - val_loss: 0.0019
# Epoch 27/50
# 0s - loss: 0.0037 - val_loss: 0.0084
# Epoch 28/50
# 0s - loss: 0.0035 - val_loss: 0.0056
# Epoch 29/50
# 0s - loss: 0.0036 - val_loss: 0.0038
# Epoch 30/50
# 0s - loss: 0.0033 - val_loss: 0.0041
# Epoch 31/50
# 0s - loss: 0.0035 - val_loss: 0.0036
# Epoch 32/50
# 0s - loss: 0.0034 - val_loss: 0.0018
# Epoch 33/50
# 0s - loss: 0.0033 - val_loss: 0.0017
# Epoch 34/50
# 0s - loss: 0.0033 - val_loss: 0.0055
# Epoch 35/50
# 0s - loss: 0.0032 - val_loss: 0.0033
# Epoch 36/50
# 0s - loss: 0.0033 - val_loss: 0.0027
# Epoch 37/50
# 0s - loss: 0.0033 - val_loss: 0.0026
# Epoch 38/50
# 0s - loss: 0.0030 - val_loss: 0.0048
# Epoch 39/50
# 0s - loss: 0.0030 - val_loss: 0.0050
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-Adamax
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.0535 - val_loss: 0.0154
# Epoch 2/50
# 0s - loss: 0.0121 - val_loss: 0.0096
# Epoch 3/50
# 0s - loss: 0.0078 - val_loss: 0.0060
# Epoch 4/50
# 0s - loss: 0.0052 - val_loss: 0.0044
# Epoch 5/50
# 0s - loss: 0.0038 - val_loss: 0.0032
# Epoch 6/50
# 0s - loss: 0.0029 - val_loss: 0.0028
# Epoch 7/50
# 0s - loss: 0.0022 - val_loss: 0.0018
# Epoch 8/50
# 0s - loss: 0.0017 - val_loss: 0.0018
# Epoch 9/50
# 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 10/50
# 0s - loss: 0.0011 - val_loss: 9.0852e-04
# Epoch 11/50
# 0s - loss: 9.7539e-04 - val_loss: 7.3661e-04
# Epoch 12/50
# 0s - loss: 8.5164e-04 - val_loss: 6.7702e-04
# Epoch 13/50
# 0s - loss: 7.5737e-04 - val_loss: 8.0622e-04
# Epoch 14/50
# 0s - loss: 7.2960e-04 - val_loss: 6.0609e-04
# Epoch 15/50
# 0s - loss: 7.3225e-04 - val_loss: 6.4160e-04
# Epoch 16/50
# 0s - loss: 7.2930e-04 - val_loss: 6.9928e-04
# Epoch 17/50
# 0s - loss: 5.8488e-04 - val_loss: 4.8695e-04
# Epoch 18/50
# 0s - loss: 6.1708e-04 - val_loss: 5.6186e-04
# Epoch 19/50
# 0s - loss: 5.8295e-04 - val_loss: 5.7282e-04
# Epoch 20/50
# 0s - loss: 5.8029e-04 - val_loss: 0.0018
# Epoch 21/50
# 0s - loss: 5.3326e-04 - val_loss: 0.0011
# Epoch 22/50
# 0s - loss: 5.8820e-04 - val_loss: 7.3570e-04
# Epoch 23/50
# 0s - loss: 5.3074e-04 - val_loss: 3.6552e-04
# Epoch 24/50
# 0s - loss: 5.1665e-04 - val_loss: 5.7801e-04
# Epoch 25/50
# 0s - loss: 4.5429e-04 - val_loss: 3.4449e-04
# Epoch 26/50
# 0s - loss: 4.9990e-04 - val_loss: 3.6570e-04
# Epoch 27/50
# 0s - loss: 4.7267e-04 - val_loss: 3.2312e-04
# Epoch 28/50
# 0s - loss: 4.6061e-04 - val_loss: 7.1647e-04
# Epoch 29/50
# 0s - loss: 4.7624e-04 - val_loss: 4.3131e-04
# Epoch 30/50
# 0s - loss: 4.3756e-04 - val_loss: 3.2416e-04
# Epoch 31/50
# 0s - loss: 5.0532e-04 - val_loss: 5.9836e-04
# Epoch 32/50
# 0s - loss: 4.1966e-04 - val_loss: 4.9360e-04
# Epoch 33/50
# 0s - loss: 4.1248e-04 - val_loss: 2.6637e-04
# Epoch 34/50
# 0s - loss: 4.1663e-04 - val_loss: 2.9358e-04
# Epoch 35/50
# 0s - loss: 3.9262e-04 - val_loss: 2.5992e-04
# Epoch 36/50
# 0s - loss: 4.1048e-04 - val_loss: 3.0742e-04
# Epoch 37/50
# 0s - loss: 3.5752e-04 - val_loss: 2.9722e-04
# Epoch 38/50
# 0s - loss: 3.9627e-04 - val_loss: 3.2557e-04
# Epoch 39/50
# 0s - loss: 3.7232e-04 - val_loss: 2.5403e-04
# Epoch 40/50
# 0s - loss: 3.4654e-04 - val_loss: 3.2508e-04
# Epoch 41/50
# 0s - loss: 3.4221e-04 - val_loss: 4.9153e-04
# Epoch 42/50
# 0s - loss: 3.2684e-04 - val_loss: 2.3989e-04
# Epoch 43/50
# 0s - loss: 3.3546e-04 - val_loss: 2.9982e-04
# Epoch 44/50
# 0s - loss: 3.2783e-04 - val_loss: 3.9676e-04
# Epoch 45/50
# 0s - loss: 3.2704e-04 - val_loss: 3.0265e-04
# Epoch 46/50
# 0s - loss: 3.0491e-04 - val_loss: 7.6084e-04
# Epoch 47/50
# 0s - loss: 3.0406e-04 - val_loss: 3.1374e-04
# Epoch 48/50
# 0s - loss: 3.3768e-04 - val_loss: 8.2872e-04
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-Adam
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.0672 - val_loss: 0.0138
# Epoch 2/50
# 0s - loss: 0.0096 - val_loss: 0.0067
# Epoch 3/50
# 0s - loss: 0.0058 - val_loss: 0.0043
# Epoch 4/50
# 0s - loss: 0.0041 - val_loss: 0.0033
# Epoch 5/50
# 0s - loss: 0.0031 - val_loss: 0.0027
# Epoch 6/50
# 0s - loss: 0.0025 - val_loss: 0.0031
# Epoch 7/50
# 0s - loss: 0.0022 - val_loss: 0.0018
# Epoch 8/50
# 0s - loss: 0.0019 - val_loss: 0.0016
# Epoch 9/50
# 0s - loss: 0.0015 - val_loss: 0.0014
# Epoch 10/50
# 0s - loss: 0.0014 - val_loss: 0.0013
# Epoch 11/50
# 0s - loss: 0.0013 - val_loss: 0.0012
# Epoch 12/50
# 0s - loss: 9.9943e-04 - val_loss: 8.8793e-04
# Epoch 13/50
# 0s - loss: 9.4515e-04 - val_loss: 0.0012
# Epoch 14/50
# 0s - loss: 8.9227e-04 - val_loss: 6.2103e-04
# Epoch 15/50
# 0s - loss: 8.0377e-04 - val_loss: 0.0018
# Epoch 16/50
# 0s - loss: 8.3278e-04 - val_loss: 5.9226e-04
# Epoch 17/50
# 0s - loss: 6.9229e-04 - val_loss: 6.9374e-04
# Epoch 18/50
# 0s - loss: 6.8934e-04 - val_loss: 5.7039e-04
# Epoch 19/50
# 0s - loss: 7.3960e-04 - val_loss: 4.6050e-04
# Epoch 20/50
# 0s - loss: 6.0198e-04 - val_loss: 8.9846e-04
# Epoch 21/50
# 0s - loss: 5.5956e-04 - val_loss: 4.0403e-04
# Epoch 22/50
# 0s - loss: 6.2215e-04 - val_loss: 3.9737e-04
# Epoch 23/50
# 0s - loss: 6.1473e-04 - val_loss: 4.2334e-04
# Epoch 24/50
# 0s - loss: 5.6074e-04 - val_loss: 3.5846e-04
# Epoch 25/50
# 0s - loss: 5.9515e-04 - val_loss: 3.9862e-04
# Epoch 26/50
# 0s - loss: 4.8071e-04 - val_loss: 3.3677e-04
# Epoch 27/50
# 0s - loss: 4.5023e-04 - val_loss: 0.0012
# Epoch 28/50
# 0s - loss: 5.3177e-04 - val_loss: 4.1828e-04
# Epoch 29/50
# 0s - loss: 4.6803e-04 - val_loss: 4.7298e-04
# Epoch 30/50
# 0s - loss: 4.9369e-04 - val_loss: 5.2583e-04
# Epoch 31/50
# 0s - loss: 4.9179e-04 - val_loss: 2.8671e-04
# Epoch 32/50
# 0s - loss: 5.2086e-04 - val_loss: 8.2180e-04
# Epoch 33/50
# 0s - loss: 4.7131e-04 - val_loss: 2.8835e-04
# Epoch 34/50
# 0s - loss: 4.7419e-04 - val_loss: 5.5784e-04
# Epoch 35/50
# 0s - loss: 4.2253e-04 - val_loss: 2.9847e-04
# Epoch 36/50
# 0s - loss: 4.2986e-04 - val_loss: 2.9689e-04
# Epoch 37/50
# 0s - loss: 3.9643e-04 - val_loss: 0.0012
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-Adagrad
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.0306 - val_loss: 0.0153
# Epoch 2/50
# 0s - loss: 0.0130 - val_loss: 0.0123
# Epoch 3/50
# 0s - loss: 0.0101 - val_loss: 0.0085
# Epoch 4/50
# 0s - loss: 0.0077 - val_loss: 0.0068
# Epoch 5/50
# 0s - loss: 0.0063 - val_loss: 0.0066
# Epoch 6/50
# 0s - loss: 0.0055 - val_loss: 0.0049
# Epoch 7/50
# 0s - loss: 0.0051 - val_loss: 0.0055
# Epoch 8/50
# 0s - loss: 0.0046 - val_loss: 0.0042
# Epoch 9/50
# 0s - loss: 0.0043 - val_loss: 0.0043
# Epoch 10/50
# 0s - loss: 0.0040 - val_loss: 0.0037
# Epoch 11/50
# 0s - loss: 0.0037 - val_loss: 0.0045
# Epoch 12/50
# 0s - loss: 0.0035 - val_loss: 0.0150
# Epoch 13/50
# 0s - loss: 0.0033 - val_loss: 0.0035
# Epoch 14/50
# 0s - loss: 0.0031 - val_loss: 0.0036
# Epoch 15/50
# 0s - loss: 0.0030 - val_loss: 0.0027
# Epoch 16/50
# 0s - loss: 0.0028 - val_loss: 0.0031
# Epoch 17/50
# 0s - loss: 0.0027 - val_loss: 0.0037
# Epoch 18/50
# 0s - loss: 0.0026 - val_loss: 0.0026
# Epoch 19/50
# 0s - loss: 0.0025 - val_loss: 0.0029
# Epoch 20/50
# 0s - loss: 0.0024 - val_loss: 0.0023
# Epoch 21/50
# 0s - loss: 0.0024 - val_loss: 0.0075
# Epoch 22/50
# 0s - loss: 0.0023 - val_loss: 0.0051
# Epoch 23/50
# 0s - loss: 0.0022 - val_loss: 0.0022
# Epoch 24/50
# 0s - loss: 0.0022 - val_loss: 0.0021
# Epoch 25/50
# 0s - loss: 0.0021 - val_loss: 0.0021
# Epoch 26/50
# 0s - loss: 0.0020 - val_loss: 0.0021
# Epoch 27/50
# 0s - loss: 0.0020 - val_loss: 0.0019
# Epoch 28/50
# 0s - loss: 0.0020 - val_loss: 0.0018
# Epoch 29/50
# 0s - loss: 0.0019 - val_loss: 0.0018
# Epoch 30/50
# 0s - loss: 0.0019 - val_loss: 0.0020
# Epoch 31/50
# 0s - loss: 0.0018 - val_loss: 0.0017
# Epoch 32/50
# 0s - loss: 0.0018 - val_loss: 0.0017
# Epoch 33/50
# 0s - loss: 0.0018 - val_loss: 0.0018
# Epoch 34/50
# 0s - loss: 0.0017 - val_loss: 0.0017
# Epoch 35/50
# 0s - loss: 0.0017 - val_loss: 0.0017
# Epoch 36/50
# 0s - loss: 0.0017 - val_loss: 0.0018
# Epoch 37/50
# 0s - loss: 0.0017 - val_loss: 0.0017
# Epoch 38/50
# 0s - loss: 0.0016 - val_loss: 0.0018
# Epoch 39/50
# 0s - loss: 0.0016 - val_loss: 0.0015
# Epoch 40/50
# 0s - loss: 0.0016 - val_loss: 0.0015
# Epoch 41/50
# 0s - loss: 0.0016 - val_loss: 0.0015
# Epoch 42/50
# 0s - loss: 0.0015 - val_loss: 0.0016
# Epoch 43/50
# 0s - loss: 0.0015 - val_loss: 0.0016
# Epoch 44/50
# 0s - loss: 0.0015 - val_loss: 0.0015
# Epoch 45/50
# 0s - loss: 0.0015 - val_loss: 0.0014
# Epoch 46/50
# 0s - loss: 0.0014 - val_loss: 0.0014
# Epoch 47/50
# 0s - loss: 0.0014 - val_loss: 0.0014
# Epoch 48/50
# 0s - loss: 0.0014 - val_loss: 0.0013
# Epoch 49/50
# 0s - loss: 0.0014 - val_loss: 0.0014
# Epoch 50/50
# 0s - loss: 0.0014 - val_loss: 0.0014
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-RMSprop
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.0540 - val_loss: 0.0363
# Epoch 2/50
# 0s - loss: 0.0109 - val_loss: 0.0072
# Epoch 3/50
# 0s - loss: 0.0093 - val_loss: 0.0138
# Epoch 4/50
# 0s - loss: 0.0088 - val_loss: 0.0057
# Epoch 5/50
# 0s - loss: 0.0083 - val_loss: 0.0051
# Epoch 6/50
# 0s - loss: 0.0077 - val_loss: 0.0050
# Epoch 7/50
# 0s - loss: 0.0075 - val_loss: 0.0061
# Epoch 8/50
# 0s - loss: 0.0073 - val_loss: 0.0037
# Epoch 9/50
# 0s - loss: 0.0072 - val_loss: 0.0062
# Epoch 10/50
# 0s - loss: 0.0069 - val_loss: 0.0055
# Epoch 11/50
# 0s - loss: 0.0068 - val_loss: 0.0058
# Epoch 12/50
# 0s - loss: 0.0067 - val_loss: 0.0123
# Epoch 13/50
# 0s - loss: 0.0064 - val_loss: 0.0065
# Epoch 14/50
# 0s - loss: 0.0063 - val_loss: 0.0063
# hiden node = 16
# _encoded_edim=16-Window=128-Overlap=16-Nadam
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/50
# 0s - loss: 0.0448 - val_loss: 0.0108
# Epoch 2/50
# 0s - loss: 0.0120 - val_loss: 0.0113
# Epoch 3/50
# 0s - loss: 0.0094 - val_loss: 0.0081
# Epoch 4/50
# 0s - loss: 0.0083 - val_loss: 0.0056
# Epoch 5/50
# 0s - loss: 0.0071 - val_loss: 0.0041
# Epoch 6/50
# 0s - loss: 0.0064 - val_loss: 0.0042
# Epoch 7/50
# 0s - loss: 0.0057 - val_loss: 0.0033
# Epoch 8/50
# 0s - loss: 0.0050 - val_loss: 0.0049
# Epoch 9/50
# 0s - loss: 0.0047 - val_loss: 0.0241
# Epoch 10/50
# 0s - loss: 0.0042 - val_loss: 0.0054
# Epoch 11/50
# 0s - loss: 0.0036 - val_loss: 0.0082
# Epoch 12/50
# 0s - loss: 0.0035 - val_loss: 0.0067
# Epoch 13/50
# 0s - loss: 0.0030 - val_loss: 0.0015
# Epoch 14/50
# 0s - loss: 0.0029 - val_loss: 0.0024
# Epoch 15/50
# 0s - loss: 0.0026 - val_loss: 0.0026
# Epoch 16/50
# 0s - loss: 0.0025 - val_loss: 0.0013
# Epoch 17/50
# 0s - loss: 0.0023 - val_loss: 0.0012
# Epoch 18/50
# 0s - loss: 0.0023 - val_loss: 0.0014
# Epoch 19/50
# 0s - loss: 0.0020 - val_loss: 0.0013
# Epoch 20/50
# 0s - loss: 0.0021 - val_loss: 0.0017
# Epoch 21/50
# 0s - loss: 0.0018 - val_loss: 0.0026
# Epoch 22/50
# 0s - loss: 0.0018 - val_loss: 0.0013
# Epoch 23/50
# 0s - loss: 0.0017 - val_loss: 0.0018
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15906
# SourceData's aborting data = 6
# window shape is (15906, 256, 1)
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-SGD
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.5941 - val_loss: 0.3900
# Epoch 2/50
# 0s - loss: 0.2634 - val_loss: 0.1729
# Epoch 3/50
# 0s - loss: 0.1295 - val_loss: 0.0986
# Epoch 4/50
# 0s - loss: 0.0825 - val_loss: 0.0702
# Epoch 5/50
# 0s - loss: 0.0626 - val_loss: 0.0564
# Epoch 6/50
# 0s - loss: 0.0523 - val_loss: 0.0487
# Epoch 7/50
# 0s - loss: 0.0462 - val_loss: 0.0439
# Epoch 8/50
# 0s - loss: 0.0421 - val_loss: 0.0405
# Epoch 9/50
# 0s - loss: 0.0393 - val_loss: 0.0381
# Epoch 10/50
# 0s - loss: 0.0371 - val_loss: 0.0361
# Epoch 11/50
# 0s - loss: 0.0353 - val_loss: 0.0346
# Epoch 12/50
# 0s - loss: 0.0339 - val_loss: 0.0333
# Epoch 13/50
# 0s - loss: 0.0327 - val_loss: 0.0322
# Epoch 14/50
# 0s - loss: 0.0317 - val_loss: 0.0312
# Epoch 15/50
# 0s - loss: 0.0308 - val_loss: 0.0304
# Epoch 16/50
# 0s - loss: 0.0301 - val_loss: 0.0298
# Epoch 17/50
# 0s - loss: 0.0295 - val_loss: 0.0292
# Epoch 18/50
# 0s - loss: 0.0289 - val_loss: 0.0286
# Epoch 19/50
# 0s - loss: 0.0284 - val_loss: 0.0282
# Epoch 20/50
# 0s - loss: 0.0280 - val_loss: 0.0278
# Epoch 21/50
# 0s - loss: 0.0276 - val_loss: 0.0274
# Epoch 22/50
# 0s - loss: 0.0272 - val_loss: 0.0271
# Epoch 23/50
# 0s - loss: 0.0269 - val_loss: 0.0268
# Epoch 24/50
# 0s - loss: 0.0266 - val_loss: 0.0265
# Epoch 25/50
# 0s - loss: 0.0264 - val_loss: 0.0262
# Epoch 26/50
# 0s - loss: 0.0261 - val_loss: 0.0260
# Epoch 27/50
# 0s - loss: 0.0259 - val_loss: 0.0258
# Epoch 28/50
# 0s - loss: 0.0257 - val_loss: 0.0256
# Epoch 29/50
# 0s - loss: 0.0255 - val_loss: 0.0254
# Epoch 30/50
# 0s - loss: 0.0253 - val_loss: 0.0252
# Epoch 31/50
# 0s - loss: 0.0251 - val_loss: 0.0251
# Epoch 32/50
# 0s - loss: 0.0250 - val_loss: 0.0249
# Epoch 33/50
# 0s - loss: 0.0248 - val_loss: 0.0248
# Epoch 34/50
# 0s - loss: 0.0247 - val_loss: 0.0246
# Epoch 35/50
# 0s - loss: 0.0245 - val_loss: 0.0245
# Epoch 36/50
# 0s - loss: 0.0244 - val_loss: 0.0243
# Epoch 37/50
# 0s - loss: 0.0242 - val_loss: 0.0242
# Epoch 38/50
# 0s - loss: 0.0241 - val_loss: 0.0241
# Epoch 39/50
# 0s - loss: 0.0240 - val_loss: 0.0239
# Epoch 40/50
# 0s - loss: 0.0239 - val_loss: 0.0238
# Epoch 41/50
# 0s - loss: 0.0237 - val_loss: 0.0237
# Epoch 42/50
# 0s - loss: 0.0236 - val_loss: 0.0236
# Epoch 43/50
# 0s - loss: 0.0235 - val_loss: 0.0234
# Epoch 44/50
# 0s - loss: 0.0234 - val_loss: 0.0233
# Epoch 45/50
# 0s - loss: 0.0233 - val_loss: 0.0232
# Epoch 46/50
# 0s - loss: 0.0232 - val_loss: 0.0231
# Epoch 47/50
# 0s - loss: 0.0230 - val_loss: 0.0230
# Epoch 48/50
# 0s - loss: 0.0229 - val_loss: 0.0229
# Epoch 49/50
# 0s - loss: 0.0228 - val_loss: 0.0228
# Epoch 50/50
# 0s - loss: 0.0227 - val_loss: 0.0227
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-Adadelta
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.1036 - val_loss: 0.0422
# Epoch 2/50
# 0s - loss: 0.0196 - val_loss: 0.0306
# Epoch 3/50
# 0s - loss: 0.0150 - val_loss: 0.0263
# Epoch 4/50
# 0s - loss: 0.0125 - val_loss: 0.0304
# Epoch 5/50
# 0s - loss: 0.0108 - val_loss: 0.0132
# Epoch 6/50
# 0s - loss: 0.0101 - val_loss: 0.0075
# Epoch 7/50
# 0s - loss: 0.0098 - val_loss: 0.0108
# Epoch 8/50
# 0s - loss: 0.0096 - val_loss: 0.0078
# Epoch 9/50
# 0s - loss: 0.0088 - val_loss: 0.0079
# Epoch 10/50
# 0s - loss: 0.0088 - val_loss: 0.0068
# Epoch 11/50
# 0s - loss: 0.0090 - val_loss: 0.0148
# Epoch 12/50
# 0s - loss: 0.0083 - val_loss: 0.0303
# Epoch 13/50
# 0s - loss: 0.0079 - val_loss: 0.0080
# Epoch 14/50
# 0s - loss: 0.0077 - val_loss: 0.0114
# Epoch 15/50
# 0s - loss: 0.0078 - val_loss: 0.0067
# Epoch 16/50
# 0s - loss: 0.0071 - val_loss: 0.0062
# Epoch 17/50
# 0s - loss: 0.0072 - val_loss: 0.0050
# Epoch 18/50
# 0s - loss: 0.0070 - val_loss: 0.0069
# Epoch 19/50
# 0s - loss: 0.0068 - val_loss: 0.0101
# Epoch 20/50
# 0s - loss: 0.0070 - val_loss: 0.0137
# Epoch 21/50
# 0s - loss: 0.0072 - val_loss: 0.0045
# Epoch 22/50
# 0s - loss: 0.0065 - val_loss: 0.0046
# Epoch 23/50
# 0s - loss: 0.0063 - val_loss: 0.0051
# Epoch 24/50
# 0s - loss: 0.0064 - val_loss: 0.0124
# Epoch 25/50
# 0s - loss: 0.0066 - val_loss: 0.0192
# Epoch 26/50
# 0s - loss: 0.0071 - val_loss: 0.0083
# Epoch 27/50
# 0s - loss: 0.0067 - val_loss: 0.0231
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-Adamax
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.0582 - val_loss: 0.0231
# Epoch 2/50
# 0s - loss: 0.0197 - val_loss: 0.0155
# Epoch 3/50
# 0s - loss: 0.0117 - val_loss: 0.0093
# Epoch 4/50
# 0s - loss: 0.0078 - val_loss: 0.0063
# Epoch 5/50
# 0s - loss: 0.0056 - val_loss: 0.0046
# Epoch 6/50
# 0s - loss: 0.0042 - val_loss: 0.0035
# Epoch 7/50
# 0s - loss: 0.0033 - val_loss: 0.0035
# Epoch 8/50
# 0s - loss: 0.0026 - val_loss: 0.0053
# Epoch 9/50
# 0s - loss: 0.0023 - val_loss: 0.0022
# Epoch 10/50
# 0s - loss: 0.0020 - val_loss: 0.0022
# Epoch 11/50
# 0s - loss: 0.0018 - val_loss: 0.0016
# Epoch 12/50
# 0s - loss: 0.0017 - val_loss: 0.0021
# Epoch 13/50
# 0s - loss: 0.0015 - val_loss: 0.0017
# Epoch 14/50
# 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 15/50
# 0s - loss: 0.0014 - val_loss: 0.0045
# Epoch 16/50
# 0s - loss: 0.0013 - val_loss: 9.7948e-04
# Epoch 17/50
# 0s - loss: 0.0012 - val_loss: 0.0011
# Epoch 18/50
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 19/50
# 0s - loss: 0.0011 - val_loss: 8.8519e-04
# Epoch 20/50
# 0s - loss: 0.0011 - val_loss: 8.6754e-04
# Epoch 21/50
# 0s - loss: 9.9333e-04 - val_loss: 8.8693e-04
# Epoch 22/50
# 0s - loss: 0.0011 - val_loss: 7.5292e-04
# Epoch 23/50
# 0s - loss: 9.8537e-04 - val_loss: 0.0011
# Epoch 24/50
# 0s - loss: 9.5850e-04 - val_loss: 0.0010
# Epoch 25/50
# 0s - loss: 9.0628e-04 - val_loss: 7.5875e-04
# Epoch 26/50
# 0s - loss: 9.7016e-04 - val_loss: 7.7180e-04
# Epoch 27/50
# 0s - loss: 8.5361e-04 - val_loss: 0.0010
# Epoch 28/50
# 0s - loss: 7.8778e-04 - val_loss: 0.0091
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-Adam
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.0709 - val_loss: 0.0224
# Epoch 2/50
# 0s - loss: 0.0153 - val_loss: 0.0108
# Epoch 3/50
# 0s - loss: 0.0090 - val_loss: 0.0069
# Epoch 4/50
# 0s - loss: 0.0067 - val_loss: 0.0056
# Epoch 5/50
# 0s - loss: 0.0051 - val_loss: 0.0041
# Epoch 6/50
# 0s - loss: 0.0041 - val_loss: 0.0045
# Epoch 7/50
# 0s - loss: 0.0035 - val_loss: 0.0080
# Epoch 8/50
# 0s - loss: 0.0029 - val_loss: 0.0025
# Epoch 9/50
# 0s - loss: 0.0026 - val_loss: 0.0061
# Epoch 10/50
# 0s - loss: 0.0024 - val_loss: 0.0028
# Epoch 11/50
# 0s - loss: 0.0021 - val_loss: 0.0018
# Epoch 12/50
# 0s - loss: 0.0018 - val_loss: 0.0020
# Epoch 13/50
# 0s - loss: 0.0017 - val_loss: 0.0039
# Epoch 14/50
# 0s - loss: 0.0018 - val_loss: 0.0015
# Epoch 15/50
# 0s - loss: 0.0016 - val_loss: 0.0035
# Epoch 16/50
# 0s - loss: 0.0015 - val_loss: 0.0017
# Epoch 17/50
# 0s - loss: 0.0014 - val_loss: 0.0010
# Epoch 18/50
# 0s - loss: 0.0015 - val_loss: 0.0044
# Epoch 19/50
# 0s - loss: 0.0012 - val_loss: 0.0014
# Epoch 20/50
# 0s - loss: 0.0012 - val_loss: 9.7909e-04
# Epoch 21/50
# 0s - loss: 0.0012 - val_loss: 0.0016
# Epoch 22/50
# 0s - loss: 0.0011 - val_loss: 0.0019
# Epoch 23/50
# 0s - loss: 9.5191e-04 - val_loss: 0.0018
# Epoch 24/50
# 0s - loss: 0.0010 - val_loss: 0.0059
# Epoch 25/50
# 0s - loss: 0.0010 - val_loss: 0.0020
# Epoch 26/50
# 0s - loss: 0.0011 - val_loss: 0.0020
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-Adagrad
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.0383 - val_loss: 0.0195
# Epoch 2/50
# 0s - loss: 0.0173 - val_loss: 0.0135
# Epoch 3/50
# 0s - loss: 0.0126 - val_loss: 0.0162
# Epoch 4/50
# 0s - loss: 0.0102 - val_loss: 0.0094
# Epoch 5/50
# 0s - loss: 0.0089 - val_loss: 0.0349
# Epoch 6/50
# 0s - loss: 0.0080 - val_loss: 0.0091
# Epoch 7/50
# 0s - loss: 0.0071 - val_loss: 0.0063
# Epoch 8/50
# 0s - loss: 0.0065 - val_loss: 0.0064
# Epoch 9/50
# 0s - loss: 0.0065 - val_loss: 0.0066
# Epoch 10/50
# 0s - loss: 0.0059 - val_loss: 0.0062
# Epoch 11/50
# 0s - loss: 0.0056 - val_loss: 0.0051
# Epoch 12/50
# 0s - loss: 0.0053 - val_loss: 0.0052
# Epoch 13/50
# 0s - loss: 0.0050 - val_loss: 0.0048
# Epoch 14/50
# 0s - loss: 0.0048 - val_loss: 0.0044
# Epoch 15/50
# 0s - loss: 0.0046 - val_loss: 0.0089
# Epoch 16/50
# 0s - loss: 0.0044 - val_loss: 0.0071
# Epoch 17/50
# 0s - loss: 0.0043 - val_loss: 0.0039
# Epoch 18/50
# 0s - loss: 0.0041 - val_loss: 0.0040
# Epoch 19/50
# 0s - loss: 0.0040 - val_loss: 0.0041
# Epoch 20/50
# 0s - loss: 0.0039 - val_loss: 0.0044
# Epoch 21/50
# 0s - loss: 0.0038 - val_loss: 0.0049
# Epoch 22/50
# 0s - loss: 0.0037 - val_loss: 0.0045
# Epoch 23/50
# 0s - loss: 0.0036 - val_loss: 0.0039
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-RMSprop
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.0558 - val_loss: 0.0166
# Epoch 2/50
# 0s - loss: 0.0163 - val_loss: 0.0264
# Epoch 3/50
# 0s - loss: 0.0148 - val_loss: 0.0511
# Epoch 4/50
# 0s - loss: 0.0142 - val_loss: 0.0094
# Epoch 5/50
# 0s - loss: 0.0137 - val_loss: 0.0232
# Epoch 6/50
# 0s - loss: 0.0133 - val_loss: 0.0124
# Epoch 7/50
# 0s - loss: 0.0128 - val_loss: 0.0106
# Epoch 8/50
# 0s - loss: 0.0123 - val_loss: 0.0196
# Epoch 9/50
# 0s - loss: 0.0120 - val_loss: 0.0233
# Epoch 10/50
# 0s - loss: 0.0117 - val_loss: 0.0093
# Epoch 11/50
# 0s - loss: 0.0112 - val_loss: 0.0121
# Epoch 12/50
# 0s - loss: 0.0111 - val_loss: 0.0131
# Epoch 13/50
# 0s - loss: 0.0109 - val_loss: 0.0064
# Epoch 14/50
# 0s - loss: 0.0106 - val_loss: 0.0078
# Epoch 15/50
# 0s - loss: 0.0104 - val_loss: 0.0192
# Epoch 16/50
# 0s - loss: 0.0102 - val_loss: 0.0082
# Epoch 17/50
# 0s - loss: 0.0100 - val_loss: 0.0073
# Epoch 18/50
# 0s - loss: 0.0098 - val_loss: 0.0095
# Epoch 19/50
# 0s - loss: 0.0097 - val_loss: 0.0056
# Epoch 20/50
# 0s - loss: 0.0095 - val_loss: 0.0155
# Epoch 21/50
# 0s - loss: 0.0094 - val_loss: 0.0146
# Epoch 22/50
# 0s - loss: 0.0092 - val_loss: 0.0049
# Epoch 23/50
# 0s - loss: 0.0090 - val_loss: 0.0192
# Epoch 24/50
# 0s - loss: 0.0090 - val_loss: 0.0251
# Epoch 25/50
# 0s - loss: 0.0088 - val_loss: 0.0137
# Epoch 26/50
# 0s - loss: 0.0088 - val_loss: 0.0301
# Epoch 27/50
# 0s - loss: 0.0086 - val_loss: 0.0119
# Epoch 28/50
# 0s - loss: 0.0085 - val_loss: 0.0082
# hiden node = 16
# _encoded_edim=16-Window=256-Overlap=16-Nadam
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/50
# 0s - loss: 0.0544 - val_loss: 0.0377
# Epoch 2/50
# 0s - loss: 0.0189 - val_loss: 0.0118
# Epoch 3/50
# 0s - loss: 0.0156 - val_loss: 0.0160
# Epoch 4/50
# 0s - loss: 0.0133 - val_loss: 0.0193
# Epoch 5/50
# 0s - loss: 0.0119 - val_loss: 0.0312
# Epoch 6/50
# 0s - loss: 0.0102 - val_loss: 0.0078
# Epoch 7/50
# 0s - loss: 0.0094 - val_loss: 0.0086
# Epoch 8/50
# 0s - loss: 0.0085 - val_loss: 0.0143
# Epoch 9/50
# 0s - loss: 0.0076 - val_loss: 0.0046
# Epoch 10/50
# 0s - loss: 0.0070 - val_loss: 0.0069
# Epoch 11/50
# 0s - loss: 0.0065 - val_loss: 0.0081
# Epoch 12/50
# 0s - loss: 0.0060 - val_loss: 0.0042
# Epoch 13/50
# 0s - loss: 0.0057 - val_loss: 0.0086
# Epoch 14/50
# 0s - loss: 0.0055 - val_loss: 0.0061
# Epoch 15/50
# 0s - loss: 0.0050 - val_loss: 0.0379
# Epoch 16/50
# 0s - loss: 0.0046 - val_loss: 0.0037
# Epoch 17/50
# 0s - loss: 0.0045 - val_loss: 0.0044
# Epoch 18/50
# 0s - loss: 0.0043 - val_loss: 0.0080
# Epoch 19/50
# 0s - loss: 0.0039 - val_loss: 0.0022
# Epoch 20/50
# 0s - loss: 0.0038 - val_loss: 0.0023
# Epoch 21/50
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 22/50
# 0s - loss: 0.0034 - val_loss: 0.0017
# Epoch 23/50
# 0s - loss: 0.0032 - val_loss: 0.0430
# Epoch 24/50
# 0s - loss: 0.0031 - val_loss: 0.0093
# Epoch 25/50
# 0s - loss: 0.0027 - val_loss: 0.0026
# Epoch 26/50
# 0s - loss: 0.0027 - val_loss: 0.0016
# Epoch 27/50
# 0s - loss: 0.0025 - val_loss: 0.0026
# Epoch 28/50
# 0s - loss: 0.0025 - val_loss: 0.0018
# Epoch 29/50
# 0s - loss: 0.0021 - val_loss: 0.0028
# Epoch 30/50
# 0s - loss: 0.0023 - val_loss: 0.0114
# Epoch 31/50
# 0s - loss: 0.0021 - val_loss: 0.0016
# Epoch 32/50
# 0s - loss: 0.0020 - val_loss: 0.0011
# Epoch 33/50
# 0s - loss: 0.0019 - val_loss: 0.0025
# Epoch 34/50
# 0s - loss: 0.0018 - val_loss: 0.0048
# Epoch 35/50
# 0s - loss: 0.0019 - val_loss: 0.0022
# Epoch 36/50
# 0s - loss: 0.0019 - val_loss: 0.0017
# Epoch 37/50
# 0s - loss: 0.0017 - val_loss: 0.0010
# Epoch 38/50
# 0s - loss: 0.0018 - val_loss: 9.8323e-04
# Epoch 39/50
# 0s - loss: 0.0017 - val_loss: 0.0012
# Epoch 40/50
# 0s - loss: 0.0017 - val_loss: 0.0098
# Epoch 41/50
# 0s - loss: 0.0017 - val_loss: 0.0012
# Epoch 42/50
# 0s - loss: 0.0016 - val_loss: 0.0020
# Epoch 43/50
# 0s - loss: 0.0017 - val_loss: 0.0015
# Epoch 44/50
# 0s - loss: 0.0016 - val_loss: 0.0061
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15890
# SourceData's aborting data = 6
# window shape is (15890, 512, 1)
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-SGD
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.6432 - val_loss: 0.5194
# Epoch 2/50
# 0s - loss: 0.4157 - val_loss: 0.3282
# Epoch 3/50
# 0s - loss: 0.2685 - val_loss: 0.2188
# Epoch 4/50
# 0s - loss: 0.1849 - val_loss: 0.1565
# Epoch 5/50
# 0s - loss: 0.1366 - val_loss: 0.1195
# Epoch 6/50
# 0s - loss: 0.1072 - val_loss: 0.0964
# Epoch 7/50
# 0s - loss: 0.0885 - val_loss: 0.0815
# Epoch 8/50
# 0s - loss: 0.0762 - val_loss: 0.0715
# Epoch 9/50
# 0s - loss: 0.0679 - val_loss: 0.0646
# Epoch 10/50
# 0s - loss: 0.0620 - val_loss: 0.0596
# Epoch 11/50
# 0s - loss: 0.0577 - val_loss: 0.0559
# Epoch 12/50
# 0s - loss: 0.0544 - val_loss: 0.0530
# Epoch 13/50
# 0s - loss: 0.0519 - val_loss: 0.0508
# Epoch 14/50
# 0s - loss: 0.0498 - val_loss: 0.0489
# Epoch 15/50
# 0s - loss: 0.0482 - val_loss: 0.0474
# Epoch 16/50
# 0s - loss: 0.0468 - val_loss: 0.0462
# Epoch 17/50
# 0s - loss: 0.0456 - val_loss: 0.0451
# Epoch 18/50
# 0s - loss: 0.0446 - val_loss: 0.0441
# Epoch 19/50
# 0s - loss: 0.0437 - val_loss: 0.0433
# Epoch 20/50
# 0s - loss: 0.0430 - val_loss: 0.0426
# Epoch 21/50
# 0s - loss: 0.0423 - val_loss: 0.0420
# Epoch 22/50
# 0s - loss: 0.0418 - val_loss: 0.0415
# Epoch 23/50
# 0s - loss: 0.0412 - val_loss: 0.0410
# Epoch 24/50
# 0s - loss: 0.0408 - val_loss: 0.0406
# Epoch 25/50
# 0s - loss: 0.0404 - val_loss: 0.0402
# Epoch 26/50
# 0s - loss: 0.0400 - val_loss: 0.0398
# Epoch 27/50
# 0s - loss: 0.0397 - val_loss: 0.0395
# Epoch 28/50
# 0s - loss: 0.0394 - val_loss: 0.0392
# Epoch 29/50
# 0s - loss: 0.0391 - val_loss: 0.0390
# Epoch 30/50
# 0s - loss: 0.0388 - val_loss: 0.0387
# Epoch 31/50
# 0s - loss: 0.0386 - val_loss: 0.0385
# Epoch 32/50
# 0s - loss: 0.0384 - val_loss: 0.0383
# Epoch 33/50
# 0s - loss: 0.0382 - val_loss: 0.0381
# Epoch 34/50
# 0s - loss: 0.0380 - val_loss: 0.0379
# Epoch 35/50
# 0s - loss: 0.0378 - val_loss: 0.0377
# Epoch 36/50
# 0s - loss: 0.0377 - val_loss: 0.0376
# Epoch 37/50
# 0s - loss: 0.0375 - val_loss: 0.0374
# Epoch 38/50
# 0s - loss: 0.0374 - val_loss: 0.0373
# Epoch 39/50
# 0s - loss: 0.0372 - val_loss: 0.0371
# Epoch 40/50
# 0s - loss: 0.0371 - val_loss: 0.0370
# Epoch 41/50
# 0s - loss: 0.0370 - val_loss: 0.0369
# Epoch 42/50
# 0s - loss: 0.0368 - val_loss: 0.0368
# Epoch 43/50
# 0s - loss: 0.0367 - val_loss: 0.0367
# Epoch 44/50
# 0s - loss: 0.0366 - val_loss: 0.0365
# Epoch 45/50
# 0s - loss: 0.0365 - val_loss: 0.0364
# Epoch 46/50
# 0s - loss: 0.0364 - val_loss: 0.0363
# Epoch 47/50
# 0s - loss: 0.0363 - val_loss: 0.0362
# Epoch 48/50
# 0s - loss: 0.0361 - val_loss: 0.0361
# Epoch 49/50
# 0s - loss: 0.0360 - val_loss: 0.0360
# Epoch 50/50
# 0s - loss: 0.0359 - val_loss: 0.0359
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-Adadelta
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.1136 - val_loss: 0.0370
# Epoch 2/50
# 0s - loss: 0.0369 - val_loss: 0.0417
# Epoch 3/50
# 0s - loss: 0.0286 - val_loss: 0.0235
# Epoch 4/50
# 0s - loss: 0.0236 - val_loss: 0.0270
# Epoch 5/50
# 0s - loss: 0.0200 - val_loss: 0.0223
# Epoch 6/50
# 0s - loss: 0.0177 - val_loss: 0.0165
# Epoch 7/50
# 0s - loss: 0.0168 - val_loss: 0.0230
# Epoch 8/50
# 0s - loss: 0.0160 - val_loss: 0.0126
# Epoch 9/50
# 0s - loss: 0.0151 - val_loss: 0.0161
# Epoch 10/50
# 0s - loss: 0.0145 - val_loss: 0.0112
# Epoch 11/50
# 0s - loss: 0.0143 - val_loss: 0.0166
# Epoch 12/50
# 0s - loss: 0.0143 - val_loss: 0.0128
# Epoch 13/50
# 0s - loss: 0.0130 - val_loss: 0.0105
# Epoch 14/50
# 0s - loss: 0.0132 - val_loss: 0.0111
# Epoch 15/50
# 0s - loss: 0.0131 - val_loss: 0.0133
# Epoch 16/50
# 0s - loss: 0.0130 - val_loss: 0.0097
# Epoch 17/50
# 0s - loss: 0.0128 - val_loss: 0.0148
# Epoch 18/50
# 0s - loss: 0.0122 - val_loss: 0.0121
# Epoch 19/50
# 0s - loss: 0.0118 - val_loss: 0.0138
# Epoch 20/50
# 0s - loss: 0.0117 - val_loss: 0.0123
# Epoch 21/50
# 0s - loss: 0.0115 - val_loss: 0.0083
# Epoch 22/50
# 0s - loss: 0.0116 - val_loss: 0.0166
# Epoch 23/50
# 0s - loss: 0.0111 - val_loss: 0.0121
# Epoch 24/50
# 0s - loss: 0.0112 - val_loss: 0.0092
# Epoch 25/50
# 0s - loss: 0.0111 - val_loss: 0.0169
# Epoch 26/50
# 0s - loss: 0.0103 - val_loss: 0.0104
# Epoch 27/50
# 0s - loss: 0.0111 - val_loss: 0.0105
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-Adamax
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.0632 - val_loss: 0.0329
# Epoch 2/50
# 0s - loss: 0.0252 - val_loss: 0.0179
# Epoch 3/50
# 0s - loss: 0.0149 - val_loss: 0.0146
# Epoch 4/50
# 0s - loss: 0.0104 - val_loss: 0.0093
# Epoch 5/50
# 0s - loss: 0.0073 - val_loss: 0.0064
# Epoch 6/50
# 0s - loss: 0.0057 - val_loss: 0.0046
# Epoch 7/50
# 0s - loss: 0.0047 - val_loss: 0.0043
# Epoch 8/50
# 0s - loss: 0.0042 - val_loss: 0.0039
# Epoch 9/50
# 0s - loss: 0.0036 - val_loss: 0.0057
# Epoch 10/50
# 0s - loss: 0.0031 - val_loss: 0.0036
# Epoch 11/50
# 0s - loss: 0.0030 - val_loss: 0.0030
# Epoch 12/50
# 0s - loss: 0.0028 - val_loss: 0.0024
# Epoch 13/50
# 0s - loss: 0.0028 - val_loss: 0.0022
# Epoch 14/50
# 0s - loss: 0.0027 - val_loss: 0.0027
# Epoch 15/50
# 0s - loss: 0.0025 - val_loss: 0.0020
# Epoch 16/50
# 0s - loss: 0.0024 - val_loss: 0.0020
# Epoch 17/50
# 0s - loss: 0.0024 - val_loss: 0.0019
# Epoch 18/50
# 0s - loss: 0.0022 - val_loss: 0.0023
# Epoch 19/50
# 0s - loss: 0.0021 - val_loss: 0.0018
# Epoch 20/50
# 0s - loss: 0.0021 - val_loss: 0.0027
# Epoch 21/50
# 0s - loss: 0.0021 - val_loss: 0.0032
# Epoch 22/50
# 0s - loss: 0.0020 - val_loss: 0.0018
# Epoch 23/50
# 0s - loss: 0.0019 - val_loss: 0.0016
# Epoch 24/50
# 0s - loss: 0.0020 - val_loss: 0.0032
# Epoch 25/50
# 0s - loss: 0.0021 - val_loss: 0.0018
# Epoch 26/50
# 0s - loss: 0.0020 - val_loss: 0.0018
# Epoch 27/50
# 0s - loss: 0.0019 - val_loss: 0.0017
# Epoch 28/50
# 0s - loss: 0.0019 - val_loss: 0.0018
# Epoch 29/50
# 0s - loss: 0.0020 - val_loss: 0.0017
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-Adam
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.0730 - val_loss: 0.0278
# Epoch 2/50
# 0s - loss: 0.0200 - val_loss: 0.0142
# Epoch 3/50
# 0s - loss: 0.0119 - val_loss: 0.0101
# Epoch 4/50
# 0s - loss: 0.0084 - val_loss: 0.0068
# Epoch 5/50
# 0s - loss: 0.0065 - val_loss: 0.0052
# Epoch 6/50
# 0s - loss: 0.0052 - val_loss: 0.0043
# Epoch 7/50
# 0s - loss: 0.0046 - val_loss: 0.0037
# Epoch 8/50
# 0s - loss: 0.0043 - val_loss: 0.0051
# Epoch 9/50
# 0s - loss: 0.0037 - val_loss: 0.0031
# Epoch 10/50
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 11/50
# 0s - loss: 0.0032 - val_loss: 0.0027
# Epoch 12/50
# 0s - loss: 0.0029 - val_loss: 0.0023
# Epoch 13/50
# 0s - loss: 0.0029 - val_loss: 0.0031
# Epoch 14/50
# 0s - loss: 0.0028 - val_loss: 0.0022
# Epoch 15/50
# 0s - loss: 0.0026 - val_loss: 0.0035
# Epoch 16/50
# 0s - loss: 0.0025 - val_loss: 0.0031
# Epoch 17/50
# 0s - loss: 0.0026 - val_loss: 0.0020
# Epoch 18/50
# 0s - loss: 0.0023 - val_loss: 0.0019
# Epoch 19/50
# 0s - loss: 0.0024 - val_loss: 0.0030
# Epoch 20/50
# 0s - loss: 0.0024 - val_loss: 0.0026
# Epoch 21/50
# 0s - loss: 0.0022 - val_loss: 0.0017
# Epoch 22/50
# 0s - loss: 0.0023 - val_loss: 0.0024
# Epoch 23/50
# 0s - loss: 0.0021 - val_loss: 0.0016
# Epoch 24/50
# 0s - loss: 0.0022 - val_loss: 0.0017
# Epoch 25/50
# 0s - loss: 0.0021 - val_loss: 0.0018
# Epoch 26/50
# 0s - loss: 0.0020 - val_loss: 0.0018
# Epoch 27/50
# 0s - loss: 0.0021 - val_loss: 0.0020
# Epoch 28/50
# 0s - loss: 0.0021 - val_loss: 0.0017
# Epoch 29/50
# 0s - loss: 0.0021 - val_loss: 0.0035
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-Adagrad
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.0534 - val_loss: 0.0310
# Epoch 2/50
# 0s - loss: 0.0275 - val_loss: 0.0215
# Epoch 3/50
# 0s - loss: 0.0192 - val_loss: 0.0178
# Epoch 4/50
# 0s - loss: 0.0157 - val_loss: 0.0134
# Epoch 5/50
# 0s - loss: 0.0138 - val_loss: 0.0150
# Epoch 6/50
# 0s - loss: 0.0124 - val_loss: 0.0147
# Epoch 7/50
# 0s - loss: 0.0113 - val_loss: 0.0099
# Epoch 8/50
# 0s - loss: 0.0106 - val_loss: 0.0092
# Epoch 9/50
# 0s - loss: 0.0099 - val_loss: 0.0109
# Epoch 10/50
# 0s - loss: 0.0093 - val_loss: 0.0091
# Epoch 11/50
# 0s - loss: 0.0088 - val_loss: 0.0090
# Epoch 12/50
# 0s - loss: 0.0083 - val_loss: 0.0099
# Epoch 13/50
# 0s - loss: 0.0080 - val_loss: 0.0096
# Epoch 14/50
# 0s - loss: 0.0077 - val_loss: 0.0072
# Epoch 15/50
# 0s - loss: 0.0073 - val_loss: 0.0066
# Epoch 16/50
# 0s - loss: 0.0072 - val_loss: 0.0062
# Epoch 17/50
# 0s - loss: 0.0069 - val_loss: 0.0062
# Epoch 18/50
# 0s - loss: 0.0064 - val_loss: 0.0071
# Epoch 19/50
# 0s - loss: 0.0063 - val_loss: 0.0057
# Epoch 20/50
# 0s - loss: 0.0061 - val_loss: 0.0057
# Epoch 21/50
# 0s - loss: 0.0061 - val_loss: 0.0053
# Epoch 22/50
# 0s - loss: 0.0058 - val_loss: 0.0055
# Epoch 23/50
# 0s - loss: 0.0059 - val_loss: 0.0060
# Epoch 24/50
# 0s - loss: 0.0056 - val_loss: 0.0052
# Epoch 25/50
# 0s - loss: 0.0053 - val_loss: 0.0048
# Epoch 26/50
# 0s - loss: 0.0054 - val_loss: 0.0050
# Epoch 27/50
# 0s - loss: 0.0050 - val_loss: 0.0046
# Epoch 28/50
# 0s - loss: 0.0051 - val_loss: 0.0047
# Epoch 29/50
# 0s - loss: 0.0050 - val_loss: 0.0065
# Epoch 30/50
# 0s - loss: 0.0049 - val_loss: 0.0044
# Epoch 31/50
# 0s - loss: 0.0047 - val_loss: 0.0042
# Epoch 32/50
# 0s - loss: 0.0046 - val_loss: 0.0047
# Epoch 33/50
# 0s - loss: 0.0045 - val_loss: 0.0052
# Epoch 34/50
# 0s - loss: 0.0044 - val_loss: 0.0044
# Epoch 35/50
# 0s - loss: 0.0046 - val_loss: 0.0045
# Epoch 36/50
# 0s - loss: 0.0044 - val_loss: 0.0047
# Epoch 37/50
# 0s - loss: 0.0041 - val_loss: 0.0045
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-RMSprop
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.0688 - val_loss: 0.0308
# Epoch 2/50
# 0s - loss: 0.0265 - val_loss: 0.0356
# Epoch 3/50
# 0s - loss: 0.0233 - val_loss: 0.0202
# Epoch 4/50
# 0s - loss: 0.0213 - val_loss: 0.0147
# Epoch 5/50
# 0s - loss: 0.0202 - val_loss: 0.0323
# Epoch 6/50
# 0s - loss: 0.0192 - val_loss: 0.0127
# Epoch 7/50
# 0s - loss: 0.0182 - val_loss: 0.0137
# Epoch 8/50
# 0s - loss: 0.0174 - val_loss: 0.0122
# Epoch 9/50
# 0s - loss: 0.0167 - val_loss: 0.0189
# Epoch 10/50
# 0s - loss: 0.0162 - val_loss: 0.0214
# Epoch 11/50
# 0s - loss: 0.0158 - val_loss: 0.0109
# Epoch 12/50
# 0s - loss: 0.0154 - val_loss: 0.0157
# Epoch 13/50
# 0s - loss: 0.0151 - val_loss: 0.0093
# Epoch 14/50
# 0s - loss: 0.0148 - val_loss: 0.0336
# Epoch 15/50
# 0s - loss: 0.0145 - val_loss: 0.0188
# Epoch 16/50
# 0s - loss: 0.0142 - val_loss: 0.0182
# Epoch 17/50
# 0s - loss: 0.0140 - val_loss: 0.0097
# Epoch 18/50
# 0s - loss: 0.0137 - val_loss: 0.0097
# Epoch 19/50
# 0s - loss: 0.0135 - val_loss: 0.0117
# hiden node = 16
# _encoded_edim=16-Window=512-Overlap=16-Nadam
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/50
# 0s - loss: 0.0697 - val_loss: 0.0620
# Epoch 2/50
# 0s - loss: 0.0306 - val_loss: 0.0178
# Epoch 3/50
# 0s - loss: 0.0224 - val_loss: 0.0198
# Epoch 4/50
# 0s - loss: 0.0216 - val_loss: 0.0121
# Epoch 5/50
# 0s - loss: 0.0173 - val_loss: 0.0400
# Epoch 6/50
# 0s - loss: 0.0156 - val_loss: 0.0091
# Epoch 7/50
# 0s - loss: 0.0132 - val_loss: 0.0112
# Epoch 8/50
# 0s - loss: 0.0123 - val_loss: 0.0142
# Epoch 9/50
# 0s - loss: 0.0113 - val_loss: 0.0139
# Epoch 10/50
# 0s - loss: 0.0106 - val_loss: 0.0106
# Epoch 11/50
# 0s - loss: 0.0099 - val_loss: 0.0084
# Epoch 12/50
# 0s - loss: 0.0095 - val_loss: 0.0109
# Epoch 13/50
# 0s - loss: 0.0090 - val_loss: 0.0075
# Epoch 14/50
# 0s - loss: 0.0086 - val_loss: 0.0064
# Epoch 15/50
# 0s - loss: 0.0082 - val_loss: 0.0084
# Epoch 16/50
# 0s - loss: 0.0078 - val_loss: 0.0062
# Epoch 17/50
# 0s - loss: 0.0074 - val_loss: 0.0077
# Epoch 18/50
# 0s - loss: 0.0069 - val_loss: 0.0071
# Epoch 19/50
# 0s - loss: 0.0064 - val_loss: 0.0070
# Epoch 20/50
# 0s - loss: 0.0063 - val_loss: 0.0039
# Epoch 21/50
# 0s - loss: 0.0060 - val_loss: 0.0059
# Epoch 22/50
# 0s - loss: 0.0058 - val_loss: 0.0035
# Epoch 23/50
# 0s - loss: 0.0056 - val_loss: 0.0058
# Epoch 24/50
# 0s - loss: 0.0052 - val_loss: 0.0039
# Epoch 25/50
# 0s - loss: 0.0050 - val_loss: 0.0055
# Epoch 26/50
# 0s - loss: 0.0049 - val_loss: 0.0035
# Epoch 27/50
# 0s - loss: 0.0046 - val_loss: 0.0053
# Epoch 28/50
# 0s - loss: 0.0047 - val_loss: 0.0039
# Epoch 29/50
# 0s - loss: 0.0043 - val_loss: 0.0051
# Epoch 30/50
# 0s - loss: 0.0043 - val_loss: 0.0064
# Epoch 31/50
# 0s - loss: 0.0042 - val_loss: 0.0045
# Epoch 32/50
# 0s - loss: 0.0042 - val_loss: 0.0030
# Epoch 33/50
# 0s - loss: 0.0040 - val_loss: 0.0029
# Epoch 34/50
# 0s - loss: 0.0040 - val_loss: 0.0036
# Epoch 35/50
# 0s - loss: 0.0040 - val_loss: 0.0069
# Epoch 36/50
# 0s - loss: 0.0039 - val_loss: 0.0027
# Epoch 37/50
# 0s - loss: 0.0038 - val_loss: 0.0062
# Epoch 38/50
# 0s - loss: 0.0038 - val_loss: 0.0028
# Epoch 39/50
# 0s - loss: 0.0038 - val_loss: 0.0081
# Epoch 40/50
# 0s - loss: 0.0037 - val_loss: 0.0028
# Epoch 41/50
# 0s - loss: 0.0037 - val_loss: 0.0064
# Epoch 42/50
# 0s - loss: 0.0037 - val_loss: 0.0035
# AccX is registed now
# Build Complete
# (254742,)
# windowData's num =15858
# SourceData's aborting data = 6

# %%
print "finish"
