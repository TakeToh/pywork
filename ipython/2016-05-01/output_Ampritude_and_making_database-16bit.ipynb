# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import fftpack
from scipy import signal
import numpy as np
import pandas as pd
import datetime
import time as T

# %%
#my workstation

# %%
#cd /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data/

# %%
#mozart

# %%
cd ~/Documents/SyncRecord/FFT-data/
# Out:
# /home/takeyama/Documents/SyncRecord/FFT-data

# %%
ls
# Out:
# FFT-Cleaning-Conv-left-hand-ags.csv-128bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-16bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-256bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-32bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-512bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-64bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-128bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-16bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-256bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-32bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-512bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-64bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-128bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-16bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-256bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-32bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-512bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-64bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-128bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-16bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-256bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-32bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-512bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-64bit.csv
# FFT-Cleaning-Conv-west-ags.csv-128bit.csv
# FFT-Cleaning-Conv-west-ags.csv-16bit.csv
# FFT-Cleaning-Conv-west-ags.csv-256bit.csv
# FFT-Cleaning-Conv-west-ags.csv-32bit.csv
# FFT-Cleaning-Conv-west-ags.csv-512bit.csv
# FFT-Cleaning-Conv-west-ags.csv-64bit.csv

# %%
fft_left_hand = pd.read_csv('FFT-Cleaning-Conv-left-hand-ags.csv'+'-16'+'bit.csv')
#left_hand.Time=pd.to_timedelta(left_hand.Time)
fft_left_leg = pd.read_csv('FFT-'+'Cleaning-Conv-left-leg-ags.csv'+'-16'+'bit.csv')
#left_leg.Time=pd.to_timedelta(left_leg.Time)
fft_right_hand = pd.read_csv('FFT-'+'Cleaning-Conv-right-hand-ags.csv'+'-16'+'bit.csv')
#right_hand.Time=pd.to_timedelta(right_hand.Time)
fft_right_leg = pd.read_csv('FFT-'+'Cleaning-Conv-right-leg-ags.csv'+'-16'+'bit.csv')
#right_leg.Time=pd.to_timedelta(right_leg.Time)
fft_west = pd.read_csv('FFT-'+'Cleaning-Conv-west-ags.csv'+'-16'+'bit.csv')
#west.Time=pd.to_timedelta(west.Time)

fft_name=['FFT-Cleaning-Conv-left-hand-ags.csv'+'-16'+'bit.csv','FFT-'+'Cleaning-Conv-left-leg-ags.csv'+'-16'+'bit.csv',
          'FFT-'+'Cleaning-Conv-right-hand-ags.csv'+'-16'+'bit.csv','FFT-'+'Cleaning-Conv-right-leg-ags.csv'+'-16'+'bit.csv',
          'FFT-'+'Cleaning-Conv-west-ags.csv'+'-16'+'bit.csv']

# %%
# left_hand
start_time = T.clock()
Amp_left_handAX=np.array([])
Amp_left_handAY=np.array([])
Amp_left_handAZ=np.array([])

Amp_left_handGX=np.array([])
Amp_left_handGY=np.array([])
Amp_left_handGZ=np.array([])

x = fft_right_leg.where(fft_left_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAX = np.append(Amp_left_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAY = np.append(Amp_left_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAZ = np.append(Amp_left_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGX = np.append(Amp_left_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGY = np.append(Amp_left_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGZ = np.append(Amp_left_handGZ, tmp)

for t in range(1,fft_left_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_left_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAX = np.vstack((Amp_left_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAY = np.vstack((Amp_left_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAZ = np.vstack((Amp_left_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGX = np.vstack((Amp_left_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGY = np.vstack((Amp_left_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGZ = np.vstack((Amp_left_handGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:593.859878[sec]

# %%
# right_leg
start_time = T.clock()
Amp_right_legAX=np.array([])
Amp_right_legAY=np.array([])
Amp_right_legAZ=np.array([])

Amp_right_legGX=np.array([])
Amp_right_legGY=np.array([])
Amp_right_legGZ=np.array([])

x = fft_right_leg.where(fft_right_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAX = np.append(Amp_right_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAY = np.append(Amp_right_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAZ = np.append(Amp_right_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGX = np.append(Amp_right_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGY = np.append(Amp_right_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGZ = np.append(Amp_right_legGZ, tmp)

for t in range(1,fft_right_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_right_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAX = np.vstack((Amp_right_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAY = np.vstack((Amp_right_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAZ = np.vstack((Amp_right_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGX = np.vstack((Amp_right_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGY = np.vstack((Amp_right_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGZ = np.vstack((Amp_right_legGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:198.023911[sec]

# %%
# Left_leg
start_time = T.clock()
Amp_left_legAX=np.array([])
Amp_left_legAY=np.array([])
Amp_left_legAZ=np.array([])

Amp_left_legGX=np.array([])
Amp_left_legGY=np.array([])
Amp_left_legGZ=np.array([])

x = fft_left_leg.where(fft_left_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAX = np.append(Amp_left_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAY = np.append(Amp_left_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAZ = np.append(Amp_left_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGX = np.append(Amp_left_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGY = np.append(Amp_left_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGZ = np.append(Amp_left_legGZ, tmp)

for t in range(1,fft_left_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_left_leg.where(fft_left_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAX = np.vstack((Amp_left_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAY = np.vstack((Amp_left_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAZ = np.vstack((Amp_left_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGX = np.vstack((Amp_left_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGY = np.vstack((Amp_left_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGZ = np.vstack((Amp_left_legGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:191.981616[sec]

# %%
# right_hand
start_time = T.clock()
Amp_right_handAX=np.array([])
Amp_right_handAY=np.array([])
Amp_right_handAZ=np.array([])

Amp_right_handGX=np.array([])
Amp_right_handGY=np.array([])
Amp_right_handGZ=np.array([])

x = fft_right_hand.where(fft_right_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAX = np.append(Amp_right_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAY = np.append(Amp_right_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAZ = np.append(Amp_right_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGX = np.append(Amp_right_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGY = np.append(Amp_right_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGZ = np.append(Amp_right_handGZ, tmp)

for t in range(1,fft_right_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_hand.where(fft_right_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAX = np.vstack((Amp_right_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAY = np.vstack((Amp_right_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAZ = np.vstack((Amp_right_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGX = np.vstack((Amp_right_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGY = np.vstack((Amp_right_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGZ = np.vstack((Amp_right_handGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:192.060141[sec]

# %%
# west
start_time = T.clock()
Amp_westAX=np.array([])
Amp_westAY=np.array([])
Amp_westAZ=np.array([])

Amp_westGX=np.array([])
Amp_westGY=np.array([])
Amp_westGZ=np.array([])

x = fft_west.where(fft_west.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_westAX = np.append(Amp_westAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_westAY = np.append(Amp_westAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westAZ = np.append(Amp_westAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_westGX = np.append(Amp_westGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_westGY = np.append(Amp_westGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westGZ = np.append(Amp_westGZ, tmp)

for t in range(1,fft_west.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_west.where(fft_west.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAX = np.vstack((Amp_westAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAY = np.vstack((Amp_westAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAZ = np.vstack((Amp_westAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGX = np.vstack((Amp_westGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGY = np.vstack((Amp_westGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGZ = np.vstack((Amp_westGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:4.400932[sec]

# %%
Amp_westAX.shape
# Out:
# (698, 8)

# %%
fft_name=['FFT-Cleaning-Conv-left-hand-ags.csv'+'-16'+'bit.csv','FFT-'+'Cleaning-Conv-left-leg-ags.csv'+'-16'+'bit.csv',
          'FFT-'+'Cleaning-Conv-right-hand-ags.csv'+'-16'+'bit.csv','FFT-'+'Cleaning-Conv-right-leg-ags.csv'+'-16'+'bit.csv',
          'FFT-'+'Cleaning-Conv-west-ags.csv'+'-16'+'bit.csv']

# %%
def GetLabelNam(samp):
    l=['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th', '11th',
    '12th', '13th', '14th', '15th', '16th', '17th', '18th', '19th', '20th', '21st',
    '22nd', '23rd', '24th', '25th', '26th', '27th', '28th', '29th', '30th', '31st']
    
    return l[0:(samp/2)]

# %%
fft_left_hand
# Out:
#        Time Number  AccX_imag  AccX_real  AccY_imag  AccY_real  AccZ_imag  \
# 0         0    1st  -0.015192   0.358045  -0.869577  -1.991186   1.070767
# 1         0    2nd  -0.103970  -0.094514   0.583755  -0.466071   0.504561
# 2         0    3rd  -0.104528   0.058390   0.365722  -0.080314   0.164233
# 3         0    4th  -0.075054  -0.003471   0.100201   0.070954   0.156054
# 4         0    5th  -0.044162   0.022334   0.024453  -0.080821   0.105954
# 5         0    6th   0.008623   0.016851  -0.002447  -0.106568   0.080587
# 6         0    7th   0.036522   0.040966   0.007449  -0.122248   0.081826
# 7         0    8th   0.042200   0.118650  -0.026055  -0.115296   0.051019
# 8         1    1st  -0.632648  -0.352107  -0.905587   0.886202   0.150102
# 9         1    2nd  -0.096606   0.022840  -0.593620   0.431742   0.648457
# 10        1    3rd  -0.043589   0.047968  -0.325155   0.297296   0.266450
# 11        1    4th  -0.059696   0.032183  -0.245297   0.215677   0.149417
# 12        1    5th  -0.032404   0.059916  -0.237076   0.193977   0.108730
# 13        1    6th  -0.038681   0.082980  -0.134584   0.234674   0.070946
# 14        1    7th   0.006499   0.072002  -0.088348   0.234724   0.051989
# 15        1    8th  -0.015128   0.056517  -0.034792   0.222808   0.047504
# 16        2    1st  -1.067240   0.104354  -1.424992  -0.544493   0.299251
# 17        2    2nd  -0.531984   0.295617  -0.751024   0.285867  -0.019393
# 18        2    3rd  -0.352961   0.155215  -0.532554   0.192088  -0.073149
# 19        2    4th  -0.227357   0.185931  -0.236709   0.276073  -0.021741
# 20        2    5th  -0.158044   0.210359  -0.221438   0.299770  -0.001418
# 21        2    6th  -0.114681   0.194946  -0.159465   0.273196   0.001877
# 22        2    7th  -0.064581   0.179536  -0.069475   0.280297   0.000696
# 23        2    8th  -0.005724   0.192293  -0.035562   0.270903   0.014377
# 24        3    1st  -0.758383   0.428282  -2.030980   0.895451   0.075222
# 25        3    2nd  -0.411786   0.198231  -0.919091   0.288985  -0.036355
# 26        3    3rd  -0.259188   0.194640  -0.575781   0.390312  -0.004463
# 27        3    4th  -0.179520   0.147952  -0.382822   0.393096   0.000731
# 28        3    5th  -0.098588   0.161804  -0.268518   0.353010  -0.006223
# 29        3    6th  -0.072147   0.148229  -0.195100   0.354050  -0.005860
# ...     ...    ...        ...        ...        ...        ...        ...
# 55440  6930    1st   0.112294   0.346382  -0.366925   0.542414   0.427950
# 55441  6930    2nd  -0.042509   0.049959  -0.196142   0.260575  -0.188258
# 55442  6930    3rd   0.068712  -0.003253  -0.151891  -0.032927  -0.200567
# 55443  6930    4th  -0.007727  -0.033621  -0.119610   0.113003   0.006283
# 55444  6930    5th   0.033235   0.054699  -0.034005   0.039275  -0.043848
# 55445  6930    6th   0.014201  -0.100340  -0.015454   0.093346  -0.044185
# 55446  6930    7th  -0.043838   0.054537  -0.003041   0.097171   0.015686
# 55447  6930    8th   0.091906  -0.061863  -0.000703   0.086940   0.044336
# 55448  6931    1st   0.531630  -0.310988   0.633940   0.389171  -0.392602
# 55449  6931    2nd   0.034164  -0.101017   0.602982   0.019588  -0.178689
# 55450  6931    3rd   0.066916  -0.117563   0.107626  -0.145599   0.170935
# 55451  6931    4th  -0.000465  -0.112603   0.024222  -0.108141   0.014294
# 55452  6931    5th   0.065166  -0.096591   0.031899  -0.078112   0.023488
# 55453  6931    6th   0.080435  -0.072722   0.064703  -0.108694   0.014337
# 55454  6931    7th   0.099614  -0.005349   0.004747  -0.115274  -0.008454
# 55455  6931    8th   0.053702   0.043133   0.028528  -0.094991   0.015786
# 55456  6932    1st  -0.223201   0.069342  -0.124272  -0.684365   0.011053
# 55457  6932    2nd   0.077128  -0.054756   0.185314   0.495601  -0.111260
# 55458  6932    3rd  -0.030973  -0.050157   0.145772  -0.012767  -0.111086
# 55459  6932    4th   0.025156  -0.049481   0.050417  -0.094795  -0.006550
# 55460  6932    5th  -0.016108  -0.033400   0.061401  -0.004450  -0.011865
# 55461  6932    6th   0.017790   0.001607   0.030816  -0.024283  -0.010167
# 55462  6932    7th   0.040393  -0.035955   0.012698  -0.042241  -0.027168
# 55463  6932    8th  -0.040393  -0.035955  -0.012698  -0.042241   0.027168
# 55464  6933    1st   0.078883  -0.009777  -0.081775   0.397402   0.214382
# 55465  6933    2nd   0.018196  -0.019517  -0.059565   0.055469   0.066426
# 55466  6933    3rd   0.034772   0.008044   0.000473   0.048929  -0.014855
# 55467  6933    4th  -0.034772   0.008044  -0.000473   0.048929   0.014855
# 55468  6933    5th  -0.018196  -0.019517   0.059565   0.055469  -0.066426
# 55469  6933    6th  -0.078883  -0.009777   0.081775   0.397402  -0.214382
#
#        AccZ_real  GyrX_imag  GyrX_real  GyrY_imag  GyrY_real  GyrZ_imag  \
# 0       0.360219 -32.797698  15.109767 -10.299680   5.271495  -5.125378
# 1      -0.320706 -10.844850   3.459231  -3.601636   1.810484  -2.845803
# 2      -0.203757  -6.372311   3.403319  -2.309824   1.560055  -1.884029
# 3      -0.184714  -4.014669   3.820903  -1.489992   1.605612  -1.263464
# 4      -0.153572  -2.838582   3.747483  -1.125411   1.565741  -0.846813
# 5      -0.145958  -1.916918   3.792987  -0.708752   1.566015  -0.565537
# 6      -0.098964  -1.034338   3.718784  -0.367491   1.527345  -0.299721
# 7      -0.132149  -0.368778   3.775401  -0.135877   1.461038  -0.082316
# 8      -0.620925   6.051575   4.182199   1.249559   1.616194  -4.782714
# 9      -0.083275  -0.770185   2.306252  -0.149478   1.040132  -2.008409
# 10     -0.116571  -0.791167   1.416396  -0.180482   0.531225  -1.255757
# 11     -0.149271  -0.692243   1.165134  -0.115583   0.368977  -0.824653
# 12     -0.114332  -0.508958   0.970825  -0.084008   0.300747  -0.546832
# 13     -0.147592  -0.335716   0.887716  -0.108964   0.288032  -0.355392
# 14     -0.153566  -0.204608   0.809762  -0.041297   0.188052  -0.167993
# 15     -0.109868  -0.077714   0.805310   0.014746   0.242633  -0.087270
# 16     -0.125400  -5.986412  -3.840271   2.427219  -0.115558   2.317869
# 17      0.200025  -0.876965   0.030946   1.073787  -0.437463   1.004446
# 18      0.032601  -0.496562   0.152067   0.746799  -0.452785   0.651674
# 19      0.025047  -0.316384   0.156345   0.497415  -0.446652   0.355228
# 20      0.020304  -0.220575   0.203395   0.318609  -0.443179   0.315427
# 21      0.032761  -0.133165   0.231159   0.209946  -0.444742   0.177488
# 22      0.036977  -0.102731   0.225390   0.117163  -0.454303   0.081156
# 23      0.020085  -0.028109   0.221405   0.038661  -0.451718   0.056813
# 24      0.135856   1.146109   5.663823   2.296114  -0.889946   8.353991
# 25     -0.071108  -0.257739   0.889549   0.963117  -0.510645   3.911240
# 26      0.020668   0.037383   0.324586   0.591464  -0.436322   2.501015
# 27     -0.016532   0.039665   0.178834   0.438483  -0.416972   1.667221
# 28     -0.011112   0.022473   0.134103   0.279148  -0.398352   1.158887
# 29     -0.003603   0.022024   0.094201   0.179777  -0.393329   0.767401
# ...          ...        ...        ...        ...        ...        ...
# 55440   0.862050   1.503969   1.208443  -0.940651   1.045037  -0.785459
# 55441  -0.030414  -0.686442  -0.236744  -0.388932   0.038477  -0.001896
# 55442   0.178691  -0.627900  -0.205596  -0.252655   0.094396  -0.020021
# 55443  -0.025837  -0.121637   0.144202  -0.099583   0.138671  -0.006612
# 55444   0.078093  -0.229686   0.088676  -0.089170   0.158219  -0.012405
# 55445  -0.012560  -0.114489   0.079033  -0.077720   0.119714   0.001253
# 55446  -0.008766  -0.056129   0.071619  -0.032115   0.117991   0.004905
# 55447   0.065442  -0.032782   0.118873  -0.000190   0.155784  -0.009947
# 55448  -0.917766  -2.038326  -0.182286   1.140846  -0.067212  -0.541829
# 55449  -0.138772   0.809467  -0.429046   0.360419  -0.317468  -0.520409
# 55450  -0.018020   0.214314   0.024451   0.151444  -0.038180  -0.284204
# 55451  -0.007119   0.013596  -0.026644   0.103103  -0.091959  -0.164827
# 55452   0.037497  -0.006872  -0.024471   0.047526  -0.082683  -0.126834
# 55453  -0.002182  -0.019383  -0.021224   0.049626  -0.083641  -0.088172
# 55454   0.038745  -0.006155  -0.024062   0.024997  -0.066232  -0.069827
# 55455   0.018416  -0.029334  -0.043473   0.008625  -0.089861  -0.005489
# 55456   0.796005   0.282825   0.125519  -0.061702  -0.318206   0.166647
# 55457  -0.196202   0.150937   0.679710   0.381500  -0.127710   0.516310
# 55458  -0.055554  -0.022651  -0.028578   0.178982  -0.100959   0.188357
# 55459  -0.012535  -0.131317   0.132408   0.138364  -0.098439   0.156194
# 55460  -0.005750  -0.028567   0.137445   0.071796  -0.110741   0.098399
# 55461   0.019354  -0.020881   0.080502   0.041111  -0.119302   0.058604
# 55462   0.069481  -0.019314   0.092980   0.012364  -0.100631  -0.021013
# 55463   0.069481   0.019314   0.092980  -0.012364  -0.100631   0.021013
# 55464  -0.246677   0.165501   0.168264   0.112653   0.065638   0.452799
# 55465  -0.095243  -0.083253   0.057929   0.047624  -0.015910   0.165788
# 55466  -0.077230  -0.015417   0.014575   0.004661  -0.028958   0.013205
# 55467  -0.077230   0.015417   0.014575  -0.004661  -0.028958  -0.013205
# 55468  -0.095243   0.083253   0.057929  -0.047624  -0.015910  -0.165788
# 55469  -0.246677  -0.165501   0.168264  -0.112653   0.065638  -0.452799
#
#        GyrZ_real
# 0       1.122696
# 1       1.582849
# 2       1.299952
# 3       1.126835
# 4       1.140570
# 5       1.156530
# 6       1.182961
# 7       1.199499
# 8       1.945118
# 9       1.007427
# 10      0.805591
# 11      0.833309
# 12      0.828606
# 13      0.771259
# 14      0.753038
# 15      0.765819
# 16      2.660764
# 17      0.124768
# 18     -0.039816
# 19     -0.233604
# 20     -0.273924
# 21     -0.287906
# 22     -0.299001
# 23     -0.333033
# 24     -0.416086
# 25     -1.104657
# 26     -1.311648
# 27     -1.430408
# 28     -1.451319
# 29     -1.460076
# ...          ...
# 55440  -0.875828
# 55441  -0.307212
# 55442   0.049560
# 55443  -0.003108
# 55444   0.019076
# 55445   0.005320
# 55446   0.047693
# 55447   0.021840
# 55448   0.451433
# 55449  -0.075772
# 55450   0.205714
# 55451   0.176691
# 55452   0.177368
# 55453   0.150718
# 55454   0.190462
# 55455   0.192778
# 55456   0.512565
# 55457  -0.230489
# 55458  -0.097448
# 55459  -0.091912
# 55460  -0.151756
# 55461  -0.126914
# 55462  -0.092513
# 55463  -0.092513
# 55464  -0.154803
# 55465  -0.143440
# 55466  -0.163571
# 55467  -0.163571
# 55468  -0.143440
# 55469  -0.154803
#
# [55470 rows x 14 columns]

# %%
start_time = T.clock()
sample_bit=16

label = fft_left_hand.label
array =  GetLabelNam(sample_bit)
TimeArray=[]
NumArray=[]
LabelArray=[]

for t in range(0,fft_left_hand.Time.max()):
    for i in range(len(array)):
        TimeArray.append(str(t))
        
for i in range(0,fft_left_hand.Time.max()):
    for a in array:
        NumArray.append(a)

TimeArray=np.array(TimeArray)
NumArray=np.array(NumArray)
LabelArray=np.array(LabelArray)

fftdf=pd.DataFrame({
        'AccX_real':Amp_left_handAX,
        'AccY_real':Amp_left_handAY,
        'AccZ_real':Amp_left_handAZ,
        'GyrX_real':Amp_left_handGX,
        'GyrY_real':Amp_left_handGY,
        'GyrZ_real':Amp_left_handGZ,
        'Time':TimeArray,
        'Number':NumArray,
        'Label':LabelArray
        }
      )

#fftdf = fftdf.astype(np.float64)

fftdf1.to_csv('Amp-'+n)

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-28ecf5164003> in <module>()
#      28         'Time':TimeArray,
#      29         'Number':NumArray,
# ---> 30         'Label':LabelArray
#      31         }
#      32       )
#
# /home/takeyama/.pyenv/versions/2.7.10/envs/my_workspace/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     221                                  dtype=dtype, copy=copy)
#     222         elif isinstance(data, dict):
# --> 223             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     224         elif isinstance(data, ma.MaskedArray):
#     225             import numpy.ma.mrecords as mrecords
#
# /home/takeyama/.pyenv/versions/2.7.10/envs/my_workspace/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     357             arrays = [data[k] for k in keys]
#     358
# --> 359         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     360
#     361     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /home/takeyama/.pyenv/versions/2.7.10/envs/my_workspace/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5238     # figure out the index, if necessary
#    5239     if index is None:
# -> 5240         index = extract_index(arrays)
#    5241     else:
#    5242         index = _ensure_index(index)
#
# /home/takeyama/.pyenv/versions/2.7.10/envs/my_workspace/lib/python2.7/site-packages/pandas/core/frame.pyc in extract_index(data)
#    5286             lengths = list(set(raw_lengths))
#    5287             if len(lengths) > 1:
# -> 5288                 raise ValueError('arrays must all be same length')
#    5289
#    5290             if have_dicts:
#
# ValueError: arrays must all be same length
