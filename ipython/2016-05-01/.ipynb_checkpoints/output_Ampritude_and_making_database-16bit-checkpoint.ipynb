# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import fftpack
from scipy import signal
import numpy as np
import pandas as pd
import datetime
import time as T

# %%
#my workstation

# %%
cd /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data/
# Out:
# /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data

# %%
fft_left_hand = pd.read_csv('FFT-Cleaning-Conv-left-hand-ags.csv'+'-16'+'bit.csv')
#left_hand.Time=pd.to_timedelta(left_hand.Time)
fft_left_leg = pd.read_csv('FFT-'+'Cleaning-Conv-left-leg-ags.csv'+'-16'+'bit.csv')
#left_leg.Time=pd.to_timedelta(left_leg.Time)
fft_right_hand = pd.read_csv('FFT-'+'Cleaning-Conv-right-hand-ags.csv'+'-16'+'bit.csv')
#right_hand.Time=pd.to_timedelta(right_hand.Time)
fft_right_leg = pd.read_csv('FFT-'+'Cleaning-Conv-right-leg-ags.csv'+'-16'+'bit.csv')
#right_leg.Time=pd.to_timedelta(right_leg.Time)
fft_west = pd.read_csv('FFT-'+'Cleaning-Conv-west-ags.csv'+'-16'+'bit.csv')
#west.Time=pd.to_timedelta(west.Time)

# %%
# left_hand
start_time = T.clock()
Amp_left_handAX=np.array([])
Amp_left_handAY=np.array([])
Amp_left_handAZ=np.array([])

Amp_left_handGX=np.array([])
Amp_left_handGY=np.array([])
Amp_left_handGZ=np.array([])

x = fft_right_leg.where(fft_left_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAX = np.append(Amp_left_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAY = np.append(Amp_left_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAZ = np.append(Amp_left_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGX = np.append(Amp_left_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGY = np.append(Amp_left_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGZ = np.append(Amp_left_handGZ, tmp)

for t in range(1,fft_right_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_left_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAX = np.vstack((Amp_left_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAY = np.vstack((Amp_left_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAZ = np.vstack((Amp_left_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGX = np.vstack((Amp_left_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGY = np.vstack((Amp_left_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGZ = np.vstack((Amp_left_handGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-837941ce99ab> in <module>()
#      38     try:
#      39         # 抽出したデータベースを格納
# ---> 40         x = fft_right_leg.where(fft_left_hand.Time==t).dropna()
#      41
#      42         # 各軸、それぞれパワースペクトルを計算
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/generic.pyc in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4283
#    4284         if isinstance(cond, NDFrame):
# -> 4285             cond, _ = cond.align(self, join='right', broadcast_axis=1)
#    4286         else:
#    4287             if not hasattr(cond, 'shape'):
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/series.pyc in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    2328                                          fill_value=fill_value, method=method,
#    2329                                          limit=limit, fill_axis=fill_axis,
# -> 2330                                          broadcast_axis=broadcast_axis)
#    2331
#    2332     @Appender(generic._shared_docs['rename'] % _shared_doc_kwargs)
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/generic.pyc in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    4124                 df = DataFrame(
#    4125                     dict((c, self) for c in other.columns),
# -> 4126                     **other._construct_axes_dict())
#    4127                 return df._align_frame(other, join=join, axis=axis,
#    4128                                        level=level, copy=copy,
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     221                                  dtype=dtype, copy=copy)
#     222         elif isinstance(data, dict):
# --> 223             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     224         elif isinstance(data, ma.MaskedArray):
#     225             import numpy.ma.mrecords as mrecords
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_dict(self, data, index, columns, dtype)
#     357             arrays = [data[k] for k in keys]
#     358
# --> 359         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     360
#     361     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/frame.pyc in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5243
#    5244     # don't force copy because getting jammed in an ndarray anyway
# -> 5245     arrays = _homogenize(arrays, index, dtype)
#    5246
#    5247     # from BlockManager perspective
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/frame.pyc in _homogenize(data, index, dtype)
#    5541                 # Forces alignment. No need to copy data since we
#    5542                 # are putting it into an ndarray later
# -> 5543                 v = v.reindex(index, copy=False)
#    5544         else:
#    5545             if isinstance(v, dict):
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/series.pyc in reindex(self, index, **kwargs)
#    2342     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2343     def reindex(self, index=None, **kwargs):
# -> 2344         return super(Series, self).reindex(index=index, **kwargs)
#    2345
#    2346     @Appender(generic._shared_docs['fillna'] % _shared_doc_kwargs)
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/generic.pyc in reindex(self, *args, **kwargs)
#    2224         # perform the reindex on the axes
#    2225         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2226                                   fill_value, copy).__finalize__(self)
#    2227
#    2228     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/core/generic.pyc in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2237             ax = self._get_axis(a)
#    2238             new_index, indexer = ax.reindex(labels, level=level, limit=limit,
# -> 2239                                             tolerance=tolerance, method=method)
#    2240
#    2241             axis = self._get_axis_number(a)
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/indexes/base.pyc in reindex(self, target, method, level, limit, tolerance)
#    2252                     indexer = self.get_indexer(target, method=method,
#    2253                                                limit=limit,
# -> 2254                                                tolerance=tolerance)
#    2255                 else:
#    2256                     if method is not None or limit is not None:
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_indexer(self, target, method, limit, tolerance)
#    2026                                  'backfill or nearest reindexing')
#    2027
# -> 2028             indexer = self._engine.get_indexer(target._values)
#    2029
#    2030         return com._ensure_platform_int(indexer)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_indexer (pandas/index.c:5888)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.lookup (pandas/hashtable.c:7608)()
#
# /home/takeyama/.pyenv/versions/2.7.11/envs/my_theano/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     412
#     413
# --> 414 def asarray(a, dtype=None, order=None):
#     415     """Convert the input to an array.
#     416
#
# KeyboardInterrupt:

# %%
# right_leg
start_time = T.clock()
Amp_right_legAX=np.array([])
Amp_right_legAY=np.array([])
Amp_right_legAZ=np.array([])

Amp_right_legGX=np.array([])
Amp_right_legGY=np.array([])
Amp_right_legGZ=np.array([])

x = fft_right_leg.where(fft_right_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAX = np.append(Amp_right_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAY = np.append(Amp_right_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAZ = np.append(Amp_right_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGX = np.append(Amp_right_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGY = np.append(Amp_right_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGZ = np.append(Amp_right_legGZ, tmp)

for t in range(1,fft_right_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_right_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAX = np.vstack((Amp_right_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAY = np.vstack((Amp_right_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAZ = np.vstack((Amp_right_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGX = np.vstack((Amp_right_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGY = np.vstack((Amp_right_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGZ = np.vstack((Amp_right_legGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"

# %%
# Left_leg
start_time = T.clock()
Amp_left_legAX=np.array([])
Amp_left_legAY=np.array([])
Amp_left_legAZ=np.array([])

Amp_left_legGX=np.array([])
Amp_left_legGY=np.array([])
Amp_left_legGZ=np.array([])

x = fft_left_leg.where(fft_left_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAX = np.append(Amp_left_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAY = np.append(Amp_left_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAZ = np.append(Amp_left_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGX = np.append(Amp_left_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGY = np.append(Amp_left_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGZ = np.append(Amp_left_legGZ, tmp)

for t in range(1,fft_left_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_left_leg.where(fft_left_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAX = np.vstack((Amp_left_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAY = np.vstack((Amp_left_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAZ = np.vstack((Amp_left_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGX = np.vstack((Amp_left_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGY = np.vstack((Amp_left_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGZ = np.vstack((Amp_left_legGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"

# %%
# right_hand
start_time = T.clock()
Amp_right_handAX=np.array([])
Amp_right_handAY=np.array([])
Amp_right_handAZ=np.array([])

Amp_right_handGX=np.array([])
Amp_right_handGY=np.array([])
Amp_right_handGZ=np.array([])

x = fft_right_hand.where(fft_right_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAX = np.append(Amp_right_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAY = np.append(Amp_right_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAZ = np.append(Amp_right_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGX = np.append(Amp_right_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGY = np.append(Amp_right_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGZ = np.append(Amp_right_handGZ, tmp)

for t in range(1,fft_right_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_hand.where(fft_right_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAX = np.vstack((Amp_right_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAY = np.vstack((Amp_right_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAZ = np.vstack((Amp_right_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGX = np.vstack((Amp_right_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGY = np.vstack((Amp_right_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGZ = np.vstack((Amp_right_handGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"

# %%
fft_right_hand

# %%
# west
start_time = T.clock()
Amp_westAX=np.array([])
Amp_westAY=np.array([])
Amp_westAZ=np.array([])

Amp_westGX=np.array([])
Amp_westGY=np.array([])
Amp_westGZ=np.array([])

x = fft_west.where(fft_west.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_westAX = np.append(Amp_westAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_westAY = np.append(Amp_westAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westAZ = np.append(Amp_westAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_westGX = np.append(Amp_westGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_westGY = np.append(Amp_westGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westGZ = np.append(Amp_westGZ, tmp)

for t in range(1,fft_west.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_west.where(fft_west.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAX = np.vstack((Amp_westAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAY = np.vstack((Amp_westAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAZ = np.vstack((Amp_westAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGX = np.vstack((Amp_westGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGY = np.vstack((Amp_westGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGZ = np.vstack((Amp_westGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
