# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import fftpack
from scipy import signal
import numpy as np
import pandas as pd
import datetime
import time as T

# %%
#my workstation

# %%
cd /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data/
# Out:
# /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data

# %%
ls
# Out:
# FFT-Cleaning-Conv-left-hand-ags.csv-128bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-16bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-256bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-32bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-512bit.csv
# FFT-Cleaning-Conv-left-hand-ags.csv-64bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-128bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-16bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-256bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-32bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-512bit.csv
# FFT-Cleaning-Conv-left-leg-ags.csv-64bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-128bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-16bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-256bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-32bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-512bit.csv
# FFT-Cleaning-Conv-right-hand-ags.csv-64bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-128bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-16bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-256bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-32bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-512bit.csv
# FFT-Cleaning-Conv-right-leg-ags.csv-64bit.csv
# FFT-Cleaning-Conv-west-ags.csv-128bit.csv
# FFT-Cleaning-Conv-west-ags.csv-16bit.csv
# FFT-Cleaning-Conv-west-ags.csv-256bit.csv
# FFT-Cleaning-Conv-west-ags.csv-32bit.csv
# FFT-Cleaning-Conv-west-ags.csv-512bit.csv
# FFT-Cleaning-Conv-west-ags.csv-64bit.csv

# %%
fft_left_hand = pd.read_csv('FFT-Cleaning-Conv-left-hand-ags.csv'+'-16'+'bit.csv')
#left_hand.Time=pd.to_timedelta(left_hand.Time)
fft_left_leg = pd.read_csv('FFT-'+'Cleaning-Conv-left-leg-ags.csv'+'-16'+'bit.csv')
#left_leg.Time=pd.to_timedelta(left_leg.Time)
fft_right_hand = pd.read_csv('FFT-'+'Cleaning-Conv-right-hand-ags.csv'+'-16'+'bit.csv')
#right_hand.Time=pd.to_timedelta(right_hand.Time)
fft_right_leg = pd.read_csv('FFT-'+'Cleaning-Conv-right-leg-ags.csv'+'-16'+'bit.csv')
#right_leg.Time=pd.to_timedelta(right_leg.Time)
fft_west = pd.read_csv('FFT-'+'Cleaning-Conv-west-ags.csv'+'-16'+'bit.csv')
#west.Time=pd.to_timedelta(west.Time)

# %%
# left_hand
start_time = T.clock()
Amp_left_handAX=np.array([])
Amp_left_handAY=np.array([])
Amp_left_handAZ=np.array([])

Amp_left_handGX=np.array([])
Amp_left_handGY=np.array([])
Amp_left_handGZ=np.array([])

x = fft_right_leg.where(fft_left_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAX = np.append(Amp_left_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAY = np.append(Amp_left_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAZ = np.append(Amp_left_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGX = np.append(Amp_left_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGY = np.append(Amp_left_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGZ = np.append(Amp_left_handGZ, tmp)

for t in range(1,fft_left_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_left_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAX = np.vstack((Amp_left_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAY = np.vstack((Amp_left_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAZ = np.vstack((Amp_left_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGX = np.vstack((Amp_left_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGY = np.vstack((Amp_left_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGZ = np.vstack((Amp_left_handGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:725.790369[sec]

# %%
# right_leg
start_time = T.clock()
Amp_right_legAX=np.array([])
Amp_right_legAY=np.array([])
Amp_right_legAZ=np.array([])

Amp_right_legGX=np.array([])
Amp_right_legGY=np.array([])
Amp_right_legGZ=np.array([])

x = fft_right_leg.where(fft_right_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAX = np.append(Amp_right_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAY = np.append(Amp_right_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAZ = np.append(Amp_right_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGX = np.append(Amp_right_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGY = np.append(Amp_right_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGZ = np.append(Amp_right_legGZ, tmp)

for t in range(1,fft_right_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_right_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAX = np.vstack((Amp_right_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAY = np.vstack((Amp_right_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAZ = np.vstack((Amp_right_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGX = np.vstack((Amp_right_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGY = np.vstack((Amp_right_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGZ = np.vstack((Amp_right_legGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:249.624027[sec]

# %%
# Left_leg
start_time = T.clock()
Amp_left_legAX=np.array([])
Amp_left_legAY=np.array([])
Amp_left_legAZ=np.array([])

Amp_left_legGX=np.array([])
Amp_left_legGY=np.array([])
Amp_left_legGZ=np.array([])

x = fft_left_leg.where(fft_left_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAX = np.append(Amp_left_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAY = np.append(Amp_left_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAZ = np.append(Amp_left_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGX = np.append(Amp_left_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGY = np.append(Amp_left_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGZ = np.append(Amp_left_legGZ, tmp)

for t in range(1,fft_left_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_left_leg.where(fft_left_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAX = np.vstack((Amp_left_legAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAY = np.vstack((Amp_left_legAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAZ = np.vstack((Amp_left_legAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGX = np.vstack((Amp_left_legGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGY = np.vstack((Amp_left_legGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGZ = np.vstack((Amp_left_legGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:251.934397[sec]

# %%
# right_hand
start_time = T.clock()
Amp_right_handAX=np.array([])
Amp_right_handAY=np.array([])
Amp_right_handAZ=np.array([])

Amp_right_handGX=np.array([])
Amp_right_handGY=np.array([])
Amp_right_handGZ=np.array([])

x = fft_right_hand.where(fft_right_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAX = np.append(Amp_right_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAY = np.append(Amp_right_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAZ = np.append(Amp_right_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGX = np.append(Amp_right_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGY = np.append(Amp_right_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGZ = np.append(Amp_right_handGZ, tmp)

for t in range(1,fft_right_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_hand.where(fft_right_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAX = np.vstack((Amp_right_handAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAY = np.vstack((Amp_right_handAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAZ = np.vstack((Amp_right_handAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGX = np.vstack((Amp_right_handGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGY = np.vstack((Amp_right_handGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGZ = np.vstack((Amp_right_handGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:255.194648[sec]

# %%
fft_right_hand
# Out:
#        Time Number  AccX_imag  AccX_real  AccY_imag  AccY_real  AccZ_imag  \
# 0         0    1st   0.718910  -0.522388   0.057357  -0.232877   0.029444
# 1         0    2nd   0.316515  -0.370763  -0.022730   0.027965   0.093279
# 2         0    3rd   0.286144  -0.207454  -0.028356   0.000350   0.055183
# 3         0    4th   0.168795  -0.179955   0.005075  -0.002117   0.040510
# 4         0    5th   0.128302  -0.193312  -0.007220  -0.032656   0.047491
# 5         0    6th   0.067149  -0.180783  -0.007360   0.011997   0.024631
# 6         0    7th   0.039030  -0.173639   0.003594   0.009575   0.007265
# 7         0    8th   0.012150  -0.148406  -0.000415  -0.009037   0.000563
# 8         1    1st  -0.281783  -0.281706  -0.065160   0.199172   0.284018
# 9         1    2nd  -0.133012  -0.081016  -0.041428   0.006182   0.112504
# 10        1    3rd  -0.049490   0.003166   0.015999   0.002535   0.057184
# 11        1    4th  -0.016373   0.012732  -0.008242   0.020477   0.025773
# 12        1    5th  -0.035458   0.004956  -0.004295   0.019116   0.004851
# 13        1    6th  -0.017564   0.004873  -0.029104  -0.003972   0.004690
# 14        1    7th   0.000205   0.036329   0.010386  -0.006360   0.006346
# 15        1    8th  -0.004797   0.000815  -0.006545   0.008549   0.015681
# 16        2    1st  -0.574274   0.223537   0.290295  -0.046863   0.092805
# 17        2    2nd  -0.216783   0.039033   0.108894  -0.036123   0.146436
# 18        2    3rd  -0.154464   0.057588   0.059875  -0.058429   0.072614
# 19        2    4th  -0.088541   0.104240   0.027862  -0.041780   0.039278
# 20        2    5th  -0.079759   0.090511   0.031183  -0.056898   0.047881
# 21        2    6th  -0.049717   0.089930   0.000418  -0.053194   0.021854
# 22        2    7th  -0.016238   0.081832   0.007277  -0.042859   0.038416
# 23        2    8th   0.003500   0.097979  -0.007217  -0.042703   0.016285
# 24        3    1st  -0.217492   0.105200   0.013406  -0.118328   0.278133
# 25        3    2nd  -0.061552   0.061759   0.040194  -0.019942   0.094828
# 26        3    3rd  -0.055932   0.085094   0.005123  -0.017970   0.048982
# 27        3    4th  -0.049114   0.052517  -0.003613  -0.015456   0.020652
# 28        3    5th  -0.036167   0.053380  -0.001132  -0.015909   0.022973
# 29        3    6th  -0.034484   0.055529  -0.002585  -0.030653   0.016815
# ...     ...    ...        ...        ...        ...        ...        ...
# 55419  6927    4th  -0.020521  -0.143693  -0.025781   0.338109   0.143696
# 55420  6927    5th   0.135825  -0.051218  -0.031535   0.221961   0.143184
# 55421  6927    6th   0.070609  -0.205508  -0.094135   0.369217  -0.010920
# 55422  6927    7th   0.037746   0.098946   0.040092   0.288728   0.096570
# 55423  6927    8th   0.068633  -0.032019  -0.050011   0.314692  -0.029507
# 55424  6928    1st   0.131105  -0.161425   0.654661   0.237971   0.142539
# 55425  6928    2nd   0.302927  -0.082047  -0.425186   0.202018  -0.014123
# 55426  6928    3rd  -0.018608  -0.038177   0.053902   0.244119   0.136086
# 55427  6928    4th   0.055039  -0.297543  -0.233238  -0.103433  -0.209234
# 55428  6928    5th  -0.027412  -0.185520  -0.094687   0.306731   0.014627
# 55429  6928    6th   0.077707  -0.142633  -0.034428  -0.151481  -0.008361
# 55430  6928    7th   0.114510   0.014730  -0.211469   0.034731  -0.126126
# 55431  6928    8th   0.101547  -0.028284   0.007715   0.074043   0.128688
# 55432  6929    1st  -0.079230  -0.086085  -0.060286  -0.099399  -0.378874
# 55433  6929    2nd   0.203391   0.198144  -0.274714  -0.521506   0.021611
# 55434  6929    3rd   0.112847  -0.111726  -0.245188  -0.175463  -0.187200
# 55435  6929    4th   0.079365  -0.048365   0.053990  -0.260359  -0.077601
# 55436  6929    5th   0.068616   0.042302   0.107321  -0.120049   0.041516
# 55437  6929    6th  -0.072416   0.005226   0.253509   0.000092   0.182400
# 55438  6929    7th   0.130635   0.001180   0.054336   0.080514   0.132355
# 55439  6929    8th   0.032801   0.026873  -0.119222   0.067271  -0.001169
# 55440  6930    1st   0.098278   0.160972  -0.176317  -0.277167   0.354954
# 55441  6930    2nd  -0.106807  -0.047647   0.058089   0.097757  -0.090677
# 55442  6930    3rd  -0.069808   0.005678   0.071774   0.042367  -0.018150
# 55443  6930    4th  -0.033678  -0.040603  -0.022323   0.039843  -0.049995
# 55444  6930    5th   0.000000   0.044700   0.000000  -0.092900   0.000000
# 55445  6930    6th   0.033678  -0.040603   0.022323   0.039843   0.049995
# 55446  6930    7th   0.069808   0.005678  -0.071774   0.042367   0.018150
# 55447  6930    8th   0.106807  -0.047647  -0.058089   0.097757   0.090677
# 55448  6931    1st   0.000000   0.040600   0.000000  -0.040300   0.000000
#
#        AccZ_real  GyrX_imag  GyrX_real  GyrY_imag  GyrY_real  GyrZ_imag  \
# 0       0.022678   4.483277  -0.271400  -2.716996   1.058169   0.320037
# 1      -0.129522   2.638084  -0.859266  -1.161760   0.634214   0.170458
# 2      -0.043417   1.598330  -0.877930  -0.779978   0.559885   0.128193
# 3      -0.033880   1.080509  -0.940327  -0.522633   0.516237   0.069150
# 4      -0.049718   0.744085  -0.961026  -0.348056   0.518132   0.051166
# 5      -0.008475   0.484187  -0.967081  -0.235049   0.503741   0.029901
# 6      -0.031149   0.272154  -0.972437  -0.140386   0.503659   0.005325
# 7      -0.031617   0.094544  -0.967354  -0.048406   0.495669  -0.002007
# 8      -0.074634   7.049963  -1.188292  -0.802313   0.747409   2.855189
# 9      -0.091637   2.939803  -1.093284  -0.387615   0.365394   1.279538
# 10     -0.023295   1.800328  -1.134372  -0.275219   0.235489   0.774126
# 11     -0.030689   1.225578  -1.100132  -0.190423   0.227763   0.527423
# 12     -0.022729   0.826383  -1.112308  -0.120089   0.193476   0.358594
# 13     -0.024629   0.551846  -1.107214  -0.079710   0.192781   0.238586
# 14     -0.022302   0.312497  -1.097413  -0.052243   0.189394   0.137835
# 15     -0.041335   0.103990  -1.103420  -0.023911   0.198467   0.035096
# 16      0.005833   2.387165  -2.899157   0.363024   0.193736   2.312732
# 17     -0.076181   1.181251  -0.866245   0.165074   0.100842   0.894104
# 18     -0.039698   0.743909  -0.668574   0.112363  -0.010378   0.593147
# 19     -0.047674   0.508613  -0.575269   0.052783  -0.029013   0.409902
# 20     -0.022850   0.351087  -0.547382   0.041664  -0.047011   0.275224
# 21     -0.037715   0.232153  -0.535403   0.029006  -0.048168   0.178527
# 22     -0.050183   0.135856  -0.525498   0.014746  -0.040870   0.100571
# 23     -0.042732   0.043057  -0.517815  -0.003515  -0.055782   0.037399
# 24     -0.122953  -1.982415  -0.074338   1.408564   0.178407   0.609046
# 25     -0.035327  -0.766117   0.068218   0.616402  -0.168816   0.444541
# 26     -0.030588  -0.437343   0.175083   0.365761  -0.214704   0.305760
# 27     -0.038426  -0.294041   0.201613   0.262847  -0.228983   0.205601
# 28     -0.043023  -0.206393   0.213156   0.179549  -0.227115   0.141502
# 29     -0.013155  -0.129836   0.228252   0.124707  -0.234649   0.092704
# ...          ...        ...        ...        ...        ...        ...
# 55419  -0.076509   0.388240  -0.278180   0.218202  -0.152878   0.311287
# 55420  -0.131652   0.044998  -0.170451   0.133728  -0.110658   0.350863
# 55421  -0.125818   0.172386  -0.258906   0.108047  -0.109762   0.135286
# 55422  -0.103956   0.075699  -0.171819   0.056199  -0.118344   0.079710
# 55423  -0.116923  -0.005141  -0.208141  -0.013645  -0.153824   0.072476
# 55424  -0.626891   0.979427  -0.953783   2.226136  -1.044554   0.644720
# 55425   0.116643  -0.272046   0.516436   0.749892  -0.058873   0.538640
# 55426   0.128431   0.312370   0.134029   0.349849  -0.296687   0.485061
# 55427  -0.112114   0.119424   0.536272   0.280667  -0.225790   0.283501
# 55428   0.143504   0.063230   0.021938   0.179345  -0.245412   0.108552
# 55429  -0.238855  -0.186706   0.344092   0.074487  -0.195169   0.188473
# 55430   0.060083   0.123531   0.221096   0.054884  -0.226222   0.089301
# 55431  -0.060651  -0.012026   0.105905   0.008832  -0.214285   0.052355
# 55432   0.646406  -0.317695  -0.388266  -0.985077  -0.533860   0.332145
# 55433   0.049116  -1.904027  -0.252514  -0.323419   0.071946  -0.451272
# 55434  -0.231429  -0.392205   0.580953  -0.100265   0.144880  -0.080876
# 55435  -0.159069  -0.269733   0.215884  -0.061129   0.008951   0.146643
# 55436  -0.136929  -0.374312   0.296070  -0.077954   0.089622  -0.031153
# 55437  -0.006144  -0.272363   0.033902  -0.038421   0.005326   0.030713
# 55438   0.077561  -0.058649   0.031953  -0.029803   0.045982   0.025570
# 55439   0.172437   0.058211   0.139746  -0.007672   0.030668  -0.060309
# 55440  -0.053765  -1.522290  -0.286710  -0.482503   0.341822  -0.272660
# 55441   0.002046   0.099658  -0.002074  -0.067597   0.079668  -0.063417
# 55442   0.023715   0.020729   0.075263  -0.025012   0.093027  -0.025095
# 55443   0.034804   0.008373   0.071101  -0.008286   0.102108  -0.061445
# 55444  -0.013400   0.000000   0.092153   0.000000   0.096342   0.000000
# 55445   0.034804  -0.008373   0.071101   0.008286   0.102108   0.061445
# 55446   0.023715  -0.020729   0.075263   0.025012   0.093027   0.025095
# 55447   0.002046  -0.099658  -0.002074   0.067597   0.079668   0.063417
# 55448   0.061000   0.000000  -0.070860   0.000000  -0.039095   0.000000
#
#        GyrZ_real
# 0       1.275555
# 1       0.152563
# 2       0.015337
# 3      -0.023074
# 4      -0.041839
# 5      -0.049864
# 6      -0.058964
# 7      -0.054005
# 8      -0.245086
# 9      -0.300156
# 10     -0.428957
# 11     -0.447202
# 12     -0.453473
# 13     -0.456067
# 14     -0.450335
# 15     -0.466084
# 16     -1.049052
# 17     -0.477684
# 18     -0.413990
# 19     -0.413187
# 20     -0.394881
# 21     -0.393779
# 22     -0.386925
# 23     -0.385101
# 24     -0.250976
# 25     -0.309056
# 26     -0.244025
# 27     -0.216100
# 28     -0.197901
# 29     -0.201224
# ...          ...
# 55419  -0.335306
# 55420  -0.221688
# 55421  -0.342874
# 55422  -0.185373
# 55423  -0.286482
# 55424  -1.066389
# 55425   0.187460
# 55426  -0.104381
# 55427  -0.471791
# 55428  -0.335446
# 55429  -0.336322
# 55430  -0.243080
# 55431  -0.171163
# 55432  -0.109096
# 55433   0.389978
# 55434  -0.184796
# 55435  -0.091325
# 55436   0.066511
# 55437   0.064760
# 55438   0.035047
# 55439   0.035916
# 55440   0.101335
# 55441  -0.060552
# 55442   0.068748
# 55443   0.037601
# 55444   0.009774
# 55445   0.037601
# 55446   0.068748
# 55447  -0.060552
# 55448   0.018326
#
# [55449 rows x 14 columns]

# %%
# west
start_time = T.clock()
Amp_westAX=np.array([])
Amp_westAY=np.array([])
Amp_westAZ=np.array([])

Amp_westGX=np.array([])
Amp_westGY=np.array([])
Amp_westGZ=np.array([])

x = fft_west.where(fft_west.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_westAX = np.append(Amp_westAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_westAY = np.append(Amp_westAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westAZ = np.append(Amp_westAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_westGX = np.append(Amp_westGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_westGY = np.append(Amp_westGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westGZ = np.append(Amp_westGZ, tmp)

for t in range(1,fft_west.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_west.where(fft_west.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAX = np.vstack((Amp_westAX, tmp))

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAY = np.vstack((Amp_westAY, tmp))

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAZ = np.vstack((Amp_westAZ, tmp))
        
        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGX = np.vstack((Amp_westGX, tmp))

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGY = np.vstack((Amp_westGY, tmp))

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGZ = np.vstack((Amp_westGZ, tmp))
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:6.091283[sec]

# %%
Amp_westAX.shape
# Out:
# (698, 8)

# %%
# Out:
#       Time Number  AccX_imag  AccX_real  AccY_imag  AccY_real  AccZ_imag  \
# 0        0    1st  -0.127419   0.368026   0.341583   0.121483  -0.040058
# 1        0    2nd  -0.097653   0.073996   0.046518  -0.056565  -0.055211
# 2        0    3rd  -0.039497   0.049223   0.054610  -0.063027  -0.030535
# 3        0    4th  -0.024977   0.024659   0.007759  -0.031782   0.002975
# 4        0    5th  -0.011190   0.028684   0.018088  -0.060578   0.011314
# 5        0    6th  -0.010314   0.014673   0.022531  -0.000136  -0.014940
# 6        0    7th  -0.001883   0.034038   0.013210  -0.029363  -0.014341
# 7        0    8th   0.015806   0.025450   0.007210  -0.015131   0.009530
# 8        1    1st   0.517049  -0.063985   0.048954  -0.202305   0.099993
# 9        1    2nd   0.160067  -0.107563   0.069513  -0.071790   0.094330
# 10       1    3rd   0.071938  -0.083430   0.034590  -0.009064   0.017429
# 11       1    4th   0.060370  -0.038163   0.019441  -0.045865   0.041355
# 12       1    5th   0.057478  -0.064505   0.017096  -0.011824   0.003582
# 13       1    6th   0.030513  -0.066102  -0.006798  -0.021399   0.007819
# 14       1    7th   0.029895  -0.053252   0.012882  -0.036579   0.008245
# 15       1    8th   0.017166  -0.049950  -0.004831  -0.037424   0.008965
# 16       2    1st  -0.241575  -0.226997  -0.126587   0.071017   0.018101
# 17       2    2nd   0.037072  -0.041105  -0.019155  -0.003123   0.115112
# 18       2    3rd  -0.010783  -0.002701  -0.027176  -0.000759   0.036377
# 19       2    4th  -0.030641   0.021421  -0.001555  -0.001075   0.031673
# 20       2    5th  -0.014175  -0.005736  -0.019681   0.008162  -0.022721
# 21       2    6th   0.004206  -0.000308  -0.008711   0.024050   0.000477
# 22       2    7th   0.005034  -0.001943  -0.001501   0.005100   0.000905
# 23       2    8th   0.011600  -0.000880   0.012955  -0.002022  -0.007592
# 24       3    1st  -0.236493   0.113962  -0.180619  -0.115602  -0.015605
# 25       3    2nd  -0.115062   0.095109  -0.091803   0.053533   0.010373
# 26       3    3rd  -0.087768   0.063080  -0.062577   0.035131  -0.008653
# 27       3    4th  -0.066867   0.088813  -0.032216   0.047254  -0.002361
# 28       3    5th  -0.009708   0.025492  -0.025057   0.039755  -0.004657
# 29       3    6th  -0.037474   0.049994  -0.030964   0.050088  -0.027659
# ...    ...    ...        ...        ...        ...        ...        ...
# 5560   695    1st  -0.499488  -0.092220  -0.739870  -0.377362  -0.094414
# 5561   695    2nd  -0.171599   0.087313  -0.371756   0.242457   0.105331
# 5562   695    3rd  -0.094658   0.031465  -0.127020   0.103940   0.049974
# 5563   695    4th  -0.054939   0.051879  -0.121650   0.107010   0.022663
# 5564   695    5th  -0.030753   0.049247  -0.082598   0.094589   0.035428
# 5565   695    6th  -0.014699   0.084719  -0.061439   0.106712   0.024764
# 5566   695    7th   0.007376   0.035679  -0.056008   0.109380  -0.053431
# 5567   695    8th  -0.005272   0.047969  -0.043039   0.084424  -0.033689
# 5568   696    1st  -0.244047   0.093150  -1.558627   0.187992   0.579325
# 5569   696    2nd  -0.334052   0.059639  -0.890115   0.622076   0.071822
# 5570   696    3rd  -0.179556   0.116634  -0.259467   0.263716   0.139016
# 5571   696    4th  -0.116680   0.094521  -0.226121   0.210402  -0.041051
# 5572   696    5th  -0.085521   0.104026  -0.134261   0.232989  -0.041178
# 5573   696    6th  -0.067489   0.113614  -0.095159   0.189799   0.055581
# 5574   696    7th  -0.062067   0.086345  -0.044045   0.226094  -0.010007
# 5575   696    8th   0.003874   0.098269  -0.001962   0.168581   0.033146
# 5576   697    1st  -0.584337   0.092665   0.574324   1.303287  -0.977660
# 5577   697    2nd  -0.133308   0.030700   0.091229   0.092775  -0.475712
# 5578   697    3rd  -0.083050   0.072054   0.225445  -0.152990  -0.272580
# 5579   697    4th  -0.032992   0.083716   0.110214  -0.115431  -0.084688
# 5580   697    5th  -0.017667   0.061000   0.120897  -0.126200  -0.073439
# 5581   697    6th  -0.008744   0.059196   0.051404  -0.145610  -0.042551
# 5582   697    7th  -0.015156   0.067419   0.045904  -0.104681   0.020429
# 5583   697    8th   0.015156   0.067419  -0.045904  -0.104681  -0.020429
# 5584   698    1st  -0.043096   0.059694   0.578829  -0.124660  -0.445379
# 5585   698    2nd   0.001009   0.040360   0.206456  -0.221652  -0.168674
# 5586   698    3rd  -0.007295   0.016996   0.054793  -0.249789  -0.051037
# 5587   698    4th   0.007295   0.016996  -0.054793  -0.249789   0.051037
# 5588   698    5th  -0.001009   0.040360  -0.206456  -0.221652   0.168674
# 5589   698    6th   0.043096   0.059694  -0.578829  -0.124660   0.445379
#
#       AccZ_real  GyrX_imag  GyrX_real  GyrY_imag  GyrY_real  GyrZ_imag  \
# 0      0.101249  -0.042106   0.349893   0.312723   0.347523   0.938974
# 1     -0.042994   0.032341  -0.043636   0.231411  -0.029157   0.184052
# 2     -0.010483  -0.088831   0.041185   0.153833  -0.022464   0.123735
# 3     -0.008697  -0.000148   0.030985  -0.024105  -0.061550   0.095920
# 4     -0.010764  -0.019007   0.023210  -0.010727  -0.068864   0.052951
# 5     -0.004119   0.005628   0.051222   0.003502  -0.101289   0.044886
# 6      0.007404  -0.040845  -0.015384  -0.001656  -0.038326   0.028112
# 7      0.001955   0.020640   0.034286  -0.017936  -0.122914   0.010366
# 8      0.030494   0.582651  -0.205262   0.628759  -0.324116  -0.332217
# 9     -0.081884   0.168062  -0.187495   0.364134  -0.112972  -0.067844
# 10    -0.015565   0.146249   0.008681   0.041916  -0.160881   0.026203
# 11    -0.001546   0.051320  -0.009504   0.084319  -0.113987  -0.017483
# 12    -0.030696   0.103351  -0.022143   0.082901  -0.121231  -0.006951
# 13    -0.039348   0.018517  -0.053496   0.012799  -0.098887   0.017267
# 14    -0.004447   0.018817  -0.009492   0.058639  -0.081275  -0.014475
# 15    -0.009909   0.011853  -0.071418   0.021876  -0.082107  -0.016289
# 16    -0.064396   0.204159  -0.025006   0.121802  -0.066672   0.024033
# 17    -0.037525   0.129679  -0.190052   0.172950  -0.142630   0.013053
# 18    -0.011889   0.182391  -0.085166  -0.005743   0.075736  -0.033714
# 19    -0.005624   0.027655  -0.122205   0.038128   0.000885  -0.021401
# 20    -0.019255   0.018457  -0.093848   0.016076  -0.040482   0.010030
# 21    -0.012986   0.055834  -0.092632  -0.016380  -0.086083   0.002380
# 22    -0.002118   0.050187  -0.079000  -0.021533  -0.046671  -0.032122
# 23     0.014292   0.044174  -0.074191  -0.006421   0.007292  -0.019835
# 24    -0.055166   0.565278  -0.163988  -0.038419  -0.076811   0.198292
# 25     0.033454   0.104110  -0.102362   0.057134  -0.158631   0.167553
# 26     0.011290   0.131181  -0.055658  -0.021209   0.028653   0.086871
# 27     0.013076   0.154786  -0.125874   0.014071   0.058951   0.008443
# 28     0.027343   0.094331  -0.170744  -0.041598   0.077009   0.075532
# 29     0.018502  -0.025873  -0.028710   0.097235  -0.020509   0.045264
# ...         ...        ...        ...        ...        ...        ...
# 5560   0.015036   0.172221  -0.307199  -0.448576   0.851374   0.352131
# 5561  -0.040840  -0.163283   0.082781  -0.227053  -0.065610   0.094835
# 5562  -0.030814   0.039493   0.058219  -0.240608   0.127448   0.108230
# 5563  -0.005971   0.037497   0.005416  -0.130137   0.090029   0.066550
# 5564  -0.045134   0.000001  -0.003195  -0.081416   0.109629   0.039117
# 5565  -0.034189  -0.022336   0.017882  -0.070091   0.125380   0.031534
# 5566  -0.085142   0.008472   0.027639  -0.022944   0.115342   0.009949
# 5567  -0.062695   0.017950   0.023423  -0.008095   0.118332   0.006959
# 5568  -0.070969   0.194354   0.326984   0.067513  -0.363586   0.392516
# 5569  -0.037994  -0.207121   0.034554   0.135377  -0.256272   0.186878
# 5570  -0.043043   0.250241   0.127949  -0.014154   0.035463   0.165212
# 5571  -0.110245   0.301319  -0.119016  -0.018755  -0.049450   0.110103
# 5572   0.019827   0.059197  -0.162599  -0.094523   0.015665   0.116144
# 5573  -0.005388  -0.007031  -0.111601  -0.060030   0.044414   0.059215
# 5574   0.029652   0.052245  -0.090642  -0.032455   0.048564   0.033044
# 5575  -0.084440   0.002873  -0.084344  -0.005622   0.060334   0.008800
# 5576  -0.598758   0.823775  -0.179630  -1.904500  -0.585542   1.097365
# 5577   0.147317  -0.143979  -0.328342  -0.639767   0.369293   0.415905
# 5578   0.043557   0.315152  -0.207034  -0.406408   0.223438   0.254979
# 5579   0.080962   0.121340   0.042057  -0.213181   0.345767   0.112519
# 5580   0.197500   0.049879  -0.152716  -0.206169   0.305607   0.109584
# 5581   0.138143   0.041998  -0.152591  -0.078441   0.312029   0.062158
# 5582   0.210979  -0.001570  -0.120079  -0.038725   0.297913   0.007872
# 5583   0.210979   0.001570  -0.120079   0.038725   0.297913  -0.007872
# 5584   0.222672  -0.089319  -0.085779  -0.547774   0.375121   0.340936
# 5585   0.188352   0.034731  -0.003219  -0.202307   0.281956   0.095708
# 5586   0.189376  -0.010719  -0.037015  -0.050036   0.274754   0.025899
# 5587   0.189376   0.010719  -0.037015   0.050036   0.274754  -0.025899
# 5588   0.188352  -0.034731  -0.003219   0.202307   0.281956  -0.095708
# 5589   0.222672   0.089319  -0.085779   0.547774   0.375121  -0.340936
#
#       GyrZ_real
# 0     -0.356313
# 1     -0.109282
# 2     -0.049530
# 3     -0.088422
# 4     -0.092968
# 5     -0.092921
# 6     -0.114180
# 7     -0.096022
# 8     -0.164469
# 9     -0.118997
# 10    -0.054409
# 11    -0.014695
# 12     0.015425
# 13     0.009894
# 14    -0.024793
# 15     0.004287
# 16     0.247532
# 17    -0.008443
# 18     0.005126
# 19    -0.013715
# 20     0.006850
# 21     0.026859
# 22     0.017398
# 23     0.006807
# 24    -0.102105
# 25    -0.028233
# 26    -0.036892
# 27    -0.032922
# 28     0.008578
# 29    -0.057406
# ...         ...
# 5560   0.135731
# 5561   0.028860
# 5562  -0.023133
# 5563  -0.033402
# 5564  -0.046540
# 5565  -0.046548
# 5566  -0.046971
# 5567  -0.051511
# 5568  -0.133720
# 5569   0.023109
# 5570  -0.109741
# 5571  -0.050752
# 5572  -0.092526
# 5573  -0.112038
# 5574  -0.103081
# 5575  -0.101667
# 5576   0.300358
# 5577  -0.211091
# 5578  -0.173414
# 5579  -0.217417
# 5580  -0.188059
# 5581  -0.188829
# 5582  -0.180338
# 5583  -0.180338
# 5584  -0.206401
# 5585  -0.163232
# 5586  -0.158939
# 5587  -0.158939
# 5588  -0.163232
# 5589  -0.206401
#
# [5590 rows x 14 columns]
