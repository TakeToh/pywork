# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,16,16,16,16,16] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccZ' # Axis

#WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData"
WORKSPACE_PATH = "/home/takeyama/Documents/01_SyncChopin"
DATE_PATH="/2016-08-15/"
TITLE_PATH="Optim/"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping

import matplotlib.image as mpimg

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
# define rawdata directory
if not os.path.exists(WORKSPACE_PATH+"/raw/"):
    os.makedirs(WORKSPACE_PATH+"/raw/")
RawDataPath=WORKSPACE_PATH+"/raw/"

# define restoring windowdata directory
if not os.path.exists(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'

# define restoring netowrk model picture's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'

# define restoring graph data's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/Edim=16-Ol=16/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/Edim=16-Ol=16/')
GraphDataPath=WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/Edim=16-Ol=16/'

# define restoring model paarmeter directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/')
StudyDataPath=WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成 & Learning**

# %%
optimizers = [SGD, Adadelta, Adamax, Adam, Adagrad,  RMSprop, Nadam]
optimArray = ["SGD", "Adadelta","Adamax", "Adam", "Adagrad","RMSprop","Nadam"]

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

# loop windowWidth
for SampleNum,Overlap in zip(WindowWidth,OverlapArray): 
    for opt,optName in zip(optimizers,optimArray):
        print "hiden node = "+str(encoding_dim)
        CommonName='-edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+optName
        print CommonName
        SaveFileNameEncord=DataName+'_encoded'+CommonName
        SaveFileNameDecord=DataName+'_decoded'+CommonName
        SaveFileNameNet=DataName+'_net'+CommonName
        SaveFileNameTrain=DataName+'_train'+CommonName
        SaveFileNameTest=DataName+'_test'+CommonName
        SaveFileNameGraph=GraphDataPath+DataName+CommonName

        window_train=processing.LoadDicDataFromFileNPZ(WindowDataPath+SaveFileNameTrain)
        #window_test=processing.LoadDicDataFromFileNPZ(WindowDataPath+SaveFileNameTest)
        #encoded_imgs = processing.LoadDicDataFromFileNPZ(StudyDataPath+SaveFileNameEncord)
        decoded_imgs = processing.LoadDicDataFromFileNPZ(StudyDataPath+SaveFileNameDecord)
        
        length_Raw = window_train.shape[0]*window_train.shape[1]
        length_Rec = decoded_imgs.shape[0]*decoded_imgs.shape[1]
        
        window_train = window_train.reshape(length_Raw,1)
        decoded_imgs = decoded_imgs.reshape(length_Rec,1)
        
        width = length_Raw/20
        for i in range(width,length_Raw,width):
            start =i-width 
            goal=i

            dataE = window_train[start:goal]
            dataD = decoded_imgs[start:goal]
            
            ax.plot(range(0,len(dataE)),dataE,'r',label="raw data")
            ax.plot(range(0,len(dataD)),dataD,'b',label="reconstruct")
            ax.legend(loc='best',fontsize=10)
            ax.set_title(str(start)+"-"+str(goal))
            ax.figure.savefig(SaveFileNameGraph+'-'+str(start)+"-"+str(goal)+'-graph')
            ax.clear()
            print 'Graph range='+str(start)+' : '+str(goal)
# Out:
# hiden node = 16
# -edim=16-Window=128-Overlap=16-SGD
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=128-Overlap=16-Adadelta
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=128-Overlap=16-Adamax
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=128-Overlap=16-Adam
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=128-Overlap=16-Adagrad
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=128-Overlap=16-RMSprop
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=128-Overlap=16-Nadam
# Graph range=0 : 101849
# Graph range=101849 : 203698
# Graph range=203698 : 305547
# Graph range=305547 : 407396
# Graph range=407396 : 509245
# Graph range=509245 : 611094
# Graph range=611094 : 712943
# Graph range=712943 : 814792
# Graph range=814792 : 916641
# Graph range=916641 : 1018490
# Graph range=1018490 : 1120339
# Graph range=1120339 : 1222188
# Graph range=1222188 : 1324037
# Graph range=1324037 : 1425886
# Graph range=1425886 : 1527735
# Graph range=1527735 : 1629584
# Graph range=1629584 : 1731433
# Graph range=1731433 : 1833282
# Graph range=1833282 : 1935131
# Graph range=1935131 : 2036980
# hiden node = 16
# -edim=16-Window=256-Overlap=16-SGD
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=256-Overlap=16-Adadelta
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=256-Overlap=16-Adamax
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=256-Overlap=16-Adam
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=256-Overlap=16-Adagrad
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=256-Overlap=16-RMSprop
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=256-Overlap=16-Nadam
# Graph range=0 : 203596
# Graph range=203596 : 407192
# Graph range=407192 : 610788
# Graph range=610788 : 814384
# Graph range=814384 : 1017980
# Graph range=1017980 : 1221576
# Graph range=1221576 : 1425172
# Graph range=1425172 : 1628768
# Graph range=1628768 : 1832364
# Graph range=1832364 : 2035960
# Graph range=2035960 : 2239556
# Graph range=2239556 : 2443152
# Graph range=2443152 : 2646748
# Graph range=2646748 : 2850344
# Graph range=2850344 : 3053940
# Graph range=3053940 : 3257536
# Graph range=3257536 : 3461132
# Graph range=3461132 : 3664728
# Graph range=3664728 : 3868324
# Graph range=3868324 : 4071920
# hiden node = 16
# -edim=16-Window=512-Overlap=16-SGD
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=512-Overlap=16-Adadelta
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=512-Overlap=16-Adamax
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=512-Overlap=16-Adam
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=512-Overlap=16-Adagrad
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=512-Overlap=16-RMSprop
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=512-Overlap=16-Nadam
# Graph range=0 : 406784
# Graph range=406784 : 813568
# Graph range=813568 : 1220352
# Graph range=1220352 : 1627136
# Graph range=1627136 : 2033920
# Graph range=2033920 : 2440704
# Graph range=2440704 : 2847488
# Graph range=2847488 : 3254272
# Graph range=3254272 : 3661056
# Graph range=3661056 : 4067840
# Graph range=4067840 : 4474624
# Graph range=4474624 : 4881408
# Graph range=4881408 : 5288192
# Graph range=5288192 : 5694976
# Graph range=5694976 : 6101760
# Graph range=6101760 : 6508544
# Graph range=6508544 : 6915328
# Graph range=6915328 : 7322112
# Graph range=7322112 : 7728896
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-SGD
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=13802793 : 14614722
# Graph range=14614722 : 15426651
# Graph range=15426651 : 16238580
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-Adadelta
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=13802793 : 14614722
# Graph range=14614722 : 15426651
# Graph range=15426651 : 16238580
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-Adamax
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=13802793 : 14614722
# Graph range=14614722 : 15426651
# Graph range=15426651 : 16238580
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-Adam
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=13802793 : 14614722
# Graph range=14614722 : 15426651
# Graph range=15426651 : 16238580
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-Adagrad
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=13802793 : 14614722
# Graph range=14614722 : 15426651
# Graph range=15426651 : 16238580
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-RMSprop
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=13802793 : 14614722
# Graph range=14614722 : 15426651
# Graph range=15426651 : 16238580
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-Nadam
# Graph range=0 : 811929
# Graph range=811929 : 1623858
# Graph range=1623858 : 2435787
# Graph range=2435787 : 3247716
# Graph range=3247716 : 4059645
# Graph range=4059645 : 4871574
# Graph range=4871574 : 5683503
# Graph range=5683503 : 6495432
# Graph range=6495432 : 7307361
# Graph range=7307361 : 8119290
# Graph range=8119290 : 8931219
# Graph range=8931219 : 9743148
# Graph range=9743148 : 10555077
# Graph range=10555077 : 11367006
# Graph range=11367006 : 12178935
# Graph range=12178935 : 12990864
# Graph range=12990864 : 13802793
# Graph range=16041980 : 19250376
# Graph range=19250376 : 22458772
# Graph range=22458772 : 25667168
# Graph range=25667168 : 28875564
# Graph range=28875564 : 32083960
# Graph range=32083960 : 35292356
# Graph range=35292356 : 38500752
# Graph range=38500752 : 41709148
# Graph range=41709148 : 44917544
# Graph range=44917544 : 48125940
# Graph range=48125940 : 51334336
# Graph range=51334336 : 54542732
# Graph range=54542732 : 57751128
# Graph range=57751128 : 60959524
# Graph range=60959524 : 64167920
# hiden node = 16
# -edim=16-Window=4096-Overlap=16-Adam
# Graph range=0 : 3208396
# Graph range=3208396 : 6416792
# Graph range=6416792 : 9625188
# Graph range=9625188 : 12833584
# Graph range=12833584 : 16041980
# Graph range=16041980 : 19250376
# Graph range=19250376 : 22458772
# Graph range=22458772 : 25667168
# Graph range=25667168 : 28875564
# Graph range=28875564 : 32083960
# Graph range=32083960 : 35292356
# Graph range=35292356 : 38500752
# Graph range=38500752 : 41709148
# Graph range=41709148 : 44917544
# Graph range=44917544 : 48125940
# Graph range=48125940 : 51334336
# Graph range=51334336 : 54542732
# Graph range=54542732 : 57751128
# Graph range=57751128 : 60959524
# Graph range=60959524 : 64167920
# hiden node = 16
# -edim=16-Window=4096-Overlap=16-Adagrad
# Graph range=0 : 3208396
# Graph range=3208396 : 6416792
# Graph range=6416792 : 9625188
# Graph range=9625188 : 12833584
# Graph range=12833584 : 16041980
# Graph range=16041980 : 19250376
# Graph range=19250376 : 22458772
# Graph range=22458772 : 25667168
# Graph range=25667168 : 28875564
# Graph range=28875564 : 32083960
# Graph range=32083960 : 35292356
# Graph range=35292356 : 38500752
# Graph range=38500752 : 41709148
# Graph range=41709148 : 44917544
# Graph range=44917544 : 48125940
# Graph range=48125940 : 51334336
# Graph range=51334336 : 54542732
# Graph range=54542732 : 57751128
# Graph range=57751128 : 60959524
# Graph range=60959524 : 64167920
# hiden node = 16
# -edim=16-Window=4096-Overlap=16-RMSprop
# Graph range=0 : 3208396
# Graph range=3208396 : 6416792
# Graph range=6416792 : 9625188
# Graph range=9625188 : 12833584
# Graph range=12833584 : 16041980
# Graph range=16041980 : 19250376
# Graph range=19250376 : 22458772
# Graph range=22458772 : 25667168
# Graph range=25667168 : 28875564
# Graph range=28875564 : 32083960
# Graph range=32083960 : 35292356
# Graph range=35292356 : 38500752
# Graph range=38500752 : 41709148
# Graph range=41709148 : 44917544
# Graph range=44917544 : 48125940
# Graph range=48125940 : 51334336
# Graph range=51334336 : 54542732
# Graph range=54542732 : 57751128
# Graph range=57751128 : 60959524
# Graph range=60959524 : 64167920
# hiden node = 16
# -edim=16-Window=4096-Overlap=16-Nadam
# Graph range=0 : 3208396
# Graph range=3208396 : 6416792
# Graph range=6416792 : 9625188
# Graph range=9625188 : 12833584
# Graph range=12833584 : 16041980
# Graph range=16041980 : 19250376
# Graph range=19250376 : 22458772
# Graph range=22458772 : 25667168
# Graph range=25667168 : 28875564
# Graph range=28875564 : 32083960
# Graph range=32083960 : 35292356
# Graph range=35292356 : 38500752
# Graph range=38500752 : 41709148
# Graph range=41709148 : 44917544
# Graph range=44917544 : 48125940
# Graph range=48125940 : 51334336
# Graph range=51334336 : 54542732
# Graph range=54542732 : 57751128
# Graph range=57751128 : 60959524
# Graph range=60959524 : 64167920

# %%
print "finish"
# Out:
# finish
