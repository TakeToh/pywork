# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,32,64,128,256] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccX,AccY,AccZ' # Axis
PathAxis='AccXYZ'

WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData"
DATE_PATH="/2016-08-15/"
TITLE_PATH="Sparse/"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras import regularizers

import matplotlib.image as mpimg
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5005)

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
# define rawdata directory
if not os.path.exists(WORKSPACE_PATH+"/raw/"):
    os.makedirs(WORKSPACE_PATH+"/raw/")
RawDataPath=WORKSPACE_PATH+"/raw/"

# define restoring windowdata directory
if not os.path.exists(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'

# define restoring netowrk model picture's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'

# define restoring graph data's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/')
GlaphDataPath=WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'

# define restoring model paarmeter directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/')
StudyDataPath=WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成**

# %%
# loop windowWidth
for SampleNum,Overlap in zip(WindowWidth,OverlapArray):
    ArrayAxis = Axis.split(",")
    w=window.Window()
    for a in ArrayAxis:
        w.SetData(a,dic[a])
    wind=w.Compile(windowWidth=SampleNum,overlapNum=Overlap)
    print wind.shape
    windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))

    # define SaveFileName
    for AxisName,WindowNum in zip(ArrayAxis,range(3)):
            print "hiden node = "+str(encoding_dim)
            CommonName='_edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+"l1_reg=1"+'-'+AxisName
            SaveFileNameEncord=DataName+'_encoded'+CommonName
            SaveFileNameDecord=DataName+'_decoded'+CommonName
            SaveFileNameNet=DataName+'_net'+CommonName
            SaveFileNameTrain=DataName+'_train'+CommonName
            SaveFileNameTest=DataName+'_test'+CommonName
            SaveFileNameGlaph=GlaphDataPath+DataName+CommonName+'_loss_val_loss.png'

            window_test=wind[:,:,WindowNum]
            window_train=wind[:,:,WindowNum]
            processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTrain,window_test)
            processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTest,window_test)
            shapeNum=wind.shape[1]


            # this is our input placeholder
            input_img = Input(shape=(shapeNum,))
            # "encoded" is the encoded representation of the input
            encoded = Dense(encoding_dim, activation='tanh',
                        W_regularizer=regularizers.WeightRegularizer(l1=10e-5,l2=0.0))(input_img)
            # "decoded" is the lossy reconstruction of the input
            decoded = Dense(shapeNum, activation='linear')(encoded)

            # this model maps an input to its reconstruction
            autoencoder = Model(input=input_img, output=decoded)

            # this model maps an input to its encoded representation
            encoder = Model(input=input_img, output=encoded)

            # create a placeholder for an encoded (32-dimensional) input
            encoded_input = Input(shape=(encoding_dim,))
            # retrieve the last layer of the autoencoder model
            decoder_layer = autoencoder.layers[-1]
            # create the decoder model
            decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))

            #autoencoder.compile(optimizer='adam', loss='mse')
            autoencoder.compile(optimizer='adam', loss='categorical_crossentropy')

            plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')

            early_stopping = EarlyStopping(monitor='val_loss', patience=5)

            hist = autoencoder.fit(window_train, window_train,
                            nb_epoch=100,
                            verbose=2,
                            batch_size=shapeNum/8,
                            shuffle=True,
                            validation_data=(window_test, window_test)
                            ,callbacks=[early_stopping]
                                  )
            time.sleep(0.1)
            encoded_imgs = encoder.predict(window_test)
            decoded_imgs = decoder.predict(encoded_imgs)

            processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameEncord,encoded_imgs)
            processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameDecord,decoded_imgs)

            # save model and wights
            json_string = encoder.to_json()
            open(StudyDataPath+SaveFileNameEncord+'.json', 'w').write(json_string)
            encoder.save_weights(StudyDataPath+SaveFileNameEncord+'_weights.h5',overwrite=True)

            json_string = decoder.to_json()
            open(StudyDataPath+SaveFileNameDecord+'.json', 'w').write(json_string)
            decoder.save_weights(StudyDataPath+SaveFileNameDecord+'_weights.h5',overwrite=True)

            json_string = autoencoder.to_json()
            open(StudyDataPath+SaveFileNameNet+'.json', 'w').write(json_string)
            autoencoder.save_weights(StudyDataPath+SaveFileNameNet+'_weights.h5',overwrite=True)

            # plot loss
            loss = hist.history['loss']
            val_loss = hist.history['val_loss']

            nb_epoch = len(loss)
            plt.plot(range(nb_epoch), loss, marker='.', label='loss')
            plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
            plt.legend(loc='best', fontsize=10)
            plt.grid()
            plt.xlabel('epoch')
            plt.ylabel('loss')
            plt.savefig(SaveFileNameGlaph)
            plt.show()
# Out:
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =15914
# SourceData's aborting data = 6
# window shape is (15914, 128, 3)
# (15914, 128, 3)
# hiden node = 16
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 0s - loss: -5.5799e+02 - val_loss: -6.0443e+02
# Epoch 2/100
# 0s - loss: -6.3131e+02 - val_loss: -6.4862e+02
# Epoch 3/100
# 0s - loss: -6.5615e+02 - val_loss: -6.6207e+02
# Epoch 4/100
# 0s - loss: -6.6461e+02 - val_loss: -6.6458e+02
# Epoch 5/100
# 0s - loss: -6.5929e+02 - val_loss: -6.5711e+02
# Epoch 6/100
# 0s - loss: -6.6767e+02 - val_loss: -6.6943e+02
# Epoch 7/100
# 0s - loss: -6.6986e+02 - val_loss: -6.7545e+02
# Epoch 8/100
# 0s - loss: -6.7499e+02 - val_loss: -6.7700e+02
# Epoch 9/100
# 0s - loss: -6.7689e+02 - val_loss: -6.7745e+02
# Epoch 10/100
# 0s - loss: -6.7713e+02 - val_loss: -6.7802e+02
# Epoch 11/100
# 0s - loss: -6.7823e+02 - val_loss: -6.7896e+02
# Epoch 12/100
# 0s - loss: -6.7972e+02 - val_loss: -6.8090e+02
# Epoch 13/100
# 0s - loss: -6.8011e+02 - val_loss: -6.7939e+02
# Epoch 14/100
# 0s - loss: -6.8022e+02 - val_loss: -6.7888e+02
# Epoch 15/100
# 0s - loss: -6.8045e+02 - val_loss: -6.8162e+02
# Epoch 16/100
# 0s - loss: -6.8054e+02 - val_loss: -6.8005e+02
# Epoch 17/100
# 0s - loss: -6.8118e+02 - val_loss: -6.8000e+02
# Epoch 18/100
# 0s - loss: -6.8293e+02 - val_loss: -6.8602e+02
# Epoch 19/100
# 0s - loss: -6.8516e+02 - val_loss: -6.8343e+02
# Epoch 20/100
# 0s - loss: -6.8533e+02 - val_loss: -6.8629e+02
# Epoch 21/100
# 0s - loss: -6.8497e+02 - val_loss: -6.8219e+02
# Epoch 22/100
# 0s - loss: -6.8527e+02 - val_loss: -6.8605e+02
# Epoch 23/100
# 0s - loss: -6.8492e+02 - val_loss: -6.8368e+02
# Epoch 24/100
# 0s - loss: -6.8538e+02 - val_loss: -6.8852e+02
# Epoch 25/100
# 0s - loss: -6.8887e+02 - val_loss: -6.8896e+02
# Epoch 26/100
# 0s - loss: -4.9169e+02 - val_loss: -4.6458e+02
# Epoch 27/100
# 0s - loss: -5.0975e+02 - val_loss: -5.4917e+02
# Epoch 28/100
# 0s - loss: -5.9019e+02 - val_loss: -6.1912e+02
# Epoch 29/100
# 0s - loss: -6.2937e+02 - val_loss: -6.3241e+02
# Epoch 30/100
# 0s - loss: -6.4270e+02 - val_loss: -6.4860e+02
# Epoch 31/100
# 0s - loss: -6.5721e+02 - val_loss: -6.6286e+02
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/backend/theano_backend.py:558: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 1 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# hiden node = 16
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 1s - loss: -1.2934e+03 - val_loss: -1.3986e+03
# Epoch 2/100
# 0s - loss: -1.4165e+03 - val_loss: -1.4393e+03
# Epoch 3/100
# 0s - loss: -1.4729e+03 - val_loss: -1.4999e+03
# Epoch 4/100
# 1s - loss: -1.5077e+03 - val_loss: -1.5107e+03
# Epoch 5/100
# 0s - loss: -1.5109e+03 - val_loss: -1.5119e+03
# Epoch 6/100
# 1s - loss: -1.5165e+03 - val_loss: -1.5242e+03
# Epoch 7/100
# 1s - loss: -1.5248e+03 - val_loss: -1.5409e+03
# Epoch 8/100
# 1s - loss: -1.5406e+03 - val_loss: -1.5412e+03
# Epoch 9/100
# 1s - loss: -1.5411e+03 - val_loss: -1.5411e+03
# Epoch 10/100
# 1s - loss: -1.5420e+03 - val_loss: -1.5422e+03
# Epoch 11/100
# 1s - loss: -1.5452e+03 - val_loss: -1.5532e+03
# Epoch 12/100
# 0s - loss: -1.5530e+03 - val_loss: -1.5528e+03
# Epoch 13/100
# 1s - loss: -1.5532e+03 - val_loss: -1.5537e+03
# Epoch 14/100
# 0s - loss: -1.5534e+03 - val_loss: -1.5533e+03
# Epoch 15/100
# 0s - loss: -1.5536e+03 - val_loss: -1.5549e+03
# Epoch 16/100
# 0s - loss: -1.5538e+03 - val_loss: -1.5541e+03
# Epoch 17/100
# 0s - loss: -1.5539e+03 - val_loss: -1.5539e+03
# Epoch 18/100
# 1s - loss: -1.5535e+03 - val_loss: -1.5537e+03
# Epoch 19/100
# 1s - loss: -1.5546e+03 - val_loss: -1.5551e+03
# Epoch 20/100
# 1s - loss: -1.5536e+03 - val_loss: -1.5535e+03
# Epoch 21/100
# 1s - loss: -1.5537e+03 - val_loss: -1.5539e+03
# Epoch 22/100
# 1s - loss: -1.5539e+03 - val_loss: -1.5541e+03
# Epoch 23/100
# 1s - loss: -1.5539e+03 - val_loss: -1.5538e+03
# Epoch 24/100
# 1s - loss: -1.5542e+03 - val_loss: -1.5532e+03
# Epoch 25/100
# 1s - loss: -1.5543e+03 - val_loss: -1.5549e+03
# hiden node = 16
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 1s - loss: -1.8875e+01 - val_loss: -2.8208e+01
# Epoch 2/100
# 1s - loss: -4.1883e+01 - val_loss: -3.9813e+01
# Epoch 3/100
# 1s - loss: -4.7070e+01 - val_loss: -3.3388e+01
# Epoch 4/100
# 1s - loss: -4.7077e+01 - val_loss: -2.7606e+01
# Epoch 5/100
# 1s - loss: -4.9555e+01 - val_loss: -5.1996e+01
# Epoch 6/100
# 1s - loss: -5.1396e+01 - val_loss: -2.7632e+01
# Epoch 7/100
# 1s - loss: -5.1691e+01 - val_loss: -3.4662e+01
# Epoch 8/100
# 1s - loss: -5.1552e+01 - val_loss: -7.1973e+01
# Epoch 9/100
# 1s - loss: -5.4829e+01 - val_loss: -7.8417e+01
# Epoch 10/100
# 1s - loss: -5.4518e+01 - val_loss: -6.0565e+01
# Epoch 11/100
# 1s - loss: -5.5405e+01 - val_loss: -3.7710e+01
# Epoch 12/100
# 1s - loss: -6.0579e+01 - val_loss: -3.3409e+01
# Epoch 13/100
# 1s - loss: -5.7617e+01 - val_loss: -7.5834e+01
# Epoch 14/100
# 1s - loss: -6.0025e+01 - val_loss: -8.6666e+01
# Epoch 15/100
# 1s - loss: -6.0383e+01 - val_loss: -3.0278e+01
# Epoch 16/100
# 1s - loss: -6.0558e+01 - val_loss: -4.4692e+01
# Epoch 17/100
# 1s - loss: -1.6798e+00 - val_loss: -3.3690e+01
# Epoch 18/100
# 1s - loss: -2.8162e+01 - val_loss: -3.7842e+01
# Epoch 19/100
# 1s - loss: -4.0666e+01 - val_loss: -4.4242e+01
# Epoch 20/100
# 1s - loss: -4.5932e+01 - val_loss: -5.0699e+01
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =7953
# SourceData's aborting data = 22
# window shape is (7953, 256, 3)
# (7953, 256, 3)
# hiden node = 16
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -1.0372e+03 - val_loss: -1.1261e+03
# Epoch 2/100
# 0s - loss: -1.1490e+03 - val_loss: -1.1845e+03
# Epoch 3/100
# 0s - loss: -1.2064e+03 - val_loss: -1.2206e+03
# Epoch 4/100
# 0s - loss: -1.2364e+03 - val_loss: -1.2426e+03
# Epoch 5/100
# 0s - loss: -1.2592e+03 - val_loss: -1.2737e+03
# Epoch 6/100
# 0s - loss: -1.2811e+03 - val_loss: -1.2887e+03
# Epoch 7/100
# 0s - loss: -1.2953e+03 - val_loss: -1.3061e+03
# Epoch 8/100
# 0s - loss: -1.3109e+03 - val_loss: -1.3164e+03
# Epoch 9/100
# 0s - loss: -1.3185e+03 - val_loss: -1.3202e+03
# Epoch 10/100
# 0s - loss: -1.3189e+03 - val_loss: -1.3211e+03
# Epoch 11/100
# 0s - loss: -1.3188e+03 - val_loss: -1.3015e+03
# Epoch 12/100
# 0s - loss: -8.8584e+02 - val_loss: -8.7966e+02
# Epoch 13/100
# 0s - loss: -9.3514e+02 - val_loss: -9.7722e+02
# Epoch 14/100
# 0s - loss: -1.0106e+03 - val_loss: -1.0269e+03
# Epoch 15/100
# 0s - loss: -1.0441e+03 - val_loss: -1.0564e+03
# Epoch 16/100
# 0s - loss: -1.0958e+03 - val_loss: -1.1111e+03
# hiden node = 16
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -2.4239e+03 - val_loss: -2.5819e+03
# Epoch 2/100
# 0s - loss: -2.6506e+03 - val_loss: -2.7147e+03
# Epoch 3/100
# 0s - loss: -2.7501e+03 - val_loss: -2.7724e+03
# Epoch 4/100
# 0s - loss: -2.7978e+03 - val_loss: -2.8085e+03
# Epoch 5/100
# 0s - loss: -2.8378e+03 - val_loss: -2.8540e+03
# Epoch 6/100
# 0s - loss: -2.8572e+03 - val_loss: -2.8660e+03
# Epoch 7/100
# 0s - loss: -2.8750e+03 - val_loss: -2.8791e+03
# Epoch 8/100
# 0s - loss: -2.9090e+03 - val_loss: -2.9129e+03
# Epoch 9/100
# 0s - loss: -2.9188e+03 - val_loss: -2.9236e+03
# Epoch 10/100
# 0s - loss: -2.9411e+03 - val_loss: -2.9513e+03
# Epoch 11/100
# 0s - loss: -2.9589e+03 - val_loss: -2.9628e+03
# Epoch 12/100
# 0s - loss: -2.9638e+03 - val_loss: -2.9645e+03
# Epoch 13/100
# 0s - loss: -2.9643e+03 - val_loss: -2.9617e+03
# Epoch 14/100
# 0s - loss: -2.9637e+03 - val_loss: -2.9653e+03
# Epoch 15/100
# 0s - loss: -2.9774e+03 - val_loss: -2.9854e+03
# Epoch 16/100
# 0s - loss: -2.9983e+03 - val_loss: -3.0037e+03
# Epoch 17/100
# 0s - loss: -3.0128e+03 - val_loss: -3.0181e+03
# Epoch 18/100
# 0s - loss: -3.0210e+03 - val_loss: -3.0291e+03
# Epoch 19/100
# 0s - loss: -3.0299e+03 - val_loss: -3.0310e+03
# Epoch 20/100
# 0s - loss: -3.0280e+03 - val_loss: -3.0262e+03
# Epoch 21/100
# 0s - loss: -3.0238e+03 - val_loss: -3.0330e+03
# Epoch 22/100
# 0s - loss: -3.0396e+03 - val_loss: -3.0425e+03
# Epoch 23/100
# 0s - loss: -3.0393e+03 - val_loss: -3.0362e+03
# Epoch 24/100
# 0s - loss: -3.0412e+03 - val_loss: -3.0453e+03
# Epoch 25/100
# 0s - loss: -3.0440e+03 - val_loss: -3.0466e+03
# Epoch 26/100
# 0s - loss: -3.0439e+03 - val_loss: -3.0443e+03
# Epoch 27/100
# 0s - loss: -3.0445e+03 - val_loss: -3.0410e+03
# Epoch 28/100
# 0s - loss: -3.0452e+03 - val_loss: -3.0461e+03
# Epoch 29/100
# 0s - loss: -3.0463e+03 - val_loss: -3.0467e+03
# Epoch 30/100
# 0s - loss: -3.0467e+03 - val_loss: -3.0471e+03
# Epoch 31/100
# 0s - loss: -3.0468e+03 - val_loss: -3.0457e+03
# Epoch 32/100
# 0s - loss: -3.0473e+03 - val_loss: -3.0476e+03
# Epoch 33/100
# 0s - loss: -3.0476e+03 - val_loss: -3.0482e+03
# Epoch 34/100
# 0s - loss: -3.0501e+03 - val_loss: -3.0582e+03
# Epoch 35/100
# 0s - loss: -3.0620e+03 - val_loss: -3.0641e+03
# Epoch 36/100
# 0s - loss: -3.0673e+03 - val_loss: -3.0674e+03
# Epoch 37/100
# 0s - loss: -3.0676e+03 - val_loss: -3.0611e+03
# Epoch 38/100
# 0s - loss: -3.0678e+03 - val_loss: -3.0678e+03
# Epoch 39/100
# 0s - loss: -3.0676e+03 - val_loss: -3.0674e+03
# Epoch 40/100
# 0s - loss: -3.0679e+03 - val_loss: -3.0680e+03
# Epoch 41/100
# 0s - loss: -3.0677e+03 - val_loss: -3.0666e+03
# Epoch 42/100
# 0s - loss: -3.0674e+03 - val_loss: -3.0683e+03
# Epoch 43/100
# 0s - loss: -3.0683e+03 - val_loss: -3.0684e+03
# Epoch 44/100
# 0s - loss: -3.0722e+03 - val_loss: -3.0779e+03
# Epoch 45/100
# 0s - loss: -3.0777e+03 - val_loss: -3.0778e+03
# Epoch 46/100
# 0s - loss: -3.0774e+03 - val_loss: -3.0779e+03
# Epoch 47/100
# 0s - loss: -3.0778e+03 - val_loss: -3.0782e+03
# Epoch 48/100
# 0s - loss: -3.0781e+03 - val_loss: -3.0768e+03
# Epoch 49/100
# 0s - loss: -3.0776e+03 - val_loss: -3.0782e+03
# Epoch 50/100
# 0s - loss: -3.0785e+03 - val_loss: -3.0784e+03
# Epoch 51/100
# 0s - loss: -3.0782e+03 - val_loss: -3.0786e+03
# Epoch 52/100
# 0s - loss: -3.0781e+03 - val_loss: -3.0768e+03
# Epoch 53/100
# 0s - loss: -3.0775e+03 - val_loss: -3.0777e+03
# Epoch 54/100
# 0s - loss: -3.0777e+03 - val_loss: -3.0783e+03
# Epoch 55/100
# 0s - loss: -3.0782e+03 - val_loss: -3.0786e+03
# Epoch 56/100
# 0s - loss: -3.0783e+03 - val_loss: -3.0785e+03
# Epoch 57/100
# 0s - loss: -3.0788e+03 - val_loss: -3.0792e+03
# Epoch 58/100
# 0s - loss: -3.0785e+03 - val_loss: -3.0784e+03
# Epoch 59/100
# 0s - loss: -3.0787e+03 - val_loss: -3.0787e+03
# Epoch 60/100
# 0s - loss: -3.0787e+03 - val_loss: -3.0791e+03
# Epoch 61/100
# 0s - loss: -3.0796e+03 - val_loss: -3.0799e+03
# Epoch 62/100
# 0s - loss: -3.0797e+03 - val_loss: -3.0800e+03
# Epoch 63/100
# 0s - loss: -3.0801e+03 - val_loss: -3.0785e+03
# Epoch 64/100
# 0s - loss: -3.0792e+03 - val_loss: -3.0791e+03
# Epoch 65/100
# 0s - loss: -3.0792e+03 - val_loss: -3.0795e+03
# Epoch 66/100
# 0s - loss: -3.0795e+03 - val_loss: -3.0799e+03
# Epoch 67/100
# 0s - loss: -3.0800e+03 - val_loss: -3.0805e+03
# Epoch 68/100
# 0s - loss: -3.0804e+03 - val_loss: -3.0804e+03
# Epoch 69/100
# 0s - loss: -3.0802e+03 - val_loss: -3.0804e+03
# Epoch 70/100
# 0s - loss: -3.0807e+03 - val_loss: -3.0798e+03
# Epoch 71/100
# 0s - loss: -3.0801e+03 - val_loss: -3.0804e+03
# Epoch 72/100
# 0s - loss: -3.0803e+03 - val_loss: -3.0808e+03
# Epoch 73/100
# 0s - loss: -3.0812e+03 - val_loss: -3.0817e+03
# Epoch 74/100
# 0s - loss: -3.0814e+03 - val_loss: -3.0816e+03
# Epoch 75/100
# 0s - loss: -3.0813e+03 - val_loss: -3.0823e+03
# Epoch 76/100
# 0s - loss: -3.0798e+03 - val_loss: -3.0803e+03
# Epoch 77/100
# 0s - loss: -3.0807e+03 - val_loss: -3.0812e+03
# Epoch 78/100
# 0s - loss: -3.0815e+03 - val_loss: -3.0813e+03
# Epoch 79/100
# 0s - loss: -3.0812e+03 - val_loss: -3.0817e+03
# Epoch 80/100
# 0s - loss: -3.0817e+03 - val_loss: -3.0810e+03
# Epoch 81/100
# 0s - loss: -3.0810e+03 - val_loss: -3.0814e+03
# hiden node = 16
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -1.3115e+01 - val_loss: -2.2457e+01
# Epoch 2/100
# 0s - loss: -3.6555e+01 - val_loss: -8.2341e+01
# Epoch 3/100
# 0s - loss: -5.3073e+01 - val_loss: -9.8843e+01
# Epoch 4/100
# 0s - loss: -5.7694e+01 - val_loss: -1.0402e+02
# Epoch 5/100
# 0s - loss: -6.2736e+01 - val_loss: -1.1682e+02
# Epoch 6/100
# 0s - loss: -6.3702e+01 - val_loss: -1.0862e+02
# Epoch 7/100
# 0s - loss: -7.3338e+01 - val_loss: -4.3472e+01
# Epoch 8/100
# 0s - loss: -5.3322e+01 - val_loss: -4.0069e+01
# Epoch 9/100
# 0s - loss: -7.3426e+01 - val_loss: -9.9315e+01
# Epoch 10/100
# 0s - loss: -7.7399e+01 - val_loss: -4.2766e+01
# Epoch 11/100
# 0s - loss: -8.4691e+01 - val_loss: -5.4811e+01
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =3973
# SourceData's aborting data = 22
# window shape is (3973, 512, 3)
# (3973, 512, 3)
# hiden node = 16
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: -1.9000e+03 - val_loss: -2.0407e+03
# Epoch 2/100
# 0s - loss: -2.1137e+03 - val_loss: -2.1756e+03
# Epoch 3/100
# 0s - loss: -2.2115e+03 - val_loss: -2.2382e+03
# Epoch 4/100
# 0s - loss: -2.2526e+03 - val_loss: -2.2614e+03
# Epoch 5/100
# 0s - loss: -2.2798e+03 - val_loss: -2.3044e+03
# Epoch 6/100
# 0s - loss: -2.3116e+03 - val_loss: -2.3194e+03
# Epoch 7/100
# 0s - loss: -2.3407e+03 - val_loss: -2.3592e+03
# Epoch 8/100
# 0s - loss: -2.3805e+03 - val_loss: -2.3930e+03
# Epoch 9/100
# 0s - loss: -2.4016e+03 - val_loss: -2.4102e+03
# Epoch 10/100
# 0s - loss: -2.4196e+03 - val_loss: -2.4262e+03
# Epoch 11/100
# 0s - loss: -2.4406e+03 - val_loss: -2.4478e+03
# Epoch 12/100
# 0s - loss: -2.4537e+03 - val_loss: -2.4623e+03
# Epoch 13/100
# 0s - loss: -2.4651e+03 - val_loss: -2.4749e+03
# Epoch 14/100
# 0s - loss: -2.4787e+03 - val_loss: -2.4861e+03
# Epoch 15/100
# 0s - loss: -2.4893e+03 - val_loss: -2.4979e+03
# Epoch 16/100
# 0s - loss: -2.5021e+03 - val_loss: -2.5092e+03
# Epoch 17/100
# 0s - loss: -2.5133e+03 - val_loss: -2.5146e+03
# Epoch 18/100
# 0s - loss: -2.5180e+03 - val_loss: -2.5195e+03
# Epoch 19/100
# 0s - loss: -2.5176e+03 - val_loss: -2.5135e+03
# Epoch 20/100
# 0s - loss: -2.5234e+03 - val_loss: -2.5310e+03
# Epoch 21/100
# 0s - loss: -2.5313e+03 - val_loss: -2.5330e+03
# Epoch 22/100
# 0s - loss: -2.5432e+03 - val_loss: -2.5498e+03
# Epoch 23/100
# 0s - loss: -2.5514e+03 - val_loss: -2.5493e+03
# Epoch 24/100
# 0s - loss: -2.5462e+03 - val_loss: -2.5379e+03
# Epoch 25/100
# 0s - loss: -2.5457e+03 - val_loss: -2.5528e+03
# Epoch 26/100
# 0s - loss: -2.5506e+03 - val_loss: -2.5709e+03
# Epoch 27/100
# 0s - loss: -2.5754e+03 - val_loss: -2.5783e+03
# Epoch 28/100
# 0s - loss: -2.5800e+03 - val_loss: -2.5845e+03
# Epoch 29/100
# 0s - loss: -2.5856e+03 - val_loss: -2.5853e+03
# Epoch 30/100
# 0s - loss: -2.5880e+03 - val_loss: -2.5829e+03
# Epoch 31/100
# 0s - loss: -2.5820e+03 - val_loss: -2.5829e+03
# Epoch 32/100
# 0s - loss: -2.5885e+03 - val_loss: -2.5982e+03
# Epoch 33/100
# 0s - loss: -2.5979e+03 - val_loss: -2.5967e+03
# Epoch 34/100
# 0s - loss: -2.6058e+03 - val_loss: -2.6005e+03
# Epoch 35/100
# 0s - loss: -2.5961e+03 - val_loss: -2.6112e+03
# Epoch 36/100
# 0s - loss: -2.6209e+03 - val_loss: -2.6263e+03
# Epoch 37/100
# 0s - loss: -2.6237e+03 - val_loss: -2.6156e+03
# Epoch 38/100
# 0s - loss: -2.6232e+03 - val_loss: -2.6271e+03
# Epoch 39/100
# 0s - loss: -2.6282e+03 - val_loss: -2.6310e+03
# Epoch 40/100
# 0s - loss: -2.6348e+03 - val_loss: -2.6337e+03
# Epoch 41/100
# 0s - loss: -2.6350e+03 - val_loss: -2.6386e+03
# Epoch 42/100
# 0s - loss: -2.6383e+03 - val_loss: -2.6412e+03
# Epoch 43/100
# 0s - loss: -2.6402e+03 - val_loss: -2.6373e+03
# Epoch 44/100
# 0s - loss: -2.6412e+03 - val_loss: -2.6381e+03
# Epoch 45/100
# 0s - loss: -2.2530e+03 - val_loss: -1.8199e+03
# Epoch 46/100
# 0s - loss: -1.9639e+03 - val_loss: -2.0627e+03
# Epoch 47/100
# 0s - loss: -2.1098e+03 - val_loss: -2.1350e+03
# Epoch 48/100
# 0s - loss: -2.1555e+03 - val_loss: -2.1741e+03
# hiden node = 16
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: -4.4116e+03 - val_loss: -4.7755e+03
# Epoch 2/100
# 0s - loss: -4.8605e+03 - val_loss: -4.9741e+03
# Epoch 3/100
# 0s - loss: -5.0473e+03 - val_loss: -5.1088e+03
# Epoch 4/100
# 0s - loss: -5.1635e+03 - val_loss: -5.2011e+03
# Epoch 5/100
# 0s - loss: -5.2555e+03 - val_loss: -5.3171e+03
# Epoch 6/100
# 0s - loss: -5.3282e+03 - val_loss: -5.3455e+03
# Epoch 7/100
# 0s - loss: -5.3676e+03 - val_loss: -5.3778e+03
# Epoch 8/100
# 0s - loss: -5.3958e+03 - val_loss: -5.4201e+03
# Epoch 9/100
# 0s - loss: -5.4262e+03 - val_loss: -5.4235e+03
# Epoch 10/100
# 0s - loss: -5.4445e+03 - val_loss: -5.4479e+03
# Epoch 11/100
# 0s - loss: -5.4548e+03 - val_loss: -5.4640e+03
# Epoch 12/100
# 0s - loss: -5.4667e+03 - val_loss: -5.4731e+03
# Epoch 13/100
# 0s - loss: -5.4803e+03 - val_loss: -5.4991e+03
# Epoch 14/100
# 0s - loss: -5.4998e+03 - val_loss: -5.5026e+03
# Epoch 15/100
# 0s - loss: -5.5137e+03 - val_loss: -5.5198e+03
# Epoch 16/100
# 0s - loss: -5.5270e+03 - val_loss: -5.5376e+03
# Epoch 17/100
# 0s - loss: -5.5408e+03 - val_loss: -5.5465e+03
# Epoch 18/100
# 0s - loss: -5.5509e+03 - val_loss: -5.5629e+03
# Epoch 19/100
# 0s - loss: -5.5687e+03 - val_loss: -5.5821e+03
# Epoch 20/100
# 0s - loss: -5.5827e+03 - val_loss: -5.5853e+03
# Epoch 21/100
# 0s - loss: -5.5899e+03 - val_loss: -5.5956e+03
# Epoch 22/100
# 0s - loss: -5.6000e+03 - val_loss: -5.6040e+03
# Epoch 23/100
# 0s - loss: -5.6043e+03 - val_loss: -5.5997e+03
# Epoch 24/100
# 0s - loss: -5.5980e+03 - val_loss: -5.5998e+03
# Epoch 25/100
# 0s - loss: -5.6016e+03 - val_loss: -5.6104e+03
# Epoch 26/100
# 0s - loss: -5.6246e+03 - val_loss: -5.6401e+03
# Epoch 27/100
# 0s - loss: -5.6446e+03 - val_loss: -5.6433e+03
# Epoch 28/100
# 0s - loss: -5.6513e+03 - val_loss: -5.6565e+03
# Epoch 29/100
# 0s - loss: -5.6564e+03 - val_loss: -5.6570e+03
# Epoch 30/100
# 0s - loss: -5.6575e+03 - val_loss: -5.6584e+03
# Epoch 31/100
# 0s - loss: -5.6592e+03 - val_loss: -5.6594e+03
# Epoch 32/100
# 0s - loss: -5.6593e+03 - val_loss: -5.6676e+03
# Epoch 33/100
# 0s - loss: -5.6717e+03 - val_loss: -5.6766e+03
# Epoch 34/100
# 0s - loss: -5.6770e+03 - val_loss: -5.6746e+03
# Epoch 35/100
# 0s - loss: -5.6838e+03 - val_loss: -5.6859e+03
# Epoch 36/100
# 0s - loss: -5.6905e+03 - val_loss: -5.6997e+03
# Epoch 37/100
# 0s - loss: -5.7023e+03 - val_loss: -5.7015e+03
# Epoch 38/100
# 0s - loss: -5.7029e+03 - val_loss: -5.7039e+03
# Epoch 39/100
# 0s - loss: -5.7056e+03 - val_loss: -5.7121e+03
# Epoch 40/100
# 0s - loss: -5.7175e+03 - val_loss: -5.7198e+03
# Epoch 41/100
# 0s - loss: -5.7196e+03 - val_loss: -5.7204e+03
# Epoch 42/100
# 0s - loss: -5.7209e+03 - val_loss: -5.7216e+03
# Epoch 43/100
# 0s - loss: -5.7268e+03 - val_loss: -5.7281e+03
# Epoch 44/100
# 0s - loss: -5.7328e+03 - val_loss: -5.7385e+03
# Epoch 45/100
# 0s - loss: -5.7420e+03 - val_loss: -5.7485e+03
# Epoch 46/100
# 0s - loss: -5.7548e+03 - val_loss: -5.7569e+03
# Epoch 47/100
# 0s - loss: -5.7634e+03 - val_loss: -5.7643e+03
# Epoch 48/100
# 0s - loss: -5.7645e+03 - val_loss: -5.7650e+03
# Epoch 49/100
# 0s - loss: -5.7655e+03 - val_loss: -5.7667e+03
# Epoch 50/100
# 0s - loss: -5.7756e+03 - val_loss: -5.7830e+03
# Epoch 51/100
# 0s - loss: -5.7882e+03 - val_loss: -5.7911e+03
# Epoch 52/100
# 0s - loss: -5.7911e+03 - val_loss: -5.7915e+03
# Epoch 53/100
# 0s - loss: -5.7947e+03 - val_loss: -5.7971e+03
# Epoch 54/100
# 0s - loss: -5.7996e+03 - val_loss: -5.7997e+03
# Epoch 55/100
# 0s - loss: -5.7997e+03 - val_loss: -5.8007e+03
# Epoch 56/100
# 0s - loss: -5.8065e+03 - val_loss: -5.8084e+03
# Epoch 57/100
# 0s - loss: -5.8120e+03 - val_loss: -5.8146e+03
# Epoch 58/100
# 0s - loss: -5.8161e+03 - val_loss: -5.8166e+03
# Epoch 59/100
# 0s - loss: -5.8212e+03 - val_loss: -5.8249e+03
# Epoch 60/100
# 0s - loss: -5.8252e+03 - val_loss: -5.8257e+03
# Epoch 61/100
# 0s - loss: -5.8250e+03 - val_loss: -5.8260e+03
# Epoch 62/100
# 0s - loss: -5.8249e+03 - val_loss: -5.8348e+03
# Epoch 63/100
# 0s - loss: -5.8351e+03 - val_loss: -5.8357e+03
# Epoch 64/100
# 0s - loss: -5.8357e+03 - val_loss: -5.8343e+03
# Epoch 65/100
# 0s - loss: -5.8400e+03 - val_loss: -5.8455e+03
# Epoch 66/100
# 0s - loss: -5.8514e+03 - val_loss: -5.8538e+03
# Epoch 67/100
# 0s - loss: -5.8577e+03 - val_loss: -5.8592e+03
# Epoch 68/100
# 0s - loss: -5.8620e+03 - val_loss: -5.8628e+03
# Epoch 69/100
# 0s - loss: -5.8658e+03 - val_loss: -5.8710e+03
# Epoch 70/100
# 0s - loss: -5.8712e+03 - val_loss: -5.8717e+03
# Epoch 71/100
# 0s - loss: -5.8778e+03 - val_loss: -5.8796e+03
# Epoch 72/100
# 0s - loss: -5.8795e+03 - val_loss: -5.8799e+03
# Epoch 73/100
# 0s - loss: -5.8798e+03 - val_loss: -5.8805e+03
# Epoch 74/100
# 0s - loss: -5.8865e+03 - val_loss: -5.8888e+03
# Epoch 75/100
# 0s - loss: -5.8930e+03 - val_loss: -5.8968e+03
# Epoch 76/100
# 0s - loss: -5.8968e+03 - val_loss: -5.8952e+03
# Epoch 77/100
# 0s - loss: -5.8967e+03 - val_loss: -5.8970e+03
# Epoch 78/100
# 0s - loss: -5.8973e+03 - val_loss: -5.8978e+03
# Epoch 79/100
# 0s - loss: -5.8980e+03 - val_loss: -5.8982e+03
# Epoch 80/100
# 0s - loss: -5.8981e+03 - val_loss: -5.8982e+03
# Epoch 81/100
# 0s - loss: -5.8986e+03 - val_loss: -5.8991e+03
# Epoch 82/100
# 0s - loss: -5.8988e+03 - val_loss: -5.8991e+03
# Epoch 83/100
# 0s - loss: -5.8994e+03 - val_loss: -5.8999e+03
# Epoch 84/100
# 0s - loss: -5.8997e+03 - val_loss: -5.8985e+03
# Epoch 85/100
# 0s - loss: -5.8996e+03 - val_loss: -5.9004e+03
# Epoch 86/100
# 0s - loss: -5.9016e+03 - val_loss: -5.9029e+03
# Epoch 87/100
# 0s - loss: -5.9047e+03 - val_loss: -5.9118e+03
# Epoch 88/100
# 0s - loss: -5.9161e+03 - val_loss: -5.9198e+03
# Epoch 89/100
# 0s - loss: -5.9229e+03 - val_loss: -5.9316e+03
# Epoch 90/100
# 0s - loss: -5.9413e+03 - val_loss: -5.9479e+03
# Epoch 91/100
# 0s - loss: -5.9540e+03 - val_loss: -5.9545e+03
# Epoch 92/100
# 0s - loss: -5.9572e+03 - val_loss: -5.9643e+03
# Epoch 93/100
# 0s - loss: -5.9711e+03 - val_loss: -5.9722e+03
# Epoch 94/100
# 0s - loss: -5.9725e+03 - val_loss: -5.9728e+03
# Epoch 95/100
# 0s - loss: -5.9732e+03 - val_loss: -5.9738e+03
# Epoch 96/100
# 0s - loss: -5.9748e+03 - val_loss: -5.9823e+03
# Epoch 97/100
# 0s - loss: -5.9884e+03 - val_loss: -5.9909e+03
# Epoch 98/100
# 0s - loss: -5.9965e+03 - val_loss: -5.9993e+03
# Epoch 99/100
# 0s - loss: -6.0062e+03 - val_loss: -6.0072e+03
# Epoch 100/100
# 0s - loss: -6.0071e+03 - val_loss: -6.0070e+03
# hiden node = 16
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: 2.6556 - val_loss: -2.5564e+01
# Epoch 2/100
# 0s - loss: 18.9790 - val_loss: -1.2243e+00
# Epoch 3/100
# 0s - loss: -2.3260e+01 - val_loss: -4.3424e+01
# Epoch 4/100
# 0s - loss: -5.7972e+01 - val_loss: -7.3460e+01
# Epoch 5/100
# 0s - loss: -7.9586e+01 - val_loss: -8.4934e+01
# Epoch 6/100
# 0s - loss: -8.7860e+01 - val_loss: -9.1639e+01
# Epoch 7/100
# 0s - loss: -9.9081e+01 - val_loss: -1.0573e+02
# Epoch 8/100
# 0s - loss: -1.0858e+02 - val_loss: -1.1583e+02
# Epoch 9/100
# 0s - loss: 6.4933 - val_loss: -2.2247e+01
# Epoch 10/100
# 0s - loss: -3.9949e+01 - val_loss: -5.0818e+01
# Epoch 11/100
# 0s - loss: -6.3508e+01 - val_loss: -7.2882e+01
# Epoch 12/100
# 0s - loss: -7.7222e+01 - val_loss: -7.8686e+01
# Epoch 13/100
# 0s - loss: -8.1521e+01 - val_loss: -8.3500e+01
# Epoch 14/100
# 0s - loss: -4.3749e+01 - val_loss: 65.2568
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =1983
# SourceData's aborting data = 22
# window shape is (1983, 1024, 3)
# (1983, 1024, 3)
# hiden node = 16
# Train on 1983 samples, validate on 1983 samples
# Epoch 1/100
# 0s - loss: -3.7104e+03 - val_loss: -3.9812e+03
# Epoch 2/100
# 0s - loss: -4.0640e+03 - val_loss: -4.1429e+03
# Epoch 3/100
# 0s - loss: -4.1986e+03 - val_loss: -4.2654e+03
# Epoch 4/100
# 0s - loss: -4.3111e+03 - val_loss: -4.3461e+03
# Epoch 5/100
# 0s - loss: -4.3831e+03 - val_loss: -4.4306e+03
# Epoch 6/100
# 0s - loss: -4.4637e+03 - val_loss: -4.4930e+03
# Epoch 7/100
# 0s - loss: -4.5129e+03 - val_loss: -4.5368e+03
# Epoch 8/100
# 0s - loss: -4.5550e+03 - val_loss: -4.5731e+03
# Epoch 9/100
# 0s - loss: -4.5948e+03 - val_loss: -4.6221e+03
# Epoch 10/100
# 0s - loss: -4.6278e+03 - val_loss: -4.6416e+03
# Epoch 11/100
# 0s - loss: -4.6573e+03 - val_loss: -4.6709e+03
# Epoch 12/100
# 0s - loss: -4.6903e+03 - val_loss: -4.6986e+03
# Epoch 13/100
# 0s - loss: -4.7066e+03 - val_loss: -4.7208e+03
# Epoch 14/100
# 0s - loss: -4.7271e+03 - val_loss: -4.7434e+03
# Epoch 15/100
# 0s - loss: -4.7459e+03 - val_loss: -4.7496e+03
# Epoch 16/100
# 0s - loss: -4.7529e+03 - val_loss: -4.7595e+03
# Epoch 17/100
# 0s - loss: -4.7697e+03 - val_loss: -4.7838e+03
# Epoch 18/100
# 0s - loss: -4.7926e+03 - val_loss: -4.7981e+03
# Epoch 19/100
# 0s - loss: -4.7959e+03 - val_loss: -4.8022e+03
# Epoch 20/100
# 0s - loss: -4.8094e+03 - val_loss: -4.8102e+03
# Epoch 21/100
# 0s - loss: -4.8236e+03 - val_loss: -4.8310e+03
# Epoch 22/100
# 0s - loss: -4.8407e+03 - val_loss: -4.8495e+03
# Epoch 23/100
# 0s - loss: -4.8557e+03 - val_loss: -4.8643e+03
# Epoch 24/100
# 0s - loss: -4.8706e+03 - val_loss: -4.8761e+03
# Epoch 25/100
# 0s - loss: -4.8776e+03 - val_loss: -4.8811e+03
# Epoch 26/100
# 0s - loss: -4.8893e+03 - val_loss: -4.8953e+03
# Epoch 27/100
# 0s - loss: -4.8969e+03 - val_loss: -4.9002e+03
# Epoch 28/100
# 0s - loss: -4.9016e+03 - val_loss: -4.9094e+03
# Epoch 29/100
# 0s - loss: -4.9138e+03 - val_loss: -4.9200e+03
# Epoch 30/100
# 0s - loss: -4.9208e+03 - val_loss: -4.9259e+03
# Epoch 31/100
# 0s - loss: -4.9282e+03 - val_loss: -4.9315e+03
# Epoch 32/100
# 0s - loss: -4.9349e+03 - val_loss: -4.9385e+03
# Epoch 33/100
# 0s - loss: -4.9404e+03 - val_loss: -4.9428e+03
# Epoch 34/100
# 0s - loss: -4.9426e+03 - val_loss: -4.9417e+03
# Epoch 35/100
# 0s - loss: -4.9501e+03 - val_loss: -4.9532e+03
# Epoch 36/100
# 0s - loss: -4.9555e+03 - val_loss: -4.9591e+03
# Epoch 37/100
# 0s - loss: -4.9580e+03 - val_loss: -4.9670e+03
# Epoch 38/100
# 0s - loss: -4.9766e+03 - val_loss: -4.9779e+03
# Epoch 39/100
# 0s - loss: -4.9800e+03 - val_loss: -4.9844e+03
# Epoch 40/100
# 0s - loss: -4.9819e+03 - val_loss: -4.9806e+03
# Epoch 41/100
# 0s - loss: -4.9856e+03 - val_loss: -4.9940e+03
# Epoch 42/100
# 0s - loss: -4.9969e+03 - val_loss: -4.9983e+03
# Epoch 43/100
# 0s - loss: -5.0005e+03 - val_loss: -4.9986e+03
# Epoch 44/100
# 0s - loss: -4.9988e+03 - val_loss: -4.9999e+03
# Epoch 45/100
# 0s - loss: -5.0015e+03 - val_loss: -5.0040e+03
# Epoch 46/100
# 0s - loss: -5.0046e+03 - val_loss: -5.0014e+03
# Epoch 47/100
# 0s - loss: -5.0043e+03 - val_loss: -5.0037e+03
# Epoch 48/100
# 0s - loss: -5.0084e+03 - val_loss: -5.0100e+03
# Epoch 49/100
# 0s - loss: -5.0138e+03 - val_loss: -5.0192e+03
# Epoch 50/100
# 0s - loss: -5.0188e+03 - val_loss: -5.0217e+03
# Epoch 51/100
# 0s - loss: -5.0237e+03 - val_loss: -5.0272e+03
# Epoch 52/100
# 0s - loss: -5.0302e+03 - val_loss: -5.0332e+03
# Epoch 53/100
# 0s - loss: -5.0358e+03 - val_loss: -5.0410e+03
# Epoch 54/100
# 0s - loss: -5.0421e+03 - val_loss: -5.0439e+03
# Epoch 55/100
# 0s - loss: -5.0473e+03 - val_loss: -5.0481e+03
# Epoch 56/100
# 0s - loss: -5.0528e+03 - val_loss: -5.0516e+03
# Epoch 57/100
# 0s - loss: -5.0559e+03 - val_loss: -5.0627e+03
# Epoch 58/100
# 0s - loss: -5.0633e+03 - val_loss: -5.0669e+03
# Epoch 59/100
# 0s - loss: -5.0685e+03 - val_loss: -5.0694e+03
# Epoch 60/100
# 0s - loss: -5.0717e+03 - val_loss: -5.0734e+03
# Epoch 61/100
# 0s - loss: -5.0739e+03 - val_loss: -5.0768e+03
# Epoch 62/100
# 0s - loss: -5.0802e+03 - val_loss: -5.0794e+03
# Epoch 63/100
# 0s - loss: -5.0801e+03 - val_loss: -5.0798e+03
# Epoch 64/100
# 0s - loss: -5.0822e+03 - val_loss: -5.0838e+03
# Epoch 65/100
# 0s - loss: -5.0829e+03 - val_loss: -5.0787e+03
# Epoch 66/100
# 0s - loss: -5.0834e+03 - val_loss: -5.0852e+03
# Epoch 67/100
# 0s - loss: -5.0822e+03 - val_loss: -5.0787e+03
# Epoch 68/100
# 0s - loss: -5.0789e+03 - val_loss: -5.0780e+03
# Epoch 69/100
# 0s - loss: -5.0827e+03 - val_loss: -5.0854e+03
# Epoch 70/100
# 0s - loss: -5.0886e+03 - val_loss: -5.0906e+03
# Epoch 71/100
# 0s - loss: -5.0911e+03 - val_loss: -5.0928e+03
# Epoch 72/100
# 0s - loss: -5.0942e+03 - val_loss: -5.0978e+03
# Epoch 73/100
# 0s - loss: -5.1002e+03 - val_loss: -5.1030e+03
# Epoch 74/100
# 0s - loss: -5.1024e+03 - val_loss: -5.0981e+03
# Epoch 75/100
# 0s - loss: -5.0961e+03 - val_loss: -5.0963e+03
# Epoch 76/100
# 0s - loss: -5.0920e+03 - val_loss: -5.0948e+03
# Epoch 77/100
# 0s - loss: -5.1048e+03 - val_loss: -5.1143e+03
# Epoch 78/100
# 0s - loss: -5.1182e+03 - val_loss: -5.1205e+03
# Epoch 79/100
# 0s - loss: -5.1248e+03 - val_loss: -5.1296e+03
# Epoch 80/100
# 0s - loss: -5.1282e+03 - val_loss: -5.1279e+03
# Epoch 81/100
# 0s - loss: -5.1328e+03 - val_loss: -5.1324e+03
# Epoch 82/100
# 0s - loss: -5.1379e+03 - val_loss: -5.1434e+03
# Epoch 83/100
# 0s - loss: -5.1451e+03 - val_loss: -5.1460e+03
# Epoch 84/100
# 0s - loss: -5.1432e+03 - val_loss: -5.1428e+03
# Epoch 85/100
# 0s - loss: -5.1450e+03 - val_loss: -5.1477e+03
# Epoch 86/100
# 0s - loss: -5.1463e+03 - val_loss: -5.1415e+03
# Epoch 87/100
# 0s - loss: -5.1407e+03 - val_loss: -5.1438e+03
# Epoch 88/100
# 0s - loss: -5.1439e+03 - val_loss: -5.1465e+03
# Epoch 89/100
# 0s - loss: -5.1487e+03 - val_loss: -5.1517e+03
# Epoch 90/100
# 0s - loss: -5.1539e+03 - val_loss: -5.1581e+03
# Epoch 91/100
# 0s - loss: -5.1642e+03 - val_loss: -5.1664e+03
# Epoch 92/100
# 0s - loss: -5.1679e+03 - val_loss: -5.1695e+03
# Epoch 93/100
# 0s - loss: -5.1709e+03 - val_loss: -5.1730e+03
# Epoch 94/100
# 0s - loss: -5.1730e+03 - val_loss: -5.1735e+03
# Epoch 95/100
# 0s - loss: -5.1764e+03 - val_loss: -5.1771e+03
# Epoch 96/100
# 0s - loss: -5.1787e+03 - val_loss: -5.1821e+03
# Epoch 97/100
# 0s - loss: -5.1806e+03 - val_loss: -5.1796e+03
# Epoch 98/100
# 0s - loss: -5.1831e+03 - val_loss: -5.1839e+03
# Epoch 99/100
# 0s - loss: -5.1838e+03 - val_loss: -5.1851e+03
# Epoch 100/100
# 0s - loss: -5.1839e+03 - val_loss: -5.1879e+03
# hiden node = 16
# Train on 1983 samples, validate on 1983 samples
# Epoch 1/100
# 0s - loss: -8.2873e+03 - val_loss: -8.7956e+03
# Epoch 2/100
# 0s - loss: -8.9733e+03 - val_loss: -9.1267e+03
# Epoch 3/100
# 0s - loss: -9.2608e+03 - val_loss: -9.4065e+03
# Epoch 4/100
# 0s - loss: -9.4777e+03 - val_loss: -9.5595e+03
# Epoch 5/100
# 0s - loss: -9.6486e+03 - val_loss: -9.7386e+03
# Epoch 6/100
# 0s - loss: -9.7868e+03 - val_loss: -9.8436e+03
# Epoch 7/100
# 0s - loss: -9.8864e+03 - val_loss: -9.9526e+03
# Epoch 8/100
# 0s - loss: -9.9890e+03 - val_loss: -1.0032e+04
# Epoch 9/100
# 0s - loss: -1.0082e+04 - val_loss: -1.0135e+04
# Epoch 10/100
# 0s - loss: -1.0173e+04 - val_loss: -1.0215e+04
# Epoch 11/100
# 0s - loss: -1.0275e+04 - val_loss: -1.0342e+04
# Epoch 12/100
# 0s - loss: -1.0380e+04 - val_loss: -1.0432e+04
# Epoch 13/100
# 0s - loss: -1.0458e+04 - val_loss: -1.0485e+04
# Epoch 14/100
# 0s - loss: -1.0521e+04 - val_loss: -1.0546e+04
# Epoch 15/100
# 0s - loss: -1.0566e+04 - val_loss: -1.0592e+04
# Epoch 16/100
# 0s - loss: -1.0599e+04 - val_loss: -1.0611e+04
# Epoch 17/100
# 0s - loss: -1.0633e+04 - val_loss: -1.0644e+04
# Epoch 18/100
# 0s - loss: -1.0650e+04 - val_loss: -1.0649e+04
# Epoch 19/100
# 0s - loss: -1.0666e+04 - val_loss: -1.0675e+04
# Epoch 20/100
# 0s - loss: -1.0697e+04 - val_loss: -1.0729e+04
# Epoch 21/100
# 0s - loss: -1.0745e+04 - val_loss: -1.0765e+04
# Epoch 22/100
# 0s - loss: -1.0775e+04 - val_loss: -1.0783e+04
# Epoch 23/100
# 0s - loss: -1.0796e+04 - val_loss: -1.0803e+04
# Epoch 24/100
# 0s - loss: -1.0823e+04 - val_loss: -1.0842e+04
# Epoch 25/100
# 0s - loss: -1.0858e+04 - val_loss: -1.0881e+04
# Epoch 26/100
# 0s - loss: -1.0893e+04 - val_loss: -1.0906e+04
# Epoch 27/100
# 0s - loss: -1.0909e+04 - val_loss: -1.0915e+04
# Epoch 28/100
# 0s - loss: -1.0915e+04 - val_loss: -1.0915e+04
# Epoch 29/100
# 0s - loss: -1.0926e+04 - val_loss: -1.0940e+04
# Epoch 30/100
# 0s - loss: -1.0941e+04 - val_loss: -1.0943e+04
# Epoch 31/100
# 0s - loss: -1.0956e+04 - val_loss: -1.0968e+04
# Epoch 32/100
# 0s - loss: -1.0975e+04 - val_loss: -1.0987e+04
# Epoch 33/100
# 0s - loss: -1.0994e+04 - val_loss: -1.1002e+04
# Epoch 34/100
# 0s - loss: -1.1011e+04 - val_loss: -1.1018e+04
# Epoch 35/100
# 0s - loss: -1.1019e+04 - val_loss: -1.1029e+04
# Epoch 36/100
# 0s - loss: -1.1031e+04 - val_loss: -1.1041e+04
# Epoch 37/100
# 0s - loss: -1.1054e+04 - val_loss: -1.1062e+04
# Epoch 38/100
# 0s - loss: -1.1072e+04 - val_loss: -1.1082e+04
# Epoch 39/100
# 0s - loss: -1.1082e+04 - val_loss: -1.1080e+04
# Epoch 40/100
# 0s - loss: -1.1088e+04 - val_loss: -1.1088e+04
# Epoch 41/100
# 0s - loss: -1.1095e+04 - val_loss: -1.1101e+04
# Epoch 42/100
# 0s - loss: -1.1109e+04 - val_loss: -1.1123e+04
# Epoch 43/100
# 0s - loss: -1.1128e+04 - val_loss: -1.1138e+04
# Epoch 44/100
# 0s - loss: -1.1148e+04 - val_loss: -1.1153e+04
# Epoch 45/100
# 0s - loss: -1.1157e+04 - val_loss: -1.1163e+04
# Epoch 46/100
# 0s - loss: -1.1172e+04 - val_loss: -1.1178e+04
# Epoch 47/100
# 0s - loss: -1.1184e+04 - val_loss: -1.1196e+04
# Epoch 48/100
# 0s - loss: -1.1205e+04 - val_loss: -1.1209e+04
# Epoch 49/100
# 0s - loss: -1.1216e+04 - val_loss: -1.1220e+04
# Epoch 50/100
# 0s - loss: -1.1229e+04 - val_loss: -1.1232e+04
# Epoch 51/100
# 0s - loss: -1.1233e+04 - val_loss: -1.1241e+04
# Epoch 52/100
# 0s - loss: -1.1244e+04 - val_loss: -1.1252e+04
# Epoch 53/100
# 0s - loss: -1.1262e+04 - val_loss: -1.1265e+04
# Epoch 54/100
# 0s - loss: -1.1271e+04 - val_loss: -1.1280e+04
# Epoch 55/100
# 0s - loss: -1.1284e+04 - val_loss: -1.1289e+04
# Epoch 56/100
# 0s - loss: -1.1290e+04 - val_loss: -1.1296e+04
# Epoch 57/100
# 0s - loss: -1.1306e+04 - val_loss: -1.1310e+04
# Epoch 58/100
# 0s - loss: -1.1310e+04 - val_loss: -1.1312e+04
# Epoch 59/100
# 0s - loss: -1.1313e+04 - val_loss: -1.1318e+04
# Epoch 60/100
# 0s - loss: -1.1330e+04 - val_loss: -1.1338e+04
# Epoch 61/100
# 0s - loss: -1.1338e+04 - val_loss: -1.1342e+04
# Epoch 62/100
# 0s - loss: -1.1348e+04 - val_loss: -1.1358e+04
# Epoch 63/100
# 0s - loss: -1.1365e+04 - val_loss: -1.1366e+04
# Epoch 64/100
# 0s - loss: -1.1366e+04 - val_loss: -1.1367e+04
# Epoch 65/100
# 0s - loss: -1.1368e+04 - val_loss: -1.1370e+04
# Epoch 66/100
# 0s - loss: -1.1369e+04 - val_loss: -1.1372e+04
# Epoch 67/100
# 0s - loss: -1.1377e+04 - val_loss: -1.1380e+04
# Epoch 68/100
# 0s - loss: -1.1388e+04 - val_loss: -1.1391e+04
# Epoch 69/100
# 0s - loss: -1.1396e+04 - val_loss: -1.1402e+04
# Epoch 70/100
# 0s - loss: -1.1408e+04 - val_loss: -1.1417e+04
# Epoch 71/100
# 0s - loss: -1.1423e+04 - val_loss: -1.1430e+04
# Epoch 72/100
# 0s - loss: -1.1430e+04 - val_loss: -1.1431e+04
# Epoch 73/100
# 0s - loss: -1.1435e+04 - val_loss: -1.1439e+04
# Epoch 74/100
# 0s - loss: -1.1443e+04 - val_loss: -1.1447e+04
# Epoch 75/100
# 0s - loss: -1.1446e+04 - val_loss: -1.1446e+04
# Epoch 76/100
# 0s - loss: -1.1448e+04 - val_loss: -1.1446e+04
# Epoch 77/100
# 0s - loss: -1.1448e+04 - val_loss: -1.1449e+04
# Epoch 78/100
# 0s - loss: -1.1449e+04 - val_loss: -1.1449e+04
# Epoch 79/100
# 0s - loss: -1.1449e+04 - val_loss: -1.1449e+04
# Epoch 80/100
# 0s - loss: -1.1450e+04 - val_loss: -1.1450e+04
# Epoch 81/100
# 0s - loss: -1.1455e+04 - val_loss: -1.1459e+04
# Epoch 82/100
# 0s - loss: -1.1460e+04 - val_loss: -1.1461e+04
# Epoch 83/100
# 0s - loss: -1.1475e+04 - val_loss: -1.1483e+04
# Epoch 84/100
# 0s - loss: -1.1485e+04 - val_loss: -1.1492e+04
# Epoch 85/100
# 0s - loss: -1.1498e+04 - val_loss: -1.1505e+04
# Epoch 86/100
# 0s - loss: -1.1505e+04 - val_loss: -1.1506e+04
# Epoch 87/100
# 0s - loss: -1.1506e+04 - val_loss: -1.1507e+04
# Epoch 88/100
# 0s - loss: -1.1507e+04 - val_loss: -1.1507e+04
# Epoch 89/100
# 0s - loss: -1.1507e+04 - val_loss: -1.1508e+04
# Epoch 90/100
# 0s - loss: -1.1513e+04 - val_loss: -1.1523e+04
# Epoch 91/100
# 0s - loss: -1.1527e+04 - val_loss: -1.1531e+04
# Epoch 92/100
# 0s - loss: -1.1532e+04 - val_loss: -1.1533e+04
# Epoch 93/100
# 0s - loss: -1.1533e+04 - val_loss: -1.1529e+04
# Epoch 94/100
# 0s - loss: -1.1533e+04 - val_loss: -1.1535e+04
# Epoch 95/100
# 0s - loss: -1.1536e+04 - val_loss: -1.1543e+04
# Epoch 96/100
# 0s - loss: -1.1544e+04 - val_loss: -1.1551e+04
# Epoch 97/100
# 0s - loss: -1.1557e+04 - val_loss: -1.1559e+04
# Epoch 98/100
# 0s - loss: -1.1564e+04 - val_loss: -1.1565e+04
# Epoch 99/100
# 0s - loss: -1.1565e+04 - val_loss: -1.1566e+04
# Epoch 100/100
# 0s - loss: -1.1566e+04 - val_loss: -1.1568e+04
# hiden node = 16
# Train on 1983 samples, validate on 1983 samples
# Epoch 1/100
# 0s - loss: 47.0152 - val_loss: 12.0742
# Epoch 2/100
# 0s - loss: 11.9983 - val_loss: 11.7854
# Epoch 3/100
# 0s - loss: 0.8805 - val_loss: -4.3170e+01
# Epoch 4/100
# 0s - loss: -4.0216e+01 - val_loss: 5.8801
# Epoch 5/100
# 0s - loss: -1.4113e+01 - val_loss: -1.1044e+02
# Epoch 6/100
# 0s - loss: -2.2238e+01 - val_loss: 13.0094
# Epoch 7/100
# 0s - loss: 11.9038 - val_loss: 6.0978
# Epoch 8/100
# 0s - loss: -2.9109e+00 - val_loss: -1.5961e+01
# Epoch 9/100
# 0s - loss: -3.0771e+01 - val_loss: -6.6504e+01
# Epoch 10/100
# 0s - loss: -6.6460e+01 - val_loss: -1.0836e+01
# Epoch 11/100
# 0s - loss: 7.8655 - val_loss: 4.8044
# AccX is registed now
# AccY is registed now
# AccZ is registed now
# Build Complete
# (254742, 3)
# windowData's num =988
# SourceData's aborting data = 22
# window shape is (988, 2048, 3)
# (988, 2048, 3)
# hiden node = 16
# Train on 988 samples, validate on 988 samples
# Epoch 1/100
# 0s - loss: -6.9861e+03 - val_loss: -7.6244e+03
# Epoch 2/100
# 0s - loss: -7.7727e+03 - val_loss: -8.0305e+03
# Epoch 3/100
# 0s - loss: -8.1537e+03 - val_loss: -8.3300e+03
# Epoch 4/100
# 0s - loss: -8.3992e+03 - val_loss: -8.5165e+03
# Epoch 5/100
# 0s - loss: -8.5503e+03 - val_loss: -8.6099e+03
# Epoch 6/100
# 0s - loss: -8.6397e+03 - val_loss: -8.6825e+03
# Epoch 7/100
# 0s - loss: -8.7038e+03 - val_loss: -8.7359e+03
# Epoch 8/100
# 0s - loss: -8.7495e+03 - val_loss: -8.7792e+03
# Epoch 9/100
# 0s - loss: -8.7938e+03 - val_loss: -8.8160e+03
# Epoch 10/100
# 0s - loss: -8.8282e+03 - val_loss: -8.8540e+03
# Epoch 11/100
# 0s - loss: -8.8644e+03 - val_loss: -8.8846e+03
# Epoch 12/100
# 0s - loss: -8.8963e+03 - val_loss: -8.9132e+03
# Epoch 13/100
# 0s - loss: -8.9192e+03 - val_loss: -8.9358e+03
# Epoch 14/100
# 0s - loss: -8.9431e+03 - val_loss: -8.9557e+03
# Epoch 15/100
# 0s - loss: -8.9645e+03 - val_loss: -8.9854e+03
# Epoch 16/100
# 0s - loss: -8.9941e+03 - val_loss: -9.0078e+03
# Epoch 17/100
# 0s - loss: -9.0194e+03 - val_loss: -9.0334e+03
# Epoch 18/100
# 0s - loss: -9.0431e+03 - val_loss: -9.0637e+03
# Epoch 19/100
# 0s - loss: -9.0706e+03 - val_loss: -9.0763e+03
# Epoch 20/100
# 0s - loss: -9.0818e+03 - val_loss: -9.0944e+03
# Epoch 21/100
# 0s - loss: -9.1022e+03 - val_loss: -9.1165e+03
# Epoch 22/100
# 0s - loss: -9.1253e+03 - val_loss: -9.1442e+03
# Epoch 23/100
# 0s - loss: -9.1501e+03 - val_loss: -9.1609e+03
# Epoch 24/100
# 0s - loss: -9.1673e+03 - val_loss: -9.1794e+03
# Epoch 25/100
# 0s - loss: -9.1865e+03 - val_loss: -9.1986e+03
# Epoch 26/100
# 0s - loss: -9.2035e+03 - val_loss: -9.2151e+03
# Epoch 27/100
# 0s - loss: -9.2277e+03 - val_loss: -9.2414e+03
# Epoch 28/100
# 0s - loss: -9.2461e+03 - val_loss: -9.2564e+03
# Epoch 29/100
# 0s - loss: -9.2627e+03 - val_loss: -9.2755e+03
# Epoch 30/100
# 0s - loss: -9.2845e+03 - val_loss: -9.2980e+03
# Epoch 31/100
# 0s - loss: -9.3039e+03 - val_loss: -9.3168e+03
# Epoch 32/100
# 0s - loss: -9.3203e+03 - val_loss: -9.3310e+03
# Epoch 33/100
# 0s - loss: -9.3358e+03 - val_loss: -9.3482e+03
# Epoch 34/100
# 0s - loss: -9.3519e+03 - val_loss: -9.3621e+03
# Epoch 35/100
# 0s - loss: -9.3711e+03 - val_loss: -9.3794e+03
# Epoch 36/100
# 0s - loss: -9.3815e+03 - val_loss: -9.3963e+03
# Epoch 37/100
# 0s - loss: -9.4012e+03 - val_loss: -9.4138e+03
# Epoch 38/100
# 0s - loss: -9.4257e+03 - val_loss: -9.4332e+03
# Epoch 39/100
# 0s - loss: -9.4414e+03 - val_loss: -9.4530e+03
# Epoch 40/100
# 0s - loss: -9.4383e+03 - val_loss: -9.3959e+03
# Epoch 41/100
# 0s - loss: -9.4411e+03 - val_loss: -9.4644e+03
# Epoch 42/100
# 0s - loss: -9.4738e+03 - val_loss: -9.4837e+03
# Epoch 43/100
# 0s - loss: -9.4878e+03 - val_loss: -9.4924e+03
# Epoch 44/100
# 0s - loss: -9.4954e+03 - val_loss: -9.5087e+03
# Epoch 45/100
# 0s - loss: -9.5151e+03 - val_loss: -9.5273e+03
# Epoch 46/100
# 0s - loss: -9.5319e+03 - val_loss: -9.5389e+03
# Epoch 47/100
# 0s - loss: -9.5394e+03 - val_loss: -9.5424e+03
# Epoch 48/100
# 0s - loss: -9.5454e+03 - val_loss: -9.5571e+03
# Epoch 49/100
# 0s - loss: -9.5611e+03 - val_loss: -9.5733e+03
# Epoch 50/100
# 0s - loss: -9.5780e+03 - val_loss: -9.5886e+03
# Epoch 51/100
# 0s - loss: -9.5936e+03 - val_loss: -9.6016e+03
# Epoch 52/100
# 0s - loss: -9.6038e+03 - val_loss: -9.6085e+03
# Epoch 53/100
# 0s - loss: -9.6107e+03 - val_loss: -9.6136e+03
# Epoch 54/100
# 0s - loss: -9.6176e+03 - val_loss: -9.6214e+03
# Epoch 55/100
# 0s - loss: -9.6262e+03 - val_loss: -9.6349e+03
# Epoch 56/100
# 0s - loss: -9.6373e+03 - val_loss: -9.6364e+03
# Epoch 57/100
# 0s - loss: -9.6399e+03 - val_loss: -9.6541e+03
# Epoch 58/100
# 0s - loss: -9.6582e+03 - val_loss: -9.6637e+03
# Epoch 59/100
# 0s - loss: -9.6668e+03 - val_loss: -9.6700e+03
# Epoch 60/100
# 0s - loss: -9.6731e+03 - val_loss: -9.6754e+03
# Epoch 61/100
# 0s - loss: -9.6782e+03 - val_loss: -9.6800e+03
# Epoch 62/100
# 0s - loss: -9.6831e+03 - val_loss: -9.6903e+03
# Epoch 63/100
# 0s - loss: -9.6945e+03 - val_loss: -9.6971e+03
# Epoch 64/100
# 0s - loss: -9.7037e+03 - val_loss: -9.7105e+03
# Epoch 65/100
# 0s - loss: -9.7112e+03 - val_loss: -9.7004e+03
# Epoch 66/100
# 0s - loss: -9.7118e+03 - val_loss: -9.7176e+03
# Epoch 67/100
# 0s - loss: -9.7176e+03 - val_loss: -9.7206e+03
# Epoch 68/100
# 0s - loss: -9.7210e+03 - val_loss: -9.7256e+03
# Epoch 69/100
# 0s - loss: -9.7274e+03 - val_loss: -9.7296e+03
# Epoch 70/100
# 0s - loss: -9.7324e+03 - val_loss: -9.7335e+03
# Epoch 71/100
# 0s - loss: -9.7347e+03 - val_loss: -9.7350e+03
# Epoch 72/100
# 0s - loss: -9.7408e+03 - val_loss: -9.7455e+03
# Epoch 73/100
# 0s - loss: -9.7477e+03 - val_loss: -9.7563e+03
# Epoch 74/100
# 0s - loss: -9.7582e+03 - val_loss: -9.7640e+03
# Epoch 75/100
# 0s - loss: -9.7645e+03 - val_loss: -9.7667e+03
# Epoch 76/100
# 0s - loss: -9.7677e+03 - val_loss: -9.7722e+03
# Epoch 77/100
# 0s - loss: -9.7737e+03 - val_loss: -9.7716e+03
# Epoch 78/100
# 0s - loss: -9.7780e+03 - val_loss: -9.7822e+03
# Epoch 79/100
# 0s - loss: -9.7850e+03 - val_loss: -9.7859e+03
# Epoch 80/100
# 0s - loss: -9.7874e+03 - val_loss: -9.7880e+03
# Epoch 81/100
# 0s - loss: -9.7879e+03 - val_loss: -9.7898e+03
# Epoch 82/100
# 0s - loss: -9.7905e+03 - val_loss: -9.7915e+03
# Epoch 83/100
# 0s - loss: -9.7943e+03 - val_loss: -9.7977e+03
# Epoch 84/100
# 0s - loss: -9.7997e+03 - val_loss: -9.8001e+03
# Epoch 85/100
# 0s - loss: -9.8029e+03 - val_loss: -9.8064e+03
# Epoch 86/100
# 0s - loss: -9.8071e+03 - val_loss: -9.8128e+03
# Epoch 87/100
# 0s - loss: -9.8196e+03 - val_loss: -9.8274e+03
# Epoch 88/100
# 0s - loss: -9.8277e+03 - val_loss: -9.8305e+03
# Epoch 89/100
# 0s - loss: -9.8321e+03 - val_loss: -9.8362e+03
# Epoch 90/100
# 0s - loss: -9.8384e+03 - val_loss: -9.8396e+03
# Epoch 91/100
# 0s - loss: -9.8422e+03 - val_loss: -9.8499e+03
# Epoch 92/100
# 0s - loss: -9.8499e+03 - val_loss: -9.8540e+03
# Epoch 93/100
# 0s - loss: -9.8563e+03 - val_loss: -9.8601e+03
# Epoch 94/100
# 0s - loss: -9.8623e+03 - val_loss: -9.8667e+03
# Epoch 95/100
# 0s - loss: -9.8706e+03 - val_loss: -9.8727e+03
# Epoch 96/100
# 0s - loss: -9.8734e+03 - val_loss: -9.8760e+03
# Epoch 97/100
# 0s - loss: -9.8763e+03 - val_loss: -9.8647e+03
# Epoch 98/100
# 0s - loss: -9.8767e+03 - val_loss: -9.8869e+03
# Epoch 99/100
# 0s - loss: -9.8872e+03 - val_loss: -9.8903e+03
# Epoch 100/100
# 0s - loss: -9.8902e+03 - val_loss: -9.8875e+03
# hiden node = 16
# Train on 988 samples, validate on 988 samples
# Epoch 1/100
# 0s - loss: -1.6407e+04 - val_loss: -1.7197e+04
# Epoch 2/100
# 0s - loss: -1.7365e+04 - val_loss: -1.7827e+04
# Epoch 3/100
# 0s - loss: -1.7968e+04 - val_loss: -1.8203e+04
# Epoch 4/100
# 0s - loss: -1.8277e+04 - val_loss: -1.8384e+04
# Epoch 5/100
# 0s - loss: -1.8431e+04 - val_loss: -1.8502e+04
# Epoch 6/100
# 0s - loss: -1.8537e+04 - val_loss: -1.8604e+04
# Epoch 7/100
# 0s - loss: -1.8644e+04 - val_loss: -1.8731e+04
# Epoch 8/100
# 0s - loss: -1.8768e+04 - val_loss: -1.8823e+04
# Epoch 9/100
# 0s - loss: -1.8855e+04 - val_loss: -1.8895e+04
# Epoch 10/100
# 0s - loss: -1.8931e+04 - val_loss: -1.9003e+04
# Epoch 11/100
# 0s - loss: -1.9028e+04 - val_loss: -1.9085e+04
# Epoch 12/100
# 0s - loss: -1.9118e+04 - val_loss: -1.9160e+04
# Epoch 13/100
# 0s - loss: -1.9186e+04 - val_loss: -1.9245e+04
# Epoch 14/100
# 0s - loss: -1.9276e+04 - val_loss: -1.9331e+04
# Epoch 15/100
# 0s - loss: -1.9359e+04 - val_loss: -1.9393e+04
# Epoch 16/100
# 0s - loss: -1.9413e+04 - val_loss: -1.9451e+04
# Epoch 17/100
# 0s - loss: -1.9476e+04 - val_loss: -1.9530e+04
# Epoch 18/100
# 0s - loss: -1.9560e+04 - val_loss: -1.9608e+04
# Epoch 19/100
# 0s - loss: -1.9638e+04 - val_loss: -1.9697e+04
# Epoch 20/100
# 0s - loss: -1.9711e+04 - val_loss: -1.9748e+04
# Epoch 21/100
# 0s - loss: -1.9770e+04 - val_loss: -1.9813e+04
# Epoch 22/100
# 0s - loss: -1.9838e+04 - val_loss: -1.9865e+04
# Epoch 23/100
# 0s - loss: -1.9886e+04 - val_loss: -1.9909e+04
# Epoch 24/100
# 0s - loss: -1.9931e+04 - val_loss: -1.9950e+04
# Epoch 25/100
# 0s - loss: -1.9968e+04 - val_loss: -2.0004e+04
# Epoch 26/100
# 0s - loss: -2.0027e+04 - val_loss: -2.0053e+04
# Epoch 27/100
# 0s - loss: -2.0067e+04 - val_loss: -2.0112e+04
# Epoch 28/100
# 0s - loss: -2.0129e+04 - val_loss: -2.0162e+04
# Epoch 29/100
# 0s - loss: -2.0179e+04 - val_loss: -2.0203e+04
# Epoch 30/100
# 0s - loss: -2.0217e+04 - val_loss: -2.0234e+04
# Epoch 31/100
# 0s - loss: -2.0254e+04 - val_loss: -2.0280e+04
# Epoch 32/100
# 0s - loss: -2.0296e+04 - val_loss: -2.0324e+04
# Epoch 33/100
# 0s - loss: -2.0333e+04 - val_loss: -2.0350e+04
# Epoch 34/100
# 0s - loss: -2.0361e+04 - val_loss: -2.0394e+04
# Epoch 35/100
# 0s - loss: -2.0419e+04 - val_loss: -2.0472e+04
# Epoch 36/100
# 0s - loss: -2.0480e+04 - val_loss: -2.0499e+04
# Epoch 37/100
# 0s - loss: -2.0507e+04 - val_loss: -2.0522e+04
# Epoch 38/100
# 0s - loss: -2.0535e+04 - val_loss: -2.0561e+04
# Epoch 39/100
# 0s - loss: -2.0574e+04 - val_loss: -2.0599e+04
# Epoch 40/100
# 0s - loss: -2.0620e+04 - val_loss: -2.0636e+04
# Epoch 41/100
# 0s - loss: -2.0657e+04 - val_loss: -2.0691e+04
# Epoch 42/100
# 0s - loss: -2.0705e+04 - val_loss: -2.0735e+04
# Epoch 43/100
# 0s - loss: -2.0756e+04 - val_loss: -2.0785e+04
# Epoch 44/100
# 0s - loss: -2.0794e+04 - val_loss: -2.0802e+04
# Epoch 45/100
# 0s - loss: -2.0804e+04 - val_loss: -2.0821e+04
# Epoch 46/100
# 0s - loss: -2.0827e+04 - val_loss: -2.0838e+04
# Epoch 47/100
# 0s - loss: -2.0847e+04 - val_loss: -2.0856e+04
# Epoch 48/100
# 0s - loss: -2.0863e+04 - val_loss: -2.0882e+04
# Epoch 49/100
# 0s - loss: -2.0903e+04 - val_loss: -2.0924e+04
# Epoch 50/100
# 0s - loss: -2.0932e+04 - val_loss: -2.0962e+04
# Epoch 51/100
# 0s - loss: -2.0972e+04 - val_loss: -2.0989e+04
# Epoch 52/100
# 0s - loss: -2.0997e+04 - val_loss: -2.1008e+04
# Epoch 53/100
# 0s - loss: -2.1024e+04 - val_loss: -2.1035e+04
# Epoch 54/100
# 0s - loss: -2.1044e+04 - val_loss: -2.1058e+04
# Epoch 55/100
# 0s - loss: -2.1067e+04 - val_loss: -2.1089e+04
# Epoch 56/100
# 0s - loss: -2.1094e+04 - val_loss: -2.1115e+04
# Epoch 57/100
# 0s - loss: -2.1125e+04 - val_loss: -2.1150e+04
# Epoch 58/100
# 0s - loss: -2.1159e+04 - val_loss: -2.1172e+04
# Epoch 59/100
# 0s - loss: -2.1182e+04 - val_loss: -2.1197e+04
# Epoch 60/100
# 0s - loss: -2.1206e+04 - val_loss: -2.1239e+04
# Epoch 61/100
# 0s - loss: -2.1245e+04 - val_loss: -2.1264e+04
# Epoch 62/100
# 0s - loss: -2.1272e+04 - val_loss: -2.1285e+04
# Epoch 63/100
# 0s - loss: -2.1299e+04 - val_loss: -2.1317e+04
# Epoch 64/100
# 0s - loss: -2.1318e+04 - val_loss: -2.1323e+04
# Epoch 65/100
# 0s - loss: -2.1332e+04 - val_loss: -2.0940e+04
# Epoch 66/100
# 0s - loss: -2.1117e+04 - val_loss: -2.1321e+04
# Epoch 67/100
# 0s - loss: -2.1322e+04 - val_loss: -2.1310e+04
# Epoch 68/100
# 0s - loss: -2.1322e+04 - val_loss: -2.1331e+04
# Epoch 69/100
# 0s - loss: -2.1331e+04 - val_loss: -2.1322e+04
# Epoch 70/100
# 0s - loss: -2.1323e+04 - val_loss: -2.1321e+04
# Epoch 71/100
# 0s - loss: -2.1320e+04 - val_loss: -2.1310e+04
# Epoch 72/100
# 0s - loss: -2.1330e+04 - val_loss: -2.1336e+04
# Epoch 73/100
# 0s - loss: -2.1349e+04 - val_loss: -2.1353e+04
# Epoch 74/100
# 0s - loss: -2.1348e+04 - val_loss: -2.1339e+04
# Epoch 75/100
# 0s - loss: -2.1351e+04 - val_loss: -2.1353e+04
# Epoch 76/100
# 0s - loss: -2.1366e+04 - val_loss: -2.1372e+04
# Epoch 77/100
# 0s - loss: -2.1367e+04 - val_loss: -2.1367e+04
# Epoch 78/100
# 0s - loss: -2.1375e+04 - val_loss: -2.1369e+04
# Epoch 79/100
# 0s - loss: -2.1378e+04 - val_loss: -2.1383e+04
# Epoch 80/100
# 0s - loss: -2.1392e+04 - val_loss: -2.1400e+04
# Epoch 81/100
# 0s - loss: -2.1397e+04 - val_loss: -2.1391e+04
# Epoch 82/100
# 0s - loss: -2.1388e+04 - val_loss: -2.1415e+04
# Epoch 83/100
# 0s - loss: -2.1415e+04 - val_loss: -2.1420e+04
# Epoch 84/100
# 0s - loss: -2.1413e+04 - val_loss: -2.1425e+04
# Epoch 85/100
# 0s - loss: -2.1422e+04 - val_loss: -2.1418e+04
# Epoch 86/100
# 0s - loss: -2.1431e+04 - val_loss: -2.1436e+04
# Epoch 87/100
# 0s - loss: -2.1442e+04 - val_loss: -2.1455e+04
# Epoch 88/100
# 0s - loss: -2.1452e+04 - val_loss: -2.1443e+04
# Epoch 89/100
# 0s - loss: -2.1454e+04 - val_loss: -2.1463e+04
# Epoch 90/100
# 0s - loss: -2.1462e+04 - val_loss: -2.1461e+04
# Epoch 91/100
# 0s - loss: -2.1468e+04 - val_loss: -2.1478e+04
# Epoch 92/100
# 0s - loss: -2.1478e+04 - val_loss: -2.1477e+04
# Epoch 93/100
# 0s - loss: -2.1479e+04 - val_loss: -2.1481e+04
# Epoch 94/100
# 0s - loss: -2.1489e+04 - val_loss: -2.1492e+04
# Epoch 95/100
# 0s - loss: -2.1498e+04 - val_loss: -2.1501e+04
# Epoch 96/100
# 0s - loss: -2.1505e+04 - val_loss: -2.1515e+04
# Epoch 97/100
# 0s - loss: -2.1519e+04 - val_loss: -2.1519e+04
# Epoch 98/100
# 0s - loss: -2.1523e+04 - val_loss: -2.1526e+04
# Epoch 99/100
# 0s - loss: -2.1534e+04 - val_loss: -2.1542e+04
# Epoch 100/100
# 0s - loss: -2.1540e+04 - val_loss: -2.1540e+04
# hiden node = 16
# Train on 988 samples, validate on 988 samples
# Epoch 1/100
# 0s - loss: 122.0405 - val_loss: 103.0038
# Epoch 2/100
# 0s - loss: 98.0971 - val_loss: 85.2929
# Epoch 3/100
# 0s - loss: 80.2152 - val_loss: 71.8590
# Epoch 4/100
# 0s - loss: 67.6918 - val_loss: 59.1584
# Epoch 5/100
# 0s - loss: 55.3353 - val_loss: 46.6102
# Epoch 6/100
# 0s - loss: 42.6184 - val_loss: 32.4629
# Epoch 7/100
# 0s - loss: 28.0616 - val_loss: 19.1438
# Epoch 8/100
# 0s - loss: 14.5206 - val_loss: 3.9342
# Epoch 9/100
# 0s - loss: -1.5576e+00 - val_loss: -1.2865e+01
# Epoch 10/100
# 0s - loss: -1.8957e+01 - val_loss: -3.2306e+01
# Epoch 11/100
# 0s - loss: -3.8978e+01 - val_loss: -5.0800e+01
# Epoch 12/100
# 0s - loss: -5.6219e+01 - val_loss: -6.7220e+01
# Epoch 13/100
# 0s - loss: -7.4353e+01 - val_loss: -8.9322e+01
# Epoch 14/100
# 0s - loss: -9.5565e+01 - val_loss: -1.0803e+02
# Epoch 15/100
# 0s - loss: -1.1366e+02 - val_loss: -1.2622e+02
# Epoch 16/100
# 0s - loss: -1.3515e+02 - val_loss: -1.5072e+02
# Epoch 17/100
# 0s - loss: -1.5615e+02 - val_loss: -1.6816e+02
# Epoch 18/100
# 0s - loss: -1.7545e+02 - val_loss: -1.8974e+02
# Epoch 19/100
# 0s - loss: -1.9985e+02 - val_loss: -2.1280e+02
# Epoch 20/100
# 0s - loss: -2.1901e+02 - val_loss: -2.3029e+02
# Epoch 21/100
# 0s - loss: -2.3739e+02 - val_loss: -2.4762e+02
# Epoch 22/100
# 0s - loss: -2.5219e+02 - val_loss: -2.6534e+02
# Epoch 23/100
# 0s - loss: -2.7079e+02 - val_loss: -2.8063e+02
# Epoch 24/100
# 0s - loss: -2.8405e+02 - val_loss: -2.9224e+02
# Epoch 25/100
# 0s - loss: -2.9561e+02 - val_loss: -3.0333e+02
# Epoch 26/100
# 0s - loss: -3.0697e+02 - val_loss: -3.1302e+02
# Epoch 27/100
# 0s - loss: -3.1754e+02 - val_loss: -3.2678e+02
# Epoch 28/100
# 0s - loss: -3.2817e+02 - val_loss: -3.3335e+02
# Epoch 29/100
# 0s - loss: -3.3731e+02 - val_loss: -3.4334e+02
# Epoch 30/100
# 0s - loss: -3.4555e+02 - val_loss: -3.4965e+02
# Epoch 31/100
# 0s - loss: -3.5195e+02 - val_loss: -3.5695e+02
# Epoch 32/100
# 0s - loss: -3.5566e+02 - val_loss: -3.6188e+02
# Epoch 33/100
# 0s - loss: -3.6420e+02 - val_loss: -3.6617e+02
# Epoch 34/100
# 0s - loss: -3.6628e+02 - val_loss: -3.7145e+02
# Epoch 35/100
# 0s - loss: -3.7510e+02 - val_loss: -3.8089e+02
# Epoch 36/100
# 0s - loss: -3.8326e+02 - val_loss: -3.8727e+02
# Epoch 37/100
# 0s - loss: -3.8979e+02 - val_loss: -3.9471e+02
# Epoch 38/100
# 0s - loss: -3.9651e+02 - val_loss: -3.9665e+02
# Epoch 39/100
# 0s - loss: -3.9903e+02 - val_loss: -4.0311e+02
# Epoch 40/100
# 0s - loss: -4.0419e+02 - val_loss: -4.0658e+02
# Epoch 41/100
# 0s - loss: -4.0569e+02 - val_loss: -4.0419e+02
# Epoch 42/100
# 0s - loss: -4.0970e+02 - val_loss: -4.1873e+02
# Epoch 43/100
# 0s - loss: -4.1771e+02 - val_loss: -4.1533e+02
# Epoch 44/100
# 0s - loss: -4.1786e+02 - val_loss: -4.2025e+02
# Epoch 45/100
# 0s - loss: -4.2199e+02 - val_loss: -4.2395e+02
# Epoch 46/100
# 0s - loss: -4.2701e+02 - val_loss: -4.2778e+02
# Epoch 47/100
# 0s - loss: -4.2521e+02 - val_loss: -4.1800e+02
# Epoch 48/100
# 0s - loss: -4.1628e+02 - val_loss: -4.1713e+02
# Epoch 49/100
# 0s - loss: -4.1589e+02 - val_loss: -4.0992e+02
# Epoch 50/100
# 0s - loss: -4.1022e+02 - val_loss: -4.1299e+02
# Epoch 51/100
# 0s - loss: -4.1238e+02 - val_loss: -4.1127e+02
# Epoch 52/100
# 0s - loss: -4.1216e+02 - val_loss: -4.1711e+02

# %%
print "finish
# Out:
#   File "<ipython-input-8-ff76b7c1dbed>", line 1
#     print "finish
#                 ^
# SyntaxError: EOL while scanning string literal
