# %%
SensorNum=1 # Sensor number
WindowWidth=[128,256,512,1024,2048,4096] # Window Width
OverlapArray=[16,32,64,128,256] # sliding window
#width=1000 # graph width 
#EncodingDim=[4,8,12,16,32,64] # number of hidden layer note
encoding_dim=16
Axis='AccY' # Axis

WORKSPACE_PATH = "/media/takeyama/HD-PZU3/01_TAKEYAMA_WORKSPACE/02_CommonData"
DATE_PATH="/2016-08-15/"
TITLE_PATH="Sparse/"

# %%
import numpy as np
import pandas as pd
from scipy import fftpack
from scipy import signal
import time
import os
import matplotlib.pyplot as plt
import pylab
import pickle
import copy

import processing
import window

import matplotlib.animation as animation
import datetime

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras import regularizers

import matplotlib.image as mpimg
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5005)

# %%
DataName='sensor'+str(SensorNum)+'_'+Axis
SensorName='sensor'+str(SensorNum)
DicName='MemSensor'+str(SensorNum)

# %%
# define rawdata directory
if not os.path.exists(WORKSPACE_PATH+"/raw/"):
    os.makedirs(WORKSPACE_PATH+"/raw/")
RawDataPath=WORKSPACE_PATH+"/raw/"

# define restoring windowdata directory
if not os.path.exists(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/')
WindowDataPath=WORKSPACE_PATH+'/window/'+TITLE_PATH+DataName+'/'

# define restoring netowrk model picture's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/')
StudyDataModelPicPath=WORKSPACE_PATH+DATE_PATH+'/modelPic/'+TITLE_PATH+DataName+'/'

# define restoring graph data's directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/')
GlaphDataPath=WORKSPACE_PATH+DATE_PATH+'/graph/'+TITLE_PATH+DataName+'/'

# define restoring model paarmeter directory
if not os.path.exists(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'): 
    os.makedirs(WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/')
StudyDataPath=WORKSPACE_PATH+DATE_PATH+'/study/'+TITLE_PATH+DataName+'/'

# %% [markdown]
# **Phase1 計測データの取得**

# %%
dic=processing.LoadDicDataFromFileNPZ(RawDataPath+DicName)

# %% [markdown]
# **Phase2 window flame 作成 & Learning**

# %%
encoding_dim
# Out:
# 16

# %%
する# loop windowWidth
for SampleNum in WindowWidth:
    for Overlap in OverlapArray:

        w=window.Window()
        w.SetData(Axis,dic[Axis])
        wind=w.Compile(windowWidth=SampleNum,overlapNum=Overlap)
        windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
        print "hiden node = "+str(encoding_dim)
        CommonName='-edim='+str(encoding_dim)+'-Window='+str(SampleNum)+'-Overlap='+str(Overlap)+'-'+"l1_reg=1"
        print CommonName
        SaveFileNameEncord=DataName+'_encoded'+CommonName
        SaveFileNameDecord=DataName+'_decoded'+CommonName
        SaveFileNameNet=DataName+'_net'+CommonName
        SaveFileNameTrain=DataName+'_train'+CommonName
        SaveFileNameTest=DataName+'_test'+CommonName
        SaveFileNameGlaph=GlaphDataPath+DataName+CommonName+'_loss_val_loss.png'

        window_test=windoW
        window_train=windoW
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTrain,window_test)
        processing.SaveDicDataFromFileNPZ(WindowDataPath,SaveFileNameTest,window_test)
        shapeNum=windoW.shape[1]

        # this is our input placeholder
        input_img = Input(shape=(shapeNum,))
        # "encoded" is the encoded representation of the input
        encoded = Dense(encoding_dim, activation='tanh',
                    W_regularizer=regularizers.WeightRegularizer(l1=10e-5,l2=0.0))(input_img)
        # "decoded" is the lossy reconstruction of the input
        decoded = Dense(shapeNum, activation='linear')(encoded)

        # this model maps an input to its reconstruction
        autoencoder = Model(input=input_img, output=decoded)

        # this model maps an input to its encoded representation
        encoder = Model(input=input_img, output=encoded)

        # create a placeholder for an encoded (32-dimensional) input
        encoded_input = Input(shape=(encoding_dim,))
        # retrieve the last layer of the autoencoder model
        decoder_layer = autoencoder.layers[-1]
        # create the decoder model
        decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))
        
        #autoencoder.compile(optimizer='adam', loss='mse')
        autoencoder.compile(optimizer='adam', loss='categorical_crossentropy')
        
        plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')

        early_stopping = EarlyStopping(monitor='val_loss', patience=5)
        
        hist = autoencoder.fit(window_train, window_train,
                        nb_epoch=100,
                        verbose=2,
                        batch_size=shapeNum/8,
                        shuffle=True,
                        validation_data=(window_test, window_test)
                        ,callbacks=[early_stopping]
                              )
        time.sleep(0.1)
        encoded_imgs = encoder.predict(window_test)
        decoded_imgs = decoder.predict(encoded_imgs)

        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameEncord,encoded_imgs)
        processing.SaveDicDataFromFileNPZ(StudyDataPath,SaveFileNameDecord,decoded_imgs)

        # save model and wights
        json_string = encoder.to_json()
        open(StudyDataPath+SaveFileNameEncord+'.json', 'w').write(json_string)
        encoder.save_weights(StudyDataPath+SaveFileNameEncord+'_weights.h5',overwrite=True)

        json_string = decoder.to_json()
        open(StudyDataPath+SaveFileNameDecord+'.json', 'w').write(json_string)
        decoder.save_weights(StudyDataPath+SaveFileNameDecord+'_weights.h5',overwrite=True)

        json_string = autoencoder.to_json()
        open(StudyDataPath+SaveFileNameNet+'.json', 'w').write(json_string)
        autoencoder.save_weights(StudyDataPath+SaveFileNameNet+'_weights.h5',overwrite=True)

        # plot loss
        loss = hist.history['loss']
        val_loss = hist.history['val_loss']

        nb_epoch = len(loss)
        plt.plot(range(nb_epoch), loss, marker='.', label='loss')
        plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
        plt.legend(loc='best', fontsize=10)
        plt.grid()
        plt.xlabel('epoch')
        plt.ylabel('loss')
        plt.savefig(SaveFileNameGlaph)
        plt.show()
# Out:
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =15914
# SourceData's aborting data = 6
# window shape is (15914, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=16-l1_reg=10e-5
# Train on 15914 samples, validate on 15914 samples
# Epoch 1/100
# 2s - loss: -5.6049e+02 - val_loss: -6.1020e+02
# Epoch 2/100
# 3s - loss: -6.2286e+02 - val_loss: -6.3931e+02
# Epoch 3/100
# 3s - loss: -5.1132e+02 - val_loss: -5.3771e+02
# Epoch 4/100
# 3s - loss: -5.7623e+02 - val_loss: -5.9996e+02
# Epoch 5/100
# 3s - loss: -6.1742e+02 - val_loss: -6.3172e+02
# Epoch 6/100
# 3s - loss: -6.3337e+02 - val_loss: -6.3494e+02
# Epoch 7/100
# 3s - loss: -6.4217e+02 - val_loss: -6.5232e+02
# Epoch 8/100
# 3s - loss: -6.5666e+02 - val_loss: -6.6379e+02
# Epoch 9/100
# 3s - loss: -6.7183e+02 - val_loss: -6.8135e+02
# Epoch 10/100
# 3s - loss: -6.1129e+02 - val_loss: -5.8275e+02
# Epoch 11/100
# 3s - loss: -6.1142e+02 - val_loss: -6.2773e+02
# Epoch 12/100
# 4s - loss: -6.4118e+02 - val_loss: -6.4901e+02
# Epoch 13/100
# 4s - loss: -6.5180e+02 - val_loss: -6.6406e+02
# Epoch 14/100
# 4s - loss: -6.7140e+02 - val_loss: -6.7287e+02
# Epoch 15/100
# 4s - loss: -6.7583e+02 - val_loss: -6.7616e+02
# /home/takeyama/.pyenv/versions/2.7.11/envs/takeyama/lib/python2.7/site-packages/keras/backend/theano_backend.py:558: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 1 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =7957
# SourceData's aborting data = 22
# window shape is (7957, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=32-l1_reg=10e-5
# Train on 7957 samples, validate on 7957 samples
# Epoch 1/100
# 1s - loss: -5.4572e+02 - val_loss: -5.8749e+02
# Epoch 2/100
# 1s - loss: -5.9700e+02 - val_loss: -6.1465e+02
# Epoch 3/100
# 1s - loss: -6.2977e+02 - val_loss: -6.4683e+02
# Epoch 4/100
# 1s - loss: -6.4777e+02 - val_loss: -6.5292e+02
# Epoch 5/100
# 1s - loss: -5.8641e+02 - val_loss: -3.9384e+02
# Epoch 6/100
# 2s - loss: -4.6308e+02 - val_loss: -4.8979e+02
# Epoch 7/100
# 2s - loss: -5.1347e+02 - val_loss: -5.2594e+02
# Epoch 8/100
# 2s - loss: -5.4741e+02 - val_loss: -5.6064e+02
# Epoch 9/100
# 2s - loss: -5.9013e+02 - val_loss: -6.0990e+02
# Epoch 10/100
# 2s - loss: -6.2223e+02 - val_loss: -6.3784e+02
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =3979
# SourceData's aborting data = 22
# window shape is (3979, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=64-l1_reg=10e-5
# Train on 3979 samples, validate on 3979 samples
# Epoch 1/100
# 1s - loss: -4.9777e+02 - val_loss: -5.3010e+02
# Epoch 2/100
# 1s - loss: -5.4698e+02 - val_loss: -5.6479e+02
# Epoch 3/100
# 1s - loss: -5.7555e+02 - val_loss: -5.8557e+02
# Epoch 4/100
# 1s - loss: -5.8829e+02 - val_loss: -5.9353e+02
# Epoch 5/100
# 1s - loss: -6.1048e+02 - val_loss: -6.0770e+02
# Epoch 6/100
# 1s - loss: -6.1839e+02 - val_loss: -6.2345e+02
# Epoch 7/100
# 1s - loss: -6.2613e+02 - val_loss: -6.3121e+02
# Epoch 8/100
# 1s - loss: -6.3984e+02 - val_loss: -6.3975e+02
# Epoch 9/100
# 1s - loss: -6.4133e+02 - val_loss: -6.4252e+02
# Epoch 10/100
# 1s - loss: -6.4648e+02 - val_loss: -6.5165e+02
# Epoch 11/100
# 1s - loss: -6.5961e+02 - val_loss: -6.6381e+02
# Epoch 12/100
# 1s - loss: -6.6262e+02 - val_loss: -6.6382e+02
# Epoch 13/100
# 1s - loss: -6.6298e+02 - val_loss: -6.6641e+02
# Epoch 14/100
# 1s - loss: -6.6742e+02 - val_loss: -6.6502e+02
# Epoch 15/100
# 1s - loss: -6.7087e+02 - val_loss: -6.7304e+02
# Epoch 16/100
# 1s - loss: -6.7442e+02 - val_loss: -6.7690e+02
# Epoch 17/100
# 1s - loss: -6.7585e+02 - val_loss: -6.7585e+02
# Epoch 18/100
# 1s - loss: -6.7392e+02 - val_loss: -6.7408e+02
# Epoch 19/100
# 1s - loss: -6.7143e+02 - val_loss: -6.6440e+02
# Epoch 20/100
# 1s - loss: -4.2309e+02 - val_loss: -4.6183e+02
# Epoch 21/100
# 1s - loss: -4.8723e+02 - val_loss: -5.1125e+02
# Epoch 22/100
# 1s - loss: -5.2318e+02 - val_loss: -5.3827e+02
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =1990
# SourceData's aborting data = 22
# window shape is (1990, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=128-l1_reg=10e-5
# Train on 1990 samples, validate on 1990 samples
# Epoch 1/100
# 0s - loss: -4.8073e+02 - val_loss: -5.1062e+02
# Epoch 2/100
# 0s - loss: -5.2338e+02 - val_loss: -5.3086e+02
# Epoch 3/100
# 0s - loss: -5.4160e+02 - val_loss: -5.4926e+02
# Epoch 4/100
# 0s - loss: -5.5553e+02 - val_loss: -5.5944e+02
# Epoch 5/100
# 0s - loss: -5.6735e+02 - val_loss: -5.7153e+02
# Epoch 6/100
# 0s - loss: -5.7515e+02 - val_loss: -5.8120e+02
# Epoch 7/100
# 0s - loss: -5.8198e+02 - val_loss: -5.8292e+02
# Epoch 8/100
# 0s - loss: -5.9081e+02 - val_loss: -5.9476e+02
# Epoch 9/100
# 0s - loss: -5.9624e+02 - val_loss: -6.0074e+02
# Epoch 10/100
# 0s - loss: -6.0258e+02 - val_loss: -6.0421e+02
# Epoch 11/100
# 0s - loss: -6.0701e+02 - val_loss: -6.0768e+02
# Epoch 12/100
# 0s - loss: -6.1051e+02 - val_loss: -6.1137e+02
# Epoch 13/100
# 0s - loss: -6.1302e+02 - val_loss: -6.1589e+02
# Epoch 14/100
# 0s - loss: -6.1965e+02 - val_loss: -6.2392e+02
# Epoch 15/100
# 0s - loss: -6.2600e+02 - val_loss: -6.2699e+02
# Epoch 16/100
# 0s - loss: -6.2726e+02 - val_loss: -6.2820e+02
# Epoch 17/100
# 0s - loss: -6.3082e+02 - val_loss: -6.3345e+02
# Epoch 18/100
# 0s - loss: -6.3592e+02 - val_loss: -6.4195e+02
# Epoch 19/100
# 0s - loss: -6.4193e+02 - val_loss: -6.4088e+02
# Epoch 20/100
# 0s - loss: -6.4583e+02 - val_loss: -6.4689e+02
# Epoch 21/100
# 0s - loss: -6.4435e+02 - val_loss: -6.4782e+02
# Epoch 22/100
# 0s - loss: -6.5409e+02 - val_loss: -6.5708e+02
# Epoch 23/100
# 0s - loss: -6.5668e+02 - val_loss: -6.5679e+02
# Epoch 24/100
# 0s - loss: -6.5769e+02 - val_loss: -6.5989e+02
# Epoch 25/100
# 0s - loss: -6.6092e+02 - val_loss: -6.6185e+02
# Epoch 26/100
# 0s - loss: -6.6217e+02 - val_loss: -6.6229e+02
# Epoch 27/100
# 0s - loss: -6.5824e+02 - val_loss: -6.6126e+02
# Epoch 28/100
# 0s - loss: -6.6129e+02 - val_loss: -6.6091e+02
# Epoch 29/100
# 0s - loss: -6.5989e+02 - val_loss: -6.5879e+02
# Epoch 30/100
# 0s - loss: -6.5864e+02 - val_loss: -6.5349e+02
# Epoch 31/100
# 0s - loss: -6.5564e+02 - val_loss: -6.5654e+02
# Epoch 32/100
# 0s - loss: -6.5604e+02 - val_loss: -6.5206e+02
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =995
# SourceData's aborting data = 150
# window shape is (995, 128, 1)
# hiden node = 16
# -edim=16-Window=128-Overlap=256-l1_reg=10e-5
# Train on 995 samples, validate on 995 samples
# Epoch 1/100
# 0s - loss: -4.6024e+02 - val_loss: -5.0294e+02
# Epoch 2/100
# 0s - loss: -5.1897e+02 - val_loss: -5.2761e+02
# Epoch 3/100
# 0s - loss: -5.3107e+02 - val_loss: -5.3592e+02
# Epoch 4/100
# 0s - loss: -5.4870e+02 - val_loss: -5.6019e+02
# Epoch 5/100
# 0s - loss: -5.6243e+02 - val_loss: -5.6494e+02
# Epoch 6/100
# 0s - loss: -5.6943e+02 - val_loss: -5.7111e+02
# Epoch 7/100
# 0s - loss: -5.7502e+02 - val_loss: -5.7785e+02
# Epoch 8/100
# 0s - loss: -5.7895e+02 - val_loss: -5.8039e+02
# Epoch 9/100
# 0s - loss: -5.7982e+02 - val_loss: -5.8186e+02
# Epoch 10/100
# 0s - loss: -5.8230e+02 - val_loss: -5.8224e+02
# Epoch 11/100
# 0s - loss: -5.8481e+02 - val_loss: -5.8853e+02
# Epoch 12/100
# 0s - loss: -5.8986e+02 - val_loss: -5.9376e+02
# Epoch 13/100
# 0s - loss: -6.0592e+02 - val_loss: -6.1234e+02
# Epoch 14/100
# 0s - loss: -6.1364e+02 - val_loss: -6.1434e+02
# Epoch 15/100
# 0s - loss: -6.1654e+02 - val_loss: -6.1837e+02
# Epoch 16/100
# 0s - loss: -6.1475e+02 - val_loss: -6.1048e+02
# Epoch 17/100
# 0s - loss: -6.1205e+02 - val_loss: -6.1869e+02
# Epoch 18/100
# 0s - loss: -6.1750e+02 - val_loss: -6.2253e+02
# Epoch 19/100
# 0s - loss: -6.2410e+02 - val_loss: -6.2554e+02
# Epoch 20/100
# 0s - loss: -6.2948e+02 - val_loss: -6.3079e+02
# Epoch 21/100
# 0s - loss: -6.3525e+02 - val_loss: -6.4049e+02
# Epoch 22/100
# 0s - loss: -6.4243e+02 - val_loss: -6.4329e+02
# Epoch 23/100
# 0s - loss: -6.4289e+02 - val_loss: -6.4396e+02
# Epoch 24/100
# 0s - loss: -6.4406e+02 - val_loss: -6.4439e+02
# Epoch 25/100
# 0s - loss: -6.4433e+02 - val_loss: -6.4486e+02
# Epoch 26/100
# 0s - loss: -6.4842e+02 - val_loss: -6.4919e+02
# Epoch 27/100
# 0s - loss: -6.4947e+02 - val_loss: -6.5010e+02
# Epoch 28/100
# 0s - loss: -6.5218e+02 - val_loss: -6.5400e+02
# Epoch 29/100
# 0s - loss: -6.5413e+02 - val_loss: -6.5450e+02
# Epoch 30/100
# 0s - loss: -6.5441e+02 - val_loss: -6.5467e+02
# Epoch 31/100
# 0s - loss: -6.5550e+02 - val_loss: -6.5644e+02
# Epoch 32/100
# 0s - loss: -6.5542e+02 - val_loss: -6.5544e+02
# Epoch 33/100
# 0s - loss: -6.5607e+02 - val_loss: -6.6092e+02
# Epoch 34/100
# 0s - loss: -6.6033e+02 - val_loss: -6.6188e+02
# Epoch 35/100
# 0s - loss: -6.6556e+02 - val_loss: -6.6502e+02
# Epoch 36/100
# 0s - loss: -6.6576e+02 - val_loss: -6.6636e+02
# Epoch 37/100
# 0s - loss: -6.6301e+02 - val_loss: -6.6050e+02
# Epoch 38/100
# 0s - loss: -6.6262e+02 - val_loss: -6.6307e+02
# Epoch 39/100
# 0s - loss: -6.6284e+02 - val_loss: -6.6374e+02
# Epoch 40/100
# 0s - loss: -6.6404e+02 - val_loss: -6.6440e+02
# Epoch 41/100
# 0s - loss: -6.6485e+02 - val_loss: -6.6938e+02
# Epoch 42/100
# 0s - loss: -6.7115e+02 - val_loss: -6.7454e+02
# Epoch 43/100
# 0s - loss: -6.7163e+02 - val_loss: -6.7603e+02
# Epoch 44/100
# 0s - loss: -6.7578e+02 - val_loss: -6.7558e+02
# Epoch 45/100
# 0s - loss: -6.7763e+02 - val_loss: -6.8143e+02
# Epoch 46/100
# 0s - loss: -6.8175e+02 - val_loss: -6.8226e+02
# Epoch 47/100
# 0s - loss: -6.8266e+02 - val_loss: -6.8313e+02
# Epoch 48/100
# 0s - loss: -6.8304e+02 - val_loss: -6.8320e+02
# Epoch 49/100
# 0s - loss: -6.8334e+02 - val_loss: -6.8357e+02
# Epoch 50/100
# 0s - loss: -6.8357e+02 - val_loss: -6.8273e+02
# Epoch 51/100
# 0s - loss: -6.8272e+02 - val_loss: -6.8321e+02
# Epoch 52/100
# 0s - loss: -6.8327e+02 - val_loss: -6.8340e+02
# Epoch 53/100
# 0s - loss: -6.8392e+02 - val_loss: -6.8431e+02
# Epoch 54/100
# 0s - loss: -6.8476e+02 - val_loss: -6.8524e+02
# Epoch 55/100
# 0s - loss: -6.8504e+02 - val_loss: -6.8511e+02
# Epoch 56/100
# 0s - loss: -6.8153e+02 - val_loss: -6.8146e+02
# Epoch 57/100
# 0s - loss: -6.8296e+02 - val_loss: -6.8332e+02
# Epoch 58/100
# 0s - loss: -6.8378e+02 - val_loss: -6.8379e+02
# Epoch 59/100
# 0s - loss: -6.7712e+02 - val_loss: -6.7877e+02
# Epoch 60/100
# 0s - loss: -6.7996e+02 - val_loss: -6.7741e+02
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =15906
# SourceData's aborting data = 6
# window shape is (15906, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=16-l1_reg=10e-5
# Train on 15906 samples, validate on 15906 samples
# Epoch 1/100
# 1s - loss: -1.1079e+03 - val_loss: -1.1842e+03
# Epoch 2/100
# 1s - loss: -1.2152e+03 - val_loss: -1.2498e+03
# Epoch 3/100
# 1s - loss: -1.2680e+03 - val_loss: -1.2834e+03
# Epoch 4/100
# 1s - loss: -1.0830e+03 - val_loss: -1.0352e+03
# Epoch 5/100
# 1s - loss: -1.0948e+03 - val_loss: -1.1661e+03
# Epoch 6/100
# 1s - loss: -1.2107e+03 - val_loss: -1.2474e+03
# Epoch 7/100
# 2s - loss: -1.2791e+03 - val_loss: -1.2975e+03
# Epoch 8/100
# 2s - loss: -1.3210e+03 - val_loss: -1.3356e+03
# Epoch 9/100
# 2s - loss: -1.3392e+03 - val_loss: -1.3394e+03
# Epoch 10/100
# 1s - loss: -1.3459e+03 - val_loss: -1.3531e+03
# Epoch 11/100
# 1s - loss: -1.3563e+03 - val_loss: -1.3592e+03
# Epoch 12/100
# 1s - loss: -1.3598e+03 - val_loss: -1.3649e+03
# Epoch 13/100
# 1s - loss: -1.3651e+03 - val_loss: -1.3656e+03
# Epoch 14/100
# 1s - loss: -1.2561e+03 - val_loss: -8.7667e+02
# Epoch 15/100
# 1s - loss: -1.0287e+03 - val_loss: -1.1074e+03
# Epoch 16/100
# 1s - loss: -1.1472e+03 - val_loss: -1.1823e+03
# Epoch 17/100
# 1s - loss: -1.2322e+03 - val_loss: -1.2636e+03
# Epoch 18/100
# 1s - loss: -1.2734e+03 - val_loss: -1.2932e+03
# Epoch 19/100
# 1s - loss: -1.3092e+03 - val_loss: -1.3216e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =7953
# SourceData's aborting data = 22
# window shape is (7953, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=32-l1_reg=10e-5
# Train on 7953 samples, validate on 7953 samples
# Epoch 1/100
# 0s - loss: -1.0571e+03 - val_loss: -1.1370e+03
# Epoch 2/100
# 0s - loss: -1.1606e+03 - val_loss: -1.1755e+03
# Epoch 3/100
# 0s - loss: -1.1922e+03 - val_loss: -1.2156e+03
# Epoch 4/100
# 0s - loss: -1.2358e+03 - val_loss: -1.2551e+03
# Epoch 5/100
# 0s - loss: -1.2614e+03 - val_loss: -1.2737e+03
# Epoch 6/100
# 0s - loss: -1.2776e+03 - val_loss: -1.2738e+03
# Epoch 7/100
# 0s - loss: -1.1834e+03 - val_loss: -8.4580e+02
# Epoch 8/100
# 0s - loss: -9.5834e+02 - val_loss: -1.0181e+03
# Epoch 9/100
# 0s - loss: -1.0543e+03 - val_loss: -1.0962e+03
# Epoch 10/100
# 0s - loss: -1.1231e+03 - val_loss: -1.1511e+03
# Epoch 11/100
# 0s - loss: -1.1788e+03 - val_loss: -1.2090e+03
# Epoch 12/100
# 0s - loss: -1.2265e+03 - val_loss: -1.2533e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =3977
# SourceData's aborting data = 22
# window shape is (3977, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=64-l1_reg=10e-5
# Train on 3977 samples, validate on 3977 samples
# Epoch 1/100
# 0s - loss: -1.0067e+03 - val_loss: -1.0925e+03
# Epoch 2/100
# 0s - loss: -1.1137e+03 - val_loss: -1.1353e+03
# Epoch 3/100
# 0s - loss: -1.1507e+03 - val_loss: -1.1745e+03
# Epoch 4/100
# 0s - loss: -1.1918e+03 - val_loss: -1.1988e+03
# Epoch 5/100
# 0s - loss: -1.2073e+03 - val_loss: -1.2131e+03
# Epoch 6/100
# 0s - loss: -1.2230e+03 - val_loss: -1.2309e+03
# Epoch 7/100
# 0s - loss: -1.2330e+03 - val_loss: -1.2347e+03
# Epoch 8/100
# 0s - loss: -1.2379e+03 - val_loss: -1.2451e+03
# Epoch 9/100
# 0s - loss: -1.2535e+03 - val_loss: -1.2586e+03
# Epoch 10/100
# 0s - loss: -1.2609e+03 - val_loss: -1.2664e+03
# Epoch 11/100
# 0s - loss: -1.2696e+03 - val_loss: -1.2756e+03
# Epoch 12/100
# 0s - loss: -1.2778e+03 - val_loss: -1.2882e+03
# Epoch 13/100
# 0s - loss: -1.2943e+03 - val_loss: -1.2953e+03
# Epoch 14/100
# 0s - loss: -1.2969e+03 - val_loss: -1.3004e+03
# Epoch 15/100
# 0s - loss: -1.1442e+03 - val_loss: -7.7821e+02
# Epoch 16/100
# 0s - loss: -8.6617e+02 - val_loss: -9.2314e+02
# Epoch 17/100
# 0s - loss: -9.4777e+02 - val_loss: -9.6491e+02
# Epoch 18/100
# 0s - loss: -9.7605e+02 - val_loss: -9.9573e+02
# Epoch 19/100
# 0s - loss: -1.0053e+03 - val_loss: -1.0207e+03
# Epoch 20/100
# 0s - loss: -1.0421e+03 - val_loss: -1.0619e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =1989
# SourceData's aborting data = 22
# window shape is (1989, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=128-l1_reg=10e-5
# Train on 1989 samples, validate on 1989 samples
# Epoch 1/100
# 0s - loss: -9.4160e+02 - val_loss: -1.0432e+03
# Epoch 2/100
# 0s - loss: -1.0791e+03 - val_loss: -1.0996e+03
# Epoch 3/100
# 0s - loss: -1.1072e+03 - val_loss: -1.1151e+03
# Epoch 4/100
# 0s - loss: -1.1268e+03 - val_loss: -1.1367e+03
# Epoch 5/100
# 0s - loss: -1.1436e+03 - val_loss: -1.1493e+03
# Epoch 6/100
# 0s - loss: -1.1553e+03 - val_loss: -1.1634e+03
# Epoch 7/100
# 0s - loss: -1.1692e+03 - val_loss: -1.1763e+03
# Epoch 8/100
# 0s - loss: -1.1822e+03 - val_loss: -1.1865e+03
# Epoch 9/100
# 0s - loss: -1.1868e+03 - val_loss: -1.1866e+03
# Epoch 10/100
# 0s - loss: -1.1971e+03 - val_loss: -1.2098e+03
# Epoch 11/100
# 0s - loss: -1.2153e+03 - val_loss: -1.2193e+03
# Epoch 12/100
# 0s - loss: -1.2227e+03 - val_loss: -1.2243e+03
# Epoch 13/100
# 0s - loss: -1.2282e+03 - val_loss: -1.2311e+03
# Epoch 14/100
# 0s - loss: -1.2371e+03 - val_loss: -1.2433e+03
# Epoch 15/100
# 0s - loss: -1.2454e+03 - val_loss: -1.2486e+03
# Epoch 16/100
# 0s - loss: -1.2510e+03 - val_loss: -1.2576e+03
# Epoch 17/100
# 0s - loss: -1.2604e+03 - val_loss: -1.2662e+03
# Epoch 18/100
# 0s - loss: -1.2672e+03 - val_loss: -1.2696e+03
# Epoch 19/100
# 0s - loss: -1.2707e+03 - val_loss: -1.2723e+03
# Epoch 20/100
# 0s - loss: -1.2733e+03 - val_loss: -1.2810e+03
# Epoch 21/100
# 0s - loss: -1.2830e+03 - val_loss: -1.2865e+03
# Epoch 22/100
# 0s - loss: -1.2883e+03 - val_loss: -1.2900e+03
# Epoch 23/100
# 0s - loss: -1.2924e+03 - val_loss: -1.2949e+03
# Epoch 24/100
# 0s - loss: -1.2904e+03 - val_loss: -1.2915e+03
# Epoch 25/100
# 0s - loss: -1.2951e+03 - val_loss: -1.2960e+03
# Epoch 26/100
# 0s - loss: -1.2947e+03 - val_loss: -1.2935e+03
# Epoch 27/100
# 0s - loss: -1.2949e+03 - val_loss: -1.3002e+03
# Epoch 28/100
# 0s - loss: -1.3029e+03 - val_loss: -1.3040e+03
# Epoch 29/100
# 0s - loss: -1.3089e+03 - val_loss: -1.3092e+03
# Epoch 30/100
# 0s - loss: -1.3103e+03 - val_loss: -1.3111e+03
# Epoch 31/100
# 0s - loss: -1.3117e+03 - val_loss: -1.3152e+03
# Epoch 32/100
# 0s - loss: -1.3132e+03 - val_loss: -1.3115e+03
# Epoch 33/100
# 0s - loss: -1.3121e+03 - val_loss: -1.2907e+03
# Epoch 34/100
# 0s - loss: -9.4280e+02 - val_loss: -8.4517e+02
# Epoch 35/100
# 0s - loss: -9.3968e+02 - val_loss: -1.0071e+03
# Epoch 36/100
# 0s - loss: -1.0541e+03 - val_loss: -1.0870e+03
# Epoch 37/100
# 0s - loss: -1.1082e+03 - val_loss: -1.1270e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =995
# SourceData's aborting data = 22
# window shape is (995, 256, 1)
# hiden node = 16
# -edim=16-Window=256-Overlap=256-l1_reg=10e-5
# Train on 995 samples, validate on 995 samples
# Epoch 1/100
# 0s - loss: -8.7290e+02 - val_loss: -9.5120e+02
# Epoch 2/100
# 0s - loss: -9.9789e+02 - val_loss: -1.0348e+03
# Epoch 3/100
# 0s - loss: -1.0500e+03 - val_loss: -1.0468e+03
# Epoch 4/100
# 0s - loss: -1.0599e+03 - val_loss: -1.0764e+03
# Epoch 5/100
# 0s - loss: -1.0796e+03 - val_loss: -1.0831e+03
# Epoch 6/100
# 0s - loss: -1.0868e+03 - val_loss: -1.0972e+03
# Epoch 7/100
# 0s - loss: -1.1043e+03 - val_loss: -1.1192e+03
# Epoch 8/100
# 0s - loss: -1.1280e+03 - val_loss: -1.1331e+03
# Epoch 9/100
# 0s - loss: -1.1398e+03 - val_loss: -1.1470e+03
# Epoch 10/100
# 0s - loss: -1.1485e+03 - val_loss: -1.1507e+03
# Epoch 11/100
# 0s - loss: -1.1588e+03 - val_loss: -1.1659e+03
# Epoch 12/100
# 0s - loss: -1.1691e+03 - val_loss: -1.1722e+03
# Epoch 13/100
# 0s - loss: -1.1756e+03 - val_loss: -1.1775e+03
# Epoch 14/100
# 0s - loss: -1.1806e+03 - val_loss: -1.1853e+03
# Epoch 15/100
# 0s - loss: -1.1870e+03 - val_loss: -1.1871e+03
# Epoch 16/100
# 0s - loss: -1.1941e+03 - val_loss: -1.2015e+03
# Epoch 17/100
# 0s - loss: -1.2071e+03 - val_loss: -1.2101e+03
# Epoch 18/100
# 0s - loss: -1.2134e+03 - val_loss: -1.2138e+03
# Epoch 19/100
# 0s - loss: -1.2191e+03 - val_loss: -1.2209e+03
# Epoch 20/100
# 0s - loss: -1.2222e+03 - val_loss: -1.2209e+03
# Epoch 21/100
# 0s - loss: -1.2264e+03 - val_loss: -1.2336e+03
# Epoch 22/100
# 0s - loss: -1.2348e+03 - val_loss: -1.2355e+03
# Epoch 23/100
# 0s - loss: -1.2387e+03 - val_loss: -1.2434e+03
# Epoch 24/100
# 0s - loss: -1.2462e+03 - val_loss: -1.2426e+03
# Epoch 25/100
# 0s - loss: -1.2431e+03 - val_loss: -1.2436e+03
# Epoch 26/100
# 0s - loss: -1.2463e+03 - val_loss: -1.2488e+03
# Epoch 27/100
# 0s - loss: -1.2525e+03 - val_loss: -1.2535e+03
# Epoch 28/100
# 0s - loss: -1.2556e+03 - val_loss: -1.2568e+03
# Epoch 29/100
# 0s - loss: -1.2567e+03 - val_loss: -1.2572e+03
# Epoch 30/100
# 0s - loss: -1.2574e+03 - val_loss: -1.2536e+03
# Epoch 31/100
# 0s - loss: -1.2568e+03 - val_loss: -1.2661e+03
# Epoch 32/100
# 0s - loss: -1.2668e+03 - val_loss: -1.2711e+03
# Epoch 33/100
# 0s - loss: -1.2744e+03 - val_loss: -1.2765e+03
# Epoch 34/100
# 0s - loss: -1.2775e+03 - val_loss: -1.2852e+03
# Epoch 35/100
# 0s - loss: -1.2930e+03 - val_loss: -1.2941e+03
# Epoch 36/100
# 0s - loss: -1.2948e+03 - val_loss: -1.2952e+03
# Epoch 37/100
# 0s - loss: -1.2961e+03 - val_loss: -1.2967e+03
# Epoch 38/100
# 0s - loss: -1.2962e+03 - val_loss: -1.2932e+03
# Epoch 39/100
# 0s - loss: -1.2978e+03 - val_loss: -1.3008e+03
# Epoch 40/100
# 0s - loss: -1.3019e+03 - val_loss: -1.3040e+03
# Epoch 41/100
# 0s - loss: -1.3043e+03 - val_loss: -1.3052e+03
# Epoch 42/100
# 0s - loss: -1.3039e+03 - val_loss: -1.3042e+03
# Epoch 43/100
# 0s - loss: -1.3044e+03 - val_loss: -1.3048e+03
# Epoch 44/100
# 0s - loss: -1.3051e+03 - val_loss: -1.3056e+03
# Epoch 45/100
# 0s - loss: -1.3061e+03 - val_loss: -1.3063e+03
# Epoch 46/100
# 0s - loss: -1.3046e+03 - val_loss: -1.3039e+03
# Epoch 47/100
# 0s - loss: -1.3051e+03 - val_loss: -1.3067e+03
# Epoch 48/100
# 0s - loss: -1.3060e+03 - val_loss: -1.3080e+03
# Epoch 49/100
# 0s - loss: -1.3062e+03 - val_loss: -1.3057e+03
# Epoch 50/100
# 0s - loss: -1.3043e+03 - val_loss: -1.3037e+03
# Epoch 51/100
# 0s - loss: -1.3056e+03 - val_loss: -1.3062e+03
# Epoch 52/100
# 0s - loss: -1.3092e+03 - val_loss: -1.3180e+03
# Epoch 53/100
# 0s - loss: -1.3185e+03 - val_loss: -1.3189e+03
# Epoch 54/100
# 0s - loss: -1.3157e+03 - val_loss: -1.3131e+03
# Epoch 55/100
# 0s - loss: -1.3159e+03 - val_loss: -1.3201e+03
# Epoch 56/100
# 0s - loss: -1.3203e+03 - val_loss: -1.3221e+03
# Epoch 57/100
# 0s - loss: -1.3276e+03 - val_loss: -1.3290e+03
# Epoch 58/100
# 0s - loss: -1.3292e+03 - val_loss: -1.3295e+03
# Epoch 59/100
# 0s - loss: -1.3298e+03 - val_loss: -1.3303e+03
# Epoch 60/100
# 0s - loss: -1.3308e+03 - val_loss: -1.3310e+03
# Epoch 61/100
# 0s - loss: -1.3312e+03 - val_loss: -1.3310e+03
# Epoch 62/100
# 0s - loss: -1.3332e+03 - val_loss: -1.3340e+03
# Epoch 63/100
# 0s - loss: -1.3342e+03 - val_loss: -1.3348e+03
# Epoch 64/100
# 0s - loss: -1.3349e+03 - val_loss: -1.3352e+03
# Epoch 65/100
# 0s - loss: -1.3377e+03 - val_loss: -1.3392e+03
# Epoch 66/100
# 0s - loss: -1.3393e+03 - val_loss: -1.3398e+03
# Epoch 67/100
# 0s - loss: -1.3400e+03 - val_loss: -1.3403e+03
# Epoch 68/100
# 0s - loss: -1.3404e+03 - val_loss: -1.3406e+03
# Epoch 69/100
# 0s - loss: -1.3384e+03 - val_loss: -1.3376e+03
# Epoch 70/100
# 0s - loss: -1.3371e+03 - val_loss: -1.3364e+03
# Epoch 71/100
# 0s - loss: -1.3388e+03 - val_loss: -1.3425e+03
# Epoch 72/100
# 0s - loss: -1.3427e+03 - val_loss: -1.3432e+03
# Epoch 73/100
# 0s - loss: -1.3434e+03 - val_loss: -1.3436e+03
# Epoch 74/100
# 0s - loss: -1.3335e+03 - val_loss: -1.3272e+03
# Epoch 75/100
# 0s - loss: -1.3332e+03 - val_loss: -1.3388e+03
# Epoch 76/100
# 0s - loss: -1.3368e+03 - val_loss: -1.3349e+03
# Epoch 77/100
# 0s - loss: -1.3404e+03 - val_loss: -1.3430e+03
# Epoch 78/100
# 0s - loss: -1.3437e+03 - val_loss: -1.3438e+03
# Epoch 79/100
# 0s - loss: -1.3447e+03 - val_loss: -1.3456e+03
# Epoch 80/100
# 0s - loss: -1.3415e+03 - val_loss: -1.3386e+03
# Epoch 81/100
# 0s - loss: -1.3384e+03 - val_loss: -1.3395e+03
# Epoch 82/100
# 0s - loss: -1.3389e+03 - val_loss: -1.3360e+03
# Epoch 83/100
# 0s - loss: -1.3286e+03 - val_loss: -1.3233e+03
# Epoch 84/100
# 0s - loss: -1.0627e+03 - val_loss: -6.8680e+02
# Epoch 85/100
# 0s - loss: -7.4860e+02 - val_loss: -8.2022e+02
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =15890
# SourceData's aborting data = 6
# window shape is (15890, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=16-l1_reg=10e-5
# Train on 15890 samples, validate on 15890 samples
# Epoch 1/100
# 0s - loss: -2.1778e+03 - val_loss: -2.3265e+03
# Epoch 2/100
# 0s - loss: -2.3902e+03 - val_loss: -2.4541e+03
# Epoch 3/100
# 0s - loss: -2.4981e+03 - val_loss: -2.5363e+03
# Epoch 4/100
# 0s - loss: -2.5565e+03 - val_loss: -2.5775e+03
# Epoch 5/100
# 0s - loss: -2.5852e+03 - val_loss: -2.5914e+03
# Epoch 6/100
# 0s - loss: -2.6018e+03 - val_loss: -2.6075e+03
# Epoch 7/100
# 0s - loss: -2.6086e+03 - val_loss: -2.6042e+03
# Epoch 8/100
# 0s - loss: -2.5322e+03 - val_loss: -2.5629e+03
# Epoch 9/100
# 0s - loss: -2.1969e+03 - val_loss: -1.7763e+03
# Epoch 10/100
# 0s - loss: -1.8887e+03 - val_loss: -1.9702e+03
# Epoch 11/100
# 0s - loss: -2.0393e+03 - val_loss: -2.0767e+03
# Epoch 12/100
# 0s - loss: -2.1313e+03 - val_loss: -2.1870e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =7945
# SourceData's aborting data = 22
# window shape is (7945, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=32-l1_reg=10e-5
# Train on 7945 samples, validate on 7945 samples
# Epoch 1/100
# 0s - loss: -2.0588e+03 - val_loss: -2.2030e+03
# Epoch 2/100
# 0s - loss: -2.2552e+03 - val_loss: -2.2951e+03
# Epoch 3/100
# 0s - loss: -2.3492e+03 - val_loss: -2.3840e+03
# Epoch 4/100
# 0s - loss: -2.4027e+03 - val_loss: -2.4132e+03
# Epoch 5/100
# 0s - loss: -2.4310e+03 - val_loss: -2.4541e+03
# Epoch 6/100
# 0s - loss: -2.4647e+03 - val_loss: -2.4819e+03
# Epoch 7/100
# 0s - loss: -2.4906e+03 - val_loss: -2.5045e+03
# Epoch 8/100
# 0s - loss: -2.5123e+03 - val_loss: -2.5161e+03
# Epoch 9/100
# 0s - loss: -2.5273e+03 - val_loss: -2.5330e+03
# Epoch 10/100
# 0s - loss: -2.5367e+03 - val_loss: -2.5390e+03
# Epoch 11/100
# 0s - loss: -2.5418e+03 - val_loss: -2.5503e+03
# Epoch 12/100
# 0s - loss: -2.5580e+03 - val_loss: -2.5615e+03
# Epoch 13/100
# 0s - loss: -2.5652e+03 - val_loss: -2.5719e+03
# Epoch 14/100
# 0s - loss: -2.5760e+03 - val_loss: -2.5731e+03
# Epoch 15/100
# 0s - loss: -2.3497e+03 - val_loss: -2.1663e+03
# Epoch 16/100
# 0s - loss: -2.2909e+03 - val_loss: -2.3755e+03
# Epoch 17/100
# 0s - loss: -2.4488e+03 - val_loss: -2.5121e+03
# Epoch 18/100
# 0s - loss: -2.5356e+03 - val_loss: -2.5562e+03
# Epoch 19/100
# 0s - loss: -2.5601e+03 - val_loss: -2.5648e+03
# Epoch 20/100
# 0s - loss: -2.5705e+03 - val_loss: -2.5740e+03
# Epoch 21/100
# 0s - loss: -2.5768e+03 - val_loss: -2.5778e+03
# Epoch 22/100
# 0s - loss: -2.5787e+03 - val_loss: -2.5786e+03
# Epoch 23/100
# 0s - loss: -2.5879e+03 - val_loss: -2.5909e+03
# Epoch 24/100
# 0s - loss: -2.5914e+03 - val_loss: -2.5928e+03
# Epoch 25/100
# 0s - loss: -2.5925e+03 - val_loss: -2.5989e+03
# Epoch 26/100
# 0s - loss: -2.6018e+03 - val_loss: -2.6033e+03
# Epoch 27/100
# 0s - loss: -2.6082e+03 - val_loss: -2.6099e+03
# Epoch 28/100
# 0s - loss: -2.6103e+03 - val_loss: -2.6084e+03
# Epoch 29/100
# 0s - loss: -2.6107e+03 - val_loss: -2.6113e+03
# Epoch 30/100
# 0s - loss: -2.6123e+03 - val_loss: -2.6138e+03
# Epoch 31/100
# 0s - loss: -2.6143e+03 - val_loss: -2.6148e+03
# Epoch 32/100
# 0s - loss: -2.6186e+03 - val_loss: -2.6182e+03
# Epoch 33/100
# 0s - loss: -2.6224e+03 - val_loss: -2.6293e+03
# Epoch 34/100
# 0s - loss: -2.6324e+03 - val_loss: -2.6345e+03
# Epoch 35/100
# 0s - loss: -2.6391e+03 - val_loss: -2.6429e+03
# Epoch 36/100
# 0s - loss: -2.6443e+03 - val_loss: -2.6473e+03
# Epoch 37/100
# 0s - loss: -2.6455e+03 - val_loss: -2.6476e+03
# Epoch 38/100
# 0s - loss: -2.6494e+03 - val_loss: -2.6521e+03
# Epoch 39/100
# 0s - loss: -2.6549e+03 - val_loss: -2.6530e+03
# Epoch 40/100
# 0s - loss: -2.6554e+03 - val_loss: -2.6559e+03
# Epoch 41/100
# 0s - loss: -2.6575e+03 - val_loss: -2.6607e+03
# Epoch 42/100
# 0s - loss: -2.6639e+03 - val_loss: -2.6698e+03
# Epoch 43/100
# 0s - loss: -2.6674e+03 - val_loss: -2.6673e+03
# Epoch 44/100
# 0s - loss: -2.6698e+03 - val_loss: -2.6739e+03
# Epoch 45/100
# 0s - loss: -2.6734e+03 - val_loss: -2.6713e+03
# Epoch 46/100
# 0s - loss: -2.6743e+03 - val_loss: -2.6740e+03
# Epoch 47/100
# 0s - loss: -2.6761e+03 - val_loss: -2.6780e+03
# Epoch 48/100
# 0s - loss: -2.6734e+03 - val_loss: -2.6692e+03
# Epoch 49/100
# 0s - loss: -2.6736e+03 - val_loss: -2.6797e+03
# Epoch 50/100
# 0s - loss: -2.6809e+03 - val_loss: -2.6819e+03
# Epoch 51/100
# 0s - loss: -2.6838e+03 - val_loss: -2.6897e+03
# Epoch 52/100
# 0s - loss: -2.6914e+03 - val_loss: -2.6923e+03
# Epoch 53/100
# 0s - loss: -2.6941e+03 - val_loss: -2.6926e+03
# Epoch 54/100
# 0s - loss: -2.6866e+03 - val_loss: -2.6847e+03
# Epoch 55/100
# 0s - loss: -2.6779e+03 - val_loss: -2.6766e+03
# Epoch 56/100
# 0s - loss: -2.1334e+03 - val_loss: -2.2801e+03
# Epoch 57/100
# 0s - loss: -2.4564e+03 - val_loss: -2.5197e+03
# Epoch 58/100
# 0s - loss: -2.5362e+03 - val_loss: -2.5472e+03
# Epoch 59/100
# 0s - loss: -2.5566e+03 - val_loss: -2.5639e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =3973
# SourceData's aborting data = 22
# window shape is (3973, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=64-l1_reg=10e-5
# Train on 3973 samples, validate on 3973 samples
# Epoch 1/100
# 0s - loss: -2.0027e+03 - val_loss: -2.1780e+03
# Epoch 2/100
# 0s - loss: -2.2223e+03 - val_loss: -2.2777e+03
# Epoch 3/100
# 0s - loss: -2.3014e+03 - val_loss: -2.3198e+03
# Epoch 4/100
# 0s - loss: -2.3432e+03 - val_loss: -2.3711e+03
# Epoch 5/100
# 0s - loss: -2.3885e+03 - val_loss: -2.4042e+03
# Epoch 6/100
# 0s - loss: -2.4173e+03 - val_loss: -2.4253e+03
# Epoch 7/100
# 0s - loss: -2.4344e+03 - val_loss: -2.4470e+03
# Epoch 8/100
# 0s - loss: -2.4540e+03 - val_loss: -2.4560e+03
# Epoch 9/100
# 0s - loss: -2.4760e+03 - val_loss: -2.4938e+03
# Epoch 10/100
# 0s - loss: -2.5008e+03 - val_loss: -2.5037e+03
# Epoch 11/100
# 0s - loss: -2.5052e+03 - val_loss: -2.5100e+03
# Epoch 12/100
# 0s - loss: -2.5189e+03 - val_loss: -2.5268e+03
# Epoch 13/100
# 0s - loss: -2.5290e+03 - val_loss: -2.5296e+03
# Epoch 14/100
# 0s - loss: -2.5337e+03 - val_loss: -2.5411e+03
# Epoch 15/100
# 0s - loss: -2.5473e+03 - val_loss: -2.5552e+03
# Epoch 16/100
# 0s - loss: -2.5553e+03 - val_loss: -2.5562e+03
# Epoch 17/100
# 0s - loss: -2.5624e+03 - val_loss: -2.5688e+03
# Epoch 18/100
# 0s - loss: -2.5729e+03 - val_loss: -2.5762e+03
# Epoch 19/100
# 0s - loss: -2.5750e+03 - val_loss: -2.5704e+03
# Epoch 20/100
# 0s - loss: -2.5693e+03 - val_loss: -2.5668e+03
# Epoch 21/100
# 0s - loss: -2.4640e+03 - val_loss: -1.4550e+03
# Epoch 22/100
# 0s - loss: -1.6988e+03 - val_loss: -1.8107e+03
# Epoch 23/100
# 0s - loss: -1.8715e+03 - val_loss: -1.9247e+03
# Epoch 24/100
# 0s - loss: -1.9479e+03 - val_loss: -1.9736e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =1987
# SourceData's aborting data = 22
# window shape is (1987, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=128-l1_reg=10e-5
# Train on 1987 samples, validate on 1987 samples
# Epoch 1/100
# 0s - loss: -1.8632e+03 - val_loss: -2.0159e+03
# Epoch 2/100
# 0s - loss: -2.0575e+03 - val_loss: -2.0978e+03
# Epoch 3/100
# 0s - loss: -2.1282e+03 - val_loss: -2.1565e+03
# Epoch 4/100
# 0s - loss: -2.1769e+03 - val_loss: -2.2009e+03
# Epoch 5/100
# 0s - loss: -2.2247e+03 - val_loss: -2.2425e+03
# Epoch 6/100
# 0s - loss: -2.2526e+03 - val_loss: -2.2729e+03
# Epoch 7/100
# 0s - loss: -2.2779e+03 - val_loss: -2.2858e+03
# Epoch 8/100
# 0s - loss: -2.2990e+03 - val_loss: -2.3134e+03
# Epoch 9/100
# 0s - loss: -2.3196e+03 - val_loss: -2.3279e+03
# Epoch 10/100
# 0s - loss: -2.3339e+03 - val_loss: -2.3485e+03
# Epoch 11/100
# 0s - loss: -2.3607e+03 - val_loss: -2.3723e+03
# Epoch 12/100
# 0s - loss: -2.3780e+03 - val_loss: -2.3867e+03
# Epoch 13/100
# 0s - loss: -2.3893e+03 - val_loss: -2.3946e+03
# Epoch 14/100
# 0s - loss: -2.4042e+03 - val_loss: -2.4120e+03
# Epoch 15/100
# 0s - loss: -2.4215e+03 - val_loss: -2.4280e+03
# Epoch 16/100
# 0s - loss: -2.4351e+03 - val_loss: -2.4386e+03
# Epoch 17/100
# 0s - loss: -2.4412e+03 - val_loss: -2.4452e+03
# Epoch 18/100
# 0s - loss: -2.4459e+03 - val_loss: -2.4439e+03
# Epoch 19/100
# 0s - loss: -2.4449e+03 - val_loss: -2.4496e+03
# Epoch 20/100
# 0s - loss: -2.4548e+03 - val_loss: -2.4572e+03
# Epoch 21/100
# 0s - loss: -2.4607e+03 - val_loss: -2.4684e+03
# Epoch 22/100
# 0s - loss: -2.4760e+03 - val_loss: -2.4795e+03
# Epoch 23/100
# 0s - loss: -2.4832e+03 - val_loss: -2.4903e+03
# Epoch 24/100
# 0s - loss: -2.4941e+03 - val_loss: -2.4990e+03
# Epoch 25/100
# 0s - loss: -2.5001e+03 - val_loss: -2.5015e+03
# Epoch 26/100
# 0s - loss: -2.5057e+03 - val_loss: -2.5100e+03
# Epoch 27/100
# 0s - loss: -2.5085e+03 - val_loss: -2.5075e+03
# Epoch 28/100
# 0s - loss: -2.5052e+03 - val_loss: -2.5080e+03
# Epoch 29/100
# 0s - loss: -2.5113e+03 - val_loss: -2.5142e+03
# Epoch 30/100
# 0s - loss: -2.5141e+03 - val_loss: -2.5167e+03
# Epoch 31/100
# 0s - loss: -2.5169e+03 - val_loss: -2.5188e+03
# Epoch 32/100
# 0s - loss: -2.5245e+03 - val_loss: -2.5242e+03
# Epoch 33/100
# 0s - loss: -2.5264e+03 - val_loss: -2.5294e+03
# Epoch 34/100
# 0s - loss: -2.5352e+03 - val_loss: -2.5381e+03
# Epoch 35/100
# 0s - loss: -2.5379e+03 - val_loss: -2.5429e+03
# Epoch 36/100
# 0s - loss: -2.5478e+03 - val_loss: -2.5549e+03
# Epoch 37/100
# 0s - loss: -2.5587e+03 - val_loss: -2.5615e+03
# Epoch 38/100
# 0s - loss: -2.5630e+03 - val_loss: -2.5661e+03
# Epoch 39/100
# 0s - loss: -2.5669e+03 - val_loss: -2.5683e+03
# Epoch 40/100
# 0s - loss: -2.5711e+03 - val_loss: -2.5737e+03
# Epoch 41/100
# 0s - loss: -2.5730e+03 - val_loss: -2.5734e+03
# Epoch 42/100
# 0s - loss: -2.5729e+03 - val_loss: -2.5749e+03
# Epoch 43/100
# 0s - loss: -2.5568e+03 - val_loss: -2.4869e+03
# Epoch 44/100
# 0s - loss: -2.0115e+03 - val_loss: -1.7620e+03
# Epoch 45/100
# 0s - loss: -1.8926e+03 - val_loss: -1.9970e+03
# Epoch 46/100
# 0s - loss: -2.0380e+03 - val_loss: -2.0830e+03
# Epoch 47/100
# 0s - loss: -2.1187e+03 - val_loss: -2.1551e+03
# Epoch 48/100
# 0s - loss: -2.1736e+03 - val_loss: -2.1977e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =994
# SourceData's aborting data = 22
# window shape is (994, 512, 1)
# hiden node = 16
# -edim=16-Window=512-Overlap=256-l1_reg=10e-5
# Train on 994 samples, validate on 994 samples
# Epoch 1/100
# 0s - loss: -1.7927e+03 - val_loss: -1.9243e+03
# Epoch 2/100
# 0s - loss: -1.9871e+03 - val_loss: -2.0383e+03
# Epoch 3/100
# 0s - loss: -2.0655e+03 - val_loss: -2.0928e+03
# Epoch 4/100
# 0s - loss: -2.1161e+03 - val_loss: -2.1415e+03
# Epoch 5/100
# 0s - loss: -2.1567e+03 - val_loss: -2.1821e+03
# Epoch 6/100
# 0s - loss: -2.1861e+03 - val_loss: -2.2020e+03
# Epoch 7/100
# 0s - loss: -2.2160e+03 - val_loss: -2.2285e+03
# Epoch 8/100
# 0s - loss: -2.2324e+03 - val_loss: -2.2406e+03
# Epoch 9/100
# 0s - loss: -2.2531e+03 - val_loss: -2.2628e+03
# Epoch 10/100
# 0s - loss: -2.2711e+03 - val_loss: -2.2819e+03
# Epoch 11/100
# 0s - loss: -2.2843e+03 - val_loss: -2.2868e+03
# Epoch 12/100
# 0s - loss: -2.2896e+03 - val_loss: -2.2941e+03
# Epoch 13/100
# 0s - loss: -2.3033e+03 - val_loss: -2.3122e+03
# Epoch 14/100
# 0s - loss: -2.3152e+03 - val_loss: -2.3170e+03
# Epoch 15/100
# 0s - loss: -2.3204e+03 - val_loss: -2.3241e+03
# Epoch 16/100
# 0s - loss: -2.3288e+03 - val_loss: -2.3408e+03
# Epoch 17/100
# 0s - loss: -2.3463e+03 - val_loss: -2.3519e+03
# Epoch 18/100
# 0s - loss: -2.3522e+03 - val_loss: -2.3548e+03
# Epoch 19/100
# 0s - loss: -2.3546e+03 - val_loss: -2.3556e+03
# Epoch 20/100
# 0s - loss: -2.3573e+03 - val_loss: -2.3589e+03
# Epoch 21/100
# 0s - loss: -2.3610e+03 - val_loss: -2.3648e+03
# Epoch 22/100
# 0s - loss: -2.3657e+03 - val_loss: -2.3712e+03
# Epoch 23/100
# 0s - loss: -2.3766e+03 - val_loss: -2.3786e+03
# Epoch 24/100
# 0s - loss: -2.3785e+03 - val_loss: -2.3836e+03
# Epoch 25/100
# 0s - loss: -2.3852e+03 - val_loss: -2.3874e+03
# Epoch 26/100
# 0s - loss: -2.3894e+03 - val_loss: -2.3942e+03
# Epoch 27/100
# 0s - loss: -2.3951e+03 - val_loss: -2.3980e+03
# Epoch 28/100
# 0s - loss: -2.4020e+03 - val_loss: -2.4068e+03
# Epoch 29/100
# 0s - loss: -2.4050e+03 - val_loss: -2.4072e+03
# Epoch 30/100
# 0s - loss: -2.4076e+03 - val_loss: -2.4089e+03
# Epoch 31/100
# 0s - loss: -2.4105e+03 - val_loss: -2.4113e+03
# Epoch 32/100
# 0s - loss: -2.4109e+03 - val_loss: -2.4103e+03
# Epoch 33/100
# 0s - loss: -2.4126e+03 - val_loss: -2.4203e+03
# Epoch 34/100
# 0s - loss: -2.4195e+03 - val_loss: -2.4224e+03
# Epoch 35/100
# 0s - loss: -2.4251e+03 - val_loss: -2.4288e+03
# Epoch 36/100
# 0s - loss: -2.4291e+03 - val_loss: -2.4301e+03
# Epoch 37/100
# 0s - loss: -2.4308e+03 - val_loss: -2.4330e+03
# Epoch 38/100
# 0s - loss: -2.4341e+03 - val_loss: -2.4341e+03
# Epoch 39/100
# 0s - loss: -2.4339e+03 - val_loss: -2.4344e+03
# Epoch 40/100
# 0s - loss: -2.4344e+03 - val_loss: -2.4360e+03
# Epoch 41/100
# 0s - loss: -2.4403e+03 - val_loss: -2.4430e+03
# Epoch 42/100
# 0s - loss: -2.4439e+03 - val_loss: -2.4484e+03
# Epoch 43/100
# 0s - loss: -2.4492e+03 - val_loss: -2.4498e+03
# Epoch 44/100
# 0s - loss: -2.4495e+03 - val_loss: -2.4503e+03
# Epoch 45/100
# 0s - loss: -2.4535e+03 - val_loss: -2.4575e+03
# Epoch 46/100
# 0s - loss: -2.4600e+03 - val_loss: -2.4632e+03
# Epoch 47/100
# 0s - loss: -2.4631e+03 - val_loss: -2.4633e+03
# Epoch 48/100
# 0s - loss: -2.4632e+03 - val_loss: -2.4650e+03
# Epoch 49/100
# 0s - loss: -2.4634e+03 - val_loss: -2.4647e+03
# Epoch 50/100
# 0s - loss: -2.4645e+03 - val_loss: -2.4630e+03
# Epoch 51/100
# 0s - loss: -2.4629e+03 - val_loss: -2.4608e+03
# Epoch 52/100
# 0s - loss: -2.4610e+03 - val_loss: -2.4653e+03
# Epoch 53/100
# 0s - loss: -2.4653e+03 - val_loss: -2.4662e+03
# Epoch 54/100
# 0s - loss: -2.4667e+03 - val_loss: -2.4668e+03
# Epoch 55/100
# 0s - loss: -2.4704e+03 - val_loss: -2.4701e+03
# Epoch 56/100
# 0s - loss: -2.4719e+03 - val_loss: -2.4720e+03
# Epoch 57/100
# 0s - loss: -2.4720e+03 - val_loss: -2.4743e+03
# Epoch 58/100
# 0s - loss: -2.4731e+03 - val_loss: -2.4742e+03
# Epoch 59/100
# 0s - loss: -2.4760e+03 - val_loss: -2.4791e+03
# Epoch 60/100
# 0s - loss: -2.4806e+03 - val_loss: -2.4825e+03
# Epoch 61/100
# 0s - loss: -2.4828e+03 - val_loss: -2.4837e+03
# Epoch 62/100
# 0s - loss: -2.4854e+03 - val_loss: -2.4865e+03
# Epoch 63/100
# 0s - loss: -2.4905e+03 - val_loss: -2.4935e+03
# Epoch 64/100
# 0s - loss: -2.4933e+03 - val_loss: -2.4940e+03
# Epoch 65/100
# 0s - loss: -2.4940e+03 - val_loss: -2.4948e+03
# Epoch 66/100
# 0s - loss: -2.4943e+03 - val_loss: -2.4949e+03
# Epoch 67/100
# 0s - loss: -2.4951e+03 - val_loss: -2.4961e+03
# Epoch 68/100
# 0s - loss: -2.4968e+03 - val_loss: -2.4979e+03
# Epoch 69/100
# 0s - loss: -2.4985e+03 - val_loss: -2.4975e+03
# Epoch 70/100
# 0s - loss: -2.5017e+03 - val_loss: -2.5029e+03
# Epoch 71/100
# 0s - loss: -2.5013e+03 - val_loss: -2.4980e+03
# Epoch 72/100
# 0s - loss: -2.4993e+03 - val_loss: -2.4999e+03
# Epoch 73/100
# 0s - loss: -2.5035e+03 - val_loss: -2.5023e+03
# Epoch 74/100
# 0s - loss: -2.5010e+03 - val_loss: -2.5012e+03
# Epoch 75/100
# 0s - loss: -2.5010e+03 - val_loss: -2.5010e+03
# Epoch 76/100
# 0s - loss: -2.5008e+03 - val_loss: -2.5021e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =15858
# SourceData's aborting data = 6
# window shape is (15858, 1024, 1)
# hiden node = 16
# -edim=16-Window=1024-Overlap=16-l1_reg=10e-5
# Train on 15858 samples, validate on 15858 samples
# Epoch 1/100
# 1s - loss: -4.3197e+03 - val_loss: -4.5724e+03
# Epoch 2/100
# 1s - loss: -4.6917e+03 - val_loss: -4.7729e+03
# Epoch 3/100
# 1s - loss: -4.8429e+03 - val_loss: -4.8968e+03
# Epoch 4/100
# 1s - loss: -4.9233e+03 - val_loss: -4.9675e+03
# Epoch 5/100
# 1s - loss: -5.0001e+03 - val_loss: -5.0113e+03
# Epoch 6/100
# 1s - loss: -5.0283e+03 - val_loss: -5.0508e+03
# Epoch 7/100
# 1s - loss: -5.0778e+03 - val_loss: -5.0988e+03
# Epoch 8/100
# 1s - loss: -5.1082e+03 - val_loss: -5.1206e+03
# Epoch 9/100
# 1s - loss: -5.0835e+03 - val_loss: -5.0743e+03
# Epoch 10/100
# 1s - loss: -4.9672e+03 - val_loss: -5.1100e+03
# Epoch 11/100
# 1s - loss: -5.1176e+03 - val_loss: -5.1262e+03
# Epoch 12/100
# 1s - loss: -5.1362e+03 - val_loss: -5.1494e+03
# Epoch 13/100
# 1s - loss: -5.1607e+03 - val_loss: -5.1648e+03
# Epoch 14/100
# 1s - loss: -5.1731e+03 - val_loss: -5.1757e+03
# Epoch 15/100
# 1s - loss: -5.1810e+03 - val_loss: -5.1899e+03
# Epoch 16/100
# 1s - loss: -5.1954e+03 - val_loss: -5.2046e+03
# Epoch 17/100
# 1s - loss: -5.2120e+03 - val_loss: -5.2190e+03
# Epoch 18/100
# 1s - loss: -5.2277e+03 - val_loss: -5.2345e+03
# Epoch 19/100
# 1s - loss: -5.2389e+03 - val_loss: -5.2485e+03
# Epoch 20/100
# 1s - loss: -5.2519e+03 - val_loss: -5.2563e+03
# Epoch 21/100
# 1s - loss: -5.2578e+03 - val_loss: -5.2579e+03
# Epoch 22/100
# 1s - loss: -5.2637e+03 - val_loss: -5.2665e+03
# Epoch 23/100
# 1s - loss: -5.2642e+03 - val_loss: -5.2612e+03
# Epoch 24/100
# 1s - loss: -5.2680e+03 - val_loss: -5.2743e+03
# Epoch 25/100
# 1s - loss: -5.2752e+03 - val_loss: -5.2822e+03
# Epoch 26/100
# 1s - loss: -5.2871e+03 - val_loss: -5.2897e+03
# Epoch 27/100
# 1s - loss: -5.2916e+03 - val_loss: -5.2894e+03
# Epoch 28/100
# 1s - loss: -5.2960e+03 - val_loss: -5.2987e+03
# Epoch 29/100
# 1s - loss: -5.3011e+03 - val_loss: -5.3036e+03
# Epoch 30/100
# 1s - loss: -5.3077e+03 - val_loss: -5.3074e+03
# Epoch 31/100
# 1s - loss: -5.3126e+03 - val_loss: -5.3219e+03
# Epoch 32/100
# 1s - loss: -5.3244e+03 - val_loss: -5.3305e+03
# Epoch 33/100
# 1s - loss: -5.3336e+03 - val_loss: -5.3347e+03
# Epoch 34/100
# 1s - loss: -5.3396e+03 - val_loss: -5.3429e+03
# Epoch 35/100
# 1s - loss: -5.3436e+03 - val_loss: -5.3476e+03
# Epoch 36/100
# 1s - loss: -5.3507e+03 - val_loss: -5.3504e+03
# Epoch 37/100
# 1s - loss: -5.3539e+03 - val_loss: -5.3550e+03
# Epoch 38/100
# 1s - loss: -5.2717e+03 - val_loss: -5.3097e+03
# Epoch 39/100
# 1s - loss: -5.0919e+03 - val_loss: -4.9464e+03
# Epoch 40/100
# 1s - loss: -5.1220e+03 - val_loss: -5.2315e+03
# Epoch 41/100
# 1s - loss: -5.2651e+03 - val_loss: -5.2893e+03
# Epoch 42/100
# 1s - loss: -5.3078e+03 - val_loss: -5.3246e+03
# Epoch 43/100
# 1s - loss: -5.3424e+03 - val_loss: -5.3575e+03
# Epoch 44/100
# 1s - loss: -5.3628e+03 - val_loss: -5.3701e+03
# Epoch 45/100
# 1s - loss: -5.3773e+03 - val_loss: -5.3828e+03
# Epoch 46/100
# 1s - loss: -5.3912e+03 - val_loss: -5.3965e+03
# Epoch 47/100
# 1s - loss: -5.4004e+03 - val_loss: -5.4011e+03
# Epoch 48/100
# 1s - loss: -5.4063e+03 - val_loss: -5.4110e+03
# Epoch 49/100
# 1s - loss: -5.4145e+03 - val_loss: -5.4166e+03
# Epoch 50/100
# 1s - loss: -5.4192e+03 - val_loss: -5.4255e+03
# Epoch 51/100
# 1s - loss: -5.4362e+03 - val_loss: -5.4390e+03
# Epoch 52/100
# 1s - loss: -5.4403e+03 - val_loss: -5.4413e+03
# Epoch 53/100
# 1s - loss: -5.4430e+03 - val_loss: -5.4468e+03
# Epoch 54/100
# 1s - loss: -5.4473e+03 - val_loss: -5.4496e+03
# Epoch 55/100
# 1s - loss: -5.4503e+03 - val_loss: -5.4524e+03
# Epoch 56/100
# 1s - loss: -5.4537e+03 - val_loss: -5.4538e+03
# Epoch 57/100
# 1s - loss: -5.4571e+03 - val_loss: -5.4596e+03
# Epoch 58/100
# 1s - loss: -5.4621e+03 - val_loss: -5.4633e+03
# Epoch 59/100
# 1s - loss: -5.4728e+03 - val_loss: -5.4763e+03
# Epoch 60/100
# 1s - loss: -5.4730e+03 - val_loss: -5.4713e+03
# Epoch 61/100
# 1s - loss: -5.4575e+03 - val_loss: -5.4820e+03
# Epoch 62/100
# 1s - loss: -5.4976e+03 - val_loss: -5.5009e+03
# Epoch 63/100
# 1s - loss: -5.5048e+03 - val_loss: -5.5075e+03
# Epoch 64/100
# 1s - loss: -5.4997e+03 - val_loss: -5.4948e+03
# Epoch 65/100
# 1s - loss: -5.5024e+03 - val_loss: -5.5050e+03
# Epoch 66/100
# 1s - loss: -5.5166e+03 - val_loss: -5.5100e+03
# Epoch 67/100
# 1s - loss: -5.5125e+03 - val_loss: -5.5474e+03
# Epoch 68/100
# 1s - loss: -5.5106e+03 - val_loss: -5.5057e+03
# Epoch 69/100
# 1s - loss: -5.5137e+03 - val_loss: -5.5053e+03
# Epoch 70/100
# 1s - loss: -5.5177e+03 - val_loss: -5.4953e+03
# Epoch 71/100
# 1s - loss: -5.5044e+03 - val_loss: -5.4881e+03
# Epoch 72/100
# 1s - loss: -5.4999e+03 - val_loss: -5.5559e+03
# Epoch 73/100
# 1s - loss: -5.4966e+03 - val_loss: -5.5026e+03
# Epoch 74/100
# 1s - loss: -5.5127e+03 - val_loss: -5.5626e+03
# Epoch 75/100
# 1s - loss: -5.5139e+03 - val_loss: -5.4971e+03
# Epoch 76/100
# 1s - loss: -5.5182e+03 - val_loss: -5.5717e+03
# Epoch 77/100
# 1s - loss: -5.5143e+03 - val_loss: -5.5078e+03
# Epoch 78/100
# 1s - loss: -5.5206e+03 - val_loss: -5.5088e+03
# Epoch 79/100
# 1s - loss: -5.5198e+03 - val_loss: -5.5706e+03
# Epoch 80/100
# 1s - loss: -5.5220e+03 - val_loss: -5.5183e+03
# Epoch 81/100
# 1s - loss: -5.5316e+03 - val_loss: -5.5722e+03
# Epoch 82/100
# 1s - loss: -5.5264e+03 - val_loss: -5.5684e+03
# Epoch 83/100
# 1s - loss: -5.5506e+03 - val_loss: -5.5311e+03
# Epoch 84/100
# 1s - loss: -5.5469e+03 - val_loss: -5.5208e+03
# Epoch 85/100
# 1s - loss: -5.5289e+03 - val_loss: -5.5064e+03
# Epoch 86/100
# 1s - loss: -5.4749e+03 - val_loss: -5.3366e+03
# Epoch 87/100
# 1s - loss: -4.2134e+03 - val_loss: -4.3746e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =7929
# SourceData's aborting data = 22
# window shape is (7929, 1024, 1)
# hiden node = 16
# -edim=16-Window=1024-Overlap=32-l1_reg=10e-5
# Train on 7929 samples, validate on 7929 samples
# Epoch 1/100
# 0s - loss: -4.0435e+03 - val_loss: -4.2782e+03
# Epoch 2/100
# 0s - loss: -4.3757e+03 - val_loss: -4.4642e+03
# Epoch 3/100
# 0s - loss: -4.5275e+03 - val_loss: -4.5853e+03
# Epoch 4/100
# 0s - loss: -4.6266e+03 - val_loss: -4.6742e+03
# Epoch 5/100
# 0s - loss: -4.6932e+03 - val_loss: -4.7140e+03
# Epoch 6/100
# 0s - loss: -4.7278e+03 - val_loss: -4.7390e+03
# Epoch 7/100
# 0s - loss: -4.7606e+03 - val_loss: -4.7763e+03
# Epoch 8/100
# 0s - loss: -4.7902e+03 - val_loss: -4.8090e+03
# Epoch 9/100
# 0s - loss: -4.8203e+03 - val_loss: -4.8248e+03
# Epoch 10/100
# 0s - loss: -4.8406e+03 - val_loss: -4.8550e+03
# Epoch 11/100
# 0s - loss: -4.8708e+03 - val_loss: -4.8819e+03
# Epoch 12/100
# 0s - loss: -4.8849e+03 - val_loss: -4.8775e+03
# Epoch 13/100
# 0s - loss: -4.8857e+03 - val_loss: -4.8902e+03
# Epoch 14/100
# 0s - loss: -4.8945e+03 - val_loss: -4.9039e+03
# Epoch 15/100
# 0s - loss: -4.9075e+03 - val_loss: -4.9076e+03
# Epoch 16/100
# 0s - loss: -4.9245e+03 - val_loss: -4.9432e+03
# Epoch 17/100
# 0s - loss: -4.9494e+03 - val_loss: -4.9564e+03
# Epoch 18/100
# 0s - loss: -4.9691e+03 - val_loss: -4.9846e+03
# Epoch 19/100
# 0s - loss: -4.9900e+03 - val_loss: -5.0016e+03
# Epoch 20/100
# 0s - loss: -5.0076e+03 - val_loss: -5.0177e+03
# Epoch 21/100
# 0s - loss: -5.0187e+03 - val_loss: -5.0219e+03
# Epoch 22/100
# 0s - loss: -5.0259e+03 - val_loss: -5.0300e+03
# Epoch 23/100
# 0s - loss: -5.0375e+03 - val_loss: -5.0372e+03
# Epoch 24/100
# 0s - loss: -5.0359e+03 - val_loss: -5.0449e+03
# Epoch 25/100
# 0s - loss: -5.0504e+03 - val_loss: -5.0574e+03
# Epoch 26/100
# 0s - loss: -5.0663e+03 - val_loss: -5.0734e+03
# Epoch 27/100
# 0s - loss: -5.0765e+03 - val_loss: -5.0752e+03
# Epoch 28/100
# 0s - loss: -5.0849e+03 - val_loss: -5.0934e+03
# Epoch 29/100
# 0s - loss: -5.0958e+03 - val_loss: -5.0965e+03
# Epoch 30/100
# 0s - loss: -5.0950e+03 - val_loss: -5.0956e+03
# Epoch 31/100
# 0s - loss: -5.0999e+03 - val_loss: -5.1066e+03
# Epoch 32/100
# 0s - loss: -5.1083e+03 - val_loss: -5.1118e+03
# Epoch 33/100
# 0s - loss: -5.1110e+03 - val_loss: -5.1102e+03
# Epoch 34/100
# 0s - loss: -5.1128e+03 - val_loss: -5.1142e+03
# Epoch 35/100
# 0s - loss: -5.1137e+03 - val_loss: -5.1138e+03
# Epoch 36/100
# 0s - loss: -5.1137e+03 - val_loss: -5.1162e+03
# Epoch 37/100
# 0s - loss: -5.1164e+03 - val_loss: -5.1194e+03
# Epoch 38/100
# 0s - loss: -5.1232e+03 - val_loss: -5.1279e+03
# Epoch 39/100
# 0s - loss: -5.1382e+03 - val_loss: -5.1477e+03
# Epoch 40/100
# 0s - loss: -5.1491e+03 - val_loss: -5.1508e+03
# Epoch 41/100
# 0s - loss: -5.1548e+03 - val_loss: -5.1554e+03
# Epoch 42/100
# 0s - loss: -5.1599e+03 - val_loss: -5.1625e+03
# Epoch 43/100
# 0s - loss: -5.1696e+03 - val_loss: -5.1717e+03
# Epoch 44/100
# 0s - loss: -5.1717e+03 - val_loss: -5.1737e+03
# Epoch 45/100
# 0s - loss: -5.1697e+03 - val_loss: -5.1722e+03
# Epoch 46/100
# 0s - loss: -5.1760e+03 - val_loss: -5.1872e+03
# Epoch 47/100
# 0s - loss: -5.1893e+03 - val_loss: -5.1898e+03
# Epoch 48/100
# 0s - loss: -5.1869e+03 - val_loss: -5.1850e+03
# Epoch 49/100
# 0s - loss: -4.5577e+03 - val_loss: -4.8597e+03
# Epoch 50/100
# 0s - loss: -5.0362e+03 - val_loss: -5.1000e+03
# Epoch 51/100
# 0s - loss: -5.1230e+03 - val_loss: -5.1422e+03
# Epoch 52/100
# 0s - loss: -5.1610e+03 - val_loss: -5.1791e+03
# Epoch 53/100
# 0s - loss: -5.1881e+03 - val_loss: -5.1970e+03
# Epoch 54/100
# 0s - loss: -5.1997e+03 - val_loss: -5.2028e+03
# Epoch 55/100
# 0s - loss: -5.2055e+03 - val_loss: -5.2067e+03
# Epoch 56/100
# 0s - loss: -5.2131e+03 - val_loss: -5.2199e+03
# Epoch 57/100
# 0s - loss: -5.2193e+03 - val_loss: -5.2185e+03
# Epoch 58/100
# 0s - loss: -5.2204e+03 - val_loss: -5.2220e+03
# Epoch 59/100
# 0s - loss: -5.2247e+03 - val_loss: -5.2302e+03
# Epoch 60/100
# 0s - loss: -5.2300e+03 - val_loss: -5.2303e+03
# Epoch 61/100
# 0s - loss: -5.2303e+03 - val_loss: -5.2315e+03
# Epoch 62/100
# 0s - loss: -5.2311e+03 - val_loss: -5.2303e+03
# Epoch 63/100
# 0s - loss: -5.2324e+03 - val_loss: -5.2359e+03
# Epoch 64/100
# 0s - loss: -5.2348e+03 - val_loss: -5.2334e+03
# Epoch 65/100
# 0s - loss: -5.2333e+03 - val_loss: -5.2322e+03
# Epoch 66/100
# 0s - loss: -5.2333e+03 - val_loss: -5.2360e+03
# Epoch 67/100
# 0s - loss: -5.2390e+03 - val_loss: -5.2423e+03
# Epoch 68/100
# 0s - loss: -5.2433e+03 - val_loss: -5.2464e+03
# Epoch 69/100
# 0s - loss: -5.2466e+03 - val_loss: -5.2469e+03
# Epoch 70/100
# 0s - loss: -5.2459e+03 - val_loss: -5.2454e+03
# Epoch 71/100
# 0s - loss: -5.2490e+03 - val_loss: -5.2509e+03
# Epoch 72/100
# 0s - loss: -5.2556e+03 - val_loss: -5.2610e+03
# Epoch 73/100
# 0s - loss: -5.2637e+03 - val_loss: -5.2680e+03
# Epoch 74/100
# 0s - loss: -5.2685e+03 - val_loss: -5.2695e+03
# Epoch 75/100
# 0s - loss: -5.2698e+03 - val_loss: -5.2709e+03
# Epoch 76/100
# 0s - loss: -5.2725e+03 - val_loss: -5.2818e+03
# Epoch 77/100
# 0s - loss: -5.2860e+03 - val_loss: -5.2885e+03
# Epoch 78/100
# 0s - loss: -5.2886e+03 - val_loss: -5.2860e+03
# Epoch 79/100
# 0s - loss: -5.2894e+03 - val_loss: -5.2907e+03
# Epoch 80/100
# 0s - loss: -5.2925e+03 - val_loss: -5.2919e+03
# Epoch 81/100
# 0s - loss: -5.2940e+03 - val_loss: -5.2969e+03
# Epoch 82/100
# 0s - loss: -5.3001e+03 - val_loss: -5.3041e+03
# Epoch 83/100
# 0s - loss: -5.3040e+03 - val_loss: -5.3041e+03
# Epoch 84/100
# 0s - loss: -5.3071e+03 - val_loss: -5.3110e+03
# Epoch 85/100
# 0s - loss: -5.3112e+03 - val_loss: -5.3100e+03
# Epoch 86/100
# 0s - loss: -5.3138e+03 - val_loss: -5.3171e+03
# Epoch 87/100
# 0s - loss: -5.3190e+03 - val_loss: -5.3220e+03
# Epoch 88/100
# 0s - loss: -5.3275e+03 - val_loss: -5.3297e+03
# Epoch 89/100
# 0s - loss: -5.3285e+03 - val_loss: -5.3290e+03
# Epoch 90/100
# 0s - loss: -5.3205e+03 - val_loss: -5.3201e+03
# Epoch 91/100
# 0s - loss: -5.3183e+03 - val_loss: -5.3106e+03
# Epoch 92/100
# 0s - loss: -5.3064e+03 - val_loss: -5.3143e+03
# Epoch 93/100
# 0s - loss: -5.3185e+03 - val_loss: -5.3205e+03
# Epoch 94/100
# 0s - loss: -5.3244e+03 - val_loss: -5.3266e+03
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =3965
# SourceData's aborting data = 22
# window shape is (3965, 1024, 1)
# hiden node = 16
# -edim=16-Window=1024-Overlap=64-l1_reg=10e-5
# Train on 3965 samples, validate on 3965 samples
# Epoch 1/100
# 0s - loss: -3.9675e+03 - val_loss: -4.2579e+03
# Epoch 2/100
# 0s - loss: -4.3472e+03 - val_loss: -4.4218e+03
# Epoch 3/100
# 0s - loss: -4.4877e+03 - val_loss: -4.5510e+03
# Epoch 4/100
# 0s - loss: -4.5898e+03 - val_loss: -4.6186e+03
# Epoch 5/100
# 0s - loss: -4.6453e+03 - val_loss: -4.6672e+03
# Epoch 6/100
# 0s - loss: -4.6936e+03 - val_loss: -4.7154e+03
# Epoch 7/100
# 0s - loss: -4.7388e+03 - val_loss: -4.7623e+03
# Epoch 8/100
# 0s - loss: -4.7781e+03 - val_loss: -4.7968e+03
# Epoch 9/100
# 0s - loss: -4.8071e+03 - val_loss: -4.8179e+03
# Epoch 10/100
# ...
# 1s - loss: -1.9233e+04 - val_loss: -1.9237e+04
# Epoch 43/100
# 0s - loss: -1.9239e+04 - val_loss: -1.9241e+04
# Epoch 44/100
# 1s - loss: -1.9245e+04 - val_loss: -1.9252e+04
# Epoch 45/100
# 1s - loss: -1.9252e+04 - val_loss: -1.9262e+04
# Epoch 46/100
# 1s - loss: -1.9265e+04 - val_loss: -1.9266e+04
# Epoch 47/100
# 1s - loss: -1.9276e+04 - val_loss: -1.9288e+04
# Epoch 48/100
# 1s - loss: -1.9290e+04 - val_loss: -1.9296e+04
# Epoch 49/100
# 1s - loss: -1.9297e+04 - val_loss: -1.9293e+04
# Epoch 50/100
# 1s - loss: -1.9302e+04 - val_loss: -1.9307e+04
# Epoch 51/100
# 1s - loss: -1.9311e+04 - val_loss: -1.9316e+04
# Epoch 52/100
# 1s - loss: -1.9316e+04 - val_loss: -1.9324e+04
# Epoch 53/100
# 1s - loss: -1.9326e+04 - val_loss: -1.9326e+04
# Epoch 54/100
# 1s - loss: -1.9334e+04 - val_loss: -1.9339e+04
# Epoch 55/100
# 1s - loss: -1.9342e+04 - val_loss: -1.9343e+04
# Epoch 56/100
# 1s - loss: -1.9349e+04 - val_loss: -1.9351e+04
# Epoch 57/100
# 1s - loss: -1.9356e+04 - val_loss: -1.9365e+04
# Epoch 58/100
# 1s - loss: -1.9372e+04 - val_loss: -1.9378e+04
# Epoch 59/100
# 1s - loss: -1.9383e+04 - val_loss: -1.9391e+04
# Epoch 60/100
# 1s - loss: -1.9395e+04 - val_loss: -1.9400e+04
# Epoch 61/100
# 1s - loss: -1.9402e+04 - val_loss: -1.9404e+04
# Epoch 62/100
# 1s - loss: -1.9408e+04 - val_loss: -1.9413e+04
# Epoch 63/100
# 1s - loss: -1.9416e+04 - val_loss: -1.9422e+04
# Epoch 64/100
# 1s - loss: -1.9422e+04 - val_loss: -1.9424e+04
# Epoch 65/100
# 1s - loss: -1.9430e+04 - val_loss: -1.9437e+04
# Epoch 66/100
# 1s - loss: -1.9441e+04 - val_loss: -1.9451e+04
# Epoch 67/100
# 1s - loss: -1.9455e+04 - val_loss: -1.9460e+04
# Epoch 68/100
# 1s - loss: -1.9465e+04 - val_loss: -1.9471e+04
# Epoch 69/100
# 1s - loss: -1.9473e+04 - val_loss: -1.9485e+04
# Epoch 70/100
# 1s - loss: -1.9488e+04 - val_loss: -1.9492e+04
# Epoch 71/100
# 1s - loss: -1.9492e+04 - val_loss: -1.9494e+04
# Epoch 72/100
# 1s - loss: -1.9497e+04 - val_loss: -1.9499e+04
# Epoch 73/100
# 1s - loss: -1.9503e+04 - val_loss: -1.9507e+04
# Epoch 74/100
# 1s - loss: -1.9510e+04 - val_loss: -1.9515e+04
# Epoch 75/100
# 1s - loss: -1.9517e+04 - val_loss: -1.9520e+04
# Epoch 76/100
# 1s - loss: -1.9524e+04 - val_loss: -1.9526e+04
# Epoch 77/100
# 1s - loss: -1.9528e+04 - val_loss: -1.9532e+04
# Epoch 78/100
# 1s - loss: -1.9533e+04 - val_loss: -1.9539e+04
# Epoch 79/100
# 1s - loss: -1.9541e+04 - val_loss: -1.9542e+04
# Epoch 80/100
# 1s - loss: -1.9544e+04 - val_loss: -1.9549e+04
# Epoch 81/100
# 1s - loss: -1.9549e+04 - val_loss: -1.9547e+04
# Epoch 82/100
# 1s - loss: -1.9552e+04 - val_loss: -1.9558e+04
# Epoch 83/100
# 1s - loss: -1.9557e+04 - val_loss: -1.9562e+04
# Epoch 84/100
# 1s - loss: -1.9563e+04 - val_loss: -1.9564e+04
# Epoch 85/100
# 1s - loss: -1.9565e+04 - val_loss: -1.9568e+04
# Epoch 86/100
# 1s - loss: -1.9570e+04 - val_loss: -1.9572e+04
# Epoch 87/100
# 1s - loss: -1.9575e+04 - val_loss: -1.9578e+04
# Epoch 88/100
# 1s - loss: -1.9582e+04 - val_loss: -1.9590e+04
# Epoch 89/100
# 1s - loss: -1.9592e+04 - val_loss: -1.9595e+04
# Epoch 90/100
# 1s - loss: -1.9595e+04 - val_loss: -1.9596e+04
# Epoch 91/100
# 1s - loss: -1.9601e+04 - val_loss: -1.9608e+04
# Epoch 92/100
# 1s - loss: -1.9611e+04 - val_loss: -1.9615e+04
# Epoch 93/100
# 1s - loss: -1.9617e+04 - val_loss: -1.9622e+04
# Epoch 94/100
# 1s - loss: -1.9626e+04 - val_loss: -1.9629e+04
# Epoch 95/100
# 1s - loss: -1.9633e+04 - val_loss: -1.9638e+04
# Epoch 96/100
# 1s - loss: -1.9641e+04 - val_loss: -1.9647e+04
# Epoch 97/100
# 1s - loss: -1.9650e+04 - val_loss: -1.9656e+04
# Epoch 98/100
# 1s - loss: -1.9656e+04 - val_loss: -1.9659e+04
# Epoch 99/100
# 1s - loss: -1.9658e+04 - val_loss: -1.9662e+04
# Epoch 100/100
# 1s - loss: -1.9667e+04 - val_loss: -1.9669e+04
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =1959
# SourceData's aborting data = 22
# window shape is (1959, 4096, 1)
# hiden node = 16
# -edim=16-Window=4096-Overlap=128-l1_reg=10e-5
# Train on 1959 samples, validate on 1959 samples
# Epoch 1/100
# 0s - loss: -1.5354e+04 - val_loss: -1.6092e+04
# Epoch 2/100
# 0s - loss: -1.6402e+04 - val_loss: -1.6869e+04
# Epoch 3/100
# 0s - loss: -1.7082e+04 - val_loss: -1.7319e+04
# Epoch 4/100
# 0s - loss: -1.7385e+04 - val_loss: -1.7502e+04
# Epoch 5/100
# 0s - loss: -1.7549e+04 - val_loss: -1.7653e+04
# Epoch 6/100
# 0s - loss: -1.7698e+04 - val_loss: -1.7788e+04
# Epoch 7/100
# 0s - loss: -1.7832e+04 - val_loss: -1.7896e+04
# Epoch 8/100
# 0s - loss: -1.7937e+04 - val_loss: -1.8000e+04
# Epoch 9/100
# 0s - loss: -1.8033e+04 - val_loss: -1.8086e+04
# Epoch 10/100
# 0s - loss: -1.8118e+04 - val_loss: -1.8168e+04
# Epoch 11/100
# 0s - loss: -1.8192e+04 - val_loss: -1.8231e+04
# Epoch 12/100
# 0s - loss: -1.8267e+04 - val_loss: -1.8309e+04
# Epoch 13/100
# 0s - loss: -1.8330e+04 - val_loss: -1.8371e+04
# Epoch 14/100
# 0s - loss: -1.8404e+04 - val_loss: -1.8436e+04
# Epoch 15/100
# 0s - loss: -1.8448e+04 - val_loss: -1.8480e+04
# Epoch 16/100
# 0s - loss: -1.8502e+04 - val_loss: -1.8520e+04
# Epoch 17/100
# 0s - loss: -1.8539e+04 - val_loss: -1.8567e+04
# Epoch 18/100
# 0s - loss: -1.8587e+04 - val_loss: -1.8604e+04
# Epoch 19/100
# 0s - loss: -1.8624e+04 - val_loss: -1.8647e+04
# Epoch 20/100
# 0s - loss: -1.8668e+04 - val_loss: -1.8689e+04
# Epoch 21/100
# 0s - loss: -1.8704e+04 - val_loss: -1.8729e+04
# Epoch 22/100
# 0s - loss: -1.8738e+04 - val_loss: -1.8755e+04
# Epoch 23/100
# 0s - loss: -1.8756e+04 - val_loss: -1.8758e+04
# Epoch 24/100
# 0s - loss: -1.8762e+04 - val_loss: -1.8771e+04
# Epoch 25/100
# 0s - loss: -1.8788e+04 - val_loss: -1.8800e+04
# Epoch 26/100
# 0s - loss: -1.8806e+04 - val_loss: -1.8814e+04
# Epoch 27/100
# 0s - loss: -1.8826e+04 - val_loss: -1.8843e+04
# Epoch 28/100
# 0s - loss: -1.8858e+04 - val_loss: -1.8875e+04
# Epoch 29/100
# 0s - loss: -1.8886e+04 - val_loss: -1.8894e+04
# Epoch 30/100
# 0s - loss: -1.8905e+04 - val_loss: -1.8926e+04
# Epoch 31/100
# 0s - loss: -1.8932e+04 - val_loss: -1.8957e+04
# Epoch 32/100
# 0s - loss: -1.8962e+04 - val_loss: -1.8967e+04
# Epoch 33/100
# 0s - loss: -1.8979e+04 - val_loss: -1.8997e+04
# Epoch 34/100
# 0s - loss: -1.9003e+04 - val_loss: -1.9008e+04
# Epoch 35/100
# 0s - loss: -1.9019e+04 - val_loss: -1.9043e+04
# Epoch 36/100
# 0s - loss: -1.9046e+04 - val_loss: -1.9054e+04
# Epoch 37/100
# 0s - loss: -1.9056e+04 - val_loss: -1.9064e+04
# Epoch 38/100
# 0s - loss: -1.9074e+04 - val_loss: -1.9089e+04
# Epoch 39/100
# 0s - loss: -1.9088e+04 - val_loss: -1.9090e+04
# Epoch 40/100
# 0s - loss: -1.9097e+04 - val_loss: -1.9107e+04
# Epoch 41/100
# 0s - loss: -1.9114e+04 - val_loss: -1.9120e+04
# Epoch 42/100
# 0s - loss: -1.9132e+04 - val_loss: -1.9146e+04
# Epoch 43/100
# 0s - loss: -1.9146e+04 - val_loss: -1.9156e+04
# Epoch 44/100
# 0s - loss: -1.9158e+04 - val_loss: -1.9157e+04
# Epoch 45/100
# 0s - loss: -1.9167e+04 - val_loss: -1.9172e+04
# Epoch 46/100
# 0s - loss: -1.9178e+04 - val_loss: -1.9183e+04
# Epoch 47/100
# 0s - loss: -1.9187e+04 - val_loss: -1.9196e+04
# Epoch 48/100
# 0s - loss: -1.9202e+04 - val_loss: -1.9215e+04
# Epoch 49/100
# 0s - loss: -1.9224e+04 - val_loss: -1.9227e+04
# Epoch 50/100
# 0s - loss: -1.9229e+04 - val_loss: -1.9232e+04
# Epoch 51/100
# 0s - loss: -1.9247e+04 - val_loss: -1.9261e+04
# Epoch 52/100
# 0s - loss: -1.9263e+04 - val_loss: -1.9271e+04
# Epoch 53/100
# 0s - loss: -1.9271e+04 - val_loss: -1.9272e+04
# Epoch 54/100
# 0s - loss: -1.9276e+04 - val_loss: -1.9283e+04
# Epoch 55/100
# 0s - loss: -1.9282e+04 - val_loss: -1.9289e+04
# Epoch 56/100
# 0s - loss: -1.9295e+04 - val_loss: -1.9296e+04
# Epoch 57/100
# 0s - loss: -1.9302e+04 - val_loss: -1.9317e+04
# Epoch 58/100
# 0s - loss: -1.9321e+04 - val_loss: -1.9323e+04
# Epoch 59/100
# 0s - loss: -1.9327e+04 - val_loss: -1.9335e+04
# Epoch 60/100
# 0s - loss: -1.9340e+04 - val_loss: -1.9343e+04
# Epoch 61/100
# 0s - loss: -1.9353e+04 - val_loss: -1.9363e+04
# Epoch 62/100
# 0s - loss: -1.9366e+04 - val_loss: -1.9376e+04
# Epoch 63/100
# 0s - loss: -1.9383e+04 - val_loss: -1.9388e+04
# Epoch 64/100
# 0s - loss: -1.9395e+04 - val_loss: -1.9403e+04
# Epoch 65/100
# 0s - loss: -1.9406e+04 - val_loss: -1.9415e+04
# Epoch 66/100
# 0s - loss: -1.9417e+04 - val_loss: -1.9426e+04
# Epoch 67/100
# 0s - loss: -1.9426e+04 - val_loss: -1.9433e+04
# Epoch 68/100
# 0s - loss: -1.9439e+04 - val_loss: -1.9443e+04
# Epoch 69/100
# 0s - loss: -1.9447e+04 - val_loss: -1.9451e+04
# Epoch 70/100
# 0s - loss: -1.9460e+04 - val_loss: -1.9466e+04
# Epoch 71/100
# 0s - loss: -1.9471e+04 - val_loss: -1.9478e+04
# Epoch 72/100
# 0s - loss: -1.9481e+04 - val_loss: -1.9484e+04
# Epoch 73/100
# 0s - loss: -1.9488e+04 - val_loss: -1.9491e+04
# Epoch 74/100
# 0s - loss: -1.9491e+04 - val_loss: -1.9498e+04
# Epoch 75/100
# 0s - loss: -1.9497e+04 - val_loss: -1.9500e+04
# Epoch 76/100
# 0s - loss: -1.9506e+04 - val_loss: -1.9510e+04
# Epoch 77/100
# 0s - loss: -1.9512e+04 - val_loss: -1.9515e+04
# Epoch 78/100
# 0s - loss: -1.9521e+04 - val_loss: -1.9527e+04
# Epoch 79/100
# 0s - loss: -1.9528e+04 - val_loss: -1.9533e+04
# Epoch 80/100
# 0s - loss: -1.9537e+04 - val_loss: -1.9542e+04
# Epoch 81/100
# 0s - loss: -1.9544e+04 - val_loss: -1.9548e+04
# Epoch 82/100
# 0s - loss: -1.9553e+04 - val_loss: -1.9558e+04
# Epoch 83/100
# 0s - loss: -1.9561e+04 - val_loss: -1.9564e+04
# Epoch 84/100
# 0s - loss: -1.9564e+04 - val_loss: -1.9568e+04
# Epoch 85/100
# 0s - loss: -1.9571e+04 - val_loss: -1.9579e+04
# Epoch 86/100
# 0s - loss: -1.9580e+04 - val_loss: -1.9583e+04
# Epoch 87/100
# 0s - loss: -1.9587e+04 - val_loss: -1.9593e+04
# Epoch 88/100
# 0s - loss: -1.9594e+04 - val_loss: -1.9602e+04
# Epoch 89/100
# 0s - loss: -1.9604e+04 - val_loss: -1.9610e+04
# Epoch 90/100
# 0s - loss: -1.9611e+04 - val_loss: -1.9611e+04
# Epoch 91/100
# 0s - loss: -1.9613e+04 - val_loss: -1.9615e+04
# Epoch 92/100
# 0s - loss: -1.9618e+04 - val_loss: -1.9616e+04
# Epoch 93/100
# 0s - loss: -1.9619e+04 - val_loss: -1.9622e+04
# Epoch 94/100
# 0s - loss: -1.9626e+04 - val_loss: -1.9629e+04
# Epoch 95/100
# 0s - loss: -1.9633e+04 - val_loss: -1.9637e+04
# Epoch 96/100
# 0s - loss: -1.9639e+04 - val_loss: -1.9639e+04
# Epoch 97/100
# 0s - loss: -1.9642e+04 - val_loss: -1.9645e+04
# Epoch 98/100
# 0s - loss: -1.9647e+04 - val_loss: -1.9650e+04
# Epoch 99/100
# 0s - loss: -1.9652e+04 - val_loss: -1.9653e+04
# Epoch 100/100
# 0s - loss: -1.9655e+04 - val_loss: -1.9662e+04
# AccY is registed now
# Build Complete
# (254742,)
# windowData's num =980
# SourceData's aborting data = 22
# window shape is (980, 4096, 1)
# hiden node = 16
# -edim=16-Window=4096-Overlap=256-l1_reg=10e-5
# Train on 980 samples, validate on 980 samples
# Epoch 1/100
# 0s - loss: -1.5278e+04 - val_loss: -1.5590e+04
# Epoch 2/100
# 0s - loss: -1.5705e+04 - val_loss: -1.6039e+04
# Epoch 3/100
# 0s - loss: -1.6164e+04 - val_loss: -1.6558e+04
# Epoch 4/100
# 0s - loss: -1.6647e+04 - val_loss: -1.6911e+04
# Epoch 5/100
# 0s - loss: -1.6970e+04 - val_loss: -1.7172e+04
# Epoch 6/100
# 0s - loss: -1.7230e+04 - val_loss: -1.7401e+04
# Epoch 7/100
# 0s - loss: -1.7453e+04 - val_loss: -1.7595e+04
# Epoch 8/100
# 0s - loss: -1.7625e+04 - val_loss: -1.7716e+04
# Epoch 9/100
# 0s - loss: -1.7734e+04 - val_loss: -1.7823e+04
# Epoch 10/100
# 0s - loss: -1.7840e+04 - val_loss: -1.7877e+04
# Epoch 11/100
# 0s - loss: -1.7908e+04 - val_loss: -1.7978e+04
# Epoch 12/100
# 0s - loss: -1.7993e+04 - val_loss: -1.8072e+04
# Epoch 13/100
# 0s - loss: -1.8081e+04 - val_loss: -1.8109e+04
# Epoch 14/100
# 0s - loss: -1.8114e+04 - val_loss: -1.8156e+04
# Epoch 15/100
# 0s - loss: -1.8158e+04 - val_loss: -1.8192e+04
# Epoch 16/100
# 0s - loss: -1.8207e+04 - val_loss: -1.8233e+04
# Epoch 17/100
# 0s - loss: -1.8245e+04 - val_loss: -1.8278e+04
# Epoch 18/100
# 0s - loss: -1.8288e+04 - val_loss: -1.8305e+04
# Epoch 19/100
# 0s - loss: -1.8316e+04 - val_loss: -1.8355e+04
# Epoch 20/100
# 0s - loss: -1.8358e+04 - val_loss: -1.8384e+04
# Epoch 21/100
# 0s - loss: -1.8393e+04 - val_loss: -1.8441e+04
# Epoch 22/100
# 0s - loss: -1.8447e+04 - val_loss: -1.8471e+04
# Epoch 23/100
# 0s - loss: -1.8481e+04 - val_loss: -1.8513e+04
# Epoch 24/100
# 0s - loss: -1.8521e+04 - val_loss: -1.8540e+04
# Epoch 25/100
# 0s - loss: -1.8547e+04 - val_loss: -1.8575e+04
# Epoch 26/100
# 0s - loss: -1.8577e+04 - val_loss: -1.8600e+04
# Epoch 27/100
# 0s - loss: -1.8600e+04 - val_loss: -1.8613e+04
# Epoch 28/100
# 0s - loss: -1.8616e+04 - val_loss: -1.8637e+04
# Epoch 29/100
# 0s - loss: -1.8639e+04 - val_loss: -1.8669e+04
# Epoch 30/100
# 0s - loss: -1.8674e+04 - val_loss: -1.8690e+04
# Epoch 31/100
# 0s - loss: -1.8692e+04 - val_loss: -1.8719e+04
# Epoch 32/100
# 0s - loss: -1.8720e+04 - val_loss: -1.8733e+04
# Epoch 33/100
# 0s - loss: -1.8736e+04 - val_loss: -1.8744e+04
# Epoch 34/100
# 0s - loss: -1.8751e+04 - val_loss: -1.8763e+04
# Epoch 35/100
# 0s - loss: -1.8771e+04 - val_loss: -1.8798e+04
# Epoch 36/100
# 0s - loss: -1.8806e+04 - val_loss: -1.8826e+04
# Epoch 37/100
# 0s - loss: -1.8831e+04 - val_loss: -1.8843e+04
# Epoch 38/100
# 0s - loss: -1.8850e+04 - val_loss: -1.8863e+04
# Epoch 39/100
# 0s - loss: -1.8861e+04 - val_loss: -1.8877e+04
# Epoch 40/100
# 0s - loss: -1.8876e+04 - val_loss: -1.8895e+04
# Epoch 41/100
# 0s - loss: -1.8904e+04 - val_loss: -1.8908e+04
# Epoch 42/100
# 0s - loss: -1.8910e+04 - val_loss: -1.8917e+04
# Epoch 43/100
# 0s - loss: -1.8930e+04 - val_loss: -1.8946e+04
# Epoch 44/100
# 0s - loss: -1.8947e+04 - val_loss: -1.8941e+04
# Epoch 45/100
# 0s - loss: -1.8949e+04 - val_loss: -1.8971e+04
# Epoch 46/100
# 0s - loss: -1.8970e+04 - val_loss: -1.8970e+04
# Epoch 47/100
# 0s - loss: -1.8977e+04 - val_loss: -1.8974e+04
# Epoch 48/100
# 0s - loss: -1.8987e+04 - val_loss: -1.9003e+04
# Epoch 49/100
# 0s - loss: -1.9005e+04 - val_loss: -1.9021e+04
# Epoch 50/100
# 0s - loss: -1.9025e+04 - val_loss: -1.9032e+04
# Epoch 51/100
# 0s - loss: -1.9036e+04 - val_loss: -1.9040e+04
# Epoch 52/100
# 0s - loss: -1.9045e+04 - val_loss: -1.9069e+04
# Epoch 53/100
# 0s - loss: -1.9071e+04 - val_loss: -1.9068e+04
# Epoch 54/100
# 0s - loss: -1.9075e+04 - val_loss: -1.9095e+04
# Epoch 55/100
# 0s - loss: -1.9098e+04 - val_loss: -1.9109e+04
# Epoch 56/100
# 0s - loss: -1.9116e+04 - val_loss: -1.9127e+04
# Epoch 57/100
# 0s - loss: -1.9132e+04 - val_loss: -1.9145e+04
# Epoch 58/100
# 0s - loss: -1.9148e+04 - val_loss: -1.9152e+04
# Epoch 59/100
# 0s - loss: -1.9152e+04 - val_loss: -1.9158e+04
# Epoch 60/100
# 0s - loss: -1.9165e+04 - val_loss: -1.9173e+04
# Epoch 61/100
# 0s - loss: -1.9175e+04 - val_loss: -1.9184e+04
# Epoch 62/100
# 0s - loss: -1.9183e+04 - val_loss: -1.9191e+04
# Epoch 63/100
# 0s - loss: -1.9192e+04 - val_loss: -1.9202e+04
# Epoch 64/100
# 0s - loss: -1.9202e+04 - val_loss: -1.9207e+04
# Epoch 65/100
# 0s - loss: -1.9213e+04 - val_loss: -1.9222e+04
# Epoch 66/100
# 0s - loss: -1.9225e+04 - val_loss: -1.9229e+04
# Epoch 67/100
# 0s - loss: -1.9231e+04 - val_loss: -1.9237e+04
# Epoch 68/100
# 0s - loss: -1.9241e+04 - val_loss: -1.9248e+04
# Epoch 69/100
# 0s - loss: -1.9255e+04 - val_loss: -1.9262e+04
# Epoch 70/100
# 0s - loss: -1.9268e+04 - val_loss: -1.9274e+04
# Epoch 71/100
# 0s - loss: -1.9278e+04 - val_loss: -1.9278e+04
# Epoch 72/100
# 0s - loss: -1.9280e+04 - val_loss: -1.9295e+04
# Epoch 73/100
# 0s - loss: -1.9294e+04 - val_loss: -1.9305e+04
# Epoch 74/100
# 0s - loss: -1.9306e+04 - val_loss: -1.9303e+04
# Epoch 75/100
# 0s - loss: -1.9308e+04 - val_loss: -1.9322e+04
# Epoch 76/100
# 0s - loss: -1.9325e+04 - val_loss: -1.9328e+04
# Epoch 77/100
# 0s - loss: -1.9331e+04 - val_loss: -1.9330e+04
# Epoch 78/100
# 0s - loss: -1.9332e+04 - val_loss: -1.9345e+04
# Epoch 79/100
# 0s - loss: -1.9346e+04 - val_loss: -1.9353e+04
# Epoch 80/100
# 0s - loss: -1.9353e+04 - val_loss: -1.9365e+04
# Epoch 81/100
# 0s - loss: -1.9368e+04 - val_loss: -1.9375e+04
# Epoch 82/100
# 0s - loss: -1.9374e+04 - val_loss: -1.9381e+04
# Epoch 83/100
# 0s - loss: -1.9385e+04 - val_loss: -1.9384e+04
# Epoch 84/100
# 0s - loss: -1.9388e+04 - val_loss: -1.9391e+04
# Epoch 85/100
# 0s - loss: -1.9393e+04 - val_loss: -1.9389e+04
# Epoch 86/100
# 0s - loss: -1.9395e+04 - val_loss: -1.9413e+04
# Epoch 87/100
# 0s - loss: -1.9416e+04 - val_loss: -1.9414e+04
# Epoch 88/100
# 0s - loss: -1.9419e+04 - val_loss: -1.9430e+04
# Epoch 89/100
# 0s - loss: -1.9434e+04 - val_loss: -1.9448e+04
# Epoch 90/100
# 0s - loss: -1.9449e+04 - val_loss: -1.9449e+04
# Epoch 91/100
# 0s - loss: -1.9455e+04 - val_loss: -1.9459e+04
# Epoch 92/100
# 0s - loss: -1.9466e+04 - val_loss: -1.9471e+04
# Epoch 93/100
# 0s - loss: -1.9474e+04 - val_loss: -1.9473e+04
# Epoch 94/100
# 0s - loss: -1.9476e+04 - val_loss: -1.9484e+04
# Epoch 95/100
# 0s - loss: -1.9484e+04 - val_loss: -1.9489e+04
# Epoch 96/100
# 0s - loss: -1.9488e+04 - val_loss: -1.9492e+04
# Epoch 97/100
# 0s - loss: -1.9492e+04 - val_loss: -1.9490e+04
# Epoch 98/100
# 0s - loss: -1.9494e+04 - val_loss: -1.9498e+04
# Epoch 99/100
# 0s - loss: -1.9500e+04 - val_loss: -1.9509e+04
# Epoch 100/100
# 0s - loss: -1.9507e+04 - val_loss: -1.9513e+04

# %%
print "finish"
# Out:
# finish
