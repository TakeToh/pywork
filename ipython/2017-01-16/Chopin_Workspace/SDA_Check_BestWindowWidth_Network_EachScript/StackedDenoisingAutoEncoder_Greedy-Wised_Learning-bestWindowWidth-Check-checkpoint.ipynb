# %%
import numpy as np
import datetime
import os
import copy
# Generate WindowFrame Function
from mymodule import window
import joblib
import pandas as pd

from tqdm import tqdm,tqdm_notebook

# Parametor about Sensor
SensorNum=1 # Sensor number
#SensorAxis='AccX' # Axis

# Define Data Name
DATE= str( datetime.date.today() )+'/'

# Parametor about " Data Path"
StorePath = "/media/takeyama/HD-PNFU3/02_ActivityResearch/"

ParticipantsNum="Participants07/"
Version = "01_First/"
Time = "01_First/"
CommonName = 'Participants07-First-01'
LabelName = CommonName+'.csv'

TITLE = ParticipantsNum+Version

DataPath = StorePath+ParticipantsNum+Version+"RawData/"+Time

if not os.path.exists(StorePath+TITLE+'LabelData/'+Time): 
    os.makedirs(StorePath+TITLE+'LabelData/'+Time)
LabelDataPath=StorePath+TITLE+'LabelData/'+Time

if not os.path.exists(StorePath+TITLE+'dictionary/'+Time): 
    os.makedirs(StorePath+TITLE+'dictionary/'+Time)
DictionaryDataPath=StorePath+TITLE+'dictionary/'+Time

if not os.path.exists(StorePath+TITLE+'feature/'+Time): 
    os.makedirs(StorePath+TITLE+'feature/'+Time)
FeaturePath=StorePath+TITLE+'feature/'+Time

if not os.path.exists(StorePath+TITLE+'window/'+Time): 
    os.makedirs(StorePath+TITLE+'window/'+Time)
WindowDataPath=StorePath+TITLE+'window/'+Time

if not os.path.exists(StorePath+TITLE+DATE+'studyOutput/'+Time): 
    os.makedirs(StorePath+TITLE+DATE+'studyOutput/'+Time)
StudyOutputPath=StorePath+TITLE+DATE+'studyOutput/'+Time

if not os.path.exists(StorePath+TITLE+DATE+'parametor/'+Time): 
    os.makedirs(StorePath+TITLE+DATE+'parametor/'+Time)
ParametorPath=StorePath+TITLE+DATE+'parametor/'+Time

if not os.path.exists(StorePath+TITLE+DATE+'result/'+Time): 
    os.makedirs(StorePath+TITLE+DATE+'result/'+Time)
ResultPath=StorePath+TITLE+DATE+'result/'+Time

if not os.path.exists(StorePath+TITLE+DATE+'graph/'+Time): 
    os.makedirs(StorePath+TITLE+DATE+'graph/'+Time)
GraphPath=StorePath+TITLE+DATE+'graph/'+Time

if not os.path.exists(StorePath+TITLE+DATE+'anime/'+Time): 
    os.makedirs(StorePath+TITLE+DATE+'anime/'+Time)
AnimationPath=StorePath+TITLE+DATE+'anime/'+Time

# %%
# FFT library
from scipy import fftpack
from scipy import signal

# Graph Plot
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns

# Generate WindowFrame Function
from mymodule import window

# timer
import time

# temp file 
import tempfile

# pandas
import pandas as pd

# %matplotlib inline

# %%
DictName = os.listdir(DictionaryDataPath)
DictName.sort()
print DictName
Sensor1 = np.load(DictionaryDataPath+DictName[0])['data'][()]
Sensor2 = np.load(DictionaryDataPath+DictName[1])['data'][()]
Sensor3 = np.load(DictionaryDataPath+DictName[2])['data'][()]
Sensor4 = np.load(DictionaryDataPath+DictName[3])['data'][()]
Sensor6 = np.load(DictionaryDataPath+DictName[4])['data'][()]
Sensor6 = np.load(DictionaryDataPath+DictName[5])['data'][()]
Label = np.load(DictionaryDataPath+DictName[6])['data'][()]
# Out:
# ['01_LeftHand.npz', '02_RightHand.npz', '03_LeftLeg.npz', '04_Rightleg.npz', '05_West.npz', '06_Chest.npz', '07_LabelData.npz']

# %%
def GetWindowFrame(windowName, dataRaw, wWidth, sWidth, PATH):
    """
    data　ウィンドウフレームに変換するデータ
    registName　ウィンドウフレームに登録するデータの名前
    windowWidth　ウィンドウ幅
    slidingWidth　スライド幅
    PATH ウィドウフレームを保存するディレクトリ
    
    
    About Function:
        与えられたdataからウィンドウ幅windowWidth,スライド幅slidingWidthにしたがって
        registNameのウィドウフレームを返す．
        また，与えれたPATH内に同様なパラメータ( WindowWidth, slidingWidth)かつ同様な
        windowNameのものがある場合，そのデータを返す．
        この関数が登録，ウィンドウフレームに変換できるデータは１つとする
    """
    storedName = windowName+'_Win='+str(wWidth).zfill(4)+'_Sld='+str(sWidth).zfill(4)+'.npz'
    l = os.listdir(PATH)
    
    if storedName in l:
        print "this data had finished making"
        return np.load(PATH+storedName)['data'][()]
    
    w=window()
    w.SetData(windowName,dataRaw)    
    wind=w.Compile(wWidth,sWidth)
    windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
    np.savez(PATH+storedName,data=wind)

    return wind

# %%
import network
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 970 (CNMeM is disabled, cuDNN 4007)

# %%
# 試しにセンサー1の加速度XのデータをSAEにかけてみる
s = Sensor1
saxis = 'AccX'
windowNum=256
slidingNum=32
Nweight = 0.5

# %%
Sensor1['AccX'].shape
# Out:
# (826837,)

# %%
FileName = CommonName+'-'+s['Name']+'-'+saxis+\
            '-win='+str(windowNum).zfill(4)+'-sld='+str(slidingNum).zfill(4)+\
            '-NoiseWeight='+str(Nweight*100).zfill(3)
print FileName
x_test=GetWindowFrame(FileName,s[saxis],windowNum,slidingNum,WindowDataPath)
x_train = x_test + Nweight*np.random.normal(0,1,x_test.shape)
# Out:
# Participants07-First-01-01_LeftHand-AccX-win=0256-sld=0032-NoiseWeight=50.0
# this data had finished making

# %%
SAE=network.StackedAE(x_train,x_test,windowNum,windowNum,windowNum,CommonName)
# Out:
# Train on 25831 samples, validate on 25831 samples
# Epoch 1/100
# 0s - loss: 2.9959 - val_loss: 0.1151
# Epoch 2/100
# 0s - loss: 1.2867 - val_loss: 0.1592
# Epoch 3/100
# 1s - loss: 0.6532 - val_loss: 0.1964
# Epoch 4/100
# 1s - loss: 0.5148 - val_loss: 0.1677
# Epoch 5/100
# 0s - loss: 0.4849 - val_loss: 0.1636
# Epoch 6/100
# 1s - loss: 0.4756 - val_loss: 0.1435
# Epoch 7/100
# 1s - loss: 0.4708 - val_loss: 0.1528
# Epoch 8/100
# 0s - loss: 0.4670 - val_loss: 0.1611
# Epoch 9/100
# 1s - loss: 0.4652 - val_loss: 0.1529
# Epoch 10/100
# 1s - loss: 0.4631 - val_loss: 0.1467
# Epoch 11/100
# 0s - loss: 0.4628 - val_loss: 0.1427
# Epoch 12/100
# 0s - loss: 0.4614 - val_loss: 0.1424
# Epoch 13/100
# 1s - loss: 0.4610 - val_loss: 0.1482
# Epoch 14/100
# 0s - loss: 0.4608 - val_loss: 0.1646
# Epoch 15/100
# 0s - loss: 0.4607 - val_loss: 0.1385
# Epoch 16/100
# 1s - loss: 0.4598 - val_loss: 0.1303
# Epoch 17/100
# 0s - loss: 0.4598 - val_loss: 0.1358
# Epoch 18/100
# 0s - loss: 0.4585 - val_loss: 0.1469
# Epoch 19/100
# 1s - loss: 0.4587 - val_loss: 0.1466
# Epoch 20/100
# 0s - loss: 0.4583 - val_loss: 0.1465
# Epoch 21/100
# 0s - loss: 0.4584 - val_loss: 0.1445
# Epoch 22/100
# 1s - loss: 0.4583 - val_loss: 0.1418
# Epoch 23/100
# 0s - loss: 0.4578 - val_loss: 0.1323
# Epoch 24/100
# 0s - loss: 0.4577 - val_loss: 0.1275
# Epoch 25/100
# 1s - loss: 0.4570 - val_loss: 0.1334
# Epoch 26/100
# 0s - loss: 0.4570 - val_loss: 0.1383
# Epoch 27/100
# 0s - loss: 0.4567 - val_loss: 0.1294
# Epoch 28/100
# 1s - loss: 0.4564 - val_loss: 0.1459
# Epoch 29/100
# 0s - loss: 0.4565 - val_loss: 0.1288
# Epoch 30/100
# 0s - loss: 0.4563 - val_loss: 0.1281
# Epoch 31/100
# 1s - loss: 0.4553 - val_loss: 0.1334
# Epoch 32/100
# 0s - loss: 0.4558 - val_loss: 0.1477
# Epoch 33/100
# 0s - loss: 0.4553 - val_loss: 0.1284
# Epoch 34/100
# 1s - loss: 0.4548 - val_loss: 0.1305
# Epoch 35/100
# 0s - loss: 0.4547 - val_loss: 0.1266
# Epoch 36/100
# 0s - loss: 0.4547 - val_loss: 0.1309
# Epoch 37/100
# 1s - loss: 0.4541 - val_loss: 0.1265
# Epoch 38/100
# 1s - loss: 0.4537 - val_loss: 0.1429
# Epoch 39/100
# 0s - loss: 0.4545 - val_loss: 0.1202
# Epoch 40/100
# 1s - loss: 0.4533 - val_loss: 0.1185
# Epoch 41/100
# 0s - loss: 0.4528 - val_loss: 0.1220
# Epoch 42/100
# 0s - loss: 0.4527 - val_loss: 0.1263
# Epoch 43/100
# 0s - loss: 0.4526 - val_loss: 0.1204
# Epoch 44/100
# 0s - loss: 0.4529 - val_loss: 0.1305
# Epoch 45/100
# 0s - loss: 0.4520 - val_loss: 0.1222
# Epoch 46/100
# 0s - loss: 0.4523 - val_loss: 0.1213
# Epoch 47/100
# 0s - loss: 0.4517 - val_loss: 0.1250
# Epoch 48/100
# 0s - loss: 0.4514 - val_loss: 0.1426
# Epoch 49/100
# 0s - loss: 0.4512 - val_loss: 0.1140
# Epoch 50/100
# 0s - loss: 0.4516 - val_loss: 0.1332
# Epoch 51/100
# 0s - loss: 0.4509 - val_loss: 0.1106
# Epoch 52/100
# 0s - loss: 0.4509 - val_loss: 0.1427
# Epoch 53/100
# 0s - loss: 0.4505 - val_loss: 0.1064
# Epoch 54/100
# 0s - loss: 0.4502 - val_loss: 0.1050
# Epoch 55/100
# 0s - loss: 0.4502 - val_loss: 0.1097
# Epoch 56/100
# 0s - loss: 0.4499 - val_loss: 0.1146
# Epoch 57/100
# 0s - loss: 0.4502 - val_loss: 0.1068
# Epoch 58/100
# 0s - loss: 0.4493 - val_loss: 0.1260
# Epoch 59/100
# 0s - loss: 0.4492 - val_loss: 0.1088
# Epoch 60/100
# 0s - loss: 0.4491 - val_loss: 0.1487
# Epoch 61/100
# 0s - loss: 0.4490 - val_loss: 0.1102
# Epoch 62/100
# 0s - loss: 0.4491 - val_loss: 0.1134
# Epoch 63/100
# 0s - loss: 0.4488 - val_loss: 0.0999
# Epoch 64/100
# 0s - loss: 0.4486 - val_loss: 0.1324
# Epoch 65/100
# 0s - loss: 0.4486 - val_loss: 0.1005
# Epoch 66/100
# 0s - loss: 0.4483 - val_loss: 0.1248
# Epoch 67/100
# 0s - loss: 0.4479 - val_loss: 0.1102
# Epoch 68/100
# 0s - loss: 0.4475 - val_loss: 0.1269
# Epoch 69/100
# 0s - loss: 0.4478 - val_loss: 0.1020
# Epoch 70/100
# 0s - loss: 0.4476 - val_loss: 0.1404
# Epoch 71/100
# 0s - loss: 0.4475 - val_loss: 0.1218
# Epoch 72/100
# 0s - loss: 0.4479 - val_loss: 0.1053
# Epoch 73/100
# 0s - loss: 0.4468 - val_loss: 0.1160
# Epoch 74/100
# 0s - loss: 0.4470 - val_loss: 0.1009
# Epoch 75/100
# 0s - loss: 0.4468 - val_loss: 0.1031
# Epoch 76/100
# 0s - loss: 0.4465 - val_loss: 0.1296
# Epoch 77/100
# 0s - loss: 0.4469 - val_loss: 0.1244
# Epoch 78/100
# 0s - loss: 0.4461 - val_loss: 0.1006
# Epoch 79/100
# 0s - loss: 0.4462 - val_loss: 0.1234
# Epoch 80/100
# 0s - loss: 0.4461 - val_loss: 0.1104
# Epoch 81/100
# 0s - loss: 0.4458 - val_loss: 0.1132
# Epoch 82/100
# 0s - loss: 0.4461 - val_loss: 0.1040
# Epoch 83/100
# 0s - loss: 0.4456 - val_loss: 0.1203
# Epoch 84/100
# 0s - loss: 0.4459 - val_loss: 0.0998
# Epoch 85/100
# 0s - loss: 0.4454 - val_loss: 0.1209
# Epoch 86/100
# 0s - loss: 0.4457 - val_loss: 0.1079
# Epoch 87/100
# 0s - loss: 0.4454 - val_loss: 0.1296
# Epoch 88/100
# 0s - loss: 0.4452 - val_loss: 0.0979
# Epoch 89/100
# 0s - loss: 0.4454 - val_loss: 0.1273
# Epoch 90/100
# 0s - loss: 0.4450 - val_loss: 0.1075
# Epoch 91/100
# 0s - loss: 0.4444 - val_loss: 0.1140
# Epoch 92/100
# 0s - loss: 0.4440 - val_loss: 0.1138
# Epoch 93/100
# 0s - loss: 0.4449 - val_loss: 0.1029
# Epoch 94/100
# 0s - loss: 0.4445 - val_loss: 0.1356
# Epoch 95/100
# 0s - loss: 0.4441 - val_loss: 0.0949
# Epoch 96/100
# 0s - loss: 0.4443 - val_loss: 0.1258
# Epoch 97/100
# 0s - loss: 0.4443 - val_loss: 0.1037
# Epoch 98/100
# 0s - loss: 0.4440 - val_loss: 0.1112
# Epoch 99/100
# 0s - loss: 0.4438 - val_loss: 0.0934
# Epoch 100/100
# 0s - loss: 0.4435 - val_loss: 0.1067
# Epoch 1/100
# 0s - loss: 0.0408
# Epoch 2/100
# 0s - loss: 0.0250
# Epoch 3/100
# 0s - loss: 0.0227
# Epoch 4/100
# 0s - loss: 0.0212
# Epoch 5/100
# 0s - loss: 0.0197
# Epoch 6/100
# 0s - loss: 0.0185
# Epoch 7/100
# 0s - loss: 0.0173
# Epoch 8/100
# 0s - loss: 0.0166
# Epoch 9/100
# 0s - loss: 0.0159
# Epoch 10/100
# 0s - loss: 0.0152
# Epoch 11/100
# 0s - loss: 0.0147
# Epoch 12/100
# 0s - loss: 0.0139
# Epoch 13/100
# 0s - loss: 0.0136
# Epoch 14/100
# 0s - loss: 0.0131
# Epoch 15/100
# 0s - loss: 0.0128
# Epoch 16/100
# 0s - loss: 0.0124
# Epoch 17/100
# 0s - loss: 0.0120
# Epoch 18/100
# 0s - loss: 0.0118
# Epoch 19/100
# 0s - loss: 0.0116
# Epoch 20/100
# 0s - loss: 0.0113
# Epoch 21/100
# 0s - loss: 0.0112
# Epoch 22/100
# 0s - loss: 0.0111
# Epoch 23/100
# 0s - loss: 0.0107
# Epoch 24/100
# 0s - loss: 0.0106
# Epoch 25/100
# 0s - loss: 0.0106
# Epoch 26/100
# 0s - loss: 0.0104
# Epoch 27/100
# 0s - loss: 0.0102
# Epoch 28/100
# 0s - loss: 0.0103
# Epoch 29/100
# 0s - loss: 0.0102
# Epoch 30/100
# 0s - loss: 0.0099
# Epoch 31/100
# 0s - loss: 0.0098
# Epoch 32/100
# 0s - loss: 0.0098
# Epoch 33/100
# 0s - loss: 0.0096
# Epoch 34/100
# 0s - loss: 0.0096
# Epoch 35/100
# 0s - loss: 0.0095
# Epoch 36/100
# 0s - loss: 0.0093
# Epoch 37/100
# 0s - loss: 0.0093
# Epoch 38/100
# 0s - loss: 0.0092
# Epoch 39/100
# 0s - loss: 0.0091
# Epoch 40/100
# 0s - loss: 0.0092
# Epoch 41/100
# 0s - loss: 0.0090
# Epoch 42/100
# 0s - loss: 0.0090
# Epoch 43/100
# 0s - loss: 0.0089
# Epoch 44/100
# 0s - loss: 0.0088
# Epoch 45/100
# 0s - loss: 0.0088
# Epoch 46/100
# 0s - loss: 0.0087
# Epoch 47/100
# 0s - loss: 0.0085
# Epoch 48/100
# 0s - loss: 0.0086
# Epoch 49/100
# 0s - loss: 0.0085
# Epoch 50/100
# 0s - loss: 0.0083
# Epoch 51/100
# 0s - loss: 0.0084
# Epoch 52/100
# 0s - loss: 0.0083
# Epoch 53/100
# 0s - loss: 0.0082
# Epoch 54/100
# 0s - loss: 0.0080
# Epoch 55/100
# 0s - loss: 0.0080
# Epoch 56/100
# 0s - loss: 0.0080
# Epoch 57/100
# 0s - loss: 0.0079
# Epoch 58/100
# 0s - loss: 0.0078
# Epoch 59/100
# 0s - loss: 0.0078
# Epoch 60/100
# 0s - loss: 0.0077
# Epoch 61/100
# 0s - loss: 0.0076
# Epoch 62/100
# 0s - loss: 0.0075
# Epoch 63/100
# 0s - loss: 0.0074
# Epoch 64/100
# 0s - loss: 0.0075
# Epoch 65/100
# 0s - loss: 0.0074
# Epoch 66/100
# 0s - loss: 0.0074
# Epoch 67/100
# 0s - loss: 0.0074
# Epoch 68/100
# 0s - loss: 0.0073
# Epoch 69/100
# 0s - loss: 0.0071
# Epoch 70/100
# 0s - loss: 0.0072
# Epoch 71/100
# 0s - loss: 0.0070
# Epoch 72/100
# 0s - loss: 0.0070
# Epoch 73/100
# 0s - loss: 0.0070
# Epoch 74/100
# 0s - loss: 0.0069
# Epoch 75/100
# 0s - loss: 0.0069
# Epoch 76/100
# 0s - loss: 0.0069
# Epoch 77/100
# 0s - loss: 0.0068
# Epoch 78/100
# 0s - loss: 0.0068
# Epoch 79/100
# 0s - loss: 0.0067
# Epoch 80/100
# 0s - loss: 0.0066
# Epoch 81/100
# 0s - loss: 0.0066
# Epoch 82/100
# 0s - loss: 0.0065
# Epoch 83/100
# 0s - loss: 0.0065
# Epoch 84/100
# 0s - loss: 0.0065
# Epoch 85/100
# 0s - loss: 0.0064
# Epoch 86/100
# 0s - loss: 0.0064
# Epoch 87/100
# 0s - loss: 0.0064
# Epoch 88/100
# 0s - loss: 0.0062
# Epoch 89/100
# 0s - loss: 0.0062
# Epoch 90/100
# 0s - loss: 0.0061
# Epoch 91/100
# 0s - loss: 0.0062
# Epoch 92/100
# 0s - loss: 0.0061
# Epoch 93/100
# 0s - loss: 0.0061
# Epoch 94/100
# 0s - loss: 0.0061
# Epoch 95/100
# 0s - loss: 0.0061
# Epoch 96/100
# 0s - loss: 0.0060
# Epoch 97/100
# 0s - loss: 0.0059
# Epoch 98/100
# 0s - loss: 0.0059
# Epoch 99/100
# 0s - loss: 0.0058
# Epoch 100/100
# 0s - loss: 0.0058
# Epoch 1/100
# 0s - loss: 0.0311
# Epoch 2/100
# 0s - loss: 0.0203
# Epoch 3/100
# 0s - loss: 0.0161
# Epoch 4/100
# 0s - loss: 0.0130
# Epoch 5/100
# 0s - loss: 0.0105
# Epoch 6/100
# 0s - loss: 0.0085
# Epoch 7/100
# 0s - loss: 0.0069
# Epoch 8/100
# 0s - loss: 0.0057
# Epoch 9/100
# 0s - loss: 0.0049
# Epoch 10/100
# 0s - loss: 0.0045
# Epoch 11/100
# 0s - loss: 0.0042
# Epoch 12/100
# 0s - loss: 0.0039
# Epoch 13/100
# 0s - loss: 0.0038
# Epoch 14/100
# 0s - loss: 0.0036
# Epoch 15/100
# 0s - loss: 0.0035
# Epoch 16/100
# 0s - loss: 0.0034
# Epoch 17/100
# 0s - loss: 0.0033
# Epoch 18/100
# 0s - loss: 0.0033
# Epoch 19/100
# 0s - loss: 0.0032
# Epoch 20/100
# 0s - loss: 0.0032
# Epoch 21/100
# 0s - loss: 0.0031
# Epoch 22/100
# 0s - loss: 0.0031
# Epoch 23/100
# 0s - loss: 0.0031
# Epoch 24/100
# 0s - loss: 0.0030
# Epoch 25/100
# 0s - loss: 0.0030
# Epoch 26/100
# 0s - loss: 0.0030
# Epoch 27/100
# 0s - loss: 0.0030
# Epoch 28/100
# 0s - loss: 0.0030
# Epoch 29/100
# 0s - loss: 0.0029
# Epoch 30/100
# 0s - loss: 0.0029
# Epoch 31/100
# 0s - loss: 0.0029
# Epoch 32/100
# 0s - loss: 0.0029
# Epoch 33/100
# 0s - loss: 0.0029
# Epoch 34/100
# 0s - loss: 0.0029
# Epoch 35/100
# 0s - loss: 0.0029
# Epoch 36/100
# 0s - loss: 0.0029
# Epoch 37/100
# 0s - loss: 0.0028
# Epoch 38/100
# 0s - loss: 0.0028
# Epoch 39/100
# 0s - loss: 0.0028
# Epoch 40/100
# 0s - loss: 0.0028
# Epoch 41/100
# 0s - loss: 0.0028
# Epoch 42/100
# 0s - loss: 0.0028
# Epoch 43/100
# 0s - loss: 0.0028
# Epoch 44/100
# 0s - loss: 0.0028
# Epoch 45/100
# 0s - loss: 0.0028
# Epoch 46/100
# 0s - loss: 0.0028
# Epoch 47/100
# 0s - loss: 0.0028
# Epoch 48/100
# 0s - loss: 0.0027
# Epoch 49/100
# 0s - loss: 0.0027
# Epoch 50/100
# 0s - loss: 0.0027
# Epoch 51/100
# 0s - loss: 0.0027
# Epoch 52/100
# 0s - loss: 0.0027
# Epoch 53/100
# 0s - loss: 0.0027
# Epoch 54/100
# 0s - loss: 0.0027
# Epoch 55/100
# 0s - loss: 0.0027
# Epoch 56/100
# 0s - loss: 0.0027
# Epoch 57/100
# 0s - loss: 0.0027
# Epoch 58/100
# 0s - loss: 0.0027
# Epoch 59/100
# 0s - loss: 0.0027
# Epoch 60/100
# 0s - loss: 0.0027
# Epoch 61/100
# 0s - loss: 0.0027
# Epoch 62/100
# 0s - loss: 0.0026
# Epoch 63/100
# 0s - loss: 0.0026
# Epoch 64/100
# 0s - loss: 0.0026
# Epoch 65/100
# 0s - loss: 0.0026
# Epoch 66/100
# 0s - loss: 0.0026
# Epoch 67/100
# 0s - loss: 0.0026
# Epoch 68/100
# 0s - loss: 0.0026
# Epoch 69/100
# 0s - loss: 0.0026
# Epoch 70/100
# 0s - loss: 0.0026
# Epoch 71/100
# 0s - loss: 0.0026
# Epoch 72/100
# 0s - loss: 0.0026
# Epoch 73/100
# 0s - loss: 0.0026
# Epoch 74/100
# 0s - loss: 0.0026
# Epoch 75/100
# 0s - loss: 0.0026
# Epoch 76/100
# 0s - loss: 0.0025
# Epoch 77/100
# 0s - loss: 0.0026
# Epoch 78/100
# 0s - loss: 0.0025
# Epoch 79/100
# 0s - loss: 0.0025
# Epoch 80/100
# 0s - loss: 0.0025
# Epoch 81/100
# 0s - loss: 0.0025
# Epoch 82/100
# 0s - loss: 0.0025
# Epoch 83/100
# 0s - loss: 0.0025
# Epoch 84/100
# 0s - loss: 0.0025
# Epoch 85/100
# 0s - loss: 0.0025
# Epoch 86/100
# 0s - loss: 0.0025
# Epoch 87/100
# 0s - loss: 0.0025
# Epoch 88/100
# 0s - loss: 0.0025
# Epoch 89/100
# 0s - loss: 0.0025
# Epoch 90/100
# 0s - loss: 0.0025
# Epoch 91/100
# 0s - loss: 0.0025
# Epoch 92/100
# 0s - loss: 0.0025
# Epoch 93/100
# 0s - loss: 0.0025
# Epoch 94/100
# 0s - loss: 0.0025
# Epoch 95/100
# 0s - loss: 0.0024
# Epoch 96/100
# 0s - loss: 0.0024
# Epoch 97/100
# 0s - loss: 0.0024
# Epoch 98/100
# 0s - loss: 0.0024
# Epoch 99/100
# 0s - loss: 0.0024
# Epoch 100/100
# 0s - loss: 0.0024

# %%
# %matplotlib nbagg
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation

Writer = animation.writers['ffmpeg']
writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)

Output=SAE.predict(x_train)

fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xlabel("range")
ax.set_ylim(2.0,-2.0)
ax.set_xlim([0,Output.shape[1]])
ax.legend()
x = range(Output.shape[1])
reconst, = ax.plot(x,Output[0,:] ,'r',label='Reconst Data')
raw, = ax.plot(x, x_test[0,:],'b',label='No noise Raw Data')
Noised, = ax.plot(x, x_train[0,:],'g',label='Noised Raw Data')

#フレーム更新
def update(i):
    reconst.set_ydata(Output[i,:])
    raw.set_ydata(x_test[i,:])
    Noised.set_ydata(x_train[i,:])
    ax.legend()
    
ani = animation.FuncAnimation(fig, update, 1000, blit=False, interval=100, repeat=False)
#ani.save(AnimationPath+FileName+'_animation.mp4',writer=writer)

plt.show()
# Out:
# <img src="data:image/png;base64,...">
