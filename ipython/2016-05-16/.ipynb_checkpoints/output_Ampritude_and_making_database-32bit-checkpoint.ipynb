# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from scipy import fftpack
from scipy import signal
import numpy as np
import pandas as pd
import datetime
import time as T

# %%
sample_bit=16

# %%
#my workstation

# %%
#cd /home/takeyama/Documents/01_SensorData/2016_05_11/FFT-data/

# %%
#mozart

# %%
cd ~/Documents/SyncRecord/cleaning-addingLABEL/
# Out:
# /home/takeyama/Documents/SyncRecord/cleaning-addingLABEL

# %%
fft_left_hand = pd.read_csv('FFT-Cleaning-Conv-left-hand-ags.csv-'+str(sample_bit)+'bit.csv')
#left_hand.Time=pd.to_timedelta(left_hand.Time)
fft_left_leg = pd.read_csv('FFT-'+'Cleaning-Conv-left-leg-ags.csv-'+str(sample_bit)+'bit.csv')
#left_leg.Time=pd.to_timedelta(left_leg.Time)
fft_right_hand = pd.read_csv('FFT-'+'Cleaning-Conv-right-hand-ags.csv-'+str(sample_bit)+'bit.csv')
#right_hand.Time=pd.to_timedelta(right_hand.Time)
fft_right_leg = pd.read_csv('FFT-'+'Cleaning-Conv-right-leg-ags.csv-'+str(sample_bit)+'bit.csv')
#right_leg.Time=pd.to_timedelta(right_leg.Time)
fft_west = pd.read_csv('FFT-'+'Cleaning-Conv-west-ags.csv-'+str(sample_bit)+'bit.csv')
#west.Time=pd.to_timedelta(west.Time)

fft_name=['FFT-Cleaning-Conv-left-hand-ags.csv-'+str(sample_bit)+'bit.csv','FFT-'+'Cleaning-Conv-left-leg-ags.csv-'+str(sample_bit)+'bit.csv',
          'FFT-'+'Cleaning-Conv-right-hand-ags.csv-'+str(sample_bit)+'bit.csv','FFT-'+'Cleaning-Conv-right-leg-ags.csv-'+str(sample_bit)+'bit.csv',
          'FFT-'+'Cleaning-Conv-west-ags.csv-'+str(sample_bit)+'bit.csv']

# %%
# left_hand
start_time = T.clock()
Amp_left_handAX=np.array([])
Amp_left_handAY=np.array([])
Amp_left_handAZ=np.array([])

Amp_left_handGX=np.array([])
Amp_left_handGY=np.array([])
Amp_left_handGZ=np.array([])

Amp_left_hand_label=np.array([])

x = fft_right_leg.where(fft_left_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAX = np.append(Amp_left_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAY = np.append(Amp_left_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handAZ = np.append(Amp_left_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGX = np.append(Amp_left_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGY = np.append(Amp_left_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_handGZ = np.append(Amp_left_handGZ, tmp)

tmp =np.array( x.Label )
Amp_left_hand_label = np.append(Amp_left_hand_label, tmp)

for t in range(1,fft_left_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_left_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAX = np.append(Amp_left_handAX, tmp)

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAY = np.append(Amp_left_handAY, tmp)

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handAZ = np.append(Amp_left_handAZ, tmp)

        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGX = np.append(Amp_left_handGX, tmp)

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGY = np.append(Amp_left_handGY, tmp)

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_handGZ = np.append(Amp_left_handGZ, tmp)

        tmp =np.array( x.Label )
        Amp_left_hand_label = np.append(Amp_left_hand_label, tmp)
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:769.93332[sec]

# %%
# right_leg
start_time = T.clock()
Amp_right_legAX=np.array([])
Amp_right_legAY=np.array([])
Amp_right_legAZ=np.array([])

Amp_right_legGX=np.array([])
Amp_right_legGY=np.array([])
Amp_right_legGZ=np.array([])

Amp_right_leg_label=np.array([])

x = fft_right_leg.where(fft_right_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAX = np.append(Amp_right_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAY = np.append(Amp_right_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legAZ = np.append(Amp_right_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGX = np.append(Amp_right_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGY = np.append(Amp_right_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_legGZ = np.append(Amp_right_legGZ, tmp)

tmp =np.array( x.Label )
Amp_right_leg_label = np.append(Amp_right_leg_label, tmp)

for t in range(1,fft_right_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_leg.where(fft_right_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAX = np.append(Amp_right_legAX, tmp)

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAY = np.append(Amp_right_legAY, tmp)

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legAZ = np.append(Amp_right_legAZ, tmp)

        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGX = np.append(Amp_right_legGX, tmp)

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGY = np.append(Amp_right_legGY, tmp)

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_legGZ = np.append(Amp_right_legGZ, tmp)

        tmp =np.array( x.Label )
        Amp_right_leg_label = np.append(Amp_right_leg_label, tmp)
        
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break

    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:197.298472[sec]

# %%
# Left_leg
start_time = T.clock()
Amp_left_legAX=np.array([])
Amp_left_legAY=np.array([])
Amp_left_legAZ=np.array([])

Amp_left_legGX=np.array([])
Amp_left_legGY=np.array([])
Amp_left_legGZ=np.array([])

Amp_left_leg_label =np.array([])

x = fft_left_leg.where(fft_left_leg.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAX = np.append(Amp_left_legAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAY = np.append(Amp_left_legAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legAZ = np.append(Amp_left_legAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGX = np.append(Amp_left_legGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGY = np.append(Amp_left_legGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_left_legGZ = np.append(Amp_left_legGZ, tmp)

tmp =np.array( x.Label )
Amp_left_leg_label = np.append(Amp_left_leg_label, tmp)

for t in range(1,fft_left_leg.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_left_leg.where(fft_left_leg.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAX = np.append(Amp_left_legAX, tmp)

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAY = np.append(Amp_left_legAY, tmp)

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legAZ = np.append(Amp_left_legAZ, tmp)

        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGX = np.append(Amp_left_legGX, tmp)

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGY = np.append(Amp_left_legGY, tmp)

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_left_legGZ = np.append(Amp_left_legGZ, tmp)

        tmp =np.array( x.Label )
        Amp_left_leg_label = np.append(Amp_left_leg_label, tmp)
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:159.917464[sec]

# %%
# right_hand
start_time = T.clock()
Amp_right_handAX=np.array([])
Amp_right_handAY=np.array([])
Amp_right_handAZ=np.array([])

Amp_right_handGX=np.array([])
Amp_right_handGY=np.array([])
Amp_right_handGZ=np.array([])

Amp_right_hand_label=np.array([])

x = fft_right_hand.where(fft_right_hand.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAX = np.append(Amp_right_handAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAY = np.append(Amp_right_handAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handAZ = np.append(Amp_right_handAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGX = np.append(Amp_right_handGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGY = np.append(Amp_right_handGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_right_handGZ = np.append(Amp_right_handGZ, tmp)

tmp =np.array( x.Label )
Amp_right_hand_label = np.append(Amp_right_hand_label, tmp)

for t in range(1,fft_right_hand.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_right_hand.where(fft_right_hand.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAX = np.append(Amp_right_handAX, tmp)

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAY = np.append(Amp_right_handAY, tmp)

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handAZ = np.append(Amp_right_handAZ, tmp)

        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGX = np.append(Amp_right_handGX, tmp)

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGY = np.append(Amp_right_handGY, tmp)

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_right_handGZ = np.append(Amp_right_handGZ, tmp)

        tmp =np.array( x.Label )
        Amp_right_hand_label = np.append(Amp_right_hand_label, tmp)
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:176.775936[sec]

# %%
# west
start_time = T.clock()
Amp_westAX=np.array([])
Amp_westAY=np.array([])
Amp_westAZ=np.array([])

Amp_westGX=np.array([])
Amp_westGY=np.array([])
Amp_westGZ=np.array([])

Amp_west_label=np.array([])

x = fft_west.where(fft_west.Time==0).dropna()

tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
tmp =tmp/tmp.sum()
Amp_westAX = np.append(Amp_westAX, tmp)

tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
tmp =tmp/tmp.sum()
Amp_westAY = np.append(Amp_westAY, tmp)

tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westAZ = np.append(Amp_westAZ, tmp)

tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
tmp =tmp/tmp.sum()
Amp_westGX = np.append(Amp_westGX, tmp)

tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
tmp =tmp/tmp.sum()
Amp_westGY = np.append(Amp_westGY, tmp)

tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
tmp =tmp/tmp.sum()
Amp_westGZ = np.append(Amp_westGZ, tmp)

tmp =np.array( x.Label )
Amp_west_label = np.append(Amp_west_label, tmp)

for t in range(1,fft_west.Time.max()):
    try:
        # 抽出したデータベースを格納
        x = fft_west.where(fft_west.Time==t).dropna()

        # 各軸、それぞれパワースペクトルを計算
        tmp =np.array( np.sqrt(x.AccX_imag**2+x.AccX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAX = np.append(Amp_westAX, tmp)

        tmp =np.array( np.sqrt(x.AccY_imag**2+x.AccY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAY = np.append(Amp_westAY, tmp)

        tmp =np.array( np.sqrt(x.AccZ_imag**2+x.AccZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westAZ = np.append(Amp_westAZ, tmp)

        tmp =np.array( np.sqrt(x.GyrX_imag**2+x.GyrX_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGX = np.append(Amp_westGX, tmp)

        tmp =np.array( np.sqrt(x.GyrY_imag**2+x.GyrY_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGY = np.append(Amp_westGY, tmp)

        tmp =np.array( np.sqrt(x.GyrZ_imag**2+x.GyrZ_real**2) )
        tmp =tmp/tmp.sum()
        Amp_westGZ = np.append(Amp_westGZ, tmp)

        tmp =np.array( x.Label )
        Amp_west_label = np.append(Amp_west_label, tmp)
    except ValueError:
        print "No."+str(t)+"_ValueEroor"
        break
    
    
elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:4.142221[sec]

# %%
Amp_westAX.shape
# Out:
# (5584,)

# %%
def GetLabelNam(samp):
    l=['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th', '11th',
    '12th', '13th', '14th', '15th', '16th', '17th', '18th', '19th', '20th', '21st',
    '22nd', '23rd', '24th', '25th', '26th', '27th', '28th', '29th', '30th', '31st']
    
    return l[0:(samp/2)]

# %%
df_fft_name=['fft_left_hand','fft_left_leg','fft_right_hand','fft_right_leg','west']

# %%
sample_bit
# Out:
# 16

# %%
start_time = T.clock()

array =  GetLabelNam(sample_bit)
TimeArray=[]
NumArray=[]
LabelArray=[]

for t in range(0,Amp_left_handAX.size/(sample_bit/2)):
    for i in range(len(array)):
        TimeArray.append(str(t))

for i in range(0,Amp_left_handAX.size/(sample_bit/2)):
    for a in array:
        NumArray.append(a)

TimeArray=np.array(TimeArray)
NumArray=np.array(NumArray)

fftdf1=pd.DataFrame({
        'AccX_real':Amp_left_handAX,
        'AccY_real':Amp_left_handAY,
        'AccZ_real':Amp_left_handAZ,
        'GyrX_real':Amp_left_handGX,
        'GyrY_real':Amp_left_handGY,
        'GyrZ_real':Amp_left_handGZ,
        'Time':TimeArray,
        'Number':NumArray,
        'Label':Amp_left_hand_label
        }
      )

#fftdf = fftdf.astype(np.float64)

fftdf1.to_csv('Amp-'+df_fft_name[0]+'-'+str(sample_bit)+'.csv')

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:2.162091[sec]

# %%
start_time = T.clock()

array =  GetLabelNam(sample_bit)
TimeArray=[]
NumArray=[]
LabelArray=[]

for t in range(0,Amp_left_legAX.size/(sample_bit/2)):
    for i in range(len(array)):
        TimeArray.append(str(t))

for i in range(0,Amp_left_legAX.size/(sample_bit/2)):
    for a in array:
        NumArray.append(a)

TimeArray=np.array(TimeArray)
NumArray=np.array(NumArray)

fftdf2=pd.DataFrame({
        'AccX_real':Amp_left_legAX,
        'AccY_real':Amp_left_legAY,
        'AccZ_real':Amp_left_legAZ,
        'GyrX_real':Amp_left_legGX,
        'GyrY_real':Amp_left_legGY,
        'GyrZ_real':Amp_left_legGZ,
        'Time':TimeArray,
        'Number':NumArray,
        'Label':Amp_left_leg_label
        }
      )

#fftdf = fftdf.astype(np.float64)

fftdf2.to_csv('Amp-'+df_fft_name[0]+'-'+str(sample_bit)+'.csv')

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:0.690294[sec]

# %%
start_time = T.clock()

array =  GetLabelNam(sample_bit)
TimeArray=[]
NumArray=[]
LabelArray=[]

for t in range(0,Amp_right_handAX.size/(sample_bit/2)):
    for i in range(len(array)):
        TimeArray.append(str(t))

for i in range(0,Amp_right_handAX.size/(sample_bit/2)):
    for a in array:
        NumArray.append(a)

TimeArray=np.array(TimeArray)
NumArray=np.array(NumArray)

fftdf3=pd.DataFrame({
        'AccX_real':Amp_right_handAX,
        'AccY_real':Amp_right_handAY,
        'AccZ_real':Amp_right_handAZ,
        'GyrX_real':Amp_right_handGX,
        'GyrY_real':Amp_right_handGY,
        'GyrZ_real':Amp_right_handGZ,
        'Time':TimeArray,
        'Number':NumArray,
        'Label':Amp_right_hand_label
        }
      )

#fftdf = fftdf.astype(np.float64)

fftdf3.to_csv('Amp-'+df_fft_name[0]+'-'+str(sample_bit)+'.csv')

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:0.444741[sec]

# %%
start_time = T.clock()

array =  GetLabelNam(sample_bit)
TimeArray=[]
NumArray=[]
LabelArray=[]

for t in range(0,Amp_right_legAX.size/(sample_bit/2)):
    for i in range(len(array)):
        TimeArray.append(str(t))

for i in range(0,Amp_right_legAX.size/(sample_bit/2)):
    for a in array:
        NumArray.append(a)

TimeArray=np.array(TimeArray)
NumArray=np.array(NumArray)

fftdf4=pd.DataFrame({
        'AccX_real':Amp_right_legAX,
        'AccY_real':Amp_right_legAY,
        'AccZ_real':Amp_right_legAZ,
        'GyrX_real':Amp_right_legGX,
        'GyrY_real':Amp_right_legGY,
        'GyrZ_real':Amp_right_legGZ,
        'Time':TimeArray,
        'Number':NumArray,
        'Label':Amp_right_leg_label
        }
      )

#fftdf = fftdf.astype(np.float64)

fftdf4.to_csv('Amp-'+df_fft_name[0]+'-'+str(sample_bit)+'.csv')

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:0.469435[sec]

# %%
start_time = T.clock()

array =  GetLabelNam(sample_bit)
TimeArray=[]
NumArray=[]
LabelArray=[]

for t in range(0,Amp_westAX.size/(sample_bit/2)):
    for i in range(len(array)):
        TimeArray.append(str(t))

for i in range(0,Amp_westAX.size/(sample_bit/2)):
    for a in array:
        NumArray.append(a)

TimeArray=np.array(TimeArray)
NumArray=np.array(NumArray)

fftdf5=pd.DataFrame({
        'AccX_real':Amp_westAX,
        'AccY_real':Amp_westAY,
        'AccZ_real':Amp_westAZ,
        'GyrX_real':Amp_westGX,
        'GyrY_real':Amp_westGY,
        'GyrZ_real':Amp_westGZ,
        'Time':TimeArray,
        'Number':NumArray,
        'Label':Amp_west_label
        }
      )

#fftdf = fftdf.astype(np.float64)

fftdf5.to_csv('Amp-'+df_fft_name[0]+'-'+str(sample_bit)+'.csv')

elapsed_time = T.clock() - start_time
print ("elapsed_time:{0}".format(elapsed_time)) + "[sec]"
# Out:
# elapsed_time:0.0648119999998[sec]

# %%
fftdf
# Out:
#       AccX_real  AccY_real  AccZ_real  GyrX_real  GyrY_real  GyrZ_real  \
# 0      0.538698   0.528026   0.392634   0.502859   0.372241   0.526795
# 1      0.169471   0.106664   0.252332   0.077500   0.185710   0.112277
# 2      0.087294   0.121460   0.116416   0.139712   0.123783   0.069910
# 3      0.048548   0.047649   0.033145   0.044213   0.052631   0.068429
# 4      0.042588   0.092078   0.056313   0.042806   0.055492   0.056120
# 5      0.024808   0.032816   0.055882   0.073527   0.080696   0.054129
# 6      0.047153   0.046895   0.058197   0.062278   0.030544   0.061680
# 7      0.041439   0.024412   0.035080   0.057103   0.098902   0.050660
# 8      0.445859   0.405420   0.269463   0.466573   0.386877   0.550588
# 9      0.165039   0.194641   0.321976   0.190173   0.208514   0.203450
# 10     0.094275   0.069650   0.060233   0.110653   0.090925   0.089695
# 11     0.061121   0.097029   0.106671   0.039420   0.077544   0.033921
# 12     0.073939   0.040488   0.079660   0.079830   0.080323   0.025129
# 13     0.062305   0.043734   0.103407   0.042756   0.054534   0.029558
# 14     0.052262   0.075538   0.024147   0.015918   0.054812   0.042641
# 15     0.045200   0.073499   0.034443   0.054678   0.046472   0.025018
# 16     0.702484   0.560528   0.209252   0.179465   0.207426   0.591605
# 17     0.117302   0.074951   0.378748   0.200750   0.334879   0.036981
# 18     0.023556   0.104990   0.119721   0.175636   0.113461   0.081121
# 19     0.079228   0.007302   0.100632   0.109323   0.056972   0.060467
# 20     0.032405   0.082281   0.093167   0.083453   0.065067   0.028893
# 21     0.008936   0.098780   0.040651   0.094371   0.130900   0.064144
# 22     0.011436   0.020531   0.007204   0.081663   0.076781   0.086902
# 23     0.024653   0.050636   0.050626   0.075339   0.014513   0.049886
# 24     0.294343   0.314402   0.240217   0.366531   0.106889   0.254463
# 25     0.167378   0.155806   0.146757   0.090921   0.209844   0.193858
# 26     0.121187   0.105214   0.059602   0.088739   0.044367   0.107678
# 27     0.124647   0.083849   0.055673   0.124239   0.075430   0.038777
# 27              walking    4th    3
# 28              walking    5th    3
# 29              walking    6th    3
# ...                 ...    ...  ...
# 5554  walking-cross-arm    3rd  694
# 5555  walking-cross-arm    4th  694
# 5556  walking-cross-arm    5th  694
# 5557  walking-cross-arm    6th  694
# 5558  walking-cross-arm    7th  694
# 5559  walking-cross-arm    8th  694
# 5560  walking-cross-arm    1st  695
# 5561  walking-cross-arm    2nd  695
# 5562  walking-cross-arm    3rd  695
# 5563  walking-cross-arm    4th  695
# 5564  walking-cross-arm    5th  695
# 5565  walking-cross-arm    6th  695
# 5566  walking-cross-arm    7th  695
# 5567  walking-cross-arm    8th  695
# 5568  walking-cross-arm    1st  696
# 5569  walking-cross-arm    2nd  696
# 5570  walking-cross-arm    3rd  696
# 5571  walking-cross-arm    4th  696
# 5572  walking-cross-arm    5th  696
# 5573  walking-cross-arm    6th  696
# 5574  walking-cross-arm    7th  696
# 5575  walking-cross-arm    8th  696
# 5576  walking-cross-arm    1st  697
# 5577  walking-cross-arm    2nd  697
# 5578  walking-cross-arm    3rd  697
# 5579  walking-cross-arm    4th  697
# 5580  walking-cross-arm    5th  697
# 5581  walking-cross-arm    6th  697
# 5582  walking-cross-arm    7th  697
# 5583  walking-cross-arm    8th  697
#
# [5584 rows x 9 columns]

# %%
fftdf2
# Out:
#        AccX_real  AccY_real  AccZ_real  GyrX_real  GyrY_real  GyrZ_real  \
# 0       0.187776   0.167580   0.313230   0.136475   0.290864   0.345392
# 1       0.264913   0.241135   0.091644   0.248935   0.197936   0.163652
# 2       0.064407   0.131515   0.074555   0.214935   0.125898   0.113829
# 3       0.025049   0.157658   0.139436   0.198908   0.104403   0.106152
# 4       0.080226   0.042248   0.065295   0.054751   0.086629   0.081041
# 5       0.176023   0.145022   0.110059   0.059483   0.066016   0.064155
# 6       0.118927   0.071808   0.166749   0.034576   0.064605   0.056795
# 7       0.082678   0.043035   0.039033   0.051936   0.063650   0.068982
# 8       0.379988   0.250776   0.313514   0.161856   0.373631   0.420265
# 9       0.059764   0.144400   0.229500   0.283878   0.170532   0.145305
# 10      0.165009   0.124254   0.094053   0.150115   0.107942   0.122577
# 11      0.069374   0.211987   0.119461   0.079926   0.085160   0.079193
# 12      0.021365   0.058628   0.095592   0.087714   0.067009   0.062322
# 13      0.159563   0.114051   0.061292   0.090738   0.070162   0.066094
# 14      0.081195   0.041313   0.022973   0.082883   0.066122   0.059482
# 15      0.063742   0.054591   0.063616   0.062890   0.059442   0.044761
# 16      0.282557   0.269189   0.406726   0.348632   0.345444   0.261232
# 17      0.228589   0.123503   0.280572   0.221174   0.156318   0.217935
# 18      0.091996   0.110383   0.119320   0.066326   0.113575   0.076342
# 19      0.098672   0.097944   0.051100   0.091103   0.090993   0.111011
# 20      0.094537   0.157883   0.031500   0.098338   0.082984   0.105355
# 21      0.089956   0.094472   0.057453   0.070667   0.074878   0.086270
# 22      0.066197   0.092680   0.015350   0.061602   0.068368   0.064018
# 23      0.047495   0.053946   0.037978   0.042157   0.067440   0.077837
# 2      walking    3rd     0
# 3      walking    4th     0
# 4      walking    5th     0
# 5      walking    6th     0
# 6      walking    7th     0
# 7      walking    8th     0
# 8      walking    1st     1
# 9      walking    2nd     1
# 10     walking    3rd     1
# 11     walking    4th     1
# 12     walking    5th     1
# 13     walking    6th     1
# 14     walking    7th     1
# 15     walking    8th     1
# 16     walking    1st     2
# 17     walking    2nd     2
# 18     walking    3rd     2
# 19     walking    4th     2
# 20     walking    5th     2
# 21     walking    6th     2
# 22     walking    7th     2
# 23     walking    8th     2
# 24     walking    1st     3
# 25     walking    2nd     3
# 26     walking    3rd     3
# 27     walking    4th     3
# 28     walking    5th     3
# 29     walking    6th     3
# ...        ...    ...   ...
# 55466  UNKNOWN    3rd  6933
# 55467  UNKNOWN    4th  6933
# 55468  UNKNOWN    5th  6933
# 55469  UNKNOWN    6th  6933
# 55470  UNKNOWN    7th  6933
# 55471  UNKNOWN    8th  6933
# 55472  UNKNOWN    1st  6934
# 55473  UNKNOWN    2nd  6934
# 55474  UNKNOWN    3rd  6934
# 55475  UNKNOWN    4th  6934
# 55476  UNKNOWN    5th  6934
# 55477  UNKNOWN    6th  6934
# 55478  UNKNOWN    7th  6934
# 55479  UNKNOWN    8th  6934
# 55480  UNKNOWN    1st  6935
# 55481  UNKNOWN    2nd  6935
# 55482  UNKNOWN    3rd  6935
# 55483  UNKNOWN    4th  6935
# 55484  UNKNOWN    5th  6935
# 55485  UNKNOWN    6th  6935
# 55486  UNKNOWN    7th  6935
# 55487  UNKNOWN    8th  6935
# 55488  UNKNOWN    1st  6936
# 55489  UNKNOWN    2nd  6936
# 55490  UNKNOWN    3rd  6936
# 55491  UNKNOWN    4th  6936
# 55492  UNKNOWN    5th  6936
# 55493  UNKNOWN    6th  6936
# 55494  UNKNOWN    7th  6936
# 55495  UNKNOWN    8th  6936
#
# [55496 rows x 9 columns]

# %%
fftdf5
# Out:
#       AccX_real  AccY_real  AccZ_real  GyrX_real  GyrY_real  GyrZ_real  \
# 0      0.538698   0.528026   0.392634   0.502859   0.372241   0.526795
# 1      0.169471   0.106664   0.252332   0.077500   0.185710   0.112277
# 2      0.087294   0.121460   0.116416   0.139712   0.123783   0.069910
# 3      0.048548   0.047649   0.033145   0.044213   0.052631   0.068429
# 4      0.042588   0.092078   0.056313   0.042806   0.055492   0.056120
# 5      0.024808   0.032816   0.055882   0.073527   0.080696   0.054129
# 6      0.047153   0.046895   0.058197   0.062278   0.030544   0.061680
# 7      0.041439   0.024412   0.035080   0.057103   0.098902   0.050660
# 8      0.445859   0.405420   0.269463   0.466573   0.386877   0.550588
# 9      0.165039   0.194641   0.321976   0.190173   0.208514   0.203450
# 10     0.094275   0.069650   0.060233   0.110653   0.090925   0.089695
# 11     0.061121   0.097029   0.106671   0.039420   0.077544   0.033921
# 12     0.073939   0.040488   0.079660   0.079830   0.080323   0.025129
# 13     0.062305   0.043734   0.103407   0.042756   0.054534   0.029558
# 5581   0.050288   0.060694   0.051316   0.069836   0.065763   0.067738
# 5582   0.058073   0.044928   0.075250   0.052990   0.061406   0.061507
# 5583   0.058073   0.044928   0.075250   0.052990   0.061406   0.061507
#
#                   Label Number Time
# 0               walking    1st    0
# 1               walking    2nd    0
# 2               walking    3rd    0
# 3               walking    4th    0
# 4               walking    5th    0
# 5               walking    6th    0
# 6               walking    7th    0
# 7               walking    8th    0
# 8               walking    1st    1
# 9               walking    2nd    1
# 10              walking    3rd    1
# 11              walking    4th    1
# 12              walking    5th    1
# 13              walking    6th    1
# 14              walking    7th    1
# 15              walking    8th    1
# 16              walking    1st    2
# 17              walking    2nd    2
# 18              walking    3rd    2
# 19              walking    4th    2
# 20              walking    5th    2
# 21              walking    6th    2
# 22              walking    7th    2
# 23              walking    8th    2
# 24              walking    1st    3
# 25              walking    2nd    3
# 26              walking    3rd    3
# 27              walking    4th    3
# 28              walking    5th    3
# 29              walking    6th    3
# ...                 ...    ...  ...
# 5554  walking-cross-arm    3rd  694
# 5555  walking-cross-arm    4th  694
# 5556  walking-cross-arm    5th  694
# 5557  walking-cross-arm    6th  694
# 5558  walking-cross-arm    7th  694
# 5559  walking-cross-arm    8th  694
# 5560  walking-cross-arm    1st  695
# 5561  walking-cross-arm    2nd  695
# 5562  walking-cross-arm    3rd  695
# 5563  walking-cross-arm    4th  695
# 5564  walking-cross-arm    5th  695
# 5565  walking-cross-arm    6th  695
# 5566  walking-cross-arm    7th  695
# 5567  walking-cross-arm    8th  695
# 5568  walking-cross-arm    1st  696
# 5569  walking-cross-arm    2nd  696
# 5570  walking-cross-arm    3rd  696
# 5571  walking-cross-arm    4th  696
# 5572  walking-cross-arm    5th  696
# 5573  walking-cross-arm    6th  696
# 5574  walking-cross-arm    7th  696
# 5575  walking-cross-arm    8th  696
# 5576  walking-cross-arm    1st  697
# 5577  walking-cross-arm    2nd  697
# 5578  walking-cross-arm    3rd  697
# 5579  walking-cross-arm    4th  697
# 5580  walking-cross-arm    5th  697
# 5581  walking-cross-arm    6th  697
# 5582  walking-cross-arm    7th  697
# 5583  walking-cross-arm    8th  697
#
# [5584 rows x 9 columns]

# %%
Amp_left_handAX.size
# Out:
# 55464

# %%
Amp_left_handAX.shape
# Out:
# (55464,)

# %%
Amp_left_handAY.shape
# Out:
# (55464,)

# %%
Amp_left_handAZ.shape
# Out:
# (55464,)

# %%
Amp_left_handGX.shape
# Out:
# (55464,)

# %%
Amp_left_handGY.shape
# Out:
# (55464,)

# %%
Amp_left_handGZ.shape
# Out:
# (55464,)

# %%
Amp_left_hand_label.shape
# Out:
# (55464,)

# %%
TimeArray.shape
# Out:
# (55464,)

# %%
NumArray.shape
# Out:
# (55464,)

# %%
len(range(0,n.Time.max()))
# Out:
# 698

# %%
len(array)
# Out:
# 8

# %%
a=np.array([[3,3],[2,2],[2,2]])

# %%
b,c=a.shape

# %%
b
# Out:
# 3

# %%
c
# Out:
# 2
