# %% [markdown]
# # 以下テンプレート

# %%
# 表示用
from tqdm import tqdm
from tqdm import tnrange, tqdm_notebook

# %%
import numpy as np
import datetime
import os
import copy

# Parametor about Sensor
SensorNum=1 # Sensor number
#SensorAxis='AccX' # Axis

# Define Data Name
DATE= str( datetime.date.today() )+'/'
TITLE="Participants01_First_1/"
Label = ['LeftHand','RightHand','LeftLeg','Rightleg','West','Chest']

# Parametor about " Data Path"
DataPath = "/media/takeyama/Transfer/02_ActivityResearch/Paticipants01/01_First/20161018-105301/mem/"
StorePath = "/media/takeyama/Transfer/02_ActivityResearch/"

if not os.path.exists(StorePath+TITLE+'dictionary/'): 
    os.makedirs(StorePath+TITLE+'dictionary/')
DictionaryDataPath=StorePath+TITLE+'dictionary/'

if not os.path.exists(StorePath+TITLE+'window/'): 
    os.makedirs(StorePath+TITLE+'window/')
WindowDataPath=StorePath+TITLE+'window/'

if not os.path.exists(StorePath+TITLE+DATE+'studyOutput/'): 
    os.makedirs(StorePath+TITLE+DATE+'studyOutput/')
StudyOutputPath=StorePath+TITLE+DATE+'studyOutput/'

if not os.path.exists(StorePath+TITLE+DATE+'parametor/'): 
    os.makedirs(StorePath+TITLE+DATE+'parametor/')
ParametorPath=StorePath+TITLE+DATE+'parametor/'

if not os.path.exists(StorePath+TITLE+DATE+'result/'): 
    os.makedirs(StorePath+TITLE+DATE+'result/')
ResultPath=StorePath+TITLE+DATE+'result/'

if not os.path.exists(StorePath+TITLE+DATE+'graph/'): 
    os.makedirs(StorePath+TITLE+DATE+'graph/')
GraphPath=StorePath+TITLE+DATE+'graph/'

# %% [markdown]
# **センサデータの読み込み**

# %%
# センサデータのcsvファイル名をリストに集約する関数
def SensorDataFileNameList(path):
    l = os.listdir(DataPath)
    FilePath =[]
    SensorName = []
    
    for n in range(len(l)):
        if (l[n][:4].find('mem-') != -1):
            FilePath.append(l[n])
            SensorName.append(l[n][4:15])
    
    return FilePath,SensorName

# %% [markdown]
# CSVを読み込んで，CSVの中身を辞書型で表現する．

# %%
def ImportCSV(csv_file,SensorName,mode='Round'):
    import pandas as pd
    '''
    ~Argument~
    csv_file -> ファイル名 
    mode Round -> 四捨五入
         Roundup -> 切り上げ
         Rounddown -> 切り捨て
    
    ~Conversion~
    Acc Data  [0.1mG]=>[G]
    Gyr Data  [0.01dps]=>[dps]   ...dps=degree per second
    '''
    # data dictionary 
    RawData={}   
    AccConversion = 0.1 * 0.001
    GyrConversion = 0.01
    
    # design dataframe and import csv
    data = pd.read_csv(csv_file)
    data.columns=[u'Type',u'Time',u'AccX',u'AccY',u'AccZ',u'GyrX',u'GyrY',u'GyrZ']
    data = data[ data['Type']=='ags']

    # convert numpy.darray 

    AccX=data.AccX.values*AccConversion
    AccY=data.AccY.values*AccConversion
    AccZ=data.AccZ.values*AccConversion
    
    GyrX=data.GyrX.values*GyrConversion
    GyrY=data.GyrY.values*GyrConversion
    GyrZ=data.GyrZ.values*GyrConversion

    # regist each raw data 
    RawData['AccX'] = AccX
    RawData['AccY'] = AccY
    RawData['AccZ'] = AccZ
    RawData['GyrX'] = GyrX
    RawData['GyrY'] = GyrY
    RawData['GyrZ'] = GyrZ
    RawData['Name'] = SensorName

    RawData['Time'] = data.Time.values

    return RawData

# %%
# FFT library
from scipy import fftpack
from scipy import signal

# Graph Plot
import matplotlib.pyplot as plt

# Generate WindowFrame Function
from mymodule import window

# timer
import time

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.datasets import cifar10
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import SGD, Adadelta, Adagrad, Adam, Adamax, RMSprop, Nadam
from keras.utils import np_utils
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.utils.visualize_util import model_to_dot, plot
from keras import backend as K
from keras.layers import Input, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping

import matplotlib.image as mpimg
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5005)

# %% [markdown]
# **Phase1 計測データの取得**
#
# ここで行うことは，学習に用いるnpzファイルを読み込む

# %%
print DictionaryDataPath
# Out:
# /media/takeyama/Transfer/02_ActivityResearch/Participants01_First_1/dictionary/

# %%
DictName=os.listdir(DictionaryDataPath)
print DictName
# Out:
# ['Chest.npz', 'LeftHand.npz', 'LeftLeg.npz', 'RightHand.npz', 'Rightleg.npz', 'West.npz']

# %%
Sensor1 = np.load(DictionaryDataPath+DictName[0])['data'][()]
Sensor2 = np.load(DictionaryDataPath+DictName[1])['data'][()]
Sensor3 = np.load(DictionaryDataPath+DictName[2])['data'][()]
Sensor4 = np.load(DictionaryDataPath+DictName[3])['data'][()]
Sensor5 = np.load(DictionaryDataPath+DictName[4])['data'][()]
Sensor6 = np.load(DictionaryDataPath+DictName[5])['data'][()]

# %% [markdown]
# **Phase2 window flame 作成 & Learning**

# %%
def AutoEncoder(TrainWindow,TestWindow,dim,opt,cname,batchSize):
    """
    TrainWindow: 訓練データ
    TestWindow: テストデータ
    dim: 中間層の次元数
    opt: 最適化関数
    cname: 各種データを保存する用の共通の名前
    """
    input_img = Input(shape=( TrainWindow.shape[1] ,))
    encoded = Dense(dim, activation='tanh')(input_img)
    decoded = Dense( TrainWindow.shape[1] , activation='linear')(encoded)
    autoencoder = Model(input=input_img, output=decoded)
    encoder = Model(input=input_img, output=encoded)
    encoded_input = Input(shape=(dim,))
    decoder_layer = autoencoder.layers[-1]
    decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))
    autoencoder.compile(optimizer=opt, loss='mse')

    #plot(autoencoder,  to_file=StudyDataModelPicPath+SaveFileNameNet+'.png')
    
    #early_stopping = EarlyStopping(monitor='val_loss', patience=5)
    hist = autoencoder.fit(TrainWindow, TestWindow,
                    nb_epoch=50,
                    verbose=2,
                    batch_size=batchSize,
                    shuffle=False,
                    validation_data=(TrainWindow, TestWindow),
                    #callbacks=[early_stopping]
                          )
    time.sleep(0.1)

    encoded_imgs = encoder.predict(TrainWindow,batch_size=batchSize,verbose=1)
    decoded_imgs = decoder.predict(encoded_imgs,batch_size=batchSize,verbose=1)

    np.savez(StudyOutputPath+cname+'_Encoded',data=encoded_imgs)
    np.savez(StudyOutputPath+cname+'_Decoded',data=decoded_imgs)

    # save model and wights
    json_string = encoder.to_json()
    open(StudyOutputPath+cname+'_Encoded'+'.json', 'w').write(json_string)
    encoder.save_weights(ParametorPath+cname+'Encode_weights.h5',overwrite=True)

    json_string = decoder.to_json()
    open(StudyOutputPath+cname+'_Decoded'+'.json', 'w').write(json_string)
    decoder.save_weights(ParametorPath+cname+'Decord_weights.h5',overwrite=True)

    json_string = autoencoder.to_json()
    open(StudyOutputPath+cname+'_Net'+'.json', 'w').write(json_string)
    autoencoder.save_weights(ParametorPath+cname+'Net_weights.h5',overwrite=True)

    # plot loss
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']

    nb_epoch = len(loss)
    plt.plot(range(nb_epoch), loss, marker='.', label='loss')
    plt.plot(range(nb_epoch), val_loss, marker='.', label='val_loss')
    plt.legend(loc='best', fontsize=10)
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.savefig(ResultPath+cname+'.png')
    plt.show()

# %%
def GetWindowFrame(windowName, dataRaw, wWidth, sWidth, PATH):
    """
    data　ウィンドウフレームに変換するデータ
    registName　ウィンドウフレームに登録するデータの名前
    windowWidth　ウィンドウ幅
    slidingWidth　スライド幅
    PATH ウィドウフレームを保存するディレクトリ
    
    
    About Function:
        与えられたdataからウィンドウ幅windowWidth,スライド幅slidingWidthにしたがって
        registNameのウィドウフレームを返す．
        また，与えれたPATH内に同様なパラメータ( WindowWidth, slidingWidth)かつ同様な
        windowNameのものがある場合，そのデータを返す．
        この関数が登録，ウィンドウフレームに変換できるデータは１つとする
    """
    storedName = windowName+'_Win='+str(wWidth).zfill(4)+'_Sld='+str(sWidth).zfill(4)+'.npz'
    l = os.listdir(PATH)
    
    if storedName in l:
        print "this data had finished making"
        return np.load(PATH+storedName)['data'][()]
    
    w=window()
    w.SetData(windowName,dataRaw)    
    wind=w.Compile(wWidth,sWidth)
    windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
    np.savez(PATH+storedName,data=wind)

    return wind

# %%
GetWindowFrame('AccX',Sensor1['AccX'],256,256/8,WindowDataPath)
# Out:
# this data had finished making
# array([[ 0.8825,  0.8755,  0.8711, ...,  0.9233,  0.925 ,  0.9206],
#        [ 0.8674,  0.8728,  0.8821, ...,  0.8264,  0.824 ,  0.8271],
#        [ 0.8371,  0.8437,  0.8447, ...,  0.8532,  0.8471,  0.8498],
#        ...,
#        [-0.1003, -0.0998, -0.0912, ..., -0.0995, -0.0942, -0.0925],
#        [-0.1   , -0.1025, -0.1022, ..., -0.0939, -0.0986, -0.0966],
#        [-0.0939, -0.0978, -0.0981, ..., -0.0976, -0.1015, -0.0973]])

# %% [markdown]
# # denoizng AutoEncoder

# %% [markdown]
# ノイズの加え方はとても簡単
#
# ``` python
# noise_factor = 0.5
# x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
# x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
# ```
#
# 以上のように入力データに加えるだけ
# いきなり，学習するのではなくノイズを加えたらどのように変化するのかみてみよう

# %%
windowRaw = GetWindowFrame('AccX',Sensor1['AccX'],256,32,WindowDataPath)
# Out:
# this data had finished making

# %%
noiseFactor =0.5

# %%
windowNoise = windowRaw + noiseFactor*np.random.normal(loc=0.0,scale=1.0,size=windowRaw.shape)

# %%
print windowRaw.shape
print windowNoise.shape
# Out:
# (33676, 256)
# (33676, 256)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

ax.set_xlabel('Time')
ax.set_ylabel('AccX')
RngPlotWidth = 5

ax.plot(range(i*wind.shape[1],(i+1)*wind.shape[1]), wind[RngPlotStart+i,:wind.shape[1]],label='Sensor1'+'WindNum'+str(i))

# %% [markdown]
# # スクリプトの目的
# 本スクリプトの目的および学習方法を明記する
# 本スクリプトの目的は，**学習パラメータを今までのと比較して大きくことから，学習にどのような影響を与えるのか確認する**
#
# パラメータ
# * window幅 256,512,1024,2048,4096
# * slidign幅 window幅/8
# * Batch_size 32
# * Optimizer Adam

# %%
# loop windowWidth
WindowWidth = np.array( [256,512,1024,2048,4096] )
SlidingWidth = WindowWidth/8
BatchSize = 32
Optim='Adam'
AEDimention = 16

for WindowNum,SlidingNum in zip(WindowWidth,SlidingWidth):
    windoW = GetWindowFrame('AccX',Sensor1['AccX'],WindowNum,SlidingNum,WindowDataPath)
    
    print "hiden node = "+str(AEDimention)
    
    CommonName='_dim='+str(AEDimention)+'_Win='+str(WindowNum).zfill(4)+'_Sld='+str(SlidingNum).zfill(4)+\
        '_'+Optim+'_AEDimention='+str(AEDimention).zfill(3)   
        
    print CommonName

    #np.savez(WindowDataPath+CommonName+'_Test',data=windoW)
    #np.savez(WindowDataPath+CommonName+'_Train',data=windoW)

    AutoEncoder(windoW,windoW,AEDimention,Optim,CommonName,BatchSize)
# Out:
# this data had finished making
# hiden node = 16
# _dim=16_Win=0256_Sld=0032_Adam_AEDimention=016
# Train on 33676 samples, validate on 33676 samples
# Epoch 1/50
# 0s - loss: 0.0253 - val_loss: 0.0324
# Epoch 2/50
# 0s - loss: 0.0094 - val_loss: 0.0153
# Epoch 3/50
# 0s - loss: 0.0075 - val_loss: 0.0076
# Epoch 4/50
# 0s - loss: 0.0065 - val_loss: 0.0048
# Epoch 5/50
# 0s - loss: 0.0058 - val_loss: 0.0050
# Epoch 6/50
# 0s - loss: 0.0054 - val_loss: 0.0046
# Epoch 7/50
# 0s - loss: 0.0050 - val_loss: 0.0037
# Epoch 8/50
# 0s - loss: 0.0046 - val_loss: 0.0042
# Epoch 9/50
# 0s - loss: 0.0044 - val_loss: 0.0074
# Epoch 10/50
# 0s - loss: 0.0044 - val_loss: 0.0078
# Epoch 11/50
# 0s - loss: 0.0042 - val_loss: 0.0062
# Epoch 12/50
# 0s - loss: 0.0041 - val_loss: 0.0073
# Epoch 13/50
# 0s - loss: 0.0040 - val_loss: 0.0063
# Epoch 14/50
# 0s - loss: 0.0042 - val_loss: 0.0073
# Epoch 15/50
# 0s - loss: 0.0041 - val_loss: 0.0060
# Epoch 16/50
# 0s - loss: 0.0040 - val_loss: 0.0061
# Epoch 17/50
# 0s - loss: 0.0041 - val_loss: 0.0059
# Epoch 18/50
# 0s - loss: 0.0041 - val_loss: 0.0056
# Epoch 19/50
# 0s - loss: 0.0041 - val_loss: 0.0053
# Epoch 20/50
# 0s - loss: 0.0042 - val_loss: 0.0053
# Epoch 21/50
# 0s - loss: 0.0040 - val_loss: 0.0047
# Epoch 22/50
# 0s - loss: 0.0040 - val_loss: 0.0041
# Epoch 23/50
# 0s - loss: 0.0038 - val_loss: 0.0049
# Epoch 24/50
# 0s - loss: 0.0039 - val_loss: 0.0037
# Epoch 25/50
# 0s - loss: 0.0038 - val_loss: 0.0038
# Epoch 26/50
# 0s - loss: 0.0037 - val_loss: 0.0041
# Epoch 27/50
# 0s - loss: 0.0037 - val_loss: 0.0042
# Epoch 28/50
# 0s - loss: 0.0039 - val_loss: 0.0035
# Epoch 29/50
# 0s - loss: 0.0038 - val_loss: 0.0033
# Epoch 30/50
# 0s - loss: 0.0038 - val_loss: 0.0032
# Epoch 31/50
# 0s - loss: 0.0038 - val_loss: 0.0030
# Epoch 32/50
# 0s - loss: 0.0037 - val_loss: 0.0034
# Epoch 33/50
# 0s - loss: 0.0038 - val_loss: 0.0029
# Epoch 34/50
# 0s - loss: 0.0037 - val_loss: 0.0032
# Epoch 35/50
# 0s - loss: 0.0038 - val_loss: 0.0030
# Epoch 36/50
# 0s - loss: 0.0037 - val_loss: 0.0038
# Epoch 37/50
# 0s - loss: 0.0036 - val_loss: 0.0027
# Epoch 38/50
# 0s - loss: 0.0038 - val_loss: 0.0031
# Epoch 39/50
# 0s - loss: 0.0038 - val_loss: 0.0031
# Epoch 40/50
# 0s - loss: 0.0037 - val_loss: 0.0031
# Epoch 41/50
# 0s - loss: 0.0036 - val_loss: 0.0032
# Epoch 42/50
# 0s - loss: 0.0035 - val_loss: 0.0037
# Epoch 43/50
# 0s - loss: 0.0035 - val_loss: 0.0045
# Epoch 44/50
# 0s - loss: 0.0042 - val_loss: 0.0030
# Epoch 45/50
# 0s - loss: 0.0040 - val_loss: 0.0032
# Epoch 46/50
# 0s - loss: 0.0026 - val_loss: 0.0079
# Epoch 47/50
# 0s - loss: 0.0048 - val_loss: 0.0047
# Epoch 48/50
# 0s - loss: 0.0038 - val_loss: 0.0032
# Epoch 49/50
# 0s - loss: 0.0035 - val_loss: 0.0029
# Epoch 50/50
# 0s - loss: 0.0050 - val_loss: 0.0032
# 32384/33676 [===========================>..] - ETA: 0s
# this data had finished making
# hiden node = 16
# _dim=16_Win=0512_Sld=0064_Adam_AEDimention=016
# Train on 16834 samples, validate on 16834 samples
# Epoch 1/50
# 0s - loss: 0.0401 - val_loss: 0.0492
# Epoch 2/50
# 0s - loss: 0.0189 - val_loss: 0.0372
# Epoch 3/50
# 0s - loss: 0.0129 - val_loss: 0.0274
# Epoch 4/50
# 0s - loss: 0.0119 - val_loss: 0.0291
# Epoch 5/50
# 0s - loss: 0.0115 - val_loss: 0.0303
# Epoch 6/50
# 0s - loss: 0.0109 - val_loss: 0.0297
# Epoch 7/50
# 0s - loss: 0.0101 - val_loss: 0.0264
# Epoch 8/50
# 0s - loss: 0.0096 - val_loss: 0.0223
# Epoch 9/50
# 0s - loss: 0.0089 - val_loss: 0.0214
# Epoch 10/50
# 0s - loss: 0.0074 - val_loss: 0.0169
# Epoch 11/50
# 0s - loss: 0.0094 - val_loss: 0.0191
# Epoch 12/50
# 0s - loss: 0.0072 - val_loss: 0.0141
# Epoch 13/50
# 0s - loss: 0.0076 - val_loss: 0.0216
# Epoch 14/50
# 0s - loss: 0.0073 - val_loss: 0.0168
# Epoch 15/50
# 0s - loss: 0.0077 - val_loss: 0.0197
# Epoch 16/50
# 0s - loss: 0.0081 - val_loss: 0.0168
# Epoch 17/50
# 0s - loss: 0.0085 - val_loss: 0.0204
# Epoch 18/50
# 0s - loss: 0.0089 - val_loss: 0.0323
# Epoch 19/50
# 0s - loss: 0.0092 - val_loss: 0.0196
# Epoch 20/50
# 0s - loss: 0.0080 - val_loss: 0.0259
# Epoch 21/50
# 0s - loss: 0.0088 - val_loss: 0.0291
# Epoch 22/50
# 0s - loss: 0.0092 - val_loss: 0.0287
# Epoch 23/50
# 0s - loss: 0.0095 - val_loss: 0.0233
# Epoch 24/50
# 0s - loss: 0.0089 - val_loss: 0.0126
# Epoch 25/50
# 0s - loss: 0.0079 - val_loss: 0.0159
# Epoch 26/50
# 0s - loss: 0.0082 - val_loss: 0.0116
# Epoch 27/50
# 0s - loss: 0.0076 - val_loss: 0.0133
# Epoch 28/50
# 0s - loss: 0.0079 - val_loss: 0.0174
# Epoch 29/50
# 0s - loss: 0.0078 - val_loss: 0.0221
# Epoch 30/50
# 0s - loss: 0.0092 - val_loss: 0.0196
# Epoch 31/50
# 0s - loss: 0.0084 - val_loss: 0.0143
# Epoch 32/50
# 0s - loss: 0.0076 - val_loss: 0.0122
# Epoch 33/50
# 0s - loss: 0.0077 - val_loss: 0.0133
# Epoch 34/50
# 0s - loss: 0.0071 - val_loss: 0.0175
# Epoch 35/50
# 0s - loss: 0.0067 - val_loss: 0.0160
# Epoch 36/50
# 0s - loss: 0.0070 - val_loss: 0.0117
# Epoch 37/50
# 0s - loss: 0.0048 - val_loss: 0.0052
# Epoch 38/50
# 0s - loss: 0.0043 - val_loss: 0.0054
# Epoch 39/50
# 0s - loss: 0.0047 - val_loss: 0.0056
# Epoch 40/50
# 0s - loss: 0.0042 - val_loss: 0.0044
# Epoch 41/50
# 0s - loss: 0.0043 - val_loss: 0.0040
# Epoch 42/50
# 0s - loss: 0.0044 - val_loss: 0.0048
# Epoch 43/50
# 0s - loss: 0.0041 - val_loss: 0.0039
# Epoch 44/50
# 0s - loss: 0.0041 - val_loss: 0.0043
# Epoch 45/50
# 0s - loss: 0.0040 - val_loss: 0.0046
# Epoch 46/50
# 0s - loss: 0.0050 - val_loss: 0.0061
# Epoch 47/50
# 0s - loss: 0.0052 - val_loss: 0.0093
# Epoch 48/50
# 0s - loss: 0.0041 - val_loss: 0.0063
# Epoch 49/50
# 0s - loss: 0.0042 - val_loss: 0.0051
# Epoch 50/50
# 0s - loss: 0.0048 - val_loss: 0.0056
# 16448/16834 [============================>.] - ETA: 0s
# this data had finished making
# hiden node = 16
# _dim=16_Win=1024_Sld=0128_Adam_AEDimention=016
# Train on 8413 samples, validate on 8413 samples
# Epoch 1/50
# 0s - loss: 0.0640 - val_loss: 0.0427
# Epoch 2/50
# 0s - loss: 0.0397 - val_loss: 0.0357
# Epoch 3/50
# 0s - loss: 0.0303 - val_loss: 0.0201
# Epoch 4/50
# 0s - loss: 0.0367 - val_loss: 0.0278
# Epoch 5/50
# 0s - loss: 0.0428 - val_loss: 0.0421
# Epoch 6/50
# 0s - loss: 0.0383 - val_loss: 0.0229
# Epoch 7/50
# 0s - loss: 0.0363 - val_loss: 0.0260
# Epoch 8/50
# 0s - loss: 0.0351 - val_loss: 0.0238
# Epoch 9/50
# 0s - loss: 0.0415 - val_loss: 0.0308
# Epoch 10/50
# 0s - loss: 0.0325 - val_loss: 0.0344
# Epoch 11/50
# 0s - loss: 0.0288 - val_loss: 0.0178
# Epoch 12/50
# 0s - loss: 0.0316 - val_loss: 0.0262
# Epoch 13/50
# 0s - loss: 0.0318 - val_loss: 0.0194
# Epoch 14/50
# 0s - loss: 0.0290 - val_loss: 0.0177
# Epoch 15/50
# 0s - loss: 0.0316 - val_loss: 0.0364
# Epoch 16/50
# 0s - loss: 0.0317 - val_loss: 0.0154
# Epoch 17/50
# 0s - loss: 0.0334 - val_loss: 0.0353
# Epoch 18/50
# 0s - loss: 0.0184 - val_loss: 0.0218
# Epoch 19/50
# 0s - loss: 0.0169 - val_loss: 0.0269
# Epoch 20/50
# 0s - loss: 0.0156 - val_loss: 0.0120
# Epoch 21/50
# 0s - loss: 0.0138 - val_loss: 0.0271
# Epoch 22/50
# 0s - loss: 0.0140 - val_loss: 0.0125
# Epoch 23/50
# 0s - loss: 0.0139 - val_loss: 0.0114
# Epoch 24/50
# 0s - loss: 0.0126 - val_loss: 0.0107
# Epoch 25/50
# 0s - loss: 0.0123 - val_loss: 0.0107
# Epoch 26/50
# 0s - loss: 0.0122 - val_loss: 0.0131
# Epoch 27/50
# 0s - loss: 0.0118 - val_loss: 0.0113
# Epoch 28/50
# 0s - loss: 0.0110 - val_loss: 0.0109
# Epoch 29/50
# 0s - loss: 0.0102 - val_loss: 0.0103
# Epoch 30/50
# 0s - loss: 0.0104 - val_loss: 0.0099
# Epoch 31/50
# 0s - loss: 0.0102 - val_loss: 0.0093
# Epoch 32/50
# 0s - loss: 0.0099 - val_loss: 0.0089
# Epoch 33/50
# 0s - loss: 0.0093 - val_loss: 0.0086
# Epoch 34/50
# 0s - loss: 0.0090 - val_loss: 0.0081
# Epoch 35/50
# 0s - loss: 0.0082 - val_loss: 0.0076
# Epoch 36/50
# 0s - loss: 0.0083 - val_loss: 0.0074
# Epoch 37/50
# 0s - loss: 0.0081 - val_loss: 0.0180
# Epoch 38/50
# 0s - loss: 0.0123 - val_loss: 0.0077
# Epoch 39/50
# 0s - loss: 0.0078 - val_loss: 0.0072
# Epoch 40/50
# 0s - loss: 0.0079 - val_loss: 0.0078
# Epoch 41/50
# 0s - loss: 0.0096 - val_loss: 0.0344
# Epoch 42/50
# 0s - loss: 0.0296 - val_loss: 0.0108
# Epoch 43/50
# 0s - loss: 0.0104 - val_loss: 0.0091
# Epoch 44/50
# 0s - loss: 0.0094 - val_loss: 0.0102
# Epoch 45/50
# 0s - loss: 0.0107 - val_loss: 0.0170
# Epoch 46/50
# 0s - loss: 0.0091 - val_loss: 0.0077
# Epoch 47/50
# 0s - loss: 0.0076 - val_loss: 0.0076
# Epoch 48/50
# 0s - loss: 0.0078 - val_loss: 0.0072
# Epoch 49/50
# 0s - loss: 0.0067 - val_loss: 0.0081
# Epoch 50/50
# 0s - loss: 0.0099 - val_loss: 0.0078
# 6464/8413 [======================>.......] - ETA: 0s
# this data had finished making
# hiden node = 16
# _dim=16_Win=2048_Sld=0256_Adam_AEDimention=016
# Train on 4203 samples, validate on 4203 samples
# Epoch 1/50
# 0s - loss: 0.0873 - val_loss: 0.0562
# Epoch 2/50
# 0s - loss: 0.0436 - val_loss: 0.0305
# Epoch 3/50
# 0s - loss: 0.0486 - val_loss: 0.0481
# Epoch 4/50
# 0s - loss: 0.0499 - val_loss: 0.0523
# Epoch 5/50
# 0s - loss: 0.0450 - val_loss: 0.0587
# Epoch 6/50
# 0s - loss: 0.0629 - val_loss: 0.0618
# Epoch 7/50
# 0s - loss: 0.0520 - val_loss: 0.0477
# Epoch 8/50
# 0s - loss: 0.0616 - val_loss: 0.0607
# Epoch 9/50
# 0s - loss: 0.0573 - val_loss: 0.0645
# Epoch 10/50
# 0s - loss: 0.0607 - val_loss: 0.0659
# Epoch 11/50
# 0s - loss: 0.0519 - val_loss: 0.0630
# Epoch 12/50
# 0s - loss: 0.0625 - val_loss: 0.0672
# Epoch 13/50
# 0s - loss: 0.0503 - val_loss: 0.0588
# Epoch 14/50
# 0s - loss: 0.0593 - val_loss: 0.0670
# Epoch 15/50
# 0s - loss: 0.0529 - val_loss: 0.0635
# Epoch 16/50
# 0s - loss: 0.0783 - val_loss: 0.0608
# Epoch 17/50
# 0s - loss: 0.0546 - val_loss: 0.0718
# Epoch 18/50
# 0s - loss: 0.0568 - val_loss: 0.0600
# Epoch 19/50
# 0s - loss: 0.0585 - val_loss: 0.0699
# Epoch 20/50
# 0s - loss: 0.0569 - val_loss: 0.0674
# Epoch 21/50
# 0s - loss: 0.0536 - val_loss: 0.0717
# Epoch 22/50
# 0s - loss: 0.0482 - val_loss: 0.0630
# Epoch 23/50
# 0s - loss: 0.0552 - val_loss: 0.0644
# Epoch 24/50
# 0s - loss: 0.0549 - val_loss: 0.0763
# Epoch 25/50
# 0s - loss: 0.0615 - val_loss: 0.0675
# Epoch 26/50
# 0s - loss: 0.0534 - val_loss: 0.0664
# Epoch 27/50
# 0s - loss: 0.0625 - val_loss: 0.0710
# Epoch 28/50
# 0s - loss: 0.0571 - val_loss: 0.0815
# Epoch 29/50
# 0s - loss: 0.0514 - val_loss: 0.0717
# Epoch 30/50
# 0s - loss: 0.0484 - val_loss: 0.0503
# Epoch 31/50
# 0s - loss: 0.0545 - val_loss: 0.0699
# Epoch 32/50
# 0s - loss: 0.0525 - val_loss: 0.0725
# Epoch 33/50
# 0s - loss: 0.0527 - val_loss: 0.0670
# Epoch 34/50
# 0s - loss: 0.0510 - val_loss: 0.0654
# Epoch 35/50
# 0s - loss: 0.0499 - val_loss: 0.0702
# Epoch 36/50
# 0s - loss: 0.0483 - val_loss: 0.0655
# Epoch 37/50
# 0s - loss: 0.0471 - val_loss: 0.0679
# Epoch 38/50
# 0s - loss: 0.0615 - val_loss: 0.0597
# Epoch 39/50
# 0s - loss: 0.0507 - val_loss: 0.0648
# Epoch 40/50
# 0s - loss: 0.0448 - val_loss: 0.0625
# Epoch 41/50
# 0s - loss: 0.0434 - val_loss: 0.0418
# Epoch 42/50
# 0s - loss: 0.0543 - val_loss: 0.0653
# Epoch 43/50
# 0s - loss: 0.0498 - val_loss: 0.0652
# Epoch 44/50
# 0s - loss: 0.0473 - val_loss: 0.0656
# Epoch 45/50
# 0s - loss: 0.0461 - val_loss: 0.0643
# Epoch 46/50
# 0s - loss: 0.0512 - val_loss: 0.0608
# Epoch 47/50
# 0s - loss: 0.0492 - val_loss: 0.0605
# Epoch 48/50
# 0s - loss: 0.0435 - val_loss: 0.0623
# Epoch 49/50
# 0s - loss: 0.0440 - val_loss: 0.0625
# Epoch 50/50
# 0s - loss: 0.0429 - val_loss: 0.0623
# 3264/4203 [======================>.......] - ETA: 0s
# this data had finished making
# hiden node = 16
# _dim=16_Win=4096_Sld=0512_Adam_AEDimention=016
# Train on 2098 samples, validate on 2098 samples
# Epoch 1/50
# 0s - loss: 0.1249 - val_loss: 0.0637
# Epoch 2/50
# 0s - loss: 0.0676 - val_loss: 0.0601
# Epoch 3/50
# 0s - loss: 0.0556 - val_loss: 0.0596
# Epoch 4/50
# 0s - loss: 0.0567 - val_loss: 0.0541
# Epoch 5/50
# 0s - loss: 0.0527 - val_loss: 0.0611
# Epoch 6/50
# 0s - loss: 0.0637 - val_loss: 0.0641
# Epoch 7/50
# 0s - loss: 0.0581 - val_loss: 0.0626
# Epoch 8/50
# 0s - loss: 0.0607 - val_loss: 0.0583
# Epoch 9/50
# 0s - loss: 0.0614 - val_loss: 0.0618
# Epoch 10/50
# 0s - loss: 0.0596 - val_loss: 0.0576
# Epoch 11/50
# 0s - loss: 0.0697 - val_loss: 0.0711
# Epoch 12/50
# 0s - loss: 0.0631 - val_loss: 0.0716
# Epoch 13/50
# 0s - loss: 0.0643 - val_loss: 0.0694
# Epoch 14/50
# 0s - loss: 0.0637 - val_loss: 0.0681
# Epoch 15/50
# 0s - loss: 0.0646 - val_loss: 0.0689
# Epoch 16/50
# 0s - loss: 0.0657 - val_loss: 0.0718
# Epoch 17/50
# 0s - loss: 0.0652 - val_loss: 0.0656
# Epoch 18/50
# 0s - loss: 0.0623 - val_loss: 0.0660
# Epoch 19/50
# 0s - loss: 0.0645 - val_loss: 0.0650
# Epoch 20/50
# 0s - loss: 0.0633 - val_loss: 0.0662
# Epoch 21/50
# 0s - loss: 0.0639 - val_loss: 0.0675
# Epoch 22/50
# 0s - loss: 0.0611 - val_loss: 0.0634
# Epoch 23/50
# 0s - loss: 0.0610 - val_loss: 0.0614
# Epoch 24/50
# 0s - loss: 0.0598 - val_loss: 0.0626
# Epoch 25/50
# 0s - loss: 0.0618 - val_loss: 0.0628
# Epoch 26/50
# 0s - loss: 0.0589 - val_loss: 0.0641
# Epoch 27/50
# 0s - loss: 0.0614 - val_loss: 0.0628
# Epoch 28/50
# 0s - loss: 0.0605 - val_loss: 0.0629
# Epoch 29/50
# 0s - loss: 0.0604 - val_loss: 0.0646
# Epoch 30/50
# 0s - loss: 0.0602 - val_loss: 0.0661
# Epoch 31/50
# 0s - loss: 0.0613 - val_loss: 0.0625
# Epoch 32/50
# 0s - loss: 0.0604 - val_loss: 0.0592
# Epoch 33/50
# 0s - loss: 0.0677 - val_loss: 0.0668
# Epoch 34/50
# 0s - loss: 0.0632 - val_loss: 0.0651
# Epoch 35/50
# 0s - loss: 0.0616 - val_loss: 0.0673
# Epoch 36/50
# 0s - loss: 0.0596 - val_loss: 0.0639
# Epoch 37/50
# 0s - loss: 0.0610 - val_loss: 0.0649
# Epoch 38/50
# 0s - loss: 0.0601 - val_loss: 0.0636
# Epoch 39/50
# 0s - loss: 0.0587 - val_loss: 0.0619
# Epoch 40/50
# 0s - loss: 0.0607 - val_loss: 0.0620
# Epoch 41/50
# 0s - loss: 0.0589 - val_loss: 0.0650
# Epoch 42/50
# 0s - loss: 0.0616 - val_loss: 0.0630
# Epoch 43/50
# 0s - loss: 0.0613 - val_loss: 0.0617
# Epoch 44/50
# 0s - loss: 0.0600 - val_loss: 0.0615
# Epoch 45/50
# 0s - loss: 0.0579 - val_loss: 0.0583
# Epoch 46/50
# 0s - loss: 0.0585 - val_loss: 0.0602
# Epoch 47/50
# 0s - loss: 0.0586 - val_loss: 0.0617
# Epoch 48/50
# 0s - loss: 0.0576 - val_loss: 0.0590
# Epoch 49/50
# 0s - loss: 0.0572 - val_loss: 0.0592
# Epoch 50/50
# 0s - loss: 0.0570 - val_loss: 0.0636
# 1888/2098 [=========================>....] - ETA: 0s

# %% [markdown]
# 学習の過程を見ると，明らかにおかしな学習をしていることがわかる．これの原因としてを列挙する
# * 学習の際に入力データをシャッフルせず，時系列順に渡しているから
# * 最適化方法が合ってない
# * バッチサイズが最適値でない
# 他にも原因あるが，とりあえず一番の内容はもう少し考える．
# まずは，最適化方法を試す．

# %%
# loop windowWidth
WindowWidth = np.array( [256,512,1024,2048,4096] )
SlidingWidth = WindowWidth/8
BatchSize = 32
Optim='rmsprop'
AEDimention = 16

for WindowNum,SlidingNum in zip(WindowWidth,SlidingWidth):
    windoW = GetWindowFrame('AccX',Sensor1['AccX'],WindowNum,SlidingNum,WindowDataPath)
    
    print "hiden node = "+str(AEDimention)
    CommonName='_dim='+str(AEDimention)+'_Win='+str(WindowNum).zfill(4)+'_Sld='+str(SlidingNum).zfill(4)+\
        '_'+Optim+'_AEDimention='+str(AEDimention).zfill(3)   
    print CommonName

    #np.savez(WindowDataPath+CommonName+'_Test',data=windoW)
    #np.savez(WindowDataPath+CommonName+'_Train',data=windoW)

    AutoEncoder(windoW,windoW,AEDimention,Optim,CommonName,BatchSize)
# Out:
# this data had finished making
# hiden node = 16
# _dim=16_Win=0256_Sld=0032_rmsprop_AEDimention=016
# Train on 33676 samples, validate on 33676 samples
# Epoch 1/50
# 0s - loss: 0.0189 - val_loss: 0.0094
# Epoch 2/50
# 0s - loss: 0.0058 - val_loss: 0.0086
# Epoch 3/50
# 0s - loss: 0.0053 - val_loss: 0.0080
# Epoch 4/50
# 0s - loss: 0.0050 - val_loss: 0.0077
# Epoch 5/50
# 0s - loss: 0.0048 - val_loss: 0.0076
# Epoch 6/50
# 0s - loss: 0.0046 - val_loss: 0.0076
# Epoch 7/50
# 0s - loss: 0.0045 - val_loss: 0.0075
# Epoch 8/50
# 0s - loss: 0.0044 - val_loss: 0.0074
# Epoch 9/50
# 0s - loss: 0.0043 - val_loss: 0.0075
# Epoch 10/50
# 0s - loss: 0.0042 - val_loss: 0.0076
# Epoch 11/50
# 0s - loss: 0.0042 - val_loss: 0.0075
# Epoch 12/50
# 0s - loss: 0.0042 - val_loss: 0.0075
# Epoch 13/50
# 0s - loss: 0.0041 - val_loss: 0.0075
# Epoch 14/50
# 0s - loss: 0.0041 - val_loss: 0.0073
# Epoch 15/50
# 0s - loss: 0.0040 - val_loss: 0.0074
# Epoch 16/50
# 0s - loss: 0.0040 - val_loss: 0.0073
# Epoch 17/50
# 0s - loss: 0.0040 - val_loss: 0.0073
# Epoch 18/50
# 0s - loss: 0.0040 - val_loss: 0.0073
# Epoch 19/50
# 0s - loss: 0.0039 - val_loss: 0.0076
# Epoch 20/50
# 0s - loss: 0.0039 - val_loss: 0.0076
# Epoch 21/50
# 0s - loss: 0.0039 - val_loss: 0.0077
# Epoch 22/50
# 0s - loss: 0.0039 - val_loss: 0.0075
# Epoch 23/50
# 0s - loss: 0.0039 - val_loss: 0.0074
# Epoch 24/50
# 0s - loss: 0.0039 - val_loss: 0.0076
# Epoch 25/50
# 0s - loss: 0.0039 - val_loss: 0.0074
# Epoch 26/50
# 0s - loss: 0.0038 - val_loss: 0.0075
# Epoch 27/50

# %% [markdown]
# バッチサイズを変更してみる，まずは試しに先ほどの半分で学習する

# %%
# loop windowWidth
WindowWidth = np.array( [256,512,1024,2048,4096] )
SlidingWidth = WindowWidth/8
BatchSize = 16
Optim='rmsprop'
AEDimention = 16

for WindowNum,SlidingNum in zip(WindowWidth,SlidingWidth):
    windoW = GetWindowFrame('AccX',Sensor1['AccX'],WindowNum,SlidingNum,WindowDataPath)
    
    print "hiden node = "+str(AEDimention)
    
    CommonName='_dim='+str(AEDimention)+'_Win='+str(WindowNum).zfill(4)+'_Sld='+str(SlidingNum).zfill(4)+\
        '_'+Optim+'_AEDimention='+str(AEDimention).zfill(3)   
    print CommonName

    #np.savez(WindowDataPath+CommonName+'_Test',data=windoW)
    #np.savez(WindowDataPath+CommonName+'_Train',data=windoW)

    AutoEncoder(windoW,windoW,AEDimention,Optim,CommonName,BatchSize)

# %% [markdown]
# 電話を受けてやっていくこと
# まず，学習方法のパラメータを変更して見ていく．
# まず，中間層の値を変えてみるー＞入力データと同じ，２分の１，４分の１，８分の１でやる
# 次に，最適化法保をＳＧＤ試す

# %%
# loop windowWidth
WindowWidth = np.array( [256,512,1024,2048,4096] )
SlidingWidth = WindowWidth/8
BatchSize = 32
Optim='sgd'
#AEDimention = WindowWidth, WindowWidth/2, WindowWidth/4, WindowWidth/8

for WindowNum,SlidingNum in zip(WindowWidth,SlidingWidth):
    windoW = GetWindowFrame('AccX',Sensor1['AccX'],WindowNum,SlidingNum,WindowDataPath)
        
    AEDimentionS=np.array([WindowNum,WindowNum/2,WindowNum/4,WindowNum/8])

    #np.savez(WindowDataPath+CommonName+'_Test',data=windoW)
    #np.savez(WindowDataPath+CommonName+'_Train',data=windoW)
    
    for AEDimention in AEDimentionS:
        print "hiden node = "+str(AEDimention)
            
        CommonName='_dim='+str(AEDimention)+'_Win='+str(WindowNum).zfill(4)+'_Sld='+str(SlidingNum).zfill(4)+\
        '_'+Optim+'_AEDimention='+str(AEDimention).zfill(3)   
        print CommonName
      
        AutoEncoder(windoW,windoW,AEDimention,Optim,CommonName,BatchSize)

# %% [markdown]
# 上の結果を見る限り，いい感じに学習できていることがわかった．興味として，上記の中間層の次元以外のパラメータを固定して，さらに次元を圧縮してみる．具体的には，1/8より圧縮してみる．

# %%
# loop windowWidth
WindowWidth = np.array( [256,512,1024,2048,4096] )
SlidingWidth = WindowWidth/8
BatchSize = 32
Optim='sgd'
#AEDimention = WindowWidth, WindowWidth/2, WindowWidth/4, WindowWidth/8

for WindowNum,SlidingNum in zip(WindowWidth,SlidingWidth):
    windoW = GetWindowFrame('AccX',Sensor1['AccX'],WindowNum,SlidingNum,WindowDataPath)
        
    AEDimentionS=np.array([WindowNum/8,WindowNum/16,WindowNum/32,WindowNum/64])

    #np.savez(WindowDataPath+CommonName+'_Test',data=windoW)
    #np.savez(WindowDataPath+CommonName+'_Train',data=windoW)
    
    for AEDimention in AEDimentionS:
        print "hiden node = "+str(AEDimention)
            
        CommonName='_dim='+str(AEDimention)+'_Win='+str(WindowNum).zfill(4)+'_Sld='+str(SlidingNum).zfill(4)+\
        '_'+Optim+'_AEDimention='+str(AEDimention).zfill(3)
        print CommonName

        AutoEncoder(windoW,windoW,AEDimention,Optim,CommonName,BatchSize)

# %% [markdown]
# Variational Auto Encoderのサンプルコード

# %%
'''This script demonstrates how to build a variational autoencoder with Keras.
Reference: "Auto-Encoding Variational Bayes" https://arxiv.org/abs/1312.6114
'''
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras import objectives
from keras.datasets import mnist

batch_size = 100
original_dim = 784
latent_dim = 2
intermediate_dim = 256
nb_epoch = 50
epsilon_std = 1.0

x = Input(batch_shape=(batch_size, original_dim))
h = Dense(intermediate_dim, activation='relu')(x)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)


def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,
                              std=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# we instantiate these layers separately so as to reuse them later
decoder_h = Dense(intermediate_dim, activation='relu')
decoder_mean = Dense(original_dim, activation='sigmoid')
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)


def vae_loss(x, x_decoded_mean):
    xent_loss = original_dim * objectives.binary_crossentropy(x, x_decoded_mean)
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return xent_loss + kl_loss

vae = Model(x, x_decoded_mean)
vae.compile(optimizer='rmsprop', loss=vae_loss)

# train the VAE on MNIST digits
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        shuffle=True,
        nb_epoch=nb_epoch,
        batch_size=batch_size,
        validation_data=(x_test, x_test))

# build a model to project inputs on the latent space
encoder = Model(x, z_mean)

# display a 2D plot of the digit classes in the latent space
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()

# build a digit generator that can sample from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_h_decoded = decoder_h(decoder_input)
_x_decoded_mean = decoder_mean(_h_decoded)
generator = Model(decoder_input, _x_decoded_mean)

# display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# linearly spaced coordinates on the unit square were transformed through the inverse CDF (ppf) of the Gaussian
# to produce values of the latent variables z, since the prior of the latent space is Gaussian
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()

# %%
print 'finish'

# %% [markdown]
# 手洗いの識別にて「タイムスライス」という言葉が出た．意味としては，Native Baisian Networkにて，あるデータiについての確率を過去からのデータから導出する際にその過去がどれくらいの過去なのかを示す．つまりP($X_i$)をP($X_(i-1)$)からP($X_{i-T_n})$)から導出するとした時の$T_n$がタイムスライスである．
#
# これは学習で言うバッチサイズと似ているのではないかと考える．今回学習は訓練データをシャッフルしてない．つまり，学習する際の訓練データの時系列は連続であると言える．
#
# よって，件の識別はタイムスライスの値によって識別率は変化するらしい．ならば，類似していると仮定するバッチサイズの大きさによって識別結果も変わるかどうか検証する．

# %%
# loop windowWidth
l=len(WindowWidth)*len(optimArray)
pbar = tqdm_notebook(total=l)
i=0
for WindowNum,SlidingNum in zip(WindowWidth,SlidingWidth):
    w=window()
    w.SetData('AccX',TrimData[0]['AccX'])
    wind=w.Compile(windowWidth=WindowNum,slidingWidth=SlidingNum)
    windoW=wind.reshape((len(wind),np.prod(wind.shape[1:])))
    
    for bs in [1,2,4,8,16,32]:
        print "hiden node = "+str(AEDimention)
        CommonName='_dim='+str(AEDimention).zfill(4)+'_Win='+str(WindowNum).zfill(4)
        CommonName=CommonName+'_Sld='+str(SlidingNum).zfill(4)+'_'+optName
        CommonName=CommonName+'BatchSize='+str(bs).zfill(2)
        print CommonName
        
        np.savez(WindowDataPath+CommonName+'_Test',data=windoW)
        np.savez(WindowDataPath+CommonName+'_Train',data=windoW)
        
        AutoEncoder(windoW,windoW,AEDimention,optimArray[2],CommonName,batchSize=bs)
        
        pbar.update(i+1)
pbar.close()
